# %% [markdown]
# # WeatherPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, WeatherPy.ipynb, uses a Python script to 
 #      visualize the weather of over 500 cities of varying distances from the equator. 
 #      The script uses the citipy Python library and the openWeatherMap API to create 
 #      a representative model of weather across cities.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubRoutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'WeatherPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('WeatherPy')

# %% [markdown]
# # <br> **Section 1: Weather Variables and Latitude**

# %% [markdown]
# ## **Section 1.1: Data Acquisition**

# %% [markdown]
# ### **List of Cities**

# %%
citiesListOfStrings \
    = api_function \
        .ReturnCitiesList()

# %% [markdown]
# ### **Weather Data from List of Cities**

# %%
cityWeatherDataFrame \
    = api_function \
        .ReturnWeatherDataFrame \
            (citiesListOfStrings)
# Out:
# DATA RETRIEVAL FOR CITY WEATHER DATAFRAME BEGINS...
#
#
# PROCESSING RECORD #2 OF SET 1 FOR CITY, grytviken.
#
# PROCESSING RECORD #3 OF SET 1 FOR CITY, bandar lampung.
#
# PROCESSING RECORD #4 OF SET 1 FOR CITY, pisco.
#
# PROCESSING RECORD #5 OF SET 1 FOR CITY, albany.
#
# PROCESSING RECORD #6 OF SET 1 FOR CITY, lemvig.
#
# PROCESSING RECORD #7 OF SET 1 FOR CITY, aspen.
#
# PROCESSING RECORD #8 OF SET 1 FOR CITY, luderitz.
#
# PROCESSING RECORD #9 OF SET 1 FOR CITY, bonthe.
#
# PROCESSING RECORD #10 OF SET 1 FOR CITY, papatowai.
#
# PROCESSING RECORD #11 OF SET 1 FOR CITY, adamstown.
#
# PROCESSING RECORD #12 OF SET 1 FOR CITY, olonkinbyen.
#
# PROCESSING RECORD #13 OF SET 1 FOR CITY, hithadhoo.
#
# PROCESSING RECORD #14 OF SET 1 FOR CITY, puerto baquerizo moreno.
#
# PROCESSING RECORD #15 OF SET 1 FOR CITY, hawaiian paradise park.
#
# PROCESSING RECORD #16 OF SET 1 FOR CITY, port alfred.
#
# PROCESSING RECORD #17 OF SET 1 FOR CITY, sitka.
#
# PROCESSING RECORD #18 OF SET 1 FOR CITY, port-aux-francais.
#
# PROCESSING RECORD #19 OF SET 1 FOR CITY, port isabel.
#
# PROCESSING RECORD #20 OF SET 1 FOR CITY, kasongo-lunda.
#
# PROCESSING RECORD #21 OF SET 1 FOR CITY, vila franca do campo.
#
# PROCESSING RECORD #22 OF SET 1 FOR CITY, uliastay.
#
# PROCESSING RECORD #23 OF SET 1 FOR CITY, waitangi.
#
# PROCESSING RECORD #24 OF SET 1 FOR CITY, bilibino.
#
# PROCESSING RECORD #25 OF SET 1 FOR CITY, longyearbyen.
#
# PROCESSING RECORD #26 OF SET 1 FOR CITY, tommot.
#
# PROCESSING RECORD #27 OF SET 1 FOR CITY, shangqiu.
#
# PROCESSING RECORD #28 OF SET 1 FOR CITY, kalevala.
#
# PROCESSING RECORD #29 OF SET 1 FOR CITY, stanthorpe.
#
# PROCESSING RECORD #30 OF SET 1 FOR CITY, colonia.
#
# PROCESSING RECORD #31 OF SET 1 FOR CITY, hermanus.
#
# PROCESSING RECORD #32 OF SET 1 FOR CITY, yellowknife.
#
# PROCESSING RECORD #33 OF SET 1 FOR CITY, saint-philippe.
#
# PROCESSING RECORD #34 OF SET 1 FOR CITY, salgado.
#
# PROCESSING RECORD #35 OF SET 1 FOR CITY, fale old settlement.
#
# PROCESSING RECORD #36 OF SET 1 FOR CITY, san antonio de pale.
#
# PROCESSING RECORD #37 OF SET 1 FOR CITY, rawson.
#
# PROCESSING RECORD #38 OF SET 1 FOR CITY, as saffaniyah.
#
# PROCESSING RECORD #39 OF SET 1 FOR CITY, tavrichanka.
#
# PROCESSING RECORD #40 OF SET 1 FOR CITY, katabu.
#
# PROCESSING RECORD #41 OF SET 1 FOR CITY, constantia.
#
# PROCESSING RECORD #42 OF SET 1 FOR CITY, petropavlovsk-kamchatsky.
#
# PROCESSING RECORD #43 OF SET 1 FOR CITY, stanley.
#
# PROCESSING RECORD #44 OF SET 1 FOR CITY, puerto ayora.
#
# PROCESSING RECORD #45 OF SET 1 FOR CITY, isafjordur.
#
# PROCESSING RECORD #46 OF SET 1 FOR CITY, nemuro.
#
# PROCESSING RECORD #47 OF SET 1 FOR CITY, asau.
#
# PROCESSING RECORD #48 OF SET 1 FOR CITY, ushuaia.
#
# PROCESSING RECORD #49 OF SET 1 FOR CITY, checker hall.
#
# The script did not find the city, checker hall. Skipping...
#
# PROCESSING RECORD #50 OF SET 1 FOR CITY, saipan.
#
# PROCESSING RECORD #51 OF SET 1 FOR CITY, nuuk.
#
# PROCESSING RECORD #1 OF SET 2 FOR CITY, bethel.
#
# PROCESSING RECORD #2 OF SET 2 FOR CITY, georgetown.
#
# PROCESSING RECORD #3 OF SET 2 FOR CITY, boundiali.
#
# PROCESSING RECORD #4 OF SET 2 FOR CITY, samashki.
#
# PROCESSING RECORD #5 OF SET 2 FOR CITY, edinburgh of the seven seas.
#
# PROCESSING RECORD #6 OF SET 2 FOR CITY, piney green.
#
# PROCESSING RECORD #7 OF SET 2 FOR CITY, haiku-pauwela.
#
# PROCESSING RECORD #8 OF SET 2 FOR CITY, el bolson.
#
# PROCESSING RECORD #9 OF SET 2 FOR CITY, peterhead.
#
# PROCESSING RECORD #10 OF SET 2 FOR CITY, twon-brass.
#
# PROCESSING RECORD #11 OF SET 2 FOR CITY, jua dos vieiras.
#
# The script did not find the city, jua dos vieiras. Skipping...
#
# PROCESSING RECORD #12 OF SET 2 FOR CITY, hammerfest.
#
# PROCESSING RECORD #13 OF SET 2 FOR CITY, puerto natales.
#
# PROCESSING RECORD #14 OF SET 2 FOR CITY, shibetsu.
#
# PROCESSING RECORD #15 OF SET 2 FOR CITY, tsiombe.
#
# PROCESSING RECORD #16 OF SET 2 FOR CITY, ilhabela.
#
# PROCESSING RECORD #17 OF SET 2 FOR CITY, bhayavadar.
#
# PROCESSING RECORD #18 OF SET 2 FOR CITY, liberia.
#
# PROCESSING RECORD #19 OF SET 2 FOR CITY, ancud.
#
# PROCESSING RECORD #20 OF SET 2 FOR CITY, invercargill.
#
# PROCESSING RECORD #21 OF SET 2 FOR CITY, ilulissat.
#
# PROCESSING RECORD #22 OF SET 2 FOR CITY, ribeira grande.
#
# PROCESSING RECORD #23 OF SET 2 FOR CITY, trapani.
#
# PROCESSING RECORD #24 OF SET 2 FOR CITY, ramanuj ganj.
#
# PROCESSING RECORD #25 OF SET 2 FOR CITY, pandan.
#
# PROCESSING RECORD #26 OF SET 2 FOR CITY, turbat.
#
# PROCESSING RECORD #27 OF SET 2 FOR CITY, port mathurin.
#
# PROCESSING RECORD #28 OF SET 2 FOR CITY, puerto san carlos.
#
# The script did not find the city, puerto san carlos. Skipping...
#
# PROCESSING RECORD #29 OF SET 2 FOR CITY, guerrero negro.
#
# PROCESSING RECORD #30 OF SET 2 FOR CITY, kapa'a.
#
# PROCESSING RECORD #31 OF SET 2 FOR CITY, blackmans bay.
#
# PROCESSING RECORD #32 OF SET 2 FOR CITY, krasnoarmeysk.
#
# PROCESSING RECORD #33 OF SET 2 FOR CITY, punta arenas.
#
# PROCESSING RECORD #34 OF SET 2 FOR CITY, jamestown.
#
# PROCESSING RECORD #35 OF SET 2 FOR CITY, aripuana.
#
# PROCESSING RECORD #36 OF SET 2 FOR CITY, burang.
#
# PROCESSING RECORD #37 OF SET 2 FOR CITY, harper.
#
# PROCESSING RECORD #38 OF SET 2 FOR CITY, udachny.
#
# PROCESSING RECORD #39 OF SET 2 FOR CITY, vadso.
#
# PROCESSING RECORD #40 OF SET 2 FOR CITY, selfoss.
#
# PROCESSING RECORD #41 OF SET 2 FOR CITY, port augusta.
#
# PROCESSING RECORD #42 OF SET 2 FOR CITY, west island.
#
# PROCESSING RECORD #43 OF SET 2 FOR CITY, mandimba.
#
# The script did not find the city, mandimba. Skipping...
#
# PROCESSING RECORD #44 OF SET 2 FOR CITY, benito juarez.
#
# PROCESSING RECORD #45 OF SET 2 FOR CITY, st. john's.
#
# PROCESSING RECORD #46 OF SET 2 FOR CITY, maragogi.
#
# PROCESSING RECORD #47 OF SET 2 FOR CITY, zhigalovo.
#
# PROCESSING RECORD #48 OF SET 2 FOR CITY, lebu.
#
# PROCESSING RECORD #49 OF SET 2 FOR CITY, talnakh.
#
# PROCESSING RECORD #50 OF SET 2 FOR CITY, happy valley-goose bay.
#
# PROCESSING RECORD #1 OF SET 3 FOR CITY, tiksi.
#
# PROCESSING RECORD #2 OF SET 3 FOR CITY, chaguanas.
#
# PROCESSING RECORD #3 OF SET 3 FOR CITY, bredasdorp.
#
# PROCESSING RECORD #4 OF SET 3 FOR CITY, kingston.
#
# PROCESSING RECORD #5 OF SET 3 FOR CITY, taghazout.
#
# PROCESSING RECORD #6 OF SET 3 FOR CITY, halifax.
#
# PROCESSING RECORD #7 OF SET 3 FOR CITY, 'ohonua.
#
# The script did not find the city, 'ohonua. Skipping...
#
# PROCESSING RECORD #8 OF SET 3 FOR CITY, severo-yeniseyskiy.
#
# PROCESSING RECORD #9 OF SET 3 FOR CITY, kralendijk.
#
# PROCESSING RECORD #10 OF SET 3 FOR CITY, norilsk.
#
# PROCESSING RECORD #11 OF SET 3 FOR CITY, new norfolk.
#
# PROCESSING RECORD #12 OF SET 3 FOR CITY, taiohae.
#
# The script did not find the city, taiohae. Skipping...
#
# PROCESSING RECORD #13 OF SET 3 FOR CITY, antsiranana.
#
# PROCESSING RECORD #14 OF SET 3 FOR CITY, boende.
#
# PROCESSING RECORD #15 OF SET 3 FOR CITY, san patricio.
#
# PROCESSING RECORD #16 OF SET 3 FOR CITY, iqaluit.
#
# PROCESSING RECORD #17 OF SET 3 FOR CITY, weno.
#
# PROCESSING RECORD #18 OF SET 3 FOR CITY, conde.
#
# PROCESSING RECORD #19 OF SET 3 FOR CITY, pontianak.
#
# PROCESSING RECORD #20 OF SET 3 FOR CITY, alice springs.
#
# PROCESSING RECORD #21 OF SET 3 FOR CITY, ust-tsilma.
#
# PROCESSING RECORD #22 OF SET 3 FOR CITY, ketchikan.
#
# PROCESSING RECORD #23 OF SET 3 FOR CITY, suoyarvi.
#
# PROCESSING RECORD #24 OF SET 3 FOR CITY, tranovaho.
#
# The script did not find the city, tranovaho. Skipping...
#
# PROCESSING RECORD #25 OF SET 3 FOR CITY, crane.
#
# PROCESSING RECORD #26 OF SET 3 FOR CITY, enewetak.
#
# PROCESSING RECORD #27 OF SET 3 FOR CITY, codrington.
#
# PROCESSING RECORD #28 OF SET 3 FOR CITY, portland.
#
# PROCESSING RECORD #29 OF SET 3 FOR CITY, margaret river.
#
# PROCESSING RECORD #30 OF SET 3 FOR CITY, bereket.
#
# PROCESSING RECORD #31 OF SET 3 FOR CITY, kodiak.
#
# PROCESSING RECORD #32 OF SET 3 FOR CITY, bhuj.
#
# PROCESSING RECORD #33 OF SET 3 FOR CITY, college.
#
# PROCESSING RECORD #34 OF SET 3 FOR CITY, saint joseph.
#
# PROCESSING RECORD #35 OF SET 3 FOR CITY, ola.
#
# PROCESSING RECORD #36 OF SET 3 FOR CITY, logan.
#
# PROCESSING RECORD #37 OF SET 3 FOR CITY, valdez.
#
# PROCESSING RECORD #38 OF SET 3 FOR CITY, antofagasta.
#
# PROCESSING RECORD #39 OF SET 3 FOR CITY, kismayo.
#
# PROCESSING RECORD #40 OF SET 3 FOR CITY, bhisho.
#
# PROCESSING RECORD #41 OF SET 3 FOR CITY, pariaman.
#
# PROCESSING RECORD #42 OF SET 3 FOR CITY, ghat.
#
# PROCESSING RECORD #43 OF SET 3 FOR CITY, vorgashor.
#
# PROCESSING RECORD #44 OF SET 3 FOR CITY, glace bay.
#
# PROCESSING RECORD #45 OF SET 3 FOR CITY, oranjemund.
# PROCESSING RECORD #46 OF SET 3 FOR CITY, walvis bay.
#
# PROCESSING RECORD #47 OF SET 3 FOR CITY, ebon.
#
# PROCESSING RECORD #48 OF SET 3 FOR CITY, mukah.
#
# The script did not find the city, mukah. Skipping...
#
# PROCESSING RECORD #49 OF SET 3 FOR CITY, hasaki.
#
# PROCESSING RECORD #50 OF SET 3 FOR CITY, afaahiti.
#
# PROCESSING RECORD #1 OF SET 4 FOR CITY, grebenskaya.
#
# PROCESSING RECORD #2 OF SET 4 FOR CITY, port lincoln.
#
# PROCESSING RECORD #3 OF SET 4 FOR CITY, lihue.
#
# PROCESSING RECORD #4 OF SET 4 FOR CITY, springs.
#
# PROCESSING RECORD #5 OF SET 4 FOR CITY, aasiaat.
#
# PROCESSING RECORD #6 OF SET 4 FOR CITY, inverloch.
#
# PROCESSING RECORD #7 OF SET 4 FOR CITY, clarinda.
#
# PROCESSING RECORD #8 OF SET 4 FOR CITY, gadzhiyevo.
#
# PROCESSING RECORD #9 OF SET 4 FOR CITY, avarua.
#
# PROCESSING RECORD #10 OF SET 4 FOR CITY, nikolayevsk-on-amure.
#
# PROCESSING RECORD #11 OF SET 4 FOR CITY, agat village.
#
# PROCESSING RECORD #12 OF SET 4 FOR CITY, kruisfontein.
#
# PROCESSING RECORD #13 OF SET 4 FOR CITY, masterton.
#
# PROCESSING RECORD #14 OF SET 4 FOR CITY, kincardine.
#
# PROCESSING RECORD #15 OF SET 4 FOR CITY, prince rupert.
#
# PROCESSING RECORD #16 OF SET 4 FOR CITY, phan rang-thap cham.
#
# PROCESSING RECORD #17 OF SET 4 FOR CITY, ahmetli.
#
# PROCESSING RECORD #18 OF SET 4 FOR CITY, utrik.
#
# PROCESSING RECORD #19 OF SET 4 FOR CITY, qaqortoq.
#
# PROCESSING RECORD #20 OF SET 4 FOR CITY, kulob.
#
# PROCESSING RECORD #21 OF SET 4 FOR CITY, polyarnyy.
#
# PROCESSING RECORD #22 OF SET 4 FOR CITY, rio grande.
#
# PROCESSING RECORD #23 OF SET 4 FOR CITY, uray.
#
# PROCESSING RECORD #24 OF SET 4 FOR CITY, chiang rai.
#
# PROCESSING RECORD #25 OF SET 4 FOR CITY, trail.
#
# PROCESSING RECORD #26 OF SET 4 FOR CITY, wailua homesteads.
#
# PROCESSING RECORD #27 OF SET 4 FOR CITY, port saint john's.
#
# PROCESSING RECORD #28 OF SET 4 FOR CITY, nguigmi.
#
# PROCESSING RECORD #29 OF SET 4 FOR CITY, thompson.
#
# PROCESSING RECORD #30 OF SET 4 FOR CITY, caala.
#
# PROCESSING RECORD #31 OF SET 4 FOR CITY, chibougamau.
#
# PROCESSING RECORD #32 OF SET 4 FOR CITY, bodaybo.
#
# PROCESSING RECORD #33 OF SET 4 FOR CITY, el dorado.
#
# PROCESSING RECORD #34 OF SET 4 FOR CITY, yoloten.
#
# PROCESSING RECORD #35 OF SET 4 FOR CITY, dudinka.
#
# PROCESSING RECORD #36 OF SET 4 FOR CITY, malango.
#
# PROCESSING RECORD #37 OF SET 4 FOR CITY, zaozersk.
#
# PROCESSING RECORD #38 OF SET 4 FOR CITY, saint-jean-de-monts.
#
# PROCESSING RECORD #39 OF SET 4 FOR CITY, tindouf.
#
# PROCESSING RECORD #40 OF SET 4 FOR CITY, sinabang.
#
# PROCESSING RECORD #41 OF SET 4 FOR CITY, nurota.
#
# PROCESSING RECORD #42 OF SET 4 FOR CITY, darwin.
#
# PROCESSING RECORD #43 OF SET 4 FOR CITY, san sebastian de la gomera.
#
# PROCESSING RECORD #44 OF SET 4 FOR CITY, okhotsk.
#
# PROCESSING RECORD #45 OF SET 4 FOR CITY, bumba.
#
# PROCESSING RECORD #46 OF SET 4 FOR CITY, kavaratti.
#
# PROCESSING RECORD #47 OF SET 4 FOR CITY, enterprise.
#
# PROCESSING RECORD #48 OF SET 4 FOR CITY, eastbourne.
#
# PROCESSING RECORD #49 OF SET 4 FOR CITY, iquique.
#
# PROCESSING RECORD #50 OF SET 4 FOR CITY, carnarvon.
#
# PROCESSING RECORD #1 OF SET 5 FOR CITY, souda.
#
# PROCESSING RECORD #2 OF SET 5 FOR CITY, callao.
#
# PROCESSING RECORD #3 OF SET 5 FOR CITY, borkum.
#
# PROCESSING RECORD #4 OF SET 5 FOR CITY, narrabri.
#
# PROCESSING RECORD #5 OF SET 5 FOR CITY, phu kradueng.
#
# PROCESSING RECORD #6 OF SET 5 FOR CITY, jayapura.
#
# PROCESSING RECORD #7 OF SET 5 FOR CITY, pasni.
#
# PROCESSING RECORD #8 OF SET 5 FOR CITY, cargados carajos.
#
# The script did not find the city, cargados carajos. Skipping...
#
# PROCESSING RECORD #9 OF SET 5 FOR CITY, laguna.
#
# PROCESSING RECORD #10 OF SET 5 FOR CITY, noosa heads.
#
# PROCESSING RECORD #11 OF SET 5 FOR CITY, kataragama.
#
# The script did not find the city, kataragama. Skipping...
#
# PROCESSING RECORD #12 OF SET 5 FOR CITY, yinchuan.
#
# PROCESSING RECORD #13 OF SET 5 FOR CITY, kill devil hills.
#
# PROCESSING RECORD #14 OF SET 5 FOR CITY, port elizabeth.
#
# PROCESSING RECORD #15 OF SET 5 FOR CITY, dhidhdhoo.
#
# PROCESSING RECORD #16 OF SET 5 FOR CITY, maceio.
#
# PROCESSING RECORD #17 OF SET 5 FOR CITY, klyuchi.
#
# PROCESSING RECORD #18 OF SET 5 FOR CITY, pierre.
#
# PROCESSING RECORD #19 OF SET 5 FOR CITY, flying fish cove.
#
# PROCESSING RECORD #20 OF SET 5 FOR CITY, chiang klang.
#
# PROCESSING RECORD #21 OF SET 5 FOR CITY, tolanaro.
#
# PROCESSING RECORD #22 OF SET 5 FOR CITY, palopo.
#
# PROCESSING RECORD #23 OF SET 5 FOR CITY, sao joao da barra.
#
# PROCESSING RECORD #24 OF SET 5 FOR CITY, dawson creek.
#
# PROCESSING RECORD #25 OF SET 5 FOR CITY, takanabe.
#
# PROCESSING RECORD #26 OF SET 5 FOR CITY, coquimbo.
#
# PROCESSING RECORD #27 OF SET 5 FOR CITY, bizerte.
#
# PROCESSING RECORD #28 OF SET 5 FOR CITY, sao joao do piaui.
#
# PROCESSING RECORD #29 OF SET 5 FOR CITY, cidreira.
#
# PROCESSING RECORD #30 OF SET 5 FOR CITY, pimentel.
#
# PROCESSING RECORD #31 OF SET 5 FOR CITY, vizinga.
#
# PROCESSING RECORD #32 OF SET 5 FOR CITY, deniliquin.
#
# PROCESSING RECORD #33 OF SET 5 FOR CITY, buncrana.
#
# PROCESSING RECORD #34 OF SET 5 FOR CITY, karoi.
#
# PROCESSING RECORD #35 OF SET 5 FOR CITY, labuan.
#
# PROCESSING RECORD #36 OF SET 5 FOR CITY, hancheng.
#
# PROCESSING RECORD #37 OF SET 5 FOR CITY, machico.
#
# PROCESSING RECORD #38 OF SET 5 FOR CITY, saint-denis.
#
# PROCESSING RECORD #39 OF SET 5 FOR CITY, balikpapan.
#
# PROCESSING RECORD #40 OF SET 5 FOR CITY, iskateley.
#
# PROCESSING RECORD #41 OF SET 5 FOR CITY, ndibene dahra.
#
# PROCESSING RECORD #42 OF SET 5 FOR CITY, haimen.
#
# PROCESSING RECORD #43 OF SET 5 FOR CITY, sao gabriel da cachoeira.
#
# PROCESSING RECORD #44 OF SET 5 FOR CITY, noumea.
#
# PROCESSING RECORD #45 OF SET 5 FOR CITY, bria.
#
# PROCESSING RECORD #46 OF SET 5 FOR CITY, whitehorse.
#
# PROCESSING RECORD #47 OF SET 5 FOR CITY, ishikawa.
#
# PROCESSING RECORD #48 OF SET 5 FOR CITY, cockburn town.
#
# PROCESSING RECORD #49 OF SET 5 FOR CITY, susuman.
#
# PROCESSING RECORD #50 OF SET 5 FOR CITY, frontera.
#
# PROCESSING RECORD #1 OF SET 6 FOR CITY, tazovsky.
#
# PROCESSING RECORD #2 OF SET 6 FOR CITY, amga.
#
# PROCESSING RECORD #3 OF SET 6 FOR CITY, kapuskasing.
#
# PROCESSING RECORD #4 OF SET 6 FOR CITY, jerada.
#
# PROCESSING RECORD #5 OF SET 6 FOR CITY, chonchi.
#
# PROCESSING RECORD #6 OF SET 6 FOR CITY, kencong.
#
# PROCESSING RECORD #7 OF SET 6 FOR CITY, camayenne.
#
# PROCESSING RECORD #8 OF SET 6 FOR CITY, irati.
#
# PROCESSING RECORD #9 OF SET 6 FOR CITY, zapala.
#
# PROCESSING RECORD #10 OF SET 6 FOR CITY, bathurst.
#
# PROCESSING RECORD #11 OF SET 6 FOR CITY, armacao de buzios.
#
# PROCESSING RECORD #12 OF SET 6 FOR CITY, ndele.
#
# PROCESSING RECORD #13 OF SET 6 FOR CITY, wewak.
#
# PROCESSING RECORD #14 OF SET 6 FOR CITY, metahara.
#
# PROCESSING RECORD #15 OF SET 6 FOR CITY, port hedland.
#
# PROCESSING RECORD #16 OF SET 6 FOR CITY, borrazopolis.
#
# PROCESSING RECORD #17 OF SET 6 FOR CITY, bel ombre.
#
# PROCESSING RECORD #18 OF SET 6 FOR CITY, fort irwin.
#
# PROCESSING RECORD #19 OF SET 6 FOR CITY, karyes.
#
# PROCESSING RECORD #20 OF SET 6 FOR CITY, natal.
#
# PROCESSING RECORD #21 OF SET 6 FOR CITY, anadyr.
#
# PROCESSING RECORD #22 OF SET 6 FOR CITY, tromso.
#
# PROCESSING RECORD #23 OF SET 6 FOR CITY, itaporanga.
#
# PROCESSING RECORD #24 OF SET 6 FOR CITY, manaure.
#
# PROCESSING RECORD #25 OF SET 6 FOR CITY, sampit.
#
# PROCESSING RECORD #26 OF SET 6 FOR CITY, zuromin.
#
# PROCESSING RECORD #27 OF SET 6 FOR CITY, belyy yar.
#
# PROCESSING RECORD #28 OF SET 6 FOR CITY, saudarkrokur.
#
# PROCESSING RECORD #29 OF SET 6 FOR CITY, east ballina.
#
# PROCESSING RECORD #30 OF SET 6 FOR CITY, mount isa.
#
# PROCESSING RECORD #31 OF SET 6 FOR CITY, turpan.
#
# PROCESSING RECORD #32 OF SET 6 FOR CITY, dul'durga.
#
# PROCESSING RECORD #33 OF SET 6 FOR CITY, morehead city.
#
# PROCESSING RECORD #34 OF SET 6 FOR CITY, palangkaraya.
#
# PROCESSING RECORD #35 OF SET 6 FOR CITY, kerikeri.
#
# PROCESSING RECORD #36 OF SET 6 FOR CITY, san pedro pochutla.
#
# PROCESSING RECORD #37 OF SET 6 FOR CITY, nar'yan-mar.
#
# PROCESSING RECORD #38 OF SET 6 FOR CITY, rongelap.
#
# PROCESSING RECORD #39 OF SET 6 FOR CITY, polazna.
#
# PROCESSING RECORD #40 OF SET 6 FOR CITY, fortuna.
#
# PROCESSING RECORD #41 OF SET 6 FOR CITY, gantang.
#
# PROCESSING RECORD #42 OF SET 6 FOR CITY, patao.
#
# PROCESSING RECORD #43 OF SET 6 FOR CITY, ust-nera.
#
# PROCESSING RECORD #44 OF SET 6 FOR CITY, yonggang-up.
#
# PROCESSING RECORD #45 OF SET 6 FOR CITY, xining.
#
# PROCESSING RECORD #46 OF SET 6 FOR CITY, ylivieska.
#
# PROCESSING RECORD #47 OF SET 6 FOR CITY, hamilton.
# PROCESSING RECORD #48 OF SET 6 FOR CITY, ad dawadimi.
#
# PROCESSING RECORD #49 OF SET 6 FOR CITY, panama city beach.
#
# PROCESSING RECORD #50 OF SET 6 FOR CITY, ocean shores.
#
# PROCESSING RECORD #1 OF SET 7 FOR CITY, celestun.
#
# PROCESSING RECORD #2 OF SET 7 FOR CITY, chernyshevskiy.
#
# PROCESSING RECORD #3 OF SET 7 FOR CITY, cole harbour.
#
# PROCESSING RECORD #4 OF SET 7 FOR CITY, rakops.
#
# PROCESSING RECORD #5 OF SET 7 FOR CITY, mahibadhoo.
#
# PROCESSING RECORD #6 OF SET 7 FOR CITY, keflavik.
#
# PROCESSING RECORD #7 OF SET 7 FOR CITY, mangai.
#
# PROCESSING RECORD #8 OF SET 7 FOR CITY, basco.
#
# PROCESSING RECORD #9 OF SET 7 FOR CITY, tefe.
#
# PROCESSING RECORD #10 OF SET 7 FOR CITY, lerwick.
#
# PROCESSING RECORD #11 OF SET 7 FOR CITY, kidal.
#
# PROCESSING RECORD #12 OF SET 7 FOR CITY, montepuez.
#
# PROCESSING RECORD #13 OF SET 7 FOR CITY, namibe.
#
# PROCESSING RECORD #14 OF SET 7 FOR CITY, kyshtovka.
#
# PROCESSING RECORD #15 OF SET 7 FOR CITY, lompoc.
#
# PROCESSING RECORD #16 OF SET 7 FOR CITY, ulanhot.
#
# PROCESSING RECORD #17 OF SET 7 FOR CITY, sisimiut.
#
# PROCESSING RECORD #18 OF SET 7 FOR CITY, namtsy.
#
# PROCESSING RECORD #19 OF SET 7 FOR CITY, tucuma.
#
# PROCESSING RECORD #20 OF SET 7 FOR CITY, nacozari viejo.
#
# PROCESSING RECORD #21 OF SET 7 FOR CITY, kenai.
#
# PROCESSING RECORD #22 OF SET 7 FOR CITY, lata.
#
# PROCESSING RECORD #23 OF SET 7 FOR CITY, dambatta.
#
# PROCESSING RECORD #24 OF SET 7 FOR CITY, rio branco do sul.
#
# PROCESSING RECORD #25 OF SET 7 FOR CITY, mount gambier.
#
# PROCESSING RECORD #26 OF SET 7 FOR CITY, gamba.
#
# PROCESSING RECORD #27 OF SET 7 FOR CITY, san luis.
#
# PROCESSING RECORD #28 OF SET 7 FOR CITY, vrangel'.
#
# PROCESSING RECORD #29 OF SET 7 FOR CITY, peniche.
#
# PROCESSING RECORD #30 OF SET 7 FOR CITY, homer.
#
# PROCESSING RECORD #31 OF SET 7 FOR CITY, perry.
#
# PROCESSING RECORD #32 OF SET 7 FOR CITY, fomboni.
#
# PROCESSING RECORD #33 OF SET 7 FOR CITY, kaa-khem.
#
# PROCESSING RECORD #34 OF SET 7 FOR CITY, chimoio.
#
# PROCESSING RECORD #35 OF SET 7 FOR CITY, sai buri.
#
# PROCESSING RECORD #36 OF SET 7 FOR CITY, le port.
#
# PROCESSING RECORD #37 OF SET 7 FOR CITY, labytnangi.
#
# PROCESSING RECORD #38 OF SET 7 FOR CITY, malvan.
#
# PROCESSING RECORD #39 OF SET 7 FOR CITY, badger.
#
# PROCESSING RECORD #40 OF SET 7 FOR CITY, vilyuchinsk.
#
# PROCESSING RECORD #41 OF SET 7 FOR CITY, aldan.
#
# PROCESSING RECORD #42 OF SET 7 FOR CITY, bloemhof.
#
# PROCESSING RECORD #43 OF SET 7 FOR CITY, nouadhibou.
#
# PROCESSING RECORD #44 OF SET 7 FOR CITY, labrador city.
#
# PROCESSING RECORD #45 OF SET 7 FOR CITY, yakeshi.
#
# PROCESSING RECORD #46 OF SET 7 FOR CITY, porto torres.
#
# PROCESSING RECORD #47 OF SET 7 FOR CITY, horqueta.
#
# PROCESSING RECORD #48 OF SET 7 FOR CITY, encrucijada.
#
# PROCESSING RECORD #49 OF SET 7 FOR CITY, egilsstadir.
#
# PROCESSING RECORD #50 OF SET 7 FOR CITY, paoua.
#
# PROCESSING RECORD #1 OF SET 8 FOR CITY, mariental.
#
# PROCESSING RECORD #2 OF SET 8 FOR CITY, ridder.
#
# PROCESSING RECORD #3 OF SET 8 FOR CITY, vingt cinq.
#
# The script did not find the city, vingt cinq. Skipping...
#
# PROCESSING RECORD #4 OF SET 8 FOR CITY, yelizovo.
#
# PROCESSING RECORD #5 OF SET 8 FOR CITY, porto novo.
#
# PROCESSING RECORD #6 OF SET 8 FOR CITY, luanda.
#
# PROCESSING RECORD #7 OF SET 8 FOR CITY, kununurra.
#
# PROCESSING RECORD #8 OF SET 8 FOR CITY, ascension.
#
# PROCESSING RECORD #9 OF SET 8 FOR CITY, humaita.
#
# PROCESSING RECORD #10 OF SET 8 FOR CITY, isle of lewis.
#
# The script did not find the city, isle of lewis. Skipping...
#
# PROCESSING RECORD #11 OF SET 8 FOR CITY, quepos.
#
# PROCESSING RECORD #12 OF SET 8 FOR CITY, caluula.
#
# PROCESSING RECORD #13 OF SET 8 FOR CITY, inongo.
#
# PROCESSING RECORD #14 OF SET 8 FOR CITY, atafu village.
#
# PROCESSING RECORD #15 OF SET 8 FOR CITY, campeni.
#
# PROCESSING RECORD #16 OF SET 8 FOR CITY, eduardo castex.
#
# PROCESSING RECORD #17 OF SET 8 FOR CITY, novouzensk.
#
# PROCESSING RECORD #18 OF SET 8 FOR CITY, forres.
#
# PROCESSING RECORD #19 OF SET 8 FOR CITY, bokani.
#
# PROCESSING RECORD #20 OF SET 8 FOR CITY, wolmaransstad.
#
# PROCESSING RECORD #21 OF SET 8 FOR CITY, ahau.
#
# The script did not find the city, ahau. Skipping...
#
# PROCESSING RECORD #22 OF SET 8 FOR CITY, poltavka.
#
# PROCESSING RECORD #23 OF SET 8 FOR CITY, sitangkai.
#
# PROCESSING RECORD #24 OF SET 8 FOR CITY, darnah.
#
# PROCESSING RECORD #25 OF SET 8 FOR CITY, estacion santa engracia.
#
# PROCESSING RECORD #26 OF SET 8 FOR CITY, berca.
#
# PROCESSING RECORD #27 OF SET 8 FOR CITY, nishinoomote.
#
# PROCESSING RECORD #28 OF SET 8 FOR CITY, luganville.
#
# PROCESSING RECORD #29 OF SET 8 FOR CITY, nuku'alofa.
#
# PROCESSING RECORD #30 OF SET 8 FOR CITY, brandon.
#
# PROCESSING RECORD #31 OF SET 8 FOR CITY, yoko.
#
# PROCESSING RECORD #32 OF SET 8 FOR CITY, fukuecho.
#
# PROCESSING RECORD #33 OF SET 8 FOR CITY, malpica.
#
# PROCESSING RECORD #34 OF SET 8 FOR CITY, palikir - national government center.
#
# PROCESSING RECORD #35 OF SET 8 FOR CITY, tamandare.
#
# PROCESSING RECORD #36 OF SET 8 FOR CITY, midvagur.
#
# PROCESSING RECORD #37 OF SET 8 FOR CITY, isangel.
#
# PROCESSING RECORD #38 OF SET 8 FOR CITY, lijiang.
#
# PROCESSING RECORD #39 OF SET 8 FOR CITY, queenstown.
#
# PROCESSING RECORD #40 OF SET 8 FOR CITY, tura.
#
# PROCESSING RECORD #41 OF SET 8 FOR CITY, diamantino.
#
# PROCESSING RECORD #42 OF SET 8 FOR CITY, waingapu.
#
# PROCESSING RECORD #43 OF SET 8 FOR CITY, flin flon.
#
# PROCESSING RECORD #44 OF SET 8 FOR CITY, bredy.
#
# PROCESSING RECORD #45 OF SET 8 FOR CITY, bramming.
#
# PROCESSING RECORD #46 OF SET 8 FOR CITY, tintafor.
#
# PROCESSING RECORD #47 OF SET 8 FOR CITY, gharb.
#
# The script did not find the city, gharb. Skipping...
#
# PROCESSING RECORD #48 OF SET 8 FOR CITY, claveria.
#
# PROCESSING RECORD #49 OF SET 8 FOR CITY, peschanokopskoye.
#
# PROCESSING RECORD #50 OF SET 8 FOR CITY, nova vicosa.
#
# PROCESSING RECORD #1 OF SET 9 FOR CITY, wamba.
#
# PROCESSING RECORD #2 OF SET 9 FOR CITY, murun-kuren.
#
# PROCESSING RECORD #3 OF SET 9 FOR CITY, kilju.
#
# PROCESSING RECORD #4 OF SET 9 FOR CITY, eaton.
#
# PROCESSING RECORD #5 OF SET 9 FOR CITY, char bhadrasan.
#
# PROCESSING RECORD #6 OF SET 9 FOR CITY, huanimaro.
#
# PROCESSING RECORD #7 OF SET 9 FOR CITY, sogndal.
#
# PROCESSING RECORD #8 OF SET 9 FOR CITY, bafoulabe.
#
# PROCESSING RECORD #9 OF SET 9 FOR CITY, launceston.
#
# PROCESSING RECORD #10 OF SET 9 FOR CITY, ma'an.
#
# PROCESSING RECORD #11 OF SET 9 FOR CITY, tyukhtet.
#
# PROCESSING RECORD #12 OF SET 9 FOR CITY, puerto colombia.
#
# PROCESSING RECORD #13 OF SET 9 FOR CITY, mount pearl.
#
# PROCESSING RECORD #14 OF SET 9 FOR CITY, joshimath.
#
# PROCESSING RECORD #15 OF SET 9 FOR CITY, alo.
#
# PROCESSING RECORD #16 OF SET 9 FOR CITY, tshikapa.
#
# PROCESSING RECORD #17 OF SET 9 FOR CITY, kalmunai.
#
# PROCESSING RECORD #18 OF SET 9 FOR CITY, bull savanna.
#
# PROCESSING RECORD #19 OF SET 9 FOR CITY, adelaide.
#
# PROCESSING RECORD #20 OF SET 9 FOR CITY, saint-pierre.
#
# PROCESSING RECORD #21 OF SET 9 FOR CITY, hanceville.
#
# PROCESSING RECORD #22 OF SET 9 FOR CITY, hisar.
#
# PROCESSING RECORD #23 OF SET 9 FOR CITY, kirakira.
#
# PROCESSING RECORD #24 OF SET 9 FOR CITY, hornell.
#
# PROCESSING RECORD #25 OF SET 9 FOR CITY, hirara.
#
# PROCESSING RECORD #26 OF SET 9 FOR CITY, shimanovsk.
#
# PROCESSING RECORD #27 OF SET 9 FOR CITY, macas.
#
# PROCESSING RECORD #28 OF SET 9 FOR CITY, nowy dwor gdanski.
#
# PROCESSING RECORD #29 OF SET 9 FOR CITY, daru.
#
# PROCESSING RECORD #30 OF SET 9 FOR CITY, voskresenskoye.
#
# PROCESSING RECORD #31 OF SET 9 FOR CITY, chapaev.
#
# PROCESSING RECORD #32 OF SET 9 FOR CITY, gueltat zemmour.
#
# The script did not find the city, gueltat zemmour. Skipping...
#
# PROCESSING RECORD #33 OF SET 9 FOR CITY, papao.
#
# PROCESSING RECORD #34 OF SET 9 FOR CITY, west valley.
#
# PROCESSING RECORD #35 OF SET 9 FOR CITY, hilo.
#
# PROCESSING RECORD #36 OF SET 9 FOR CITY, toga village.
#
# The script did not find the city, toga village. Skipping...
#
# PROCESSING RECORD #37 OF SET 9 FOR CITY, ljusdal.
#
# PROCESSING RECORD #38 OF SET 9 FOR CITY, alpena.
#
# PROCESSING RECORD #39 OF SET 9 FOR CITY, bamboo flat.
#
# PROCESSING RECORD #40 OF SET 9 FOR CITY, tocopilla.
#
# PROCESSING RECORD #41 OF SET 9 FOR CITY, cordele.
#
# PROCESSING RECORD #42 OF SET 9 FOR CITY, gazli.
#
# PROCESSING RECORD #43 OF SET 9 FOR CITY, rio gallegos.
#
# PROCESSING RECORD #44 OF SET 9 FOR CITY, oamaru.
#
# PROCESSING RECORD #45 OF SET 9 FOR CITY, higuera de zaragoza.
#
# PROCESSING RECORD #46 OF SET 9 FOR CITY, itaituba.
#
# PROCESSING RECORD #47 OF SET 9 FOR CITY, galveston.
# PROCESSING RECORD #48 OF SET 9 FOR CITY, floro.
#
# PROCESSING RECORD #49 OF SET 9 FOR CITY, ouellah.
#
# The script did not find the city, ouellah. Skipping...
#
# PROCESSING RECORD #50 OF SET 9 FOR CITY, kostopil'.
#
# PROCESSING RECORD #1 OF SET 10 FOR CITY, east london.
#
# PROCESSING RECORD #2 OF SET 10 FOR CITY, cabo san lucas.
#
# PROCESSING RECORD #3 OF SET 10 FOR CITY, gulf shores.
#
# PROCESSING RECORD #4 OF SET 10 FOR CITY, touros.
#
# PROCESSING RECORD #5 OF SET 10 FOR CITY, vorkuta.
#
# PROCESSING RECORD #6 OF SET 10 FOR CITY, pacific grove.
#
# PROCESSING RECORD #7 OF SET 10 FOR CITY, robertsport.
#
# PROCESSING RECORD #8 OF SET 10 FOR CITY, kaset sombun.
#
# PROCESSING RECORD #9 OF SET 10 FOR CITY, chenzhou.
#
# PROCESSING RECORD #10 OF SET 10 FOR CITY, kisangani.
#
# PROCESSING RECORD #11 OF SET 10 FOR CITY, kievka.
#
# PROCESSING RECORD #12 OF SET 10 FOR CITY, balkanabat.
#
# PROCESSING RECORD #13 OF SET 10 FOR CITY, xinyuan.
#
# PROCESSING RECORD #14 OF SET 10 FOR CITY, an nuhud.
#
# PROCESSING RECORD #15 OF SET 10 FOR CITY, severnoye.
#
# PROCESSING RECORD #16 OF SET 10 FOR CITY, nkurenkuru.
#
# The script did not find the city, nkurenkuru. Skipping...
#
# PROCESSING RECORD #17 OF SET 10 FOR CITY, malabar.
#
# PROCESSING RECORD #18 OF SET 10 FOR CITY, gracemere.
#
# PROCESSING RECORD #19 OF SET 10 FOR CITY, birao.
#
# PROCESSING RECORD #20 OF SET 10 FOR CITY, ariquemes.
#
# PROCESSING RECORD #21 OF SET 10 FOR CITY, spring creek.
#
# PROCESSING RECORD #22 OF SET 10 FOR CITY, thurgoona.
#
# PROCESSING RECORD #23 OF SET 10 FOR CITY, cooma.
#
# PROCESSING RECORD #24 OF SET 10 FOR CITY, nizhniy ingash.
#
# PROCESSING RECORD #25 OF SET 10 FOR CITY, santa elena de uairen.
#
# PROCESSING RECORD #26 OF SET 10 FOR CITY, bomdila.
#
# PROCESSING RECORD #27 OF SET 10 FOR CITY, kattivakkam.
#
# PROCESSING RECORD #28 OF SET 10 FOR CITY, ryotsu-minato.
#
# PROCESSING RECORD #29 OF SET 10 FOR CITY, acapulco de juarez.
#
# PROCESSING RECORD #30 OF SET 10 FOR CITY, sierra grande.
#
# PROCESSING RECORD #31 OF SET 10 FOR CITY, rio san juan.
#
# PROCESSING RECORD #32 OF SET 10 FOR CITY, mejit.
#
# PROCESSING RECORD #33 OF SET 10 FOR CITY, praia da vitoria.
#
# PROCESSING RECORD #34 OF SET 10 FOR CITY, rasht.
#
# PROCESSING RECORD #35 OF SET 10 FOR CITY, gonzalez.
#
# PROCESSING RECORD #36 OF SET 10 FOR CITY, thunder bay.
#
# PROCESSING RECORD #37 OF SET 10 FOR CITY, saksaul'skiy.
#
# The script did not find the city, saksaul'skiy. Skipping...
#
# PROCESSING RECORD #38 OF SET 10 FOR CITY, saldanha.
#
# PROCESSING RECORD #39 OF SET 10 FOR CITY, sheridan.
#
# PROCESSING RECORD #40 OF SET 10 FOR CITY, moranbah.
#
# PROCESSING RECORD #41 OF SET 10 FOR CITY, guilin.
#
# PROCESSING RECORD #42 OF SET 10 FOR CITY, beli.
#
# PROCESSING RECORD #43 OF SET 10 FOR CITY, revda.
#
# PROCESSING RECORD #44 OF SET 10 FOR CITY, fisterra.
#
# PROCESSING RECORD #45 OF SET 10 FOR CITY, mandalgovi.
#
# PROCESSING RECORD #46 OF SET 10 FOR CITY, nukunonu.
#
# The script did not find the city, nukunonu. Skipping...
#
# PROCESSING RECORD #47 OF SET 10 FOR CITY, zhangye.
#
# PROCESSING RECORD #48 OF SET 10 FOR CITY, kolwezi.
#
# PROCESSING RECORD #49 OF SET 10 FOR CITY, cabedelo.
#
# PROCESSING RECORD #50 OF SET 10 FOR CITY, toritto.
#
# PROCESSING RECORD #1 OF SET 11 FOR CITY, arteche.
#
# PROCESSING RECORD #2 OF SET 11 FOR CITY, galle.
#
# PROCESSING RECORD #3 OF SET 11 FOR CITY, holualoa.
#
# PROCESSING RECORD #4 OF SET 11 FOR CITY, hihifo.
#
# The script did not find the city, hihifo. Skipping...
#
# PROCESSING RECORD #5 OF SET 11 FOR CITY, mokhsogollokh.
#
# PROCESSING RECORD #6 OF SET 11 FOR CITY, nova sintra.
#
# PROCESSING RECORD #7 OF SET 11 FOR CITY, porbandar.
#
# PROCESSING RECORD #8 OF SET 11 FOR CITY, lospalos.
#
# PROCESSING RECORD #9 OF SET 11 FOR CITY, uturoa.
#
# PROCESSING RECORD #10 OF SET 11 FOR CITY, carolina beach.
#
# PROCESSING RECORD #11 OF SET 11 FOR CITY, purpe.
#
# PROCESSING RECORD #12 OF SET 11 FOR CITY, port erin.
#
# PROCESSING RECORD #13 OF SET 11 FOR CITY, budapest xxi. kerulet.
#
# The script did not find the city, budapest xxi. kerulet. Skipping...
#
# PROCESSING RECORD #14 OF SET 11 FOR CITY, abeche.
#
# PROCESSING RECORD #15 OF SET 11 FOR CITY, camana.
#
# PROCESSING RECORD #16 OF SET 11 FOR CITY, changling.
#
# PROCESSING RECORD #17 OF SET 11 FOR CITY, tidjikja.
#
# PROCESSING RECORD #18 OF SET 11 FOR CITY, macau.
#
# PROCESSING RECORD #19 OF SET 11 FOR CITY, aleksandrovsk-sakhalinskiy.
#
# PROCESSING RECORD #20 OF SET 11 FOR CITY, huarmey.
#
# PROCESSING RECORD #21 OF SET 11 FOR CITY, bathsheba.
#
# PROCESSING RECORD #22 OF SET 11 FOR CITY, tosontsengel.
#
# PROCESSING RECORD #23 OF SET 11 FOR CITY, hammam bou hadjar.
#
# PROCESSING RECORD #24 OF SET 11 FOR CITY, souillac.
#
# PROCESSING RECORD #25 OF SET 11 FOR CITY, kemise.
#
# PROCESSING RECORD #26 OF SET 11 FOR CITY, wanxian.
#
# PROCESSING RECORD #27 OF SET 11 FOR CITY, monterey.
#
# PROCESSING RECORD #28 OF SET 11 FOR CITY, krasnoturansk.
#
# PROCESSING RECORD #29 OF SET 11 FOR CITY, ar ruways.
#
# PROCESSING RECORD #30 OF SET 11 FOR CITY, mamuju.
#
# PROCESSING RECORD #31 OF SET 11 FOR CITY, terra nova.
#
# PROCESSING RECORD #32 OF SET 11 FOR CITY, tobelo.
#
# PROCESSING RECORD #33 OF SET 11 FOR CITY, berdigestyakh.
#
# PROCESSING RECORD #34 OF SET 11 FOR CITY, katsuren-haebaru.
#
# PROCESSING RECORD #35 OF SET 11 FOR CITY, larache.
#
# PROCESSING RECORD #36 OF SET 11 FOR CITY, banda aceh.
#
# PROCESSING RECORD #37 OF SET 11 FOR CITY, la passe.
#
# PROCESSING RECORD #38 OF SET 11 FOR CITY, hauterive.
#
# PROCESSING RECORD #39 OF SET 11 FOR CITY, vilyuysk.
#
# PROCESSING RECORD #40 OF SET 11 FOR CITY, urzhar.
#
# PROCESSING RECORD #41 OF SET 11 FOR CITY, kish.
#
# PROCESSING RECORD #42 OF SET 11 FOR CITY, cuilapan de guerrero.
#
# PROCESSING RECORD #43 OF SET 11 FOR CITY, kuanda.
#
# PROCESSING RECORD #44 OF SET 11 FOR CITY, fuvahmulah.
#
# The script did not find the city, fuvahmulah. Skipping...
#
# PROCESSING RECORD #45 OF SET 11 FOR CITY, kawthoung.
#
# The script did not find the city, kawthoung. Skipping...
#
# PROCESSING RECORD #46 OF SET 11 FOR CITY, chak two hundred forty-nine thal development authority.
#
# PROCESSING RECORD #47 OF SET 11 FOR CITY, oum hadjer.
#
# PROCESSING RECORD #48 OF SET 11 FOR CITY, winnemucca.
#
# PROCESSING RECORD #49 OF SET 11 FOR CITY, jiangyou.
#
# PROCESSING RECORD #50 OF SET 11 FOR CITY, axim.
#
# PROCESSING RECORD #1 OF SET 12 FOR CITY, pangody.
#
# PROCESSING RECORD #2 OF SET 12 FOR CITY, shingu.
#
# PROCESSING RECORD #3 OF SET 12 FOR CITY, mamu kanjan.
#
# PROCESSING RECORD #4 OF SET 12 FOR CITY, atherton.
#
# PROCESSING RECORD #5 OF SET 12 FOR CITY, tobi village.
#
# The script did not find the city, tobi village. Skipping...
#
# PROCESSING RECORD #6 OF SET 12 FOR CITY, de aar.
#
# PROCESSING RECORD #7 OF SET 12 FOR CITY, port moresby.
#
# PROCESSING RECORD #8 OF SET 12 FOR CITY, capo d'orlando.
#
# PROCESSING RECORD #9 OF SET 12 FOR CITY, manismata.
#
# PROCESSING RECORD #10 OF SET 12 FOR CITY, damongo.
#
# The script did not find the city, damongo. Skipping...
#
# PROCESSING RECORD #11 OF SET 12 FOR CITY, plettenberg bay.
#
# PROCESSING RECORD #12 OF SET 12 FOR CITY, santana.
#
# PROCESSING RECORD #13 OF SET 12 FOR CITY, angaur state.
#
# PROCESSING RECORD #14 OF SET 12 FOR CITY, aykhal.
#
# PROCESSING RECORD #15 OF SET 12 FOR CITY, cidade velha.
#
# PROCESSING RECORD #16 OF SET 12 FOR CITY, coahuayana de hidalgo.
#
# PROCESSING RECORD #17 OF SET 12 FOR CITY, kailua-kona.
#
# PROCESSING RECORD #18 OF SET 12 FOR CITY, villa de arista.
#
# PROCESSING RECORD #19 OF SET 12 FOR CITY, chimbote.
#
# PROCESSING RECORD #20 OF SET 12 FOR CITY, mahina.
#
# PROCESSING RECORD #21 OF SET 12 FOR CITY, auki.
#
# PROCESSING RECORD #22 OF SET 12 FOR CITY, topki.
#
# PROCESSING RECORD #23 OF SET 12 FOR CITY, tanout.
#
# PROCESSING RECORD #24 OF SET 12 FOR CITY, remire-montjoly.
#
# PROCESSING RECORD #25 OF SET 12 FOR CITY, puntarenas.
#
# PROCESSING RECORD #26 OF SET 12 FOR CITY, lacombe.
#
# PROCESSING RECORD #27 OF SET 12 FOR CITY, mariinsk.
#
# PROCESSING RECORD #28 OF SET 12 FOR CITY, conception bay south.
#
# PROCESSING RECORD #29 OF SET 12 FOR CITY, kulia village.
#
# The script did not find the city, kulia village. Skipping...
#
# PROCESSING RECORD #30 OF SET 12 FOR CITY, geraldton.
#
# PROCESSING RECORD #31 OF SET 12 FOR CITY, juan aldama.
#
# PROCESSING RECORD #32 OF SET 12 FOR CITY, yarmouth.
#
# PROCESSING RECORD #33 OF SET 12 FOR CITY, ocean pointe.
#
# The script did not find the city, ocean pointe. Skipping...
#
# PROCESSING RECORD #34 OF SET 12 FOR CITY, fort bragg.
#
# PROCESSING RECORD #35 OF SET 12 FOR CITY, n'zeto.
# PROCESSING RECORD #36 OF SET 12 FOR CITY, makoua.
#
# PROCESSING RECORD #37 OF SET 12 FOR CITY, mahanje.
#
# PROCESSING RECORD #38 OF SET 12 FOR CITY, manicore.
#
# PROCESSING RECORD #39 OF SET 12 FOR CITY, ouesso.
#
# PROCESSING RECORD #40 OF SET 12 FOR CITY, goure.
#
# PROCESSING RECORD #41 OF SET 12 FOR CITY, newport.
#
# PROCESSING RECORD #42 OF SET 12 FOR CITY, kovdor.
#
# PROCESSING RECORD #43 OF SET 12 FOR CITY, kilinochchi.
#
# PROCESSING RECORD #44 OF SET 12 FOR CITY, undurkhaan.
#
# PROCESSING RECORD #45 OF SET 12 FOR CITY, la ronge.
#
# PROCESSING RECORD #46 OF SET 12 FOR CITY, navia.
#
# PROCESSING RECORD #47 OF SET 12 FOR CITY, hemsby.
#
# PROCESSING RECORD #48 OF SET 12 FOR CITY, labasa.
#
# PROCESSING RECORD #49 OF SET 12 FOR CITY, illizi.
#
# PROCESSING RECORD #50 OF SET 12 FOR CITY, disa.
#
# PROCESSING RECORD #1 OF SET 13 FOR CITY, grand falls-windsor.
#
# Data Retrieval for city weather DataFrame is complete.

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Records Count**

# %%
cityWeatherCountIntegerVariable \
    = cityWeatherDataFrame \
        ['City'] \
            .count()

print \
    (f"There are {cityWeatherCountIntegerVariable} " \
     + f"records in the city weather DataFrame.")
# Out:
# There are 573 records in the city weather DataFrame.

# %% [markdown]
# ### **Display City Weather DataFrame**

# %%
captionString \
    = 'Table: 1.1.1: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_511d1 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_511d1_row0_col0, #T_511d1_row0_col1, #T_511d1_row0_col2, #T_511d1_row0_col4, #T_511d1_row0_col5, #T_511d1_row0_col6, #T_511d1_row0_col7, #T_511d1_row0_col8, #T_511d1_row1_col0, #T_511d1_row1_col1, #T_511d1_row1_col2, #T_511d1_row1_col3, #T_511d1_row1_col4, #T_511d1_row1_col5, #T_511d1_row1_col6, #T_511d1_row1_col7, #T_511d1_row1_col8, #T_511d1_row2_col0, #T_511d1_row2_col1, #T_511d1_row2_col2, #T_511d1_row2_col3, #T_511d1_row2_col4, #T_511d1_row2_col6, #T_511d1_row2_col7, #T_511d1_row2_col8, #T_511d1_row3_col0, #T_511d1_row3_col1, #T_511d1_row3_col2, #T_511d1_row3_col3, #T_511d1_row3_col4, #T_511d1_row3_col5, #T_511d1_row3_col7, #T_511d1_row3_col8, #T_511d1_row4_col0, #T_511d1_row4_col1, #T_511d1_row4_col2, #T_511d1_row4_col3, #T_511d1_row4_col6, #T_511d1_row4_col7, #T_511d1_row4_col8, #T_511d1_row5_col0, #T_511d1_row5_col1, #T_511d1_row5_col2, #T_511d1_row5_col3, #T_511d1_row5_col6, #T_511d1_row5_col7, #T_511d1_row5_col8, #T_511d1_row6_col0, #T_511d1_row6_col1, #T_511d1_row6_col2, #T_511d1_row6_col3, #T_511d1_row6_col4, #T_511d1_row6_col6, #T_511d1_row6_col7, #T_511d1_row6_col8, #T_511d1_row7_col0, #T_511d1_row7_col1, #T_511d1_row7_col2, #T_511d1_row7_col3, #T_511d1_row7_col4, #T_511d1_row7_col5, #T_511d1_row7_col6, #T_511d1_row7_col7, #T_511d1_row7_col8, #T_511d1_row8_col0, #T_511d1_row8_col1, #T_511d1_row8_col2, #T_511d1_row8_col3, #T_511d1_row8_col4, #T_511d1_row8_col6, #T_511d1_row8_col7, #T_511d1_row8_col8, #T_511d1_row9_col0, #T_511d1_row9_col1, #T_511d1_row9_col2, #T_511d1_row9_col3, #T_511d1_row9_col4, #T_511d1_row9_col5, #T_511d1_row9_col6, #T_511d1_row9_col7, #T_511d1_row9_col8, #T_511d1_row10_col0, #T_511d1_row10_col1, #T_511d1_row10_col2, #T_511d1_row10_col3, #T_511d1_row10_col4, #T_511d1_row10_col7, #T_511d1_row10_col8, #T_511d1_row11_col0, #T_511d1_row11_col1, #T_511d1_row11_col2, #T_511d1_row11_col4, #T_511d1_row11_col5, #T_511d1_row11_col6, #T_511d1_row11_col7, #T_511d1_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_511d1_row0_col3, #T_511d1_row2_col5, #T_511d1_row3_col6, #T_511d1_row5_col4, #T_511d1_row5_col5, #T_511d1_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_511d1_row4_col4, #T_511d1_row4_col5, #T_511d1_row8_col5, #T_511d1_row10_col5, #T_511d1_row10_col6, #T_511d1_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_511d1">
#   <caption>Table: 1.1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_511d1_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_511d1_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_511d1_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_511d1_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_511d1_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_511d1_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_511d1_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_511d1_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_511d1_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_511d1_row0_col0" class="data row0 col0" >grytviken</td>
#       <td id="T_511d1_row0_col1" class="data row0 col1" >-54.28</td>
#       <td id="T_511d1_row0_col2" class="data row0 col2" >-36.51</td>
#       <td id="T_511d1_row0_col3" class="data row0 col3" >28.22° F</td>
#       <td id="T_511d1_row0_col4" class="data row0 col4" >81%</td>
#       <td id="T_511d1_row0_col5" class="data row0 col5" >24%</td>
#       <td id="T_511d1_row0_col6" class="data row0 col6" >9.19</td>
#       <td id="T_511d1_row0_col7" class="data row0 col7" >GS</td>
#       <td id="T_511d1_row0_col8" class="data row0 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_511d1_row1_col0" class="data row1 col0" >bandar lampung</td>
#       <td id="T_511d1_row1_col1" class="data row1 col1" >-5.43</td>
#       <td id="T_511d1_row1_col2" class="data row1 col2" >105.26</td>
#       <td id="T_511d1_row1_col3" class="data row1 col3" >81.45° F</td>
#       <td id="T_511d1_row1_col4" class="data row1 col4" >62%</td>
#       <td id="T_511d1_row1_col5" class="data row1 col5" >1%</td>
#       <td id="T_511d1_row1_col6" class="data row1 col6" >3.85</td>
#       <td id="T_511d1_row1_col7" class="data row1 col7" >ID</td>
#       <td id="T_511d1_row1_col8" class="data row1 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_511d1_row2_col0" class="data row2 col0" >pisco</td>
#       <td id="T_511d1_row2_col1" class="data row2 col1" >-13.70</td>
#       <td id="T_511d1_row2_col2" class="data row2 col2" >-76.22</td>
#       <td id="T_511d1_row2_col3" class="data row2 col3" >66.25° F</td>
#       <td id="T_511d1_row2_col4" class="data row2 col4" >82%</td>
#       <td id="T_511d1_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_511d1_row2_col6" class="data row2 col6" >17.27</td>
#       <td id="T_511d1_row2_col7" class="data row2 col7" >PE</td>
#       <td id="T_511d1_row2_col8" class="data row2 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_511d1_row3_col0" class="data row3 col0" >albany</td>
#       <td id="T_511d1_row3_col1" class="data row3 col1" >42.60</td>
#       <td id="T_511d1_row3_col2" class="data row3 col2" >-73.97</td>
#       <td id="T_511d1_row3_col3" class="data row3 col3" >52.59° F</td>
#       <td id="T_511d1_row3_col4" class="data row3 col4" >88%</td>
#       <td id="T_511d1_row3_col5" class="data row3 col5" >98%</td>
#       <td id="T_511d1_row3_col6" class="data row3 col6" >1.01</td>
#       <td id="T_511d1_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_511d1_row3_col8" class="data row3 col8" >2023-09-26 17:28:56</td>
#     </tr>
#     <tr>
#       <td id="T_511d1_row4_col0" class="data row4 col0" >lemvig</td>
#       <td id="T_511d1_row4_col1" class="data row4 col1" >56.55</td>
#       <td id="T_511d1_row4_col2" class="data row4 col2" >8.31</td>
#       <td id="T_511d1_row4_col3" class="data row4 col3" >59.14° F</td>
#       <td id="T_511d1_row4_col4" class="data row4 col4" >90%</td>
#       <td id="T_511d1_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_511d1_row4_col6" class="data row4 col6" >11.90</td>
#       <td id="T_511d1_row4_col7" class="data row4 col7" >DK</td>
#       <td id="T_511d1_row4_col8" class="data row4 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_511d1_row5_col0" class="data row5 col0" >aspen</td>
#       <td id="T_511d1_row5_col1" class="data row5 col1" >39.19</td>
#       <td id="T_511d1_row5_col2" class="data row5 col2" >-106.82</td>
#       <td id="T_511d1_row5_col3" class="data row5 col3" >71.04° F</td>
#       <td id="T_511d1_row5_col4" class="data row5 col4" >15%</td>
#       <td id="T_511d1_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_511d1_row5_col6" class="data row5 col6" >8.05</td>
#       <td id="T_511d1_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_511d1_row5_col8" class="data row5 col8" >2023-09-26 17:28:42</td>
#     </tr>
#     <tr>
#       <td id="T_511d1_row6_col0" class="data row6 col0" >luderitz</td>
#       <td id="T_511d1_row6_col1" class="data row6 col1" >-26.65</td>
#       <td id="T_511d1_row6_col2" class="data row6 col2" >15.16</td>
#       <td id="T_511d1_row6_col3" class="data row6 col3" >63.48° F</td>
#       <td id="T_511d1_row6_col4" class="data row6 col4" >47%</td>
#       <td id="T_511d1_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_511d1_row6_col6" class="data row6 col6" >12.91</td>
#       <td id="T_511d1_row6_col7" class="data row6 col7" >NA</td>
#       <td id="T_511d1_row6_col8" class="data row6 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_511d1_row7_col0" class="data row

# %% [markdown]
# ### **Data Export to CSV File**

# %%
subroutine \
    .WriteDataFrameToCSVFile \
        (cityWeatherDataFrame,
         local_constant.WEATHER_DATA_FILE_PATH,
         local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Data Import from CSV File**

# %%
sampleCityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Display Sample City Weather DataFrame**

# %%
captionString \
    = 'Table: 1.1.2: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_90531 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_90531_row0_col0, #T_90531_row0_col1, #T_90531_row0_col2, #T_90531_row0_col4, #T_90531_row0_col5, #T_90531_row0_col6, #T_90531_row0_col7, #T_90531_row0_col8, #T_90531_row1_col0, #T_90531_row1_col1, #T_90531_row1_col2, #T_90531_row1_col3, #T_90531_row1_col4, #T_90531_row1_col5, #T_90531_row1_col6, #T_90531_row1_col7, #T_90531_row1_col8, #T_90531_row2_col0, #T_90531_row2_col1, #T_90531_row2_col2, #T_90531_row2_col3, #T_90531_row2_col4, #T_90531_row2_col6, #T_90531_row2_col7, #T_90531_row2_col8, #T_90531_row3_col0, #T_90531_row3_col1, #T_90531_row3_col2, #T_90531_row3_col3, #T_90531_row3_col4, #T_90531_row3_col5, #T_90531_row3_col7, #T_90531_row3_col8, #T_90531_row4_col0, #T_90531_row4_col1, #T_90531_row4_col2, #T_90531_row4_col3, #T_90531_row4_col6, #T_90531_row4_col7, #T_90531_row4_col8, #T_90531_row5_col0, #T_90531_row5_col1, #T_90531_row5_col2, #T_90531_row5_col3, #T_90531_row5_col6, #T_90531_row5_col7, #T_90531_row5_col8, #T_90531_row6_col0, #T_90531_row6_col1, #T_90531_row6_col2, #T_90531_row6_col3, #T_90531_row6_col4, #T_90531_row6_col6, #T_90531_row6_col7, #T_90531_row6_col8, #T_90531_row7_col0, #T_90531_row7_col1, #T_90531_row7_col2, #T_90531_row7_col3, #T_90531_row7_col4, #T_90531_row7_col5, #T_90531_row7_col6, #T_90531_row7_col7, #T_90531_row7_col8, #T_90531_row8_col0, #T_90531_row8_col1, #T_90531_row8_col2, #T_90531_row8_col3, #T_90531_row8_col4, #T_90531_row8_col6, #T_90531_row8_col7, #T_90531_row8_col8, #T_90531_row9_col0, #T_90531_row9_col1, #T_90531_row9_col2, #T_90531_row9_col3, #T_90531_row9_col4, #T_90531_row9_col5, #T_90531_row9_col6, #T_90531_row9_col7, #T_90531_row9_col8, #T_90531_row10_col0, #T_90531_row10_col1, #T_90531_row10_col2, #T_90531_row10_col3, #T_90531_row10_col4, #T_90531_row10_col7, #T_90531_row10_col8, #T_90531_row11_col0, #T_90531_row11_col1, #T_90531_row11_col2, #T_90531_row11_col4, #T_90531_row11_col5, #T_90531_row11_col6, #T_90531_row11_col7, #T_90531_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_90531_row0_col3, #T_90531_row2_col5, #T_90531_row3_col6, #T_90531_row5_col4, #T_90531_row5_col5, #T_90531_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_90531_row4_col4, #T_90531_row4_col5, #T_90531_row8_col5, #T_90531_row10_col5, #T_90531_row10_col6, #T_90531_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_90531">
#   <caption>Table: 1.1.2: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_90531_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_90531_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_90531_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_90531_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_90531_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_90531_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_90531_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_90531_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_90531_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_90531_row0_col0" class="data row0 col0" >grytviken</td>
#       <td id="T_90531_row0_col1" class="data row0 col1" >-54.28</td>
#       <td id="T_90531_row0_col2" class="data row0 col2" >-36.51</td>
#       <td id="T_90531_row0_col3" class="data row0 col3" >28.22° F</td>
#       <td id="T_90531_row0_col4" class="data row0 col4" >81%</td>
#       <td id="T_90531_row0_col5" class="data row0 col5" >24%</td>
#       <td id="T_90531_row0_col6" class="data row0 col6" >9.19</td>
#       <td id="T_90531_row0_col7" class="data row0 col7" >GS</td>
#       <td id="T_90531_row0_col8" class="data row0 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_90531_row1_col0" class="data row1 col0" >bandar lampung</td>
#       <td id="T_90531_row1_col1" class="data row1 col1" >-5.43</td>
#       <td id="T_90531_row1_col2" class="data row1 col2" >105.26</td>
#       <td id="T_90531_row1_col3" class="data row1 col3" >81.45° F</td>
#       <td id="T_90531_row1_col4" class="data row1 col4" >62%</td>
#       <td id="T_90531_row1_col5" class="data row1 col5" >1%</td>
#       <td id="T_90531_row1_col6" class="data row1 col6" >3.85</td>
#       <td id="T_90531_row1_col7" class="data row1 col7" >ID</td>
#       <td id="T_90531_row1_col8" class="data row1 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_90531_row2_col0" class="data row2 col0" >pisco</td>
#       <td id="T_90531_row2_col1" class="data row2 col1" >-13.70</td>
#       <td id="T_90531_row2_col2" class="data row2 col2" >-76.22</td>
#       <td id="T_90531_row2_col3" class="data row2 col3" >66.25° F</td>
#       <td id="T_90531_row2_col4" class="data row2 col4" >82%</td>
#       <td id="T_90531_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_90531_row2_col6" class="data row2 col6" >17.27</td>
#       <td id="T_90531_row2_col7" class="data row2 col7" >PE</td>
#       <td id="T_90531_row2_col8" class="data row2 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_90531_row3_col0" class="data row3 col0" >albany</td>
#       <td id="T_90531_row3_col1" class="data row3 col1" >42.60</td>
#       <td id="T_90531_row3_col2" class="data row3 col2" >-73.97</td>
#       <td id="T_90531_row3_col3" class="data row3 col3" >52.59° F</td>
#       <td id="T_90531_row3_col4" class="data row3 col4" >88%</td>
#       <td id="T_90531_row3_col5" class="data row3 col5" >98%</td>
#       <td id="T_90531_row3_col6" class="data row3 col6" >1.01</td>
#       <td id="T_90531_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_90531_row3_col8" class="data row3 col8" >2023-09-26 17:28:56</td>
#     </tr>
#     <tr>
#       <td id="T_90531_row4_col0" class="data row4 col0" >lemvig</td>
#       <td id="T_90531_row4_col1" class="data row4 col1" >56.55</td>
#       <td id="T_90531_row4_col2" class="data row4 col2" >8.31</td>
#       <td id="T_90531_row4_col3" class="data row4 col3" >59.14° F</td>
#       <td id="T_90531_row4_col4" class="data row4 col4" >90%</td>
#       <td id="T_90531_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_90531_row4_col6" class="data row4 col6" >11.90</td>
#       <td id="T_90531_row4_col7" class="data row4 col7" >DK</td>
#       <td id="T_90531_row4_col8" class="data row4 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_90531_row5_col0" class="data row5 col0" >aspen</td>
#       <td id="T_90531_row5_col1" class="data row5 col1" >39.19</td>
#       <td id="T_90531_row5_col2" class="data row5 col2" >-106.82</td>
#       <td id="T_90531_row5_col3" class="data row5 col3" >71.04° F</td>
#       <td id="T_90531_row5_col4" class="data row5 col4" >15%</td>
#       <td id="T_90531_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_90531_row5_col6" class="data row5 col6" >8.05</td>
#       <td id="T_90531_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_90531_row5_col8" class="data row5 col8" >2023-09-26 17:28:42</td>
#     </tr>
#     <tr>
#       <td id="T_90531_row6_col0" class="data row6 col0" >luderitz</td>
#       <td id="T_90531_row6_col1" class="data row6 col1" >-26.65</td>
#       <td id="T_90531_row6_col2" class="data row6 col2" >15.16</td>
#       <td id="T_90531_row6_col3" class="data row6 col3" >63.48° F</td>
#       <td id="T_90531_row6_col4" class="data row6 col4" >47%</td>
#       <td id="T_90531_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_90531_row6_col6" class="data row6 col6" >12.91</td>
#       <td id="T_90531_row6_col7" class="data row6 col7" >NA</td>
#       <td id="T_90531_row6_col8" class="data row6 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_90531_row7_col0" class="data row

# %% [markdown]
# ## **Section 1.2: Scatter Plots w/Regression**

# %% [markdown]
# ### **Temperature Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1: Temperature Vs. Latitude (Scatter Plot)')

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1.1: Temperature Vs. Latitude (Scatter Plot w/Regression)', 
         2, -48.0, 28.0)
# Out:
# r-value:     0.8554
# r-squared:   0.7317

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### Although this assignment is about linear regression, I notice that the independent variable, latitude, has a relationship with the dependent variable, temperature, just not a linear one.  With linear regression, we obtain a -0.1346 correlation; with quadratic regression, the correlation increases to 0.7879.  In practiice, analysts consider a 0.60-0.79 correlation to be strong.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.2.2: Humidity Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Cloudiness Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.2.3: Cloudiness Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.2.4: Wind Speed vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **City Weather Information Correlation Matrix**

# %%
frameDictionary \
    = {'Latitude': 
            cityWeatherDataFrame \
                ['Latitude'], 
       'Temperature': 
            cityWeatherDataFrame \
                ['Temperature'], 
       'Humidity': 
            cityWeatherDataFrame \
                ['Humidity'],
       'Cloudiness': 
            cityWeatherDataFrame \
                ['Cloudiness'],
       'Wind Speed':
            cityWeatherDataFrame \
                ['Wind Speed']}


function \
    .ReturnCorrelationTableStandardFormat \
        (pd \
             .DataFrame \
                 (frameDictionary),
         'Table 1.2.1: City Weather Correlation Matrix')
# Out:
# <style type="text/css">
# #T_8a633 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_8a633_row0_col0, #T_8a633_row0_col1, #T_8a633_row0_col2, #T_8a633_row0_col3, #T_8a633_row0_col4, #T_8a633_row1_col0, #T_8a633_row1_col1, #T_8a633_row1_col2, #T_8a633_row1_col3, #T_8a633_row1_col4, #T_8a633_row2_col0, #T_8a633_row2_col1, #T_8a633_row2_col2, #T_8a633_row2_col3, #T_8a633_row2_col4, #T_8a633_row3_col0, #T_8a633_row3_col1, #T_8a633_row3_col2, #T_8a633_row3_col3, #T_8a633_row3_col4, #T_8a633_row4_col0, #T_8a633_row4_col1, #T_8a633_row4_col2, #T_8a633_row4_col3, #T_8a633_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_8a633">
#   <caption>Table 1.2.1: City Weather Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a633_level0_col0" class="col_heading level0 col0" >Latitude</th>
#       <th id="T_8a633_level0_col1" class="col_heading level0 col1" >Temperature</th>
#       <th id="T_8a633_level0_col2" class="col_heading level0 col2" >Humidity</th>
#       <th id="T_8a633_level0_col3" class="col_heading level0 col3" >Cloudiness</th>
#       <th id="T_8a633_level0_col4" class="col_heading level0 col4" >Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a633_level0_row0" class="row_heading level0 row0" >Latitude</th>
#       <td id="T_8a633_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8a633_row0_col1" class="data row0 col1" >-0.381145</td>
#       <td id="T_8a633_row0_col2" class="data row0 col2" >0.113636</td>
#       <td id="T_8a633_row0_col3" class="data row0 col3" >0.073313</td>
#       <td id="T_8a633_row0_col4" class="data row0 col4" >-0.061319</td>
#     </tr>
#     <tr>
#       <th id="T_8a633_level0_row1" class="row_heading level0 row1" >Temperature</th>
#       <td id="T_8a633_row1_col0" class="data row1 col0" >-0.381145</td>
#       <td id="T_8a633_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8a633_row1_col2" class="data row1 col2" >-0.234667</td>
#       <td id="T_8a633_row1_col3" class="data row1 col3" >-0.171730</td>
#       <td id="T_8a633_row1_col4" class="data row1 col4" >-0.109318</td>
#     </tr>
#     <tr>
#       <th id="T_8a633_level0_row2" class="row_heading level0 row2" >Humidity</th>
#       <td id="T_8a633_row2_col0" class="data row2 col0" >0.113636</td>
#       <td id="T_8a633_row2_col1" class="data row2 col1" >-0.234667</td>
#       <td id="T_8a633_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8a633_row2_col3" class="data row2 col3" >0.379296</td>
#       <td id="T_8a633_row2_col4" class="data row2 col4" >0.011343</td>
#     </tr>
#     <tr>
#       <th id="T_8a633_level0_row3" class="row_heading level0 row3" >Cloudiness</th>
#       <td id="T_8a633_row3_col0" class="data row3 col0" >0.073313</td>
#       <td id="T_8a633_row3_col1" class="data row3 col1" >-0.171730</td>
#       <td id="T_8a633_row3_col2" class="data row3 col2" >0.379296</td>
#       <td id="T_8a633_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8a633_row3_col4" class="data row3 col4" >0.096136</td>
#     </tr>
#     <tr>
#       <th id="T_8a633_level0_row4" class="row_heading level0 row4" >Wind Speed</th>
#       <td id="T_8a633_row4_col0" class="data row4 col0" >-0.061319</td>
#       <td id="T_8a633_row4_col1" class="data row4 col1" >-0.109318</td>
#       <td id="T_8a633_row4_col2" class="data row4 col2" >0.011343</td>
#       <td id="T_8a633_row4_col3" class="data row4 col3" >0.096136</td>
#       <td id="T_8a633_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Discussion about correlation:** YOUR RESPONSE HERE

# %% [markdown]
# ## **Section 1.3: Hemisphere Scatter Plots with Linear Regression**

# %% [markdown]
# ### **Northern Hemisphere City Weather Information**

# %%
northernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (northernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.1: City Weather Information (Northern Hemisphere)')
# Out:
# <style type="text/css">
# #T_71bf5 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_71bf5_row0_col0, #T_71bf5_row0_col1, #T_71bf5_row0_col2, #T_71bf5_row0_col3, #T_71bf5_row0_col4, #T_71bf5_row0_col5, #T_71bf5_row0_col7, #T_71bf5_row0_col8, #T_71bf5_row1_col0, #T_71bf5_row1_col1, #T_71bf5_row1_col2, #T_71bf5_row1_col3, #T_71bf5_row1_col4, #T_71bf5_row1_col6, #T_71bf5_row1_col7, #T_71bf5_row1_col8, #T_71bf5_row2_col0, #T_71bf5_row2_col1, #T_71bf5_row2_col2, #T_71bf5_row2_col3, #T_71bf5_row2_col6, #T_71bf5_row2_col7, #T_71bf5_row2_col8, #T_71bf5_row3_col0, #T_71bf5_row3_col1, #T_71bf5_row3_col2, #T_71bf5_row3_col3, #T_71bf5_row3_col4, #T_71bf5_row3_col5, #T_71bf5_row3_col6, #T_71bf5_row3_col7, #T_71bf5_row3_col8, #T_71bf5_row4_col0, #T_71bf5_row4_col1, #T_71bf5_row4_col2, #T_71bf5_row4_col3, #T_71bf5_row4_col4, #T_71bf5_row4_col7, #T_71bf5_row4_col8, #T_71bf5_row5_col0, #T_71bf5_row5_col1, #T_71bf5_row5_col2, #T_71bf5_row5_col3, #T_71bf5_row5_col4, #T_71bf5_row5_col6, #T_71bf5_row5_col7, #T_71bf5_row5_col8, #T_71bf5_row6_col0, #T_71bf5_row6_col1, #T_71bf5_row6_col2, #T_71bf5_row6_col3, #T_71bf5_row6_col4, #T_71bf5_row6_col6, #T_71bf5_row6_col7, #T_71bf5_row6_col8, #T_71bf5_row7_col0, #T_71bf5_row7_col1, #T_71bf5_row7_col2, #T_71bf5_row7_col4, #T_71bf5_row7_col6, #T_71bf5_row7_col7, #T_71bf5_row7_col8, #T_71bf5_row8_col0, #T_71bf5_row8_col1, #T_71bf5_row8_col2, #T_71bf5_row8_col3, #T_71bf5_row8_col6, #T_71bf5_row8_col7, #T_71bf5_row8_col8, #T_71bf5_row9_col0, #T_71bf5_row9_col1, #T_71bf5_row9_col2, #T_71bf5_row9_col3, #T_71bf5_row9_col4, #T_71bf5_row9_col5, #T_71bf5_row9_col6, #T_71bf5_row9_col7, #T_71bf5_row9_col8, #T_71bf5_row10_col0, #T_71bf5_row10_col1, #T_71bf5_row10_col2, #T_71bf5_row10_col3, #T_71bf5_row10_col4, #T_71bf5_row10_col6, #T_71bf5_row10_col7, #T_71bf5_row10_col8, #T_71bf5_row11_col0, #T_71bf5_row11_col1, #T_71bf5_row11_col2, #T_71bf5_row11_col4, #T_71bf5_row11_col5, #T_71bf5_row11_col6, #T_71bf5_row11_col7, #T_71bf5_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_71bf5_row0_col6, #T_71bf5_row2_col4, #T_71bf5_row2_col5, #T_71bf5_row7_col5, #T_71bf5_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_71bf5_row1_col5, #T_71bf5_row4_col5, #T_71bf5_row4_col6, #T_71bf5_row5_col5, #T_71bf5_row6_col5, #T_71bf5_row7_col3, #T_71bf5_row8_col4, #T_71bf5_row8_col5, #T_71bf5_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_71bf5">
#   <caption>Table: 1.3.1: City Weather Information (Northern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_71bf5_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_71bf5_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_71bf5_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_71bf5_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_71bf5_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_71bf5_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_71bf5_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_71bf5_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_71bf5_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_71bf5_row0_col0" class="data row0 col0" >albany</td>
#       <td id="T_71bf5_row0_col1" class="data row0 col1" >42.60</td>
#       <td id="T_71bf5_row0_col2" class="data row0 col2" >-73.97</td>
#       <td id="T_71bf5_row0_col3" class="data row0 col3" >52.59° F</td>
#       <td id="T_71bf5_row0_col4" class="data row0 col4" >88%</td>
#       <td id="T_71bf5_row0_col5" class="data row0 col5" >98%</td>
#       <td id="T_71bf5_row0_col6" class="data row0 col6" >1.01</td>
#       <td id="T_71bf5_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_71bf5_row0_col8" class="data row0 col8" >2023-09-26 17:28:56</td>
#     </tr>
#     <tr>
#       <td id="T_71bf5_row1_col0" class="data row1 col0" >lemvig</td>
#       <td id="T_71bf5_row1_col1" class="data row1 col1" >56.55</td>
#       <td id="T_71bf5_row1_col2" class="data row1 col2" >8.31</td>
#       <td id="T_71bf5_row1_col3" class="data row1 col3" >59.14° F</td>
#       <td id="T_71bf5_row1_col4" class="data row1 col4" >90%</td>
#       <td id="T_71bf5_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_71bf5_row1_col6" class="data row1 col6" >11.90</td>
#       <td id="T_71bf5_row1_col7" class="data row1 col7" >DK</td>
#       <td id="T_71bf5_row1_col8" class="data row1 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_71bf5_row2_col0" class="data row2 col0" >aspen</td>
#       <td id="T_71bf5_row2_col1" class="data row2 col1" >39.19</td>
#       <td id="T_71bf5_row2_col2" class="data row2 col2" >-106.82</td>
#       <td id="T_71bf5_row2_col3" class="data row2 col3" >71.04° F</td>
#       <td id="T_71bf5_row2_col4" class="data row2 col4" >15%</td>
#       <td id="T_71bf5_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_71bf5_row2_col6" class="data row2 col6" >8.05</td>
#       <td id="T_71bf5_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_71bf5_row2_col8" class="data row2 col8" >2023-09-26 17:28:42</td>
#     </tr>
#     <tr>
#       <td id="T_71bf5_row3_col0" class="data row3 col0" >bonthe</td>
#       <td id="T_71bf5_row3_col1" class="data row3 col1" >7.53</td>
#       <td id="T_71bf5_row3_col2" class="data row3 col2" >-12.51</td>
#       <td id="T_71bf5_row3_col3" class="data row3 col3" >78.26° F</td>
#       <td id="T_71bf5_row3_col4" class="data row3 col4" >89%</td>
#       <td id="T_71bf5_row3_col5" class="data row3 col5" >23%</td>
#       <td id="T_71bf5_row3_col6" class="data row3 col6" >3.11</td>
#       <td id="T_71bf5_row3_col7" class="data row3 col7" >SL</td>
#       <td id="T_71bf5_row3_col8" class="data row3 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_71bf5_row4_col0" class="data row4 col0" >olonkinbyen</td>
#       <td id="T_71bf5_row4_col1" class="data row4 col1" >70.92</td>
#       <td id="T_71bf5_row4_col2" class="data row4 col2" >-8.72</td>
#       <td id="T_71bf5_row4_col3" class="data row4 col3" >38.55° F</td>
#       <td id="T_71bf5_row4_col4" class="data row4 col4" >82%</td>
#       <td id="T_71bf5_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_71bf5_row4_col6" class="data row4 col6" >18.37</td>
#       <td id="T_71bf5_row4_col7" class="data row4 col7" >SJ</td>
#       <td id="T_71bf5_row4_col8" class="data row4 col8" >2023-09-26 17:33:05</td>
#     </tr>
#     <tr>
#       <td id="T_71bf5_row5_col0" class="data row5 col0" >hawaiian paradise park</td>
#       <td id="T_71bf5_row5_col1" class="data row5 col1" >19.59</td>
#       <td id="T_71bf5_row5_col2" class="data row5 col2" >-154.97</td>
#       <td id="T_71bf5_row5_col3" class="data row5 col3" >80.91° F</td>
#       <td id="T_71bf5_row5_col4" class="data row5 col4" >68%</td>
#       <td id="T_71bf5_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_71bf5_row5_col6" class="data row5 col6" >6.91</td>
#       <td id="T_71bf5_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_71bf5_row5_col8" class="data row5 col8" >2023-09-26 17:33:06</td>
#     </tr>
#     <tr>
#       <td id="T_71bf5_row6_col0" class="data row6 col0" >sitka</td>
#       <td id="T_71bf5_row6_col1" class="data row6 col1" >57.05</td>
#       <td id="T_71bf5_row6_col2" class="data row6 col2" >-135.33</td>
#       <td id="T_71bf5_row6_col3" class="data row6 col3" >55.29° F</td>
#       <td id="T_71bf5_row6_col4" class="data row6 col4" >88%</td>
#       <td id="T_71bf5_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_71bf5_row6_col6" class="data row6 col6" >5.75</td>
#       <td id="T_71bf5_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_71bf5_row6_col8" class="data row6 col8" >2023-09-26 17:33:06</td>
#     </tr>
#     <tr>
#       <td id="T

# %% [markdown]
# ### **Southern Hemisphere City Weather Information**

# %%
southernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (southernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.2: City Weather Information (Southern Hemisphere)')
# Out:
# <style type="text/css">
# #T_94363 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_94363_row0_col0, #T_94363_row0_col1, #T_94363_row0_col2, #T_94363_row0_col3, #T_94363_row0_col4, #T_94363_row0_col5, #T_94363_row0_col7, #T_94363_row0_col8, #T_94363_row1_col0, #T_94363_row1_col1, #T_94363_row1_col2, #T_94363_row1_col3, #T_94363_row1_col4, #T_94363_row1_col6, #T_94363_row1_col7, #T_94363_row1_col8, #T_94363_row2_col0, #T_94363_row2_col1, #T_94363_row2_col2, #T_94363_row2_col3, #T_94363_row2_col6, #T_94363_row2_col7, #T_94363_row2_col8, #T_94363_row3_col0, #T_94363_row3_col1, #T_94363_row3_col2, #T_94363_row3_col3, #T_94363_row3_col4, #T_94363_row3_col5, #T_94363_row3_col6, #T_94363_row3_col7, #T_94363_row3_col8, #T_94363_row4_col0, #T_94363_row4_col1, #T_94363_row4_col2, #T_94363_row4_col3, #T_94363_row4_col4, #T_94363_row4_col7, #T_94363_row4_col8, #T_94363_row5_col0, #T_94363_row5_col1, #T_94363_row5_col2, #T_94363_row5_col3, #T_94363_row5_col4, #T_94363_row5_col6, #T_94363_row5_col7, #T_94363_row5_col8, #T_94363_row6_col0, #T_94363_row6_col1, #T_94363_row6_col2, #T_94363_row6_col3, #T_94363_row6_col4, #T_94363_row6_col6, #T_94363_row6_col7, #T_94363_row6_col8, #T_94363_row7_col0, #T_94363_row7_col1, #T_94363_row7_col2, #T_94363_row7_col4, #T_94363_row7_col6, #T_94363_row7_col7, #T_94363_row7_col8, #T_94363_row8_col0, #T_94363_row8_col1, #T_94363_row8_col2, #T_94363_row8_col3, #T_94363_row8_col6, #T_94363_row8_col7, #T_94363_row8_col8, #T_94363_row9_col0, #T_94363_row9_col1, #T_94363_row9_col2, #T_94363_row9_col3, #T_94363_row9_col4, #T_94363_row9_col5, #T_94363_row9_col6, #T_94363_row9_col7, #T_94363_row9_col8, #T_94363_row10_col0, #T_94363_row10_col1, #T_94363_row10_col2, #T_94363_row10_col3, #T_94363_row10_col4, #T_94363_row10_col6, #T_94363_row10_col7, #T_94363_row10_col8, #T_94363_row11_col0, #T_94363_row11_col1, #T_94363_row11_col2, #T_94363_row11_col4, #T_94363_row11_col5, #T_94363_row11_col6, #T_94363_row11_col7, #T_94363_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_94363_row0_col6, #T_94363_row2_col4, #T_94363_row2_col5, #T_94363_row7_col5, #T_94363_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_94363_row1_col5, #T_94363_row4_col5, #T_94363_row4_col6, #T_94363_row5_col5, #T_94363_row6_col5, #T_94363_row7_col3, #T_94363_row8_col4, #T_94363_row8_col5, #T_94363_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_94363">
#   <caption>Table: 1.3.2: City Weather Information (Southern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_94363_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_94363_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_94363_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_94363_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_94363_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_94363_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_94363_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_94363_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_94363_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94363_row0_col0" class="data row0 col0" >albany</td>
#       <td id="T_94363_row0_col1" class="data row0 col1" >42.60</td>
#       <td id="T_94363_row0_col2" class="data row0 col2" >-73.97</td>
#       <td id="T_94363_row0_col3" class="data row0 col3" >52.59° F</td>
#       <td id="T_94363_row0_col4" class="data row0 col4" >88%</td>
#       <td id="T_94363_row0_col5" class="data row0 col5" >98%</td>
#       <td id="T_94363_row0_col6" class="data row0 col6" >1.01</td>
#       <td id="T_94363_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_94363_row0_col8" class="data row0 col8" >2023-09-26 17:28:56</td>
#     </tr>
#     <tr>
#       <td id="T_94363_row1_col0" class="data row1 col0" >lemvig</td>
#       <td id="T_94363_row1_col1" class="data row1 col1" >56.55</td>
#       <td id="T_94363_row1_col2" class="data row1 col2" >8.31</td>
#       <td id="T_94363_row1_col3" class="data row1 col3" >59.14° F</td>
#       <td id="T_94363_row1_col4" class="data row1 col4" >90%</td>
#       <td id="T_94363_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_94363_row1_col6" class="data row1 col6" >11.90</td>
#       <td id="T_94363_row1_col7" class="data row1 col7" >DK</td>
#       <td id="T_94363_row1_col8" class="data row1 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_94363_row2_col0" class="data row2 col0" >aspen</td>
#       <td id="T_94363_row2_col1" class="data row2 col1" >39.19</td>
#       <td id="T_94363_row2_col2" class="data row2 col2" >-106.82</td>
#       <td id="T_94363_row2_col3" class="data row2 col3" >71.04° F</td>
#       <td id="T_94363_row2_col4" class="data row2 col4" >15%</td>
#       <td id="T_94363_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_94363_row2_col6" class="data row2 col6" >8.05</td>
#       <td id="T_94363_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_94363_row2_col8" class="data row2 col8" >2023-09-26 17:28:42</td>
#     </tr>
#     <tr>
#       <td id="T_94363_row3_col0" class="data row3 col0" >bonthe</td>
#       <td id="T_94363_row3_col1" class="data row3 col1" >7.53</td>
#       <td id="T_94363_row3_col2" class="data row3 col2" >-12.51</td>
#       <td id="T_94363_row3_col3" class="data row3 col3" >78.26° F</td>
#       <td id="T_94363_row3_col4" class="data row3 col4" >89%</td>
#       <td id="T_94363_row3_col5" class="data row3 col5" >23%</td>
#       <td id="T_94363_row3_col6" class="data row3 col6" >3.11</td>
#       <td id="T_94363_row3_col7" class="data row3 col7" >SL</td>
#       <td id="T_94363_row3_col8" class="data row3 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_94363_row4_col0" class="data row4 col0" >olonkinbyen</td>
#       <td id="T_94363_row4_col1" class="data row4 col1" >70.92</td>
#       <td id="T_94363_row4_col2" class="data row4 col2" >-8.72</td>
#       <td id="T_94363_row4_col3" class="data row4 col3" >38.55° F</td>
#       <td id="T_94363_row4_col4" class="data row4 col4" >82%</td>
#       <td id="T_94363_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_94363_row4_col6" class="data row4 col6" >18.37</td>
#       <td id="T_94363_row4_col7" class="data row4 col7" >SJ</td>
#       <td id="T_94363_row4_col8" class="data row4 col8" >2023-09-26 17:33:05</td>
#     </tr>
#     <tr>
#       <td id="T_94363_row5_col0" class="data row5 col0" >hawaiian paradise park</td>
#       <td id="T_94363_row5_col1" class="data row5 col1" >19.59</td>
#       <td id="T_94363_row5_col2" class="data row5 col2" >-154.97</td>
#       <td id="T_94363_row5_col3" class="data row5 col3" >80.91° F</td>
#       <td id="T_94363_row5_col4" class="data row5 col4" >68%</td>
#       <td id="T_94363_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_94363_row5_col6" class="data row5 col6" >6.91</td>
#       <td id="T_94363_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_94363_row5_col8" class="data row5 col8" >2023-09-26 17:33:06</td>
#     </tr>
#     <tr>
#       <td id="T_94363_row6_col0" class="data row6 col0" >sitka</td>
#       <td id="T_94363_row6_col1" class="data row6 col1" >57.05</td>
#       <td id="T_94363_row6_col2" class="data row6 col2" >-135.33</td>
#       <td id="T_94363_row6_col3" class="data row6 col3" >55.29° F</td>
#       <td id="T_94363_row6_col4" class="data row6 col4" >88%</td>
#       <td id="T_94363_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_94363_row6_col6" class="data row6 col6" >5.75</td>
#       <td id="T_94363_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_94363_row6_col8" class="data row6 col8" >2023-09-26 17:33:06</td>
#     </tr>
#     <tr>
#       <td id="T

# %% [markdown]
# ### **Temperature vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.1: Temperature vs. Latitude (Northern Hemisphere)',
         1, 2.0, 45.0)
# Out:
# r-value:     -0.8415
# r-squared:   0.7081

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.2: Temperature vs. Latitude (Southern Hemisphere)',
         1, -55.0, 85.0)
# Out:
# r-value:     0.7761
# r-squared:   0.6023

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### From the results of the linear regression, in the northern hemisphere, the latitude is negatively correlated with temperature; this negative correlation tells us that the two variables move in opposite directions: as latitude increases, the temperature drops, and vice versa.  In the southern hemisphers, the latitude is positively correlated with temperature: this positive correlation tells us that the two variables move in the same direction: as latitude increases, the temperature increases.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.3: Humidity vs. Latitude (Northern Hemisphere)',
         1, 45.0, 18.0)
# Out:
# r-value:     0.0589
# r-squared:   0.0035

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.4: Humidity vs. Latitude (Southern Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     0.0834
# r-squared:   0.0070

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and humidity in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Cloudiness vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.5: Cloudiness vs. Latitude (Northern Hemisphere)',
         1, 16.0, 62.0)
# Out:
# r-value:     0.0959
# r-squared:   0.0092

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.6: Cloudiness vs. Latitude (Southern Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     -0.0090
# r-squared:   0.0001

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and cloudiness in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.7: Wind Speed vs. Latitude (Northern Hemisphere)',
         1, 15.0, 22.0)
# Out:
# r-value:     0.1926
# r-squared:   0.0371

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.8: Wind Speed vs. Latitude (Southern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.2531
# r-squared:   0.0641

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and wind speed in either hemisphere.

# %%
#log_subroutine \
#    .EndProgramExecution()
