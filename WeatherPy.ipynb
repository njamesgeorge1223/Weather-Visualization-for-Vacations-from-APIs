# %% [markdown]
# # WeatherPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, WeatherPy.ipynb, uses a Python script to 
 #      visualize the weather of over 500 cities of varying distances from the equator. 
 #      The script uses the citipy Python library and the openWeatherMap API to create 
 #      a representative model of weather across cities.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubRoutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'WeatherPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('WeatherPy')

# %% [markdown]
# # <br> **Section 1: Weather Variables and Latitude**

# %% [markdown]
# ## **Section 1.1: Data Acquisition**

# %% [markdown]
# ### **List of Cities**

# %%
citiesListOfStrings \
    = api_function \
        .ReturnCitiesList()

# %% [markdown]
# ### **Weather Data from List of Cities**

# %%
cityWeatherDataFrame \
    = api_function \
        .ReturnWeatherDataFrame \
            (citiesListOfStrings)
# Out:
# DATA RETRIEVAL FOR CITY WEATHER DATAFRAME BEGINS...
#
#
# PROCESSING RECORD #2 OF SET 1 FOR CITY, margaret river.
#
# PROCESSING RECORD #3 OF SET 1 FOR CITY, edinburgh of the seven seas.
#
# PROCESSING RECORD #4 OF SET 1 FOR CITY, nova sintra.
#
# PROCESSING RECORD #5 OF SET 1 FOR CITY, adamstown.
#
# PROCESSING RECORD #6 OF SET 1 FOR CITY, port-aux-francais.
#
# PROCESSING RECORD #7 OF SET 1 FOR CITY, afaahiti.
#
# PROCESSING RECORD #8 OF SET 1 FOR CITY, gueoul.
#
# The script did not find the city, gueoul. Skipping...
#
# PROCESSING RECORD #9 OF SET 1 FOR CITY, lompoc.
#
# PROCESSING RECORD #10 OF SET 1 FOR CITY, albany.
#
# PROCESSING RECORD #11 OF SET 1 FOR CITY, bilibino.
#
# PROCESSING RECORD #12 OF SET 1 FOR CITY, wailua homesteads.
#
# PROCESSING RECORD #13 OF SET 1 FOR CITY, camapua.
#
# PROCESSING RECORD #14 OF SET 1 FOR CITY, pasuquin.
#
# PROCESSING RECORD #15 OF SET 1 FOR CITY, dryden.
#
# PROCESSING RECORD #16 OF SET 1 FOR CITY, gonzaga.
#
# PROCESSING RECORD #17 OF SET 1 FOR CITY, bredasdorp.
#
# PROCESSING RECORD #18 OF SET 1 FOR CITY, grytviken.
#
# PROCESSING RECORD #19 OF SET 1 FOR CITY, gherla.
#
# PROCESSING RECORD #20 OF SET 1 FOR CITY, lebu.
#
# PROCESSING RECORD #21 OF SET 1 FOR CITY, khowy.
#
# PROCESSING RECORD #22 OF SET 1 FOR CITY, kingston.
#
# PROCESSING RECORD #23 OF SET 1 FOR CITY, tol'yatti.
#
# PROCESSING RECORD #24 OF SET 1 FOR CITY, bethel.
#
# PROCESSING RECORD #25 OF SET 1 FOR CITY, alice springs.
#
# PROCESSING RECORD #26 OF SET 1 FOR CITY, kruisfontein.
#
# PROCESSING RECORD #27 OF SET 1 FOR CITY, palikir - national government center.
#
# PROCESSING RECORD #28 OF SET 1 FOR CITY, cidade velha.
#
# PROCESSING RECORD #29 OF SET 1 FOR CITY, puerto natales.
#
# PROCESSING RECORD #30 OF SET 1 FOR CITY, vilyuchinsk.
#
# PROCESSING RECORD #31 OF SET 1 FOR CITY, aykhal.
#
# PROCESSING RECORD #32 OF SET 1 FOR CITY, hasaki.
#
# PROCESSING RECORD #33 OF SET 1 FOR CITY, kodiak.
#
# PROCESSING RECORD #34 OF SET 1 FOR CITY, qamdo.
#
# PROCESSING RECORD #35 OF SET 1 FOR CITY, west island.
#
# PROCESSING RECORD #36 OF SET 1 FOR CITY, belyy yar.
#
# PROCESSING RECORD #37 OF SET 1 FOR CITY, kavaratti.
#
# PROCESSING RECORD #38 OF SET 1 FOR CITY, kurumkan.
#
# PROCESSING RECORD #39 OF SET 1 FOR CITY, bryne.
#
# PROCESSING RECORD #40 OF SET 1 FOR CITY, touros.
#
# PROCESSING RECORD #41 OF SET 1 FOR CITY, kaga bandoro.
#
# PROCESSING RECORD #42 OF SET 1 FOR CITY, chegdomyn.
#
# PROCESSING RECORD #43 OF SET 1 FOR CITY, taiohae.
#
# The script did not find the city, taiohae. Skipping...
#
# PROCESSING RECORD #44 OF SET 1 FOR CITY, edd.
#
# PROCESSING RECORD #45 OF SET 1 FOR CITY, georgetown.
#
# PROCESSING RECORD #46 OF SET 1 FOR CITY, constantia.
#
# PROCESSING RECORD #47 OF SET 1 FOR CITY, invercargill.
#
# PROCESSING RECORD #48 OF SET 1 FOR CITY, ta`u.
#
# PROCESSING RECORD #49 OF SET 1 FOR CITY, punta arenas.
#
# PROCESSING RECORD #50 OF SET 1 FOR CITY, ushuaia.
#
# PROCESSING RECORD #51 OF SET 1 FOR CITY, blackmans bay.
#
# PROCESSING RECORD #1 OF SET 2 FOR CITY, tavda.
#
# PROCESSING RECORD #2 OF SET 2 FOR CITY, akjoujt.
#
# PROCESSING RECORD #3 OF SET 2 FOR CITY, sao paulo de olivenca.
#
# PROCESSING RECORD #4 OF SET 2 FOR CITY, heber city.
#
# PROCESSING RECORD #5 OF SET 2 FOR CITY, urangan.
#
# PROCESSING RECORD #6 OF SET 2 FOR CITY, chilca.
#
# PROCESSING RECORD #7 OF SET 2 FOR CITY, waitangi.
#
# PROCESSING RECORD #8 OF SET 2 FOR CITY, jamestown.
#
# PROCESSING RECORD #9 OF SET 2 FOR CITY, papatowai.
#
# PROCESSING RECORD #10 OF SET 2 FOR CITY, bertoua.
#
# PROCESSING RECORD #11 OF SET 2 FOR CITY, villamontes.
#
# PROCESSING RECORD #12 OF SET 2 FOR CITY, aasiaat.
#
# PROCESSING RECORD #13 OF SET 2 FOR CITY, vila velha.
#
# PROCESSING RECORD #14 OF SET 2 FOR CITY, kultali.
#
# The script did not find the city, kultali. Skipping...
#
# PROCESSING RECORD #15 OF SET 2 FOR CITY, mirny.
#
# PROCESSING RECORD #16 OF SET 2 FOR CITY, yellowknife.
#
# PROCESSING RECORD #17 OF SET 2 FOR CITY, cable beach.
#
# The script did not find the city, cable beach. Skipping...
#
# PROCESSING RECORD #18 OF SET 2 FOR CITY, l'alcora.
#
# PROCESSING RECORD #19 OF SET 2 FOR CITY, thompson.
#
# PROCESSING RECORD #20 OF SET 2 FOR CITY, hamilton.
#
# PROCESSING RECORD #21 OF SET 2 FOR CITY, yulinshi.
#
# PROCESSING RECORD #22 OF SET 2 FOR CITY, salinopolis.
#
# PROCESSING RECORD #23 OF SET 2 FOR CITY, saipan.
#
# PROCESSING RECORD #24 OF SET 2 FOR CITY, kimbe.
#
# PROCESSING RECORD #25 OF SET 2 FOR CITY, lihue.
#
# PROCESSING RECORD #26 OF SET 2 FOR CITY, codrington.
#
# PROCESSING RECORD #27 OF SET 2 FOR CITY, hilo.
#
# PROCESSING RECORD #28 OF SET 2 FOR CITY, ribeira grande.
#
# PROCESSING RECORD #29 OF SET 2 FOR CITY, arkhangel'sk.
#
# PROCESSING RECORD #30 OF SET 2 FOR CITY, conceicao da barra.
#
# PROCESSING RECORD #31 OF SET 2 FOR CITY, nuuk.
#
# PROCESSING RECORD #32 OF SET 2 FOR CITY, atbara.
#
# PROCESSING RECORD #33 OF SET 2 FOR CITY, anuradhapura.
#
# PROCESSING RECORD #34 OF SET 2 FOR CITY, avarua.
#
# PROCESSING RECORD #35 OF SET 2 FOR CITY, college.
#
# PROCESSING RECORD #36 OF SET 2 FOR CITY, st. john's.
#
# PROCESSING RECORD #37 OF SET 2 FOR CITY, puerto ayora.
#
# PROCESSING RECORD #38 OF SET 2 FOR CITY, pangai.
#
# PROCESSING RECORD #39 OF SET 2 FOR CITY, labytnangi.
#
# PROCESSING RECORD #40 OF SET 2 FOR CITY, genhe.
#
# PROCESSING RECORD #41 OF SET 2 FOR CITY, hopelchen.
#
# PROCESSING RECORD #42 OF SET 2 FOR CITY, shekhupura.
#
# PROCESSING RECORD #43 OF SET 2 FOR CITY, guneysu.
#
# PROCESSING RECORD #44 OF SET 2 FOR CITY, nookat.
#
# The script did not find the city, nookat. Skipping...
#
# PROCESSING RECORD #45 OF SET 2 FOR CITY, colonia.
#
# PROCESSING RECORD #46 OF SET 2 FOR CITY, hermanus.
#
# PROCESSING RECORD #47 OF SET 2 FOR CITY, nova vicosa.
#
# PROCESSING RECORD #48 OF SET 2 FOR CITY, uturoa.
#
# PROCESSING RECORD #49 OF SET 2 FOR CITY, kirakira.
#
# PROCESSING RECORD #50 OF SET 2 FOR CITY, badger.
#
# PROCESSING RECORD #1 OF SET 3 FOR CITY, asbe teferi.
#
# PROCESSING RECORD #2 OF SET 3 FOR CITY, anadyr.
#
# PROCESSING RECORD #3 OF SET 3 FOR CITY, fauske.
#
# PROCESSING RECORD #4 OF SET 3 FOR CITY, wellington.
#
# PROCESSING RECORD #5 OF SET 3 FOR CITY, weno.
#
# PROCESSING RECORD #6 OF SET 3 FOR CITY, an nuhud.
#
# PROCESSING RECORD #7 OF SET 3 FOR CITY, vernon.
#
# PROCESSING RECORD #8 OF SET 3 FOR CITY, klaksvik.
#
# PROCESSING RECORD #9 OF SET 3 FOR CITY, chonchi.
#
# PROCESSING RECORD #10 OF SET 3 FOR CITY, sinabang.
#
# PROCESSING RECORD #11 OF SET 3 FOR CITY, tolanaro.
#
# PROCESSING RECORD #12 OF SET 3 FOR CITY, severo-yeniseyskiy.
#
# PROCESSING RECORD #13 OF SET 3 FOR CITY, maragogi.
#
# PROCESSING RECORD #14 OF SET 3 FOR CITY, hithadhoo.
#
# PROCESSING RECORD #15 OF SET 3 FOR CITY, iskateley.
#
# PROCESSING RECORD #16 OF SET 3 FOR CITY, duong dong.
#
# PROCESSING RECORD #17 OF SET 3 FOR CITY, fuvahmulah.
#
# The script did not find the city, fuvahmulah. Skipping...
#
# PROCESSING RECORD #18 OF SET 3 FOR CITY, hawaiian paradise park.
#
# PROCESSING RECORD #19 OF SET 3 FOR CITY, souillac.
#
# PROCESSING RECORD #20 OF SET 3 FOR CITY, vorgashor.
#
# PROCESSING RECORD #21 OF SET 3 FOR CITY, cidreira.
#
# PROCESSING RECORD #22 OF SET 3 FOR CITY, ilulissat.
#
# PROCESSING RECORD #23 OF SET 3 FOR CITY, ust-nera.
#
# PROCESSING RECORD #24 OF SET 3 FOR CITY, osorno.
#
# PROCESSING RECORD #25 OF SET 3 FOR CITY, rio grande.
#
# PROCESSING RECORD #26 OF SET 3 FOR CITY, beruwala.
#
# PROCESSING RECORD #27 OF SET 3 FOR CITY, tantou.
#
# PROCESSING RECORD #28 OF SET 3 FOR CITY, morehead city.
#
# PROCESSING RECORD #29 OF SET 3 FOR CITY, fale old settlement.
#
# PROCESSING RECORD #30 OF SET 3 FOR CITY, pacific grove.
#
# PROCESSING RECORD #31 OF SET 3 FOR CITY, puerto leguizamo.
#
# PROCESSING RECORD #32 OF SET 3 FOR CITY, ankang.
#
# PROCESSING RECORD #33 OF SET 3 FOR CITY, sisimiut.
#
# PROCESSING RECORD #34 OF SET 3 FOR CITY, balimila.
#
# PROCESSING RECORD #35 OF SET 3 FOR CITY, olonkinbyen.
#
# PROCESSING RECORD #36 OF SET 3 FOR CITY, nampula.
#
# PROCESSING RECORD #37 OF SET 3 FOR CITY, lisala.
#
# PROCESSING RECORD #38 OF SET 3 FOR CITY, tsiombe.
#
# PROCESSING RECORD #39 OF SET 3 FOR CITY, hadibu.
#
# PROCESSING RECORD #40 OF SET 3 FOR CITY, talnakh.
#
# PROCESSING RECORD #41 OF SET 3 FOR CITY, alappuzha.
#
# PROCESSING RECORD #42 OF SET 3 FOR CITY, longyearbyen.
#
# PROCESSING RECORD #43 OF SET 3 FOR CITY, port mathurin.
#
# PROCESSING RECORD #44 OF SET 3 FOR CITY, sint michiel liber.
#
# PROCESSING RECORD #45 OF SET 3 FOR CITY, lata.
#
# PROCESSING RECORD #46 OF SET 3 FOR CITY, remire-montjoly.
#
# PROCESSING RECORD #47 OF SET 3 FOR CITY, allapalli.
#
# PROCESSING RECORD #48 OF SET 3 FOR CITY, kolonia.
# PROCESSING RECORD #49 OF SET 3 FOR CITY, mount gambier.
#
# PROCESSING RECORD #50 OF SET 3 FOR CITY, andovoranto.
#
# PROCESSING RECORD #1 OF SET 4 FOR CITY, petropavlovsk-kamchatsky.
#
# PROCESSING RECORD #2 OF SET 4 FOR CITY, central.
#
# PROCESSING RECORD #3 OF SET 4 FOR CITY, flying fish cove.
#
# PROCESSING RECORD #4 OF SET 4 FOR CITY, carutapera.
#
# PROCESSING RECORD #5 OF SET 4 FOR CITY, fort bragg.
#
# PROCESSING RECORD #6 OF SET 4 FOR CITY, tsetserleg.
#
# PROCESSING RECORD #7 OF SET 4 FOR CITY, whitehorse.
#
# PROCESSING RECORD #8 OF SET 4 FOR CITY, sault ste. marie.
#
# PROCESSING RECORD #9 OF SET 4 FOR CITY, chibougamau.
#
# PROCESSING RECORD #10 OF SET 4 FOR CITY, san angelo.
#
# PROCESSING RECORD #11 OF SET 4 FOR CITY, wanlaweyn.
#
# PROCESSING RECORD #12 OF SET 4 FOR CITY, nouadhibou.
#
# PROCESSING RECORD #13 OF SET 4 FOR CITY, qaqortoq.
#
# PROCESSING RECORD #14 OF SET 4 FOR CITY, am djarass.
#
# The script did not find the city, am djarass. Skipping...
#
# PROCESSING RECORD #15 OF SET 4 FOR CITY, tazovsky.
#
# PROCESSING RECORD #16 OF SET 4 FOR CITY, polyarnyy.
#
# PROCESSING RECORD #17 OF SET 4 FOR CITY, holualoa.
#
# PROCESSING RECORD #18 OF SET 4 FOR CITY, sitka.
#
# PROCESSING RECORD #19 OF SET 4 FOR CITY, toga village.
#
# The script did not find the city, toga village. Skipping...
#
# PROCESSING RECORD #20 OF SET 4 FOR CITY, center.
#
# PROCESSING RECORD #21 OF SET 4 FOR CITY, portland.
#
# PROCESSING RECORD #22 OF SET 4 FOR CITY, melilla.
#
# PROCESSING RECORD #23 OF SET 4 FOR CITY, san pedro.
#
# PROCESSING RECORD #24 OF SET 4 FOR CITY, tromso.
#
# PROCESSING RECORD #25 OF SET 4 FOR CITY, keflavik.
#
# PROCESSING RECORD #26 OF SET 4 FOR CITY, lansdowne.
#
# PROCESSING RECORD #27 OF SET 4 FOR CITY, amga.
#
# PROCESSING RECORD #28 OF SET 4 FOR CITY, enriquillo.
#
# PROCESSING RECORD #29 OF SET 4 FOR CITY, ruteng.
#
# PROCESSING RECORD #30 OF SET 4 FOR CITY, dudinka.
#
# PROCESSING RECORD #31 OF SET 4 FOR CITY, renk.
#
# The script did not find the city, renk. Skipping...
#
# PROCESSING RECORD #32 OF SET 4 FOR CITY, meadow lake.
#
# PROCESSING RECORD #33 OF SET 4 FOR CITY, bermeo.
#
# PROCESSING RECORD #34 OF SET 4 FOR CITY, lautoka.
#
# PROCESSING RECORD #35 OF SET 4 FOR CITY, burang.
#
# PROCESSING RECORD #36 OF SET 4 FOR CITY, stanley.
#
# PROCESSING RECORD #37 OF SET 4 FOR CITY, zhangjiakou shi xuanhua qu.
#
# PROCESSING RECORD #38 OF SET 4 FOR CITY, villa bruzual.
#
# PROCESSING RECORD #39 OF SET 4 FOR CITY, selfoss.
#
# PROCESSING RECORD #40 OF SET 4 FOR CITY, port alfred.
#
# PROCESSING RECORD #41 OF SET 4 FOR CITY, ujae.
#
# PROCESSING RECORD #42 OF SET 4 FOR CITY, sos'va.
#
# PROCESSING RECORD #43 OF SET 4 FOR CITY, haiku-pauwela.
#
# PROCESSING RECORD #44 OF SET 4 FOR CITY, bousso.
#
# PROCESSING RECORD #45 OF SET 4 FOR CITY, inhambane.
#
# PROCESSING RECORD #46 OF SET 4 FOR CITY, iqaluit.
#
# PROCESSING RECORD #47 OF SET 4 FOR CITY, taulaga.
#
# PROCESSING RECORD #48 OF SET 4 FOR CITY, diego de almagro.
#
# PROCESSING RECORD #49 OF SET 4 FOR CITY, sao geraldo do araguaia.
#
# PROCESSING RECORD #50 OF SET 4 FOR CITY, utrik.
#
# PROCESSING RECORD #1 OF SET 5 FOR CITY, vingt cinq.
#
# The script did not find the city, vingt cinq. Skipping...
#
# PROCESSING RECORD #2 OF SET 5 FOR CITY, arboletes.
#
# PROCESSING RECORD #3 OF SET 5 FOR CITY, pavilosta.
#
# PROCESSING RECORD #4 OF SET 5 FOR CITY, gorakhpur.
#
# PROCESSING RECORD #5 OF SET 5 FOR CITY, isafjordur.
#
# PROCESSING RECORD #6 OF SET 5 FOR CITY, port elizabeth.
#
# PROCESSING RECORD #7 OF SET 5 FOR CITY, tura.
#
# PROCESSING RECORD #8 OF SET 5 FOR CITY, san patricio.
#
# PROCESSING RECORD #9 OF SET 5 FOR CITY, manokwari.
#
# PROCESSING RECORD #10 OF SET 5 FOR CITY, ancud.
#
# PROCESSING RECORD #11 OF SET 5 FOR CITY, mokopane.
#
# PROCESSING RECORD #12 OF SET 5 FOR CITY, tucuma.
#
# PROCESSING RECORD #13 OF SET 5 FOR CITY, al kharijah.
#
# PROCESSING RECORD #14 OF SET 5 FOR CITY, balch springs.
#
# PROCESSING RECORD #15 OF SET 5 FOR CITY, retreat.
#
# PROCESSING RECORD #16 OF SET 5 FOR CITY, tejen.
#
# PROCESSING RECORD #17 OF SET 5 FOR CITY, almirante.
#
# PROCESSING RECORD #18 OF SET 5 FOR CITY, atafu village.
#
# PROCESSING RECORD #19 OF SET 5 FOR CITY, acapulco de juarez.
#
# PROCESSING RECORD #20 OF SET 5 FOR CITY, quellon.
#
# PROCESSING RECORD #21 OF SET 5 FOR CITY, maceio.
#
# PROCESSING RECORD #22 OF SET 5 FOR CITY, port blair.
#
# PROCESSING RECORD #23 OF SET 5 FOR CITY, mar del plata.
#
# PROCESSING RECORD #24 OF SET 5 FOR CITY, idrinskoye.
#
# PROCESSING RECORD #25 OF SET 5 FOR CITY, vallenar.
#
# PROCESSING RECORD #26 OF SET 5 FOR CITY, saguenay.
#
# PROCESSING RECORD #27 OF SET 5 FOR CITY, noumea.
#
# PROCESSING RECORD #28 OF SET 5 FOR CITY, ballyclare.
#
# PROCESSING RECORD #29 OF SET 5 FOR CITY, plastun.
#
# PROCESSING RECORD #30 OF SET 5 FOR CITY, port lincoln.
#
# PROCESSING RECORD #31 OF SET 5 FOR CITY, bodaybo.
#
# PROCESSING RECORD #32 OF SET 5 FOR CITY, toliara.
#
# PROCESSING RECORD #33 OF SET 5 FOR CITY, weiser.
#
# PROCESSING RECORD #34 OF SET 5 FOR CITY, ivdel'.
#
# PROCESSING RECORD #35 OF SET 5 FOR CITY, siwa oasis.
#
# PROCESSING RECORD #36 OF SET 5 FOR CITY, recani.
#
# PROCESSING RECORD #37 OF SET 5 FOR CITY, kupang.
#
# PROCESSING RECORD #38 OF SET 5 FOR CITY, kapa'a.
#
# PROCESSING RECORD #39 OF SET 5 FOR CITY, smara.
#
# PROCESSING RECORD #40 OF SET 5 FOR CITY, broken hill.
#
# PROCESSING RECORD #41 OF SET 5 FOR CITY, san jose del cabo.
#
# PROCESSING RECORD #42 OF SET 5 FOR CITY, gallneukirchen.
#
# PROCESSING RECORD #43 OF SET 5 FOR CITY, porto novo.
#
# PROCESSING RECORD #44 OF SET 5 FOR CITY, fuyu.
#
# PROCESSING RECORD #45 OF SET 5 FOR CITY, oltinko'l.
#
# PROCESSING RECORD #46 OF SET 5 FOR CITY, bonthe.
#
# PROCESSING RECORD #47 OF SET 5 FOR CITY, turpan.
#
# PROCESSING RECORD #48 OF SET 5 FOR CITY, gadzhiyevo.
#
# PROCESSING RECORD #49 OF SET 5 FOR CITY, sao jose da coroa grande.
#
# PROCESSING RECORD #50 OF SET 5 FOR CITY, pskov.
#
# PROCESSING RECORD #1 OF SET 6 FOR CITY, uige.
#
# PROCESSING RECORD #2 OF SET 6 FOR CITY, dakhla.
#
# PROCESSING RECORD #3 OF SET 6 FOR CITY, alesund.
#
# PROCESSING RECORD #4 OF SET 6 FOR CITY, wladyslawowo.
#
# PROCESSING RECORD #5 OF SET 6 FOR CITY, minas de marcona.
#
# PROCESSING RECORD #6 OF SET 6 FOR CITY, antalaha.
#
# PROCESSING RECORD #7 OF SET 6 FOR CITY, luau.
#
# PROCESSING RECORD #8 OF SET 6 FOR CITY, kulia village.
#
# The script did not find the city, kulia village. Skipping...
#
# PROCESSING RECORD #9 OF SET 6 FOR CITY, beira.
#
# PROCESSING RECORD #10 OF SET 6 FOR CITY, cambria.
#
# PROCESSING RECORD #11 OF SET 6 FOR CITY, klyuchi.
#
# PROCESSING RECORD #12 OF SET 6 FOR CITY, playa del ingles.
#
# PROCESSING RECORD #13 OF SET 6 FOR CITY, nar'yan-mar.
#
# PROCESSING RECORD #14 OF SET 6 FOR CITY, aldan.
#
# PROCESSING RECORD #15 OF SET 6 FOR CITY, bladel.
#
# PROCESSING RECORD #16 OF SET 6 FOR CITY, cabo san lucas.
#
# PROCESSING RECORD #17 OF SET 6 FOR CITY, karlskrona.
#
# PROCESSING RECORD #18 OF SET 6 FOR CITY, carnarvon.
#
# PROCESSING RECORD #19 OF SET 6 FOR CITY, praia grande.
#
# PROCESSING RECORD #20 OF SET 6 FOR CITY, lionel town.
#
# PROCESSING RECORD #21 OF SET 6 FOR CITY, nemuro.
#
# PROCESSING RECORD #22 OF SET 6 FOR CITY, east london.
#
# PROCESSING RECORD #23 OF SET 6 FOR CITY, kirkwall.
#
# PROCESSING RECORD #24 OF SET 6 FOR CITY, 'ohonua.
#
# The script did not find the city, 'ohonua. Skipping...
#
# PROCESSING RECORD #25 OF SET 6 FOR CITY, vyborg.
#
# PROCESSING RECORD #26 OF SET 6 FOR CITY, cill airne.
#
# PROCESSING RECORD #27 OF SET 6 FOR CITY, la sarre.
#
# PROCESSING RECORD #28 OF SET 6 FOR CITY, afif.
#
# PROCESSING RECORD #29 OF SET 6 FOR CITY, benghazi.
#
# PROCESSING RECORD #30 OF SET 6 FOR CITY, anaconda.
#
# PROCESSING RECORD #31 OF SET 6 FOR CITY, egilsstadir.
#
# PROCESSING RECORD #32 OF SET 6 FOR CITY, port-gentil.
#
# PROCESSING RECORD #33 OF SET 6 FOR CITY, katsuren-haebaru.
#
# PROCESSING RECORD #34 OF SET 6 FOR CITY, richard-toll.
#
# PROCESSING RECORD #35 OF SET 6 FOR CITY, mathis.
#
# PROCESSING RECORD #36 OF SET 6 FOR CITY, lorengau.
#
# PROCESSING RECORD #37 OF SET 6 FOR CITY, gewane.
#
# PROCESSING RECORD #38 OF SET 6 FOR CITY, rongelap.
#
# PROCESSING RECORD #39 OF SET 6 FOR CITY, olinda.
#
# PROCESSING RECORD #40 OF SET 6 FOR CITY, aitape.
#
# PROCESSING RECORD #41 OF SET 6 FOR CITY, berlin.
#
# PROCESSING RECORD #42 OF SET 6 FOR CITY, newman.
#
# PROCESSING RECORD #43 OF SET 6 FOR CITY, nerja.
#
# PROCESSING RECORD #44 OF SET 6 FOR CITY, gizo.
#
# PROCESSING RECORD #45 OF SET 6 FOR CITY, new norfolk.
#
# PROCESSING RECORD #46 OF SET 6 FOR CITY, saratamata.
#
# The script did not find the city, saratamata. Skipping...
#
# PROCESSING RECORD #47 OF SET 6 FOR CITY, revda.
# PROCESSING RECORD #48 OF SET 6 FOR CITY, calderitas.
#
# PROCESSING RECORD #49 OF SET 6 FOR CITY, east grand forks.
#
# PROCESSING RECORD #50 OF SET 6 FOR CITY, aoulef.
#
# PROCESSING RECORD #1 OF SET 7 FOR CITY, puerto san carlos.
#
# The script did not find the city, puerto san carlos. Skipping...
#
# PROCESSING RECORD #2 OF SET 7 FOR CITY, san antonio de pale.
#
# PROCESSING RECORD #3 OF SET 7 FOR CITY, nantucket.
#
# PROCESSING RECORD #4 OF SET 7 FOR CITY, nadym.
#
# PROCESSING RECORD #5 OF SET 7 FOR CITY, uliastay.
#
# PROCESSING RECORD #6 OF SET 7 FOR CITY, nambucca heads.
#
# PROCESSING RECORD #7 OF SET 7 FOR CITY, puerto ayacucho.
#
# PROCESSING RECORD #8 OF SET 7 FOR CITY, praia da vitoria.
#
# PROCESSING RECORD #9 OF SET 7 FOR CITY, bera.
#
# PROCESSING RECORD #10 OF SET 7 FOR CITY, cockburn town.
#
# PROCESSING RECORD #11 OF SET 7 FOR CITY, kerikeri.
#
# PROCESSING RECORD #12 OF SET 7 FOR CITY, kharan.
#
# PROCESSING RECORD #13 OF SET 7 FOR CITY, beroroha.
#
# PROCESSING RECORD #14 OF SET 7 FOR CITY, kannangad.
#
# PROCESSING RECORD #15 OF SET 7 FOR CITY, tazacorte.
#
# PROCESSING RECORD #16 OF SET 7 FOR CITY, port-saint-louis-du-rhone.
#
# PROCESSING RECORD #17 OF SET 7 FOR CITY, mejit.
#
# PROCESSING RECORD #18 OF SET 7 FOR CITY, robore.
#
# PROCESSING RECORD #19 OF SET 7 FOR CITY, yaren.
#
# PROCESSING RECORD #20 OF SET 7 FOR CITY, karratha.
#
# PROCESSING RECORD #21 OF SET 7 FOR CITY, happy valley-goose bay.
#
# PROCESSING RECORD #22 OF SET 7 FOR CITY, richards bay.
#
# PROCESSING RECORD #23 OF SET 7 FOR CITY, mabini.
#
# PROCESSING RECORD #24 OF SET 7 FOR CITY, howrah.
#
# PROCESSING RECORD #25 OF SET 7 FOR CITY, crane.
#
# PROCESSING RECORD #26 OF SET 7 FOR CITY, labrador city.
#
# PROCESSING RECORD #27 OF SET 7 FOR CITY, ust-tsilma.
#
# PROCESSING RECORD #28 OF SET 7 FOR CITY, fortuna.
#
# PROCESSING RECORD #29 OF SET 7 FOR CITY, mukah.
#
# The script did not find the city, mukah. Skipping...
#
# PROCESSING RECORD #30 OF SET 7 FOR CITY, rosso.
#
# PROCESSING RECORD #31 OF SET 7 FOR CITY, shanwei.
#
# PROCESSING RECORD #32 OF SET 7 FOR CITY, hammerfest.
#
# PROCESSING RECORD #33 OF SET 7 FOR CITY, yuzhno-kurilsk.
#
# PROCESSING RECORD #34 OF SET 7 FOR CITY, la passe.
#
# PROCESSING RECORD #35 OF SET 7 FOR CITY, choszczno.
#
# PROCESSING RECORD #36 OF SET 7 FOR CITY, susuman.
#
# PROCESSING RECORD #37 OF SET 7 FOR CITY, dolinsk.
#
# PROCESSING RECORD #38 OF SET 7 FOR CITY, hovd.
#
# PROCESSING RECORD #39 OF SET 7 FOR CITY, falmouth.
#
# PROCESSING RECORD #40 OF SET 7 FOR CITY, muynoq.
#
# PROCESSING RECORD #41 OF SET 7 FOR CITY, suva.
#
# PROCESSING RECORD #42 OF SET 7 FOR CITY, vila franca do campo.
#
# PROCESSING RECORD #43 OF SET 7 FOR CITY, claveria.
#
# PROCESSING RECORD #44 OF SET 7 FOR CITY, gandajika.
#
# PROCESSING RECORD #45 OF SET 7 FOR CITY, east ballina.
#
# PROCESSING RECORD #46 OF SET 7 FOR CITY, tiksi.
#
# PROCESSING RECORD #47 OF SET 7 FOR CITY, zabaykal'sk.
#
# PROCESSING RECORD #48 OF SET 7 FOR CITY, hoxtolgay.
#
# The script did not find the city, hoxtolgay. Skipping...
#
# PROCESSING RECORD #49 OF SET 7 FOR CITY, vadso.
#
# PROCESSING RECORD #50 OF SET 7 FOR CITY, antsiranana.
#
# PROCESSING RECORD #1 OF SET 8 FOR CITY, ghadamis.
#
# PROCESSING RECORD #2 OF SET 8 FOR CITY, betare oya.
#
# PROCESSING RECORD #3 OF SET 8 FOR CITY, taskopru.
#
# PROCESSING RECORD #4 OF SET 8 FOR CITY, anapa.
#
# PROCESSING RECORD #5 OF SET 8 FOR CITY, jagraon.
#
# PROCESSING RECORD #6 OF SET 8 FOR CITY, bogale.
#
# PROCESSING RECORD #7 OF SET 8 FOR CITY, port hedland.
#
# PROCESSING RECORD #8 OF SET 8 FOR CITY, revelstoke.
#
# PROCESSING RECORD #9 OF SET 8 FOR CITY, suntar.
#
# PROCESSING RECORD #10 OF SET 8 FOR CITY, enewetak.
#
# PROCESSING RECORD #11 OF SET 8 FOR CITY, basco.
#
# PROCESSING RECORD #12 OF SET 8 FOR CITY, onguday.
#
# PROCESSING RECORD #13 OF SET 8 FOR CITY, krasavino.
#
# PROCESSING RECORD #14 OF SET 8 FOR CITY, ouadda.
#
# PROCESSING RECORD #15 OF SET 8 FOR CITY, kiunga.
#
# PROCESSING RECORD #16 OF SET 8 FOR CITY, udachny.
#
# PROCESSING RECORD #17 OF SET 8 FOR CITY, narrabri.
#
# PROCESSING RECORD #18 OF SET 8 FOR CITY, carbonear.
#
# PROCESSING RECORD #19 OF SET 8 FOR CITY, baukau.
#
# PROCESSING RECORD #20 OF SET 8 FOR CITY, aleksandrovsk-sakhalinskiy.
#
# PROCESSING RECORD #21 OF SET 8 FOR CITY, sidi bel abbes.
#
# PROCESSING RECORD #22 OF SET 8 FOR CITY, paxtakor shahri.
#
# The script did not find the city, paxtakor shahri. Skipping...
#
# PROCESSING RECORD #23 OF SET 8 FOR CITY, yeppoon.
#
# PROCESSING RECORD #24 OF SET 8 FOR CITY, hargeysa.
#
# PROCESSING RECORD #25 OF SET 8 FOR CITY, key west.
#
# PROCESSING RECORD #26 OF SET 8 FOR CITY, anshun.
#
# PROCESSING RECORD #27 OF SET 8 FOR CITY, sao vicente.
#
# PROCESSING RECORD #28 OF SET 8 FOR CITY, timimoun.
#
# PROCESSING RECORD #29 OF SET 8 FOR CITY, keminmaa.
#
# PROCESSING RECORD #30 OF SET 8 FOR CITY, pisco.
#
# PROCESSING RECORD #31 OF SET 8 FOR CITY, tarawa.
#
# PROCESSING RECORD #32 OF SET 8 FOR CITY, lethem.
#
# PROCESSING RECORD #33 OF SET 8 FOR CITY, ahau.
#
# The script did not find the city, ahau. Skipping...
#
# PROCESSING RECORD #34 OF SET 8 FOR CITY, zouerate.
#
# PROCESSING RECORD #35 OF SET 8 FOR CITY, mount isa.
#
# PROCESSING RECORD #36 OF SET 8 FOR CITY, santa cruz.
#
# PROCESSING RECORD #37 OF SET 8 FOR CITY, grand falls-windsor.
#
# PROCESSING RECORD #38 OF SET 8 FOR CITY, garhi khairo.
#
# PROCESSING RECORD #39 OF SET 8 FOR CITY, hobyo.
#
# PROCESSING RECORD #40 OF SET 8 FOR CITY, ampanihy.
#
# PROCESSING RECORD #41 OF SET 8 FOR CITY, aripuana.
#
# PROCESSING RECORD #42 OF SET 8 FOR CITY, hultsfred.
#
# PROCESSING RECORD #43 OF SET 8 FOR CITY, brawley.
#
# PROCESSING RECORD #44 OF SET 8 FOR CITY, xiongzhou.
#
# PROCESSING RECORD #45 OF SET 8 FOR CITY, santanyi.
#
# PROCESSING RECORD #46 OF SET 8 FOR CITY, tanrake village.
#
# The script did not find the city, tanrake village. Skipping...
#
# PROCESSING RECORD #47 OF SET 8 FOR CITY, los llanos de aridane.
#
# PROCESSING RECORD #48 OF SET 8 FOR CITY, popondetta.
#
# PROCESSING RECORD #49 OF SET 8 FOR CITY, sambava.
#
# PROCESSING RECORD #50 OF SET 8 FOR CITY, yeed.
#
# PROCESSING RECORD #1 OF SET 9 FOR CITY, port macquarie.
#
# PROCESSING RECORD #2 OF SET 9 FOR CITY, pontotoc.
#
# PROCESSING RECORD #3 OF SET 9 FOR CITY, namibe.
#
# PROCESSING RECORD #4 OF SET 9 FOR CITY, boa vista.
#
# PROCESSING RECORD #5 OF SET 9 FOR CITY, paita.
#
# PROCESSING RECORD #6 OF SET 9 FOR CITY, nagqu.
#
# PROCESSING RECORD #7 OF SET 9 FOR CITY, rikaze.
#
# PROCESSING RECORD #8 OF SET 9 FOR CITY, lomonosov.
#
# PROCESSING RECORD #9 OF SET 9 FOR CITY, thunder bay.
#
# PROCESSING RECORD #10 OF SET 9 FOR CITY, verkhnyaya salda.
#
# PROCESSING RECORD #11 OF SET 9 FOR CITY, wenchang.
#
# PROCESSING RECORD #12 OF SET 9 FOR CITY, cloverdale.
#
# PROCESSING RECORD #13 OF SET 9 FOR CITY, macau.
#
# PROCESSING RECORD #14 OF SET 9 FOR CITY, tofol.
#
# PROCESSING RECORD #15 OF SET 9 FOR CITY, cadale.
#
# PROCESSING RECORD #16 OF SET 9 FOR CITY, mbanza-ngungu.
#
# PROCESSING RECORD #17 OF SET 9 FOR CITY, umm kaddadah.
#
# PROCESSING RECORD #18 OF SET 9 FOR CITY, howard springs.
#
# PROCESSING RECORD #19 OF SET 9 FOR CITY, puerto aysen.
#
# PROCESSING RECORD #20 OF SET 9 FOR CITY, champerico.
#
# PROCESSING RECORD #21 OF SET 9 FOR CITY, general roca.
#
# PROCESSING RECORD #22 OF SET 9 FOR CITY, altay.
#
# PROCESSING RECORD #23 OF SET 9 FOR CITY, karliova.
#
# PROCESSING RECORD #24 OF SET 9 FOR CITY, amungan.
#
# PROCESSING RECORD #25 OF SET 9 FOR CITY, sovetskaya gavan'.
#
# PROCESSING RECORD #26 OF SET 9 FOR CITY, coquimbo.
#
# PROCESSING RECORD #27 OF SET 9 FOR CITY, steamboat springs.
#
# PROCESSING RECORD #28 OF SET 9 FOR CITY, ayr.
#
# PROCESSING RECORD #29 OF SET 9 FOR CITY, nabire.
#
# PROCESSING RECORD #30 OF SET 9 FOR CITY, nogliki.
#
# PROCESSING RECORD #31 OF SET 9 FOR CITY, manismata.
#
# PROCESSING RECORD #32 OF SET 9 FOR CITY, maraba.
#
# PROCESSING RECORD #33 OF SET 9 FOR CITY, papao.
#
# PROCESSING RECORD #34 OF SET 9 FOR CITY, fada.
#
# PROCESSING RECORD #35 OF SET 9 FOR CITY, arkalyk.
#
# PROCESSING RECORD #36 OF SET 9 FOR CITY, saldanha.
#
# PROCESSING RECORD #37 OF SET 9 FOR CITY, moose jaw.
#
# PROCESSING RECORD #38 OF SET 9 FOR CITY, tamanrasset.
#
# PROCESSING RECORD #39 OF SET 9 FOR CITY, buncrana.
#
# PROCESSING RECORD #40 OF SET 9 FOR CITY, olot shahri.
#
# The script did not find the city, olot shahri. Skipping...
#
# PROCESSING RECORD #41 OF SET 9 FOR CITY, flin flon.
#
# PROCESSING RECORD #42 OF SET 9 FOR CITY, juticalpa.
#
# PROCESSING RECORD #43 OF SET 9 FOR CITY, cestos city.
#
# PROCESSING RECORD #44 OF SET 9 FOR CITY, sarkikaraagac.
#
# PROCESSING RECORD #45 OF SET 9 FOR CITY, zeya.
# PROCESSING RECORD #46 OF SET 9 FOR CITY, akureyri.
#
# PROCESSING RECORD #47 OF SET 9 FOR CITY, fisterra.
#
# PROCESSING RECORD #48 OF SET 9 FOR CITY, mata-utu.
#
# PROCESSING RECORD #49 OF SET 9 FOR CITY, ouellah.
#
# The script did not find the city, ouellah. Skipping...
#
# PROCESSING RECORD #50 OF SET 9 FOR CITY, formosa do rio preto.
#
# PROCESSING RECORD #1 OF SET 10 FOR CITY, metkovic.
#
# PROCESSING RECORD #2 OF SET 10 FOR CITY, nuku'alofa.
#
# PROCESSING RECORD #3 OF SET 10 FOR CITY, betio village.
#
# PROCESSING RECORD #4 OF SET 10 FOR CITY, igarka.
#
# PROCESSING RECORD #5 OF SET 10 FOR CITY, murray bridge.
#
# PROCESSING RECORD #6 OF SET 10 FOR CITY, pitkyaranta.
#
# PROCESSING RECORD #7 OF SET 10 FOR CITY, tagab.
#
# PROCESSING RECORD #8 OF SET 10 FOR CITY, puerto maldonado.
#
# PROCESSING RECORD #9 OF SET 10 FOR CITY, hotan.
#
# PROCESSING RECORD #10 OF SET 10 FOR CITY, zaragoza.
#
# PROCESSING RECORD #11 OF SET 10 FOR CITY, juneau.
#
# PROCESSING RECORD #12 OF SET 10 FOR CITY, castro marim.
#
# PROCESSING RECORD #13 OF SET 10 FOR CITY, bocana de paiwas.
#
# PROCESSING RECORD #14 OF SET 10 FOR CITY, tranovaho.
#
# The script did not find the city, tranovaho. Skipping...
#
# PROCESSING RECORD #15 OF SET 10 FOR CITY, ravar.
#
# PROCESSING RECORD #16 OF SET 10 FOR CITY, qui nhon.
#
# PROCESSING RECORD #17 OF SET 10 FOR CITY, camocim.
#
# PROCESSING RECORD #18 OF SET 10 FOR CITY, trairi.
#
# PROCESSING RECORD #19 OF SET 10 FOR CITY, tshikapa.
#
# PROCESSING RECORD #20 OF SET 10 FOR CITY, saint-philippe.
#
# PROCESSING RECORD #21 OF SET 10 FOR CITY, vorkuta.
#
# PROCESSING RECORD #22 OF SET 10 FOR CITY, siavonga.
#
# PROCESSING RECORD #23 OF SET 10 FOR CITY, yelan'.
#
# PROCESSING RECORD #24 OF SET 10 FOR CITY, bandar-e lengeh.
#
# PROCESSING RECORD #25 OF SET 10 FOR CITY, qapqal.
#
# The script did not find the city, qapqal. Skipping...
#
# PROCESSING RECORD #26 OF SET 10 FOR CITY, hailin.
#
# PROCESSING RECORD #27 OF SET 10 FOR CITY, daru.
#
# PROCESSING RECORD #28 OF SET 10 FOR CITY, port saint john's.
#
# PROCESSING RECORD #29 OF SET 10 FOR CITY, davlekanovo.
#
# PROCESSING RECORD #30 OF SET 10 FOR CITY, oranjemund.
#
# PROCESSING RECORD #31 OF SET 10 FOR CITY, illizi.
#
# PROCESSING RECORD #32 OF SET 10 FOR CITY, hirara.
#
# PROCESSING RECORD #33 OF SET 10 FOR CITY, greymouth.
#
# PROCESSING RECORD #34 OF SET 10 FOR CITY, riosucio.
#
# PROCESSING RECORD #35 OF SET 10 FOR CITY, douliu.
#
# PROCESSING RECORD #36 OF SET 10 FOR CITY, veraval.
#
# PROCESSING RECORD #37 OF SET 10 FOR CITY, changleng.
#
# PROCESSING RECORD #38 OF SET 10 FOR CITY, sandy.
#
# PROCESSING RECORD #39 OF SET 10 FOR CITY, ratodero.
#
# PROCESSING RECORD #40 OF SET 10 FOR CITY, metlili chaamba.
#
# PROCESSING RECORD #41 OF SET 10 FOR CITY, keren.
#
# PROCESSING RECORD #42 OF SET 10 FOR CITY, byron bay.
#
# PROCESSING RECORD #43 OF SET 10 FOR CITY, tandalti.
#
# PROCESSING RECORD #44 OF SET 10 FOR CITY, george town.
#
# PROCESSING RECORD #45 OF SET 10 FOR CITY, yonan-up.
#
# PROCESSING RECORD #46 OF SET 10 FOR CITY, longview.
#
# PROCESSING RECORD #47 OF SET 10 FOR CITY, micheweni.
#
# PROCESSING RECORD #48 OF SET 10 FOR CITY, faya-largeau.
#
# PROCESSING RECORD #49 OF SET 10 FOR CITY, voss.
#
# PROCESSING RECORD #50 OF SET 10 FOR CITY, tuy hoa.
#
# PROCESSING RECORD #1 OF SET 11 FOR CITY, glencoe.
#
# PROCESSING RECORD #2 OF SET 11 FOR CITY, mishelevka.
#
# PROCESSING RECORD #3 OF SET 11 FOR CITY, zhigalovo.
#
# PROCESSING RECORD #4 OF SET 11 FOR CITY, ceeldheer.
#
# PROCESSING RECORD #5 OF SET 11 FOR CITY, ulaangom.
#
# PROCESSING RECORD #6 OF SET 11 FOR CITY, tebingtinggi.
#
# PROCESSING RECORD #7 OF SET 11 FOR CITY, sumbawa besar.
#
# PROCESSING RECORD #8 OF SET 11 FOR CITY, saint-pierre.
#
# PROCESSING RECORD #9 OF SET 11 FOR CITY, prince rupert.
#
# PROCESSING RECORD #10 OF SET 11 FOR CITY, isla del bosque.
#
# PROCESSING RECORD #11 OF SET 11 FOR CITY, auki.
#
# PROCESSING RECORD #12 OF SET 11 FOR CITY, mugia.
#
# PROCESSING RECORD #13 OF SET 11 FOR CITY, island harbour.
#
# PROCESSING RECORD #14 OF SET 11 FOR CITY, koulamoutou.
#
# PROCESSING RECORD #15 OF SET 11 FOR CITY, bengkulu.
#
# PROCESSING RECORD #16 OF SET 11 FOR CITY, padang.
#
# PROCESSING RECORD #17 OF SET 11 FOR CITY, portage la prairie.
#
# PROCESSING RECORD #18 OF SET 11 FOR CITY, antofagasta.
#
# PROCESSING RECORD #19 OF SET 11 FOR CITY, deqen.
#
# PROCESSING RECORD #20 OF SET 11 FOR CITY, taltal.
#
# PROCESSING RECORD #21 OF SET 11 FOR CITY, mulanje.
#
# PROCESSING RECORD #22 OF SET 11 FOR CITY, mirriah.
#
# PROCESSING RECORD #23 OF SET 11 FOR CITY, i-n-salah.
#
# PROCESSING RECORD #24 OF SET 11 FOR CITY, namsos.
#
# PROCESSING RECORD #25 OF SET 11 FOR CITY, piti village.
#
# PROCESSING RECORD #26 OF SET 11 FOR CITY, chernyshevskiy.
#
# PROCESSING RECORD #27 OF SET 11 FOR CITY, louis trichardt.
#
# PROCESSING RECORD #28 OF SET 11 FOR CITY, manaure.
#
# PROCESSING RECORD #29 OF SET 11 FOR CITY, alotau.
#
# The script did not find the city, alotau. Skipping...
#
# PROCESSING RECORD #30 OF SET 11 FOR CITY, anshan.
#
# PROCESSING RECORD #31 OF SET 11 FOR CITY, liberal.
#
# PROCESSING RECORD #32 OF SET 11 FOR CITY, bamboo flat.
#
# PROCESSING RECORD #33 OF SET 11 FOR CITY, acajutla.
#
# PROCESSING RECORD #34 OF SET 11 FOR CITY, kailua-kona.
#
# PROCESSING RECORD #35 OF SET 11 FOR CITY, jinji.
#
# PROCESSING RECORD #36 OF SET 11 FOR CITY, el alto.
#
# PROCESSING RECORD #37 OF SET 11 FOR CITY, severobaykal'sk.
#
# PROCESSING RECORD #38 OF SET 11 FOR CITY, mugla.
#
# PROCESSING RECORD #39 OF SET 11 FOR CITY, huarmey.
#
# PROCESSING RECORD #40 OF SET 11 FOR CITY, awjilah.
#
# PROCESSING RECORD #41 OF SET 11 FOR CITY, catumbela.
#
# PROCESSING RECORD #42 OF SET 11 FOR CITY, queenstown.
#
# PROCESSING RECORD #43 OF SET 11 FOR CITY, fuerte olimpo.
#
# PROCESSING RECORD #44 OF SET 11 FOR CITY, vinzons.
#
# PROCESSING RECORD #45 OF SET 11 FOR CITY, kupino.
#
# PROCESSING RECORD #46 OF SET 11 FOR CITY, conduaga.
#
# PROCESSING RECORD #47 OF SET 11 FOR CITY, juliaca.
#
# PROCESSING RECORD #48 OF SET 11 FOR CITY, natal.
#
# PROCESSING RECORD #49 OF SET 11 FOR CITY, kristiansund.
#
# PROCESSING RECORD #50 OF SET 11 FOR CITY, arraial do cabo.
#
# PROCESSING RECORD #1 OF SET 12 FOR CITY, novo aripuana.
#
# PROCESSING RECORD #2 OF SET 12 FOR CITY, koya.
#
# PROCESSING RECORD #3 OF SET 12 FOR CITY, kargasok.
#
# PROCESSING RECORD #4 OF SET 12 FOR CITY, melfort.
#
# PROCESSING RECORD #5 OF SET 12 FOR CITY, union city.
#
# PROCESSING RECORD #6 OF SET 12 FOR CITY, xai-xai.
#
# PROCESSING RECORD #7 OF SET 12 FOR CITY, peniche.
#
# PROCESSING RECORD #8 OF SET 12 FOR CITY, al jawf.
#
# PROCESSING RECORD #9 OF SET 12 FOR CITY, nikol'sk.
#
# PROCESSING RECORD #10 OF SET 12 FOR CITY, ambon.
#
# PROCESSING RECORD #11 OF SET 12 FOR CITY, cavalaire-sur-mer.
#
# PROCESSING RECORD #12 OF SET 12 FOR CITY, callao.
#
# PROCESSING RECORD #13 OF SET 12 FOR CITY, grand-bassam.
#
# PROCESSING RECORD #14 OF SET 12 FOR CITY, jiaojiang.
#
# PROCESSING RECORD #15 OF SET 12 FOR CITY, lodja.
#
# PROCESSING RECORD #16 OF SET 12 FOR CITY, yakakent.
#
# PROCESSING RECORD #17 OF SET 12 FOR CITY, bathsheba.
#
# PROCESSING RECORD #18 OF SET 12 FOR CITY, ingeniero guillermo n. juarez.
#
# PROCESSING RECORD #19 OF SET 12 FOR CITY, makinsk.
#
# PROCESSING RECORD #20 OF SET 12 FOR CITY, nguigmi.
#
# PROCESSING RECORD #21 OF SET 12 FOR CITY, kill devil hills.
#
# PROCESSING RECORD #22 OF SET 12 FOR CITY, andergrove.
#
# PROCESSING RECORD #23 OF SET 12 FOR CITY, san julian.
#
# PROCESSING RECORD #24 OF SET 12 FOR CITY, buala.
#
# PROCESSING RECORD #25 OF SET 12 FOR CITY, olyokminsk.
#
# PROCESSING RECORD #26 OF SET 12 FOR CITY, puerto deseado.
#
# PROCESSING RECORD #27 OF SET 12 FOR CITY, guisa.
#
# PROCESSING RECORD #28 OF SET 12 FOR CITY, xining.
#
# PROCESSING RECORD #29 OF SET 12 FOR CITY, jayapura.
#
# PROCESSING RECORD #30 OF SET 12 FOR CITY, khandyga.
#
# PROCESSING RECORD #31 OF SET 12 FOR CITY, emerald.
#
# PROCESSING RECORD #32 OF SET 12 FOR CITY, gornopravdinsk.
#
# PROCESSING RECORD #33 OF SET 12 FOR CITY, degerfors.
#
# PROCESSING RECORD #34 OF SET 12 FOR CITY, ranau.
#
# PROCESSING RECORD #35 OF SET 12 FOR CITY, naze.
#
# PROCESSING RECORD #36 OF SET 12 FOR CITY, nola.
#
# PROCESSING RECORD #37 OF SET 12 FOR CITY, vershino-darasunskiy.
#
# PROCESSING RECORD #38 OF SET 12 FOR CITY, murun-kuren.
#
# PROCESSING RECORD #39 OF SET 12 FOR CITY, lubang.
#
# PROCESSING RECORD #40 OF SET 12 FOR CITY, sinjar.
#
# PROCESSING RECORD #41 OF SET 12 FOR CITY, northam.
#
# PROCESSING RECORD #42 OF SET 12 FOR CITY, al muwayh.
#
# PROCESSING RECORD #43 OF SET 12 FOR CITY, goba.
#
# Data Retrieval for city weather DataFrame is complete.

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Records Count**

# %%
cityWeatherCountIntegerVariable \
    = cityWeatherDataFrame \
        ['City'] \
            .count()

print \
    (f"There are {cityWeatherCountIntegerVariable} " \
     + f"records in the city weather DataFrame.")
# Out:
# There are 569 records in the city weather DataFrame.

# %% [markdown]
# ### **Display City Weather DataFrame**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_a010c caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_a010c_row0_col0, #T_a010c_row0_col1, #T_a010c_row0_col2, #T_a010c_row0_col3, #T_a010c_row0_col4, #T_a010c_row0_col6, #T_a010c_row0_col7, #T_a010c_row0_col8, #T_a010c_row1_col0, #T_a010c_row1_col1, #T_a010c_row1_col2, #T_a010c_row1_col3, #T_a010c_row1_col4, #T_a010c_row1_col5, #T_a010c_row1_col6, #T_a010c_row1_col7, #T_a010c_row1_col8, #T_a010c_row2_col0, #T_a010c_row2_col1, #T_a010c_row2_col2, #T_a010c_row2_col3, #T_a010c_row2_col4, #T_a010c_row2_col5, #T_a010c_row2_col6, #T_a010c_row2_col7, #T_a010c_row2_col8, #T_a010c_row3_col0, #T_a010c_row3_col1, #T_a010c_row3_col2, #T_a010c_row3_col3, #T_a010c_row3_col4, #T_a010c_row3_col6, #T_a010c_row3_col7, #T_a010c_row3_col8, #T_a010c_row4_col0, #T_a010c_row4_col1, #T_a010c_row4_col2, #T_a010c_row4_col3, #T_a010c_row4_col4, #T_a010c_row4_col5, #T_a010c_row4_col7, #T_a010c_row4_col8, #T_a010c_row5_col0, #T_a010c_row5_col1, #T_a010c_row5_col2, #T_a010c_row5_col3, #T_a010c_row5_col4, #T_a010c_row5_col6, #T_a010c_row5_col7, #T_a010c_row5_col8, #T_a010c_row6_col0, #T_a010c_row6_col1, #T_a010c_row6_col2, #T_a010c_row6_col3, #T_a010c_row6_col4, #T_a010c_row6_col7, #T_a010c_row6_col8, #T_a010c_row7_col0, #T_a010c_row7_col1, #T_a010c_row7_col2, #T_a010c_row7_col3, #T_a010c_row7_col4, #T_a010c_row7_col7, #T_a010c_row7_col8, #T_a010c_row8_col0, #T_a010c_row8_col1, #T_a010c_row8_col2, #T_a010c_row8_col4, #T_a010c_row8_col5, #T_a010c_row8_col6, #T_a010c_row8_col7, #T_a010c_row8_col8, #T_a010c_row9_col0, #T_a010c_row9_col1, #T_a010c_row9_col2, #T_a010c_row9_col3, #T_a010c_row9_col4, #T_a010c_row9_col5, #T_a010c_row9_col6, #T_a010c_row9_col7, #T_a010c_row9_col8, #T_a010c_row10_col0, #T_a010c_row10_col1, #T_a010c_row10_col2, #T_a010c_row10_col6, #T_a010c_row10_col7, #T_a010c_row10_col8, #T_a010c_row11_col0, #T_a010c_row11_col1, #T_a010c_row11_col2, #T_a010c_row11_col3, #T_a010c_row11_col5, #T_a010c_row11_col6, #T_a010c_row11_col7, #T_a010c_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_a010c_row0_col5, #T_a010c_row3_col5, #T_a010c_row4_col6, #T_a010c_row5_col5, #T_a010c_row6_col5, #T_a010c_row10_col3, #T_a010c_row10_col5, #T_a010c_row11_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_a010c_row6_col6, #T_a010c_row7_col5, #T_a010c_row7_col6, #T_a010c_row8_col3, #T_a010c_row10_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_a010c">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_a010c_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_a010c_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_a010c_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_a010c_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_a010c_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_a010c_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_a010c_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_a010c_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_a010c_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a010c_row0_col0" class="data row0 col0" >margaret river</td>
#       <td id="T_a010c_row0_col1" class="data row0 col1" >-33.95</td>
#       <td id="T_a010c_row0_col2" class="data row0 col2" >115.07</td>
#       <td id="T_a010c_row0_col3" class="data row0 col3" >60.98° F</td>
#       <td id="T_a010c_row0_col4" class="data row0 col4" >78%</td>
#       <td id="T_a010c_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_a010c_row0_col6" class="data row0 col6" >19.24</td>
#       <td id="T_a010c_row0_col7" class="data row0 col7" >AU</td>
#       <td id="T_a010c_row0_col8" class="data row0 col8" >2023-09-14 11:43:18</td>
#     </tr>
#     <tr>
#       <td id="T_a010c_row1_col0" class="data row1 col0" >edinburgh of the seven seas</td>
#       <td id="T_a010c_row1_col1" class="data row1 col1" >-37.07</td>
#       <td id="T_a010c_row1_col2" class="data row1 col2" >-12.31</td>
#       <td id="T_a010c_row1_col3" class="data row1 col3" >51.91° F</td>
#       <td id="T_a010c_row1_col4" class="data row1 col4" >68%</td>
#       <td id="T_a010c_row1_col5" class="data row1 col5" >55%</td>
#       <td id="T_a010c_row1_col6" class="data row1 col6" >15.23</td>
#       <td id="T_a010c_row1_col7" class="data row1 col7" >SH</td>
#       <td id="T_a010c_row1_col8" class="data row1 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_a010c_row2_col0" class="data row2 col0" >nova sintra</td>
#       <td id="T_a010c_row2_col1" class="data row2 col1" >14.87</td>
#       <td id="T_a010c_row2_col2" class="data row2 col2" >-24.72</td>
#       <td id="T_a010c_row2_col3" class="data row2 col3" >75.85° F</td>
#       <td id="T_a010c_row2_col4" class="data row2 col4" >82%</td>
#       <td id="T_a010c_row2_col5" class="data row2 col5" >9%</td>
#       <td id="T_a010c_row2_col6" class="data row2 col6" >13.87</td>
#       <td id="T_a010c_row2_col7" class="data row2 col7" >CV</td>
#       <td id="T_a010c_row2_col8" class="data row2 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_a010c_row3_col0" class="data row3 col0" >adamstown</td>
#       <td id="T_a010c_row3_col1" class="data row3 col1" >-25.07</td>
#       <td id="T_a010c_row3_col2" class="data row3 col2" >-130.10</td>
#       <td id="T_a010c_row3_col3" class="data row3 col3" >64.40° F</td>
#       <td id="T_a010c_row3_col4" class="data row3 col4" >57%</td>
#       <td id="T_a010c_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_a010c_row3_col6" class="data row3 col6" >20.40</td>
#       <td id="T_a010c_row3_col7" class="data row3 col7" >PN</td>
#       <td id="T_a010c_row3_col8" class="data row3 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_a010c_row4_col0" class="data row4 col0" >port-aux-francais</td>
#       <td id="T_a010c_row4_col1" class="data row4 col1" >-49.35</td>
#       <td id="T_a010c_row4_col2" class="data row4 col2" >70.22</td>
#       <td id="T_a010c_row4_col3" class="data row4 col3" >38.30° F</td>
#       <td id="T_a010c_row4_col4" class="data row4 col4" >85%</td>
#       <td id="T_a010c_row4_col5" class="data row4 col5" >94%</td>
#       <td id="T_a010c_row4_col6" class="data row4 col6" >36.46</td>
#       <td id="T_a010c_row4_col7" class="data row4 col7" >TF</td>
#       <td id="T_a010c_row4_col8" class="data row4 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <tr>
#       <td id="T_a010c_row5_col0" class="data row5 col0" >afaahiti</td>
#       <td id="T_a010c_row5_col1" class="data row5 col1" >-17.75</td>
#       <td id="T_a010c_row5_col2" class="data row5 col2" >-149.28</td>
#       <td id="T_a010c_row5_col3" class="data row5 col3" >71.47° F</td>
#       <td id="T_a010c_row5_col4" class="data row5 col4" >90%</td>
#       <td id="T_a010c_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_a010c_row5_col6" class="data row5 col6" >20.71</td>
#       <td id="T_a010c_row5_col7" class="data row5 col7" >PF</td>
#       <td id="T_a010c_row5_col8" class="data row5 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <tr>
#       <td id="T_a010c_row6_col0" class="data row6 col0" >lompoc</td>
#       <td id="T_a010c_row6_col1" class="data row6 col1" >34.64</td>
#       <td id="T_a010c_row6_col2" class="data row6 col2" >-120.46</td>
#       <td id="T_a010c_row6_col3" class="data row6 col3" >65.59° F</td>
#       <td id="T_a010c_row6_col4" class="data row6 col4" >83%</td>
#       <td id="T_a010c_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_a010c_row6_col6" class="data row6 col6" >1.99</td>
#       <td id="T_a010c_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_a010c_row6_col8" class="data row6 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <

# %% [markdown]
# ### **Data Export to CSV File**

# %%
subroutine \
    .WriteDataFrameToCSVFile \
        (cityWeatherDataFrame,
         local_constant.WEATHER_DATA_FILE_PATH,
         local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Data Import from CSV File**

# %%
sampleCityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Display Sample City Weather DataFrame**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information from CSV File')
# Out:
# <style type="text/css">
# #T_c61c2 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c61c2_row0_col0, #T_c61c2_row0_col1, #T_c61c2_row0_col2, #T_c61c2_row0_col3, #T_c61c2_row0_col4, #T_c61c2_row0_col6, #T_c61c2_row0_col7, #T_c61c2_row0_col8, #T_c61c2_row1_col0, #T_c61c2_row1_col1, #T_c61c2_row1_col2, #T_c61c2_row1_col3, #T_c61c2_row1_col4, #T_c61c2_row1_col5, #T_c61c2_row1_col6, #T_c61c2_row1_col7, #T_c61c2_row1_col8, #T_c61c2_row2_col0, #T_c61c2_row2_col1, #T_c61c2_row2_col2, #T_c61c2_row2_col3, #T_c61c2_row2_col4, #T_c61c2_row2_col5, #T_c61c2_row2_col6, #T_c61c2_row2_col7, #T_c61c2_row2_col8, #T_c61c2_row3_col0, #T_c61c2_row3_col1, #T_c61c2_row3_col2, #T_c61c2_row3_col3, #T_c61c2_row3_col4, #T_c61c2_row3_col6, #T_c61c2_row3_col7, #T_c61c2_row3_col8, #T_c61c2_row4_col0, #T_c61c2_row4_col1, #T_c61c2_row4_col2, #T_c61c2_row4_col3, #T_c61c2_row4_col4, #T_c61c2_row4_col5, #T_c61c2_row4_col7, #T_c61c2_row4_col8, #T_c61c2_row5_col0, #T_c61c2_row5_col1, #T_c61c2_row5_col2, #T_c61c2_row5_col3, #T_c61c2_row5_col4, #T_c61c2_row5_col6, #T_c61c2_row5_col7, #T_c61c2_row5_col8, #T_c61c2_row6_col0, #T_c61c2_row6_col1, #T_c61c2_row6_col2, #T_c61c2_row6_col3, #T_c61c2_row6_col4, #T_c61c2_row6_col7, #T_c61c2_row6_col8, #T_c61c2_row7_col0, #T_c61c2_row7_col1, #T_c61c2_row7_col2, #T_c61c2_row7_col3, #T_c61c2_row7_col4, #T_c61c2_row7_col7, #T_c61c2_row7_col8, #T_c61c2_row8_col0, #T_c61c2_row8_col1, #T_c61c2_row8_col2, #T_c61c2_row8_col4, #T_c61c2_row8_col5, #T_c61c2_row8_col6, #T_c61c2_row8_col7, #T_c61c2_row8_col8, #T_c61c2_row9_col0, #T_c61c2_row9_col1, #T_c61c2_row9_col2, #T_c61c2_row9_col3, #T_c61c2_row9_col4, #T_c61c2_row9_col5, #T_c61c2_row9_col6, #T_c61c2_row9_col7, #T_c61c2_row9_col8, #T_c61c2_row10_col0, #T_c61c2_row10_col1, #T_c61c2_row10_col2, #T_c61c2_row10_col6, #T_c61c2_row10_col7, #T_c61c2_row10_col8, #T_c61c2_row11_col0, #T_c61c2_row11_col1, #T_c61c2_row11_col2, #T_c61c2_row11_col3, #T_c61c2_row11_col5, #T_c61c2_row11_col6, #T_c61c2_row11_col7, #T_c61c2_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_c61c2_row0_col5, #T_c61c2_row3_col5, #T_c61c2_row4_col6, #T_c61c2_row5_col5, #T_c61c2_row6_col5, #T_c61c2_row10_col3, #T_c61c2_row10_col5, #T_c61c2_row11_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_c61c2_row6_col6, #T_c61c2_row7_col5, #T_c61c2_row7_col6, #T_c61c2_row8_col3, #T_c61c2_row10_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_c61c2">
#   <caption>Table: 1.1: City Weather Information from CSV File</caption>
#   <thead>
#     <tr>
#       <th id="T_c61c2_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_c61c2_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_c61c2_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_c61c2_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_c61c2_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_c61c2_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_c61c2_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_c61c2_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_c61c2_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c61c2_row0_col0" class="data row0 col0" >margaret river</td>
#       <td id="T_c61c2_row0_col1" class="data row0 col1" >-33.95</td>
#       <td id="T_c61c2_row0_col2" class="data row0 col2" >115.07</td>
#       <td id="T_c61c2_row0_col3" class="data row0 col3" >60.98° F</td>
#       <td id="T_c61c2_row0_col4" class="data row0 col4" >78%</td>
#       <td id="T_c61c2_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_c61c2_row0_col6" class="data row0 col6" >19.24</td>
#       <td id="T_c61c2_row0_col7" class="data row0 col7" >AU</td>
#       <td id="T_c61c2_row0_col8" class="data row0 col8" >2023-09-14 11:43:18</td>
#     </tr>
#     <tr>
#       <td id="T_c61c2_row1_col0" class="data row1 col0" >edinburgh of the seven seas</td>
#       <td id="T_c61c2_row1_col1" class="data row1 col1" >-37.07</td>
#       <td id="T_c61c2_row1_col2" class="data row1 col2" >-12.31</td>
#       <td id="T_c61c2_row1_col3" class="data row1 col3" >51.91° F</td>
#       <td id="T_c61c2_row1_col4" class="data row1 col4" >68%</td>
#       <td id="T_c61c2_row1_col5" class="data row1 col5" >55%</td>
#       <td id="T_c61c2_row1_col6" class="data row1 col6" >15.23</td>
#       <td id="T_c61c2_row1_col7" class="data row1 col7" >SH</td>
#       <td id="T_c61c2_row1_col8" class="data row1 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_c61c2_row2_col0" class="data row2 col0" >nova sintra</td>
#       <td id="T_c61c2_row2_col1" class="data row2 col1" >14.87</td>
#       <td id="T_c61c2_row2_col2" class="data row2 col2" >-24.72</td>
#       <td id="T_c61c2_row2_col3" class="data row2 col3" >75.85° F</td>
#       <td id="T_c61c2_row2_col4" class="data row2 col4" >82%</td>
#       <td id="T_c61c2_row2_col5" class="data row2 col5" >9%</td>
#       <td id="T_c61c2_row2_col6" class="data row2 col6" >13.87</td>
#       <td id="T_c61c2_row2_col7" class="data row2 col7" >CV</td>
#       <td id="T_c61c2_row2_col8" class="data row2 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_c61c2_row3_col0" class="data row3 col0" >adamstown</td>
#       <td id="T_c61c2_row3_col1" class="data row3 col1" >-25.07</td>
#       <td id="T_c61c2_row3_col2" class="data row3 col2" >-130.10</td>
#       <td id="T_c61c2_row3_col3" class="data row3 col3" >64.40° F</td>
#       <td id="T_c61c2_row3_col4" class="data row3 col4" >57%</td>
#       <td id="T_c61c2_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_c61c2_row3_col6" class="data row3 col6" >20.40</td>
#       <td id="T_c61c2_row3_col7" class="data row3 col7" >PN</td>
#       <td id="T_c61c2_row3_col8" class="data row3 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_c61c2_row4_col0" class="data row4 col0" >port-aux-francais</td>
#       <td id="T_c61c2_row4_col1" class="data row4 col1" >-49.35</td>
#       <td id="T_c61c2_row4_col2" class="data row4 col2" >70.22</td>
#       <td id="T_c61c2_row4_col3" class="data row4 col3" >38.30° F</td>
#       <td id="T_c61c2_row4_col4" class="data row4 col4" >85%</td>
#       <td id="T_c61c2_row4_col5" class="data row4 col5" >94%</td>
#       <td id="T_c61c2_row4_col6" class="data row4 col6" >36.46</td>
#       <td id="T_c61c2_row4_col7" class="data row4 col7" >TF</td>
#       <td id="T_c61c2_row4_col8" class="data row4 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <tr>
#       <td id="T_c61c2_row5_col0" class="data row5 col0" >afaahiti</td>
#       <td id="T_c61c2_row5_col1" class="data row5 col1" >-17.75</td>
#       <td id="T_c61c2_row5_col2" class="data row5 col2" >-149.28</td>
#       <td id="T_c61c2_row5_col3" class="data row5 col3" >71.47° F</td>
#       <td id="T_c61c2_row5_col4" class="data row5 col4" >90%</td>
#       <td id="T_c61c2_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_c61c2_row5_col6" class="data row5 col6" >20.71</td>
#       <td id="T_c61c2_row5_col7" class="data row5 col7" >PF</td>
#       <td id="T_c61c2_row5_col8" class="data row5 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <tr>
#       <td id="T_c61c2_row6_col0" class="data row6 col0" >lompoc</td>
#       <td id="T_c61c2_row6_col1" class="data row6 col1" >34.64</td>
#       <td id="T_c61c2_row6_col2" class="data row6 col2" >-120.46</td>
#       <td id="T_c61c2_row6_col3" class="data row6 col3" >65.59° F</td>
#       <td id="T_c61c2_row6_col4" class="data row6 col4" >83%</td>
#       <td id="T_c61c2_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_c61c2_row6_col6" class="data row6 col6" >1.99</td>
#       <td id="T_c61c2_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_c61c2_row6_col8" class="data row6 col8" >2023-09-14 11:43:20</td>

# %% [markdown]
# ## **Section 1.2: Scatter Plots w/Regression**

# %% [markdown]
# ### **Temperature Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1: Temperature Vs. Latitude (Scatter Plot)')

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1.1: Temperature Vs. Latitude (Scatter Plot w/Regression)', 
         2, -48.0, 28.0)
# Out:
# r-value:     0.8286
# r-squared:   0.6865

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### Although this assignment is about linear regression, I notice that the independent variable, latitude, has a relationship with the dependent variable, temperature, just not a linear one.  With linear regression, we obtain a -0.1346 correlation; with quadratic regression, the correlation increases to 0.7879.  In practiice, analysts consider a 0.60-0.79 correlation to be strong.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.2.2: Humidity Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Cloudiness Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.2.3: Cloudiness Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.2.4: Wind Speed vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **City Weather Information Correlation Matrix**

# %%
frameDictionary \
    = {'Latitude': 
            cityWeatherDataFrame \
                ['Latitude'], 
       'Temperature': 
            cityWeatherDataFrame \
                ['Temperature'], 
       'Humidity': 
            cityWeatherDataFrame \
                ['Humidity'],
       'Cloudiness': 
            cityWeatherDataFrame \
                ['Cloudiness'],
       'Wind Speed':
            cityWeatherDataFrame \
                ['Wind Speed']}


function \
    .ReturnCorrelationTableStandardFormat \
        (pd \
             .DataFrame \
                 (frameDictionary),
         'Table 1.2.1: City Weather Correlation Matrix')
# Out:
# <style type="text/css">
# #T_97a36 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_97a36_row0_col0, #T_97a36_row0_col1, #T_97a36_row0_col2, #T_97a36_row0_col3, #T_97a36_row0_col4, #T_97a36_row1_col0, #T_97a36_row1_col1, #T_97a36_row1_col2, #T_97a36_row1_col3, #T_97a36_row1_col4, #T_97a36_row2_col0, #T_97a36_row2_col1, #T_97a36_row2_col2, #T_97a36_row2_col3, #T_97a36_row2_col4, #T_97a36_row3_col0, #T_97a36_row3_col1, #T_97a36_row3_col2, #T_97a36_row3_col3, #T_97a36_row3_col4, #T_97a36_row4_col0, #T_97a36_row4_col1, #T_97a36_row4_col2, #T_97a36_row4_col3, #T_97a36_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_97a36">
#   <caption>Table 1.2.1: City Weather Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97a36_level0_col0" class="col_heading level0 col0" >Latitude</th>
#       <th id="T_97a36_level0_col1" class="col_heading level0 col1" >Temperature</th>
#       <th id="T_97a36_level0_col2" class="col_heading level0 col2" >Humidity</th>
#       <th id="T_97a36_level0_col3" class="col_heading level0 col3" >Cloudiness</th>
#       <th id="T_97a36_level0_col4" class="col_heading level0 col4" >Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97a36_level0_row0" class="row_heading level0 row0" >Latitude</th>
#       <td id="T_97a36_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_97a36_row0_col1" class="data row0 col1" >-0.295762</td>
#       <td id="T_97a36_row0_col2" class="data row0 col2" >0.072848</td>
#       <td id="T_97a36_row0_col3" class="data row0 col3" >0.055043</td>
#       <td id="T_97a36_row0_col4" class="data row0 col4" >-0.163477</td>
#     </tr>
#     <tr>
#       <th id="T_97a36_level0_row1" class="row_heading level0 row1" >Temperature</th>
#       <td id="T_97a36_row1_col0" class="data row1 col0" >-0.295762</td>
#       <td id="T_97a36_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_97a36_row1_col2" class="data row1 col2" >-0.419825</td>
#       <td id="T_97a36_row1_col3" class="data row1 col3" >-0.194616</td>
#       <td id="T_97a36_row1_col4" class="data row1 col4" >0.069022</td>
#     </tr>
#     <tr>
#       <th id="T_97a36_level0_row2" class="row_heading level0 row2" >Humidity</th>
#       <td id="T_97a36_row2_col0" class="data row2 col0" >0.072848</td>
#       <td id="T_97a36_row2_col1" class="data row2 col1" >-0.419825</td>
#       <td id="T_97a36_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_97a36_row2_col3" class="data row2 col3" >0.406547</td>
#       <td id="T_97a36_row2_col4" class="data row2 col4" >-0.051785</td>
#     </tr>
#     <tr>
#       <th id="T_97a36_level0_row3" class="row_heading level0 row3" >Cloudiness</th>
#       <td id="T_97a36_row3_col0" class="data row3 col0" >0.055043</td>
#       <td id="T_97a36_row3_col1" class="data row3 col1" >-0.194616</td>
#       <td id="T_97a36_row3_col2" class="data row3 col2" >0.406547</td>
#       <td id="T_97a36_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_97a36_row3_col4" class="data row3 col4" >-0.010896</td>
#     </tr>
#     <tr>
#       <th id="T_97a36_level0_row4" class="row_heading level0 row4" >Wind Speed</th>
#       <td id="T_97a36_row4_col0" class="data row4 col0" >-0.163477</td>
#       <td id="T_97a36_row4_col1" class="data row4 col1" >0.069022</td>
#       <td id="T_97a36_row4_col2" class="data row4 col2" >-0.051785</td>
#       <td id="T_97a36_row4_col3" class="data row4 col3" >-0.010896</td>
#       <td id="T_97a36_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Discussion about correlation:** YOUR RESPONSE HERE

# %% [markdown]
# ## **Section 1.3: Hemisphere Scatter Plots with Linear Regression**

# %% [markdown]
# ### **Northern Hemisphere City Weather Information**

# %%
northernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (northernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.1: City Weather Information (Northern Hemisphere)')
# Out:
# <style type="text/css">
# #T_68298 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_68298_row0_col0, #T_68298_row0_col1, #T_68298_row0_col2, #T_68298_row0_col3, #T_68298_row0_col4, #T_68298_row0_col5, #T_68298_row0_col7, #T_68298_row0_col8, #T_68298_row1_col0, #T_68298_row1_col1, #T_68298_row1_col2, #T_68298_row1_col3, #T_68298_row1_col4, #T_68298_row1_col7, #T_68298_row1_col8, #T_68298_row2_col0, #T_68298_row2_col1, #T_68298_row2_col2, #T_68298_row2_col3, #T_68298_row2_col4, #T_68298_row2_col7, #T_68298_row2_col8, #T_68298_row3_col0, #T_68298_row3_col1, #T_68298_row3_col2, #T_68298_row3_col4, #T_68298_row3_col5, #T_68298_row3_col6, #T_68298_row3_col7, #T_68298_row3_col8, #T_68298_row4_col0, #T_68298_row4_col1, #T_68298_row4_col2, #T_68298_row4_col3, #T_68298_row4_col4, #T_68298_row4_col5, #T_68298_row4_col6, #T_68298_row4_col7, #T_68298_row4_col8, #T_68298_row5_col0, #T_68298_row5_col1, #T_68298_row5_col2, #T_68298_row5_col3, #T_68298_row5_col5, #T_68298_row5_col6, #T_68298_row5_col7, #T_68298_row5_col8, #T_68298_row6_col0, #T_68298_row6_col1, #T_68298_row6_col2, #T_68298_row6_col3, #T_68298_row6_col4, #T_68298_row6_col6, #T_68298_row6_col7, #T_68298_row6_col8, #T_68298_row7_col0, #T_68298_row7_col1, #T_68298_row7_col2, #T_68298_row7_col3, #T_68298_row7_col4, #T_68298_row7_col6, #T_68298_row7_col7, #T_68298_row7_col8, #T_68298_row8_col0, #T_68298_row8_col1, #T_68298_row8_col2, #T_68298_row8_col3, #T_68298_row8_col4, #T_68298_row8_col5, #T_68298_row8_col6, #T_68298_row8_col7, #T_68298_row8_col8, #T_68298_row9_col0, #T_68298_row9_col1, #T_68298_row9_col2, #T_68298_row9_col3, #T_68298_row9_col5, #T_68298_row9_col6, #T_68298_row9_col7, #T_68298_row9_col8, #T_68298_row10_col0, #T_68298_row10_col1, #T_68298_row10_col2, #T_68298_row10_col4, #T_68298_row10_col5, #T_68298_row10_col6, #T_68298_row10_col7, #T_68298_row10_col8, #T_68298_row11_col0, #T_68298_row11_col1, #T_68298_row11_col2, #T_68298_row11_col3, #T_68298_row11_col4, #T_68298_row11_col5, #T_68298_row11_col6, #T_68298_row11_col7, #T_68298_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_68298_row0_col6, #T_68298_row1_col5, #T_68298_row5_col4, #T_68298_row6_col5, #T_68298_row7_col5, #T_68298_row10_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_68298_row1_col6, #T_68298_row2_col5, #T_68298_row2_col6, #T_68298_row3_col3, #T_68298_row9_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_68298">
#   <caption>Table: 1.3.1: City Weather Information (Northern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_68298_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_68298_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_68298_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_68298_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_68298_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_68298_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_68298_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_68298_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_68298_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_68298_row0_col0" class="data row0 col0" >nova sintra</td>
#       <td id="T_68298_row0_col1" class="data row0 col1" >14.87</td>
#       <td id="T_68298_row0_col2" class="data row0 col2" >-24.72</td>
#       <td id="T_68298_row0_col3" class="data row0 col3" >75.85° F</td>
#       <td id="T_68298_row0_col4" class="data row0 col4" >82%</td>
#       <td id="T_68298_row0_col5" class="data row0 col5" >9%</td>
#       <td id="T_68298_row0_col6" class="data row0 col6" >13.87</td>
#       <td id="T_68298_row0_col7" class="data row0 col7" >CV</td>
#       <td id="T_68298_row0_col8" class="data row0 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_68298_row1_col0" class="data row1 col0" >lompoc</td>
#       <td id="T_68298_row1_col1" class="data row1 col1" >34.64</td>
#       <td id="T_68298_row1_col2" class="data row1 col2" >-120.46</td>
#       <td id="T_68298_row1_col3" class="data row1 col3" >65.59° F</td>
#       <td id="T_68298_row1_col4" class="data row1 col4" >83%</td>
#       <td id="T_68298_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_68298_row1_col6" class="data row1 col6" >1.99</td>
#       <td id="T_68298_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_68298_row1_col8" class="data row1 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <tr>
#       <td id="T_68298_row2_col0" class="data row2 col0" >albany</td>
#       <td id="T_68298_row2_col1" class="data row2 col1" >42.60</td>
#       <td id="T_68298_row2_col2" class="data row2 col2" >-73.97</td>
#       <td id="T_68298_row2_col3" class="data row2 col3" >68.94° F</td>
#       <td id="T_68298_row2_col4" class="data row2 col4" >60%</td>
#       <td id="T_68298_row2_col5" class="data row2 col5" >8%</td>
#       <td id="T_68298_row2_col6" class="data row2 col6" >1.99</td>
#       <td id="T_68298_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_68298_row2_col8" class="data row2 col8" >2023-09-14 11:42:27</td>
#     </tr>
#     <tr>
#       <td id="T_68298_row3_col0" class="data row3 col0" >bilibino</td>
#       <td id="T_68298_row3_col1" class="data row3 col1" >68.05</td>
#       <td id="T_68298_row3_col2" class="data row3 col2" >166.44</td>
#       <td id="T_68298_row3_col3" class="data row3 col3" >32.90° F</td>
#       <td id="T_68298_row3_col4" class="data row3 col4" >82%</td>
#       <td id="T_68298_row3_col5" class="data row3 col5" >97%</td>
#       <td id="T_68298_row3_col6" class="data row3 col6" >3.67</td>
#       <td id="T_68298_row3_col7" class="data row3 col7" >RU</td>
#       <td id="T_68298_row3_col8" class="data row3 col8" >2023-09-14 11:33:57</td>
#     </tr>
#     <tr>
#       <td id="T_68298_row4_col0" class="data row4 col0" >wailua homesteads</td>
#       <td id="T_68298_row4_col1" class="data row4 col1" >22.07</td>
#       <td id="T_68298_row4_col2" class="data row4 col2" >-159.38</td>
#       <td id="T_68298_row4_col3" class="data row4 col3" >77.83° F</td>
#       <td id="T_68298_row4_col4" class="data row4 col4" >79%</td>
#       <td id="T_68298_row4_col5" class="data row4 col5" >20%</td>
#       <td id="T_68298_row4_col6" class="data row4 col6" >13.80</td>
#       <td id="T_68298_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_68298_row4_col8" class="data row4 col8" >2023-09-14 11:33:22</td>
#     </tr>
#     <tr>
#       <td id="T_68298_row5_col0" class="data row5 col0" >pasuquin</td>
#       <td id="T_68298_row5_col1" class="data row5 col1" >18.33</td>
#       <td id="T_68298_row5_col2" class="data row5 col2" >120.62</td>
#       <td id="T_68298_row5_col3" class="data row5 col3" >76.95° F</td>
#       <td id="T_68298_row5_col4" class="data row5 col4" >94%</td>
#       <td id="T_68298_row5_col5" class="data row5 col5" >20%</td>
#       <td id="T_68298_row5_col6" class="data row5 col6" >3.44</td>
#       <td id="T_68298_row5_col7" class="data row5 col7" >PH</td>
#       <td id="T_68298_row5_col8" class="data row5 col8" >2023-09-14 11:43:21</td>
#     </tr>
#     <tr>
#       <td id="T_68298_row6_col0" class="data row6 col0" >dryden</td>
#       <td id="T_68298_row6_col1" class="data row6 col1" >49.78</td>
#       <td id="T_68298_row6_col2" class="data row6 col2" >-92.75</td>
#       <td id="T_68298_row6_col3" class="data row6 col3" >55.69° F</td>
#       <td id="T_68298_row6_col4" class="data row6 col4" >82%</td>
#       <td id="T_68298_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_68298_row6_col6" class="data row6 col6" >10.36</td>
#       <td id="T_68298_row6_col7" class="data row6 col7" >CA</td>
#       <td id="T_68298_row6_col8" class="data row6 col8" >2023-09-14 11:33:24</td>
#     </tr>
#     <tr>
#       <td id=

# %% [markdown]
# ### **Southern Hemisphere City Weather Information**

# %%
southernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (southernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.2: City Weather Information (Southern Hemisphere)')
# Out:
# <style type="text/css">
# #T_c24d1 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c24d1_row0_col0, #T_c24d1_row0_col1, #T_c24d1_row0_col2, #T_c24d1_row0_col3, #T_c24d1_row0_col4, #T_c24d1_row0_col5, #T_c24d1_row0_col7, #T_c24d1_row0_col8, #T_c24d1_row1_col0, #T_c24d1_row1_col1, #T_c24d1_row1_col2, #T_c24d1_row1_col3, #T_c24d1_row1_col4, #T_c24d1_row1_col7, #T_c24d1_row1_col8, #T_c24d1_row2_col0, #T_c24d1_row2_col1, #T_c24d1_row2_col2, #T_c24d1_row2_col3, #T_c24d1_row2_col4, #T_c24d1_row2_col7, #T_c24d1_row2_col8, #T_c24d1_row3_col0, #T_c24d1_row3_col1, #T_c24d1_row3_col2, #T_c24d1_row3_col4, #T_c24d1_row3_col5, #T_c24d1_row3_col6, #T_c24d1_row3_col7, #T_c24d1_row3_col8, #T_c24d1_row4_col0, #T_c24d1_row4_col1, #T_c24d1_row4_col2, #T_c24d1_row4_col3, #T_c24d1_row4_col4, #T_c24d1_row4_col5, #T_c24d1_row4_col6, #T_c24d1_row4_col7, #T_c24d1_row4_col8, #T_c24d1_row5_col0, #T_c24d1_row5_col1, #T_c24d1_row5_col2, #T_c24d1_row5_col3, #T_c24d1_row5_col5, #T_c24d1_row5_col6, #T_c24d1_row5_col7, #T_c24d1_row5_col8, #T_c24d1_row6_col0, #T_c24d1_row6_col1, #T_c24d1_row6_col2, #T_c24d1_row6_col3, #T_c24d1_row6_col4, #T_c24d1_row6_col6, #T_c24d1_row6_col7, #T_c24d1_row6_col8, #T_c24d1_row7_col0, #T_c24d1_row7_col1, #T_c24d1_row7_col2, #T_c24d1_row7_col3, #T_c24d1_row7_col4, #T_c24d1_row7_col6, #T_c24d1_row7_col7, #T_c24d1_row7_col8, #T_c24d1_row8_col0, #T_c24d1_row8_col1, #T_c24d1_row8_col2, #T_c24d1_row8_col3, #T_c24d1_row8_col4, #T_c24d1_row8_col5, #T_c24d1_row8_col6, #T_c24d1_row8_col7, #T_c24d1_row8_col8, #T_c24d1_row9_col0, #T_c24d1_row9_col1, #T_c24d1_row9_col2, #T_c24d1_row9_col3, #T_c24d1_row9_col5, #T_c24d1_row9_col6, #T_c24d1_row9_col7, #T_c24d1_row9_col8, #T_c24d1_row10_col0, #T_c24d1_row10_col1, #T_c24d1_row10_col2, #T_c24d1_row10_col4, #T_c24d1_row10_col5, #T_c24d1_row10_col6, #T_c24d1_row10_col7, #T_c24d1_row10_col8, #T_c24d1_row11_col0, #T_c24d1_row11_col1, #T_c24d1_row11_col2, #T_c24d1_row11_col3, #T_c24d1_row11_col4, #T_c24d1_row11_col5, #T_c24d1_row11_col6, #T_c24d1_row11_col7, #T_c24d1_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_c24d1_row0_col6, #T_c24d1_row1_col5, #T_c24d1_row5_col4, #T_c24d1_row6_col5, #T_c24d1_row7_col5, #T_c24d1_row10_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_c24d1_row1_col6, #T_c24d1_row2_col5, #T_c24d1_row2_col6, #T_c24d1_row3_col3, #T_c24d1_row9_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_c24d1">
#   <caption>Table: 1.3.2: City Weather Information (Southern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_c24d1_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_c24d1_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_c24d1_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_c24d1_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_c24d1_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_c24d1_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_c24d1_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_c24d1_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_c24d1_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c24d1_row0_col0" class="data row0 col0" >nova sintra</td>
#       <td id="T_c24d1_row0_col1" class="data row0 col1" >14.87</td>
#       <td id="T_c24d1_row0_col2" class="data row0 col2" >-24.72</td>
#       <td id="T_c24d1_row0_col3" class="data row0 col3" >75.85° F</td>
#       <td id="T_c24d1_row0_col4" class="data row0 col4" >82%</td>
#       <td id="T_c24d1_row0_col5" class="data row0 col5" >9%</td>
#       <td id="T_c24d1_row0_col6" class="data row0 col6" >13.87</td>
#       <td id="T_c24d1_row0_col7" class="data row0 col7" >CV</td>
#       <td id="T_c24d1_row0_col8" class="data row0 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_c24d1_row1_col0" class="data row1 col0" >lompoc</td>
#       <td id="T_c24d1_row1_col1" class="data row1 col1" >34.64</td>
#       <td id="T_c24d1_row1_col2" class="data row1 col2" >-120.46</td>
#       <td id="T_c24d1_row1_col3" class="data row1 col3" >65.59° F</td>
#       <td id="T_c24d1_row1_col4" class="data row1 col4" >83%</td>
#       <td id="T_c24d1_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_c24d1_row1_col6" class="data row1 col6" >1.99</td>
#       <td id="T_c24d1_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_c24d1_row1_col8" class="data row1 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <tr>
#       <td id="T_c24d1_row2_col0" class="data row2 col0" >albany</td>
#       <td id="T_c24d1_row2_col1" class="data row2 col1" >42.60</td>
#       <td id="T_c24d1_row2_col2" class="data row2 col2" >-73.97</td>
#       <td id="T_c24d1_row2_col3" class="data row2 col3" >68.94° F</td>
#       <td id="T_c24d1_row2_col4" class="data row2 col4" >60%</td>
#       <td id="T_c24d1_row2_col5" class="data row2 col5" >8%</td>
#       <td id="T_c24d1_row2_col6" class="data row2 col6" >1.99</td>
#       <td id="T_c24d1_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_c24d1_row2_col8" class="data row2 col8" >2023-09-14 11:42:27</td>
#     </tr>
#     <tr>
#       <td id="T_c24d1_row3_col0" class="data row3 col0" >bilibino</td>
#       <td id="T_c24d1_row3_col1" class="data row3 col1" >68.05</td>
#       <td id="T_c24d1_row3_col2" class="data row3 col2" >166.44</td>
#       <td id="T_c24d1_row3_col3" class="data row3 col3" >32.90° F</td>
#       <td id="T_c24d1_row3_col4" class="data row3 col4" >82%</td>
#       <td id="T_c24d1_row3_col5" class="data row3 col5" >97%</td>
#       <td id="T_c24d1_row3_col6" class="data row3 col6" >3.67</td>
#       <td id="T_c24d1_row3_col7" class="data row3 col7" >RU</td>
#       <td id="T_c24d1_row3_col8" class="data row3 col8" >2023-09-14 11:33:57</td>
#     </tr>
#     <tr>
#       <td id="T_c24d1_row4_col0" class="data row4 col0" >wailua homesteads</td>
#       <td id="T_c24d1_row4_col1" class="data row4 col1" >22.07</td>
#       <td id="T_c24d1_row4_col2" class="data row4 col2" >-159.38</td>
#       <td id="T_c24d1_row4_col3" class="data row4 col3" >77.83° F</td>
#       <td id="T_c24d1_row4_col4" class="data row4 col4" >79%</td>
#       <td id="T_c24d1_row4_col5" class="data row4 col5" >20%</td>
#       <td id="T_c24d1_row4_col6" class="data row4 col6" >13.80</td>
#       <td id="T_c24d1_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_c24d1_row4_col8" class="data row4 col8" >2023-09-14 11:33:22</td>
#     </tr>
#     <tr>
#       <td id="T_c24d1_row5_col0" class="data row5 col0" >pasuquin</td>
#       <td id="T_c24d1_row5_col1" class="data row5 col1" >18.33</td>
#       <td id="T_c24d1_row5_col2" class="data row5 col2" >120.62</td>
#       <td id="T_c24d1_row5_col3" class="data row5 col3" >76.95° F</td>
#       <td id="T_c24d1_row5_col4" class="data row5 col4" >94%</td>
#       <td id="T_c24d1_row5_col5" class="data row5 col5" >20%</td>
#       <td id="T_c24d1_row5_col6" class="data row5 col6" >3.44</td>
#       <td id="T_c24d1_row5_col7" class="data row5 col7" >PH</td>
#       <td id="T_c24d1_row5_col8" class="data row5 col8" >2023-09-14 11:43:21</td>
#     </tr>
#     <tr>
#       <td id="T_c24d1_row6_col0" class="data row6 col0" >dryden</td>
#       <td id="T_c24d1_row6_col1" class="data row6 col1" >49.78</td>
#       <td id="T_c24d1_row6_col2" class="data row6 col2" >-92.75</td>
#       <td id="T_c24d1_row6_col3" class="data row6 col3" >55.69° F</td>
#       <td id="T_c24d1_row6_col4" class="data row6 col4" >82%</td>
#       <td id="T_c24d1_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_c24d1_row6_col6" class="data row6 col6" >10.36</td>
#       <td id="T_c24d1_row6_col7" class="data row6 col7" >CA</td>
#       <td id="T_c24d1_row6_col8" class="data row6 col8" >2023-09-14 11:33:24</td>
#     </tr>
#     <tr>
#       <td id=

# %% [markdown]
# ### **Temperature vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.1: Temperature vs. Latitude (Northern Hemisphere)',
         1, 2.0, 45.0)
# Out:
# r-value:     -0.7982
# r-squared:   0.6371

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.2: Temperature vs. Latitude (Southern Hemisphere)',
         1, -55.0, 85.0)
# Out:
# r-value:     0.8103
# r-squared:   0.6567

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### From the results of the linear regression, in the northern hemisphere, the latitude is negatively correlated with temperature; this negative correlation tells us that the two variables move in opposite directions: as latitude increases, the temperature drops, and vice versa.  In the southern hemisphers, the latitude is positively correlated with temperature: this positive correlation tells us that the two variables move in the same direction: as latitude increases, the temperature increases.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.3: Humidity vs. Latitude (Northern Hemisphere)',
         1, 45.0, 18.0)
# Out:
# r-value:     0.1625
# r-squared:   0.0264

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.4: Humidity vs. Latitude (Southern Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     -0.0197
# r-squared:   0.0004

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and humidity in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Cloudiness vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.5: Cloudiness vs. Latitude (Northern Hemisphere)',
         1, 16.0, 62.0)
# Out:
# r-value:     0.0317
# r-squared:   0.0010

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.6: Cloudiness vs. Latitude (Southern Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     -0.1036
# r-squared:   0.0107

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and cloudiness in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.7: Wind Speed vs. Latitude (Northern Hemisphere)',
         1, 15.0, 22.0)
# Out:
# r-value:     -0.0120
# r-squared:   0.0001

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.8: Wind Speed vs. Latitude (Southern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.1795
# r-squared:   0.0322

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and wind speed in either hemisphere.

# %%
#log_subroutine \
#    .EndProgramExecution()
