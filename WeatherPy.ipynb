# %% [markdown]
# # WeatherPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, WeatherPy.ipynb, uses a Python script to 
 #      visualize the weather of over 500 cities of varying distances from the equator. 
 #      The script uses the citipy Python library and the openWeatherMap API to create 
 #      a representative model of weather across cities.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubRoutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'WeatherPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('WeatherPy')

# %% [markdown]
# # <br> **Section 1: Weather Variables and Latitude**

# %% [markdown]
# ## **Section 1.1: Data Acquisition**

# %% [markdown]
# ### **List of Cities**

# %%
citiesListOfStrings \
    = api_function \
        .ReturnCitiesList()

# %% [markdown]
# ### **Weather Data from List of Cities**

# %%
cityWeatherDataFrame \
    = api_function \
        .ReturnWeatherDataFrame \
            (citiesListOfStrings)
# Out:
# DATA RETRIEVAL FOR CITY WEATHER DATAFRAME BEGINS...
#
#
# PROCESSING RECORD #2 OF SET 1 FOR CITY, bondo.
#
# PROCESSING RECORD #3 OF SET 1 FOR CITY, uribia.
#
# PROCESSING RECORD #4 OF SET 1 FOR CITY, saldanha.
#
# PROCESSING RECORD #5 OF SET 1 FOR CITY, miguel aleman (la doce).
#
# The script did not find the city, miguel aleman (la doce). Skipping...
#
# PROCESSING RECORD #6 OF SET 1 FOR CITY, el calafate.
#
# PROCESSING RECORD #7 OF SET 1 FOR CITY, edinburgh of the seven seas.
#
# PROCESSING RECORD #8 OF SET 1 FOR CITY, thompson.
#
# PROCESSING RECORD #9 OF SET 1 FOR CITY, waitangi.
#
# PROCESSING RECORD #10 OF SET 1 FOR CITY, walvis bay.
#
# PROCESSING RECORD #11 OF SET 1 FOR CITY, port-aux-francais.
#
# PROCESSING RECORD #12 OF SET 1 FOR CITY, porteirinha.
#
# PROCESSING RECORD #13 OF SET 1 FOR CITY, susuman.
#
# PROCESSING RECORD #14 OF SET 1 FOR CITY, hasaki.
#
# PROCESSING RECORD #15 OF SET 1 FOR CITY, chibougamau.
#
# PROCESSING RECORD #16 OF SET 1 FOR CITY, puerto natales.
#
# PROCESSING RECORD #17 OF SET 1 FOR CITY, qaqortoq.
#
# PROCESSING RECORD #18 OF SET 1 FOR CITY, kampot.
#
# PROCESSING RECORD #19 OF SET 1 FOR CITY, hithadhoo.
#
# PROCESSING RECORD #20 OF SET 1 FOR CITY, taiohae.
#
# The script did not find the city, taiohae. Skipping...
#
# PROCESSING RECORD #21 OF SET 1 FOR CITY, prado.
#
# PROCESSING RECORD #22 OF SET 1 FOR CITY, bethel.
#
# PROCESSING RECORD #23 OF SET 1 FOR CITY, hamilton.
#
# PROCESSING RECORD #24 OF SET 1 FOR CITY, kodiak.
#
# PROCESSING RECORD #25 OF SET 1 FOR CITY, albany.
#
# PROCESSING RECORD #26 OF SET 1 FOR CITY, lupane.
#
# PROCESSING RECORD #27 OF SET 1 FOR CITY, adamstown.
#
# PROCESSING RECORD #28 OF SET 1 FOR CITY, saint croix.
#
# PROCESSING RECORD #29 OF SET 1 FOR CITY, badger.
#
# PROCESSING RECORD #30 OF SET 1 FOR CITY, keflavik.
#
# PROCESSING RECORD #31 OF SET 1 FOR CITY, blackmans bay.
#
# PROCESSING RECORD #32 OF SET 1 FOR CITY, jamestown.
#
# PROCESSING RECORD #33 OF SET 1 FOR CITY, northam.
#
# PROCESSING RECORD #34 OF SET 1 FOR CITY, whitehorse.
#
# PROCESSING RECORD #35 OF SET 1 FOR CITY, santo tome.
#
# PROCESSING RECORD #36 OF SET 1 FOR CITY, enewetak.
#
# PROCESSING RECORD #37 OF SET 1 FOR CITY, vung tau.
#
# PROCESSING RECORD #38 OF SET 1 FOR CITY, grytviken.
#
# PROCESSING RECORD #39 OF SET 1 FOR CITY, rimouski.
#
# PROCESSING RECORD #40 OF SET 1 FOR CITY, tianpeng.
#
# PROCESSING RECORD #41 OF SET 1 FOR CITY, saudarkrokur.
#
# PROCESSING RECORD #42 OF SET 1 FOR CITY, awjilah.
#
# PROCESSING RECORD #43 OF SET 1 FOR CITY, tidjikja.
#
# PROCESSING RECORD #44 OF SET 1 FOR CITY, loyew.
#
# PROCESSING RECORD #45 OF SET 1 FOR CITY, longyearbyen.
#
# PROCESSING RECORD #46 OF SET 1 FOR CITY, gadzhiyevo.
#
# PROCESSING RECORD #47 OF SET 1 FOR CITY, carnarvon.
#
# PROCESSING RECORD #48 OF SET 1 FOR CITY, kavieng.
#
# PROCESSING RECORD #49 OF SET 1 FOR CITY, livadiya.
#
# PROCESSING RECORD #50 OF SET 1 FOR CITY, takamaka.
#
# The script did not find the city, takamaka. Skipping...
#
# PROCESSING RECORD #51 OF SET 1 FOR CITY, swakopmund.
#
# PROCESSING RECORD #1 OF SET 2 FOR CITY, hotan.
#
# PROCESSING RECORD #2 OF SET 2 FOR CITY, faya-largeau.
#
# PROCESSING RECORD #3 OF SET 2 FOR CITY, constantia.
#
# PROCESSING RECORD #4 OF SET 2 FOR CITY, tiksi.
#
# PROCESSING RECORD #5 OF SET 2 FOR CITY, pibor.
#
# The script did not find the city, pibor. Skipping...
#
# PROCESSING RECORD #6 OF SET 2 FOR CITY, chonchi.
#
# PROCESSING RECORD #7 OF SET 2 FOR CITY, orkney.
#
# PROCESSING RECORD #8 OF SET 2 FOR CITY, puerto san carlos.
#
# The script did not find the city, puerto san carlos. Skipping...
#
# PROCESSING RECORD #9 OF SET 2 FOR CITY, tobruk.
#
# PROCESSING RECORD #10 OF SET 2 FOR CITY, olonkinbyen.
#
# PROCESSING RECORD #11 OF SET 2 FOR CITY, bikenibeu village.
#
# PROCESSING RECORD #12 OF SET 2 FOR CITY, ancud.
#
# PROCESSING RECORD #13 OF SET 2 FOR CITY, yukhnov.
#
# PROCESSING RECORD #14 OF SET 2 FOR CITY, deschutes river woods.
#
# PROCESSING RECORD #15 OF SET 2 FOR CITY, papatowai.
#
# PROCESSING RECORD #16 OF SET 2 FOR CITY, ushuaia.
#
# PROCESSING RECORD #17 OF SET 2 FOR CITY, nzerekore.
#
# PROCESSING RECORD #18 OF SET 2 FOR CITY, vorgashor.
#
# PROCESSING RECORD #19 OF SET 2 FOR CITY, kramfors.
#
# PROCESSING RECORD #20 OF SET 2 FOR CITY, bredasdorp.
#
# PROCESSING RECORD #21 OF SET 2 FOR CITY, great falls.
#
# PROCESSING RECORD #22 OF SET 2 FOR CITY, sorong.
#
# PROCESSING RECORD #23 OF SET 2 FOR CITY, ilulissat.
#
# PROCESSING RECORD #24 OF SET 2 FOR CITY, sitka.
#
# PROCESSING RECORD #25 OF SET 2 FOR CITY, birao.
#
# PROCESSING RECORD #26 OF SET 2 FOR CITY, mizque.
#
# PROCESSING RECORD #27 OF SET 2 FOR CITY, kayangel.
#
# PROCESSING RECORD #28 OF SET 2 FOR CITY, pakokku.
#
# PROCESSING RECORD #29 OF SET 2 FOR CITY, beau vallon.
#
# PROCESSING RECORD #30 OF SET 2 FOR CITY, dakoro.
#
# PROCESSING RECORD #31 OF SET 2 FOR CITY, bilibino.
#
# PROCESSING RECORD #32 OF SET 2 FOR CITY, port elizabeth.
#
# PROCESSING RECORD #33 OF SET 2 FOR CITY, saint-francois.
#
# PROCESSING RECORD #34 OF SET 2 FOR CITY, georgetown.
#
# PROCESSING RECORD #35 OF SET 2 FOR CITY, portland.
#
# PROCESSING RECORD #36 OF SET 2 FOR CITY, kavaratti.
#
# PROCESSING RECORD #37 OF SET 2 FOR CITY, maracacume.
#
# PROCESSING RECORD #38 OF SET 2 FOR CITY, egilsstadir.
#
# PROCESSING RECORD #39 OF SET 2 FOR CITY, yellowknife.
#
# PROCESSING RECORD #40 OF SET 2 FOR CITY, anadyr.
#
# PROCESSING RECORD #41 OF SET 2 FOR CITY, maros.
#
# The script did not find the city, maros. Skipping...
#
# PROCESSING RECORD #42 OF SET 2 FOR CITY, port mathurin.
#
# PROCESSING RECORD #43 OF SET 2 FOR CITY, remire-montjoly.
#
# PROCESSING RECORD #44 OF SET 2 FOR CITY, ribeira grande.
#
# PROCESSING RECORD #45 OF SET 2 FOR CITY, dalandzadgad.
#
# PROCESSING RECORD #46 OF SET 2 FOR CITY, kununurra.
#
# PROCESSING RECORD #47 OF SET 2 FOR CITY, tadine.
#
# PROCESSING RECORD #48 OF SET 2 FOR CITY, ubari.
#
# PROCESSING RECORD #49 OF SET 2 FOR CITY, cabedelo.
#
# PROCESSING RECORD #50 OF SET 2 FOR CITY, glendive.
#
# PROCESSING RECORD #1 OF SET 3 FOR CITY, sarnia.
#
# PROCESSING RECORD #2 OF SET 3 FOR CITY, caleta de carquin.
#
# PROCESSING RECORD #3 OF SET 3 FOR CITY, burutu.
#
# PROCESSING RECORD #4 OF SET 3 FOR CITY, st. john's.
#
# PROCESSING RECORD #5 OF SET 3 FOR CITY, cabo san lucas.
#
# PROCESSING RECORD #6 OF SET 3 FOR CITY, tulun.
#
# PROCESSING RECORD #7 OF SET 3 FOR CITY, midvagur.
#
# PROCESSING RECORD #8 OF SET 3 FOR CITY, independencia.
#
# PROCESSING RECORD #9 OF SET 3 FOR CITY, inhambane.
#
# PROCESSING RECORD #10 OF SET 3 FOR CITY, magalia.
#
# PROCESSING RECORD #11 OF SET 3 FOR CITY, fuvahmulah.
#
# The script did not find the city, fuvahmulah. Skipping...
#
# PROCESSING RECORD #12 OF SET 3 FOR CITY, basco.
#
# PROCESSING RECORD #13 OF SET 3 FOR CITY, hermanus.
#
# PROCESSING RECORD #14 OF SET 3 FOR CITY, menongue.
#
# PROCESSING RECORD #15 OF SET 3 FOR CITY, tazovsky.
#
# PROCESSING RECORD #16 OF SET 3 FOR CITY, atafu village.
#
# PROCESSING RECORD #17 OF SET 3 FOR CITY, vilyuchinsk.
#
# PROCESSING RECORD #18 OF SET 3 FOR CITY, narasannapeta.
#
# PROCESSING RECORD #19 OF SET 3 FOR CITY, talnakh.
#
# PROCESSING RECORD #20 OF SET 3 FOR CITY, new norfolk.
#
# PROCESSING RECORD #21 OF SET 3 FOR CITY, banjarmasin.
#
# PROCESSING RECORD #22 OF SET 3 FOR CITY, port alfred.
#
# PROCESSING RECORD #23 OF SET 3 FOR CITY, ulsteinvik.
#
# PROCESSING RECORD #24 OF SET 3 FOR CITY, muzayri'.
#
# The script did not find the city, muzayri'. Skipping...
#
# PROCESSING RECORD #25 OF SET 3 FOR CITY, upington.
#
# PROCESSING RECORD #26 OF SET 3 FOR CITY, utrik.
#
# PROCESSING RECORD #27 OF SET 3 FOR CITY, cururupu.
#
# PROCESSING RECORD #28 OF SET 3 FOR CITY, west island.
#
# PROCESSING RECORD #29 OF SET 3 FOR CITY, avarua.
#
# PROCESSING RECORD #30 OF SET 3 FOR CITY, invercargill.
#
# PROCESSING RECORD #31 OF SET 3 FOR CITY, east london.
#
# PROCESSING RECORD #32 OF SET 3 FOR CITY, martapura.
#
# PROCESSING RECORD #33 OF SET 3 FOR CITY, geraldton.
#
# PROCESSING RECORD #34 OF SET 3 FOR CITY, san julian.
#
# PROCESSING RECORD #35 OF SET 3 FOR CITY, maxixe.
#
# PROCESSING RECORD #36 OF SET 3 FOR CITY, malabar.
#
# PROCESSING RECORD #37 OF SET 3 FOR CITY, claiborne.
#
# PROCESSING RECORD #38 OF SET 3 FOR CITY, kyren.
#
# PROCESSING RECORD #39 OF SET 3 FOR CITY, isafjordur.
#
# PROCESSING RECORD #40 OF SET 3 FOR CITY, itaueira.
#
# PROCESSING RECORD #41 OF SET 3 FOR CITY, erattupetta.
#
# PROCESSING RECORD #42 OF SET 3 FOR CITY, mossel bay.
#
# PROCESSING RECORD #43 OF SET 3 FOR CITY, bishops waltham.
#
# PROCESSING RECORD #44 OF SET 3 FOR CITY, puerto ayora.
#
# PROCESSING RECORD #45 OF SET 3 FOR CITY, kenai.
# PROCESSING RECORD #46 OF SET 3 FOR CITY, muroto-misakicho.
#
# PROCESSING RECORD #47 OF SET 3 FOR CITY, sirjan.
#
# PROCESSING RECORD #48 OF SET 3 FOR CITY, tranovaho.
#
# The script did not find the city, tranovaho. Skipping...
#
# PROCESSING RECORD #49 OF SET 3 FOR CITY, iqaluit.
#
# PROCESSING RECORD #50 OF SET 3 FOR CITY, samraong.
#
# PROCESSING RECORD #1 OF SET 4 FOR CITY, wailua homesteads.
#
# PROCESSING RECORD #2 OF SET 4 FOR CITY, lebu.
#
# PROCESSING RECORD #3 OF SET 4 FOR CITY, nuuk.
#
# PROCESSING RECORD #4 OF SET 4 FOR CITY, pandan.
#
# PROCESSING RECORD #5 OF SET 4 FOR CITY, berdigestyakh.
#
# PROCESSING RECORD #6 OF SET 4 FOR CITY, markha.
#
# PROCESSING RECORD #7 OF SET 4 FOR CITY, dudinka.
#
# PROCESSING RECORD #8 OF SET 4 FOR CITY, sao pedro do sul.
#
# PROCESSING RECORD #9 OF SET 4 FOR CITY, inari.
#
# PROCESSING RECORD #10 OF SET 4 FOR CITY, dumas.
#
# PROCESSING RECORD #11 OF SET 4 FOR CITY, ariguani.
#
# PROCESSING RECORD #12 OF SET 4 FOR CITY, pante makasar.
#
# The script did not find the city, pante makasar. Skipping...
#
# PROCESSING RECORD #13 OF SET 4 FOR CITY, stanley.
#
# PROCESSING RECORD #14 OF SET 4 FOR CITY, kone.
#
# PROCESSING RECORD #15 OF SET 4 FOR CITY, uacu cungo.
#
# PROCESSING RECORD #16 OF SET 4 FOR CITY, ust-nera.
#
# PROCESSING RECORD #17 OF SET 4 FOR CITY, fale old settlement.
#
# PROCESSING RECORD #18 OF SET 4 FOR CITY, ambalavao.
#
# PROCESSING RECORD #19 OF SET 4 FOR CITY, domat.
#
# PROCESSING RECORD #20 OF SET 4 FOR CITY, yuzhno-kurilsk.
#
# PROCESSING RECORD #21 OF SET 4 FOR CITY, pacocha.
#
# PROCESSING RECORD #22 OF SET 4 FOR CITY, mikun'.
#
# PROCESSING RECORD #23 OF SET 4 FOR CITY, springbok.
#
# PROCESSING RECORD #24 OF SET 4 FOR CITY, uturoa.
#
# PROCESSING RECORD #25 OF SET 4 FOR CITY, dunedin.
#
# PROCESSING RECORD #26 OF SET 4 FOR CITY, singtam.
#
# PROCESSING RECORD #27 OF SET 4 FOR CITY, zaozersk.
#
# PROCESSING RECORD #28 OF SET 4 FOR CITY, callao.
#
# PROCESSING RECORD #29 OF SET 4 FOR CITY, margaret river.
#
# PROCESSING RECORD #30 OF SET 4 FOR CITY, hakui.
#
# PROCESSING RECORD #31 OF SET 4 FOR CITY, mikashevichy.
#
# PROCESSING RECORD #32 OF SET 4 FOR CITY, kamianske.
#
# PROCESSING RECORD #33 OF SET 4 FOR CITY, touros.
#
# PROCESSING RECORD #34 OF SET 4 FOR CITY, makungu.
#
# PROCESSING RECORD #35 OF SET 4 FOR CITY, prince rupert.
#
# PROCESSING RECORD #36 OF SET 4 FOR CITY, nova vicosa.
#
# PROCESSING RECORD #37 OF SET 4 FOR CITY, albertina.
#
# PROCESSING RECORD #38 OF SET 4 FOR CITY, zhezqazghan.
#
# PROCESSING RECORD #39 OF SET 4 FOR CITY, college.
#
# PROCESSING RECORD #40 OF SET 4 FOR CITY, horqueta.
#
# PROCESSING RECORD #41 OF SET 4 FOR CITY, tsiombe.
#
# PROCESSING RECORD #42 OF SET 4 FOR CITY, metlili chaamba.
#
# PROCESSING RECORD #43 OF SET 4 FOR CITY, nagqu.
#
# PROCESSING RECORD #44 OF SET 4 FOR CITY, luumaki.
#
# PROCESSING RECORD #45 OF SET 4 FOR CITY, guantanamo.
#
# PROCESSING RECORD #46 OF SET 4 FOR CITY, gebeit.
#
# PROCESSING RECORD #47 OF SET 4 FOR CITY, colonia.
#
# PROCESSING RECORD #48 OF SET 4 FOR CITY, newman.
#
# PROCESSING RECORD #49 OF SET 4 FOR CITY, salalah.
#
# PROCESSING RECORD #50 OF SET 4 FOR CITY, vila franca do campo.
#
# PROCESSING RECORD #1 OF SET 5 FOR CITY, morondava.
#
# PROCESSING RECORD #2 OF SET 5 FOR CITY, mili.
#
# PROCESSING RECORD #3 OF SET 5 FOR CITY, selfoss.
#
# PROCESSING RECORD #4 OF SET 5 FOR CITY, gaspe.
#
# PROCESSING RECORD #5 OF SET 5 FOR CITY, nishinoomote.
#
# PROCESSING RECORD #6 OF SET 5 FOR CITY, labrador city.
#
# PROCESSING RECORD #7 OF SET 5 FOR CITY, yopal.
#
# PROCESSING RECORD #8 OF SET 5 FOR CITY, berriane.
#
# PROCESSING RECORD #9 OF SET 5 FOR CITY, nova olimpia.
#
# PROCESSING RECORD #10 OF SET 5 FOR CITY, machico.
#
# PROCESSING RECORD #11 OF SET 5 FOR CITY, punta arenas.
#
# PROCESSING RECORD #12 OF SET 5 FOR CITY, sisimiut.
#
# PROCESSING RECORD #13 OF SET 5 FOR CITY, zhanga buqtyrma.
#
# PROCESSING RECORD #14 OF SET 5 FOR CITY, vavuniya.
#
# PROCESSING RECORD #15 OF SET 5 FOR CITY, bull savanna.
#
# PROCESSING RECORD #16 OF SET 5 FOR CITY, zinder.
#
# PROCESSING RECORD #17 OF SET 5 FOR CITY, murray bridge.
#
# PROCESSING RECORD #18 OF SET 5 FOR CITY, nemuro.
#
# PROCESSING RECORD #19 OF SET 5 FOR CITY, codrington.
#
# PROCESSING RECORD #20 OF SET 5 FOR CITY, port sudan.
#
# PROCESSING RECORD #21 OF SET 5 FOR CITY, kosh-agach.
#
# PROCESSING RECORD #22 OF SET 5 FOR CITY, torghay.
#
# PROCESSING RECORD #23 OF SET 5 FOR CITY, hawaiian paradise park.
#
# PROCESSING RECORD #24 OF SET 5 FOR CITY, san luis de la loma.
#
# PROCESSING RECORD #25 OF SET 5 FOR CITY, espargos.
#
# The script did not find the city, espargos. Skipping...
#
# PROCESSING RECORD #26 OF SET 5 FOR CITY, areka.
#
# PROCESSING RECORD #27 OF SET 5 FOR CITY, mar del plata.
#
# PROCESSING RECORD #28 OF SET 5 FOR CITY, kapuskasing.
#
# PROCESSING RECORD #29 OF SET 5 FOR CITY, kultali.
#
# The script did not find the city, kultali. Skipping...
#
# PROCESSING RECORD #30 OF SET 5 FOR CITY, santiago de cao.
#
# PROCESSING RECORD #31 OF SET 5 FOR CITY, conduaga.
#
# PROCESSING RECORD #32 OF SET 5 FOR CITY, bubaque.
#
# PROCESSING RECORD #33 OF SET 5 FOR CITY, huangpi.
#
# PROCESSING RECORD #34 OF SET 5 FOR CITY, somero.
#
# PROCESSING RECORD #35 OF SET 5 FOR CITY, pacasmayo.
#
# PROCESSING RECORD #36 OF SET 5 FOR CITY, dryden.
#
# PROCESSING RECORD #37 OF SET 5 FOR CITY, altinoluk.
#
# The script did not find the city, altinoluk. Skipping...
#
# PROCESSING RECORD #38 OF SET 5 FOR CITY, ganye.
#
# PROCESSING RECORD #39 OF SET 5 FOR CITY, nebraska city.
#
# PROCESSING RECORD #40 OF SET 5 FOR CITY, minas de marcona.
#
# PROCESSING RECORD #41 OF SET 5 FOR CITY, anna.
#
# PROCESSING RECORD #42 OF SET 5 FOR CITY, kapa'a.
#
# PROCESSING RECORD #43 OF SET 5 FOR CITY, olyokminsk.
#
# PROCESSING RECORD #44 OF SET 5 FOR CITY, saipan.
#
# PROCESSING RECORD #45 OF SET 5 FOR CITY, la asuncion.
#
# PROCESSING RECORD #46 OF SET 5 FOR CITY, yemva.
#
# PROCESSING RECORD #47 OF SET 5 FOR CITY, cole harbour.
#
# PROCESSING RECORD #48 OF SET 5 FOR CITY, pisco.
#
# PROCESSING RECORD #49 OF SET 5 FOR CITY, monte argentario.
#
# PROCESSING RECORD #50 OF SET 5 FOR CITY, fuglafjordur.
#
# PROCESSING RECORD #1 OF SET 6 FOR CITY, bage.
#
# PROCESSING RECORD #2 OF SET 6 FOR CITY, nadym.
#
# PROCESSING RECORD #3 OF SET 6 FOR CITY, al qanayat.
#
# PROCESSING RECORD #4 OF SET 6 FOR CITY, weyburn.
#
# PROCESSING RECORD #5 OF SET 6 FOR CITY, labuan.
#
# PROCESSING RECORD #6 OF SET 6 FOR CITY, nanao.
#
# PROCESSING RECORD #7 OF SET 6 FOR CITY, oshnaviyeh.
#
# PROCESSING RECORD #8 OF SET 6 FOR CITY, turan.
#
# PROCESSING RECORD #9 OF SET 6 FOR CITY, panaba.
#
# PROCESSING RECORD #10 OF SET 6 FOR CITY, kigonsera.
#
# PROCESSING RECORD #11 OF SET 6 FOR CITY, opuwo.
#
# PROCESSING RECORD #12 OF SET 6 FOR CITY, mount isa.
#
# PROCESSING RECORD #13 OF SET 6 FOR CITY, banda aceh.
#
# PROCESSING RECORD #14 OF SET 6 FOR CITY, tralee.
#
# PROCESSING RECORD #15 OF SET 6 FOR CITY, port lincoln.
#
# PROCESSING RECORD #16 OF SET 6 FOR CITY, cockburn town.
#
# PROCESSING RECORD #17 OF SET 6 FOR CITY, puerto baquerizo moreno.
#
# PROCESSING RECORD #18 OF SET 6 FOR CITY, carmen.
#
# PROCESSING RECORD #19 OF SET 6 FOR CITY, la sarre.
#
# PROCESSING RECORD #20 OF SET 6 FOR CITY, bengkulu.
#
# PROCESSING RECORD #21 OF SET 6 FOR CITY, viedma.
#
# PROCESSING RECORD #22 OF SET 6 FOR CITY, richards bay.
#
# PROCESSING RECORD #23 OF SET 6 FOR CITY, daoukro.
#
# PROCESSING RECORD #24 OF SET 6 FOR CITY, island harbour.
#
# PROCESSING RECORD #25 OF SET 6 FOR CITY, talara.
#
# PROCESSING RECORD #26 OF SET 6 FOR CITY, port hedland.
#
# PROCESSING RECORD #27 OF SET 6 FOR CITY, belo sur tsiribihina.
#
# PROCESSING RECORD #28 OF SET 6 FOR CITY, lamu.
#
# PROCESSING RECORD #29 OF SET 6 FOR CITY, kyzylorda.
#
# PROCESSING RECORD #30 OF SET 6 FOR CITY, ola.
#
# PROCESSING RECORD #31 OF SET 6 FOR CITY, puerto cortez.
#
# PROCESSING RECORD #32 OF SET 6 FOR CITY, nchelenge.
#
# PROCESSING RECORD #33 OF SET 6 FOR CITY, ciudad bolivar.
#
# PROCESSING RECORD #34 OF SET 6 FOR CITY, lata.
#
# PROCESSING RECORD #35 OF SET 6 FOR CITY, batarasa.
#
# PROCESSING RECORD #36 OF SET 6 FOR CITY, coquimbo.
#
# PROCESSING RECORD #37 OF SET 6 FOR CITY, dickinson.
#
# PROCESSING RECORD #38 OF SET 6 FOR CITY, whitburn.
#
# PROCESSING RECORD #39 OF SET 6 FOR CITY, fort bragg.
#
# PROCESSING RECORD #40 OF SET 6 FOR CITY, kenitra.
#
# PROCESSING RECORD #41 OF SET 6 FOR CITY, sarupathar.
#
# PROCESSING RECORD #42 OF SET 6 FOR CITY, gur'yevsk.
#
# PROCESSING RECORD #43 OF SET 6 FOR CITY, reedsburg.
#
# PROCESSING RECORD #44 OF SET 6 FOR CITY, massenya.
#
# PROCESSING RECORD #45 OF SET 6 FOR CITY, petrovsk.
# PROCESSING RECORD #46 OF SET 6 FOR CITY, bay roberts.
#
# PROCESSING RECORD #47 OF SET 6 FOR CITY, qal'at bishah.
#
# The script did not find the city, qal'at bishah. Skipping...
#
# PROCESSING RECORD #48 OF SET 6 FOR CITY, al-hamdaniya.
#
# PROCESSING RECORD #49 OF SET 6 FOR CITY, cill airne.
#
# PROCESSING RECORD #50 OF SET 6 FOR CITY, afaahiti.
#
# PROCESSING RECORD #1 OF SET 7 FOR CITY, nizao.
#
# PROCESSING RECORD #2 OF SET 7 FOR CITY, kasane.
#
# PROCESSING RECORD #3 OF SET 7 FOR CITY, illizi.
#
# PROCESSING RECORD #4 OF SET 7 FOR CITY, baruun-urt.
#
# PROCESSING RECORD #5 OF SET 7 FOR CITY, kantunilkin.
#
# PROCESSING RECORD #6 OF SET 7 FOR CITY, tughyl.
#
# PROCESSING RECORD #7 OF SET 7 FOR CITY, papao.
#
# PROCESSING RECORD #8 OF SET 7 FOR CITY, amos.
#
# PROCESSING RECORD #9 OF SET 7 FOR CITY, page.
#
# PROCESSING RECORD #10 OF SET 7 FOR CITY, cozumel.
#
# PROCESSING RECORD #11 OF SET 7 FOR CITY, birni n konni.
#
# PROCESSING RECORD #12 OF SET 7 FOR CITY, tommot.
#
# PROCESSING RECORD #13 OF SET 7 FOR CITY, rongelap.
#
# PROCESSING RECORD #14 OF SET 7 FOR CITY, nar'yan-mar.
#
# PROCESSING RECORD #15 OF SET 7 FOR CITY, olinda.
#
# PROCESSING RECORD #16 OF SET 7 FOR CITY, tual.
#
# PROCESSING RECORD #17 OF SET 7 FOR CITY, alto barinas.
#
# PROCESSING RECORD #18 OF SET 7 FOR CITY, flying fish cove.
#
# PROCESSING RECORD #19 OF SET 7 FOR CITY, klyuchi.
#
# PROCESSING RECORD #20 OF SET 7 FOR CITY, luderitz.
#
# PROCESSING RECORD #21 OF SET 7 FOR CITY, hobyo.
#
# PROCESSING RECORD #22 OF SET 7 FOR CITY, lerwick.
#
# PROCESSING RECORD #23 OF SET 7 FOR CITY, tura.
#
# PROCESSING RECORD #24 OF SET 7 FOR CITY, lazaro cardenas.
#
# PROCESSING RECORD #25 OF SET 7 FOR CITY, ponta delgada.
#
# PROCESSING RECORD #26 OF SET 7 FOR CITY, haiku-pauwela.
#
# PROCESSING RECORD #27 OF SET 7 FOR CITY, zaysan.
#
# PROCESSING RECORD #28 OF SET 7 FOR CITY, vadso.
#
# PROCESSING RECORD #29 OF SET 7 FOR CITY, kirensk.
#
# PROCESSING RECORD #30 OF SET 7 FOR CITY, marsh harbour.
#
# PROCESSING RECORD #31 OF SET 7 FOR CITY, smithers.
#
# PROCESSING RECORD #32 OF SET 7 FOR CITY, aasiaat.
#
# PROCESSING RECORD #33 OF SET 7 FOR CITY, izyum.
#
# PROCESSING RECORD #34 OF SET 7 FOR CITY, bannu.
#
# PROCESSING RECORD #35 OF SET 7 FOR CITY, zheleznodorozhnyy.
#
# PROCESSING RECORD #36 OF SET 7 FOR CITY, acarau.
#
# PROCESSING RECORD #37 OF SET 7 FOR CITY, tofol.
#
# PROCESSING RECORD #38 OF SET 7 FOR CITY, kiunga.
#
# PROCESSING RECORD #39 OF SET 7 FOR CITY, messaad.
#
# PROCESSING RECORD #40 OF SET 7 FOR CITY, bridgewater.
#
# PROCESSING RECORD #41 OF SET 7 FOR CITY, pisogne.
#
# PROCESSING RECORD #42 OF SET 7 FOR CITY, kupang.
#
# PROCESSING RECORD #43 OF SET 7 FOR CITY, gudari.
#
# PROCESSING RECORD #44 OF SET 7 FOR CITY, dakhla.
#
# PROCESSING RECORD #45 OF SET 7 FOR CITY, wacheng.
#
# PROCESSING RECORD #46 OF SET 7 FOR CITY, gemena.
#
# PROCESSING RECORD #47 OF SET 7 FOR CITY, ketchikan.
#
# PROCESSING RECORD #48 OF SET 7 FOR CITY, polyarnyy.
#
# PROCESSING RECORD #49 OF SET 7 FOR CITY, bandar lampung.
#
# PROCESSING RECORD #50 OF SET 7 FOR CITY, mhamid.
#
# PROCESSING RECORD #1 OF SET 8 FOR CITY, kamaishi.
#
# PROCESSING RECORD #2 OF SET 8 FOR CITY, shiyan.
#
# PROCESSING RECORD #3 OF SET 8 FOR CITY, alamosa.
#
# PROCESSING RECORD #4 OF SET 8 FOR CITY, ambon.
#
# PROCESSING RECORD #5 OF SET 8 FOR CITY, turinsk.
#
# PROCESSING RECORD #6 OF SET 8 FOR CITY, masaka.
#
# PROCESSING RECORD #7 OF SET 8 FOR CITY, 'ohonua.
#
# The script did not find the city, 'ohonua. Skipping...
#
# PROCESSING RECORD #8 OF SET 8 FOR CITY, ulladulla.
#
# PROCESSING RECORD #9 OF SET 8 FOR CITY, croix-des-bouquets.
#
# PROCESSING RECORD #10 OF SET 8 FOR CITY, bureya.
#
# PROCESSING RECORD #11 OF SET 8 FOR CITY, bol.
#
# PROCESSING RECORD #12 OF SET 8 FOR CITY, altai.
#
# PROCESSING RECORD #13 OF SET 8 FOR CITY, zvishavane.
#
# PROCESSING RECORD #14 OF SET 8 FOR CITY, luganville.
#
# PROCESSING RECORD #15 OF SET 8 FOR CITY, cidreira.
#
# PROCESSING RECORD #16 OF SET 8 FOR CITY, nizhniy kuranakh.
#
# PROCESSING RECORD #17 OF SET 8 FOR CITY, dera bugti.
#
# PROCESSING RECORD #18 OF SET 8 FOR CITY, greenville.
#
# PROCESSING RECORD #19 OF SET 8 FOR CITY, tvoroyri.
#
# PROCESSING RECORD #20 OF SET 8 FOR CITY, ciudad lazaro cardenas.
#
# PROCESSING RECORD #21 OF SET 8 FOR CITY, ende.
#
# PROCESSING RECORD #22 OF SET 8 FOR CITY, kerikeri.
#
# PROCESSING RECORD #23 OF SET 8 FOR CITY, langsa.
#
# PROCESSING RECORD #24 OF SET 8 FOR CITY, 'ayy.
#
# The script did not find the city, 'ayy. Skipping...
#
# PROCESSING RECORD #25 OF SET 8 FOR CITY, iskateley.
#
# PROCESSING RECORD #26 OF SET 8 FOR CITY, muroran.
#
# PROCESSING RECORD #27 OF SET 8 FOR CITY, owando.
#
# PROCESSING RECORD #28 OF SET 8 FOR CITY, shangqiu.
#
# PROCESSING RECORD #29 OF SET 8 FOR CITY, nantucket.
#
# PROCESSING RECORD #30 OF SET 8 FOR CITY, peterhead.
#
# PROCESSING RECORD #31 OF SET 8 FOR CITY, calca.
#
# PROCESSING RECORD #32 OF SET 8 FOR CITY, mount pearl.
#
# PROCESSING RECORD #33 OF SET 8 FOR CITY, sokoni.
#
# PROCESSING RECORD #34 OF SET 8 FOR CITY, port blair.
#
# PROCESSING RECORD #35 OF SET 8 FOR CITY, urzhar.
#
# PROCESSING RECORD #36 OF SET 8 FOR CITY, zahedan.
#
# PROCESSING RECORD #37 OF SET 8 FOR CITY, margate.
#
# PROCESSING RECORD #38 OF SET 8 FOR CITY, dergachi.
#
# PROCESSING RECORD #39 OF SET 8 FOR CITY, alotau.
#
# The script did not find the city, alotau. Skipping...
#
# PROCESSING RECORD #40 OF SET 8 FOR CITY, khenchela.
#
# PROCESSING RECORD #41 OF SET 8 FOR CITY, varna.
#
# PROCESSING RECORD #42 OF SET 8 FOR CITY, tolanaro.
#
# PROCESSING RECORD #43 OF SET 8 FOR CITY, pachino.
#
# PROCESSING RECORD #44 OF SET 8 FOR CITY, samana.
#
# PROCESSING RECORD #45 OF SET 8 FOR CITY, la'ie.
#
# PROCESSING RECORD #46 OF SET 8 FOR CITY, mahriz.
#
# PROCESSING RECORD #47 OF SET 8 FOR CITY, porto novo.
#
# PROCESSING RECORD #48 OF SET 8 FOR CITY, sofifi.
#
# The script did not find the city, sofifi. Skipping...
#
# PROCESSING RECORD #49 OF SET 8 FOR CITY, sanghar.
#
# PROCESSING RECORD #50 OF SET 8 FOR CITY, hazard.
#
# PROCESSING RECORD #1 OF SET 9 FOR CITY, turpan.
#
# PROCESSING RECORD #2 OF SET 9 FOR CITY, lihue.
#
# PROCESSING RECORD #3 OF SET 9 FOR CITY, lewistown.
#
# PROCESSING RECORD #4 OF SET 9 FOR CITY, lively.
#
# PROCESSING RECORD #5 OF SET 9 FOR CITY, lindi.
#
# PROCESSING RECORD #6 OF SET 9 FOR CITY, yorkton.
#
# PROCESSING RECORD #7 OF SET 9 FOR CITY, chistopol'.
#
# PROCESSING RECORD #8 OF SET 9 FOR CITY, lorengau.
#
# PROCESSING RECORD #9 OF SET 9 FOR CITY, san lawrenz.
#
# PROCESSING RECORD #10 OF SET 9 FOR CITY, suntar.
#
# PROCESSING RECORD #11 OF SET 9 FOR CITY, wenxing.
#
# PROCESSING RECORD #12 OF SET 9 FOR CITY, udachny.
#
# PROCESSING RECORD #13 OF SET 9 FOR CITY, wladyslawowo.
#
# PROCESSING RECORD #14 OF SET 9 FOR CITY, yilan.
#
# PROCESSING RECORD #15 OF SET 9 FOR CITY, eravur town.
#
# PROCESSING RECORD #16 OF SET 9 FOR CITY, bonthe.
#
# PROCESSING RECORD #17 OF SET 9 FOR CITY, nabire.
#
# PROCESSING RECORD #18 OF SET 9 FOR CITY, alice springs.
#
# PROCESSING RECORD #19 OF SET 9 FOR CITY, masterton.
#
# PROCESSING RECORD #20 OF SET 9 FOR CITY, barth.
#
# PROCESSING RECORD #21 OF SET 9 FOR CITY, tobelo.
#
# PROCESSING RECORD #22 OF SET 9 FOR CITY, san patricio.
#
# PROCESSING RECORD #23 OF SET 9 FOR CITY, ulaangom.
#
# PROCESSING RECORD #24 OF SET 9 FOR CITY, alvaraes.
#
# PROCESSING RECORD #25 OF SET 9 FOR CITY, anloga.
#
# PROCESSING RECORD #26 OF SET 9 FOR CITY, boa vista.
#
# PROCESSING RECORD #27 OF SET 9 FOR CITY, konigsbach-stein.
#
# PROCESSING RECORD #28 OF SET 9 FOR CITY, vernon.
#
# PROCESSING RECORD #29 OF SET 9 FOR CITY, charlottetown.
#
# PROCESSING RECORD #30 OF SET 9 FOR CITY, bardaskan.
#
# The script did not find the city, bardaskan. Skipping...
#
# PROCESSING RECORD #31 OF SET 9 FOR CITY, vorkuta.
#
# PROCESSING RECORD #32 OF SET 9 FOR CITY, katsuura.
#
# PROCESSING RECORD #33 OF SET 9 FOR CITY, itoman.
#
# PROCESSING RECORD #34 OF SET 9 FOR CITY, srivardhan.
#
# PROCESSING RECORD #35 OF SET 9 FOR CITY, dhidhdhoo.
#
# PROCESSING RECORD #36 OF SET 9 FOR CITY, petropavlovsk-kamchatsky.
#
# PROCESSING RECORD #37 OF SET 9 FOR CITY, sinabang.
#
# PROCESSING RECORD #38 OF SET 9 FOR CITY, rio grande.
#
# PROCESSING RECORD #39 OF SET 9 FOR CITY, paso de los toros.
#
# PROCESSING RECORD #40 OF SET 9 FOR CITY, saint-philippe.
#
# PROCESSING RECORD #41 OF SET 9 FOR CITY, happy valley-goose bay.
#
# PROCESSING RECORD #42 OF SET 9 FOR CITY, weno.
#
# PROCESSING RECORD #43 OF SET 9 FOR CITY, mejit.
#
# PROCESSING RECORD #44 OF SET 9 FOR CITY, alta sierra.
#
# PROCESSING RECORD #45 OF SET 9 FOR CITY, preobrazheniye.
#
# PROCESSING RECORD #46 OF SET 9 FOR CITY, laguna.
# PROCESSING RECORD #47 OF SET 9 FOR CITY, beloretsk.
#
# PROCESSING RECORD #48 OF SET 9 FOR CITY, kavarna.
#
# PROCESSING RECORD #49 OF SET 9 FOR CITY, mhangura.
#
# PROCESSING RECORD #50 OF SET 9 FOR CITY, namtsy.
#
# PROCESSING RECORD #1 OF SET 10 FOR CITY, hoemul-li.
#
# PROCESSING RECORD #2 OF SET 10 FOR CITY, paola.
#
# PROCESSING RECORD #3 OF SET 10 FOR CITY, silute.
#
# PROCESSING RECORD #4 OF SET 10 FOR CITY, buka.
#
# PROCESSING RECORD #5 OF SET 10 FOR CITY, pancota.
#
# PROCESSING RECORD #6 OF SET 10 FOR CITY, veinticinco de mayo.
#
# PROCESSING RECORD #7 OF SET 10 FOR CITY, chiredzi.
#
# PROCESSING RECORD #8 OF SET 10 FOR CITY, ribeira brava.
#
# PROCESSING RECORD #9 OF SET 10 FOR CITY, abashiri.
#
# PROCESSING RECORD #10 OF SET 10 FOR CITY, montevideo.
#
# PROCESSING RECORD #11 OF SET 10 FOR CITY, iida.
#
# PROCESSING RECORD #12 OF SET 10 FOR CITY, karungdong.
#
# PROCESSING RECORD #13 OF SET 10 FOR CITY, cargados carajos.
#
# The script did not find the city, cargados carajos. Skipping...
#
# PROCESSING RECORD #14 OF SET 10 FOR CITY, toliara.
#
# PROCESSING RECORD #15 OF SET 10 FOR CITY, ixtapa.
#
# PROCESSING RECORD #16 OF SET 10 FOR CITY, clarksville.
#
# PROCESSING RECORD #17 OF SET 10 FOR CITY, pimentel.
#
# PROCESSING RECORD #18 OF SET 10 FOR CITY, emerald.
#
# PROCESSING RECORD #19 OF SET 10 FOR CITY, puerto boyaca.
#
# PROCESSING RECORD #20 OF SET 10 FOR CITY, penzance.
#
# PROCESSING RECORD #21 OF SET 10 FOR CITY, ndele.
#
# PROCESSING RECORD #22 OF SET 10 FOR CITY, mount gambier.
#
# PROCESSING RECORD #23 OF SET 10 FOR CITY, mazagao.
#
# PROCESSING RECORD #24 OF SET 10 FOR CITY, rikaze.
#
# PROCESSING RECORD #25 OF SET 10 FOR CITY, queenstown.
#
# PROCESSING RECORD #26 OF SET 10 FOR CITY, tra vinh.
#
# PROCESSING RECORD #27 OF SET 10 FOR CITY, najran.
#
# PROCESSING RECORD #28 OF SET 10 FOR CITY, naze.
#
# PROCESSING RECORD #29 OF SET 10 FOR CITY, qamdo.
#
# PROCESSING RECORD #30 OF SET 10 FOR CITY, zhosaly.
#
# PROCESSING RECORD #31 OF SET 10 FOR CITY, camana.
#
# PROCESSING RECORD #32 OF SET 10 FOR CITY, pervomayskoye.
#
# PROCESSING RECORD #33 OF SET 10 FOR CITY, khash.
#
# PROCESSING RECORD #34 OF SET 10 FOR CITY, hadibu.
#
# PROCESSING RECORD #35 OF SET 10 FOR CITY, katsuren-haebaru.
#
# PROCESSING RECORD #36 OF SET 10 FOR CITY, darwin.
#
# PROCESSING RECORD #37 OF SET 10 FOR CITY, lompoc.
#
# PROCESSING RECORD #38 OF SET 10 FOR CITY, arraial do cabo.
#
# PROCESSING RECORD #39 OF SET 10 FOR CITY, mananjary.
#
# PROCESSING RECORD #40 OF SET 10 FOR CITY, glace bay.
#
# PROCESSING RECORD #41 OF SET 10 FOR CITY, dongsheng.
#
# PROCESSING RECORD #42 OF SET 10 FOR CITY, youssoufia.
#
# PROCESSING RECORD #43 OF SET 10 FOR CITY, brightlingsea.
#
# PROCESSING RECORD #44 OF SET 10 FOR CITY, am djarass.
#
# The script did not find the city, am djarass. Skipping...
#
# PROCESSING RECORD #45 OF SET 10 FOR CITY, lethem.
#
# PROCESSING RECORD #46 OF SET 10 FOR CITY, greymouth.
#
# PROCESSING RECORD #47 OF SET 10 FOR CITY, berezovyy.
#
# PROCESSING RECORD #48 OF SET 10 FOR CITY, qarqaraly.
#
# PROCESSING RECORD #49 OF SET 10 FOR CITY, kristiansund.
#
# PROCESSING RECORD #50 OF SET 10 FOR CITY, zarghun shahr.
#
# PROCESSING RECORD #1 OF SET 11 FOR CITY, whangarei.
#
# PROCESSING RECORD #2 OF SET 11 FOR CITY, onverwacht.
#
# PROCESSING RECORD #3 OF SET 11 FOR CITY, kurtamysh.
#
# PROCESSING RECORD #4 OF SET 11 FOR CITY, arenapolis.
#
# PROCESSING RECORD #5 OF SET 11 FOR CITY, conception bay south.
#
# PROCESSING RECORD #6 OF SET 11 FOR CITY, aras-asan.
#
# PROCESSING RECORD #7 OF SET 11 FOR CITY, holualoa.
#
# PROCESSING RECORD #8 OF SET 11 FOR CITY, novouzensk.
#
# PROCESSING RECORD #9 OF SET 11 FOR CITY, santa elena de uairen.
#
# PROCESSING RECORD #10 OF SET 11 FOR CITY, howard springs.
#
# PROCESSING RECORD #11 OF SET 11 FOR CITY, howrah.
#
# PROCESSING RECORD #12 OF SET 11 FOR CITY, palmas de monte alto.
#
# PROCESSING RECORD #13 OF SET 11 FOR CITY, monteagudo.
#
# PROCESSING RECORD #14 OF SET 11 FOR CITY, quzhou.
#
# PROCESSING RECORD #15 OF SET 11 FOR CITY, lagos.
#
# PROCESSING RECORD #16 OF SET 11 FOR CITY, salinopolis.
#
# PROCESSING RECORD #17 OF SET 11 FOR CITY, kulia village.
#
# The script did not find the city, kulia village. Skipping...
#
# PROCESSING RECORD #18 OF SET 11 FOR CITY, grand falls-windsor.
#
# PROCESSING RECORD #19 OF SET 11 FOR CITY, pitimbu.
#
# PROCESSING RECORD #20 OF SET 11 FOR CITY, ylitornio.
#
# PROCESSING RECORD #21 OF SET 11 FOR CITY, visby.
#
# PROCESSING RECORD #22 OF SET 11 FOR CITY, acton vale.
#
# PROCESSING RECORD #23 OF SET 11 FOR CITY, piacabucu.
#
# PROCESSING RECORD #24 OF SET 11 FOR CITY, sibolga.
#
# PROCESSING RECORD #25 OF SET 11 FOR CITY, la passe.
#
# PROCESSING RECORD #26 OF SET 11 FOR CITY, cloquet.
#
# PROCESSING RECORD #27 OF SET 11 FOR CITY, cerkno.
#
# PROCESSING RECORD #28 OF SET 11 FOR CITY, saurimo.
#
# PROCESSING RECORD #29 OF SET 11 FOR CITY, alofi.
#
# PROCESSING RECORD #30 OF SET 11 FOR CITY, tucurui.
#
# PROCESSING RECORD #31 OF SET 11 FOR CITY, severo-yeniseyskiy.
#
# PROCESSING RECORD #32 OF SET 11 FOR CITY, keokuk.
#
# PROCESSING RECORD #33 OF SET 11 FOR CITY, kananga.
#
# PROCESSING RECORD #34 OF SET 11 FOR CITY, point pleasant.
#
# PROCESSING RECORD #35 OF SET 11 FOR CITY, inebolu.
#
# PROCESSING RECORD #36 OF SET 11 FOR CITY, seydi.
#
# PROCESSING RECORD #37 OF SET 11 FOR CITY, nova sintra.
#
# PROCESSING RECORD #38 OF SET 11 FOR CITY, odienne.
#
# PROCESSING RECORD #39 OF SET 11 FOR CITY, siocon.
#
# PROCESSING RECORD #40 OF SET 11 FOR CITY, peniche.
#
# PROCESSING RECORD #41 OF SET 11 FOR CITY, broken hill.
#
# PROCESSING RECORD #42 OF SET 11 FOR CITY, lospalos.
#
# PROCESSING RECORD #43 OF SET 11 FOR CITY, guanica.
#
# PROCESSING RECORD #44 OF SET 11 FOR CITY, aral.
#
# PROCESSING RECORD #45 OF SET 11 FOR CITY, toga village.
#
# The script did not find the city, toga village. Skipping...
#
# PROCESSING RECORD #46 OF SET 11 FOR CITY, gornji petrovci.
#
# PROCESSING RECORD #47 OF SET 11 FOR CITY, usogorsk.
#
# PROCESSING RECORD #48 OF SET 11 FOR CITY, iquique.
#
# PROCESSING RECORD #49 OF SET 11 FOR CITY, boende.
#
# PROCESSING RECORD #50 OF SET 11 FOR CITY, ares.
#
# PROCESSING RECORD #1 OF SET 12 FOR CITY, agadez.
#
# PROCESSING RECORD #2 OF SET 12 FOR CITY, harper.
#
# PROCESSING RECORD #3 OF SET 12 FOR CITY, bouarfa.
#
# PROCESSING RECORD #4 OF SET 12 FOR CITY, port augusta.
#
# PROCESSING RECORD #5 OF SET 12 FOR CITY, yemetsk.
#
# PROCESSING RECORD #6 OF SET 12 FOR CITY, kailua-kona.
#
# PROCESSING RECORD #7 OF SET 12 FOR CITY, fort mcmurray.
#
# PROCESSING RECORD #8 OF SET 12 FOR CITY, tympaki.
#
# PROCESSING RECORD #9 OF SET 12 FOR CITY, tamiahua.
#
# PROCESSING RECORD #10 OF SET 12 FOR CITY, auki.
#
# PROCESSING RECORD #11 OF SET 12 FOR CITY, wenchang.
#
# PROCESSING RECORD #12 OF SET 12 FOR CITY, girvan.
#
# PROCESSING RECORD #13 OF SET 12 FOR CITY, magadan.
#
# PROCESSING RECORD #14 OF SET 12 FOR CITY, kittila.
#
# PROCESSING RECORD #15 OF SET 12 FOR CITY, lenger.
#
# PROCESSING RECORD #16 OF SET 12 FOR CITY, jinchang.
#
# PROCESSING RECORD #17 OF SET 12 FOR CITY, bay point.
#
# PROCESSING RECORD #18 OF SET 12 FOR CITY, san gabriel.
#
# PROCESSING RECORD #19 OF SET 12 FOR CITY, thinadhoo.
#
# PROCESSING RECORD #20 OF SET 12 FOR CITY, choma.
#
# PROCESSING RECORD #21 OF SET 12 FOR CITY, sisteron.
#
# PROCESSING RECORD #22 OF SET 12 FOR CITY, brokopondo.
#
# PROCESSING RECORD #23 OF SET 12 FOR CITY, san agustin de valle fertil.
#
# PROCESSING RECORD #24 OF SET 12 FOR CITY, zorritos.
#
# PROCESSING RECORD #25 OF SET 12 FOR CITY, saint cloud.
#
# PROCESSING RECORD #26 OF SET 12 FOR CITY, guercif.
#
# PROCESSING RECORD #27 OF SET 12 FOR CITY, goianesia.
#
# PROCESSING RECORD #28 OF SET 12 FOR CITY, skovorodino.
#
# PROCESSING RECORD #29 OF SET 12 FOR CITY, dedza.
#
# PROCESSING RECORD #30 OF SET 12 FOR CITY, gamba.
#
# PROCESSING RECORD #31 OF SET 12 FOR CITY, veraval.
#
# PROCESSING RECORD #32 OF SET 12 FOR CITY, ulanhot.
#
# PROCESSING RECORD #33 OF SET 12 FOR CITY, zubtsov.
#
# PROCESSING RECORD #34 OF SET 12 FOR CITY, north haven.
#
# PROCESSING RECORD #35 OF SET 12 FOR CITY, santa maria.
#
# PROCESSING RECORD #36 OF SET 12 FOR CITY, aykhal.
#
# PROCESSING RECORD #37 OF SET 12 FOR CITY, al kharj.
#
# PROCESSING RECORD #38 OF SET 12 FOR CITY, karatuzskoye.
#
# PROCESSING RECORD #39 OF SET 12 FOR CITY, sotnikovskoye.
#
# PROCESSING RECORD #40 OF SET 12 FOR CITY, usinsk.
#
# PROCESSING RECORD #41 OF SET 12 FOR CITY, vicuna.
#
# PROCESSING RECORD #42 OF SET 12 FOR CITY, nhamunda.
#
# PROCESSING RECORD #43 OF SET 12 FOR CITY, exeter.
#
# PROCESSING RECORD #44 OF SET 12 FOR CITY, tinajo.
#
# PROCESSING RECORD #45 OF SET 12 FOR CITY, salekhard.
#
# PROCESSING RECORD #46 OF SET 12 FOR CITY, hongjiang.
# PROCESSING RECORD #47 OF SET 12 FOR CITY, mafinga.
#
# PROCESSING RECORD #48 OF SET 12 FOR CITY, eldorado at santa fe.
#
# PROCESSING RECORD #49 OF SET 12 FOR CITY, arteche.
#
# PROCESSING RECORD #50 OF SET 12 FOR CITY, duncan town.
#
# The script did not find the city, duncan town. Skipping...
#
# Data Retrieval for city weather DataFrame is complete.

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Records Count**

# %%
cityWeatherCountIntegerVariable \
    = cityWeatherDataFrame \
        ['City'] \
            .count()

print \
    (f"There are {cityWeatherCountIntegerVariable} " \
     + f"records in the city weather DataFrame.")
# Out:
# There are 576 records in the city weather DataFrame.

# %% [markdown]
# ### **Display City Weather DataFrame**

# %%
captionString \
    = 'Table: 1.1.1: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_a5284 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_a5284_row0_col0, #T_a5284_row0_col1, #T_a5284_row0_col2, #T_a5284_row0_col3, #T_a5284_row0_col4, #T_a5284_row0_col5, #T_a5284_row0_col7, #T_a5284_row0_col8, #T_a5284_row1_col0, #T_a5284_row1_col1, #T_a5284_row1_col2, #T_a5284_row1_col4, #T_a5284_row1_col6, #T_a5284_row1_col7, #T_a5284_row1_col8, #T_a5284_row2_col0, #T_a5284_row2_col1, #T_a5284_row2_col2, #T_a5284_row2_col3, #T_a5284_row2_col4, #T_a5284_row2_col6, #T_a5284_row2_col7, #T_a5284_row2_col8, #T_a5284_row3_col0, #T_a5284_row3_col1, #T_a5284_row3_col2, #T_a5284_row3_col3, #T_a5284_row3_col4, #T_a5284_row3_col5, #T_a5284_row3_col6, #T_a5284_row3_col7, #T_a5284_row3_col8, #T_a5284_row4_col0, #T_a5284_row4_col1, #T_a5284_row4_col2, #T_a5284_row4_col3, #T_a5284_row4_col4, #T_a5284_row4_col5, #T_a5284_row4_col6, #T_a5284_row4_col7, #T_a5284_row4_col8, #T_a5284_row5_col0, #T_a5284_row5_col1, #T_a5284_row5_col2, #T_a5284_row5_col5, #T_a5284_row5_col6, #T_a5284_row5_col7, #T_a5284_row5_col8, #T_a5284_row6_col0, #T_a5284_row6_col1, #T_a5284_row6_col2, #T_a5284_row6_col3, #T_a5284_row6_col4, #T_a5284_row6_col5, #T_a5284_row6_col6, #T_a5284_row6_col7, #T_a5284_row6_col8, #T_a5284_row7_col0, #T_a5284_row7_col1, #T_a5284_row7_col2, #T_a5284_row7_col3, #T_a5284_row7_col6, #T_a5284_row7_col7, #T_a5284_row7_col8, #T_a5284_row8_col0, #T_a5284_row8_col1, #T_a5284_row8_col2, #T_a5284_row8_col3, #T_a5284_row8_col4, #T_a5284_row8_col7, #T_a5284_row8_col8, #T_a5284_row9_col0, #T_a5284_row9_col1, #T_a5284_row9_col2, #T_a5284_row9_col3, #T_a5284_row9_col4, #T_a5284_row9_col6, #T_a5284_row9_col7, #T_a5284_row9_col8, #T_a5284_row10_col0, #T_a5284_row10_col1, #T_a5284_row10_col2, #T_a5284_row10_col3, #T_a5284_row10_col5, #T_a5284_row10_col6, #T_a5284_row10_col7, #T_a5284_row10_col8, #T_a5284_row11_col0, #T_a5284_row11_col1, #T_a5284_row11_col2, #T_a5284_row11_col3, #T_a5284_row11_col4, #T_a5284_row11_col5, #T_a5284_row11_col6, #T_a5284_row11_col7, #T_a5284_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_a5284_row0_col6, #T_a5284_row2_col5, #T_a5284_row5_col3, #T_a5284_row7_col5, #T_a5284_row9_col5, #T_a5284_row10_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_a5284_row1_col3, #T_a5284_row1_col5, #T_a5284_row5_col4, #T_a5284_row7_col4, #T_a5284_row8_col5, #T_a5284_row8_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_a5284">
#   <caption>Table: 1.1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_a5284_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_a5284_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_a5284_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_a5284_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_a5284_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_a5284_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_a5284_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_a5284_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_a5284_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a5284_row0_col0" class="data row0 col0" >bondo</td>
#       <td id="T_a5284_row0_col1" class="data row0 col1" >3.81</td>
#       <td id="T_a5284_row0_col2" class="data row0 col2" >23.69</td>
#       <td id="T_a5284_row0_col3" class="data row0 col3" >70.16° F</td>
#       <td id="T_a5284_row0_col4" class="data row0 col4" >99%</td>
#       <td id="T_a5284_row0_col5" class="data row0 col5" >87%</td>
#       <td id="T_a5284_row0_col6" class="data row0 col6" >1.57</td>
#       <td id="T_a5284_row0_col7" class="data row0 col7" >CD</td>
#       <td id="T_a5284_row0_col8" class="data row0 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_a5284_row1_col0" class="data row1 col0" >uribia</td>
#       <td id="T_a5284_row1_col1" class="data row1 col1" >11.71</td>
#       <td id="T_a5284_row1_col2" class="data row1 col2" >-72.27</td>
#       <td id="T_a5284_row1_col3" class="data row1 col3" >84.61° F</td>
#       <td id="T_a5284_row1_col4" class="data row1 col4" >71%</td>
#       <td id="T_a5284_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_a5284_row1_col6" class="data row1 col6" >5.41</td>
#       <td id="T_a5284_row1_col7" class="data row1 col7" >CO</td>
#       <td id="T_a5284_row1_col8" class="data row1 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_a5284_row2_col0" class="data row2 col0" >saldanha</td>
#       <td id="T_a5284_row2_col1" class="data row2 col1" >-33.01</td>
#       <td id="T_a5284_row2_col2" class="data row2 col2" >17.94</td>
#       <td id="T_a5284_row2_col3" class="data row2 col3" >42.85° F</td>
#       <td id="T_a5284_row2_col4" class="data row2 col4" >77%</td>
#       <td id="T_a5284_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_a5284_row2_col6" class="data row2 col6" >11.86</td>
#       <td id="T_a5284_row2_col7" class="data row2 col7" >ZA</td>
#       <td id="T_a5284_row2_col8" class="data row2 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_a5284_row3_col0" class="data row3 col0" >el calafate</td>
#       <td id="T_a5284_row3_col1" class="data row3 col1" >-50.34</td>
#       <td id="T_a5284_row3_col2" class="data row3 col2" >-72.28</td>
#       <td id="T_a5284_row3_col3" class="data row3 col3" >37.27° F</td>
#       <td id="T_a5284_row3_col4" class="data row3 col4" >70%</td>
#       <td id="T_a5284_row3_col5" class="data row3 col5" >18%</td>
#       <td id="T_a5284_row3_col6" class="data row3 col6" >3.38</td>
#       <td id="T_a5284_row3_col7" class="data row3 col7" >AR</td>
#       <td id="T_a5284_row3_col8" class="data row3 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_a5284_row4_col0" class="data row4 col0" >edinburgh of the seven seas</td>
#       <td id="T_a5284_row4_col1" class="data row4 col1" >-37.07</td>
#       <td id="T_a5284_row4_col2" class="data row4 col2" >-12.31</td>
#       <td id="T_a5284_row4_col3" class="data row4 col3" >50.23° F</td>
#       <td id="T_a5284_row4_col4" class="data row4 col4" >69%</td>
#       <td id="T_a5284_row4_col5" class="data row4 col5" >92%</td>
#       <td id="T_a5284_row4_col6" class="data row4 col6" >30.85</td>
#       <td id="T_a5284_row4_col7" class="data row4 col7" >SH</td>
#       <td id="T_a5284_row4_col8" class="data row4 col8" >2023-09-30 21:28:12</td>
#     </tr>
#     <tr>
#       <td id="T_a5284_row5_col0" class="data row5 col0" >thompson</td>
#       <td id="T_a5284_row5_col1" class="data row5 col1" >55.74</td>
#       <td id="T_a5284_row5_col2" class="data row5 col2" >-97.86</td>
#       <td id="T_a5284_row5_col3" class="data row5 col3" >33.96° F</td>
#       <td id="T_a5284_row5_col4" class="data row5 col4" >100%</td>
#       <td id="T_a5284_row5_col5" class="data row5 col5" >75%</td>
#       <td id="T_a5284_row5_col6" class="data row5 col6" >2.30</td>
#       <td id="T_a5284_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_a5284_row5_col8" class="data row5 col8" >2023-09-30 21:26:07</td>
#     </tr>
#     <tr>
#       <td id="T_a5284_row6_col0" class="data row6 col0" >waitangi</td>
#       <td id="T_a5284_row6_col1" class="data row6 col1" >-43.95</td>
#       <td id="T_a5284_row6_col2" class="data row6 col2" >-176.56</td>
#       <td id="T_a5284_row6_col3" class="data row6 col3" >50.83° F</td>
#       <td id="T_a5284_row6_col4" class="data row6 col4" >79%</td>
#       <td id="T_a5284_row6_col5" class="data row6 col5" >22%</td>
#       <td id="T_a5284_row6_col6" class="data row6 col6" >11.01</td>
#       <td id="T_a5284_row6_col7" class="data row6 col7" >NZ</td>
#       <td id="T_a5284_row6_col8" class="data row6 col8" >2023-09-30 21:28:12</td>
#     </tr>
#     <tr>
#       <td id="T_a5284_r

# %% [markdown]
# ### **Data Export to CSV File**

# %%
subroutine \
    .WriteDataFrameToCSVFile \
        (cityWeatherDataFrame,
         local_constant \
             .WEATHER_DATA_FILE_PATH,
         local_constant \
             .WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Data Import from CSV File**

# %%
sampleCityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant \
                 .WEATHER_DATA_FILE_PATH,
             local_constant \
                 .WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Display Sample City Weather DataFrame**

# %%
captionString \
    = 'Table: 1.1.2: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_5f3d1 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_5f3d1_row0_col0, #T_5f3d1_row0_col1, #T_5f3d1_row0_col2, #T_5f3d1_row0_col3, #T_5f3d1_row0_col4, #T_5f3d1_row0_col5, #T_5f3d1_row0_col7, #T_5f3d1_row0_col8, #T_5f3d1_row1_col0, #T_5f3d1_row1_col1, #T_5f3d1_row1_col2, #T_5f3d1_row1_col4, #T_5f3d1_row1_col6, #T_5f3d1_row1_col7, #T_5f3d1_row1_col8, #T_5f3d1_row2_col0, #T_5f3d1_row2_col1, #T_5f3d1_row2_col2, #T_5f3d1_row2_col3, #T_5f3d1_row2_col4, #T_5f3d1_row2_col6, #T_5f3d1_row2_col7, #T_5f3d1_row2_col8, #T_5f3d1_row3_col0, #T_5f3d1_row3_col1, #T_5f3d1_row3_col2, #T_5f3d1_row3_col3, #T_5f3d1_row3_col4, #T_5f3d1_row3_col5, #T_5f3d1_row3_col6, #T_5f3d1_row3_col7, #T_5f3d1_row3_col8, #T_5f3d1_row4_col0, #T_5f3d1_row4_col1, #T_5f3d1_row4_col2, #T_5f3d1_row4_col3, #T_5f3d1_row4_col4, #T_5f3d1_row4_col5, #T_5f3d1_row4_col6, #T_5f3d1_row4_col7, #T_5f3d1_row4_col8, #T_5f3d1_row5_col0, #T_5f3d1_row5_col1, #T_5f3d1_row5_col2, #T_5f3d1_row5_col5, #T_5f3d1_row5_col6, #T_5f3d1_row5_col7, #T_5f3d1_row5_col8, #T_5f3d1_row6_col0, #T_5f3d1_row6_col1, #T_5f3d1_row6_col2, #T_5f3d1_row6_col3, #T_5f3d1_row6_col4, #T_5f3d1_row6_col5, #T_5f3d1_row6_col6, #T_5f3d1_row6_col7, #T_5f3d1_row6_col8, #T_5f3d1_row7_col0, #T_5f3d1_row7_col1, #T_5f3d1_row7_col2, #T_5f3d1_row7_col3, #T_5f3d1_row7_col6, #T_5f3d1_row7_col7, #T_5f3d1_row7_col8, #T_5f3d1_row8_col0, #T_5f3d1_row8_col1, #T_5f3d1_row8_col2, #T_5f3d1_row8_col3, #T_5f3d1_row8_col4, #T_5f3d1_row8_col7, #T_5f3d1_row8_col8, #T_5f3d1_row9_col0, #T_5f3d1_row9_col1, #T_5f3d1_row9_col2, #T_5f3d1_row9_col3, #T_5f3d1_row9_col4, #T_5f3d1_row9_col6, #T_5f3d1_row9_col7, #T_5f3d1_row9_col8, #T_5f3d1_row10_col0, #T_5f3d1_row10_col1, #T_5f3d1_row10_col2, #T_5f3d1_row10_col3, #T_5f3d1_row10_col5, #T_5f3d1_row10_col6, #T_5f3d1_row10_col7, #T_5f3d1_row10_col8, #T_5f3d1_row11_col0, #T_5f3d1_row11_col1, #T_5f3d1_row11_col2, #T_5f3d1_row11_col3, #T_5f3d1_row11_col4, #T_5f3d1_row11_col5, #T_5f3d1_row11_col6, #T_5f3d1_row11_col7, #T_5f3d1_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_5f3d1_row0_col6, #T_5f3d1_row2_col5, #T_5f3d1_row5_col3, #T_5f3d1_row7_col5, #T_5f3d1_row9_col5, #T_5f3d1_row10_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_5f3d1_row1_col3, #T_5f3d1_row1_col5, #T_5f3d1_row5_col4, #T_5f3d1_row7_col4, #T_5f3d1_row8_col5, #T_5f3d1_row8_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_5f3d1">
#   <caption>Table: 1.1.2: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_5f3d1_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_5f3d1_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_5f3d1_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_5f3d1_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_5f3d1_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_5f3d1_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_5f3d1_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_5f3d1_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_5f3d1_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f3d1_row0_col0" class="data row0 col0" >bondo</td>
#       <td id="T_5f3d1_row0_col1" class="data row0 col1" >3.81</td>
#       <td id="T_5f3d1_row0_col2" class="data row0 col2" >23.69</td>
#       <td id="T_5f3d1_row0_col3" class="data row0 col3" >70.16° F</td>
#       <td id="T_5f3d1_row0_col4" class="data row0 col4" >99%</td>
#       <td id="T_5f3d1_row0_col5" class="data row0 col5" >87%</td>
#       <td id="T_5f3d1_row0_col6" class="data row0 col6" >1.57</td>
#       <td id="T_5f3d1_row0_col7" class="data row0 col7" >CD</td>
#       <td id="T_5f3d1_row0_col8" class="data row0 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_5f3d1_row1_col0" class="data row1 col0" >uribia</td>
#       <td id="T_5f3d1_row1_col1" class="data row1 col1" >11.71</td>
#       <td id="T_5f3d1_row1_col2" class="data row1 col2" >-72.27</td>
#       <td id="T_5f3d1_row1_col3" class="data row1 col3" >84.61° F</td>
#       <td id="T_5f3d1_row1_col4" class="data row1 col4" >71%</td>
#       <td id="T_5f3d1_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_5f3d1_row1_col6" class="data row1 col6" >5.41</td>
#       <td id="T_5f3d1_row1_col7" class="data row1 col7" >CO</td>
#       <td id="T_5f3d1_row1_col8" class="data row1 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_5f3d1_row2_col0" class="data row2 col0" >saldanha</td>
#       <td id="T_5f3d1_row2_col1" class="data row2 col1" >-33.01</td>
#       <td id="T_5f3d1_row2_col2" class="data row2 col2" >17.94</td>
#       <td id="T_5f3d1_row2_col3" class="data row2 col3" >42.85° F</td>
#       <td id="T_5f3d1_row2_col4" class="data row2 col4" >77%</td>
#       <td id="T_5f3d1_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_5f3d1_row2_col6" class="data row2 col6" >11.86</td>
#       <td id="T_5f3d1_row2_col7" class="data row2 col7" >ZA</td>
#       <td id="T_5f3d1_row2_col8" class="data row2 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_5f3d1_row3_col0" class="data row3 col0" >el calafate</td>
#       <td id="T_5f3d1_row3_col1" class="data row3 col1" >-50.34</td>
#       <td id="T_5f3d1_row3_col2" class="data row3 col2" >-72.28</td>
#       <td id="T_5f3d1_row3_col3" class="data row3 col3" >37.27° F</td>
#       <td id="T_5f3d1_row3_col4" class="data row3 col4" >70%</td>
#       <td id="T_5f3d1_row3_col5" class="data row3 col5" >18%</td>
#       <td id="T_5f3d1_row3_col6" class="data row3 col6" >3.38</td>
#       <td id="T_5f3d1_row3_col7" class="data row3 col7" >AR</td>
#       <td id="T_5f3d1_row3_col8" class="data row3 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_5f3d1_row4_col0" class="data row4 col0" >edinburgh of the seven seas</td>
#       <td id="T_5f3d1_row4_col1" class="data row4 col1" >-37.07</td>
#       <td id="T_5f3d1_row4_col2" class="data row4 col2" >-12.31</td>
#       <td id="T_5f3d1_row4_col3" class="data row4 col3" >50.23° F</td>
#       <td id="T_5f3d1_row4_col4" class="data row4 col4" >69%</td>
#       <td id="T_5f3d1_row4_col5" class="data row4 col5" >92%</td>
#       <td id="T_5f3d1_row4_col6" class="data row4 col6" >30.85</td>
#       <td id="T_5f3d1_row4_col7" class="data row4 col7" >SH</td>
#       <td id="T_5f3d1_row4_col8" class="data row4 col8" >2023-09-30 21:28:12</td>
#     </tr>
#     <tr>
#       <td id="T_5f3d1_row5_col0" class="data row5 col0" >thompson</td>
#       <td id="T_5f3d1_row5_col1" class="data row5 col1" >55.74</td>
#       <td id="T_5f3d1_row5_col2" class="data row5 col2" >-97.86</td>
#       <td id="T_5f3d1_row5_col3" class="data row5 col3" >33.96° F</td>
#       <td id="T_5f3d1_row5_col4" class="data row5 col4" >100%</td>
#       <td id="T_5f3d1_row5_col5" class="data row5 col5" >75%</td>
#       <td id="T_5f3d1_row5_col6" class="data row5 col6" >2.30</td>
#       <td id="T_5f3d1_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_5f3d1_row5_col8" class="data row5 col8" >2023-09-30 21:26:07</td>
#     </tr>
#     <tr>
#       <td id="T_5f3d1_row6_col0" class="data row6 col0" >waitangi</td>
#       <td id="T_5f3d1_row6_col1" class="data row6 col1" >-43.95</td>
#       <td id="T_5f3d1_row6_col2" class="data row6 col2" >-176.56</td>
#       <td id="T_5f3d1_row6_col3" class="data row6 col3" >50.83° F</td>
#       <td id="T_5f3d1_row6_col4" class="data row6 col4" >79%</td>
#       <td id="T_5f3d1_row6_col5" class="data row6 col5" >22%</td>
#       <td id="T_5f3d1_row6_col6" class="data row6 col6" >11.01</td>
#       <td id="T_5f3d1_row6_col7" class="data row6 col7" >NZ</td>
#       <td id="T_5f3d1_row6_col8" class="data row6 col8" >2023-09-30 21:28:12</td>
#     </tr>
#     <tr>
#       <td id="T_5f3d1_r

# %% [markdown]
# ## **Section 1.2: Scatter Plots w/Regression**

# %% [markdown]
# ### **Temperature Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1: Temperature Vs. Latitude (Scatter Plot)')

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.2: Temperature Vs. Latitude (Scatter Plot w/Regression)', 
         2, -48.0, 28.0)
# Out:
# r-value:     0.8481
# r-squared:   0.7192

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### Although this assignment is about linear regression, I notice that the independent variable, latitude, has a relationship with the dependent variable, temperature, just not a linear one.  With linear regression, we obtain a -0.1346 correlation; with quadratic regression, the correlation increases to 0.7879.  In practiice, analysts consider a 0.60-0.79 correlation to be strong.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.2.3: Humidity Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Cloudiness Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.2.4: Cloudiness Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.2.5: Wind Speed vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **City Weather Information Correlation Matrix**

# %%
frameDictionary \
    = {'Latitude': cityWeatherDataFrame['Latitude'], 
       'Temperature': cityWeatherDataFrame['Temperature'], 
       'Humidity': cityWeatherDataFrame['Humidity'],
       'Cloudiness': cityWeatherDataFrame['Cloudiness'],
       'Wind Speed': cityWeatherDataFrame['Wind Speed']}


function \
    .ReturnCorrelationTableStandardFormat \
        (pd.DataFrame \
            (frameDictionary),
         'Table 1.2.1: City Weather Correlation Matrix')
# Out:
# <style type="text/css">
# #T_64145 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_64145_row0_col0, #T_64145_row0_col1, #T_64145_row0_col2, #T_64145_row0_col3, #T_64145_row0_col4, #T_64145_row1_col0, #T_64145_row1_col1, #T_64145_row1_col2, #T_64145_row1_col3, #T_64145_row1_col4, #T_64145_row2_col0, #T_64145_row2_col1, #T_64145_row2_col2, #T_64145_row2_col3, #T_64145_row2_col4, #T_64145_row3_col0, #T_64145_row3_col1, #T_64145_row3_col2, #T_64145_row3_col3, #T_64145_row3_col4, #T_64145_row4_col0, #T_64145_row4_col1, #T_64145_row4_col2, #T_64145_row4_col3, #T_64145_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_64145">
#   <caption>Table 1.2.1: City Weather Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64145_level0_col0" class="col_heading level0 col0" >Latitude</th>
#       <th id="T_64145_level0_col1" class="col_heading level0 col1" >Temperature</th>
#       <th id="T_64145_level0_col2" class="col_heading level0 col2" >Humidity</th>
#       <th id="T_64145_level0_col3" class="col_heading level0 col3" >Cloudiness</th>
#       <th id="T_64145_level0_col4" class="col_heading level0 col4" >Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64145_level0_row0" class="row_heading level0 row0" >Latitude</th>
#       <td id="T_64145_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_64145_row0_col1" class="data row0 col1" >-0.399770</td>
#       <td id="T_64145_row0_col2" class="data row0 col2" >0.122767</td>
#       <td id="T_64145_row0_col3" class="data row0 col3" >0.222382</td>
#       <td id="T_64145_row0_col4" class="data row0 col4" >-0.052768</td>
#     </tr>
#     <tr>
#       <th id="T_64145_level0_row1" class="row_heading level0 row1" >Temperature</th>
#       <td id="T_64145_row1_col0" class="data row1 col0" >-0.399770</td>
#       <td id="T_64145_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_64145_row1_col2" class="data row1 col2" >-0.252053</td>
#       <td id="T_64145_row1_col3" class="data row1 col3" >-0.060458</td>
#       <td id="T_64145_row1_col4" class="data row1 col4" >0.050196</td>
#     </tr>
#     <tr>
#       <th id="T_64145_level0_row2" class="row_heading level0 row2" >Humidity</th>
#       <td id="T_64145_row2_col0" class="data row2 col0" >0.122767</td>
#       <td id="T_64145_row2_col1" class="data row2 col1" >-0.252053</td>
#       <td id="T_64145_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_64145_row2_col3" class="data row2 col3" >0.374645</td>
#       <td id="T_64145_row2_col4" class="data row2 col4" >0.002613</td>
#     </tr>
#     <tr>
#       <th id="T_64145_level0_row3" class="row_heading level0 row3" >Cloudiness</th>
#       <td id="T_64145_row3_col0" class="data row3 col0" >0.222382</td>
#       <td id="T_64145_row3_col1" class="data row3 col1" >-0.060458</td>
#       <td id="T_64145_row3_col2" class="data row3 col2" >0.374645</td>
#       <td id="T_64145_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_64145_row3_col4" class="data row3 col4" >0.120400</td>
#     </tr>
#     <tr>
#       <th id="T_64145_level0_row4" class="row_heading level0 row4" >Wind Speed</th>
#       <td id="T_64145_row4_col0" class="data row4 col0" >-0.052768</td>
#       <td id="T_64145_row4_col1" class="data row4 col1" >0.050196</td>
#       <td id="T_64145_row4_col2" class="data row4 col2" >0.002613</td>
#       <td id="T_64145_row4_col3" class="data row4 col3" >0.120400</td>
#       <td id="T_64145_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Discussion about correlation:** YOUR RESPONSE HERE

# %% [markdown]
# ## **Section 1.3: Hemisphere Scatter Plots with Linear Regression**

# %% [markdown]
# ### **Northern Hemisphere City Weather Information**

# %%
northernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (northernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.1: City Weather Information (Northern Hemisphere)')
# Out:
# <style type="text/css">
# #T_51d4b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_51d4b_row0_col0, #T_51d4b_row0_col1, #T_51d4b_row0_col2, #T_51d4b_row0_col3, #T_51d4b_row0_col4, #T_51d4b_row0_col5, #T_51d4b_row0_col6, #T_51d4b_row0_col7, #T_51d4b_row0_col8, #T_51d4b_row1_col0, #T_51d4b_row1_col1, #T_51d4b_row1_col2, #T_51d4b_row1_col3, #T_51d4b_row1_col4, #T_51d4b_row1_col6, #T_51d4b_row1_col7, #T_51d4b_row1_col8, #T_51d4b_row2_col0, #T_51d4b_row2_col1, #T_51d4b_row2_col2, #T_51d4b_row2_col5, #T_51d4b_row2_col6, #T_51d4b_row2_col7, #T_51d4b_row2_col8, #T_51d4b_row3_col0, #T_51d4b_row3_col1, #T_51d4b_row3_col2, #T_51d4b_row3_col3, #T_51d4b_row3_col5, #T_51d4b_row3_col6, #T_51d4b_row3_col7, #T_51d4b_row3_col8, #T_51d4b_row4_col0, #T_51d4b_row4_col1, #T_51d4b_row4_col2, #T_51d4b_row4_col3, #T_51d4b_row4_col4, #T_51d4b_row4_col5, #T_51d4b_row4_col7, #T_51d4b_row4_col8, #T_51d4b_row5_col0, #T_51d4b_row5_col1, #T_51d4b_row5_col2, #T_51d4b_row5_col3, #T_51d4b_row5_col4, #T_51d4b_row5_col5, #T_51d4b_row5_col6, #T_51d4b_row5_col7, #T_51d4b_row5_col8, #T_51d4b_row6_col0, #T_51d4b_row6_col1, #T_51d4b_row6_col2, #T_51d4b_row6_col3, #T_51d4b_row6_col4, #T_51d4b_row6_col5, #T_51d4b_row6_col7, #T_51d4b_row6_col8, #T_51d4b_row7_col0, #T_51d4b_row7_col1, #T_51d4b_row7_col2, #T_51d4b_row7_col4, #T_51d4b_row7_col5, #T_51d4b_row7_col6, #T_51d4b_row7_col7, #T_51d4b_row7_col8, #T_51d4b_row8_col0, #T_51d4b_row8_col1, #T_51d4b_row8_col2, #T_51d4b_row8_col3, #T_51d4b_row8_col4, #T_51d4b_row8_col5, #T_51d4b_row8_col6, #T_51d4b_row8_col7, #T_51d4b_row8_col8, #T_51d4b_row9_col0, #T_51d4b_row9_col1, #T_51d4b_row9_col2, #T_51d4b_row9_col3, #T_51d4b_row9_col4, #T_51d4b_row9_col6, #T_51d4b_row9_col7, #T_51d4b_row9_col8, #T_51d4b_row10_col0, #T_51d4b_row10_col1, #T_51d4b_row10_col2, #T_51d4b_row10_col3, #T_51d4b_row10_col6, #T_51d4b_row10_col7, #T_51d4b_row10_col8, #T_51d4b_row11_col0, #T_51d4b_row11_col1, #T_51d4b_row11_col2, #T_51d4b_row11_col3, #T_51d4b_row11_col4, #T_51d4b_row11_col6, #T_51d4b_row11_col7, #T_51d4b_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_51d4b_row1_col5, #T_51d4b_row2_col4, #T_51d4b_row4_col6, #T_51d4b_row7_col3, #T_51d4b_row10_col4, #T_51d4b_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_51d4b_row2_col3, #T_51d4b_row3_col4, #T_51d4b_row6_col6, #T_51d4b_row9_col5, #T_51d4b_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_51d4b">
#   <caption>Table: 1.3.1: City Weather Information (Northern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_51d4b_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_51d4b_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_51d4b_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_51d4b_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_51d4b_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_51d4b_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_51d4b_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_51d4b_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_51d4b_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_51d4b_row0_col0" class="data row0 col0" >bondo</td>
#       <td id="T_51d4b_row0_col1" class="data row0 col1" >3.81</td>
#       <td id="T_51d4b_row0_col2" class="data row0 col2" >23.69</td>
#       <td id="T_51d4b_row0_col3" class="data row0 col3" >70.16° F</td>
#       <td id="T_51d4b_row0_col4" class="data row0 col4" >99%</td>
#       <td id="T_51d4b_row0_col5" class="data row0 col5" >87%</td>
#       <td id="T_51d4b_row0_col6" class="data row0 col6" >1.57</td>
#       <td id="T_51d4b_row0_col7" class="data row0 col7" >CD</td>
#       <td id="T_51d4b_row0_col8" class="data row0 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_51d4b_row1_col0" class="data row1 col0" >uribia</td>
#       <td id="T_51d4b_row1_col1" class="data row1 col1" >11.71</td>
#       <td id="T_51d4b_row1_col2" class="data row1 col2" >-72.27</td>
#       <td id="T_51d4b_row1_col3" class="data row1 col3" >84.61° F</td>
#       <td id="T_51d4b_row1_col4" class="data row1 col4" >71%</td>
#       <td id="T_51d4b_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_51d4b_row1_col6" class="data row1 col6" >5.41</td>
#       <td id="T_51d4b_row1_col7" class="data row1 col7" >CO</td>
#       <td id="T_51d4b_row1_col8" class="data row1 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_51d4b_row2_col0" class="data row2 col0" >thompson</td>
#       <td id="T_51d4b_row2_col1" class="data row2 col1" >55.74</td>
#       <td id="T_51d4b_row2_col2" class="data row2 col2" >-97.86</td>
#       <td id="T_51d4b_row2_col3" class="data row2 col3" >33.96° F</td>
#       <td id="T_51d4b_row2_col4" class="data row2 col4" >100%</td>
#       <td id="T_51d4b_row2_col5" class="data row2 col5" >75%</td>
#       <td id="T_51d4b_row2_col6" class="data row2 col6" >2.30</td>
#       <td id="T_51d4b_row2_col7" class="data row2 col7" >CA</td>
#       <td id="T_51d4b_row2_col8" class="data row2 col8" >2023-09-30 21:26:07</td>
#     </tr>
#     <tr>
#       <td id="T_51d4b_row3_col0" class="data row3 col0" >susuman</td>
#       <td id="T_51d4b_row3_col1" class="data row3 col1" >62.78</td>
#       <td id="T_51d4b_row3_col2" class="data row3 col2" >148.17</td>
#       <td id="T_51d4b_row3_col3" class="data row3 col3" >35.91° F</td>
#       <td id="T_51d4b_row3_col4" class="data row3 col4" >52%</td>
#       <td id="T_51d4b_row3_col5" class="data row3 col5" >16%</td>
#       <td id="T_51d4b_row3_col6" class="data row3 col6" >3.18</td>
#       <td id="T_51d4b_row3_col7" class="data row3 col7" >RU</td>
#       <td id="T_51d4b_row3_col8" class="data row3 col8" >2023-09-30 21:28:13</td>
#     </tr>
#     <tr>
#       <td id="T_51d4b_row4_col0" class="data row4 col0" >hasaki</td>
#       <td id="T_51d4b_row4_col1" class="data row4 col1" >35.73</td>
#       <td id="T_51d4b_row4_col2" class="data row4 col2" >140.83</td>
#       <td id="T_51d4b_row4_col3" class="data row4 col3" >82.80° F</td>
#       <td id="T_51d4b_row4_col4" class="data row4 col4" >70%</td>
#       <td id="T_51d4b_row4_col5" class="data row4 col5" >53%</td>
#       <td id="T_51d4b_row4_col6" class="data row4 col6" >18.72</td>
#       <td id="T_51d4b_row4_col7" class="data row4 col7" >JP</td>
#       <td id="T_51d4b_row4_col8" class="data row4 col8" >2023-09-30 21:28:13</td>
#     </tr>
#     <tr>
#       <td id="T_51d4b_row5_col0" class="data row5 col0" >chibougamau</td>
#       <td id="T_51d4b_row5_col1" class="data row5 col1" >49.92</td>
#       <td id="T_51d4b_row5_col2" class="data row5 col2" >-74.37</td>
#       <td id="T_51d4b_row5_col3" class="data row5 col3" >55.00° F</td>
#       <td id="T_51d4b_row5_col4" class="data row5 col4" >93%</td>
#       <td id="T_51d4b_row5_col5" class="data row5 col5" >76%</td>
#       <td id="T_51d4b_row5_col6" class="data row5 col6" >4.90</td>
#       <td id="T_51d4b_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_51d4b_row5_col8" class="data row5 col8" >2023-09-30 21:28:13</td>
#     </tr>
#     <tr>
#       <td id="T_51d4b_row6_col0" class="data row6 col0" >qaqortoq</td>
#       <td id="T_51d4b_row6_col1" class="data row6 col1" >60.72</td>
#       <td id="T_51d4b_row6_col2" class="data row6 col2" >-46.03</td>
#       <td id="T_51d4b_row6_col3" class="data row6 col3" >36.77° F</td>
#       <td id="T_51d4b_row6_col4" class="data row6 col4" >81%</td>
#       <td id="T_51d4b_row6_col5" class="data row6 col5" >80%</td>
#       <td id="T_51d4b_row6_col6" class="data row6 col6" >0.92</td>
#       <td id="T_51d4b_row6_col7" class="data row6 col7" >GL</td>
#       <td id="T_51d4b_row6_col8" class="data row6 col8" >2023-09-30 21:28:13</td>
#     </tr>
#     <tr>
#       <td id="T_51d4b_row7_c

# %% [markdown]
# ### **Southern Hemisphere City Weather Information**

# %%
southernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (southernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.2: City Weather Information (Southern Hemisphere)')
# Out:
# <style type="text/css">
# #T_b992e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b992e_row0_col0, #T_b992e_row0_col1, #T_b992e_row0_col2, #T_b992e_row0_col3, #T_b992e_row0_col4, #T_b992e_row0_col5, #T_b992e_row0_col6, #T_b992e_row0_col7, #T_b992e_row0_col8, #T_b992e_row1_col0, #T_b992e_row1_col1, #T_b992e_row1_col2, #T_b992e_row1_col3, #T_b992e_row1_col4, #T_b992e_row1_col6, #T_b992e_row1_col7, #T_b992e_row1_col8, #T_b992e_row2_col0, #T_b992e_row2_col1, #T_b992e_row2_col2, #T_b992e_row2_col5, #T_b992e_row2_col6, #T_b992e_row2_col7, #T_b992e_row2_col8, #T_b992e_row3_col0, #T_b992e_row3_col1, #T_b992e_row3_col2, #T_b992e_row3_col3, #T_b992e_row3_col5, #T_b992e_row3_col6, #T_b992e_row3_col7, #T_b992e_row3_col8, #T_b992e_row4_col0, #T_b992e_row4_col1, #T_b992e_row4_col2, #T_b992e_row4_col3, #T_b992e_row4_col4, #T_b992e_row4_col5, #T_b992e_row4_col7, #T_b992e_row4_col8, #T_b992e_row5_col0, #T_b992e_row5_col1, #T_b992e_row5_col2, #T_b992e_row5_col3, #T_b992e_row5_col4, #T_b992e_row5_col5, #T_b992e_row5_col6, #T_b992e_row5_col7, #T_b992e_row5_col8, #T_b992e_row6_col0, #T_b992e_row6_col1, #T_b992e_row6_col2, #T_b992e_row6_col3, #T_b992e_row6_col4, #T_b992e_row6_col5, #T_b992e_row6_col7, #T_b992e_row6_col8, #T_b992e_row7_col0, #T_b992e_row7_col1, #T_b992e_row7_col2, #T_b992e_row7_col4, #T_b992e_row7_col5, #T_b992e_row7_col6, #T_b992e_row7_col7, #T_b992e_row7_col8, #T_b992e_row8_col0, #T_b992e_row8_col1, #T_b992e_row8_col2, #T_b992e_row8_col3, #T_b992e_row8_col4, #T_b992e_row8_col5, #T_b992e_row8_col6, #T_b992e_row8_col7, #T_b992e_row8_col8, #T_b992e_row9_col0, #T_b992e_row9_col1, #T_b992e_row9_col2, #T_b992e_row9_col3, #T_b992e_row9_col4, #T_b992e_row9_col6, #T_b992e_row9_col7, #T_b992e_row9_col8, #T_b992e_row10_col0, #T_b992e_row10_col1, #T_b992e_row10_col2, #T_b992e_row10_col3, #T_b992e_row10_col6, #T_b992e_row10_col7, #T_b992e_row10_col8, #T_b992e_row11_col0, #T_b992e_row11_col1, #T_b992e_row11_col2, #T_b992e_row11_col3, #T_b992e_row11_col4, #T_b992e_row11_col6, #T_b992e_row11_col7, #T_b992e_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_b992e_row1_col5, #T_b992e_row2_col4, #T_b992e_row4_col6, #T_b992e_row7_col3, #T_b992e_row10_col4, #T_b992e_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_b992e_row2_col3, #T_b992e_row3_col4, #T_b992e_row6_col6, #T_b992e_row9_col5, #T_b992e_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_b992e">
#   <caption>Table: 1.3.2: City Weather Information (Southern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_b992e_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_b992e_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_b992e_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_b992e_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_b992e_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_b992e_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_b992e_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_b992e_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_b992e_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b992e_row0_col0" class="data row0 col0" >bondo</td>
#       <td id="T_b992e_row0_col1" class="data row0 col1" >3.81</td>
#       <td id="T_b992e_row0_col2" class="data row0 col2" >23.69</td>
#       <td id="T_b992e_row0_col3" class="data row0 col3" >70.16° F</td>
#       <td id="T_b992e_row0_col4" class="data row0 col4" >99%</td>
#       <td id="T_b992e_row0_col5" class="data row0 col5" >87%</td>
#       <td id="T_b992e_row0_col6" class="data row0 col6" >1.57</td>
#       <td id="T_b992e_row0_col7" class="data row0 col7" >CD</td>
#       <td id="T_b992e_row0_col8" class="data row0 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_b992e_row1_col0" class="data row1 col0" >uribia</td>
#       <td id="T_b992e_row1_col1" class="data row1 col1" >11.71</td>
#       <td id="T_b992e_row1_col2" class="data row1 col2" >-72.27</td>
#       <td id="T_b992e_row1_col3" class="data row1 col3" >84.61° F</td>
#       <td id="T_b992e_row1_col4" class="data row1 col4" >71%</td>
#       <td id="T_b992e_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_b992e_row1_col6" class="data row1 col6" >5.41</td>
#       <td id="T_b992e_row1_col7" class="data row1 col7" >CO</td>
#       <td id="T_b992e_row1_col8" class="data row1 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_b992e_row2_col0" class="data row2 col0" >thompson</td>
#       <td id="T_b992e_row2_col1" class="data row2 col1" >55.74</td>
#       <td id="T_b992e_row2_col2" class="data row2 col2" >-97.86</td>
#       <td id="T_b992e_row2_col3" class="data row2 col3" >33.96° F</td>
#       <td id="T_b992e_row2_col4" class="data row2 col4" >100%</td>
#       <td id="T_b992e_row2_col5" class="data row2 col5" >75%</td>
#       <td id="T_b992e_row2_col6" class="data row2 col6" >2.30</td>
#       <td id="T_b992e_row2_col7" class="data row2 col7" >CA</td>
#       <td id="T_b992e_row2_col8" class="data row2 col8" >2023-09-30 21:26:07</td>
#     </tr>
#     <tr>
#       <td id="T_b992e_row3_col0" class="data row3 col0" >susuman</td>
#       <td id="T_b992e_row3_col1" class="data row3 col1" >62.78</td>
#       <td id="T_b992e_row3_col2" class="data row3 col2" >148.17</td>
#       <td id="T_b992e_row3_col3" class="data row3 col3" >35.91° F</td>
#       <td id="T_b992e_row3_col4" class="data row3 col4" >52%</td>
#       <td id="T_b992e_row3_col5" class="data row3 col5" >16%</td>
#       <td id="T_b992e_row3_col6" class="data row3 col6" >3.18</td>
#       <td id="T_b992e_row3_col7" class="data row3 col7" >RU</td>
#       <td id="T_b992e_row3_col8" class="data row3 col8" >2023-09-30 21:28:13</td>
#     </tr>
#     <tr>
#       <td id="T_b992e_row4_col0" class="data row4 col0" >hasaki</td>
#       <td id="T_b992e_row4_col1" class="data row4 col1" >35.73</td>
#       <td id="T_b992e_row4_col2" class="data row4 col2" >140.83</td>
#       <td id="T_b992e_row4_col3" class="data row4 col3" >82.80° F</td>
#       <td id="T_b992e_row4_col4" class="data row4 col4" >70%</td>
#       <td id="T_b992e_row4_col5" class="data row4 col5" >53%</td>
#       <td id="T_b992e_row4_col6" class="data row4 col6" >18.72</td>
#       <td id="T_b992e_row4_col7" class="data row4 col7" >JP</td>
#       <td id="T_b992e_row4_col8" class="data row4 col8" >2023-09-30 21:28:13</td>
#     </tr>
#     <tr>
#       <td id="T_b992e_row5_col0" class="data row5 col0" >chibougamau</td>
#       <td id="T_b992e_row5_col1" class="data row5 col1" >49.92</td>
#       <td id="T_b992e_row5_col2" class="data row5 col2" >-74.37</td>
#       <td id="T_b992e_row5_col3" class="data row5 col3" >55.00° F</td>
#       <td id="T_b992e_row5_col4" class="data row5 col4" >93%</td>
#       <td id="T_b992e_row5_col5" class="data row5 col5" >76%</td>
#       <td id="T_b992e_row5_col6" class="data row5 col6" >4.90</td>
#       <td id="T_b992e_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_b992e_row5_col8" class="data row5 col8" >2023-09-30 21:28:13</td>
#     </tr>
#     <tr>
#       <td id="T_b992e_row6_col0" class="data row6 col0" >qaqortoq</td>
#       <td id="T_b992e_row6_col1" class="data row6 col1" >60.72</td>
#       <td id="T_b992e_row6_col2" class="data row6 col2" >-46.03</td>
#       <td id="T_b992e_row6_col3" class="data row6 col3" >36.77° F</td>
#       <td id="T_b992e_row6_col4" class="data row6 col4" >81%</td>
#       <td id="T_b992e_row6_col5" class="data row6 col5" >80%</td>
#       <td id="T_b992e_row6_col6" class="data row6 col6" >0.92</td>
#       <td id="T_b992e_row6_col7" class="data row6 col7" >GL</td>
#       <td id="T_b992e_row6_col8" class="data row6 col8" >2023-09-30 21:28:13</td>
#     </tr>
#     <tr>
#       <td id="T_b992e_row7_c

# %% [markdown]
# ### **Temperature vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.1: Temperature vs. Latitude (Northern Hemisphere)',
         1, 2.0, 45.0)
# Out:
# r-value:     -0.8772
# r-squared:   0.7695

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.2: Temperature vs. Latitude (Southern Hemisphere)',
         1, -55.0, 85.0)
# Out:
# r-value:     0.6852
# r-squared:   0.4695

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### From the results of the linear regression, in the northern hemisphere, the latitude is negatively correlated with temperature; this negative correlation tells us that the two variables move in opposite directions: as latitude increases, the temperature drops, and vice versa.  In the southern hemisphers, the latitude is positively correlated with temperature: this positive correlation tells us that the two variables move in the same direction: as latitude increases, the temperature increases.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.3: Humidity vs. Latitude (Northern Hemisphere)',
         1, 45.0, 18.0)
# Out:
# r-value:     0.0813
# r-squared:   0.0066

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.4: Humidity vs. Latitude (Southern Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     0.0708
# r-squared:   0.0050

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and humidity in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Cloudiness vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.5: Cloudiness vs. Latitude (Northern Hemisphere)',
         1, 16.0, 62.0)
# Out:
# r-value:     0.0626
# r-squared:   0.0039

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.6: Cloudiness vs. Latitude (Southern Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     0.1411
# r-squared:   0.0199

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and cloudiness in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.7: Wind Speed vs. Latitude (Northern Hemisphere)',
         1, 15.0, 22.0)
# Out:
# r-value:     0.1129
# r-squared:   0.0128

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.8: Wind Speed vs. Latitude (Southern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.1741
# r-squared:   0.0303

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and wind speed in either hemisphere.

# %%
#log_subroutine \
#    .EndProgramExecution()
