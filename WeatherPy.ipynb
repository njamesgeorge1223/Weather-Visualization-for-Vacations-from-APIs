# %% [markdown]
# # WeatherPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, WeatherPy.ipynb, uses a Python script to 
 #      visualize the weather of over 500 cities of varying distances from the equator. 
 #      The script uses the citipy Python library and the openWeatherMap API to create 
 #      a representative model of weather across cities.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubRoutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'WeatherPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('WeatherPy')

# %% [markdown]
# # <br> **Section 1: Weather Variables and Latitude**

# %% [markdown]
# ## **Section 1.1: Data Acquisition**

# %% [markdown]
# ### **List of Cities**

# %%
citiesListOfStrings \
    = api_function \
        .ReturnCitiesList()

# %% [markdown]
# ### **Weather Data from List of Cities**

# %%
cityWeatherDataFrame \
    = api_function \
        .ReturnWeatherDataFrame \
            (citiesListOfStrings)
# Out:
# DATA RETRIEVAL FOR CITY WEATHER DATAFRAME BEGINS...
#
#
# PROCESSING RECORD #2 OF SET 1 FOR CITY, kapuskasing.
#
# PROCESSING RECORD #3 OF SET 1 FOR CITY, salinopolis.
#
# PROCESSING RECORD #4 OF SET 1 FOR CITY, alofi.
#
# PROCESSING RECORD #5 OF SET 1 FOR CITY, port-aux-francais.
#
# PROCESSING RECORD #6 OF SET 1 FOR CITY, saipan.
#
# PROCESSING RECORD #7 OF SET 1 FOR CITY, ushuaia.
#
# PROCESSING RECORD #8 OF SET 1 FOR CITY, tazovsky.
#
# PROCESSING RECORD #9 OF SET 1 FOR CITY, waitangi.
#
# PROCESSING RECORD #10 OF SET 1 FOR CITY, lazaro cardenas.
#
# PROCESSING RECORD #11 OF SET 1 FOR CITY, ribeira grande.
#
# PROCESSING RECORD #12 OF SET 1 FOR CITY, invercargill.
#
# PROCESSING RECORD #13 OF SET 1 FOR CITY, grytviken.
#
# PROCESSING RECORD #14 OF SET 1 FOR CITY, nova vicosa.
#
# PROCESSING RECORD #15 OF SET 1 FOR CITY, albany.
#
# PROCESSING RECORD #16 OF SET 1 FOR CITY, blackmans bay.
#
# PROCESSING RECORD #17 OF SET 1 FOR CITY, taiohae.
#
# The script did not find the city, taiohae. Skipping...
#
# PROCESSING RECORD #18 OF SET 1 FOR CITY, qaqortoq.
#
# PROCESSING RECORD #19 OF SET 1 FOR CITY, wailua homesteads.
#
# PROCESSING RECORD #20 OF SET 1 FOR CITY, nouadhibou.
#
# PROCESSING RECORD #21 OF SET 1 FOR CITY, puerto natales.
#
# PROCESSING RECORD #22 OF SET 1 FOR CITY, mersa matruh.
#
# PROCESSING RECORD #23 OF SET 1 FOR CITY, papatowai.
#
# PROCESSING RECORD #24 OF SET 1 FOR CITY, kuta.
#
# PROCESSING RECORD #25 OF SET 1 FOR CITY, semey.
#
# PROCESSING RECORD #26 OF SET 1 FOR CITY, springwood.
#
# PROCESSING RECORD #27 OF SET 1 FOR CITY, hasaki.
#
# PROCESSING RECORD #28 OF SET 1 FOR CITY, margaret river.
#
# PROCESSING RECORD #29 OF SET 1 FOR CITY, sinabang.
#
# PROCESSING RECORD #30 OF SET 1 FOR CITY, saint-francois.
#
# PROCESSING RECORD #31 OF SET 1 FOR CITY, bethel.
#
# PROCESSING RECORD #32 OF SET 1 FOR CITY, isafjordur.
#
# PROCESSING RECORD #33 OF SET 1 FOR CITY, hermanus.
#
# PROCESSING RECORD #34 OF SET 1 FOR CITY, velikiy ustyug.
#
# PROCESSING RECORD #35 OF SET 1 FOR CITY, afaahiti.
#
# PROCESSING RECORD #36 OF SET 1 FOR CITY, urumqi.
#
# PROCESSING RECORD #37 OF SET 1 FOR CITY, olyokminsk.
#
# PROCESSING RECORD #38 OF SET 1 FOR CITY, tiksi.
#
# PROCESSING RECORD #39 OF SET 1 FOR CITY, adamstown.
#
# PROCESSING RECORD #40 OF SET 1 FOR CITY, paungde.
#
# PROCESSING RECORD #41 OF SET 1 FOR CITY, chirilagua.
#
# PROCESSING RECORD #42 OF SET 1 FOR CITY, brandon.
#
# PROCESSING RECORD #43 OF SET 1 FOR CITY, kirakira.
#
# PROCESSING RECORD #44 OF SET 1 FOR CITY, stanley.
#
# PROCESSING RECORD #45 OF SET 1 FOR CITY, bargaal.
#
# PROCESSING RECORD #46 OF SET 1 FOR CITY, nizhnesortymskiy.
#
# PROCESSING RECORD #47 OF SET 1 FOR CITY, atafu village.
#
# PROCESSING RECORD #48 OF SET 1 FOR CITY, balrampur.
#
# PROCESSING RECORD #49 OF SET 1 FOR CITY, kavieng.
#
# PROCESSING RECORD #50 OF SET 1 FOR CITY, west island.
#
# PROCESSING RECORD #51 OF SET 1 FOR CITY, los frentones.
#
# PROCESSING RECORD #1 OF SET 2 FOR CITY, hawaiian paradise park.
#
# PROCESSING RECORD #2 OF SET 2 FOR CITY, georgetown.
#
# PROCESSING RECORD #3 OF SET 2 FOR CITY, udachny.
#
# PROCESSING RECORD #4 OF SET 2 FOR CITY, jamestown.
#
# PROCESSING RECORD #5 OF SET 2 FOR CITY, namibe.
#
# PROCESSING RECORD #6 OF SET 2 FOR CITY, ciudad lazaro cardenas.
#
# PROCESSING RECORD #7 OF SET 2 FOR CITY, edinburgh of the seven seas.
#
# PROCESSING RECORD #8 OF SET 2 FOR CITY, olonkinbyen.
#
# PROCESSING RECORD #9 OF SET 2 FOR CITY, puerto san carlos.
#
# The script did not find the city, puerto san carlos. Skipping...
#
# PROCESSING RECORD #10 OF SET 2 FOR CITY, mahriz.
#
# PROCESSING RECORD #11 OF SET 2 FOR CITY, la ronge.
#
# PROCESSING RECORD #12 OF SET 2 FOR CITY, la'ie.
#
# PROCESSING RECORD #13 OF SET 2 FOR CITY, oranjemund.
#
# PROCESSING RECORD #14 OF SET 2 FOR CITY, rafsanjan.
#
# PROCESSING RECORD #15 OF SET 2 FOR CITY, khandyga.
#
# PROCESSING RECORD #16 OF SET 2 FOR CITY, marsh harbour.
#
# PROCESSING RECORD #17 OF SET 2 FOR CITY, port mathurin.
#
# PROCESSING RECORD #18 OF SET 2 FOR CITY, fortuna.
#
# PROCESSING RECORD #19 OF SET 2 FOR CITY, hotan.
#
# PROCESSING RECORD #20 OF SET 2 FOR CITY, pacific grove.
#
# PROCESSING RECORD #21 OF SET 2 FOR CITY, arinos.
#
# PROCESSING RECORD #22 OF SET 2 FOR CITY, uturoa.
#
# PROCESSING RECORD #23 OF SET 2 FOR CITY, oroqen zizhiqi.
#
# PROCESSING RECORD #24 OF SET 2 FOR CITY, meadow lakes.
#
# PROCESSING RECORD #25 OF SET 2 FOR CITY, imbituva.
#
# PROCESSING RECORD #26 OF SET 2 FOR CITY, hamilton.
#
# PROCESSING RECORD #27 OF SET 2 FOR CITY, bilibino.
#
# PROCESSING RECORD #28 OF SET 2 FOR CITY, sambava.
#
# PROCESSING RECORD #29 OF SET 2 FOR CITY, kodiak.
#
# PROCESSING RECORD #30 OF SET 2 FOR CITY, sotnikovskoye.
#
# PROCESSING RECORD #31 OF SET 2 FOR CITY, imbituba.
#
# PROCESSING RECORD #32 OF SET 2 FOR CITY, lorengau.
#
# PROCESSING RECORD #33 OF SET 2 FOR CITY, itacare.
#
# PROCESSING RECORD #34 OF SET 2 FOR CITY, bandarbeyla.
#
# PROCESSING RECORD #35 OF SET 2 FOR CITY, tokar.
#
# PROCESSING RECORD #36 OF SET 2 FOR CITY, thompson.
#
# PROCESSING RECORD #37 OF SET 2 FOR CITY, haiku-pauwela.
#
# PROCESSING RECORD #38 OF SET 2 FOR CITY, makoua.
#
# PROCESSING RECORD #39 OF SET 2 FOR CITY, saldanha.
#
# PROCESSING RECORD #40 OF SET 2 FOR CITY, sabang.
#
# PROCESSING RECORD #41 OF SET 2 FOR CITY, iskateley.
#
# PROCESSING RECORD #42 OF SET 2 FOR CITY, whitehorse.
#
# PROCESSING RECORD #43 OF SET 2 FOR CITY, punta arenas.
#
# PROCESSING RECORD #44 OF SET 2 FOR CITY, riachao das neves.
#
# PROCESSING RECORD #45 OF SET 2 FOR CITY, tura.
#
# PROCESSING RECORD #46 OF SET 2 FOR CITY, porto novo.
#
# PROCESSING RECORD #47 OF SET 2 FOR CITY, muriti.
#
# PROCESSING RECORD #48 OF SET 2 FOR CITY, tshikapa.
#
# PROCESSING RECORD #49 OF SET 2 FOR CITY, inari.
#
# PROCESSING RECORD #50 OF SET 2 FOR CITY, puerto ayora.
#
# PROCESSING RECORD #1 OF SET 3 FOR CITY, karaton.
#
# PROCESSING RECORD #2 OF SET 3 FOR CITY, kayangel.
#
# PROCESSING RECORD #3 OF SET 3 FOR CITY, tshabong.
#
# PROCESSING RECORD #4 OF SET 3 FOR CITY, santa cruz.
#
# PROCESSING RECORD #5 OF SET 3 FOR CITY, pisco.
#
# PROCESSING RECORD #6 OF SET 3 FOR CITY, yellowknife.
#
# PROCESSING RECORD #7 OF SET 3 FOR CITY, port lincoln.
#
# PROCESSING RECORD #8 OF SET 3 FOR CITY, tidjikja.
#
# PROCESSING RECORD #9 OF SET 3 FOR CITY, borsa.
#
# PROCESSING RECORD #10 OF SET 3 FOR CITY, harnosand.
#
# PROCESSING RECORD #11 OF SET 3 FOR CITY, xinzhi.
#
# PROCESSING RECORD #12 OF SET 3 FOR CITY, bubaque.
#
# PROCESSING RECORD #13 OF SET 3 FOR CITY, yilan.
#
# PROCESSING RECORD #14 OF SET 3 FOR CITY, barcelos.
#
# PROCESSING RECORD #15 OF SET 3 FOR CITY, rensselaer.
#
# PROCESSING RECORD #16 OF SET 3 FOR CITY, thomasville.
#
# PROCESSING RECORD #17 OF SET 3 FOR CITY, hirara.
#
# PROCESSING RECORD #18 OF SET 3 FOR CITY, tara.
#
# PROCESSING RECORD #19 OF SET 3 FOR CITY, prince rupert.
#
# PROCESSING RECORD #20 OF SET 3 FOR CITY, tocopilla.
#
# PROCESSING RECORD #21 OF SET 3 FOR CITY, east ballina.
#
# PROCESSING RECORD #22 OF SET 3 FOR CITY, souillac.
#
# PROCESSING RECORD #23 OF SET 3 FOR CITY, enewetak.
#
# PROCESSING RECORD #24 OF SET 3 FOR CITY, kone.
#
# PROCESSING RECORD #25 OF SET 3 FOR CITY, badger.
#
# PROCESSING RECORD #26 OF SET 3 FOR CITY, sar-e pul.
#
# PROCESSING RECORD #27 OF SET 3 FOR CITY, nova sintra.
#
# PROCESSING RECORD #28 OF SET 3 FOR CITY, al qubbah.
#
# PROCESSING RECORD #29 OF SET 3 FOR CITY, vorgashor.
#
# PROCESSING RECORD #30 OF SET 3 FOR CITY, elliot lake.
#
# PROCESSING RECORD #31 OF SET 3 FOR CITY, lichtenburg.
#
# PROCESSING RECORD #32 OF SET 3 FOR CITY, rouissat.
#
# PROCESSING RECORD #33 OF SET 3 FOR CITY, aykhal.
#
# PROCESSING RECORD #34 OF SET 3 FOR CITY, utrik.
#
# PROCESSING RECORD #35 OF SET 3 FOR CITY, luderitz.
#
# PROCESSING RECORD #36 OF SET 3 FOR CITY, novyy urgal.
#
# PROCESSING RECORD #37 OF SET 3 FOR CITY, ilulissat.
#
# PROCESSING RECORD #38 OF SET 3 FOR CITY, san antonio de pale.
#
# PROCESSING RECORD #39 OF SET 3 FOR CITY, borshchiv.
#
# PROCESSING RECORD #40 OF SET 3 FOR CITY, kapa'a.
#
# PROCESSING RECORD #41 OF SET 3 FOR CITY, long beach.
#
# PROCESSING RECORD #42 OF SET 3 FOR CITY, bredasdorp.
#
# PROCESSING RECORD #43 OF SET 3 FOR CITY, yayladagi.
#
# PROCESSING RECORD #44 OF SET 3 FOR CITY, lebu.
#
# PROCESSING RECORD #45 OF SET 3 FOR CITY, vingt cinq.
#
# The script did not find the city, vingt cinq. Skipping...
#
# PROCESSING RECORD #46 OF SET 3 FOR CITY, nuuk.
#
# PROCESSING RECORD #47 OF SET 3 FOR CITY, severo-yeniseyskiy.
#
# PROCESSING RECORD #48 OF SET 3 FOR CITY, port hedland.
#
# PROCESSING RECORD #49 OF SET 3 FOR CITY, adler.
#
# PROCESSING RECORD #50 OF SET 3 FOR CITY, nemuro.
# PROCESSING RECORD #1 OF SET 4 FOR CITY, keflavik.
#
# PROCESSING RECORD #2 OF SET 4 FOR CITY, sfax.
#
# PROCESSING RECORD #3 OF SET 4 FOR CITY, vadso.
#
# PROCESSING RECORD #4 OF SET 4 FOR CITY, vila franca do campo.
#
# PROCESSING RECORD #5 OF SET 4 FOR CITY, isangel.
#
# PROCESSING RECORD #6 OF SET 4 FOR CITY, jacobina.
#
# PROCESSING RECORD #7 OF SET 4 FOR CITY, swakopmund.
#
# PROCESSING RECORD #8 OF SET 4 FOR CITY, page.
#
# PROCESSING RECORD #9 OF SET 4 FOR CITY, rosarito.
#
# PROCESSING RECORD #10 OF SET 4 FOR CITY, east london.
#
# PROCESSING RECORD #11 OF SET 4 FOR CITY, kaa-khem.
#
# PROCESSING RECORD #12 OF SET 4 FOR CITY, massawa.
#
# PROCESSING RECORD #13 OF SET 4 FOR CITY, stephenville.
#
# PROCESSING RECORD #14 OF SET 4 FOR CITY, petropavlovka.
#
# PROCESSING RECORD #15 OF SET 4 FOR CITY, itoman.
#
# PROCESSING RECORD #16 OF SET 4 FOR CITY, sola.
#
# PROCESSING RECORD #17 OF SET 4 FOR CITY, guerrero negro.
#
# PROCESSING RECORD #18 OF SET 4 FOR CITY, arraial do cabo.
#
# PROCESSING RECORD #19 OF SET 4 FOR CITY, gebeit.
#
# PROCESSING RECORD #20 OF SET 4 FOR CITY, tralee.
#
# PROCESSING RECORD #21 OF SET 4 FOR CITY, dukhan.
#
# PROCESSING RECORD #22 OF SET 4 FOR CITY, lobujya.
#
# PROCESSING RECORD #23 OF SET 4 FOR CITY, zinjibar.
#
# PROCESSING RECORD #24 OF SET 4 FOR CITY, banda aceh.
#
# PROCESSING RECORD #25 OF SET 4 FOR CITY, college.
#
# PROCESSING RECORD #26 OF SET 4 FOR CITY, mermoz boabab.
#
# PROCESSING RECORD #27 OF SET 4 FOR CITY, ciudad guayana.
#
# PROCESSING RECORD #28 OF SET 4 FOR CITY, ulanhot.
#
# PROCESSING RECORD #29 OF SET 4 FOR CITY, gutierrez zamora.
#
# PROCESSING RECORD #30 OF SET 4 FOR CITY, san jose village.
#
# The script did not find the city, san jose village. Skipping...
#
# PROCESSING RECORD #31 OF SET 4 FOR CITY, iqaluit.
#
# PROCESSING RECORD #32 OF SET 4 FOR CITY, akureyri.
#
# PROCESSING RECORD #33 OF SET 4 FOR CITY, dudinka.
#
# PROCESSING RECORD #34 OF SET 4 FOR CITY, andkhoy.
#
# PROCESSING RECORD #35 OF SET 4 FOR CITY, al-`ula.
#
# The script did not find the city, al-`ula. Skipping...
#
# PROCESSING RECORD #36 OF SET 4 FOR CITY, longyearbyen.
#
# PROCESSING RECORD #37 OF SET 4 FOR CITY, as sanad.
#
# PROCESSING RECORD #38 OF SET 4 FOR CITY, acarau.
#
# PROCESSING RECORD #39 OF SET 4 FOR CITY, el nido.
#
# PROCESSING RECORD #40 OF SET 4 FOR CITY, colonia.
#
# PROCESSING RECORD #41 OF SET 4 FOR CITY, petropavlovsk-kamchatsky.
#
# PROCESSING RECORD #42 OF SET 4 FOR CITY, lompoc.
#
# PROCESSING RECORD #43 OF SET 4 FOR CITY, manta.
#
# PROCESSING RECORD #44 OF SET 4 FOR CITY, aitape.
#
# PROCESSING RECORD #45 OF SET 4 FOR CITY, sakaraha.
#
# PROCESSING RECORD #46 OF SET 4 FOR CITY, kruisfontein.
#
# PROCESSING RECORD #47 OF SET 4 FOR CITY, nguigmi.
#
# PROCESSING RECORD #48 OF SET 4 FOR CITY, mgandu.
#
# PROCESSING RECORD #49 OF SET 4 FOR CITY, sao felix do xingu.
#
# PROCESSING RECORD #50 OF SET 4 FOR CITY, rio san juan.
#
# PROCESSING RECORD #1 OF SET 5 FOR CITY, grand falls-windsor.
#
# PROCESSING RECORD #2 OF SET 5 FOR CITY, alotau.
#
# The script did not find the city, alotau. Skipping...
#
# PROCESSING RECORD #3 OF SET 5 FOR CITY, bol.
#
# PROCESSING RECORD #4 OF SET 5 FOR CITY, fort bragg.
#
# PROCESSING RECORD #5 OF SET 5 FOR CITY, moundou.
#
# PROCESSING RECORD #6 OF SET 5 FOR CITY, timimoun.
#
# PROCESSING RECORD #7 OF SET 5 FOR CITY, talnakh.
#
# PROCESSING RECORD #8 OF SET 5 FOR CITY, kavaratti.
#
# PROCESSING RECORD #9 OF SET 5 FOR CITY, st. john's.
#
# PROCESSING RECORD #10 OF SET 5 FOR CITY, vilyuysk.
#
# PROCESSING RECORD #11 OF SET 5 FOR CITY, asau village.
#
# The script did not find the city, asau village. Skipping...
#
# PROCESSING RECORD #12 OF SET 5 FOR CITY, goundam.
#
# PROCESSING RECORD #13 OF SET 5 FOR CITY, port alfred.
#
# PROCESSING RECORD #14 OF SET 5 FOR CITY, wynyard.
#
# PROCESSING RECORD #15 OF SET 5 FOR CITY, fale old settlement.
#
# PROCESSING RECORD #16 OF SET 5 FOR CITY, port elizabeth.
#
# PROCESSING RECORD #17 OF SET 5 FOR CITY, junin.
#
# PROCESSING RECORD #18 OF SET 5 FOR CITY, choyr.
#
# PROCESSING RECORD #19 OF SET 5 FOR CITY, zaigrayevo.
#
# PROCESSING RECORD #20 OF SET 5 FOR CITY, san clemente del tuyu.
#
# PROCESSING RECORD #21 OF SET 5 FOR CITY, anadyr.
#
# PROCESSING RECORD #22 OF SET 5 FOR CITY, saint-philippe.
#
# PROCESSING RECORD #23 OF SET 5 FOR CITY, tinajo.
#
# PROCESSING RECORD #24 OF SET 5 FOR CITY, mil'kovo.
#
# PROCESSING RECORD #25 OF SET 5 FOR CITY, silao.
#
# PROCESSING RECORD #26 OF SET 5 FOR CITY, corpus christi.
#
# PROCESSING RECORD #27 OF SET 5 FOR CITY, carlsbad.
#
# PROCESSING RECORD #28 OF SET 5 FOR CITY, vurpar.
#
# PROCESSING RECORD #29 OF SET 5 FOR CITY, chemolgan.
#
# PROCESSING RECORD #30 OF SET 5 FOR CITY, kurmuk.
#
# PROCESSING RECORD #31 OF SET 5 FOR CITY, constantia.
#
# PROCESSING RECORD #32 OF SET 5 FOR CITY, buala.
#
# PROCESSING RECORD #33 OF SET 5 FOR CITY, tromso.
#
# PROCESSING RECORD #34 OF SET 5 FOR CITY, ancud.
#
# PROCESSING RECORD #35 OF SET 5 FOR CITY, yuzhno-kurilsk.
#
# PROCESSING RECORD #36 OF SET 5 FOR CITY, vranje.
#
# PROCESSING RECORD #37 OF SET 5 FOR CITY, dahab.
#
# PROCESSING RECORD #38 OF SET 5 FOR CITY, barra.
#
# PROCESSING RECORD #39 OF SET 5 FOR CITY, north bend.
#
# PROCESSING RECORD #40 OF SET 5 FOR CITY, klyuchi.
#
# PROCESSING RECORD #41 OF SET 5 FOR CITY, rongelap.
#
# PROCESSING RECORD #42 OF SET 5 FOR CITY, chonchi.
#
# PROCESSING RECORD #43 OF SET 5 FOR CITY, elko.
#
# PROCESSING RECORD #44 OF SET 5 FOR CITY, beas de segura.
#
# PROCESSING RECORD #45 OF SET 5 FOR CITY, xai-xai.
#
# PROCESSING RECORD #46 OF SET 5 FOR CITY, santiago de cao.
#
# PROCESSING RECORD #47 OF SET 5 FOR CITY, uhrichsville.
#
# PROCESSING RECORD #48 OF SET 5 FOR CITY, ust'-ordynskiy.
#
# PROCESSING RECORD #49 OF SET 5 FOR CITY, sao gabriel da cachoeira.
#
# PROCESSING RECORD #50 OF SET 5 FOR CITY, fuglafjordur.
#
# PROCESSING RECORD #1 OF SET 6 FOR CITY, mont-laurier.
#
# PROCESSING RECORD #2 OF SET 6 FOR CITY, kerikeri.
#
# PROCESSING RECORD #3 OF SET 6 FOR CITY, laguna.
#
# PROCESSING RECORD #4 OF SET 6 FOR CITY, mount isa.
#
# PROCESSING RECORD #5 OF SET 6 FOR CITY, morris.
#
# PROCESSING RECORD #6 OF SET 6 FOR CITY, basco.
#
# PROCESSING RECORD #7 OF SET 6 FOR CITY, gwanda.
#
# PROCESSING RECORD #8 OF SET 6 FOR CITY, bani walid.
#
# PROCESSING RECORD #9 OF SET 6 FOR CITY, grande prairie.
#
# PROCESSING RECORD #10 OF SET 6 FOR CITY, le pouliguen.
#
# PROCESSING RECORD #11 OF SET 6 FOR CITY, jales.
#
# PROCESSING RECORD #12 OF SET 6 FOR CITY, chon buri.
#
# PROCESSING RECORD #13 OF SET 6 FOR CITY, luganville.
#
# PROCESSING RECORD #14 OF SET 6 FOR CITY, kanniyakumari.
#
# PROCESSING RECORD #15 OF SET 6 FOR CITY, kingston.
#
# PROCESSING RECORD #16 OF SET 6 FOR CITY, cabo san lucas.
#
# PROCESSING RECORD #17 OF SET 6 FOR CITY, san patricio.
#
# PROCESSING RECORD #18 OF SET 6 FOR CITY, miles city.
#
# PROCESSING RECORD #19 OF SET 6 FOR CITY, susuman.
#
# PROCESSING RECORD #20 OF SET 6 FOR CITY, minas de marcona.
#
# PROCESSING RECORD #21 OF SET 6 FOR CITY, nizhniy ingash.
#
# PROCESSING RECORD #22 OF SET 6 FOR CITY, pandan.
#
# PROCESSING RECORD #23 OF SET 6 FOR CITY, carnarvon.
#
# PROCESSING RECORD #24 OF SET 6 FOR CITY, shakawe.
#
# PROCESSING RECORD #25 OF SET 6 FOR CITY, lere.
#
# PROCESSING RECORD #26 OF SET 6 FOR CITY, boa vista.
#
# PROCESSING RECORD #27 OF SET 6 FOR CITY, obo.
#
# PROCESSING RECORD #28 OF SET 6 FOR CITY, tongchuanshi.
#
# PROCESSING RECORD #29 OF SET 6 FOR CITY, morondava.
#
# PROCESSING RECORD #30 OF SET 6 FOR CITY, terrassa.
#
# PROCESSING RECORD #31 OF SET 6 FOR CITY, roxas.
#
# PROCESSING RECORD #32 OF SET 6 FOR CITY, slavsk.
#
# PROCESSING RECORD #33 OF SET 6 FOR CITY, aasiaat.
#
# PROCESSING RECORD #34 OF SET 6 FOR CITY, carutapera.
#
# PROCESSING RECORD #35 OF SET 6 FOR CITY, karema.
#
# PROCESSING RECORD #36 OF SET 6 FOR CITY, avarua.
#
# PROCESSING RECORD #37 OF SET 6 FOR CITY, mount pearl.
#
# PROCESSING RECORD #38 OF SET 6 FOR CITY, pangody.
#
# PROCESSING RECORD #39 OF SET 6 FOR CITY, shihezi.
#
# PROCESSING RECORD #40 OF SET 6 FOR CITY, changuinola.
#
# PROCESSING RECORD #41 OF SET 6 FOR CITY, diyarbakir.
#
# PROCESSING RECORD #42 OF SET 6 FOR CITY, gurupa.
#
# PROCESSING RECORD #43 OF SET 6 FOR CITY, santa ana.
#
# PROCESSING RECORD #44 OF SET 6 FOR CITY, mata-utu.
#
# PROCESSING RECORD #45 OF SET 6 FOR CITY, taman'.
#
# PROCESSING RECORD #46 OF SET 6 FOR CITY, 'ohonua.
#
# The script did not find the city, 'ohonua. Skipping...
#
# PROCESSING RECORD #47 OF SET 6 FOR CITY, tranovaho.
#
# The script did not find the city, tranovaho. Skipping...
#
# PROCESSING RECORD #48 OF SET 6 FOR CITY, argo.
#
# PROCESSING RECORD #49 OF SET 6 FOR CITY, miyanoura.
#
# The script did not find the city, miyanoura. Skipping...
#
# PROCESSING RECORD #50 OF SET 6 FOR CITY, sitka.
# PROCESSING RECORD #1 OF SET 7 FOR CITY, nema.
#
# PROCESSING RECORD #2 OF SET 7 FOR CITY, aqsay.
#
# PROCESSING RECORD #3 OF SET 7 FOR CITY, kiunga.
#
# PROCESSING RECORD #4 OF SET 7 FOR CITY, amga.
#
# PROCESSING RECORD #5 OF SET 7 FOR CITY, weno.
#
# PROCESSING RECORD #6 OF SET 7 FOR CITY, westport.
#
# PROCESSING RECORD #7 OF SET 7 FOR CITY, holualoa.
#
# PROCESSING RECORD #8 OF SET 7 FOR CITY, tobelo.
#
# PROCESSING RECORD #9 OF SET 7 FOR CITY, mapleton.
#
# PROCESSING RECORD #10 OF SET 7 FOR CITY, alice springs.
#
# PROCESSING RECORD #11 OF SET 7 FOR CITY, myitkyina.
#
# PROCESSING RECORD #12 OF SET 7 FOR CITY, trincomalee.
#
# PROCESSING RECORD #13 OF SET 7 FOR CITY, san lorenzo.
#
# PROCESSING RECORD #14 OF SET 7 FOR CITY, rusape.
#
# PROCESSING RECORD #15 OF SET 7 FOR CITY, jayapura.
#
# PROCESSING RECORD #16 OF SET 7 FOR CITY, huayacocotla.
#
# PROCESSING RECORD #17 OF SET 7 FOR CITY, katsuren-haebaru.
#
# PROCESSING RECORD #18 OF SET 7 FOR CITY, dul'durga.
#
# PROCESSING RECORD #19 OF SET 7 FOR CITY, campbellton.
#
# PROCESSING RECORD #20 OF SET 7 FOR CITY, lata.
#
# PROCESSING RECORD #21 OF SET 7 FOR CITY, la passe.
#
# PROCESSING RECORD #22 OF SET 7 FOR CITY, praia da vitoria.
#
# PROCESSING RECORD #23 OF SET 7 FOR CITY, geraldton.
#
# PROCESSING RECORD #24 OF SET 7 FOR CITY, chopda.
#
# PROCESSING RECORD #25 OF SET 7 FOR CITY, prokudskoye.
#
# PROCESSING RECORD #26 OF SET 7 FOR CITY, cabedelo.
#
# PROCESSING RECORD #27 OF SET 7 FOR CITY, moreira sales.
#
# PROCESSING RECORD #28 OF SET 7 FOR CITY, eyl.
#
# PROCESSING RECORD #29 OF SET 7 FOR CITY, klaksvik.
#
# PROCESSING RECORD #30 OF SET 7 FOR CITY, koungheul.
#
# PROCESSING RECORD #31 OF SET 7 FOR CITY, new norfolk.
#
# PROCESSING RECORD #32 OF SET 7 FOR CITY, saudarkrokur.
#
# PROCESSING RECORD #33 OF SET 7 FOR CITY, shchyolkino.
#
# PROCESSING RECORD #34 OF SET 7 FOR CITY, marudi.
#
# The script did not find the city, marudi. Skipping...
#
# PROCESSING RECORD #35 OF SET 7 FOR CITY, mandalgovi.
#
# PROCESSING RECORD #36 OF SET 7 FOR CITY, brezina.
#
# PROCESSING RECORD #37 OF SET 7 FOR CITY, touros.
#
# PROCESSING RECORD #38 OF SET 7 FOR CITY, cidreira.
#
# PROCESSING RECORD #39 OF SET 7 FOR CITY, puerto carreno.
#
# PROCESSING RECORD #40 OF SET 7 FOR CITY, ust-nera.
#
# PROCESSING RECORD #41 OF SET 7 FOR CITY, ighiu.
#
# PROCESSING RECORD #42 OF SET 7 FOR CITY, port-vila.
#
# PROCESSING RECORD #43 OF SET 7 FOR CITY, champerico.
#
# PROCESSING RECORD #44 OF SET 7 FOR CITY, island harbour.
#
# PROCESSING RECORD #45 OF SET 7 FOR CITY, la sarre.
#
# PROCESSING RECORD #46 OF SET 7 FOR CITY, emerald.
#
# PROCESSING RECORD #47 OF SET 7 FOR CITY, chicoana.
#
# PROCESSING RECORD #48 OF SET 7 FOR CITY, gargalianoi.
#
# PROCESSING RECORD #49 OF SET 7 FOR CITY, zarnesti.
#
# PROCESSING RECORD #50 OF SET 7 FOR CITY, happy valley-goose bay.
#
# PROCESSING RECORD #1 OF SET 8 FOR CITY, puerto leguizamo.
#
# PROCESSING RECORD #2 OF SET 8 FOR CITY, mataquescuintla.
#
# PROCESSING RECORD #3 OF SET 8 FOR CITY, guanambi.
#
# PROCESSING RECORD #4 OF SET 8 FOR CITY, mul.
#
# PROCESSING RECORD #5 OF SET 8 FOR CITY, port douglas.
#
# PROCESSING RECORD #6 OF SET 8 FOR CITY, ruidoso.
#
# PROCESSING RECORD #7 OF SET 8 FOR CITY, hithadhoo.
#
# PROCESSING RECORD #8 OF SET 8 FOR CITY, sisimiut.
#
# PROCESSING RECORD #9 OF SET 8 FOR CITY, coquimbo.
#
# PROCESSING RECORD #10 OF SET 8 FOR CITY, fuvahmulah.
#
# The script did not find the city, fuvahmulah. Skipping...
#
# PROCESSING RECORD #11 OF SET 8 FOR CITY, murwillumbah.
#
# PROCESSING RECORD #12 OF SET 8 FOR CITY, freeport.
#
# PROCESSING RECORD #13 OF SET 8 FOR CITY, san andres.
#
# PROCESSING RECORD #14 OF SET 8 FOR CITY, detroit lakes.
#
# PROCESSING RECORD #15 OF SET 8 FOR CITY, brookings.
#
# PROCESSING RECORD #16 OF SET 8 FOR CITY, bonnyville.
#
# PROCESSING RECORD #17 OF SET 8 FOR CITY, orkney.
#
# PROCESSING RECORD #18 OF SET 8 FOR CITY, dayr al 'asafir.
#
# The script did not find the city, dayr al 'asafir. Skipping...
#
# PROCESSING RECORD #19 OF SET 8 FOR CITY, tulun.
#
# PROCESSING RECORD #20 OF SET 8 FOR CITY, nili.
#
# PROCESSING RECORD #21 OF SET 8 FOR CITY, naze.
#
# PROCESSING RECORD #22 OF SET 8 FOR CITY, santa maria do para.
#
# PROCESSING RECORD #23 OF SET 8 FOR CITY, chu.
#
# PROCESSING RECORD #24 OF SET 8 FOR CITY, camacupa.
#
# PROCESSING RECORD #25 OF SET 8 FOR CITY, koscierzyna.
#
# PROCESSING RECORD #26 OF SET 8 FOR CITY, campos gerais.
#
# PROCESSING RECORD #27 OF SET 8 FOR CITY, yung shue wan.
#
# PROCESSING RECORD #28 OF SET 8 FOR CITY, newman.
#
# PROCESSING RECORD #29 OF SET 8 FOR CITY, genhe.
#
# PROCESSING RECORD #30 OF SET 8 FOR CITY, vilyuchinsk.
#
# PROCESSING RECORD #31 OF SET 8 FOR CITY, am djarass.
#
# The script did not find the city, am djarass. Skipping...
#
# PROCESSING RECORD #32 OF SET 8 FOR CITY, kristiansund.
#
# PROCESSING RECORD #33 OF SET 8 FOR CITY, ta`u.
#
# PROCESSING RECORD #34 OF SET 8 FOR CITY, trstenik.
#
# PROCESSING RECORD #35 OF SET 8 FOR CITY, g'uzor.
#
# PROCESSING RECORD #36 OF SET 8 FOR CITY, egilsstadir.
#
# PROCESSING RECORD #37 OF SET 8 FOR CITY, kachug.
#
# PROCESSING RECORD #38 OF SET 8 FOR CITY, gobabis.
#
# PROCESSING RECORD #39 OF SET 8 FOR CITY, es castell.
#
# PROCESSING RECORD #40 OF SET 8 FOR CITY, huarmey.
#
# PROCESSING RECORD #41 OF SET 8 FOR CITY, amarante do maranhao.
#
# PROCESSING RECORD #42 OF SET 8 FOR CITY, dalhart.
#
# PROCESSING RECORD #43 OF SET 8 FOR CITY, bac lieu.
#
# PROCESSING RECORD #44 OF SET 8 FOR CITY, sretensk.
#
# PROCESSING RECORD #45 OF SET 8 FOR CITY, callao.
#
# PROCESSING RECORD #46 OF SET 8 FOR CITY, mamit.
#
# PROCESSING RECORD #47 OF SET 8 FOR CITY, omagh.
#
# PROCESSING RECORD #48 OF SET 8 FOR CITY, tyuratam.
#
# PROCESSING RECORD #49 OF SET 8 FOR CITY, pathein.
#
# PROCESSING RECORD #50 OF SET 8 FOR CITY, bumba.
#
# PROCESSING RECORD #1 OF SET 9 FOR CITY, camalu.
#
# PROCESSING RECORD #2 OF SET 9 FOR CITY, sao joao da barra.
#
# PROCESSING RECORD #3 OF SET 9 FOR CITY, galle.
#
# PROCESSING RECORD #4 OF SET 9 FOR CITY, tamanrasset.
#
# PROCESSING RECORD #5 OF SET 9 FOR CITY, polavaram.
#
# The script did not find the city, polavaram. Skipping...
#
# PROCESSING RECORD #6 OF SET 9 FOR CITY, freetown.
#
# PROCESSING RECORD #7 OF SET 9 FOR CITY, khovd.
#
# PROCESSING RECORD #8 OF SET 9 FOR CITY, kudahuvadhoo.
#
# PROCESSING RECORD #9 OF SET 9 FOR CITY, bati.
#
# PROCESSING RECORD #10 OF SET 9 FOR CITY, neryungri.
#
# PROCESSING RECORD #11 OF SET 9 FOR CITY, dalandzadgad.
#
# PROCESSING RECORD #12 OF SET 9 FOR CITY, meulaboh.
#
# PROCESSING RECORD #13 OF SET 9 FOR CITY, chichawatni.
#
# PROCESSING RECORD #14 OF SET 9 FOR CITY, nerekhta.
#
# PROCESSING RECORD #15 OF SET 9 FOR CITY, crane.
#
# PROCESSING RECORD #16 OF SET 9 FOR CITY, merowe.
#
# PROCESSING RECORD #17 OF SET 9 FOR CITY, gadzhiyevo.
#
# PROCESSING RECORD #18 OF SET 9 FOR CITY, bodo.
#
# PROCESSING RECORD #19 OF SET 9 FOR CITY, mar del plata.
#
# PROCESSING RECORD #20 OF SET 9 FOR CITY, statesboro.
#
# PROCESSING RECORD #21 OF SET 9 FOR CITY, posto da mata.
#
# The script did not find the city, posto da mata. Skipping...
#
# PROCESSING RECORD #22 OF SET 9 FOR CITY, brantford.
#
# PROCESSING RECORD #23 OF SET 9 FOR CITY, labrador city.
#
# PROCESSING RECORD #24 OF SET 9 FOR CITY, scappoose.
#
# PROCESSING RECORD #25 OF SET 9 FOR CITY, horqueta.
#
# PROCESSING RECORD #26 OF SET 9 FOR CITY, harper.
#
# PROCESSING RECORD #27 OF SET 9 FOR CITY, tolanaro.
#
# PROCESSING RECORD #28 OF SET 9 FOR CITY, mejit.
#
# PROCESSING RECORD #29 OF SET 9 FOR CITY, rosetta.
#
# PROCESSING RECORD #30 OF SET 9 FOR CITY, lewiston orchards.
#
# PROCESSING RECORD #31 OF SET 9 FOR CITY, cartagena.
#
# PROCESSING RECORD #32 OF SET 9 FOR CITY, irymple.
#
# PROCESSING RECORD #33 OF SET 9 FOR CITY, puerto san jose.
#
# PROCESSING RECORD #34 OF SET 9 FOR CITY, aleysk.
#
# PROCESSING RECORD #35 OF SET 9 FOR CITY, puerto quijarro.
#
# PROCESSING RECORD #36 OF SET 9 FOR CITY, paita.
#
# PROCESSING RECORD #37 OF SET 9 FOR CITY, saryaghash.
#
# PROCESSING RECORD #38 OF SET 9 FOR CITY, ad dabbah.
#
# PROCESSING RECORD #39 OF SET 9 FOR CITY, santona.
#
# PROCESSING RECORD #40 OF SET 9 FOR CITY, ketchikan.
#
# PROCESSING RECORD #41 OF SET 9 FOR CITY, tashtagol.
#
# PROCESSING RECORD #42 OF SET 9 FOR CITY, sinjar.
#
# PROCESSING RECORD #43 OF SET 9 FOR CITY, chelak.
#
# PROCESSING RECORD #44 OF SET 9 FOR CITY, hovd.
#
# PROCESSING RECORD #45 OF SET 9 FOR CITY, varzea da palma.
#
# PROCESSING RECORD #46 OF SET 9 FOR CITY, sinjai.
#
# PROCESSING RECORD #47 OF SET 9 FOR CITY, dongargarh.
#
# PROCESSING RECORD #48 OF SET 9 FOR CITY, bardai.
#
# PROCESSING RECORD #49 OF SET 9 FOR CITY, baganga.
#
# PROCESSING RECORD #50 OF SET 9 FOR CITY, villa de reyes.
# PROCESSING RECORD #1 OF SET 10 FOR CITY, brak.
#
# PROCESSING RECORD #2 OF SET 10 FOR CITY, jinchang.
#
# PROCESSING RECORD #3 OF SET 10 FOR CITY, aldinga beach.
#
# PROCESSING RECORD #4 OF SET 10 FOR CITY, bridgewater.
#
# PROCESSING RECORD #5 OF SET 10 FOR CITY, remire-montjoly.
#
# PROCESSING RECORD #6 OF SET 10 FOR CITY, mahina.
#
# PROCESSING RECORD #7 OF SET 10 FOR CITY, morant bay.
#
# PROCESSING RECORD #8 OF SET 10 FOR CITY, al hudaydah.
#
# PROCESSING RECORD #9 OF SET 10 FOR CITY, valparaiso.
#
# PROCESSING RECORD #10 OF SET 10 FOR CITY, yagry.
#
# The script did not find the city, yagry. Skipping...
#
# PROCESSING RECORD #11 OF SET 10 FOR CITY, viligili.
#
# The script did not find the city, viligili. Skipping...
#
# PROCESSING RECORD #12 OF SET 10 FOR CITY, mana.
#
# PROCESSING RECORD #13 OF SET 10 FOR CITY, inirida.
#
# PROCESSING RECORD #14 OF SET 10 FOR CITY, shahrud.
#
# PROCESSING RECORD #15 OF SET 10 FOR CITY, aginskoye.
#
# PROCESSING RECORD #16 OF SET 10 FOR CITY, huruta.
#
# PROCESSING RECORD #17 OF SET 10 FOR CITY, dalnegorsk.
#
# PROCESSING RECORD #18 OF SET 10 FOR CITY, corralillo.
#
# PROCESSING RECORD #19 OF SET 10 FOR CITY, seguela.
#
# PROCESSING RECORD #20 OF SET 10 FOR CITY, dinguiraye.
#
# PROCESSING RECORD #21 OF SET 10 FOR CITY, les avirons.
#
# PROCESSING RECORD #22 OF SET 10 FOR CITY, santiago suchilquitongo.
#
# PROCESSING RECORD #23 OF SET 10 FOR CITY, saint-joseph.
#
# PROCESSING RECORD #24 OF SET 10 FOR CITY, general pico.
#
# PROCESSING RECORD #25 OF SET 10 FOR CITY, aral.
#
# PROCESSING RECORD #26 OF SET 10 FOR CITY, qarqaraly.
#
# PROCESSING RECORD #27 OF SET 10 FOR CITY, tarauaca.
#
# PROCESSING RECORD #28 OF SET 10 FOR CITY, camana.
#
# PROCESSING RECORD #29 OF SET 10 FOR CITY, ambodifotatra.
#
# PROCESSING RECORD #30 OF SET 10 FOR CITY, cam ranh.
#
# PROCESSING RECORD #31 OF SET 10 FOR CITY, lagoa da prata.
#
# PROCESSING RECORD #32 OF SET 10 FOR CITY, rio gallegos.
#
# PROCESSING RECORD #33 OF SET 10 FOR CITY, tsetserleg.
#
# PROCESSING RECORD #34 OF SET 10 FOR CITY, natal.
#
# PROCESSING RECORD #35 OF SET 10 FOR CITY, christchurch.
#
# PROCESSING RECORD #36 OF SET 10 FOR CITY, kendari.
#
# PROCESSING RECORD #37 OF SET 10 FOR CITY, san juan.
#
# PROCESSING RECORD #38 OF SET 10 FOR CITY, tazacorte.
#
# PROCESSING RECORD #39 OF SET 10 FOR CITY, mahenge.
#
# PROCESSING RECORD #40 OF SET 10 FOR CITY, taihecun.
#
# PROCESSING RECORD #41 OF SET 10 FOR CITY, rabaul.
#
# PROCESSING RECORD #42 OF SET 10 FOR CITY, achinsk.
#
# PROCESSING RECORD #43 OF SET 10 FOR CITY, bikenibeu village.
#
# PROCESSING RECORD #44 OF SET 10 FOR CITY, punta cardon.
#
# PROCESSING RECORD #45 OF SET 10 FOR CITY, antigonish.
#
# PROCESSING RECORD #46 OF SET 10 FOR CITY, bel ombre.
#
# PROCESSING RECORD #47 OF SET 10 FOR CITY, richards bay.
#
# PROCESSING RECORD #48 OF SET 10 FOR CITY, formosa do rio preto.
#
# PROCESSING RECORD #49 OF SET 10 FOR CITY, luau.
#
# PROCESSING RECORD #50 OF SET 10 FOR CITY, belomorsk.
#
# PROCESSING RECORD #1 OF SET 11 FOR CITY, sandnessjoen.
#
# PROCESSING RECORD #2 OF SET 11 FOR CITY, bengkulu.
#
# PROCESSING RECORD #3 OF SET 11 FOR CITY, yunguyo.
#
# PROCESSING RECORD #4 OF SET 11 FOR CITY, ibipeba.
#
# PROCESSING RECORD #5 OF SET 11 FOR CITY, hola.
#
# PROCESSING RECORD #6 OF SET 11 FOR CITY, oltinko'l.
#
# PROCESSING RECORD #7 OF SET 11 FOR CITY, alik ghund.
#
# PROCESSING RECORD #8 OF SET 11 FOR CITY, andergrove.
#
# PROCESSING RECORD #9 OF SET 11 FOR CITY, kosti.
#
# PROCESSING RECORD #10 OF SET 11 FOR CITY, vrangel'.
#
# PROCESSING RECORD #11 OF SET 11 FOR CITY, floro.
#
# PROCESSING RECORD #12 OF SET 11 FOR CITY, blandon.
#
# PROCESSING RECORD #13 OF SET 11 FOR CITY, bangkalan.
#
# PROCESSING RECORD #14 OF SET 11 FOR CITY, colditz.
#
# PROCESSING RECORD #15 OF SET 11 FOR CITY, askale.
#
# PROCESSING RECORD #16 OF SET 11 FOR CITY, trevelin.
#
# PROCESSING RECORD #17 OF SET 11 FOR CITY, vilhena.
#
# PROCESSING RECORD #18 OF SET 11 FOR CITY, safonovo.
#
# PROCESSING RECORD #19 OF SET 11 FOR CITY, peterhead.
#
# PROCESSING RECORD #20 OF SET 11 FOR CITY, sabha.
#
# PROCESSING RECORD #21 OF SET 11 FOR CITY, xinmin.
#
# PROCESSING RECORD #22 OF SET 11 FOR CITY, khanapur.
#
# PROCESSING RECORD #23 OF SET 11 FOR CITY, tianchang.
#
# PROCESSING RECORD #24 OF SET 11 FOR CITY, baker city.
#
# PROCESSING RECORD #25 OF SET 11 FOR CITY, barmer.
#
# PROCESSING RECORD #26 OF SET 11 FOR CITY, vorkuta.
#
# PROCESSING RECORD #27 OF SET 11 FOR CITY, popondetta.
#
# PROCESSING RECORD #28 OF SET 11 FOR CITY, caburan.
#
# PROCESSING RECORD #29 OF SET 11 FOR CITY, kanggye.
#
# PROCESSING RECORD #30 OF SET 11 FOR CITY, celica.
#
# PROCESSING RECORD #31 OF SET 11 FOR CITY, i-n-salah.
#
# PROCESSING RECORD #32 OF SET 11 FOR CITY, tres arroyos.
#
# PROCESSING RECORD #33 OF SET 11 FOR CITY, usinsk.
#
# PROCESSING RECORD #34 OF SET 11 FOR CITY, nago.
#
# PROCESSING RECORD #35 OF SET 11 FOR CITY, polyarnyy.
#
# PROCESSING RECORD #36 OF SET 11 FOR CITY, acapulco de juarez.
#
# PROCESSING RECORD #37 OF SET 11 FOR CITY, turgen.
#
# PROCESSING RECORD #38 OF SET 11 FOR CITY, montmorillon.
#
# PROCESSING RECORD #39 OF SET 11 FOR CITY, newberg.
#
# PROCESSING RECORD #40 OF SET 11 FOR CITY, flin flon.
#
# PROCESSING RECORD #41 OF SET 11 FOR CITY, papao.
#
# PROCESSING RECORD #42 OF SET 11 FOR CITY, sidrolandia.
#
# PROCESSING RECORD #43 OF SET 11 FOR CITY, salalah.
#
# PROCESSING RECORD #44 OF SET 11 FOR CITY, nakhon thai.
#
# PROCESSING RECORD #45 OF SET 11 FOR CITY, dunedin.
#
# PROCESSING RECORD #46 OF SET 11 FOR CITY, tucuma.
#
# PROCESSING RECORD #47 OF SET 11 FOR CITY, daru.
#
# PROCESSING RECORD #48 OF SET 11 FOR CITY, hashtrud.
#
# PROCESSING RECORD #49 OF SET 11 FOR CITY, kulhudhuffushi.
#
# PROCESSING RECORD #50 OF SET 11 FOR CITY, kuala terengganu.
#
# PROCESSING RECORD #1 OF SET 12 FOR CITY, omuthiya.
#
# The script did not find the city, omuthiya. Skipping...
#
# PROCESSING RECORD #2 OF SET 12 FOR CITY, corod.
#
# PROCESSING RECORD #3 OF SET 12 FOR CITY, magong.
#
# PROCESSING RECORD #4 OF SET 12 FOR CITY, ulsteinvik.
#
# PROCESSING RECORD #5 OF SET 12 FOR CITY, walvis bay.
#
# PROCESSING RECORD #6 OF SET 12 FOR CITY, paradip garh.
#
# PROCESSING RECORD #7 OF SET 12 FOR CITY, kindu.
#
# PROCESSING RECORD #8 OF SET 12 FOR CITY, xinyuan.
#
# PROCESSING RECORD #9 OF SET 12 FOR CITY, shingu.
#
# PROCESSING RECORD #10 OF SET 12 FOR CITY, undurkhaan.
#
# PROCESSING RECORD #11 OF SET 12 FOR CITY, vryburg.
#
# PROCESSING RECORD #12 OF SET 12 FOR CITY, fort st. john.
#
# PROCESSING RECORD #13 OF SET 12 FOR CITY, kalmunai.
#
# PROCESSING RECORD #14 OF SET 12 FOR CITY, el colorado.
#
# PROCESSING RECORD #15 OF SET 12 FOR CITY, matoury.
#
# PROCESSING RECORD #16 OF SET 12 FOR CITY, el calafate.
#
# PROCESSING RECORD #17 OF SET 12 FOR CITY, duba.
#
# PROCESSING RECORD #18 OF SET 12 FOR CITY, fortaleza.
#
# PROCESSING RECORD #19 OF SET 12 FOR CITY, portland.
#
# PROCESSING RECORD #20 OF SET 12 FOR CITY, forbes.
#
# PROCESSING RECORD #21 OF SET 12 FOR CITY, hayma'.
#
# The script did not find the city, hayma'. Skipping...
#
# PROCESSING RECORD #22 OF SET 12 FOR CITY, tsiombe.
#
# PROCESSING RECORD #23 OF SET 12 FOR CITY, san diego.
#
# PROCESSING RECORD #24 OF SET 12 FOR CITY, minzhu.
#
# PROCESSING RECORD #25 OF SET 12 FOR CITY, karratha.
#
# PROCESSING RECORD #26 OF SET 12 FOR CITY, mirriah.
#
# PROCESSING RECORD #27 OF SET 12 FOR CITY, beloyarskiy.
#
# PROCESSING RECORD #28 OF SET 12 FOR CITY, baise city.
#
# PROCESSING RECORD #29 OF SET 12 FOR CITY, broome.
#
# PROCESSING RECORD #30 OF SET 12 FOR CITY, londa.
#
# PROCESSING RECORD #31 OF SET 12 FOR CITY, port blair.
#
# PROCESSING RECORD #32 OF SET 12 FOR CITY, lihue.
#
# PROCESSING RECORD #33 OF SET 12 FOR CITY, kattivakkam.
#
# PROCESSING RECORD #34 OF SET 12 FOR CITY, moires.
#
# PROCESSING RECORD #35 OF SET 12 FOR CITY, eiguliai.
#
# PROCESSING RECORD #36 OF SET 12 FOR CITY, cumnock.
#
# PROCESSING RECORD #37 OF SET 12 FOR CITY, cargados carajos.
#
# The script did not find the city, cargados carajos. Skipping...
#
# PROCESSING RECORD #38 OF SET 12 FOR CITY, saint-denis.
#
# PROCESSING RECORD #39 OF SET 12 FOR CITY, kenitra.
#
# PROCESSING RECORD #40 OF SET 12 FOR CITY, zheleznogorsk-ilimskiy.
#
# PROCESSING RECORD #41 OF SET 12 FOR CITY, namtsy.
#
# PROCESSING RECORD #42 OF SET 12 FOR CITY, mhamid.
#
# PROCESSING RECORD #43 OF SET 12 FOR CITY, samokov.
#
# PROCESSING RECORD #44 OF SET 12 FOR CITY, karystos.
#
# PROCESSING RECORD #45 OF SET 12 FOR CITY, paracuru.
#
# PROCESSING RECORD #46 OF SET 12 FOR CITY, sujiatun.
#
# Data Retrieval for city weather DataFrame is complete.

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Records Count**

# %%
cityWeatherCountIntegerVariable \
    = cityWeatherDataFrame \
        ['City'] \
            .count()

print \
    (f"There are {cityWeatherCountIntegerVariable} " \
     + f"records in the city weather DataFrame.")
# Out:
# There are 575 records in the city weather DataFrame.

# %% [markdown]
# ### **Display City Weather DataFrame**

# %%
captionString \
    = 'Table: 1.1.1: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_08d76 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_08d76_row0_col0, #T_08d76_row0_col1, #T_08d76_row0_col2, #T_08d76_row0_col3, #T_08d76_row0_col4, #T_08d76_row0_col5, #T_08d76_row0_col7, #T_08d76_row0_col8, #T_08d76_row1_col0, #T_08d76_row1_col1, #T_08d76_row1_col2, #T_08d76_row1_col3, #T_08d76_row1_col4, #T_08d76_row1_col5, #T_08d76_row1_col6, #T_08d76_row1_col7, #T_08d76_row1_col8, #T_08d76_row2_col0, #T_08d76_row2_col1, #T_08d76_row2_col2, #T_08d76_row2_col3, #T_08d76_row2_col5, #T_08d76_row2_col6, #T_08d76_row2_col7, #T_08d76_row2_col8, #T_08d76_row3_col0, #T_08d76_row3_col1, #T_08d76_row3_col2, #T_08d76_row3_col3, #T_08d76_row3_col4, #T_08d76_row3_col5, #T_08d76_row3_col7, #T_08d76_row3_col8, #T_08d76_row4_col0, #T_08d76_row4_col1, #T_08d76_row4_col2, #T_08d76_row4_col4, #T_08d76_row4_col5, #T_08d76_row4_col6, #T_08d76_row4_col7, #T_08d76_row4_col8, #T_08d76_row5_col0, #T_08d76_row5_col1, #T_08d76_row5_col2, #T_08d76_row5_col3, #T_08d76_row5_col4, #T_08d76_row5_col5, #T_08d76_row5_col6, #T_08d76_row5_col7, #T_08d76_row5_col8, #T_08d76_row6_col0, #T_08d76_row6_col1, #T_08d76_row6_col2, #T_08d76_row6_col3, #T_08d76_row6_col4, #T_08d76_row6_col6, #T_08d76_row6_col7, #T_08d76_row6_col8, #T_08d76_row7_col0, #T_08d76_row7_col1, #T_08d76_row7_col2, #T_08d76_row7_col3, #T_08d76_row7_col6, #T_08d76_row7_col7, #T_08d76_row7_col8, #T_08d76_row8_col0, #T_08d76_row8_col1, #T_08d76_row8_col2, #T_08d76_row8_col3, #T_08d76_row8_col4, #T_08d76_row8_col5, #T_08d76_row8_col6, #T_08d76_row8_col7, #T_08d76_row8_col8, #T_08d76_row9_col0, #T_08d76_row9_col1, #T_08d76_row9_col2, #T_08d76_row9_col3, #T_08d76_row9_col4, #T_08d76_row9_col6, #T_08d76_row9_col7, #T_08d76_row9_col8, #T_08d76_row10_col0, #T_08d76_row10_col1, #T_08d76_row10_col2, #T_08d76_row10_col3, #T_08d76_row10_col4, #T_08d76_row10_col6, #T_08d76_row10_col7, #T_08d76_row10_col8, #T_08d76_row11_col0, #T_08d76_row11_col1, #T_08d76_row11_col2, #T_08d76_row11_col4, #T_08d76_row11_col5, #T_08d76_row11_col6, #T_08d76_row11_col7, #T_08d76_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_08d76_row0_col6, #T_08d76_row2_col4, #T_08d76_row7_col5, #T_08d76_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_08d76_row3_col6, #T_08d76_row4_col3, #T_08d76_row6_col5, #T_08d76_row7_col4, #T_08d76_row9_col5, #T_08d76_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_08d76">
#   <caption>Table: 1.1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_08d76_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_08d76_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_08d76_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_08d76_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_08d76_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_08d76_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_08d76_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_08d76_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_08d76_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_08d76_row0_col0" class="data row0 col0" >kapuskasing</td>
#       <td id="T_08d76_row0_col1" class="data row0 col1" >49.42</td>
#       <td id="T_08d76_row0_col2" class="data row0 col2" >-82.43</td>
#       <td id="T_08d76_row0_col3" class="data row0 col3" >57.20° F</td>
#       <td id="T_08d76_row0_col4" class="data row0 col4" >72%</td>
#       <td id="T_08d76_row0_col5" class="data row0 col5" >20%</td>
#       <td id="T_08d76_row0_col6" class="data row0 col6" >3.44</td>
#       <td id="T_08d76_row0_col7" class="data row0 col7" >CA</td>
#       <td id="T_08d76_row0_col8" class="data row0 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_08d76_row1_col0" class="data row1 col0" >salinopolis</td>
#       <td id="T_08d76_row1_col1" class="data row1 col1" >-0.61</td>
#       <td id="T_08d76_row1_col2" class="data row1 col2" >-47.36</td>
#       <td id="T_08d76_row1_col3" class="data row1 col3" >80.89° F</td>
#       <td id="T_08d76_row1_col4" class="data row1 col4" >76%</td>
#       <td id="T_08d76_row1_col5" class="data row1 col5" >3%</td>
#       <td id="T_08d76_row1_col6" class="data row1 col6" >12.24</td>
#       <td id="T_08d76_row1_col7" class="data row1 col7" >BR</td>
#       <td id="T_08d76_row1_col8" class="data row1 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_08d76_row2_col0" class="data row2 col0" >alofi</td>
#       <td id="T_08d76_row2_col1" class="data row2 col1" >-19.06</td>
#       <td id="T_08d76_row2_col2" class="data row2 col2" >-169.92</td>
#       <td id="T_08d76_row2_col3" class="data row2 col3" >78.69° F</td>
#       <td id="T_08d76_row2_col4" class="data row2 col4" >65%</td>
#       <td id="T_08d76_row2_col5" class="data row2 col5" >40%</td>
#       <td id="T_08d76_row2_col6" class="data row2 col6" >13.80</td>
#       <td id="T_08d76_row2_col7" class="data row2 col7" >NU</td>
#       <td id="T_08d76_row2_col8" class="data row2 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_08d76_row3_col0" class="data row3 col0" >port-aux-francais</td>
#       <td id="T_08d76_row3_col1" class="data row3 col1" >-49.35</td>
#       <td id="T_08d76_row3_col2" class="data row3 col2" >70.22</td>
#       <td id="T_08d76_row3_col3" class="data row3 col3" >35.19° F</td>
#       <td id="T_08d76_row3_col4" class="data row3 col4" >83%</td>
#       <td id="T_08d76_row3_col5" class="data row3 col5" >49%</td>
#       <td id="T_08d76_row3_col6" class="data row3 col6" >42.64</td>
#       <td id="T_08d76_row3_col7" class="data row3 col7" >TF</td>
#       <td id="T_08d76_row3_col8" class="data row3 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_08d76_row4_col0" class="data row4 col0" >saipan</td>
#       <td id="T_08d76_row4_col1" class="data row4 col1" >15.14</td>
#       <td id="T_08d76_row4_col2" class="data row4 col2" >145.70</td>
#       <td id="T_08d76_row4_col3" class="data row4 col3" >83.10° F</td>
#       <td id="T_08d76_row4_col4" class="data row4 col4" >89%</td>
#       <td id="T_08d76_row4_col5" class="data row4 col5" >40%</td>
#       <td id="T_08d76_row4_col6" class="data row4 col6" >6.91</td>
#       <td id="T_08d76_row4_col7" class="data row4 col7" >MP</td>
#       <td id="T_08d76_row4_col8" class="data row4 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_08d76_row5_col0" class="data row5 col0" >ushuaia</td>
#       <td id="T_08d76_row5_col1" class="data row5 col1" >-54.80</td>
#       <td id="T_08d76_row5_col2" class="data row5 col2" >-68.30</td>
#       <td id="T_08d76_row5_col3" class="data row5 col3" >37.06° F</td>
#       <td id="T_08d76_row5_col4" class="data row5 col4" >70%</td>
#       <td id="T_08d76_row5_col5" class="data row5 col5" >40%</td>
#       <td id="T_08d76_row5_col6" class="data row5 col6" >21.85</td>
#       <td id="T_08d76_row5_col7" class="data row5 col7" >AR</td>
#       <td id="T_08d76_row5_col8" class="data row5 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_08d76_row6_col0" class="data row6 col0" >tazovsky</td>
#       <td id="T_08d76_row6_col1" class="data row6 col1" >67.47</td>
#       <td id="T_08d76_row6_col2" class="data row6 col2" >78.70</td>
#       <td id="T_08d76_row6_col3" class="data row6 col3" >32.47° F</td>
#       <td id="T_08d76_row6_col4" class="data row6 col4" >75%</td>
#       <td id="T_08d76_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_08d76_row6_col6" class="data row6 col6" >12.84</td>
#       <td id="T_08d76_row6_col7" class="data row6 col7" >RU</td>
#       <td id="T_08d76_row6_col8" class="data row6 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_08d76_row7_col

# %% [markdown]
# ### **Data Export to CSV File**

# %%
subroutine \
    .WriteDataFrameToCSVFile \
        (cityWeatherDataFrame,
         local_constant.WEATHER_DATA_FILE_PATH,
         local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Data Import from CSV File**

# %%
sampleCityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Display Sample City Weather DataFrame**

# %%
captionString \
    = 'Table: 1.1.2: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_3eccc caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_3eccc_row0_col0, #T_3eccc_row0_col1, #T_3eccc_row0_col2, #T_3eccc_row0_col3, #T_3eccc_row0_col4, #T_3eccc_row0_col5, #T_3eccc_row0_col7, #T_3eccc_row0_col8, #T_3eccc_row1_col0, #T_3eccc_row1_col1, #T_3eccc_row1_col2, #T_3eccc_row1_col3, #T_3eccc_row1_col4, #T_3eccc_row1_col5, #T_3eccc_row1_col6, #T_3eccc_row1_col7, #T_3eccc_row1_col8, #T_3eccc_row2_col0, #T_3eccc_row2_col1, #T_3eccc_row2_col2, #T_3eccc_row2_col3, #T_3eccc_row2_col5, #T_3eccc_row2_col6, #T_3eccc_row2_col7, #T_3eccc_row2_col8, #T_3eccc_row3_col0, #T_3eccc_row3_col1, #T_3eccc_row3_col2, #T_3eccc_row3_col3, #T_3eccc_row3_col4, #T_3eccc_row3_col5, #T_3eccc_row3_col7, #T_3eccc_row3_col8, #T_3eccc_row4_col0, #T_3eccc_row4_col1, #T_3eccc_row4_col2, #T_3eccc_row4_col4, #T_3eccc_row4_col5, #T_3eccc_row4_col6, #T_3eccc_row4_col7, #T_3eccc_row4_col8, #T_3eccc_row5_col0, #T_3eccc_row5_col1, #T_3eccc_row5_col2, #T_3eccc_row5_col3, #T_3eccc_row5_col4, #T_3eccc_row5_col5, #T_3eccc_row5_col6, #T_3eccc_row5_col7, #T_3eccc_row5_col8, #T_3eccc_row6_col0, #T_3eccc_row6_col1, #T_3eccc_row6_col2, #T_3eccc_row6_col3, #T_3eccc_row6_col4, #T_3eccc_row6_col6, #T_3eccc_row6_col7, #T_3eccc_row6_col8, #T_3eccc_row7_col0, #T_3eccc_row7_col1, #T_3eccc_row7_col2, #T_3eccc_row7_col3, #T_3eccc_row7_col6, #T_3eccc_row7_col7, #T_3eccc_row7_col8, #T_3eccc_row8_col0, #T_3eccc_row8_col1, #T_3eccc_row8_col2, #T_3eccc_row8_col3, #T_3eccc_row8_col4, #T_3eccc_row8_col5, #T_3eccc_row8_col6, #T_3eccc_row8_col7, #T_3eccc_row8_col8, #T_3eccc_row9_col0, #T_3eccc_row9_col1, #T_3eccc_row9_col2, #T_3eccc_row9_col3, #T_3eccc_row9_col4, #T_3eccc_row9_col6, #T_3eccc_row9_col7, #T_3eccc_row9_col8, #T_3eccc_row10_col0, #T_3eccc_row10_col1, #T_3eccc_row10_col2, #T_3eccc_row10_col3, #T_3eccc_row10_col4, #T_3eccc_row10_col6, #T_3eccc_row10_col7, #T_3eccc_row10_col8, #T_3eccc_row11_col0, #T_3eccc_row11_col1, #T_3eccc_row11_col2, #T_3eccc_row11_col4, #T_3eccc_row11_col5, #T_3eccc_row11_col6, #T_3eccc_row11_col7, #T_3eccc_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_3eccc_row0_col6, #T_3eccc_row2_col4, #T_3eccc_row7_col5, #T_3eccc_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_3eccc_row3_col6, #T_3eccc_row4_col3, #T_3eccc_row6_col5, #T_3eccc_row7_col4, #T_3eccc_row9_col5, #T_3eccc_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_3eccc">
#   <caption>Table: 1.1.2: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_3eccc_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_3eccc_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_3eccc_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_3eccc_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_3eccc_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_3eccc_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_3eccc_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_3eccc_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_3eccc_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3eccc_row0_col0" class="data row0 col0" >kapuskasing</td>
#       <td id="T_3eccc_row0_col1" class="data row0 col1" >49.42</td>
#       <td id="T_3eccc_row0_col2" class="data row0 col2" >-82.43</td>
#       <td id="T_3eccc_row0_col3" class="data row0 col3" >57.20° F</td>
#       <td id="T_3eccc_row0_col4" class="data row0 col4" >72%</td>
#       <td id="T_3eccc_row0_col5" class="data row0 col5" >20%</td>
#       <td id="T_3eccc_row0_col6" class="data row0 col6" >3.44</td>
#       <td id="T_3eccc_row0_col7" class="data row0 col7" >CA</td>
#       <td id="T_3eccc_row0_col8" class="data row0 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_3eccc_row1_col0" class="data row1 col0" >salinopolis</td>
#       <td id="T_3eccc_row1_col1" class="data row1 col1" >-0.61</td>
#       <td id="T_3eccc_row1_col2" class="data row1 col2" >-47.36</td>
#       <td id="T_3eccc_row1_col3" class="data row1 col3" >80.89° F</td>
#       <td id="T_3eccc_row1_col4" class="data row1 col4" >76%</td>
#       <td id="T_3eccc_row1_col5" class="data row1 col5" >3%</td>
#       <td id="T_3eccc_row1_col6" class="data row1 col6" >12.24</td>
#       <td id="T_3eccc_row1_col7" class="data row1 col7" >BR</td>
#       <td id="T_3eccc_row1_col8" class="data row1 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_3eccc_row2_col0" class="data row2 col0" >alofi</td>
#       <td id="T_3eccc_row2_col1" class="data row2 col1" >-19.06</td>
#       <td id="T_3eccc_row2_col2" class="data row2 col2" >-169.92</td>
#       <td id="T_3eccc_row2_col3" class="data row2 col3" >78.69° F</td>
#       <td id="T_3eccc_row2_col4" class="data row2 col4" >65%</td>
#       <td id="T_3eccc_row2_col5" class="data row2 col5" >40%</td>
#       <td id="T_3eccc_row2_col6" class="data row2 col6" >13.80</td>
#       <td id="T_3eccc_row2_col7" class="data row2 col7" >NU</td>
#       <td id="T_3eccc_row2_col8" class="data row2 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_3eccc_row3_col0" class="data row3 col0" >port-aux-francais</td>
#       <td id="T_3eccc_row3_col1" class="data row3 col1" >-49.35</td>
#       <td id="T_3eccc_row3_col2" class="data row3 col2" >70.22</td>
#       <td id="T_3eccc_row3_col3" class="data row3 col3" >35.19° F</td>
#       <td id="T_3eccc_row3_col4" class="data row3 col4" >83%</td>
#       <td id="T_3eccc_row3_col5" class="data row3 col5" >49%</td>
#       <td id="T_3eccc_row3_col6" class="data row3 col6" >42.64</td>
#       <td id="T_3eccc_row3_col7" class="data row3 col7" >TF</td>
#       <td id="T_3eccc_row3_col8" class="data row3 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_3eccc_row4_col0" class="data row4 col0" >saipan</td>
#       <td id="T_3eccc_row4_col1" class="data row4 col1" >15.14</td>
#       <td id="T_3eccc_row4_col2" class="data row4 col2" >145.70</td>
#       <td id="T_3eccc_row4_col3" class="data row4 col3" >83.10° F</td>
#       <td id="T_3eccc_row4_col4" class="data row4 col4" >89%</td>
#       <td id="T_3eccc_row4_col5" class="data row4 col5" >40%</td>
#       <td id="T_3eccc_row4_col6" class="data row4 col6" >6.91</td>
#       <td id="T_3eccc_row4_col7" class="data row4 col7" >MP</td>
#       <td id="T_3eccc_row4_col8" class="data row4 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_3eccc_row5_col0" class="data row5 col0" >ushuaia</td>
#       <td id="T_3eccc_row5_col1" class="data row5 col1" >-54.80</td>
#       <td id="T_3eccc_row5_col2" class="data row5 col2" >-68.30</td>
#       <td id="T_3eccc_row5_col3" class="data row5 col3" >37.06° F</td>
#       <td id="T_3eccc_row5_col4" class="data row5 col4" >70%</td>
#       <td id="T_3eccc_row5_col5" class="data row5 col5" >40%</td>
#       <td id="T_3eccc_row5_col6" class="data row5 col6" >21.85</td>
#       <td id="T_3eccc_row5_col7" class="data row5 col7" >AR</td>
#       <td id="T_3eccc_row5_col8" class="data row5 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_3eccc_row6_col0" class="data row6 col0" >tazovsky</td>
#       <td id="T_3eccc_row6_col1" class="data row6 col1" >67.47</td>
#       <td id="T_3eccc_row6_col2" class="data row6 col2" >78.70</td>
#       <td id="T_3eccc_row6_col3" class="data row6 col3" >32.47° F</td>
#       <td id="T_3eccc_row6_col4" class="data row6 col4" >75%</td>
#       <td id="T_3eccc_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_3eccc_row6_col6" class="data row6 col6" >12.84</td>
#       <td id="T_3eccc_row6_col7" class="data row6 col7" >RU</td>
#       <td id="T_3eccc_row6_col8" class="data row6 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_3eccc_row7_col

# %% [markdown]
# ## **Section 1.2: Scatter Plots w/Regression**

# %% [markdown]
# ### **Temperature Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1: Temperature Vs. Latitude (Scatter Plot)')

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1.1: Temperature Vs. Latitude (Scatter Plot w/Regression)', 
         2, -48.0, 28.0)
# Out:
# r-value:     0.8242
# r-squared:   0.6792

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### Although this assignment is about linear regression, I notice that the independent variable, latitude, has a relationship with the dependent variable, temperature, just not a linear one.  With linear regression, we obtain a -0.1346 correlation; with quadratic regression, the correlation increases to 0.7879.  In practiice, analysts consider a 0.60-0.79 correlation to be strong.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.2.2: Humidity Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Cloudiness Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.2.3: Cloudiness Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.2.4: Wind Speed vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **City Weather Information Correlation Matrix**

# %%
frameDictionary \
    = {'Latitude': 
            cityWeatherDataFrame \
                ['Latitude'], 
       'Temperature': 
            cityWeatherDataFrame \
                ['Temperature'], 
       'Humidity': 
            cityWeatherDataFrame \
                ['Humidity'],
       'Cloudiness': 
            cityWeatherDataFrame \
                ['Cloudiness'],
       'Wind Speed':
            cityWeatherDataFrame \
                ['Wind Speed']}


function \
    .ReturnCorrelationTableStandardFormat \
        (pd \
             .DataFrame \
                 (frameDictionary),
         'Table 1.2.1: City Weather Correlation Matrix')
# Out:
# <style type="text/css">
# #T_9af55 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_9af55_row0_col0, #T_9af55_row0_col1, #T_9af55_row0_col2, #T_9af55_row0_col3, #T_9af55_row0_col4, #T_9af55_row1_col0, #T_9af55_row1_col1, #T_9af55_row1_col2, #T_9af55_row1_col3, #T_9af55_row1_col4, #T_9af55_row2_col0, #T_9af55_row2_col1, #T_9af55_row2_col2, #T_9af55_row2_col3, #T_9af55_row2_col4, #T_9af55_row3_col0, #T_9af55_row3_col1, #T_9af55_row3_col2, #T_9af55_row3_col3, #T_9af55_row3_col4, #T_9af55_row4_col0, #T_9af55_row4_col1, #T_9af55_row4_col2, #T_9af55_row4_col3, #T_9af55_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_9af55">
#   <caption>Table 1.2.1: City Weather Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9af55_level0_col0" class="col_heading level0 col0" >Latitude</th>
#       <th id="T_9af55_level0_col1" class="col_heading level0 col1" >Temperature</th>
#       <th id="T_9af55_level0_col2" class="col_heading level0 col2" >Humidity</th>
#       <th id="T_9af55_level0_col3" class="col_heading level0 col3" >Cloudiness</th>
#       <th id="T_9af55_level0_col4" class="col_heading level0 col4" >Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9af55_level0_row0" class="row_heading level0 row0" >Latitude</th>
#       <td id="T_9af55_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9af55_row0_col1" class="data row0 col1" >-0.398292</td>
#       <td id="T_9af55_row0_col2" class="data row0 col2" >0.087760</td>
#       <td id="T_9af55_row0_col3" class="data row0 col3" >0.092984</td>
#       <td id="T_9af55_row0_col4" class="data row0 col4" >-0.113829</td>
#     </tr>
#     <tr>
#       <th id="T_9af55_level0_row1" class="row_heading level0 row1" >Temperature</th>
#       <td id="T_9af55_row1_col0" class="data row1 col0" >-0.398292</td>
#       <td id="T_9af55_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9af55_row1_col2" class="data row1 col2" >-0.256836</td>
#       <td id="T_9af55_row1_col3" class="data row1 col3" >-0.151540</td>
#       <td id="T_9af55_row1_col4" class="data row1 col4" >-0.009328</td>
#     </tr>
#     <tr>
#       <th id="T_9af55_level0_row2" class="row_heading level0 row2" >Humidity</th>
#       <td id="T_9af55_row2_col0" class="data row2 col0" >0.087760</td>
#       <td id="T_9af55_row2_col1" class="data row2 col1" >-0.256836</td>
#       <td id="T_9af55_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9af55_row2_col3" class="data row2 col3" >0.408644</td>
#       <td id="T_9af55_row2_col4" class="data row2 col4" >0.026682</td>
#     </tr>
#     <tr>
#       <th id="T_9af55_level0_row3" class="row_heading level0 row3" >Cloudiness</th>
#       <td id="T_9af55_row3_col0" class="data row3 col0" >0.092984</td>
#       <td id="T_9af55_row3_col1" class="data row3 col1" >-0.151540</td>
#       <td id="T_9af55_row3_col2" class="data row3 col2" >0.408644</td>
#       <td id="T_9af55_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_9af55_row3_col4" class="data row3 col4" >0.090503</td>
#     </tr>
#     <tr>
#       <th id="T_9af55_level0_row4" class="row_heading level0 row4" >Wind Speed</th>
#       <td id="T_9af55_row4_col0" class="data row4 col0" >-0.113829</td>
#       <td id="T_9af55_row4_col1" class="data row4 col1" >-0.009328</td>
#       <td id="T_9af55_row4_col2" class="data row4 col2" >0.026682</td>
#       <td id="T_9af55_row4_col3" class="data row4 col3" >0.090503</td>
#       <td id="T_9af55_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Discussion about correlation:** YOUR RESPONSE HERE

# %% [markdown]
# ## **Section 1.3: Hemisphere Scatter Plots with Linear Regression**

# %% [markdown]
# ### **Northern Hemisphere City Weather Information**

# %%
northernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (northernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.1: City Weather Information (Northern Hemisphere)')
# Out:
# <style type="text/css">
# #T_a2f7a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_a2f7a_row0_col0, #T_a2f7a_row0_col1, #T_a2f7a_row0_col2, #T_a2f7a_row0_col3, #T_a2f7a_row0_col4, #T_a2f7a_row0_col5, #T_a2f7a_row0_col6, #T_a2f7a_row0_col7, #T_a2f7a_row0_col8, #T_a2f7a_row1_col0, #T_a2f7a_row1_col1, #T_a2f7a_row1_col2, #T_a2f7a_row1_col5, #T_a2f7a_row1_col6, #T_a2f7a_row1_col7, #T_a2f7a_row1_col8, #T_a2f7a_row2_col0, #T_a2f7a_row2_col1, #T_a2f7a_row2_col2, #T_a2f7a_row2_col4, #T_a2f7a_row2_col6, #T_a2f7a_row2_col7, #T_a2f7a_row2_col8, #T_a2f7a_row3_col0, #T_a2f7a_row3_col1, #T_a2f7a_row3_col2, #T_a2f7a_row3_col3, #T_a2f7a_row3_col4, #T_a2f7a_row3_col5, #T_a2f7a_row3_col6, #T_a2f7a_row3_col7, #T_a2f7a_row3_col8, #T_a2f7a_row4_col0, #T_a2f7a_row4_col1, #T_a2f7a_row4_col2, #T_a2f7a_row4_col3, #T_a2f7a_row4_col4, #T_a2f7a_row4_col6, #T_a2f7a_row4_col7, #T_a2f7a_row4_col8, #T_a2f7a_row5_col0, #T_a2f7a_row5_col1, #T_a2f7a_row5_col2, #T_a2f7a_row5_col3, #T_a2f7a_row5_col7, #T_a2f7a_row5_col8, #T_a2f7a_row6_col0, #T_a2f7a_row6_col1, #T_a2f7a_row6_col2, #T_a2f7a_row6_col3, #T_a2f7a_row6_col4, #T_a2f7a_row6_col6, #T_a2f7a_row6_col7, #T_a2f7a_row6_col8, #T_a2f7a_row7_col0, #T_a2f7a_row7_col1, #T_a2f7a_row7_col2, #T_a2f7a_row7_col3, #T_a2f7a_row7_col4, #T_a2f7a_row7_col6, #T_a2f7a_row7_col7, #T_a2f7a_row7_col8, #T_a2f7a_row8_col0, #T_a2f7a_row8_col1, #T_a2f7a_row8_col2, #T_a2f7a_row8_col3, #T_a2f7a_row8_col4, #T_a2f7a_row8_col7, #T_a2f7a_row8_col8, #T_a2f7a_row9_col0, #T_a2f7a_row9_col1, #T_a2f7a_row9_col2, #T_a2f7a_row9_col3, #T_a2f7a_row9_col4, #T_a2f7a_row9_col6, #T_a2f7a_row9_col7, #T_a2f7a_row9_col8, #T_a2f7a_row10_col0, #T_a2f7a_row10_col1, #T_a2f7a_row10_col2, #T_a2f7a_row10_col3, #T_a2f7a_row10_col6, #T_a2f7a_row10_col7, #T_a2f7a_row10_col8, #T_a2f7a_row11_col0, #T_a2f7a_row11_col1, #T_a2f7a_row11_col2, #T_a2f7a_row11_col3, #T_a2f7a_row11_col4, #T_a2f7a_row11_col5, #T_a2f7a_row11_col6, #T_a2f7a_row11_col7, #T_a2f7a_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_a2f7a_row1_col3, #T_a2f7a_row1_col4, #T_a2f7a_row2_col5, #T_a2f7a_row4_col5, #T_a2f7a_row5_col4, #T_a2f7a_row5_col5, #T_a2f7a_row8_col5, #T_a2f7a_row8_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_a2f7a_row2_col3, #T_a2f7a_row5_col6, #T_a2f7a_row6_col5, #T_a2f7a_row7_col5, #T_a2f7a_row9_col5, #T_a2f7a_row10_col4, #T_a2f7a_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_a2f7a">
#   <caption>Table: 1.3.1: City Weather Information (Northern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_a2f7a_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_a2f7a_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_a2f7a_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_a2f7a_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_a2f7a_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_a2f7a_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_a2f7a_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_a2f7a_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_a2f7a_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a2f7a_row0_col0" class="data row0 col0" >kapuskasing</td>
#       <td id="T_a2f7a_row0_col1" class="data row0 col1" >49.42</td>
#       <td id="T_a2f7a_row0_col2" class="data row0 col2" >-82.43</td>
#       <td id="T_a2f7a_row0_col3" class="data row0 col3" >57.20° F</td>
#       <td id="T_a2f7a_row0_col4" class="data row0 col4" >72%</td>
#       <td id="T_a2f7a_row0_col5" class="data row0 col5" >20%</td>
#       <td id="T_a2f7a_row0_col6" class="data row0 col6" >3.44</td>
#       <td id="T_a2f7a_row0_col7" class="data row0 col7" >CA</td>
#       <td id="T_a2f7a_row0_col8" class="data row0 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_a2f7a_row1_col0" class="data row1 col0" >saipan</td>
#       <td id="T_a2f7a_row1_col1" class="data row1 col1" >15.14</td>
#       <td id="T_a2f7a_row1_col2" class="data row1 col2" >145.70</td>
#       <td id="T_a2f7a_row1_col3" class="data row1 col3" >83.10° F</td>
#       <td id="T_a2f7a_row1_col4" class="data row1 col4" >89%</td>
#       <td id="T_a2f7a_row1_col5" class="data row1 col5" >40%</td>
#       <td id="T_a2f7a_row1_col6" class="data row1 col6" >6.91</td>
#       <td id="T_a2f7a_row1_col7" class="data row1 col7" >MP</td>
#       <td id="T_a2f7a_row1_col8" class="data row1 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_a2f7a_row2_col0" class="data row2 col0" >tazovsky</td>
#       <td id="T_a2f7a_row2_col1" class="data row2 col1" >67.47</td>
#       <td id="T_a2f7a_row2_col2" class="data row2 col2" >78.70</td>
#       <td id="T_a2f7a_row2_col3" class="data row2 col3" >32.47° F</td>
#       <td id="T_a2f7a_row2_col4" class="data row2 col4" >75%</td>
#       <td id="T_a2f7a_row2_col5" class="data row2 col5" >100%</td>
#       <td id="T_a2f7a_row2_col6" class="data row2 col6" >12.84</td>
#       <td id="T_a2f7a_row2_col7" class="data row2 col7" >RU</td>
#       <td id="T_a2f7a_row2_col8" class="data row2 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_a2f7a_row3_col0" class="data row3 col0" >lazaro cardenas</td>
#       <td id="T_a2f7a_row3_col1" class="data row3 col1" >17.96</td>
#       <td id="T_a2f7a_row3_col2" class="data row3 col2" >-102.20</td>
#       <td id="T_a2f7a_row3_col3" class="data row3 col3" >82.63° F</td>
#       <td id="T_a2f7a_row3_col4" class="data row3 col4" >79%</td>
#       <td id="T_a2f7a_row3_col5" class="data row3 col5" >1%</td>
#       <td id="T_a2f7a_row3_col6" class="data row3 col6" >4.65</td>
#       <td id="T_a2f7a_row3_col7" class="data row3 col7" >MX</td>
#       <td id="T_a2f7a_row3_col8" class="data row3 col8" >2023-09-26 17:57:13</td>
#     </tr>
#     <tr>
#       <td id="T_a2f7a_row4_col0" class="data row4 col0" >ribeira grande</td>
#       <td id="T_a2f7a_row4_col1" class="data row4 col1" >38.52</td>
#       <td id="T_a2f7a_row4_col2" class="data row4 col2" >-28.70</td>
#       <td id="T_a2f7a_row4_col3" class="data row4 col3" >65.77° F</td>
#       <td id="T_a2f7a_row4_col4" class="data row4 col4" >86%</td>
#       <td id="T_a2f7a_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_a2f7a_row4_col6" class="data row4 col6" >7.00</td>
#       <td id="T_a2f7a_row4_col7" class="data row4 col7" >PT</td>
#       <td id="T_a2f7a_row4_col8" class="data row4 col8" >2023-09-26 17:57:13</td>
#     </tr>
#     <tr>
#       <td id="T_a2f7a_row5_col0" class="data row5 col0" >albany</td>
#       <td id="T_a2f7a_row5_col1" class="data row5 col1" >42.60</td>
#       <td id="T_a2f7a_row5_col2" class="data row5 col2" >-73.97</td>
#       <td id="T_a2f7a_row5_col3" class="data row5 col3" >51.49° F</td>
#       <td id="T_a2f7a_row5_col4" class="data row5 col4" >89%</td>
#       <td id="T_a2f7a_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_a2f7a_row5_col6" class="data row5 col6" >1.01</td>
#       <td id="T_a2f7a_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_a2f7a_row5_col8" class="data row5 col8" >2023-09-26 17:57:14</td>
#     </tr>
#     <tr>
#       <td id="T_a2f7a_row6_col0" class="data row6 col0" >qaqortoq</td>
#       <td id="T_a2f7a_row6_col1" class="data row6 col1" >60.72</td>
#       <td id="T_a2f7a_row6_col2" class="data row6 col2" >-46.03</td>
#       <td id="T_a2f7a_row6_col3" class="data row6 col3" >36.81° F</td>
#       <td id="T_a2f7a_row6_col4" class="data row6 col4" >60%</td>
#       <td id="T_a2f7a_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_a2f7a_row6_col6" class="data row6 col6" >2.71</td>
#       <td id="T_a2f7a_row6_col7" class="data row6 col7" >GL</td>
#       <td id="T_a2f7a_row6_col8" class="data row6 col8" >2023-09-26 17:57:15</td>
#     </tr>
#     <tr>
#       <td

# %% [markdown]
# ### **Southern Hemisphere City Weather Information**

# %%
southernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (southernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.2: City Weather Information (Southern Hemisphere)')
# Out:
# <style type="text/css">
# #T_c0aae caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c0aae_row0_col0, #T_c0aae_row0_col1, #T_c0aae_row0_col2, #T_c0aae_row0_col3, #T_c0aae_row0_col4, #T_c0aae_row0_col5, #T_c0aae_row0_col6, #T_c0aae_row0_col7, #T_c0aae_row0_col8, #T_c0aae_row1_col0, #T_c0aae_row1_col1, #T_c0aae_row1_col2, #T_c0aae_row1_col5, #T_c0aae_row1_col6, #T_c0aae_row1_col7, #T_c0aae_row1_col8, #T_c0aae_row2_col0, #T_c0aae_row2_col1, #T_c0aae_row2_col2, #T_c0aae_row2_col4, #T_c0aae_row2_col6, #T_c0aae_row2_col7, #T_c0aae_row2_col8, #T_c0aae_row3_col0, #T_c0aae_row3_col1, #T_c0aae_row3_col2, #T_c0aae_row3_col3, #T_c0aae_row3_col4, #T_c0aae_row3_col5, #T_c0aae_row3_col6, #T_c0aae_row3_col7, #T_c0aae_row3_col8, #T_c0aae_row4_col0, #T_c0aae_row4_col1, #T_c0aae_row4_col2, #T_c0aae_row4_col3, #T_c0aae_row4_col4, #T_c0aae_row4_col6, #T_c0aae_row4_col7, #T_c0aae_row4_col8, #T_c0aae_row5_col0, #T_c0aae_row5_col1, #T_c0aae_row5_col2, #T_c0aae_row5_col3, #T_c0aae_row5_col7, #T_c0aae_row5_col8, #T_c0aae_row6_col0, #T_c0aae_row6_col1, #T_c0aae_row6_col2, #T_c0aae_row6_col3, #T_c0aae_row6_col4, #T_c0aae_row6_col6, #T_c0aae_row6_col7, #T_c0aae_row6_col8, #T_c0aae_row7_col0, #T_c0aae_row7_col1, #T_c0aae_row7_col2, #T_c0aae_row7_col3, #T_c0aae_row7_col4, #T_c0aae_row7_col6, #T_c0aae_row7_col7, #T_c0aae_row7_col8, #T_c0aae_row8_col0, #T_c0aae_row8_col1, #T_c0aae_row8_col2, #T_c0aae_row8_col3, #T_c0aae_row8_col4, #T_c0aae_row8_col7, #T_c0aae_row8_col8, #T_c0aae_row9_col0, #T_c0aae_row9_col1, #T_c0aae_row9_col2, #T_c0aae_row9_col3, #T_c0aae_row9_col4, #T_c0aae_row9_col6, #T_c0aae_row9_col7, #T_c0aae_row9_col8, #T_c0aae_row10_col0, #T_c0aae_row10_col1, #T_c0aae_row10_col2, #T_c0aae_row10_col3, #T_c0aae_row10_col6, #T_c0aae_row10_col7, #T_c0aae_row10_col8, #T_c0aae_row11_col0, #T_c0aae_row11_col1, #T_c0aae_row11_col2, #T_c0aae_row11_col3, #T_c0aae_row11_col4, #T_c0aae_row11_col5, #T_c0aae_row11_col6, #T_c0aae_row11_col7, #T_c0aae_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_c0aae_row1_col3, #T_c0aae_row1_col4, #T_c0aae_row2_col5, #T_c0aae_row4_col5, #T_c0aae_row5_col4, #T_c0aae_row5_col5, #T_c0aae_row8_col5, #T_c0aae_row8_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_c0aae_row2_col3, #T_c0aae_row5_col6, #T_c0aae_row6_col5, #T_c0aae_row7_col5, #T_c0aae_row9_col5, #T_c0aae_row10_col4, #T_c0aae_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_c0aae">
#   <caption>Table: 1.3.2: City Weather Information (Southern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_c0aae_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_c0aae_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_c0aae_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_c0aae_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_c0aae_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_c0aae_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_c0aae_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_c0aae_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_c0aae_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c0aae_row0_col0" class="data row0 col0" >kapuskasing</td>
#       <td id="T_c0aae_row0_col1" class="data row0 col1" >49.42</td>
#       <td id="T_c0aae_row0_col2" class="data row0 col2" >-82.43</td>
#       <td id="T_c0aae_row0_col3" class="data row0 col3" >57.20° F</td>
#       <td id="T_c0aae_row0_col4" class="data row0 col4" >72%</td>
#       <td id="T_c0aae_row0_col5" class="data row0 col5" >20%</td>
#       <td id="T_c0aae_row0_col6" class="data row0 col6" >3.44</td>
#       <td id="T_c0aae_row0_col7" class="data row0 col7" >CA</td>
#       <td id="T_c0aae_row0_col8" class="data row0 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_c0aae_row1_col0" class="data row1 col0" >saipan</td>
#       <td id="T_c0aae_row1_col1" class="data row1 col1" >15.14</td>
#       <td id="T_c0aae_row1_col2" class="data row1 col2" >145.70</td>
#       <td id="T_c0aae_row1_col3" class="data row1 col3" >83.10° F</td>
#       <td id="T_c0aae_row1_col4" class="data row1 col4" >89%</td>
#       <td id="T_c0aae_row1_col5" class="data row1 col5" >40%</td>
#       <td id="T_c0aae_row1_col6" class="data row1 col6" >6.91</td>
#       <td id="T_c0aae_row1_col7" class="data row1 col7" >MP</td>
#       <td id="T_c0aae_row1_col8" class="data row1 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_c0aae_row2_col0" class="data row2 col0" >tazovsky</td>
#       <td id="T_c0aae_row2_col1" class="data row2 col1" >67.47</td>
#       <td id="T_c0aae_row2_col2" class="data row2 col2" >78.70</td>
#       <td id="T_c0aae_row2_col3" class="data row2 col3" >32.47° F</td>
#       <td id="T_c0aae_row2_col4" class="data row2 col4" >75%</td>
#       <td id="T_c0aae_row2_col5" class="data row2 col5" >100%</td>
#       <td id="T_c0aae_row2_col6" class="data row2 col6" >12.84</td>
#       <td id="T_c0aae_row2_col7" class="data row2 col7" >RU</td>
#       <td id="T_c0aae_row2_col8" class="data row2 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_c0aae_row3_col0" class="data row3 col0" >lazaro cardenas</td>
#       <td id="T_c0aae_row3_col1" class="data row3 col1" >17.96</td>
#       <td id="T_c0aae_row3_col2" class="data row3 col2" >-102.20</td>
#       <td id="T_c0aae_row3_col3" class="data row3 col3" >82.63° F</td>
#       <td id="T_c0aae_row3_col4" class="data row3 col4" >79%</td>
#       <td id="T_c0aae_row3_col5" class="data row3 col5" >1%</td>
#       <td id="T_c0aae_row3_col6" class="data row3 col6" >4.65</td>
#       <td id="T_c0aae_row3_col7" class="data row3 col7" >MX</td>
#       <td id="T_c0aae_row3_col8" class="data row3 col8" >2023-09-26 17:57:13</td>
#     </tr>
#     <tr>
#       <td id="T_c0aae_row4_col0" class="data row4 col0" >ribeira grande</td>
#       <td id="T_c0aae_row4_col1" class="data row4 col1" >38.52</td>
#       <td id="T_c0aae_row4_col2" class="data row4 col2" >-28.70</td>
#       <td id="T_c0aae_row4_col3" class="data row4 col3" >65.77° F</td>
#       <td id="T_c0aae_row4_col4" class="data row4 col4" >86%</td>
#       <td id="T_c0aae_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_c0aae_row4_col6" class="data row4 col6" >7.00</td>
#       <td id="T_c0aae_row4_col7" class="data row4 col7" >PT</td>
#       <td id="T_c0aae_row4_col8" class="data row4 col8" >2023-09-26 17:57:13</td>
#     </tr>
#     <tr>
#       <td id="T_c0aae_row5_col0" class="data row5 col0" >albany</td>
#       <td id="T_c0aae_row5_col1" class="data row5 col1" >42.60</td>
#       <td id="T_c0aae_row5_col2" class="data row5 col2" >-73.97</td>
#       <td id="T_c0aae_row5_col3" class="data row5 col3" >51.49° F</td>
#       <td id="T_c0aae_row5_col4" class="data row5 col4" >89%</td>
#       <td id="T_c0aae_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_c0aae_row5_col6" class="data row5 col6" >1.01</td>
#       <td id="T_c0aae_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_c0aae_row5_col8" class="data row5 col8" >2023-09-26 17:57:14</td>
#     </tr>
#     <tr>
#       <td id="T_c0aae_row6_col0" class="data row6 col0" >qaqortoq</td>
#       <td id="T_c0aae_row6_col1" class="data row6 col1" >60.72</td>
#       <td id="T_c0aae_row6_col2" class="data row6 col2" >-46.03</td>
#       <td id="T_c0aae_row6_col3" class="data row6 col3" >36.81° F</td>
#       <td id="T_c0aae_row6_col4" class="data row6 col4" >60%</td>
#       <td id="T_c0aae_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_c0aae_row6_col6" class="data row6 col6" >2.71</td>
#       <td id="T_c0aae_row6_col7" class="data row6 col7" >GL</td>
#       <td id="T_c0aae_row6_col8" class="data row6 col8" >2023-09-26 17:57:15</td>
#     </tr>
#     <tr>
#       <td

# %% [markdown]
# ### **Temperature vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.1: Temperature vs. Latitude (Northern Hemisphere)',
         1, 2.0, 45.0)
# Out:
# r-value:     -0.8263
# r-squared:   0.6827

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.2: Temperature vs. Latitude (Southern Hemisphere)',
         1, -55.0, 85.0)
# Out:
# r-value:     0.7426
# r-squared:   0.5514

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### From the results of the linear regression, in the northern hemisphere, the latitude is negatively correlated with temperature; this negative correlation tells us that the two variables move in opposite directions: as latitude increases, the temperature drops, and vice versa.  In the southern hemisphers, the latitude is positively correlated with temperature: this positive correlation tells us that the two variables move in the same direction: as latitude increases, the temperature increases.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.3: Humidity vs. Latitude (Northern Hemisphere)',
         1, 45.0, 18.0)
# Out:
# r-value:     0.0210
# r-squared:   0.0004

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.4: Humidity vs. Latitude (Southern Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     -0.0042
# r-squared:   0.0000

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and humidity in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Cloudiness vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.5: Cloudiness vs. Latitude (Northern Hemisphere)',
         1, 16.0, 62.0)
# Out:
# r-value:     0.0905
# r-squared:   0.0082

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.6: Cloudiness vs. Latitude (Southern Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     0.0617
# r-squared:   0.0038

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and cloudiness in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.7: Wind Speed vs. Latitude (Northern Hemisphere)',
         1, 15.0, 22.0)
# Out:
# r-value:     0.1160
# r-squared:   0.0135

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.8: Wind Speed vs. Latitude (Southern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.1962
# r-squared:   0.0385

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and wind speed in either hemisphere.

# %%
#log_subroutine \
#    .EndProgramExecution()
