# %% [markdown]
# # WeatherPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, WeatherPy.ipynb, uses a Python script to 
 #      visualize the weather of over 500 cities of varying distances from the equator. 
 #      The script uses the citipy Python library and the openWeatherMap API to create 
 #      a representative model of weather across cities.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubRoutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'WeatherPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('WeatherPy')

# %% [markdown]
# # <br> **Section 1: Weather Variables and Latitude**

# %% [markdown]
# ## **Section 1.1: Data Acquisition**

# %% [markdown]
# ### **List of Cities**

# %%
citiesListOfStrings \
    = api_function \
        .ReturnCitiesList()

# %% [markdown]
# ### **Weather Data from List of Cities**

# %%
cityWeatherDataFrame \
    = api_function \
        .ReturnWeatherDataFrame \
            (citiesListOfStrings)
# Out:
# DATA RETRIEVAL FOR CITY WEATHER DATAFRAME BEGINS...
#
#
# PROCESSING RECORD #2 OF SET 1 FOR CITY, ust'-barguzin.
#
# PROCESSING RECORD #3 OF SET 1 FOR CITY, longyearbyen.
#
# PROCESSING RECORD #4 OF SET 1 FOR CITY, lebu.
#
# PROCESSING RECORD #5 OF SET 1 FOR CITY, carutapera.
#
# PROCESSING RECORD #6 OF SET 1 FOR CITY, alofi.
#
# PROCESSING RECORD #7 OF SET 1 FOR CITY, teteven.
#
# PROCESSING RECORD #8 OF SET 1 FOR CITY, morondava.
#
# PROCESSING RECORD #9 OF SET 1 FOR CITY, yellowknife.
#
# PROCESSING RECORD #10 OF SET 1 FOR CITY, azul.
#
# PROCESSING RECORD #11 OF SET 1 FOR CITY, puerto natales.
#
# PROCESSING RECORD #12 OF SET 1 FOR CITY, amahai.
#
# PROCESSING RECORD #13 OF SET 1 FOR CITY, revda.
#
# PROCESSING RECORD #14 OF SET 1 FOR CITY, avarua.
#
# PROCESSING RECORD #15 OF SET 1 FOR CITY, hawaiian paradise park.
#
# PROCESSING RECORD #16 OF SET 1 FOR CITY, udachny.
#
# PROCESSING RECORD #17 OF SET 1 FOR CITY, hovd.
#
# PROCESSING RECORD #18 OF SET 1 FOR CITY, thakurgaon.
#
# PROCESSING RECORD #19 OF SET 1 FOR CITY, tiksi.
#
# PROCESSING RECORD #20 OF SET 1 FOR CITY, djambala.
#
# PROCESSING RECORD #21 OF SET 1 FOR CITY, gebeit.
#
# PROCESSING RECORD #22 OF SET 1 FOR CITY, smithers.
#
# PROCESSING RECORD #23 OF SET 1 FOR CITY, hirara.
#
# PROCESSING RECORD #24 OF SET 1 FOR CITY, puerto san carlos.
#
# The script did not find the city, puerto san carlos. Skipping...
#
# PROCESSING RECORD #25 OF SET 1 FOR CITY, stanley.
#
# PROCESSING RECORD #26 OF SET 1 FOR CITY, wailua homesteads.
#
# PROCESSING RECORD #27 OF SET 1 FOR CITY, alto araguaia.
#
# PROCESSING RECORD #28 OF SET 1 FOR CITY, dryden.
#
# PROCESSING RECORD #29 OF SET 1 FOR CITY, remire-montjoly.
#
# PROCESSING RECORD #30 OF SET 1 FOR CITY, bredasdorp.
#
# PROCESSING RECORD #31 OF SET 1 FOR CITY, nova sintra.
#
# PROCESSING RECORD #32 OF SET 1 FOR CITY, bungu.
#
# PROCESSING RECORD #33 OF SET 1 FOR CITY, sorong.
#
# PROCESSING RECORD #34 OF SET 1 FOR CITY, puerto ayora.
#
# PROCESSING RECORD #35 OF SET 1 FOR CITY, degema hulk.
#
# PROCESSING RECORD #36 OF SET 1 FOR CITY, tarko-sale.
#
# PROCESSING RECORD #37 OF SET 1 FOR CITY, college.
#
# PROCESSING RECORD #38 OF SET 1 FOR CITY, nyala.
#
# PROCESSING RECORD #39 OF SET 1 FOR CITY, tazovsky.
#
# PROCESSING RECORD #40 OF SET 1 FOR CITY, invercargill.
#
# PROCESSING RECORD #41 OF SET 1 FOR CITY, hithadhoo.
#
# PROCESSING RECORD #42 OF SET 1 FOR CITY, vorgashor.
#
# PROCESSING RECORD #43 OF SET 1 FOR CITY, utrik.
#
# PROCESSING RECORD #44 OF SET 1 FOR CITY, jamestown.
#
# PROCESSING RECORD #45 OF SET 1 FOR CITY, laguna.
#
# PROCESSING RECORD #46 OF SET 1 FOR CITY, ilulissat.
#
# PROCESSING RECORD #47 OF SET 1 FOR CITY, ust-nera.
#
# PROCESSING RECORD #48 OF SET 1 FOR CITY, estevan.
#
# PROCESSING RECORD #49 OF SET 1 FOR CITY, port-aux-francais.
#
# PROCESSING RECORD #50 OF SET 1 FOR CITY, yanam.
#
# PROCESSING RECORD #51 OF SET 1 FOR CITY, taiohae.
#
# The script did not find the city, taiohae. Skipping...
#
# PROCESSING RECORD #1 OF SET 2 FOR CITY, lesnoy.
#
# PROCESSING RECORD #2 OF SET 2 FOR CITY, blackmans bay.
#
# PROCESSING RECORD #3 OF SET 2 FOR CITY, fuvahmulah.
#
# The script did not find the city, fuvahmulah. Skipping...
#
# PROCESSING RECORD #4 OF SET 2 FOR CITY, kirakira.
#
# PROCESSING RECORD #5 OF SET 2 FOR CITY, enewetak.
#
# PROCESSING RECORD #6 OF SET 2 FOR CITY, saipan.
#
# PROCESSING RECORD #7 OF SET 2 FOR CITY, albany.
#
# PROCESSING RECORD #8 OF SET 2 FOR CITY, port alfred.
#
# PROCESSING RECORD #9 OF SET 2 FOR CITY, saint-francois.
#
# PROCESSING RECORD #10 OF SET 2 FOR CITY, grytviken.
#
# PROCESSING RECORD #11 OF SET 2 FOR CITY, ambodifotatra.
#
# PROCESSING RECORD #12 OF SET 2 FOR CITY, ancud.
#
# PROCESSING RECORD #13 OF SET 2 FOR CITY, edinburgh of the seven seas.
#
# PROCESSING RECORD #14 OF SET 2 FOR CITY, sillamae.
#
# PROCESSING RECORD #15 OF SET 2 FOR CITY, saucillo.
#
# PROCESSING RECORD #16 OF SET 2 FOR CITY, olonkinbyen.
#
# PROCESSING RECORD #17 OF SET 2 FOR CITY, hami.
#
# PROCESSING RECORD #18 OF SET 2 FOR CITY, vilyuchinsk.
#
# PROCESSING RECORD #19 OF SET 2 FOR CITY, fort bragg.
#
# PROCESSING RECORD #20 OF SET 2 FOR CITY, ribeira grande.
#
# PROCESSING RECORD #21 OF SET 2 FOR CITY, lisakovsk.
#
# PROCESSING RECORD #22 OF SET 2 FOR CITY, bethel.
#
# PROCESSING RECORD #23 OF SET 2 FOR CITY, savave village.
#
# The script did not find the city, savave village. Skipping...
#
# PROCESSING RECORD #24 OF SET 2 FOR CITY, qaqortoq.
#
# PROCESSING RECORD #25 OF SET 2 FOR CITY, ola.
#
# PROCESSING RECORD #26 OF SET 2 FOR CITY, afaahiti.
#
# PROCESSING RECORD #27 OF SET 2 FOR CITY, thompson.
#
# PROCESSING RECORD #28 OF SET 2 FOR CITY, whitehorse.
#
# PROCESSING RECORD #29 OF SET 2 FOR CITY, lihue.
#
# PROCESSING RECORD #30 OF SET 2 FOR CITY, rio rancho.
#
# PROCESSING RECORD #31 OF SET 2 FOR CITY, sinan.
#
# PROCESSING RECORD #32 OF SET 2 FOR CITY, nyurba.
#
# PROCESSING RECORD #33 OF SET 2 FOR CITY, westport.
#
# PROCESSING RECORD #34 OF SET 2 FOR CITY, santa ana de yacuma.
#
# PROCESSING RECORD #35 OF SET 2 FOR CITY, xinyuan.
#
# PROCESSING RECORD #36 OF SET 2 FOR CITY, tsengel.
#
# PROCESSING RECORD #37 OF SET 2 FOR CITY, pokrovsk.
#
# PROCESSING RECORD #38 OF SET 2 FOR CITY, anadyr.
#
# PROCESSING RECORD #39 OF SET 2 FOR CITY, fale old settlement.
#
# PROCESSING RECORD #40 OF SET 2 FOR CITY, am djarass.
#
# The script did not find the city, am djarass. Skipping...
#
# PROCESSING RECORD #41 OF SET 2 FOR CITY, plettenberg bay.
#
# PROCESSING RECORD #42 OF SET 2 FOR CITY, vingt cinq.
#
# The script did not find the city, vingt cinq. Skipping...
#
# PROCESSING RECORD #43 OF SET 2 FOR CITY, saba.
#
# PROCESSING RECORD #44 OF SET 2 FOR CITY, iqaluit.
#
# PROCESSING RECORD #45 OF SET 2 FOR CITY, ushuaia.
#
# PROCESSING RECORD #46 OF SET 2 FOR CITY, palu.
#
# PROCESSING RECORD #47 OF SET 2 FOR CITY, acapulco de juarez.
#
# PROCESSING RECORD #48 OF SET 2 FOR CITY, catio.
#
# PROCESSING RECORD #49 OF SET 2 FOR CITY, shinjo.
#
# PROCESSING RECORD #50 OF SET 2 FOR CITY, waitangi.
#
# PROCESSING RECORD #1 OF SET 3 FOR CITY, wanganui.
#
# PROCESSING RECORD #2 OF SET 3 FOR CITY, sambava.
#
# PROCESSING RECORD #3 OF SET 3 FOR CITY, grand centre.
#
# The script did not find the city, grand centre. Skipping...
#
# PROCESSING RECORD #4 OF SET 3 FOR CITY, lazaro cardenas.
#
# PROCESSING RECORD #5 OF SET 3 FOR CITY, minas de marcona.
#
# PROCESSING RECORD #6 OF SET 3 FOR CITY, geraldton.
#
# PROCESSING RECORD #7 OF SET 3 FOR CITY, christchurch.
#
# PROCESSING RECORD #8 OF SET 3 FOR CITY, capitan bado.
#
# PROCESSING RECORD #9 OF SET 3 FOR CITY, paka.
#
# PROCESSING RECORD #10 OF SET 3 FOR CITY, norilsk.
#
# PROCESSING RECORD #11 OF SET 3 FOR CITY, oranjemund.
#
# PROCESSING RECORD #12 OF SET 3 FOR CITY, fortuna.
#
# PROCESSING RECORD #13 OF SET 3 FOR CITY, isafjordur.
#
# PROCESSING RECORD #14 OF SET 3 FOR CITY, jedlicze.
#
# PROCESSING RECORD #15 OF SET 3 FOR CITY, adamstown.
#
# PROCESSING RECORD #16 OF SET 3 FOR CITY, nanawua.
#
# PROCESSING RECORD #17 OF SET 3 FOR CITY, yuzhno-kurilsk.
#
# PROCESSING RECORD #18 OF SET 3 FOR CITY, susanville.
#
# PROCESSING RECORD #19 OF SET 3 FOR CITY, borinskoye.
#
# PROCESSING RECORD #20 OF SET 3 FOR CITY, steinbach.
#
# PROCESSING RECORD #21 OF SET 3 FOR CITY, carnarvon.
#
# PROCESSING RECORD #22 OF SET 3 FOR CITY, vila velha.
#
# PROCESSING RECORD #23 OF SET 3 FOR CITY, aasiaat.
#
# PROCESSING RECORD #24 OF SET 3 FOR CITY, cabo san lucas.
#
# PROCESSING RECORD #25 OF SET 3 FOR CITY, labytnangi.
#
# PROCESSING RECORD #26 OF SET 3 FOR CITY, torres.
#
# PROCESSING RECORD #27 OF SET 3 FOR CITY, kruisfontein.
#
# PROCESSING RECORD #28 OF SET 3 FOR CITY, port saint john's.
#
# PROCESSING RECORD #29 OF SET 3 FOR CITY, posto fiscal rolim de moura.
#
# PROCESSING RECORD #30 OF SET 3 FOR CITY, machida.
#
# PROCESSING RECORD #31 OF SET 3 FOR CITY, petropavlovsk-kamchatsky.
#
# PROCESSING RECORD #32 OF SET 3 FOR CITY, atafu village.
#
# PROCESSING RECORD #33 OF SET 3 FOR CITY, alice springs.
#
# PROCESSING RECORD #34 OF SET 3 FOR CITY, susuman.
#
# PROCESSING RECORD #35 OF SET 3 FOR CITY, at-bashi.
#
# PROCESSING RECORD #36 OF SET 3 FOR CITY, bamboo flat.
#
# PROCESSING RECORD #37 OF SET 3 FOR CITY, al bardiyah.
#
# PROCESSING RECORD #38 OF SET 3 FOR CITY, crane.
#
# PROCESSING RECORD #39 OF SET 3 FOR CITY, hermanus.
#
# PROCESSING RECORD #40 OF SET 3 FOR CITY, namibe.
#
# PROCESSING RECORD #41 OF SET 3 FOR CITY, tralee.
#
# PROCESSING RECORD #42 OF SET 3 FOR CITY, vila franca do campo.
#
# PROCESSING RECORD #43 OF SET 3 FOR CITY, saint-pierre.
#
# PROCESSING RECORD #44 OF SET 3 FOR CITY, yulinshi.
#
# PROCESSING RECORD #45 OF SET 3 FOR CITY, kokopo.
#
# PROCESSING RECORD #46 OF SET 3 FOR CITY, okha.
# PROCESSING RECORD #47 OF SET 3 FOR CITY, praia da vitoria.
#
# PROCESSING RECORD #48 OF SET 3 FOR CITY, keflavik.
#
# PROCESSING RECORD #49 OF SET 3 FOR CITY, scone.
#
# PROCESSING RECORD #50 OF SET 3 FOR CITY, punta arenas.
#
# PROCESSING RECORD #1 OF SET 4 FOR CITY, hamilton.
#
# PROCESSING RECORD #2 OF SET 4 FOR CITY, bredy.
#
# PROCESSING RECORD #3 OF SET 4 FOR CITY, yirol.
#
# The script did not find the city, yirol. Skipping...
#
# PROCESSING RECORD #4 OF SET 4 FOR CITY, goz beida.
#
# PROCESSING RECORD #5 OF SET 4 FOR CITY, papatowai.
#
# PROCESSING RECORD #6 OF SET 4 FOR CITY, farmville.
#
# PROCESSING RECORD #7 OF SET 4 FOR CITY, margaret river.
#
# PROCESSING RECORD #8 OF SET 4 FOR CITY, mount pearl.
#
# PROCESSING RECORD #9 OF SET 4 FOR CITY, ribeira brava.
#
# PROCESSING RECORD #10 OF SET 4 FOR CITY, kataragama.
#
# The script did not find the city, kataragama. Skipping...
#
# PROCESSING RECORD #11 OF SET 4 FOR CITY, san antonio de pale.
#
# PROCESSING RECORD #12 OF SET 4 FOR CITY, champerico.
#
# PROCESSING RECORD #13 OF SET 4 FOR CITY, zhangatas.
#
# PROCESSING RECORD #14 OF SET 4 FOR CITY, acarau.
#
# PROCESSING RECORD #15 OF SET 4 FOR CITY, yorkton.
#
# PROCESSING RECORD #16 OF SET 4 FOR CITY, ayod.
#
# The script did not find the city, ayod. Skipping...
#
# PROCESSING RECORD #17 OF SET 4 FOR CITY, talnakh.
#
# PROCESSING RECORD #18 OF SET 4 FOR CITY, ghanzi.
#
# PROCESSING RECORD #19 OF SET 4 FOR CITY, kodiak.
#
# PROCESSING RECORD #20 OF SET 4 FOR CITY, chonchi.
#
# PROCESSING RECORD #21 OF SET 4 FOR CITY, sitka.
#
# PROCESSING RECORD #22 OF SET 4 FOR CITY, prince rupert.
#
# PROCESSING RECORD #23 OF SET 4 FOR CITY, bilibino.
#
# PROCESSING RECORD #24 OF SET 4 FOR CITY, qorovulbozor.
#
# PROCESSING RECORD #25 OF SET 4 FOR CITY, uturoa.
#
# PROCESSING RECORD #26 OF SET 4 FOR CITY, maihar.
#
# PROCESSING RECORD #27 OF SET 4 FOR CITY, porto recanati.
#
# PROCESSING RECORD #28 OF SET 4 FOR CITY, port shepstone.
#
# PROCESSING RECORD #29 OF SET 4 FOR CITY, remuna.
#
# PROCESSING RECORD #30 OF SET 4 FOR CITY, selfoss.
#
# PROCESSING RECORD #31 OF SET 4 FOR CITY, jining.
#
# PROCESSING RECORD #32 OF SET 4 FOR CITY, woodinville.
#
# PROCESSING RECORD #33 OF SET 4 FOR CITY, kingston.
#
# PROCESSING RECORD #34 OF SET 4 FOR CITY, port elizabeth.
#
# PROCESSING RECORD #35 OF SET 4 FOR CITY, tranovaho.
#
# The script did not find the city, tranovaho. Skipping...
#
# PROCESSING RECORD #36 OF SET 4 FOR CITY, kolwezi.
#
# PROCESSING RECORD #37 OF SET 4 FOR CITY, vohipaho.
#
# The script did not find the city, vohipaho. Skipping...
#
# PROCESSING RECORD #38 OF SET 4 FOR CITY, hayma'.
#
# The script did not find the city, hayma'. Skipping...
#
# PROCESSING RECORD #39 OF SET 4 FOR CITY, port glaud.
#
# The script did not find the city, port glaud. Skipping...
#
# PROCESSING RECORD #40 OF SET 4 FOR CITY, shache.
#
# PROCESSING RECORD #41 OF SET 4 FOR CITY, urengoy.
#
# PROCESSING RECORD #42 OF SET 4 FOR CITY, new plymouth.
#
# PROCESSING RECORD #43 OF SET 4 FOR CITY, phibun mangsahan.
#
# PROCESSING RECORD #44 OF SET 4 FOR CITY, westonaria.
#
# PROCESSING RECORD #45 OF SET 4 FOR CITY, tazacorte.
#
# PROCESSING RECORD #46 OF SET 4 FOR CITY, isangel.
#
# PROCESSING RECORD #47 OF SET 4 FOR CITY, ardabil.
#
# PROCESSING RECORD #48 OF SET 4 FOR CITY, banavar.
#
# PROCESSING RECORD #49 OF SET 4 FOR CITY, magadan.
#
# PROCESSING RECORD #50 OF SET 4 FOR CITY, nizhniy odes.
#
# PROCESSING RECORD #1 OF SET 5 FOR CITY, nadym.
#
# PROCESSING RECORD #2 OF SET 5 FOR CITY, aykhal.
#
# PROCESSING RECORD #3 OF SET 5 FOR CITY, broome.
#
# PROCESSING RECORD #4 OF SET 5 FOR CITY, brisas de zicatela.
#
# PROCESSING RECORD #5 OF SET 5 FOR CITY, kailua-kona.
#
# PROCESSING RECORD #6 OF SET 5 FOR CITY, bom jesus.
#
# PROCESSING RECORD #7 OF SET 5 FOR CITY, tezu.
#
# PROCESSING RECORD #8 OF SET 5 FOR CITY, verkhnevilyuysk.
#
# PROCESSING RECORD #9 OF SET 5 FOR CITY, port mathurin.
#
# PROCESSING RECORD #10 OF SET 5 FOR CITY, tolanaro.
#
# PROCESSING RECORD #11 OF SET 5 FOR CITY, anibare.
#
# The script did not find the city, anibare. Skipping...
#
# PROCESSING RECORD #12 OF SET 5 FOR CITY, harstad.
#
# PROCESSING RECORD #13 OF SET 5 FOR CITY, kapuskasing.
#
# PROCESSING RECORD #14 OF SET 5 FOR CITY, rongelap.
#
# PROCESSING RECORD #15 OF SET 5 FOR CITY, saldanha.
#
# PROCESSING RECORD #16 OF SET 5 FOR CITY, wailea.
#
# PROCESSING RECORD #17 OF SET 5 FOR CITY, langepas.
#
# PROCESSING RECORD #18 OF SET 5 FOR CITY, lorengau.
#
# PROCESSING RECORD #19 OF SET 5 FOR CITY, shilin.
#
# PROCESSING RECORD #20 OF SET 5 FOR CITY, puerto armuelles.
#
# PROCESSING RECORD #21 OF SET 5 FOR CITY, porto novo.
#
# PROCESSING RECORD #22 OF SET 5 FOR CITY, severoural'sk.
#
# PROCESSING RECORD #23 OF SET 5 FOR CITY, waajid.
#
# PROCESSING RECORD #24 OF SET 5 FOR CITY, wadebridge.
#
# PROCESSING RECORD #25 OF SET 5 FOR CITY, soio.
#
# PROCESSING RECORD #26 OF SET 5 FOR CITY, pacific grove.
#
# PROCESSING RECORD #27 OF SET 5 FOR CITY, qarqaraly.
#
# PROCESSING RECORD #28 OF SET 5 FOR CITY, kyelang.
#
# PROCESSING RECORD #29 OF SET 5 FOR CITY, gaspe.
#
# PROCESSING RECORD #30 OF SET 5 FOR CITY, quellon.
#
# PROCESSING RECORD #31 OF SET 5 FOR CITY, undurkhaan.
#
# PROCESSING RECORD #32 OF SET 5 FOR CITY, san pedro.
#
# PROCESSING RECORD #33 OF SET 5 FOR CITY, brasileia.
#
# PROCESSING RECORD #34 OF SET 5 FOR CITY, eforie sud.
#
# PROCESSING RECORD #35 OF SET 5 FOR CITY, st. john's.
#
# PROCESSING RECORD #36 OF SET 5 FOR CITY, belmonte.
#
# PROCESSING RECORD #37 OF SET 5 FOR CITY, nar'yan-mar.
#
# PROCESSING RECORD #38 OF SET 5 FOR CITY, nishinoomote.
#
# PROCESSING RECORD #39 OF SET 5 FOR CITY, alexandria.
#
# PROCESSING RECORD #40 OF SET 5 FOR CITY, port lincoln.
#
# PROCESSING RECORD #41 OF SET 5 FOR CITY, arraial do cabo.
#
# PROCESSING RECORD #42 OF SET 5 FOR CITY, antalaha.
#
# PROCESSING RECORD #43 OF SET 5 FOR CITY, el nido.
#
# PROCESSING RECORD #44 OF SET 5 FOR CITY, mar del plata.
#
# PROCESSING RECORD #45 OF SET 5 FOR CITY, beyneu.
#
# PROCESSING RECORD #46 OF SET 5 FOR CITY, pyshma.
#
# PROCESSING RECORD #47 OF SET 5 FOR CITY, meadow lakes.
#
# PROCESSING RECORD #48 OF SET 5 FOR CITY, jyvaskyla.
#
# PROCESSING RECORD #49 OF SET 5 FOR CITY, spring creek.
#
# PROCESSING RECORD #50 OF SET 5 FOR CITY, ganganagar.
#
# PROCESSING RECORD #1 OF SET 6 FOR CITY, canavieiras.
#
# PROCESSING RECORD #2 OF SET 6 FOR CITY, siocon.
#
# PROCESSING RECORD #3 OF SET 6 FOR CITY, xiva.
#
# PROCESSING RECORD #4 OF SET 6 FOR CITY, badger.
#
# PROCESSING RECORD #5 OF SET 6 FOR CITY, weno.
#
# PROCESSING RECORD #6 OF SET 6 FOR CITY, klyuchi.
#
# PROCESSING RECORD #7 OF SET 6 FOR CITY, cruzeiro do sul.
#
# PROCESSING RECORD #8 OF SET 6 FOR CITY, wanning.
#
# PROCESSING RECORD #9 OF SET 6 FOR CITY, safi.
#
# PROCESSING RECORD #10 OF SET 6 FOR CITY, khandyga.
#
# PROCESSING RECORD #11 OF SET 6 FOR CITY, nukunonu.
#
# The script did not find the city, nukunonu. Skipping...
#
# PROCESSING RECORD #12 OF SET 6 FOR CITY, suai.
#
# The script did not find the city, suai. Skipping...
#
# PROCESSING RECORD #13 OF SET 6 FOR CITY, tocopilla.
#
# PROCESSING RECORD #14 OF SET 6 FOR CITY, salina cruz.
#
# PROCESSING RECORD #15 OF SET 6 FOR CITY, morieres-les-avignon.
#
# PROCESSING RECORD #16 OF SET 6 FOR CITY, grand island.
#
# PROCESSING RECORD #17 OF SET 6 FOR CITY, colonia.
#
# PROCESSING RECORD #18 OF SET 6 FOR CITY, basco.
#
# PROCESSING RECORD #19 OF SET 6 FOR CITY, alo.
#
# PROCESSING RECORD #20 OF SET 6 FOR CITY, itamaraca.
#
# PROCESSING RECORD #21 OF SET 6 FOR CITY, queenstown.
#
# PROCESSING RECORD #22 OF SET 6 FOR CITY, constantia.
#
# PROCESSING RECORD #23 OF SET 6 FOR CITY, dolores.
#
# PROCESSING RECORD #24 OF SET 6 FOR CITY, yei.
#
# PROCESSING RECORD #25 OF SET 6 FOR CITY, miyanoura.
#
# The script did not find the city, miyanoura. Skipping...
#
# PROCESSING RECORD #26 OF SET 6 FOR CITY, conduaga.
#
# PROCESSING RECORD #27 OF SET 6 FOR CITY, ilave.
#
# PROCESSING RECORD #28 OF SET 6 FOR CITY, la passe.
#
# PROCESSING RECORD #29 OF SET 6 FOR CITY, adrar.
#
# PROCESSING RECORD #30 OF SET 6 FOR CITY, pascagoula.
#
# PROCESSING RECORD #31 OF SET 6 FOR CITY, yamethin.
#
# PROCESSING RECORD #32 OF SET 6 FOR CITY, dubbo.
#
# PROCESSING RECORD #33 OF SET 6 FOR CITY, karratha.
#
# PROCESSING RECORD #34 OF SET 6 FOR CITY, tutoia.
#
# PROCESSING RECORD #35 OF SET 6 FOR CITY, cannonvale.
#
# PROCESSING RECORD #36 OF SET 6 FOR CITY, west island.
#
# PROCESSING RECORD #37 OF SET 6 FOR CITY, suva.
#
# PROCESSING RECORD #38 OF SET 6 FOR CITY, manacapuru.
#
# PROCESSING RECORD #39 OF SET 6 FOR CITY, vorkuta.
#
# PROCESSING RECORD #40 OF SET 6 FOR CITY, hasaki.
#
# PROCESSING RECORD #41 OF SET 6 FOR CITY, thunder bay.
#
# PROCESSING RECORD #42 OF SET 6 FOR CITY, east london.
# PROCESSING RECORD #43 OF SET 6 FOR CITY, taunggyi.
#
# PROCESSING RECORD #44 OF SET 6 FOR CITY, kangal.
#
# PROCESSING RECORD #45 OF SET 6 FOR CITY, kyaukse.
#
# PROCESSING RECORD #46 OF SET 6 FOR CITY, ta`u.
#
# PROCESSING RECORD #47 OF SET 6 FOR CITY, happy valley-goose bay.
#
# PROCESSING RECORD #48 OF SET 6 FOR CITY, kerch.
#
# PROCESSING RECORD #49 OF SET 6 FOR CITY, luganville.
#
# PROCESSING RECORD #50 OF SET 6 FOR CITY, kirensk.
#
# PROCESSING RECORD #1 OF SET 7 FOR CITY, masterton.
#
# PROCESSING RECORD #2 OF SET 7 FOR CITY, harper.
#
# PROCESSING RECORD #3 OF SET 7 FOR CITY, pula.
#
# PROCESSING RECORD #4 OF SET 7 FOR CITY, takamaka.
#
# The script did not find the city, takamaka. Skipping...
#
# PROCESSING RECORD #5 OF SET 7 FOR CITY, aginskoye.
#
# PROCESSING RECORD #6 OF SET 7 FOR CITY, valentin gomez farias.
#
# PROCESSING RECORD #7 OF SET 7 FOR CITY, chinchilla.
#
# PROCESSING RECORD #8 OF SET 7 FOR CITY, joal-fadiout.
#
# PROCESSING RECORD #9 OF SET 7 FOR CITY, olyokminsk.
#
# PROCESSING RECORD #10 OF SET 7 FOR CITY, okhotsk.
#
# PROCESSING RECORD #11 OF SET 7 FOR CITY, kimbe.
#
# PROCESSING RECORD #12 OF SET 7 FOR CITY, constitucion.
#
# PROCESSING RECORD #13 OF SET 7 FOR CITY, swift current.
#
# PROCESSING RECORD #14 OF SET 7 FOR CITY, iskateley.
#
# PROCESSING RECORD #15 OF SET 7 FOR CITY, manicore.
#
# PROCESSING RECORD #16 OF SET 7 FOR CITY, sibut.
#
# PROCESSING RECORD #17 OF SET 7 FOR CITY, arar.
#
# PROCESSING RECORD #18 OF SET 7 FOR CITY, ziro.
#
# PROCESSING RECORD #19 OF SET 7 FOR CITY, torghay.
#
# PROCESSING RECORD #20 OF SET 7 FOR CITY, labrador city.
#
# PROCESSING RECORD #21 OF SET 7 FOR CITY, bandon.
#
# PROCESSING RECORD #22 OF SET 7 FOR CITY, nichlaul.
#
# PROCESSING RECORD #23 OF SET 7 FOR CITY, mossel bay.
#
# PROCESSING RECORD #24 OF SET 7 FOR CITY, muynoq.
#
# PROCESSING RECORD #25 OF SET 7 FOR CITY, pimentel.
#
# PROCESSING RECORD #26 OF SET 7 FOR CITY, novyy urgal.
#
# PROCESSING RECORD #27 OF SET 7 FOR CITY, hotan.
#
# PROCESSING RECORD #28 OF SET 7 FOR CITY, emerald.
#
# PROCESSING RECORD #29 OF SET 7 FOR CITY, hobyo.
#
# PROCESSING RECORD #30 OF SET 7 FOR CITY, waddan.
#
# PROCESSING RECORD #31 OF SET 7 FOR CITY, kili.
#
# PROCESSING RECORD #32 OF SET 7 FOR CITY, gisborne.
#
# PROCESSING RECORD #33 OF SET 7 FOR CITY, suarez.
#
# PROCESSING RECORD #34 OF SET 7 FOR CITY, dalbandin.
#
# PROCESSING RECORD #35 OF SET 7 FOR CITY, rikaze.
#
# PROCESSING RECORD #36 OF SET 7 FOR CITY, baukau.
#
# PROCESSING RECORD #37 OF SET 7 FOR CITY, san patricio.
#
# PROCESSING RECORD #38 OF SET 7 FOR CITY, lodja.
#
# PROCESSING RECORD #39 OF SET 7 FOR CITY, al 'alamayn.
#
# The script did not find the city, al 'alamayn. Skipping...
#
# PROCESSING RECORD #40 OF SET 7 FOR CITY, ifrane.
#
# PROCESSING RECORD #41 OF SET 7 FOR CITY, bereznik.
#
# PROCESSING RECORD #42 OF SET 7 FOR CITY, santiago de cao.
#
# PROCESSING RECORD #43 OF SET 7 FOR CITY, shwebo.
#
# PROCESSING RECORD #44 OF SET 7 FOR CITY, chibougamau.
#
# PROCESSING RECORD #45 OF SET 7 FOR CITY, castillos.
#
# PROCESSING RECORD #46 OF SET 7 FOR CITY, filadelfia.
#
# PROCESSING RECORD #47 OF SET 7 FOR CITY, vanino.
#
# PROCESSING RECORD #48 OF SET 7 FOR CITY, ytyk-kyuyel'.
#
# The script did not find the city, ytyk-kyuyel'. Skipping...
#
# PROCESSING RECORD #49 OF SET 7 FOR CITY, rusera.
#
# PROCESSING RECORD #50 OF SET 7 FOR CITY, chivhu.
#
# PROCESSING RECORD #1 OF SET 8 FOR CITY, pierre.
#
# PROCESSING RECORD #2 OF SET 8 FOR CITY, 'ohonua.
#
# The script did not find the city, 'ohonua. Skipping...
#
# PROCESSING RECORD #3 OF SET 8 FOR CITY, coahuayana de hidalgo.
#
# PROCESSING RECORD #4 OF SET 8 FOR CITY, cascais.
#
# PROCESSING RECORD #5 OF SET 8 FOR CITY, nemuro.
#
# PROCESSING RECORD #6 OF SET 8 FOR CITY, mataram.
#
# PROCESSING RECORD #7 OF SET 8 FOR CITY, farafangana.
#
# PROCESSING RECORD #8 OF SET 8 FOR CITY, luderitz.
#
# PROCESSING RECORD #9 OF SET 8 FOR CITY, puerto baquerizo moreno.
#
# PROCESSING RECORD #10 OF SET 8 FOR CITY, merida.
#
# PROCESSING RECORD #11 OF SET 8 FOR CITY, la'ie.
#
# PROCESSING RECORD #12 OF SET 8 FOR CITY, broken hill.
#
# PROCESSING RECORD #13 OF SET 8 FOR CITY, yeppoon.
#
# PROCESSING RECORD #14 OF SET 8 FOR CITY, siyabuswa.
#
# PROCESSING RECORD #15 OF SET 8 FOR CITY, kaura namoda.
#
# PROCESSING RECORD #16 OF SET 8 FOR CITY, chukhloma.
#
# PROCESSING RECORD #17 OF SET 8 FOR CITY, woolgoolga.
#
# PROCESSING RECORD #18 OF SET 8 FOR CITY, siwa oasis.
#
# PROCESSING RECORD #19 OF SET 8 FOR CITY, mount gambier.
#
# PROCESSING RECORD #20 OF SET 8 FOR CITY, georgetown.
#
# PROCESSING RECORD #21 OF SET 8 FOR CITY, northport.
#
# PROCESSING RECORD #22 OF SET 8 FOR CITY, pho thong.
#
# PROCESSING RECORD #23 OF SET 8 FOR CITY, mu'minobod.
#
# PROCESSING RECORD #24 OF SET 8 FOR CITY, lata.
#
# PROCESSING RECORD #25 OF SET 8 FOR CITY, worland.
#
# PROCESSING RECORD #26 OF SET 8 FOR CITY, greenland.
#
# PROCESSING RECORD #27 OF SET 8 FOR CITY, fiambala.
#
# PROCESSING RECORD #28 OF SET 8 FOR CITY, 'aqrah.
#
# The script did not find the city, 'aqrah. Skipping...
#
# PROCESSING RECORD #29 OF SET 8 FOR CITY, trancas.
#
# PROCESSING RECORD #30 OF SET 8 FOR CITY, beya.
#
# PROCESSING RECORD #31 OF SET 8 FOR CITY, la palma.
#
# PROCESSING RECORD #32 OF SET 8 FOR CITY, al hamul.
#
# PROCESSING RECORD #33 OF SET 8 FOR CITY, talara.
#
# PROCESSING RECORD #34 OF SET 8 FOR CITY, flin flon.
#
# PROCESSING RECORD #35 OF SET 8 FOR CITY, eatonton.
#
# PROCESSING RECORD #36 OF SET 8 FOR CITY, ulladulla.
#
# PROCESSING RECORD #37 OF SET 8 FOR CITY, kapit.
#
# PROCESSING RECORD #38 OF SET 8 FOR CITY, greymouth.
#
# PROCESSING RECORD #39 OF SET 8 FOR CITY, lesozavodsk.
#
# PROCESSING RECORD #40 OF SET 8 FOR CITY, sao joao da barra.
#
# PROCESSING RECORD #41 OF SET 8 FOR CITY, chala.
#
# PROCESSING RECORD #42 OF SET 8 FOR CITY, ashland.
#
# PROCESSING RECORD #43 OF SET 8 FOR CITY, pokaran.
#
# PROCESSING RECORD #44 OF SET 8 FOR CITY, ankola.
#
# PROCESSING RECORD #45 OF SET 8 FOR CITY, salinas.
#
# PROCESSING RECORD #46 OF SET 8 FOR CITY, santa ana.
#
# PROCESSING RECORD #47 OF SET 8 FOR CITY, yopal.
#
# PROCESSING RECORD #48 OF SET 8 FOR CITY, prado.
#
# PROCESSING RECORD #49 OF SET 8 FOR CITY, awjilah.
#
# PROCESSING RECORD #50 OF SET 8 FOR CITY, suomussalmi.
#
# PROCESSING RECORD #1 OF SET 9 FOR CITY, yagry.
#
# The script did not find the city, yagry. Skipping...
#
# PROCESSING RECORD #2 OF SET 9 FOR CITY, riyadh.
#
# PROCESSING RECORD #3 OF SET 9 FOR CITY, urangan.
#
# PROCESSING RECORD #4 OF SET 9 FOR CITY, yaren.
#
# PROCESSING RECORD #5 OF SET 9 FOR CITY, cidreira.
#
# PROCESSING RECORD #6 OF SET 9 FOR CITY, usevia.
#
# PROCESSING RECORD #7 OF SET 9 FOR CITY, rethymno.
#
# PROCESSING RECORD #8 OF SET 9 FOR CITY, haiku-pauwela.
#
# PROCESSING RECORD #9 OF SET 9 FOR CITY, eaton rapids.
#
# PROCESSING RECORD #10 OF SET 9 FOR CITY, polessk.
#
# PROCESSING RECORD #11 OF SET 9 FOR CITY, ubari.
#
# PROCESSING RECORD #12 OF SET 9 FOR CITY, port macquarie.
#
# PROCESSING RECORD #13 OF SET 9 FOR CITY, riachao das neves.
#
# PROCESSING RECORD #14 OF SET 9 FOR CITY, moelan-sur-mer.
#
# PROCESSING RECORD #15 OF SET 9 FOR CITY, bliss corner.
#
# PROCESSING RECORD #16 OF SET 9 FOR CITY, mormugao.
#
# PROCESSING RECORD #17 OF SET 9 FOR CITY, san ignacio.
#
# PROCESSING RECORD #18 OF SET 9 FOR CITY, kolonia.
#
# PROCESSING RECORD #19 OF SET 9 FOR CITY, bardai.
#
# PROCESSING RECORD #20 OF SET 9 FOR CITY, minas de matahambre.
#
# The script did not find the city, minas de matahambre. Skipping...
#
# PROCESSING RECORD #21 OF SET 9 FOR CITY, armacao de buzios.
#
# PROCESSING RECORD #22 OF SET 9 FOR CITY, mahibadhoo.
#
# PROCESSING RECORD #23 OF SET 9 FOR CITY, arkalyk.
#
# PROCESSING RECORD #24 OF SET 9 FOR CITY, manokwari.
#
# PROCESSING RECORD #25 OF SET 9 FOR CITY, holualoa.
#
# PROCESSING RECORD #26 OF SET 9 FOR CITY, yabelo.
#
# PROCESSING RECORD #27 OF SET 9 FOR CITY, fisterra.
#
# PROCESSING RECORD #28 OF SET 9 FOR CITY, hilo.
#
# PROCESSING RECORD #29 OF SET 9 FOR CITY, saint-philippe.
#
# PROCESSING RECORD #30 OF SET 9 FOR CITY, gadzhiyevo.
#
# PROCESSING RECORD #31 OF SET 9 FOR CITY, moires.
#
# PROCESSING RECORD #32 OF SET 9 FOR CITY, tura.
#
# PROCESSING RECORD #33 OF SET 9 FOR CITY, malango.
#
# PROCESSING RECORD #34 OF SET 9 FOR CITY, soto la marina.
#
# PROCESSING RECORD #35 OF SET 9 FOR CITY, copala.
#
# PROCESSING RECORD #36 OF SET 9 FOR CITY, worthington.
#
# PROCESSING RECORD #37 OF SET 9 FOR CITY, ginir.
#
# PROCESSING RECORD #38 OF SET 9 FOR CITY, guixi.
#
# PROCESSING RECORD #39 OF SET 9 FOR CITY, dudinka.
#
# PROCESSING RECORD #40 OF SET 9 FOR CITY, poggio renatico.
#
# PROCESSING RECORD #41 OF SET 9 FOR CITY, nueva gerona.
#
# PROCESSING RECORD #42 OF SET 9 FOR CITY, srikakulam.
# PROCESSING RECORD #43 OF SET 9 FOR CITY, midvagur.
#
# PROCESSING RECORD #44 OF SET 9 FOR CITY, beledweyne.
#
# PROCESSING RECORD #45 OF SET 9 FOR CITY, dawson creek.
#
# PROCESSING RECORD #46 OF SET 9 FOR CITY, hadibu.
#
# PROCESSING RECORD #47 OF SET 9 FOR CITY, anacapri.
#
# PROCESSING RECORD #48 OF SET 9 FOR CITY, vadso.
#
# PROCESSING RECORD #49 OF SET 9 FOR CITY, charters towers.
#
# PROCESSING RECORD #50 OF SET 9 FOR CITY, new norfolk.
#
# PROCESSING RECORD #1 OF SET 10 FOR CITY, humboldt.
#
# PROCESSING RECORD #2 OF SET 10 FOR CITY, la ronge.
#
# PROCESSING RECORD #3 OF SET 10 FOR CITY, caibarien.
#
# PROCESSING RECORD #4 OF SET 10 FOR CITY, nuuk.
#
# PROCESSING RECORD #5 OF SET 10 FOR CITY, sarangani.
#
# PROCESSING RECORD #6 OF SET 10 FOR CITY, abraham's bay.
#
# The script did not find the city, abraham's bay. Skipping...
#
# PROCESSING RECORD #7 OF SET 10 FOR CITY, saynshand.
#
# PROCESSING RECORD #8 OF SET 10 FOR CITY, gannan.
#
# PROCESSING RECORD #9 OF SET 10 FOR CITY, kiunga.
#
# PROCESSING RECORD #10 OF SET 10 FOR CITY, yerofey pavlovich.
#
# PROCESSING RECORD #11 OF SET 10 FOR CITY, chos malal.
#
# PROCESSING RECORD #12 OF SET 10 FOR CITY, oamaru.
#
# PROCESSING RECORD #13 OF SET 10 FOR CITY, midland.
#
# PROCESSING RECORD #14 OF SET 10 FOR CITY, nazca.
#
# PROCESSING RECORD #15 OF SET 10 FOR CITY, polyarnyy.
#
# PROCESSING RECORD #16 OF SET 10 FOR CITY, barcelos.
#
# PROCESSING RECORD #17 OF SET 10 FOR CITY, barkhan.
#
# PROCESSING RECORD #18 OF SET 10 FOR CITY, kill devil hills.
#
# PROCESSING RECORD #19 OF SET 10 FOR CITY, sinabang.
#
# PROCESSING RECORD #20 OF SET 10 FOR CITY, agat village.
#
# PROCESSING RECORD #21 OF SET 10 FOR CITY, santana.
#
# PROCESSING RECORD #22 OF SET 10 FOR CITY, sassandra.
#
# PROCESSING RECORD #23 OF SET 10 FOR CITY, tambacounda.
#
# PROCESSING RECORD #24 OF SET 10 FOR CITY, band.
#
# PROCESSING RECORD #25 OF SET 10 FOR CITY, mil'kovo.
#
# PROCESSING RECORD #26 OF SET 10 FOR CITY, salekhard.
#
# PROCESSING RECORD #27 OF SET 10 FOR CITY, belyy yar.
#
# PROCESSING RECORD #28 OF SET 10 FOR CITY, kulhudhuffushi.
#
# PROCESSING RECORD #29 OF SET 10 FOR CITY, tongliao.
#
# PROCESSING RECORD #30 OF SET 10 FOR CITY, sur.
#
# PROCESSING RECORD #31 OF SET 10 FOR CITY, ghat.
#
# PROCESSING RECORD #32 OF SET 10 FOR CITY, lerwick.
#
# PROCESSING RECORD #33 OF SET 10 FOR CITY, lydenburg.
#
# PROCESSING RECORD #34 OF SET 10 FOR CITY, concepcion.
#
# PROCESSING RECORD #35 OF SET 10 FOR CITY, rangpur.
#
# PROCESSING RECORD #36 OF SET 10 FOR CITY, corner brook.
#
# PROCESSING RECORD #37 OF SET 10 FOR CITY, tagiura.
#
# PROCESSING RECORD #38 OF SET 10 FOR CITY, bubaque.
#
# PROCESSING RECORD #39 OF SET 10 FOR CITY, zaozersk.
#
# PROCESSING RECORD #40 OF SET 10 FOR CITY, pitea.
#
# PROCESSING RECORD #41 OF SET 10 FOR CITY, kodinsk.
#
# PROCESSING RECORD #42 OF SET 10 FOR CITY, shirdi.
#
# PROCESSING RECORD #43 OF SET 10 FOR CITY, bhakkar.
#
# PROCESSING RECORD #44 OF SET 10 FOR CITY, diamante.
#
# PROCESSING RECORD #45 OF SET 10 FOR CITY, las tablas.
#
# PROCESSING RECORD #46 OF SET 10 FOR CITY, kurumkan.
#
# PROCESSING RECORD #47 OF SET 10 FOR CITY, melekeok village.
#
# PROCESSING RECORD #48 OF SET 10 FOR CITY, horki.
#
# PROCESSING RECORD #49 OF SET 10 FOR CITY, bafoulabe.
#
# PROCESSING RECORD #50 OF SET 10 FOR CITY, meulaboh.
#
# PROCESSING RECORD #1 OF SET 11 FOR CITY, salalah.
#
# PROCESSING RECORD #2 OF SET 11 FOR CITY, bangassou.
#
# PROCESSING RECORD #3 OF SET 11 FOR CITY, antsiranana.
#
# PROCESSING RECORD #4 OF SET 11 FOR CITY, port augusta.
#
# PROCESSING RECORD #5 OF SET 11 FOR CITY, kirs.
#
# PROCESSING RECORD #6 OF SET 11 FOR CITY, troitsko-pechorsk.
#
# PROCESSING RECORD #7 OF SET 11 FOR CITY, callao.
#
# PROCESSING RECORD #8 OF SET 11 FOR CITY, ocos.
#
# PROCESSING RECORD #9 OF SET 11 FOR CITY, terrace.
#
# PROCESSING RECORD #10 OF SET 11 FOR CITY, sakakah.
#
# PROCESSING RECORD #11 OF SET 11 FOR CITY, el sauzal de rodriguez.
#
# PROCESSING RECORD #12 OF SET 11 FOR CITY, tokmak.
#
# PROCESSING RECORD #13 OF SET 11 FOR CITY, kresek.
#
# PROCESSING RECORD #14 OF SET 11 FOR CITY, viligili.
#
# The script did not find the city, viligili. Skipping...
#
# PROCESSING RECORD #15 OF SET 11 FOR CITY, conception bay south.
#
# PROCESSING RECORD #16 OF SET 11 FOR CITY, necochea.
#
# PROCESSING RECORD #17 OF SET 11 FOR CITY, ceeldheer.
#
# PROCESSING RECORD #18 OF SET 11 FOR CITY, wynyard.
#
# PROCESSING RECORD #19 OF SET 11 FOR CITY, corinto.
#
# PROCESSING RECORD #20 OF SET 11 FOR CITY, heihe.
#
# PROCESSING RECORD #21 OF SET 11 FOR CITY, sonsorol village.
#
# The script did not find the city, sonsorol village. Skipping...
#
# PROCESSING RECORD #22 OF SET 11 FOR CITY, sidi khaled.
#
# PROCESSING RECORD #23 OF SET 11 FOR CITY, island harbour.
#
# PROCESSING RECORD #24 OF SET 11 FOR CITY, alotau.
#
# The script did not find the city, alotau. Skipping...
#
# PROCESSING RECORD #25 OF SET 11 FOR CITY, whangarei.
#
# PROCESSING RECORD #26 OF SET 11 FOR CITY, vecvarkava.
#
# PROCESSING RECORD #27 OF SET 11 FOR CITY, kasangulu.
#
# PROCESSING RECORD #28 OF SET 11 FOR CITY, mana.
#
# PROCESSING RECORD #29 OF SET 11 FOR CITY, ust'-uda.
#
# PROCESSING RECORD #30 OF SET 11 FOR CITY, mitu.
#
# PROCESSING RECORD #31 OF SET 11 FOR CITY, ed damer.
#
# PROCESSING RECORD #32 OF SET 11 FOR CITY, waimea.
#
# PROCESSING RECORD #33 OF SET 11 FOR CITY, devinuwara.
#
# The script did not find the city, devinuwara. Skipping...
#
# PROCESSING RECORD #34 OF SET 11 FOR CITY, sant antoni de portmany.
#
# PROCESSING RECORD #35 OF SET 11 FOR CITY, canutama.
#
# PROCESSING RECORD #36 OF SET 11 FOR CITY, closepet.
#
# PROCESSING RECORD #37 OF SET 11 FOR CITY, cockburn town.
#
# PROCESSING RECORD #38 OF SET 11 FOR CITY, puerto deseado.
#
# PROCESSING RECORD #39 OF SET 11 FOR CITY, chagoda.
#
# PROCESSING RECORD #40 OF SET 11 FOR CITY, nikolayevsk-on-amure.
#
# PROCESSING RECORD #41 OF SET 11 FOR CITY, floro.
#
# PROCESSING RECORD #42 OF SET 11 FOR CITY, smidovich.
#
# PROCESSING RECORD #43 OF SET 11 FOR CITY, xiongzhou.
#
# PROCESSING RECORD #44 OF SET 11 FOR CITY, tataouine.
#
# PROCESSING RECORD #45 OF SET 11 FOR CITY, aquidauana.
#
# PROCESSING RECORD #46 OF SET 11 FOR CITY, el calafate.
#
# PROCESSING RECORD #47 OF SET 11 FOR CITY, rio preto da eva.
#
# PROCESSING RECORD #48 OF SET 11 FOR CITY, camana.
#
# PROCESSING RECORD #49 OF SET 11 FOR CITY, torzhok.
#
# PROCESSING RECORD #50 OF SET 11 FOR CITY, inverloch.
#
# PROCESSING RECORD #1 OF SET 12 FOR CITY, taltal.
#
# PROCESSING RECORD #2 OF SET 12 FOR CITY, launceston.
#
# PROCESSING RECORD #3 OF SET 12 FOR CITY, curup.
#
# PROCESSING RECORD #4 OF SET 12 FOR CITY, krasnyy chikoy.
#
# PROCESSING RECORD #5 OF SET 12 FOR CITY, astara.
#
# PROCESSING RECORD #6 OF SET 12 FOR CITY, camayenne.
#
# PROCESSING RECORD #7 OF SET 12 FOR CITY, puerto ayacucho.
#
# PROCESSING RECORD #8 OF SET 12 FOR CITY, cananeia.
#
# PROCESSING RECORD #9 OF SET 12 FOR CITY, ndola.
#
# PROCESSING RECORD #10 OF SET 12 FOR CITY, chui.
#
# PROCESSING RECORD #11 OF SET 12 FOR CITY, quibala.
#
# PROCESSING RECORD #12 OF SET 12 FOR CITY, severo-yeniseyskiy.
#
# PROCESSING RECORD #13 OF SET 12 FOR CITY, festus.
#
# PROCESSING RECORD #14 OF SET 12 FOR CITY, mahajanga.
#
# PROCESSING RECORD #15 OF SET 12 FOR CITY, elmendorf air force base.
#
# The script did not find the city, elmendorf air force base. Skipping...
#
# PROCESSING RECORD #16 OF SET 12 FOR CITY, ilha de mocambique.
#
# PROCESSING RECORD #17 OF SET 12 FOR CITY, mlimba.
#
# PROCESSING RECORD #18 OF SET 12 FOR CITY, wakkanai.
#
# PROCESSING RECORD #19 OF SET 12 FOR CITY, shakiso.
#
# PROCESSING RECORD #20 OF SET 12 FOR CITY, yemetsk.
#
# PROCESSING RECORD #21 OF SET 12 FOR CITY, lubao.
#
# PROCESSING RECORD #22 OF SET 12 FOR CITY, al qadarif.
#
# PROCESSING RECORD #23 OF SET 12 FOR CITY, coari.
#
# PROCESSING RECORD #24 OF SET 12 FOR CITY, flying fish cove.
#
# PROCESSING RECORD #25 OF SET 12 FOR CITY, palikir - national government center.
#
# PROCESSING RECORD #26 OF SET 12 FOR CITY, conceicao da barra.
#
# PROCESSING RECORD #27 OF SET 12 FOR CITY, ballarat east.
#
# PROCESSING RECORD #28 OF SET 12 FOR CITY, altai.
#
# PROCESSING RECORD #29 OF SET 12 FOR CITY, mili.
#
# PROCESSING RECORD #30 OF SET 12 FOR CITY, toga village.
#
# The script did not find the city, toga village. Skipping...
#
# PROCESSING RECORD #31 OF SET 12 FOR CITY, mbake.
#
# PROCESSING RECORD #32 OF SET 12 FOR CITY, beloyarskiy.
#
# PROCESSING RECORD #33 OF SET 12 FOR CITY, edmond.
#
# PROCESSING RECORD #34 OF SET 12 FOR CITY, ocean shores.
#
# PROCESSING RECORD #35 OF SET 12 FOR CITY, as saffaniyah.
#
# PROCESSING RECORD #36 OF SET 12 FOR CITY, sovetskaya gavan'.
# PROCESSING RECORD #37 OF SET 12 FOR CITY, karyes.
#
# PROCESSING RECORD #38 OF SET 12 FOR CITY, newman.
#
# PROCESSING RECORD #39 OF SET 12 FOR CITY, kavieng.
#
# PROCESSING RECORD #40 OF SET 12 FOR CITY, kirgiz-miyaki.
#
# PROCESSING RECORD #41 OF SET 12 FOR CITY, kavaratti.
#
# PROCESSING RECORD #42 OF SET 12 FOR CITY, bikenibeu village.
#
# PROCESSING RECORD #43 OF SET 12 FOR CITY, yala.
#
# PROCESSING RECORD #44 OF SET 12 FOR CITY, marsh harbour.
#
# Data Retrieval for city weather DataFrame is complete.

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Records Count**

# %%
cityWeatherCountIntegerVariable \
    = cityWeatherDataFrame \
        ['City'] \
            .count()

print \
    (f"There are {cityWeatherCountIntegerVariable} " \
     + f"records in the city weather DataFrame.")
# Out:
# There are 562 records in the city weather DataFrame.

# %% [markdown]
# ### **Display City Weather DataFrame**

# %%
captionString \
    = 'Table: 1.1.1: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_37258 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_37258_row0_col0, #T_37258_row0_col1, #T_37258_row0_col2, #T_37258_row0_col3, #T_37258_row0_col4, #T_37258_row0_col7, #T_37258_row0_col8, #T_37258_row1_col0, #T_37258_row1_col1, #T_37258_row1_col2, #T_37258_row1_col4, #T_37258_row1_col5, #T_37258_row1_col6, #T_37258_row1_col7, #T_37258_row1_col8, #T_37258_row2_col0, #T_37258_row2_col1, #T_37258_row2_col2, #T_37258_row2_col3, #T_37258_row2_col4, #T_37258_row2_col6, #T_37258_row2_col7, #T_37258_row2_col8, #T_37258_row3_col0, #T_37258_row3_col1, #T_37258_row3_col2, #T_37258_row3_col4, #T_37258_row3_col5, #T_37258_row3_col6, #T_37258_row3_col7, #T_37258_row3_col8, #T_37258_row4_col0, #T_37258_row4_col1, #T_37258_row4_col2, #T_37258_row4_col3, #T_37258_row4_col4, #T_37258_row4_col7, #T_37258_row4_col8, #T_37258_row5_col0, #T_37258_row5_col1, #T_37258_row5_col2, #T_37258_row5_col3, #T_37258_row5_col4, #T_37258_row5_col5, #T_37258_row5_col6, #T_37258_row5_col7, #T_37258_row5_col8, #T_37258_row6_col0, #T_37258_row6_col1, #T_37258_row6_col2, #T_37258_row6_col3, #T_37258_row6_col4, #T_37258_row6_col5, #T_37258_row6_col6, #T_37258_row6_col7, #T_37258_row6_col8, #T_37258_row7_col0, #T_37258_row7_col1, #T_37258_row7_col2, #T_37258_row7_col3, #T_37258_row7_col4, #T_37258_row7_col6, #T_37258_row7_col7, #T_37258_row7_col8, #T_37258_row8_col0, #T_37258_row8_col1, #T_37258_row8_col2, #T_37258_row8_col3, #T_37258_row8_col5, #T_37258_row8_col6, #T_37258_row8_col7, #T_37258_row8_col8, #T_37258_row9_col0, #T_37258_row9_col1, #T_37258_row9_col2, #T_37258_row9_col3, #T_37258_row9_col4, #T_37258_row9_col5, #T_37258_row9_col6, #T_37258_row9_col7, #T_37258_row9_col8, #T_37258_row10_col0, #T_37258_row10_col1, #T_37258_row10_col2, #T_37258_row10_col3, #T_37258_row10_col4, #T_37258_row10_col5, #T_37258_row10_col6, #T_37258_row10_col7, #T_37258_row10_col8, #T_37258_row11_col0, #T_37258_row11_col1, #T_37258_row11_col2, #T_37258_row11_col3, #T_37258_row11_col6, #T_37258_row11_col7, #T_37258_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_37258_row0_col5, #T_37258_row3_col3, #T_37258_row4_col5, #T_37258_row4_col6, #T_37258_row7_col5, #T_37258_row11_col4, #T_37258_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_37258_row0_col6, #T_37258_row1_col3, #T_37258_row2_col5, #T_37258_row8_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_37258">
#   <caption>Table: 1.1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_37258_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_37258_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_37258_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_37258_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_37258_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_37258_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_37258_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_37258_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_37258_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_37258_row0_col0" class="data row0 col0" >ust'-barguzin</td>
#       <td id="T_37258_row0_col1" class="data row0 col1" >53.45</td>
#       <td id="T_37258_row0_col2" class="data row0 col2" >108.98</td>
#       <td id="T_37258_row0_col3" class="data row0 col3" >52.56° F</td>
#       <td id="T_37258_row0_col4" class="data row0 col4" >89%</td>
#       <td id="T_37258_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_37258_row0_col6" class="data row0 col6" >4.18</td>
#       <td id="T_37258_row0_col7" class="data row0 col7" >RU</td>
#       <td id="T_37258_row0_col8" class="data row0 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_37258_row1_col0" class="data row1 col0" >longyearbyen</td>
#       <td id="T_37258_row1_col1" class="data row1 col1" >78.22</td>
#       <td id="T_37258_row1_col2" class="data row1 col2" >15.64</td>
#       <td id="T_37258_row1_col3" class="data row1 col3" >22.84° F</td>
#       <td id="T_37258_row1_col4" class="data row1 col4" >80%</td>
#       <td id="T_37258_row1_col5" class="data row1 col5" >20%</td>
#       <td id="T_37258_row1_col6" class="data row1 col6" >5.75</td>
#       <td id="T_37258_row1_col7" class="data row1 col7" >SJ</td>
#       <td id="T_37258_row1_col8" class="data row1 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_37258_row2_col0" class="data row2 col0" >lebu</td>
#       <td id="T_37258_row2_col1" class="data row2 col1" >-37.62</td>
#       <td id="T_37258_row2_col2" class="data row2 col2" >-73.65</td>
#       <td id="T_37258_row2_col3" class="data row2 col3" >52.09° F</td>
#       <td id="T_37258_row2_col4" class="data row2 col4" >65%</td>
#       <td id="T_37258_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_37258_row2_col6" class="data row2 col6" >12.62</td>
#       <td id="T_37258_row2_col7" class="data row2 col7" >CL</td>
#       <td id="T_37258_row2_col8" class="data row2 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_37258_row3_col0" class="data row3 col0" >carutapera</td>
#       <td id="T_37258_row3_col1" class="data row3 col1" >-1.20</td>
#       <td id="T_37258_row3_col2" class="data row3 col2" >-46.02</td>
#       <td id="T_37258_row3_col3" class="data row3 col3" >86.38° F</td>
#       <td id="T_37258_row3_col4" class="data row3 col4" >63%</td>
#       <td id="T_37258_row3_col5" class="data row3 col5" >3%</td>
#       <td id="T_37258_row3_col6" class="data row3 col6" >12.64</td>
#       <td id="T_37258_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_37258_row3_col8" class="data row3 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_37258_row4_col0" class="data row4 col0" >alofi</td>
#       <td id="T_37258_row4_col1" class="data row4 col1" >-19.06</td>
#       <td id="T_37258_row4_col2" class="data row4 col2" >-169.92</td>
#       <td id="T_37258_row4_col3" class="data row4 col3" >71.49° F</td>
#       <td id="T_37258_row4_col4" class="data row4 col4" >68%</td>
#       <td id="T_37258_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_37258_row4_col6" class="data row4 col6" >19.57</td>
#       <td id="T_37258_row4_col7" class="data row4 col7" >NU</td>
#       <td id="T_37258_row4_col8" class="data row4 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_37258_row5_col0" class="data row5 col0" >teteven</td>
#       <td id="T_37258_row5_col1" class="data row5 col1" >42.92</td>
#       <td id="T_37258_row5_col2" class="data row5 col2" >24.27</td>
#       <td id="T_37258_row5_col3" class="data row5 col3" >74.39° F</td>
#       <td id="T_37258_row5_col4" class="data row5 col4" >45%</td>
#       <td id="T_37258_row5_col5" class="data row5 col5" >16%</td>
#       <td id="T_37258_row5_col6" class="data row5 col6" >6.40</td>
#       <td id="T_37258_row5_col7" class="data row5 col7" >BG</td>
#       <td id="T_37258_row5_col8" class="data row5 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_37258_row6_col0" class="data row6 col0" >morondava</td>
#       <td id="T_37258_row6_col1" class="data row6 col1" >-20.28</td>
#       <td id="T_37258_row6_col2" class="data row6 col2" >44.28</td>
#       <td id="T_37258_row6_col3" class="data row6 col3" >77.72° F</td>
#       <td id="T_37258_row6_col4" class="data row6 col4" >83%</td>
#       <td id="T_37258_row6_col5" class="data row6 col5" >69%</td>
#       <td id="T_37258_row6_col6" class="data row6 col6" >4.90</td>
#       <td id="T_37258_row6_col7" class="data row6 col7" >MG</td>
#       <td id="T_37258_row6_col8" class="data row6 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_37258_row7_col0" class

# %% [markdown]
# ### **Data Export to CSV File**

# %%
subroutine \
    .WriteDataFrameToCSVFile \
        (cityWeatherDataFrame,
         local_constant.WEATHER_DATA_FILE_PATH,
         local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Data Import from CSV File**

# %%
sampleCityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Display Sample City Weather DataFrame**

# %%
captionString \
    = 'Table: 1.1.2: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_3b634 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_3b634_row0_col0, #T_3b634_row0_col1, #T_3b634_row0_col2, #T_3b634_row0_col3, #T_3b634_row0_col4, #T_3b634_row0_col7, #T_3b634_row0_col8, #T_3b634_row1_col0, #T_3b634_row1_col1, #T_3b634_row1_col2, #T_3b634_row1_col4, #T_3b634_row1_col5, #T_3b634_row1_col6, #T_3b634_row1_col7, #T_3b634_row1_col8, #T_3b634_row2_col0, #T_3b634_row2_col1, #T_3b634_row2_col2, #T_3b634_row2_col3, #T_3b634_row2_col4, #T_3b634_row2_col6, #T_3b634_row2_col7, #T_3b634_row2_col8, #T_3b634_row3_col0, #T_3b634_row3_col1, #T_3b634_row3_col2, #T_3b634_row3_col4, #T_3b634_row3_col5, #T_3b634_row3_col6, #T_3b634_row3_col7, #T_3b634_row3_col8, #T_3b634_row4_col0, #T_3b634_row4_col1, #T_3b634_row4_col2, #T_3b634_row4_col3, #T_3b634_row4_col4, #T_3b634_row4_col7, #T_3b634_row4_col8, #T_3b634_row5_col0, #T_3b634_row5_col1, #T_3b634_row5_col2, #T_3b634_row5_col3, #T_3b634_row5_col4, #T_3b634_row5_col5, #T_3b634_row5_col6, #T_3b634_row5_col7, #T_3b634_row5_col8, #T_3b634_row6_col0, #T_3b634_row6_col1, #T_3b634_row6_col2, #T_3b634_row6_col3, #T_3b634_row6_col4, #T_3b634_row6_col5, #T_3b634_row6_col6, #T_3b634_row6_col7, #T_3b634_row6_col8, #T_3b634_row7_col0, #T_3b634_row7_col1, #T_3b634_row7_col2, #T_3b634_row7_col3, #T_3b634_row7_col4, #T_3b634_row7_col6, #T_3b634_row7_col7, #T_3b634_row7_col8, #T_3b634_row8_col0, #T_3b634_row8_col1, #T_3b634_row8_col2, #T_3b634_row8_col3, #T_3b634_row8_col5, #T_3b634_row8_col6, #T_3b634_row8_col7, #T_3b634_row8_col8, #T_3b634_row9_col0, #T_3b634_row9_col1, #T_3b634_row9_col2, #T_3b634_row9_col3, #T_3b634_row9_col4, #T_3b634_row9_col5, #T_3b634_row9_col6, #T_3b634_row9_col7, #T_3b634_row9_col8, #T_3b634_row10_col0, #T_3b634_row10_col1, #T_3b634_row10_col2, #T_3b634_row10_col3, #T_3b634_row10_col4, #T_3b634_row10_col5, #T_3b634_row10_col6, #T_3b634_row10_col7, #T_3b634_row10_col8, #T_3b634_row11_col0, #T_3b634_row11_col1, #T_3b634_row11_col2, #T_3b634_row11_col3, #T_3b634_row11_col6, #T_3b634_row11_col7, #T_3b634_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_3b634_row0_col5, #T_3b634_row3_col3, #T_3b634_row4_col5, #T_3b634_row4_col6, #T_3b634_row7_col5, #T_3b634_row11_col4, #T_3b634_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_3b634_row0_col6, #T_3b634_row1_col3, #T_3b634_row2_col5, #T_3b634_row8_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_3b634">
#   <caption>Table: 1.1.2: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_3b634_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_3b634_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_3b634_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_3b634_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_3b634_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_3b634_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_3b634_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_3b634_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_3b634_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3b634_row0_col0" class="data row0 col0" >ust'-barguzin</td>
#       <td id="T_3b634_row0_col1" class="data row0 col1" >53.45</td>
#       <td id="T_3b634_row0_col2" class="data row0 col2" >108.98</td>
#       <td id="T_3b634_row0_col3" class="data row0 col3" >52.56° F</td>
#       <td id="T_3b634_row0_col4" class="data row0 col4" >89%</td>
#       <td id="T_3b634_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_3b634_row0_col6" class="data row0 col6" >4.18</td>
#       <td id="T_3b634_row0_col7" class="data row0 col7" >RU</td>
#       <td id="T_3b634_row0_col8" class="data row0 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_3b634_row1_col0" class="data row1 col0" >longyearbyen</td>
#       <td id="T_3b634_row1_col1" class="data row1 col1" >78.22</td>
#       <td id="T_3b634_row1_col2" class="data row1 col2" >15.64</td>
#       <td id="T_3b634_row1_col3" class="data row1 col3" >22.84° F</td>
#       <td id="T_3b634_row1_col4" class="data row1 col4" >80%</td>
#       <td id="T_3b634_row1_col5" class="data row1 col5" >20%</td>
#       <td id="T_3b634_row1_col6" class="data row1 col6" >5.75</td>
#       <td id="T_3b634_row1_col7" class="data row1 col7" >SJ</td>
#       <td id="T_3b634_row1_col8" class="data row1 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_3b634_row2_col0" class="data row2 col0" >lebu</td>
#       <td id="T_3b634_row2_col1" class="data row2 col1" >-37.62</td>
#       <td id="T_3b634_row2_col2" class="data row2 col2" >-73.65</td>
#       <td id="T_3b634_row2_col3" class="data row2 col3" >52.09° F</td>
#       <td id="T_3b634_row2_col4" class="data row2 col4" >65%</td>
#       <td id="T_3b634_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_3b634_row2_col6" class="data row2 col6" >12.62</td>
#       <td id="T_3b634_row2_col7" class="data row2 col7" >CL</td>
#       <td id="T_3b634_row2_col8" class="data row2 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_3b634_row3_col0" class="data row3 col0" >carutapera</td>
#       <td id="T_3b634_row3_col1" class="data row3 col1" >-1.20</td>
#       <td id="T_3b634_row3_col2" class="data row3 col2" >-46.02</td>
#       <td id="T_3b634_row3_col3" class="data row3 col3" >86.38° F</td>
#       <td id="T_3b634_row3_col4" class="data row3 col4" >63%</td>
#       <td id="T_3b634_row3_col5" class="data row3 col5" >3%</td>
#       <td id="T_3b634_row3_col6" class="data row3 col6" >12.64</td>
#       <td id="T_3b634_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_3b634_row3_col8" class="data row3 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_3b634_row4_col0" class="data row4 col0" >alofi</td>
#       <td id="T_3b634_row4_col1" class="data row4 col1" >-19.06</td>
#       <td id="T_3b634_row4_col2" class="data row4 col2" >-169.92</td>
#       <td id="T_3b634_row4_col3" class="data row4 col3" >71.49° F</td>
#       <td id="T_3b634_row4_col4" class="data row4 col4" >68%</td>
#       <td id="T_3b634_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_3b634_row4_col6" class="data row4 col6" >19.57</td>
#       <td id="T_3b634_row4_col7" class="data row4 col7" >NU</td>
#       <td id="T_3b634_row4_col8" class="data row4 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_3b634_row5_col0" class="data row5 col0" >teteven</td>
#       <td id="T_3b634_row5_col1" class="data row5 col1" >42.92</td>
#       <td id="T_3b634_row5_col2" class="data row5 col2" >24.27</td>
#       <td id="T_3b634_row5_col3" class="data row5 col3" >74.39° F</td>
#       <td id="T_3b634_row5_col4" class="data row5 col4" >45%</td>
#       <td id="T_3b634_row5_col5" class="data row5 col5" >16%</td>
#       <td id="T_3b634_row5_col6" class="data row5 col6" >6.40</td>
#       <td id="T_3b634_row5_col7" class="data row5 col7" >BG</td>
#       <td id="T_3b634_row5_col8" class="data row5 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_3b634_row6_col0" class="data row6 col0" >morondava</td>
#       <td id="T_3b634_row6_col1" class="data row6 col1" >-20.28</td>
#       <td id="T_3b634_row6_col2" class="data row6 col2" >44.28</td>
#       <td id="T_3b634_row6_col3" class="data row6 col3" >77.72° F</td>
#       <td id="T_3b634_row6_col4" class="data row6 col4" >83%</td>
#       <td id="T_3b634_row6_col5" class="data row6 col5" >69%</td>
#       <td id="T_3b634_row6_col6" class="data row6 col6" >4.90</td>
#       <td id="T_3b634_row6_col7" class="data row6 col7" >MG</td>
#       <td id="T_3b634_row6_col8" class="data row6 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_3b634_row7_col0" class

# %% [markdown]
# ## **Section 1.2: Scatter Plots w/Regression**

# %% [markdown]
# ### **Temperature Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1: Temperature Vs. Latitude (Scatter Plot)')

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1.1: Temperature Vs. Latitude (Scatter Plot w/Regression)', 
         2, -48.0, 28.0)
# Out:
# r-value:     0.8252
# r-squared:   0.6809

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### Although this assignment is about linear regression, I notice that the independent variable, latitude, has a relationship with the dependent variable, temperature, just not a linear one.  With linear regression, we obtain a -0.1346 correlation; with quadratic regression, the correlation increases to 0.7879.  In practiice, analysts consider a 0.60-0.79 correlation to be strong.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.2.2: Humidity Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Cloudiness Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.2.3: Cloudiness Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.2.4: Wind Speed vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **City Weather Information Correlation Matrix**

# %%
frameDictionary \
    = {'Latitude': 
            cityWeatherDataFrame \
                ['Latitude'], 
       'Temperature': 
            cityWeatherDataFrame \
                ['Temperature'], 
       'Humidity': 
            cityWeatherDataFrame \
                ['Humidity'],
       'Cloudiness': 
            cityWeatherDataFrame \
                ['Cloudiness'],
       'Wind Speed':
            cityWeatherDataFrame \
                ['Wind Speed']}


function \
    .ReturnCorrelationTableStandardFormat \
        (pd \
             .DataFrame \
                 (frameDictionary),
         'Table 1.2.1: City Weather Correlation Matrix')
# Out:
# <style type="text/css">
# #T_10423 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_10423_row0_col0, #T_10423_row0_col1, #T_10423_row0_col2, #T_10423_row0_col3, #T_10423_row0_col4, #T_10423_row1_col0, #T_10423_row1_col1, #T_10423_row1_col2, #T_10423_row1_col3, #T_10423_row1_col4, #T_10423_row2_col0, #T_10423_row2_col1, #T_10423_row2_col2, #T_10423_row2_col3, #T_10423_row2_col4, #T_10423_row3_col0, #T_10423_row3_col1, #T_10423_row3_col2, #T_10423_row3_col3, #T_10423_row3_col4, #T_10423_row4_col0, #T_10423_row4_col1, #T_10423_row4_col2, #T_10423_row4_col3, #T_10423_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_10423">
#   <caption>Table 1.2.1: City Weather Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10423_level0_col0" class="col_heading level0 col0" >Latitude</th>
#       <th id="T_10423_level0_col1" class="col_heading level0 col1" >Temperature</th>
#       <th id="T_10423_level0_col2" class="col_heading level0 col2" >Humidity</th>
#       <th id="T_10423_level0_col3" class="col_heading level0 col3" >Cloudiness</th>
#       <th id="T_10423_level0_col4" class="col_heading level0 col4" >Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10423_level0_row0" class="row_heading level0 row0" >Latitude</th>
#       <td id="T_10423_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_10423_row0_col1" class="data row0 col1" >-0.300390</td>
#       <td id="T_10423_row0_col2" class="data row0 col2" >0.030063</td>
#       <td id="T_10423_row0_col3" class="data row0 col3" >-0.018386</td>
#       <td id="T_10423_row0_col4" class="data row0 col4" >-0.160250</td>
#     </tr>
#     <tr>
#       <th id="T_10423_level0_row1" class="row_heading level0 row1" >Temperature</th>
#       <td id="T_10423_row1_col0" class="data row1 col0" >-0.300390</td>
#       <td id="T_10423_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_10423_row1_col2" class="data row1 col2" >-0.392030</td>
#       <td id="T_10423_row1_col3" class="data row1 col3" >-0.098595</td>
#       <td id="T_10423_row1_col4" class="data row1 col4" >-0.007461</td>
#     </tr>
#     <tr>
#       <th id="T_10423_level0_row2" class="row_heading level0 row2" >Humidity</th>
#       <td id="T_10423_row2_col0" class="data row2 col0" >0.030063</td>
#       <td id="T_10423_row2_col1" class="data row2 col1" >-0.392030</td>
#       <td id="T_10423_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_10423_row2_col3" class="data row2 col3" >0.389305</td>
#       <td id="T_10423_row2_col4" class="data row2 col4" >0.035823</td>
#     </tr>
#     <tr>
#       <th id="T_10423_level0_row3" class="row_heading level0 row3" >Cloudiness</th>
#       <td id="T_10423_row3_col0" class="data row3 col0" >-0.018386</td>
#       <td id="T_10423_row3_col1" class="data row3 col1" >-0.098595</td>
#       <td id="T_10423_row3_col2" class="data row3 col2" >0.389305</td>
#       <td id="T_10423_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_10423_row3_col4" class="data row3 col4" >0.053470</td>
#     </tr>
#     <tr>
#       <th id="T_10423_level0_row4" class="row_heading level0 row4" >Wind Speed</th>
#       <td id="T_10423_row4_col0" class="data row4 col0" >-0.160250</td>
#       <td id="T_10423_row4_col1" class="data row4 col1" >-0.007461</td>
#       <td id="T_10423_row4_col2" class="data row4 col2" >0.035823</td>
#       <td id="T_10423_row4_col3" class="data row4 col3" >0.053470</td>
#       <td id="T_10423_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Discussion about correlation:** YOUR RESPONSE HERE

# %% [markdown]
# ## **Section 1.3: Hemisphere Scatter Plots with Linear Regression**

# %% [markdown]
# ### **Northern Hemisphere City Weather Information**

# %%
northernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (northernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.1: City Weather Information (Northern Hemisphere)')
# Out:
# <style type="text/css">
# #T_22a29 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_22a29_row0_col0, #T_22a29_row0_col1, #T_22a29_row0_col2, #T_22a29_row0_col3, #T_22a29_row0_col4, #T_22a29_row0_col6, #T_22a29_row0_col7, #T_22a29_row0_col8, #T_22a29_row1_col0, #T_22a29_row1_col1, #T_22a29_row1_col2, #T_22a29_row1_col4, #T_22a29_row1_col5, #T_22a29_row1_col6, #T_22a29_row1_col7, #T_22a29_row1_col8, #T_22a29_row2_col0, #T_22a29_row2_col1, #T_22a29_row2_col2, #T_22a29_row2_col3, #T_22a29_row2_col4, #T_22a29_row2_col5, #T_22a29_row2_col6, #T_22a29_row2_col7, #T_22a29_row2_col8, #T_22a29_row3_col0, #T_22a29_row3_col1, #T_22a29_row3_col2, #T_22a29_row3_col3, #T_22a29_row3_col4, #T_22a29_row3_col7, #T_22a29_row3_col8, #T_22a29_row4_col0, #T_22a29_row4_col1, #T_22a29_row4_col2, #T_22a29_row4_col3, #T_22a29_row4_col4, #T_22a29_row4_col6, #T_22a29_row4_col7, #T_22a29_row4_col8, #T_22a29_row5_col0, #T_22a29_row5_col1, #T_22a29_row5_col2, #T_22a29_row5_col3, #T_22a29_row5_col4, #T_22a29_row5_col5, #T_22a29_row5_col6, #T_22a29_row5_col7, #T_22a29_row5_col8, #T_22a29_row6_col0, #T_22a29_row6_col1, #T_22a29_row6_col2, #T_22a29_row6_col3, #T_22a29_row6_col4, #T_22a29_row6_col5, #T_22a29_row6_col6, #T_22a29_row6_col7, #T_22a29_row6_col8, #T_22a29_row7_col0, #T_22a29_row7_col1, #T_22a29_row7_col2, #T_22a29_row7_col3, #T_22a29_row7_col4, #T_22a29_row7_col6, #T_22a29_row7_col7, #T_22a29_row7_col8, #T_22a29_row8_col0, #T_22a29_row8_col1, #T_22a29_row8_col2, #T_22a29_row8_col3, #T_22a29_row8_col6, #T_22a29_row8_col7, #T_22a29_row8_col8, #T_22a29_row9_col0, #T_22a29_row9_col1, #T_22a29_row9_col2, #T_22a29_row9_col3, #T_22a29_row9_col4, #T_22a29_row9_col5, #T_22a29_row9_col6, #T_22a29_row9_col7, #T_22a29_row9_col8, #T_22a29_row10_col0, #T_22a29_row10_col1, #T_22a29_row10_col2, #T_22a29_row10_col7, #T_22a29_row10_col8, #T_22a29_row11_col0, #T_22a29_row11_col1, #T_22a29_row11_col2, #T_22a29_row11_col3, #T_22a29_row11_col4, #T_22a29_row11_col5, #T_22a29_row11_col6, #T_22a29_row11_col7, #T_22a29_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_22a29_row0_col5, #T_22a29_row3_col5, #T_22a29_row3_col6, #T_22a29_row4_col5, #T_22a29_row7_col5, #T_22a29_row8_col4, #T_22a29_row8_col5, #T_22a29_row10_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_22a29_row1_col3, #T_22a29_row10_col4, #T_22a29_row10_col5, #T_22a29_row10_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_22a29">
#   <caption>Table: 1.3.1: City Weather Information (Northern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_22a29_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_22a29_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_22a29_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_22a29_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_22a29_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_22a29_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_22a29_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_22a29_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_22a29_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_22a29_row0_col0" class="data row0 col0" >ust'-barguzin</td>
#       <td id="T_22a29_row0_col1" class="data row0 col1" >53.45</td>
#       <td id="T_22a29_row0_col2" class="data row0 col2" >108.98</td>
#       <td id="T_22a29_row0_col3" class="data row0 col3" >52.56° F</td>
#       <td id="T_22a29_row0_col4" class="data row0 col4" >89%</td>
#       <td id="T_22a29_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_22a29_row0_col6" class="data row0 col6" >4.18</td>
#       <td id="T_22a29_row0_col7" class="data row0 col7" >RU</td>
#       <td id="T_22a29_row0_col8" class="data row0 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_22a29_row1_col0" class="data row1 col0" >longyearbyen</td>
#       <td id="T_22a29_row1_col1" class="data row1 col1" >78.22</td>
#       <td id="T_22a29_row1_col2" class="data row1 col2" >15.64</td>
#       <td id="T_22a29_row1_col3" class="data row1 col3" >22.84° F</td>
#       <td id="T_22a29_row1_col4" class="data row1 col4" >80%</td>
#       <td id="T_22a29_row1_col5" class="data row1 col5" >20%</td>
#       <td id="T_22a29_row1_col6" class="data row1 col6" >5.75</td>
#       <td id="T_22a29_row1_col7" class="data row1 col7" >SJ</td>
#       <td id="T_22a29_row1_col8" class="data row1 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_22a29_row2_col0" class="data row2 col0" >teteven</td>
#       <td id="T_22a29_row2_col1" class="data row2 col1" >42.92</td>
#       <td id="T_22a29_row2_col2" class="data row2 col2" >24.27</td>
#       <td id="T_22a29_row2_col3" class="data row2 col3" >74.39° F</td>
#       <td id="T_22a29_row2_col4" class="data row2 col4" >45%</td>
#       <td id="T_22a29_row2_col5" class="data row2 col5" >16%</td>
#       <td id="T_22a29_row2_col6" class="data row2 col6" >6.40</td>
#       <td id="T_22a29_row2_col7" class="data row2 col7" >BG</td>
#       <td id="T_22a29_row2_col8" class="data row2 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_22a29_row3_col0" class="data row3 col0" >yellowknife</td>
#       <td id="T_22a29_row3_col1" class="data row3 col1" >62.46</td>
#       <td id="T_22a29_row3_col2" class="data row3 col2" >-114.35</td>
#       <td id="T_22a29_row3_col3" class="data row3 col3" >52.32° F</td>
#       <td id="T_22a29_row3_col4" class="data row3 col4" >82%</td>
#       <td id="T_22a29_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_22a29_row3_col6" class="data row3 col6" >10.36</td>
#       <td id="T_22a29_row3_col7" class="data row3 col7" >CA</td>
#       <td id="T_22a29_row3_col8" class="data row3 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_22a29_row4_col0" class="data row4 col0" >revda</td>
#       <td id="T_22a29_row4_col1" class="data row4 col1" >56.80</td>
#       <td id="T_22a29_row4_col2" class="data row4 col2" >59.93</td>
#       <td id="T_22a29_row4_col3" class="data row4 col3" >51.19° F</td>
#       <td id="T_22a29_row4_col4" class="data row4 col4" >93%</td>
#       <td id="T_22a29_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_22a29_row4_col6" class="data row4 col6" >4.97</td>
#       <td id="T_22a29_row4_col7" class="data row4 col7" >RU</td>
#       <td id="T_22a29_row4_col8" class="data row4 col8" >2023-09-23 11:54:06</td>
#     </tr>
#     <tr>
#       <td id="T_22a29_row5_col0" class="data row5 col0" >hawaiian paradise park</td>
#       <td id="T_22a29_row5_col1" class="data row5 col1" >19.59</td>
#       <td id="T_22a29_row5_col2" class="data row5 col2" >-154.97</td>
#       <td id="T_22a29_row5_col3" class="data row5 col3" >78.49° F</td>
#       <td id="T_22a29_row5_col4" class="data row5 col4" >88%</td>
#       <td id="T_22a29_row5_col5" class="data row5 col5" >75%</td>
#       <td id="T_22a29_row5_col6" class="data row5 col6" >4.61</td>
#       <td id="T_22a29_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_22a29_row5_col8" class="data row5 col8" >2023-09-23 11:54:06</td>
#     </tr>
#     <tr>
#       <td id="T_22a29_row6_col0" class="data row6 col0" >udachny</td>
#       <td id="T_22a29_row6_col1" class="data row6 col1" >66.42</td>
#       <td id="T_22a29_row6_col2" class="data row6 col2" >112.40</td>
#       <td id="T_22a29_row6_col3" class="data row6 col3" >46.45° F</td>
#       <td id="T_22a29_row6_col4" class="data row6 col4" >93%</td>
#       <td id="T_22a29_row6_col5" class="data row6 col5" >65%</td>
#       <td id="T_22a29_row6_col6" class="data row6 col6" >6.73</td>
#       <td id="T_22a29_row6_col7" class="data row6 col7" >RU</td>
#       <td id="T_22a29_row6_col8" class="data row6 col8" >2023-09-23 11:54:06</td>
#     </tr>
#     <tr>

# %% [markdown]
# ### **Southern Hemisphere City Weather Information**

# %%
southernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (southernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.2: City Weather Information (Southern Hemisphere)')
# Out:
# <style type="text/css">
# #T_8f5f2 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_8f5f2_row0_col0, #T_8f5f2_row0_col1, #T_8f5f2_row0_col2, #T_8f5f2_row0_col3, #T_8f5f2_row0_col4, #T_8f5f2_row0_col6, #T_8f5f2_row0_col7, #T_8f5f2_row0_col8, #T_8f5f2_row1_col0, #T_8f5f2_row1_col1, #T_8f5f2_row1_col2, #T_8f5f2_row1_col4, #T_8f5f2_row1_col5, #T_8f5f2_row1_col6, #T_8f5f2_row1_col7, #T_8f5f2_row1_col8, #T_8f5f2_row2_col0, #T_8f5f2_row2_col1, #T_8f5f2_row2_col2, #T_8f5f2_row2_col3, #T_8f5f2_row2_col4, #T_8f5f2_row2_col5, #T_8f5f2_row2_col6, #T_8f5f2_row2_col7, #T_8f5f2_row2_col8, #T_8f5f2_row3_col0, #T_8f5f2_row3_col1, #T_8f5f2_row3_col2, #T_8f5f2_row3_col3, #T_8f5f2_row3_col4, #T_8f5f2_row3_col7, #T_8f5f2_row3_col8, #T_8f5f2_row4_col0, #T_8f5f2_row4_col1, #T_8f5f2_row4_col2, #T_8f5f2_row4_col3, #T_8f5f2_row4_col4, #T_8f5f2_row4_col6, #T_8f5f2_row4_col7, #T_8f5f2_row4_col8, #T_8f5f2_row5_col0, #T_8f5f2_row5_col1, #T_8f5f2_row5_col2, #T_8f5f2_row5_col3, #T_8f5f2_row5_col4, #T_8f5f2_row5_col5, #T_8f5f2_row5_col6, #T_8f5f2_row5_col7, #T_8f5f2_row5_col8, #T_8f5f2_row6_col0, #T_8f5f2_row6_col1, #T_8f5f2_row6_col2, #T_8f5f2_row6_col3, #T_8f5f2_row6_col4, #T_8f5f2_row6_col5, #T_8f5f2_row6_col6, #T_8f5f2_row6_col7, #T_8f5f2_row6_col8, #T_8f5f2_row7_col0, #T_8f5f2_row7_col1, #T_8f5f2_row7_col2, #T_8f5f2_row7_col3, #T_8f5f2_row7_col4, #T_8f5f2_row7_col6, #T_8f5f2_row7_col7, #T_8f5f2_row7_col8, #T_8f5f2_row8_col0, #T_8f5f2_row8_col1, #T_8f5f2_row8_col2, #T_8f5f2_row8_col3, #T_8f5f2_row8_col6, #T_8f5f2_row8_col7, #T_8f5f2_row8_col8, #T_8f5f2_row9_col0, #T_8f5f2_row9_col1, #T_8f5f2_row9_col2, #T_8f5f2_row9_col3, #T_8f5f2_row9_col4, #T_8f5f2_row9_col5, #T_8f5f2_row9_col6, #T_8f5f2_row9_col7, #T_8f5f2_row9_col8, #T_8f5f2_row10_col0, #T_8f5f2_row10_col1, #T_8f5f2_row10_col2, #T_8f5f2_row10_col7, #T_8f5f2_row10_col8, #T_8f5f2_row11_col0, #T_8f5f2_row11_col1, #T_8f5f2_row11_col2, #T_8f5f2_row11_col3, #T_8f5f2_row11_col4, #T_8f5f2_row11_col5, #T_8f5f2_row11_col6, #T_8f5f2_row11_col7, #T_8f5f2_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_8f5f2_row0_col5, #T_8f5f2_row3_col5, #T_8f5f2_row3_col6, #T_8f5f2_row4_col5, #T_8f5f2_row7_col5, #T_8f5f2_row8_col4, #T_8f5f2_row8_col5, #T_8f5f2_row10_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_8f5f2_row1_col3, #T_8f5f2_row10_col4, #T_8f5f2_row10_col5, #T_8f5f2_row10_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_8f5f2">
#   <caption>Table: 1.3.2: City Weather Information (Southern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_8f5f2_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_8f5f2_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_8f5f2_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_8f5f2_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_8f5f2_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_8f5f2_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_8f5f2_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_8f5f2_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_8f5f2_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8f5f2_row0_col0" class="data row0 col0" >ust'-barguzin</td>
#       <td id="T_8f5f2_row0_col1" class="data row0 col1" >53.45</td>
#       <td id="T_8f5f2_row0_col2" class="data row0 col2" >108.98</td>
#       <td id="T_8f5f2_row0_col3" class="data row0 col3" >52.56° F</td>
#       <td id="T_8f5f2_row0_col4" class="data row0 col4" >89%</td>
#       <td id="T_8f5f2_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_8f5f2_row0_col6" class="data row0 col6" >4.18</td>
#       <td id="T_8f5f2_row0_col7" class="data row0 col7" >RU</td>
#       <td id="T_8f5f2_row0_col8" class="data row0 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_8f5f2_row1_col0" class="data row1 col0" >longyearbyen</td>
#       <td id="T_8f5f2_row1_col1" class="data row1 col1" >78.22</td>
#       <td id="T_8f5f2_row1_col2" class="data row1 col2" >15.64</td>
#       <td id="T_8f5f2_row1_col3" class="data row1 col3" >22.84° F</td>
#       <td id="T_8f5f2_row1_col4" class="data row1 col4" >80%</td>
#       <td id="T_8f5f2_row1_col5" class="data row1 col5" >20%</td>
#       <td id="T_8f5f2_row1_col6" class="data row1 col6" >5.75</td>
#       <td id="T_8f5f2_row1_col7" class="data row1 col7" >SJ</td>
#       <td id="T_8f5f2_row1_col8" class="data row1 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_8f5f2_row2_col0" class="data row2 col0" >teteven</td>
#       <td id="T_8f5f2_row2_col1" class="data row2 col1" >42.92</td>
#       <td id="T_8f5f2_row2_col2" class="data row2 col2" >24.27</td>
#       <td id="T_8f5f2_row2_col3" class="data row2 col3" >74.39° F</td>
#       <td id="T_8f5f2_row2_col4" class="data row2 col4" >45%</td>
#       <td id="T_8f5f2_row2_col5" class="data row2 col5" >16%</td>
#       <td id="T_8f5f2_row2_col6" class="data row2 col6" >6.40</td>
#       <td id="T_8f5f2_row2_col7" class="data row2 col7" >BG</td>
#       <td id="T_8f5f2_row2_col8" class="data row2 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_8f5f2_row3_col0" class="data row3 col0" >yellowknife</td>
#       <td id="T_8f5f2_row3_col1" class="data row3 col1" >62.46</td>
#       <td id="T_8f5f2_row3_col2" class="data row3 col2" >-114.35</td>
#       <td id="T_8f5f2_row3_col3" class="data row3 col3" >52.32° F</td>
#       <td id="T_8f5f2_row3_col4" class="data row3 col4" >82%</td>
#       <td id="T_8f5f2_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_8f5f2_row3_col6" class="data row3 col6" >10.36</td>
#       <td id="T_8f5f2_row3_col7" class="data row3 col7" >CA</td>
#       <td id="T_8f5f2_row3_col8" class="data row3 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_8f5f2_row4_col0" class="data row4 col0" >revda</td>
#       <td id="T_8f5f2_row4_col1" class="data row4 col1" >56.80</td>
#       <td id="T_8f5f2_row4_col2" class="data row4 col2" >59.93</td>
#       <td id="T_8f5f2_row4_col3" class="data row4 col3" >51.19° F</td>
#       <td id="T_8f5f2_row4_col4" class="data row4 col4" >93%</td>
#       <td id="T_8f5f2_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_8f5f2_row4_col6" class="data row4 col6" >4.97</td>
#       <td id="T_8f5f2_row4_col7" class="data row4 col7" >RU</td>
#       <td id="T_8f5f2_row4_col8" class="data row4 col8" >2023-09-23 11:54:06</td>
#     </tr>
#     <tr>
#       <td id="T_8f5f2_row5_col0" class="data row5 col0" >hawaiian paradise park</td>
#       <td id="T_8f5f2_row5_col1" class="data row5 col1" >19.59</td>
#       <td id="T_8f5f2_row5_col2" class="data row5 col2" >-154.97</td>
#       <td id="T_8f5f2_row5_col3" class="data row5 col3" >78.49° F</td>
#       <td id="T_8f5f2_row5_col4" class="data row5 col4" >88%</td>
#       <td id="T_8f5f2_row5_col5" class="data row5 col5" >75%</td>
#       <td id="T_8f5f2_row5_col6" class="data row5 col6" >4.61</td>
#       <td id="T_8f5f2_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_8f5f2_row5_col8" class="data row5 col8" >2023-09-23 11:54:06</td>
#     </tr>
#     <tr>
#       <td id="T_8f5f2_row6_col0" class="data row6 col0" >udachny</td>
#       <td id="T_8f5f2_row6_col1" class="data row6 col1" >66.42</td>
#       <td id="T_8f5f2_row6_col2" class="data row6 col2" >112.40</td>
#       <td id="T_8f5f2_row6_col3" class="data row6 col3" >46.45° F</td>
#       <td id="T_8f5f2_row6_col4" class="data row6 col4" >93%</td>
#       <td id="T_8f5f2_row6_col5" class="data row6 col5" >65%</td>
#       <td id="T_8f5f2_row6_col6" class="data row6 col6" >6.73</td>
#       <td id="T_8f5f2_row6_col7" class="data row6 col7" >RU</td>
#       <td id="T_8f5f2_row6_col8" class="data row6 col8" >2023-09-23 11:54:06</td>
#     </tr>
#     <tr>

# %% [markdown]
# ### **Temperature vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.1: Temperature vs. Latitude (Northern Hemisphere)',
         1, 2.0, 45.0)
# Out:
# r-value:     -0.8124
# r-squared:   0.6600

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.2: Temperature vs. Latitude (Southern Hemisphere)',
         1, -55.0, 85.0)
# Out:
# r-value:     0.7567
# r-squared:   0.5725

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### From the results of the linear regression, in the northern hemisphere, the latitude is negatively correlated with temperature; this negative correlation tells us that the two variables move in opposite directions: as latitude increases, the temperature drops, and vice versa.  In the southern hemisphers, the latitude is positively correlated with temperature: this positive correlation tells us that the two variables move in the same direction: as latitude increases, the temperature increases.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.3: Humidity vs. Latitude (Northern Hemisphere)',
         1, 45.0, 18.0)
# Out:
# r-value:     0.0771
# r-squared:   0.0059

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.4: Humidity vs. Latitude (Southern Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     -0.1396
# r-squared:   0.0195

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and humidity in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Cloudiness vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.5: Cloudiness vs. Latitude (Northern Hemisphere)',
         1, 16.0, 62.0)
# Out:
# r-value:     -0.0662
# r-squared:   0.0044

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.6: Cloudiness vs. Latitude (Southern Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     -0.0755
# r-squared:   0.0057

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and cloudiness in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.7: Wind Speed vs. Latitude (Northern Hemisphere)',
         1, 15.0, 22.0)
# Out:
# r-value:     0.0900
# r-squared:   0.0081

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.8: Wind Speed vs. Latitude (Southern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.1647
# r-squared:   0.0271

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and wind speed in either hemisphere.

# %%
#log_subroutine \
#    .EndProgramExecution()
