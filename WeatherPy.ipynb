# %% [markdown]
# # WeatherPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, WeatherPy.ipynb, uses a Python script to 
 #      visualize the weather of over 500 cities of varying distances from the equator. 
 #      The script uses the citipy Python library and the openWeatherMap API to create 
 #      a representative model of weather across cities.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubRoutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'WeatherPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('WeatherPy')

# %% [markdown]
# # <br> **Section 1: Weather Variables and Latitude**

# %% [markdown]
# ## **Section 1.1: Data Acquisition**

# %% [markdown]
# ### **List of Cities**

# %%
citiesListOfStrings \
    = api_function \
        .ReturnCitiesList()

# %% [markdown]
# ### **Weather Data from List of Cities**

# %%
cityWeatherDataFrame \
    = api_function \
        .ReturnWeatherDataFrame \
            (citiesListOfStrings)
# Out:
# DATA RETRIEVAL FOR CITY WEATHER DATAFRAME BEGINS...
#
#
# PROCESSING RECORD #2 OF SET 1 FOR CITY, albany.
#
# PROCESSING RECORD #3 OF SET 1 FOR CITY, bethel.
#
# PROCESSING RECORD #4 OF SET 1 FOR CITY, taiohae.
#
# The script did not find the city, taiohae. Skipping...
#
# PROCESSING RECORD #5 OF SET 1 FOR CITY, college.
#
# PROCESSING RECORD #6 OF SET 1 FOR CITY, sisimiut.
#
# PROCESSING RECORD #7 OF SET 1 FOR CITY, calvinia.
#
# PROCESSING RECORD #8 OF SET 1 FOR CITY, port-aux-francais.
#
# PROCESSING RECORD #9 OF SET 1 FOR CITY, qaqortoq.
#
# PROCESSING RECORD #10 OF SET 1 FOR CITY, lorengau.
#
# PROCESSING RECORD #11 OF SET 1 FOR CITY, adamstown.
#
# PROCESSING RECORD #12 OF SET 1 FOR CITY, okha.
#
# PROCESSING RECORD #13 OF SET 1 FOR CITY, lihue.
#
# PROCESSING RECORD #14 OF SET 1 FOR CITY, prince rupert.
#
# PROCESSING RECORD #15 OF SET 1 FOR CITY, flying fish cove.
#
# PROCESSING RECORD #16 OF SET 1 FOR CITY, stanley.
#
# PROCESSING RECORD #17 OF SET 1 FOR CITY, chinde.
#
# PROCESSING RECORD #18 OF SET 1 FOR CITY, haiku-pauwela.
#
# PROCESSING RECORD #19 OF SET 1 FOR CITY, mar del plata.
#
# PROCESSING RECORD #20 OF SET 1 FOR CITY, kodiak.
#
# PROCESSING RECORD #21 OF SET 1 FOR CITY, island harbour.
#
# PROCESSING RECORD #22 OF SET 1 FOR CITY, genhe.
#
# PROCESSING RECORD #23 OF SET 1 FOR CITY, invercargill.
#
# PROCESSING RECORD #24 OF SET 1 FOR CITY, tazovsky.
#
# PROCESSING RECORD #25 OF SET 1 FOR CITY, vingt cinq.
#
# The script did not find the city, vingt cinq. Skipping...
#
# PROCESSING RECORD #26 OF SET 1 FOR CITY, kismayo.
#
# PROCESSING RECORD #27 OF SET 1 FOR CITY, viitasaari.
#
# PROCESSING RECORD #28 OF SET 1 FOR CITY, belmonte.
#
# PROCESSING RECORD #29 OF SET 1 FOR CITY, tsiombe.
#
# PROCESSING RECORD #30 OF SET 1 FOR CITY, punta arenas.
#
# PROCESSING RECORD #31 OF SET 1 FOR CITY, jamestown.
#
# PROCESSING RECORD #32 OF SET 1 FOR CITY, atafu village.
#
# PROCESSING RECORD #33 OF SET 1 FOR CITY, tateyama.
#
# PROCESSING RECORD #34 OF SET 1 FOR CITY, rabaul.
#
# PROCESSING RECORD #35 OF SET 1 FOR CITY, zag.
#
# PROCESSING RECORD #36 OF SET 1 FOR CITY, pointe-noire.
#
# PROCESSING RECORD #37 OF SET 1 FOR CITY, saipan.
#
# PROCESSING RECORD #38 OF SET 1 FOR CITY, edinburgh of the seven seas.
#
# PROCESSING RECORD #39 OF SET 1 FOR CITY, puerto natales.
#
# PROCESSING RECORD #40 OF SET 1 FOR CITY, walvis bay.
#
# PROCESSING RECORD #41 OF SET 1 FOR CITY, gulubovo.
#
# PROCESSING RECORD #42 OF SET 1 FOR CITY, sur.
#
# PROCESSING RECORD #43 OF SET 1 FOR CITY, vrangel'.
#
# PROCESSING RECORD #44 OF SET 1 FOR CITY, egilsstadir.
#
# PROCESSING RECORD #45 OF SET 1 FOR CITY, ilulissat.
#
# PROCESSING RECORD #46 OF SET 1 FOR CITY, fuvahmulah.
#
# The script did not find the city, fuvahmulah. Skipping...
#
# PROCESSING RECORD #47 OF SET 1 FOR CITY, callao.
#
# PROCESSING RECORD #48 OF SET 1 FOR CITY, conde.
#
# PROCESSING RECORD #49 OF SET 1 FOR CITY, sinabang.
#
# PROCESSING RECORD #50 OF SET 1 FOR CITY, viedma.
#
# PROCESSING RECORD #51 OF SET 1 FOR CITY, camana.
#
# PROCESSING RECORD #1 OF SET 2 FOR CITY, portland.
#
# PROCESSING RECORD #2 OF SET 2 FOR CITY, blackmans bay.
#
# PROCESSING RECORD #3 OF SET 2 FOR CITY, zhosaly.
#
# PROCESSING RECORD #4 OF SET 2 FOR CITY, waitangi.
#
# PROCESSING RECORD #5 OF SET 2 FOR CITY, teluknaga.
#
# PROCESSING RECORD #6 OF SET 2 FOR CITY, olonkinbyen.
#
# PROCESSING RECORD #7 OF SET 2 FOR CITY, morehead city.
#
# PROCESSING RECORD #8 OF SET 2 FOR CITY, margaret river.
#
# PROCESSING RECORD #9 OF SET 2 FOR CITY, vila velha.
#
# PROCESSING RECORD #10 OF SET 2 FOR CITY, vanimo.
#
# PROCESSING RECORD #11 OF SET 2 FOR CITY, xai-xai.
#
# PROCESSING RECORD #12 OF SET 2 FOR CITY, ola.
#
# PROCESSING RECORD #13 OF SET 2 FOR CITY, olinda.
#
# PROCESSING RECORD #14 OF SET 2 FOR CITY, alofi.
#
# PROCESSING RECORD #15 OF SET 2 FOR CITY, lyubimets.
#
# PROCESSING RECORD #16 OF SET 2 FOR CITY, west island.
#
# PROCESSING RECORD #17 OF SET 2 FOR CITY, remire-montjoly.
#
# PROCESSING RECORD #18 OF SET 2 FOR CITY, cabo san lucas.
#
# PROCESSING RECORD #19 OF SET 2 FOR CITY, kaniv.
#
# PROCESSING RECORD #20 OF SET 2 FOR CITY, castillos.
#
# PROCESSING RECORD #21 OF SET 2 FOR CITY, hadibu.
#
# PROCESSING RECORD #22 OF SET 2 FOR CITY, thompson.
#
# PROCESSING RECORD #23 OF SET 2 FOR CITY, beinamar.
#
# PROCESSING RECORD #24 OF SET 2 FOR CITY, san patricio.
#
# PROCESSING RECORD #25 OF SET 2 FOR CITY, grytviken.
#
# PROCESSING RECORD #26 OF SET 2 FOR CITY, soto la marina.
#
# PROCESSING RECORD #27 OF SET 2 FOR CITY, mossel bay.
#
# PROCESSING RECORD #28 OF SET 2 FOR CITY, chegutu.
#
# PROCESSING RECORD #29 OF SET 2 FOR CITY, formosa.
#
# PROCESSING RECORD #30 OF SET 2 FOR CITY, papatowai.
#
# PROCESSING RECORD #31 OF SET 2 FOR CITY, rakvere.
#
# PROCESSING RECORD #32 OF SET 2 FOR CITY, puerto ayora.
#
# PROCESSING RECORD #33 OF SET 2 FOR CITY, port lincoln.
#
# PROCESSING RECORD #34 OF SET 2 FOR CITY, yellowknife.
#
# PROCESSING RECORD #35 OF SET 2 FOR CITY, longyearbyen.
#
# PROCESSING RECORD #36 OF SET 2 FOR CITY, xinqing.
#
# PROCESSING RECORD #37 OF SET 2 FOR CITY, ubinskoye.
#
# PROCESSING RECORD #38 OF SET 2 FOR CITY, whitehorse.
#
# PROCESSING RECORD #39 OF SET 2 FOR CITY, kenai.
#
# PROCESSING RECORD #40 OF SET 2 FOR CITY, port elizabeth.
#
# PROCESSING RECORD #41 OF SET 2 FOR CITY, natal.
#
# PROCESSING RECORD #42 OF SET 2 FOR CITY, ghorawal.
#
# PROCESSING RECORD #43 OF SET 2 FOR CITY, tura.
#
# PROCESSING RECORD #44 OF SET 2 FOR CITY, vorgashor.
#
# PROCESSING RECORD #45 OF SET 2 FOR CITY, izluchinsk.
#
# PROCESSING RECORD #46 OF SET 2 FOR CITY, mariinsk.
#
# PROCESSING RECORD #47 OF SET 2 FOR CITY, hammerfest.
#
# PROCESSING RECORD #48 OF SET 2 FOR CITY, shangri-la.
#
# The script did not find the city, shangri-la. Skipping...
#
# PROCESSING RECORD #49 OF SET 2 FOR CITY, talcahuano.
#
# PROCESSING RECORD #50 OF SET 2 FOR CITY, port alfred.
#
# PROCESSING RECORD #1 OF SET 3 FOR CITY, petropavlovsk-kamchatsky.
#
# PROCESSING RECORD #2 OF SET 3 FOR CITY, malvan.
#
# PROCESSING RECORD #3 OF SET 3 FOR CITY, wailua homesteads.
#
# PROCESSING RECORD #4 OF SET 3 FOR CITY, chonchi.
#
# PROCESSING RECORD #5 OF SET 3 FOR CITY, hotan.
#
# PROCESSING RECORD #6 OF SET 3 FOR CITY, giyani.
#
# PROCESSING RECORD #7 OF SET 3 FOR CITY, badger.
#
# PROCESSING RECORD #8 OF SET 3 FOR CITY, hamilton.
#
# PROCESSING RECORD #9 OF SET 3 FOR CITY, weno.
#
# PROCESSING RECORD #10 OF SET 3 FOR CITY, ushuaia.
#
# PROCESSING RECORD #11 OF SET 3 FOR CITY, katsuura.
#
# PROCESSING RECORD #12 OF SET 3 FOR CITY, hermanus.
#
# PROCESSING RECORD #13 OF SET 3 FOR CITY, aykhal.
#
# PROCESSING RECORD #14 OF SET 3 FOR CITY, hami.
#
# PROCESSING RECORD #15 OF SET 3 FOR CITY, taltal.
#
# PROCESSING RECORD #16 OF SET 3 FOR CITY, maddela.
#
# PROCESSING RECORD #17 OF SET 3 FOR CITY, afaahiti.
#
# PROCESSING RECORD #18 OF SET 3 FOR CITY, georgetown.
#
# PROCESSING RECORD #19 OF SET 3 FOR CITY, polyarnyy.
#
# PROCESSING RECORD #20 OF SET 3 FOR CITY, iskateley.
#
# PROCESSING RECORD #21 OF SET 3 FOR CITY, nuku'alofa.
#
# PROCESSING RECORD #22 OF SET 3 FOR CITY, bredasdorp.
#
# PROCESSING RECORD #23 OF SET 3 FOR CITY, shakhan.
#
# PROCESSING RECORD #24 OF SET 3 FOR CITY, bamboo flat.
#
# PROCESSING RECORD #25 OF SET 3 FOR CITY, kailua-kona.
#
# PROCESSING RECORD #26 OF SET 3 FOR CITY, strelka.
#
# PROCESSING RECORD #27 OF SET 3 FOR CITY, villa gesell.
#
# PROCESSING RECORD #28 OF SET 3 FOR CITY, nijar.
#
# PROCESSING RECORD #29 OF SET 3 FOR CITY, san fernando del valle de catamarca.
#
# PROCESSING RECORD #30 OF SET 3 FOR CITY, kuhmo.
#
# PROCESSING RECORD #31 OF SET 3 FOR CITY, nuuk.
#
# PROCESSING RECORD #32 OF SET 3 FOR CITY, port saint john's.
#
# PROCESSING RECORD #33 OF SET 3 FOR CITY, tiksi.
#
# PROCESSING RECORD #34 OF SET 3 FOR CITY, happy valley-goose bay.
#
# PROCESSING RECORD #35 OF SET 3 FOR CITY, isafjordur.
#
# PROCESSING RECORD #36 OF SET 3 FOR CITY, prado.
#
# PROCESSING RECORD #37 OF SET 3 FOR CITY, nadym.
#
# PROCESSING RECORD #38 OF SET 3 FOR CITY, yangor.
#
# The script did not find the city, yangor. Skipping...
#
# PROCESSING RECORD #39 OF SET 3 FOR CITY, ironwood.
#
# PROCESSING RECORD #40 OF SET 3 FOR CITY, la passe.
#
# PROCESSING RECORD #41 OF SET 3 FOR CITY, codajas.
#
# PROCESSING RECORD #42 OF SET 3 FOR CITY, cabugao.
#
# PROCESSING RECORD #43 OF SET 3 FOR CITY, hemsby.
#
# PROCESSING RECORD #44 OF SET 3 FOR CITY, colonia.
#
# PROCESSING RECORD #45 OF SET 3 FOR CITY, beyneu.
#
# PROCESSING RECORD #46 OF SET 3 FOR CITY, saudarkrokur.
#
# PROCESSING RECORD #47 OF SET 3 FOR CITY, ribeira grande.
#
# PROCESSING RECORD #48 OF SET 3 FOR CITY, anadyr.
#
# PROCESSING RECORD #49 OF SET 3 FOR CITY, flin flon.
#
# PROCESSING RECORD #50 OF SET 3 FOR CITY, masuguru.
# PROCESSING RECORD #1 OF SET 4 FOR CITY, st. john's.
#
# PROCESSING RECORD #2 OF SET 4 FOR CITY, klyuchi.
#
# PROCESSING RECORD #3 OF SET 4 FOR CITY, hustopece.
#
# PROCESSING RECORD #4 OF SET 4 FOR CITY, mapimi.
#
# PROCESSING RECORD #5 OF SET 4 FOR CITY, atherton.
#
# PROCESSING RECORD #6 OF SET 4 FOR CITY, nar'yan-mar.
#
# PROCESSING RECORD #7 OF SET 4 FOR CITY, ust-nera.
#
# PROCESSING RECORD #8 OF SET 4 FOR CITY, eyl.
#
# PROCESSING RECORD #9 OF SET 4 FOR CITY, udachny.
#
# PROCESSING RECORD #10 OF SET 4 FOR CITY, cururupu.
#
# PROCESSING RECORD #11 OF SET 4 FOR CITY, lydenburg.
#
# PROCESSING RECORD #12 OF SET 4 FOR CITY, guajara mirim.
#
# PROCESSING RECORD #13 OF SET 4 FOR CITY, vilyuysk.
#
# PROCESSING RECORD #14 OF SET 4 FOR CITY, kataragama.
#
# The script did not find the city, kataragama. Skipping...
#
# PROCESSING RECORD #15 OF SET 4 FOR CITY, belleville.
#
# PROCESSING RECORD #16 OF SET 4 FOR CITY, mogok.
#
# PROCESSING RECORD #17 OF SET 4 FOR CITY, hawaiian paradise park.
#
# PROCESSING RECORD #18 OF SET 4 FOR CITY, minas de marcona.
#
# PROCESSING RECORD #19 OF SET 4 FOR CITY, baukau.
#
# PROCESSING RECORD #20 OF SET 4 FOR CITY, kruisfontein.
#
# PROCESSING RECORD #21 OF SET 4 FOR CITY, ternate.
#
# PROCESSING RECORD #22 OF SET 4 FOR CITY, iqaluit.
#
# PROCESSING RECORD #23 OF SET 4 FOR CITY, pisco.
#
# PROCESSING RECORD #24 OF SET 4 FOR CITY, choyr.
#
# PROCESSING RECORD #25 OF SET 4 FOR CITY, antofagasta.
#
# PROCESSING RECORD #26 OF SET 4 FOR CITY, crane.
#
# PROCESSING RECORD #27 OF SET 4 FOR CITY, lebu.
#
# PROCESSING RECORD #28 OF SET 4 FOR CITY, dakhla.
#
# PROCESSING RECORD #29 OF SET 4 FOR CITY, avarua.
#
# PROCESSING RECORD #30 OF SET 4 FOR CITY, utrik.
#
# PROCESSING RECORD #31 OF SET 4 FOR CITY, bandar-e anzali.
#
# PROCESSING RECORD #32 OF SET 4 FOR CITY, hilo.
#
# PROCESSING RECORD #33 OF SET 4 FOR CITY, praia.
#
# PROCESSING RECORD #34 OF SET 4 FOR CITY, madera acres.
#
# PROCESSING RECORD #35 OF SET 4 FOR CITY, riverside.
#
# PROCESSING RECORD #36 OF SET 4 FOR CITY, aripuana.
#
# PROCESSING RECORD #37 OF SET 4 FOR CITY, 'ohonua.
#
# The script did not find the city, 'ohonua. Skipping...
#
# PROCESSING RECORD #38 OF SET 4 FOR CITY, rio gallegos.
#
# PROCESSING RECORD #39 OF SET 4 FOR CITY, general villegas.
#
# PROCESSING RECORD #40 OF SET 4 FOR CITY, yamada.
#
# PROCESSING RECORD #41 OF SET 4 FOR CITY, malmesbury.
#
# PROCESSING RECORD #42 OF SET 4 FOR CITY, taulaga.
#
# PROCESSING RECORD #43 OF SET 4 FOR CITY, talnakh.
#
# PROCESSING RECORD #44 OF SET 4 FOR CITY, beledweyne.
#
# PROCESSING RECORD #45 OF SET 4 FOR CITY, key largo.
#
# PROCESSING RECORD #46 OF SET 4 FOR CITY, al qubbah.
#
# PROCESSING RECORD #47 OF SET 4 FOR CITY, alotau.
#
# The script did not find the city, alotau. Skipping...
#
# PROCESSING RECORD #48 OF SET 4 FOR CITY, fisterra.
#
# PROCESSING RECORD #49 OF SET 4 FOR CITY, egra.
#
# PROCESSING RECORD #50 OF SET 4 FOR CITY, champerico.
#
# PROCESSING RECORD #1 OF SET 5 FOR CITY, joaquin v. gonzalez.
#
# PROCESSING RECORD #2 OF SET 5 FOR CITY, vadso.
#
# PROCESSING RECORD #3 OF SET 5 FOR CITY, mugia.
#
# PROCESSING RECORD #4 OF SET 5 FOR CITY, levuka.
#
# PROCESSING RECORD #5 OF SET 5 FOR CITY, luanco.
#
# PROCESSING RECORD #6 OF SET 5 FOR CITY, kassala.
#
# PROCESSING RECORD #7 OF SET 5 FOR CITY, boa vista.
#
# PROCESSING RECORD #8 OF SET 5 FOR CITY, puerto deseado.
#
# PROCESSING RECORD #9 OF SET 5 FOR CITY, carnarvon.
#
# PROCESSING RECORD #10 OF SET 5 FOR CITY, uturoa.
#
# PROCESSING RECORD #11 OF SET 5 FOR CITY, tual.
#
# PROCESSING RECORD #12 OF SET 5 FOR CITY, nelson bay.
#
# PROCESSING RECORD #13 OF SET 5 FOR CITY, selfoss.
#
# PROCESSING RECORD #14 OF SET 5 FOR CITY, kiunga.
#
# PROCESSING RECORD #15 OF SET 5 FOR CITY, rongelap.
#
# PROCESSING RECORD #16 OF SET 5 FOR CITY, bryne.
#
# PROCESSING RECORD #17 OF SET 5 FOR CITY, hashimoto.
#
# PROCESSING RECORD #18 OF SET 5 FOR CITY, el chorrillo.
#
# PROCESSING RECORD #19 OF SET 5 FOR CITY, tokar.
#
# PROCESSING RECORD #20 OF SET 5 FOR CITY, ouadda.
#
# PROCESSING RECORD #21 OF SET 5 FOR CITY, enewetak.
#
# PROCESSING RECORD #22 OF SET 5 FOR CITY, mount gambier.
#
# PROCESSING RECORD #23 OF SET 5 FOR CITY, saint-pierre.
#
# PROCESSING RECORD #24 OF SET 5 FOR CITY, prachuap khiri khan.
#
# PROCESSING RECORD #25 OF SET 5 FOR CITY, mount pleasant.
#
# PROCESSING RECORD #26 OF SET 5 FOR CITY, tukrah.
#
# PROCESSING RECORD #27 OF SET 5 FOR CITY, bilibino.
#
# PROCESSING RECORD #28 OF SET 5 FOR CITY, aljezur.
#
# PROCESSING RECORD #29 OF SET 5 FOR CITY, north bend.
#
# PROCESSING RECORD #30 OF SET 5 FOR CITY, karratha.
#
# PROCESSING RECORD #31 OF SET 5 FOR CITY, kabalo.
#
# PROCESSING RECORD #32 OF SET 5 FOR CITY, kijang.
#
# PROCESSING RECORD #33 OF SET 5 FOR CITY, gaspe.
#
# PROCESSING RECORD #34 OF SET 5 FOR CITY, charles city.
#
# PROCESSING RECORD #35 OF SET 5 FOR CITY, tughyl.
#
# PROCESSING RECORD #36 OF SET 5 FOR CITY, dubovskoye.
#
# PROCESSING RECORD #37 OF SET 5 FOR CITY, muynoq.
#
# PROCESSING RECORD #38 OF SET 5 FOR CITY, kone.
#
# PROCESSING RECORD #39 OF SET 5 FOR CITY, mantua.
#
# PROCESSING RECORD #40 OF SET 5 FOR CITY, shimoda.
#
# PROCESSING RECORD #41 OF SET 5 FOR CITY, puerto princesa.
#
# PROCESSING RECORD #42 OF SET 5 FOR CITY, cadale.
#
# PROCESSING RECORD #43 OF SET 5 FOR CITY, poco branco.
#
# PROCESSING RECORD #44 OF SET 5 FOR CITY, korla.
#
# PROCESSING RECORD #45 OF SET 5 FOR CITY, luis correia.
#
# PROCESSING RECORD #46 OF SET 5 FOR CITY, vanino.
#
# PROCESSING RECORD #47 OF SET 5 FOR CITY, new plymouth.
#
# PROCESSING RECORD #48 OF SET 5 FOR CITY, tamanrasset.
#
# PROCESSING RECORD #49 OF SET 5 FOR CITY, teknaf.
#
# PROCESSING RECORD #50 OF SET 5 FOR CITY, al kharijah.
#
# PROCESSING RECORD #1 OF SET 6 FOR CITY, dudinka.
#
# PROCESSING RECORD #2 OF SET 6 FOR CITY, quang ngai.
#
# PROCESSING RECORD #3 OF SET 6 FOR CITY, fort bragg.
#
# PROCESSING RECORD #4 OF SET 6 FOR CITY, calipatria.
#
# PROCESSING RECORD #5 OF SET 6 FOR CITY, zheleznogorsk-ilimskiy.
#
# PROCESSING RECORD #6 OF SET 6 FOR CITY, kawthoung.
#
# The script did not find the city, kawthoung. Skipping...
#
# PROCESSING RECORD #7 OF SET 6 FOR CITY, skutskar.
#
# The script did not find the city, skutskar. Skipping...
#
# PROCESSING RECORD #8 OF SET 6 FOR CITY, port mathurin.
#
# PROCESSING RECORD #9 OF SET 6 FOR CITY, lakhdenpokh'ya.
#
# PROCESSING RECORD #10 OF SET 6 FOR CITY, mezhdurechenskiy.
#
# PROCESSING RECORD #11 OF SET 6 FOR CITY, coquimbo.
#
# PROCESSING RECORD #12 OF SET 6 FOR CITY, dali.
#
# PROCESSING RECORD #13 OF SET 6 FOR CITY, timmins.
#
# PROCESSING RECORD #14 OF SET 6 FOR CITY, alice springs.
#
# PROCESSING RECORD #15 OF SET 6 FOR CITY, kavaratti.
#
# PROCESSING RECORD #16 OF SET 6 FOR CITY, cape coast.
#
# PROCESSING RECORD #17 OF SET 6 FOR CITY, yasnyy.
#
# PROCESSING RECORD #18 OF SET 6 FOR CITY, charters towers.
#
# PROCESSING RECORD #19 OF SET 6 FOR CITY, severo-yeniseyskiy.
#
# PROCESSING RECORD #20 OF SET 6 FOR CITY, holualoa.
#
# PROCESSING RECORD #21 OF SET 6 FOR CITY, kushiro.
#
# PROCESSING RECORD #22 OF SET 6 FOR CITY, lautoka.
#
# PROCESSING RECORD #23 OF SET 6 FOR CITY, pacasmayo.
#
# PROCESSING RECORD #24 OF SET 6 FOR CITY, wau.
#
# PROCESSING RECORD #25 OF SET 6 FOR CITY, shancheng.
#
# PROCESSING RECORD #26 OF SET 6 FOR CITY, south hedland.
#
# PROCESSING RECORD #27 OF SET 6 FOR CITY, kittila.
#
# PROCESSING RECORD #28 OF SET 6 FOR CITY, qamdo.
#
# PROCESSING RECORD #29 OF SET 6 FOR CITY, ahau.
#
# The script did not find the city, ahau. Skipping...
#
# PROCESSING RECORD #30 OF SET 6 FOR CITY, amga.
#
# PROCESSING RECORD #31 OF SET 6 FOR CITY, pedro carbo.
#
# PROCESSING RECORD #32 OF SET 6 FOR CITY, biryusinsk.
#
# PROCESSING RECORD #33 OF SET 6 FOR CITY, dongxing.
#
# PROCESSING RECORD #34 OF SET 6 FOR CITY, gaigeturi.
#
# PROCESSING RECORD #35 OF SET 6 FOR CITY, aasiaat.
#
# PROCESSING RECORD #36 OF SET 6 FOR CITY, itupiranga.
#
# PROCESSING RECORD #37 OF SET 6 FOR CITY, tranovaho.
#
# The script did not find the city, tranovaho. Skipping...
#
# PROCESSING RECORD #38 OF SET 6 FOR CITY, totness.
#
# PROCESSING RECORD #39 OF SET 6 FOR CITY, touros.
#
# PROCESSING RECORD #40 OF SET 6 FOR CITY, toga village.
#
# The script did not find the city, toga village. Skipping...
#
# PROCESSING RECORD #41 OF SET 6 FOR CITY, novodvinsk.
#
# PROCESSING RECORD #42 OF SET 6 FOR CITY, mizhou.
#
# PROCESSING RECORD #43 OF SET 6 FOR CITY, visby.
#
# PROCESSING RECORD #44 OF SET 6 FOR CITY, taghazout.
#
# PROCESSING RECORD #45 OF SET 6 FOR CITY, nakskov.
#
# PROCESSING RECORD #46 OF SET 6 FOR CITY, new norfolk.
#
# PROCESSING RECORD #47 OF SET 6 FOR CITY, luganville.
#
# PROCESSING RECORD #48 OF SET 6 FOR CITY, mont-dore.
#
# PROCESSING RECORD #49 OF SET 6 FOR CITY, itaituba.
# PROCESSING RECORD #50 OF SET 6 FOR CITY, pangkalpinang.
#
# PROCESSING RECORD #1 OF SET 7 FOR CITY, suva.
#
# PROCESSING RECORD #2 OF SET 7 FOR CITY, hayma'.
#
# The script did not find the city, hayma'. Skipping...
#
# PROCESSING RECORD #3 OF SET 7 FOR CITY, aitape.
#
# PROCESSING RECORD #4 OF SET 7 FOR CITY, toliara.
#
# PROCESSING RECORD #5 OF SET 7 FOR CITY, leava.
#
# PROCESSING RECORD #6 OF SET 7 FOR CITY, gobabis.
#
# PROCESSING RECORD #7 OF SET 7 FOR CITY, mili.
#
# PROCESSING RECORD #8 OF SET 7 FOR CITY, anabar.
#
# The script did not find the city, anabar. Skipping...
#
# PROCESSING RECORD #9 OF SET 7 FOR CITY, demre.
#
# PROCESSING RECORD #10 OF SET 7 FOR CITY, jijiga.
#
# PROCESSING RECORD #11 OF SET 7 FOR CITY, nova sintra.
#
# PROCESSING RECORD #12 OF SET 7 FOR CITY, devinuwara.
#
# The script did not find the city, devinuwara. Skipping...
#
# PROCESSING RECORD #13 OF SET 7 FOR CITY, kulebaki.
#
# PROCESSING RECORD #14 OF SET 7 FOR CITY, guerrero negro.
#
# PROCESSING RECORD #15 OF SET 7 FOR CITY, san antonio de pale.
#
# PROCESSING RECORD #16 OF SET 7 FOR CITY, broken hill.
#
# PROCESSING RECORD #17 OF SET 7 FOR CITY, ulsteinvik.
#
# PROCESSING RECORD #18 OF SET 7 FOR CITY, kingston.
#
# PROCESSING RECORD #19 OF SET 7 FOR CITY, penzance.
#
# PROCESSING RECORD #20 OF SET 7 FOR CITY, ete.
#
# PROCESSING RECORD #21 OF SET 7 FOR CITY, fort saskatchewan.
#
# PROCESSING RECORD #22 OF SET 7 FOR CITY, kerikeri.
#
# PROCESSING RECORD #23 OF SET 7 FOR CITY, labuan.
#
# PROCESSING RECORD #24 OF SET 7 FOR CITY, noumea.
#
# PROCESSING RECORD #25 OF SET 7 FOR CITY, sunne.
#
# PROCESSING RECORD #26 OF SET 7 FOR CITY, fale old settlement.
#
# PROCESSING RECORD #27 OF SET 7 FOR CITY, arkhangel'sk.
#
# PROCESSING RECORD #28 OF SET 7 FOR CITY, puerto rico.
#
# PROCESSING RECORD #29 OF SET 7 FOR CITY, la'ie.
#
# PROCESSING RECORD #30 OF SET 7 FOR CITY, fort st. john.
#
# PROCESSING RECORD #31 OF SET 7 FOR CITY, hastings.
#
# PROCESSING RECORD #32 OF SET 7 FOR CITY, new romney.
#
# PROCESSING RECORD #33 OF SET 7 FOR CITY, burang.
#
# PROCESSING RECORD #34 OF SET 7 FOR CITY, pont rouge.
#
# PROCESSING RECORD #35 OF SET 7 FOR CITY, naracoorte.
#
# PROCESSING RECORD #36 OF SET 7 FOR CITY, kununurra.
#
# PROCESSING RECORD #37 OF SET 7 FOR CITY, nikol'sk.
#
# PROCESSING RECORD #38 OF SET 7 FOR CITY, moju.
#
# PROCESSING RECORD #39 OF SET 7 FOR CITY, xiva.
#
# PROCESSING RECORD #40 OF SET 7 FOR CITY, boda.
#
# PROCESSING RECORD #41 OF SET 7 FOR CITY, pokachi.
#
# PROCESSING RECORD #42 OF SET 7 FOR CITY, kanggye.
#
# PROCESSING RECORD #43 OF SET 7 FOR CITY, usogorsk.
#
# PROCESSING RECORD #44 OF SET 7 FOR CITY, bubaque.
#
# PROCESSING RECORD #45 OF SET 7 FOR CITY, balkanabat.
#
# PROCESSING RECORD #46 OF SET 7 FOR CITY, jawhar.
#
# PROCESSING RECORD #47 OF SET 7 FOR CITY, that phanom.
#
# PROCESSING RECORD #48 OF SET 7 FOR CITY, ankang.
#
# PROCESSING RECORD #49 OF SET 7 FOR CITY, tolanaro.
#
# PROCESSING RECORD #50 OF SET 7 FOR CITY, fortaleza.
#
# PROCESSING RECORD #1 OF SET 8 FOR CITY, ust'-kut.
#
# PROCESSING RECORD #2 OF SET 8 FOR CITY, port-de-paix.
#
# The script did not find the city, port-de-paix. Skipping...
#
# PROCESSING RECORD #3 OF SET 8 FOR CITY, codrington.
#
# PROCESSING RECORD #4 OF SET 8 FOR CITY, cabedelo.
#
# PROCESSING RECORD #5 OF SET 8 FOR CITY, terme.
#
# PROCESSING RECORD #6 OF SET 8 FOR CITY, ozernyy.
#
# PROCESSING RECORD #7 OF SET 8 FOR CITY, nilsia.
#
# PROCESSING RECORD #8 OF SET 8 FOR CITY, turpan.
#
# PROCESSING RECORD #9 OF SET 8 FOR CITY, theniet el had.
#
# PROCESSING RECORD #10 OF SET 8 FOR CITY, plastun.
#
# PROCESSING RECORD #11 OF SET 8 FOR CITY, marsh harbour.
#
# PROCESSING RECORD #12 OF SET 8 FOR CITY, santa terezinha.
#
# PROCESSING RECORD #13 OF SET 8 FOR CITY, bandarbeyla.
#
# PROCESSING RECORD #14 OF SET 8 FOR CITY, qarazhal.
#
# PROCESSING RECORD #15 OF SET 8 FOR CITY, ribeira brava.
#
# PROCESSING RECORD #16 OF SET 8 FOR CITY, pacific grove.
#
# PROCESSING RECORD #17 OF SET 8 FOR CITY, gadzhiyevo.
#
# PROCESSING RECORD #18 OF SET 8 FOR CITY, bafq.
#
# PROCESSING RECORD #19 OF SET 8 FOR CITY, mcrae.
#
# PROCESSING RECORD #20 OF SET 8 FOR CITY, malone.
#
# PROCESSING RECORD #21 OF SET 8 FOR CITY, new ipswich.
#
# PROCESSING RECORD #22 OF SET 8 FOR CITY, vanju-mare.
#
# PROCESSING RECORD #23 OF SET 8 FOR CITY, port douglas.
#
# PROCESSING RECORD #24 OF SET 8 FOR CITY, lompoc.
#
# PROCESSING RECORD #25 OF SET 8 FOR CITY, khandyga.
#
# PROCESSING RECORD #26 OF SET 8 FOR CITY, nishinoomote.
#
# PROCESSING RECORD #27 OF SET 8 FOR CITY, carutapera.
#
# PROCESSING RECORD #28 OF SET 8 FOR CITY, coahuayana de hidalgo.
#
# PROCESSING RECORD #29 OF SET 8 FOR CITY, la leonesa.
#
# PROCESSING RECORD #30 OF SET 8 FOR CITY, mulifanua.
#
# The script did not find the city, mulifanua. Skipping...
#
# PROCESSING RECORD #31 OF SET 8 FOR CITY, guangming.
#
# PROCESSING RECORD #32 OF SET 8 FOR CITY, toyohashi.
#
# PROCESSING RECORD #33 OF SET 8 FOR CITY, vinh.
#
# PROCESSING RECORD #34 OF SET 8 FOR CITY, arraial do cabo.
#
# PROCESSING RECORD #35 OF SET 8 FOR CITY, maxixe.
#
# PROCESSING RECORD #36 OF SET 8 FOR CITY, dombarovskiy.
#
# PROCESSING RECORD #37 OF SET 8 FOR CITY, sao joao do piaui.
#
# PROCESSING RECORD #38 OF SET 8 FOR CITY, joacaba.
#
# PROCESSING RECORD #39 OF SET 8 FOR CITY, kiruna.
#
# PROCESSING RECORD #40 OF SET 8 FOR CITY, marcali.
#
# PROCESSING RECORD #41 OF SET 8 FOR CITY, labrador city.
#
# PROCESSING RECORD #42 OF SET 8 FOR CITY, bereeda.
#
# PROCESSING RECORD #43 OF SET 8 FOR CITY, male.
#
# PROCESSING RECORD #44 OF SET 8 FOR CITY, talara.
#
# PROCESSING RECORD #45 OF SET 8 FOR CITY, carbonear.
#
# PROCESSING RECORD #46 OF SET 8 FOR CITY, papao.
#
# PROCESSING RECORD #47 OF SET 8 FOR CITY, macas.
#
# PROCESSING RECORD #48 OF SET 8 FOR CITY, jieshi.
#
# PROCESSING RECORD #49 OF SET 8 FOR CITY, james island.
#
# The script did not find the city, james island. Skipping...
#
# PROCESSING RECORD #50 OF SET 8 FOR CITY, dongcun.
#
# PROCESSING RECORD #1 OF SET 9 FOR CITY, manado.
#
# PROCESSING RECORD #2 OF SET 9 FOR CITY, palikir - national government center.
#
# PROCESSING RECORD #3 OF SET 9 FOR CITY, nagqu.
#
# PROCESSING RECORD #4 OF SET 9 FOR CITY, vila franca do campo.
#
# PROCESSING RECORD #5 OF SET 9 FOR CITY, smithers.
#
# PROCESSING RECORD #6 OF SET 9 FOR CITY, kapa'a.
#
# PROCESSING RECORD #7 OF SET 9 FOR CITY, kachug.
#
# PROCESSING RECORD #8 OF SET 9 FOR CITY, bundibugyo.
#
# PROCESSING RECORD #9 OF SET 9 FOR CITY, puerto aysen.
#
# PROCESSING RECORD #10 OF SET 9 FOR CITY, guiyang.
#
# PROCESSING RECORD #11 OF SET 9 FOR CITY, piacabucu.
#
# PROCESSING RECORD #12 OF SET 9 FOR CITY, labytnangi.
#
# PROCESSING RECORD #13 OF SET 9 FOR CITY, loango.
#
# PROCESSING RECORD #14 OF SET 9 FOR CITY, mount pearl.
#
# PROCESSING RECORD #15 OF SET 9 FOR CITY, howard springs.
#
# PROCESSING RECORD #16 OF SET 9 FOR CITY, copala.
#
# PROCESSING RECORD #17 OF SET 9 FOR CITY, zarghun shahr.
#
# PROCESSING RECORD #18 OF SET 9 FOR CITY, malango.
#
# PROCESSING RECORD #19 OF SET 9 FOR CITY, porbandar.
#
# PROCESSING RECORD #20 OF SET 9 FOR CITY, santa uxia de ribeira.
#
# The script did not find the city, santa uxia de ribeira. Skipping...
#
# PROCESSING RECORD #21 OF SET 9 FOR CITY, puntarenas.
#
# PROCESSING RECORD #22 OF SET 9 FOR CITY, laguna.
#
# PROCESSING RECORD #23 OF SET 9 FOR CITY, jose mariano jimenez.
#
# The script did not find the city, jose mariano jimenez. Skipping...
#
# PROCESSING RECORD #24 OF SET 9 FOR CITY, cruz alta.
#
# PROCESSING RECORD #25 OF SET 9 FOR CITY, tortoli.
#
# PROCESSING RECORD #26 OF SET 9 FOR CITY, richards bay.
#
# PROCESSING RECORD #27 OF SET 9 FOR CITY, hithadhoo.
#
# PROCESSING RECORD #28 OF SET 9 FOR CITY, tanjung selor.
#
# The script did not find the city, tanjung selor. Skipping...
#
# PROCESSING RECORD #29 OF SET 9 FOR CITY, cestos city.
#
# PROCESSING RECORD #30 OF SET 9 FOR CITY, belyy yar.
#
# PROCESSING RECORD #31 OF SET 9 FOR CITY, mizan teferi.
#
# PROCESSING RECORD #32 OF SET 9 FOR CITY, koulamoutou.
#
# PROCESSING RECORD #33 OF SET 9 FOR CITY, ulundi.
#
# PROCESSING RECORD #34 OF SET 9 FOR CITY, brokopondo.
#
# PROCESSING RECORD #35 OF SET 9 FOR CITY, freetown.
#
# PROCESSING RECORD #36 OF SET 9 FOR CITY, el rosario.
#
# PROCESSING RECORD #37 OF SET 9 FOR CITY, cao bang.
#
# PROCESSING RECORD #38 OF SET 9 FOR CITY, graham.
#
# PROCESSING RECORD #39 OF SET 9 FOR CITY, ancud.
#
# PROCESSING RECORD #40 OF SET 9 FOR CITY, gabes.
#
# PROCESSING RECORD #41 OF SET 9 FOR CITY, mata-utu.
#
# PROCESSING RECORD #42 OF SET 9 FOR CITY, acapulco de juarez.
#
# PROCESSING RECORD #43 OF SET 9 FOR CITY, yatou.
#
# PROCESSING RECORD #44 OF SET 9 FOR CITY, podgornoye.
#
# PROCESSING RECORD #45 OF SET 9 FOR CITY, puerto san carlos.
# The script did not find the city, puerto san carlos. Skipping...
#
# PROCESSING RECORD #46 OF SET 9 FOR CITY, greymouth.
#
# PROCESSING RECORD #47 OF SET 9 FOR CITY, oualidia.
#
# The script did not find the city, oualidia. Skipping...
#
# PROCESSING RECORD #48 OF SET 9 FOR CITY, forster.
#
# PROCESSING RECORD #49 OF SET 9 FOR CITY, fereydun kenar.
#
# PROCESSING RECORD #50 OF SET 9 FOR CITY, kashgar.
#
# PROCESSING RECORD #1 OF SET 10 FOR CITY, peace river.
#
# PROCESSING RECORD #2 OF SET 10 FOR CITY, espargos.
#
# The script did not find the city, espargos. Skipping...
#
# PROCESSING RECORD #3 OF SET 10 FOR CITY, inhambane.
#
# PROCESSING RECORD #4 OF SET 10 FOR CITY, fairfield.
#
# PROCESSING RECORD #5 OF SET 10 FOR CITY, northam.
#
# PROCESSING RECORD #6 OF SET 10 FOR CITY, port blair.
#
# PROCESSING RECORD #7 OF SET 10 FOR CITY, sokode.
#
# PROCESSING RECORD #8 OF SET 10 FOR CITY, xunchang.
#
# PROCESSING RECORD #9 OF SET 10 FOR CITY, birobidzhan.
#
# PROCESSING RECORD #10 OF SET 10 FOR CITY, nioki.
#
# PROCESSING RECORD #11 OF SET 10 FOR CITY, yerofey pavlovich.
#
# PROCESSING RECORD #12 OF SET 10 FOR CITY, jayapura.
#
# PROCESSING RECORD #13 OF SET 10 FOR CITY, hasaki.
#
# PROCESSING RECORD #14 OF SET 10 FOR CITY, bardai.
#
# PROCESSING RECORD #15 OF SET 10 FOR CITY, constantia.
#
# PROCESSING RECORD #16 OF SET 10 FOR CITY, mamuju.
#
# PROCESSING RECORD #17 OF SET 10 FOR CITY, tazacorte.
#
# PROCESSING RECORD #18 OF SET 10 FOR CITY, pinas.
#
# PROCESSING RECORD #19 OF SET 10 FOR CITY, qarqaraly.
#
# PROCESSING RECORD #20 OF SET 10 FOR CITY, puerto quijarro.
#
# PROCESSING RECORD #21 OF SET 10 FOR CITY, dalandzadgad.
#
# PROCESSING RECORD #22 OF SET 10 FOR CITY, ambovombe.
#
# PROCESSING RECORD #23 OF SET 10 FOR CITY, grootfontein.
#
# PROCESSING RECORD #24 OF SET 10 FOR CITY, kabanjahe.
#
# PROCESSING RECORD #25 OF SET 10 FOR CITY, hauterive.
#
# PROCESSING RECORD #26 OF SET 10 FOR CITY, namibe.
#
# PROCESSING RECORD #27 OF SET 10 FOR CITY, lodja.
#
# PROCESSING RECORD #28 OF SET 10 FOR CITY, cargados carajos.
#
# The script did not find the city, cargados carajos. Skipping...
#
# PROCESSING RECORD #29 OF SET 10 FOR CITY, newman.
#
# PROCESSING RECORD #30 OF SET 10 FOR CITY, eunapolis.
#
# The script did not find the city, eunapolis. Skipping...
#
# PROCESSING RECORD #31 OF SET 10 FOR CITY, baruun-urt.
#
# PROCESSING RECORD #32 OF SET 10 FOR CITY, cidreira.
#
# PROCESSING RECORD #33 OF SET 10 FOR CITY, qacha's nek.
#
# PROCESSING RECORD #34 OF SET 10 FOR CITY, sao joao do paraiso.
#
# PROCESSING RECORD #35 OF SET 10 FOR CITY, redencao.
#
# PROCESSING RECORD #36 OF SET 10 FOR CITY, caleta de carquin.
#
# PROCESSING RECORD #37 OF SET 10 FOR CITY, evron.
#
# PROCESSING RECORD #38 OF SET 10 FOR CITY, edeia.
#
# PROCESSING RECORD #39 OF SET 10 FOR CITY, hassi messaoud.
#
# PROCESSING RECORD #40 OF SET 10 FOR CITY, mejit.
#
# PROCESSING RECORD #41 OF SET 10 FOR CITY, vorkuta.
#
# PROCESSING RECORD #42 OF SET 10 FOR CITY, matoury.
#
# PROCESSING RECORD #43 OF SET 10 FOR CITY, hobyo.
#
# PROCESSING RECORD #44 OF SET 10 FOR CITY, coyhaique.
#
# PROCESSING RECORD #45 OF SET 10 FOR CITY, kolonia town.
#
# PROCESSING RECORD #46 OF SET 10 FOR CITY, bethanie.
#
# PROCESSING RECORD #47 OF SET 10 FOR CITY, isnos.
#
# PROCESSING RECORD #48 OF SET 10 FOR CITY, huambo.
#
# PROCESSING RECORD #49 OF SET 10 FOR CITY, grand falls-windsor.
#
# PROCESSING RECORD #50 OF SET 10 FOR CITY, huarmey.
#
# PROCESSING RECORD #1 OF SET 11 FOR CITY, arroyo.
#
# PROCESSING RECORD #2 OF SET 11 FOR CITY, nguigmi.
#
# PROCESSING RECORD #3 OF SET 11 FOR CITY, tralee.
#
# PROCESSING RECORD #4 OF SET 11 FOR CITY, lisala.
#
# PROCESSING RECORD #5 OF SET 11 FOR CITY, keflavik.
#
# PROCESSING RECORD #6 OF SET 11 FOR CITY, barra de santo antonio.
#
# PROCESSING RECORD #7 OF SET 11 FOR CITY, sterling.
#
# PROCESSING RECORD #8 OF SET 11 FOR CITY, gulf shores.
#
# PROCESSING RECORD #9 OF SET 11 FOR CITY, nemuro.
#
# PROCESSING RECORD #10 OF SET 11 FOR CITY, dire dawa.
#
# PROCESSING RECORD #11 OF SET 11 FOR CITY, zliten.
#
# PROCESSING RECORD #12 OF SET 11 FOR CITY, sidi khaled.
#
# PROCESSING RECORD #13 OF SET 11 FOR CITY, cassilandia.
#
# PROCESSING RECORD #14 OF SET 11 FOR CITY, armacao de buzios.
#
# PROCESSING RECORD #15 OF SET 11 FOR CITY, mucumpiz.
#
# PROCESSING RECORD #16 OF SET 11 FOR CITY, nizhniy odes.
#
# PROCESSING RECORD #17 OF SET 11 FOR CITY, gunjur.
#
# PROCESSING RECORD #18 OF SET 11 FOR CITY, adh dhibiyah.
#
# The script did not find the city, adh dhibiyah. Skipping...
#
# PROCESSING RECORD #19 OF SET 11 FOR CITY, wanning.
#
# PROCESSING RECORD #20 OF SET 11 FOR CITY, cill airne.
#
# PROCESSING RECORD #21 OF SET 11 FOR CITY, sinan.
#
# PROCESSING RECORD #22 OF SET 11 FOR CITY, vasudevanallur.
#
# PROCESSING RECORD #23 OF SET 11 FOR CITY, bathsheba.
#
# PROCESSING RECORD #24 OF SET 11 FOR CITY, gebeit.
#
# PROCESSING RECORD #25 OF SET 11 FOR CITY, kulia village.
#
# The script did not find the city, kulia village. Skipping...
#
# PROCESSING RECORD #26 OF SET 11 FOR CITY, tevragh zeina.
#
# The script did not find the city, tevragh zeina. Skipping...
#
# PROCESSING RECORD #27 OF SET 11 FOR CITY, berdigestyakh.
#
# PROCESSING RECORD #28 OF SET 11 FOR CITY, kristiansund.
#
# PROCESSING RECORD #29 OF SET 11 FOR CITY, raduzhny.
#
# PROCESSING RECORD #30 OF SET 11 FOR CITY, qazigund.
#
# PROCESSING RECORD #31 OF SET 11 FOR CITY, hihifo.
#
# The script did not find the city, hihifo. Skipping...
#
# PROCESSING RECORD #32 OF SET 11 FOR CITY, camarinas.
#
# PROCESSING RECORD #33 OF SET 11 FOR CITY, chingola.
#
# PROCESSING RECORD #34 OF SET 11 FOR CITY, magdagachi.
#
# PROCESSING RECORD #35 OF SET 11 FOR CITY, i-n-salah.
#
# PROCESSING RECORD #36 OF SET 11 FOR CITY, san pedro pochutla.
#
# PROCESSING RECORD #37 OF SET 11 FOR CITY, fortuna.
#
# PROCESSING RECORD #38 OF SET 11 FOR CITY, prince george.
#
# PROCESSING RECORD #39 OF SET 11 FOR CITY, bowen.
#
# PROCESSING RECORD #40 OF SET 11 FOR CITY, waingapu.
#
# PROCESSING RECORD #41 OF SET 11 FOR CITY, tambura.
#
# PROCESSING RECORD #42 OF SET 11 FOR CITY, westport.
#
# PROCESSING RECORD #43 OF SET 11 FOR CITY, mbeya.
#
# PROCESSING RECORD #44 OF SET 11 FOR CITY, catarman.
#
# PROCESSING RECORD #45 OF SET 11 FOR CITY, elverum.
#
# PROCESSING RECORD #46 OF SET 11 FOR CITY, tangalle.
#
# PROCESSING RECORD #47 OF SET 11 FOR CITY, castro.
#
# PROCESSING RECORD #48 OF SET 11 FOR CITY, okulovka.
#
# PROCESSING RECORD #49 OF SET 11 FOR CITY, khorixas.
#
# PROCESSING RECORD #50 OF SET 11 FOR CITY, vilyuchinsk.
#
# PROCESSING RECORD #1 OF SET 12 FOR CITY, zhanaozen.
#
# PROCESSING RECORD #2 OF SET 12 FOR CITY, dundalk.
#
# PROCESSING RECORD #3 OF SET 12 FOR CITY, chulakkurgan.
#
# PROCESSING RECORD #4 OF SET 12 FOR CITY, poronaysk.
#
# PROCESSING RECORD #5 OF SET 12 FOR CITY, naze.
#
# PROCESSING RECORD #6 OF SET 12 FOR CITY, lazaro cardenas.
#
# PROCESSING RECORD #7 OF SET 12 FOR CITY, hopelchen.
#
# PROCESSING RECORD #8 OF SET 12 FOR CITY, el calafate.
#
# PROCESSING RECORD #9 OF SET 12 FOR CITY, garachico.
#
# PROCESSING RECORD #10 OF SET 12 FOR CITY, geraldton.
#
# PROCESSING RECORD #11 OF SET 12 FOR CITY, midland.
#
# PROCESSING RECORD #12 OF SET 12 FOR CITY, sandnessjoen.
#
# PROCESSING RECORD #13 OF SET 12 FOR CITY, inari.
#
# PROCESSING RECORD #14 OF SET 12 FOR CITY, loreto.
#
# PROCESSING RECORD #15 OF SET 12 FOR CITY, viligili.
#
# The script did not find the city, viligili. Skipping...
#
# PROCESSING RECORD #16 OF SET 12 FOR CITY, guane.
#
# PROCESSING RECORD #17 OF SET 12 FOR CITY, faya-largeau.
#
# PROCESSING RECORD #18 OF SET 12 FOR CITY, saldanha.
#
# PROCESSING RECORD #19 OF SET 12 FOR CITY, dhidhdhoo.
#
# PROCESSING RECORD #20 OF SET 12 FOR CITY, marsa alam.
#
# PROCESSING RECORD #21 OF SET 12 FOR CITY, ylitornio.
#
# PROCESSING RECORD #22 OF SET 12 FOR CITY, lata.
#
# PROCESSING RECORD #23 OF SET 12 FOR CITY, bodo.
#
# PROCESSING RECORD #24 OF SET 12 FOR CITY, novyy urengoy.
#
# PROCESSING RECORD #25 OF SET 12 FOR CITY, itoman.
#
# PROCESSING RECORD #26 OF SET 12 FOR CITY, kurumkan.
#
# PROCESSING RECORD #27 OF SET 12 FOR CITY, la foa.
#
# PROCESSING RECORD #28 OF SET 12 FOR CITY, ghauspur.
#
# PROCESSING RECORD #29 OF SET 12 FOR CITY, vyazemskiy.
#
# PROCESSING RECORD #30 OF SET 12 FOR CITY, zaozersk.
#
# PROCESSING RECORD #31 OF SET 12 FOR CITY, inskoy.
#
# PROCESSING RECORD #32 OF SET 12 FOR CITY, key west.
#
# PROCESSING RECORD #33 OF SET 12 FOR CITY, eilat.
#
# PROCESSING RECORD #34 OF SET 12 FOR CITY, ichinohe.
#
# PROCESSING RECORD #35 OF SET 12 FOR CITY, dunay.
#
# PROCESSING RECORD #36 OF SET 12 FOR CITY, aras-asan.
#
# PROCESSING RECORD #37 OF SET 12 FOR CITY, outjo.
# PROCESSING RECORD #38 OF SET 12 FOR CITY, kulhudhuffushi.
#
# PROCESSING RECORD #39 OF SET 12 FOR CITY, corumba.
#
# PROCESSING RECORD #40 OF SET 12 FOR CITY, kegen.
#
# PROCESSING RECORD #41 OF SET 12 FOR CITY, decatur.
#
# PROCESSING RECORD #42 OF SET 12 FOR CITY, copainala.
#
# PROCESSING RECORD #43 OF SET 12 FOR CITY, sumbe.
#
# PROCESSING RECORD #44 OF SET 12 FOR CITY, birao.
#
# PROCESSING RECORD #45 OF SET 12 FOR CITY, yazman.
#
# Data Retrieval for city weather DataFrame is complete.

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Records Count**

# %%
cityWeatherCountIntegerVariable \
    = cityWeatherDataFrame \
        ['City'] \
            .count()

print \
    (f"There are {cityWeatherCountIntegerVariable} " \
     + f"records in the city weather DataFrame.")
# Out:
# There are 563 records in the city weather DataFrame.

# %% [markdown]
# ### **Display City Weather DataFrame**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_62994 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_62994_row0_col0, #T_62994_row0_col1, #T_62994_row0_col2, #T_62994_row0_col3, #T_62994_row0_col4, #T_62994_row0_col5, #T_62994_row0_col6, #T_62994_row0_col7, #T_62994_row0_col8, #T_62994_row1_col0, #T_62994_row1_col1, #T_62994_row1_col2, #T_62994_row1_col3, #T_62994_row1_col4, #T_62994_row1_col6, #T_62994_row1_col7, #T_62994_row1_col8, #T_62994_row2_col0, #T_62994_row2_col1, #T_62994_row2_col2, #T_62994_row2_col3, #T_62994_row2_col5, #T_62994_row2_col6, #T_62994_row2_col7, #T_62994_row2_col8, #T_62994_row3_col0, #T_62994_row3_col1, #T_62994_row3_col2, #T_62994_row3_col3, #T_62994_row3_col4, #T_62994_row3_col6, #T_62994_row3_col7, #T_62994_row3_col8, #T_62994_row4_col0, #T_62994_row4_col1, #T_62994_row4_col2, #T_62994_row4_col5, #T_62994_row4_col7, #T_62994_row4_col8, #T_62994_row5_col0, #T_62994_row5_col1, #T_62994_row5_col2, #T_62994_row5_col3, #T_62994_row5_col7, #T_62994_row5_col8, #T_62994_row6_col0, #T_62994_row6_col1, #T_62994_row6_col2, #T_62994_row6_col3, #T_62994_row6_col4, #T_62994_row6_col6, #T_62994_row6_col7, #T_62994_row6_col8, #T_62994_row7_col0, #T_62994_row7_col1, #T_62994_row7_col2, #T_62994_row7_col4, #T_62994_row7_col5, #T_62994_row7_col6, #T_62994_row7_col7, #T_62994_row7_col8, #T_62994_row8_col0, #T_62994_row8_col1, #T_62994_row8_col2, #T_62994_row8_col3, #T_62994_row8_col4, #T_62994_row8_col6, #T_62994_row8_col7, #T_62994_row8_col8, #T_62994_row9_col0, #T_62994_row9_col1, #T_62994_row9_col2, #T_62994_row9_col3, #T_62994_row9_col4, #T_62994_row9_col5, #T_62994_row9_col6, #T_62994_row9_col7, #T_62994_row9_col8, #T_62994_row10_col0, #T_62994_row10_col1, #T_62994_row10_col2, #T_62994_row10_col3, #T_62994_row10_col4, #T_62994_row10_col5, #T_62994_row10_col6, #T_62994_row10_col7, #T_62994_row10_col8, #T_62994_row11_col0, #T_62994_row11_col1, #T_62994_row11_col2, #T_62994_row11_col3, #T_62994_row11_col4, #T_62994_row11_col6, #T_62994_row11_col7, #T_62994_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_62994_row1_col5, #T_62994_row2_col4, #T_62994_row4_col3, #T_62994_row4_col6, #T_62994_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_62994_row3_col5, #T_62994_row4_col4, #T_62994_row5_col4, #T_62994_row5_col5, #T_62994_row5_col6, #T_62994_row7_col3, #T_62994_row8_col5, #T_62994_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_62994">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_62994_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_62994_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_62994_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_62994_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_62994_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_62994_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_62994_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_62994_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_62994_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_62994_row0_col0" class="data row0 col0" >albany</td>
#       <td id="T_62994_row0_col1" class="data row0 col1" >42.60</td>
#       <td id="T_62994_row0_col2" class="data row0 col2" >-73.97</td>
#       <td id="T_62994_row0_col3" class="data row0 col3" >58.15° F</td>
#       <td id="T_62994_row0_col4" class="data row0 col4" >81%</td>
#       <td id="T_62994_row0_col5" class="data row0 col5" >11%</td>
#       <td id="T_62994_row0_col6" class="data row0 col6" >1.99</td>
#       <td id="T_62994_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_62994_row0_col8" class="data row0 col8" >2023-09-16 20:03:46</td>
#     </tr>
#     <tr>
#       <td id="T_62994_row1_col0" class="data row1 col0" >bethel</td>
#       <td id="T_62994_row1_col1" class="data row1 col1" >41.37</td>
#       <td id="T_62994_row1_col2" class="data row1 col2" >-73.41</td>
#       <td id="T_62994_row1_col3" class="data row1 col3" >56.30° F</td>
#       <td id="T_62994_row1_col4" class="data row1 col4" >80%</td>
#       <td id="T_62994_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_62994_row1_col6" class="data row1 col6" >4.61</td>
#       <td id="T_62994_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_62994_row1_col8" class="data row1 col8" >2023-09-16 19:58:04</td>
#     </tr>
#     <tr>
#       <td id="T_62994_row2_col0" class="data row2 col0" >college</td>
#       <td id="T_62994_row2_col1" class="data row2 col1" >64.86</td>
#       <td id="T_62994_row2_col2" class="data row2 col2" >-147.80</td>
#       <td id="T_62994_row2_col3" class="data row2 col3" >57.18° F</td>
#       <td id="T_62994_row2_col4" class="data row2 col4" >48%</td>
#       <td id="T_62994_row2_col5" class="data row2 col5" >40%</td>
#       <td id="T_62994_row2_col6" class="data row2 col6" >4.61</td>
#       <td id="T_62994_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_62994_row2_col8" class="data row2 col8" >2023-09-16 20:00:00</td>
#     </tr>
#     <tr>
#       <td id="T_62994_row3_col0" class="data row3 col0" >sisimiut</td>
#       <td id="T_62994_row3_col1" class="data row3 col1" >66.94</td>
#       <td id="T_62994_row3_col2" class="data row3 col2" >-53.67</td>
#       <td id="T_62994_row3_col3" class="data row3 col3" >35.73° F</td>
#       <td id="T_62994_row3_col4" class="data row3 col4" >74%</td>
#       <td id="T_62994_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_62994_row3_col6" class="data row3 col6" >3.56</td>
#       <td id="T_62994_row3_col7" class="data row3 col7" >GL</td>
#       <td id="T_62994_row3_col8" class="data row3 col8" >2023-09-16 20:07:38</td>
#     </tr>
#     <tr>
#       <td id="T_62994_row4_col0" class="data row4 col0" >calvinia</td>
#       <td id="T_62994_row4_col1" class="data row4 col1" >-31.47</td>
#       <td id="T_62994_row4_col2" class="data row4 col2" >19.78</td>
#       <td id="T_62994_row4_col3" class="data row4 col3" >35.40° F</td>
#       <td id="T_62994_row4_col4" class="data row4 col4" >96%</td>
#       <td id="T_62994_row4_col5" class="data row4 col5" >63%</td>
#       <td id="T_62994_row4_col6" class="data row4 col6" >1.36</td>
#       <td id="T_62994_row4_col7" class="data row4 col7" >ZA</td>
#       <td id="T_62994_row4_col8" class="data row4 col8" >2023-09-16 20:07:38</td>
#     </tr>
#     <tr>
#       <td id="T_62994_row5_col0" class="data row5 col0" >port-aux-francais</td>
#       <td id="T_62994_row5_col1" class="data row5 col1" >-49.35</td>
#       <td id="T_62994_row5_col2" class="data row5 col2" >70.22</td>
#       <td id="T_62994_row5_col3" class="data row5 col3" >42.51° F</td>
#       <td id="T_62994_row5_col4" class="data row5 col4" >96%</td>
#       <td id="T_62994_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_62994_row5_col6" class="data row5 col6" >36.04</td>
#       <td id="T_62994_row5_col7" class="data row5 col7" >TF</td>
#       <td id="T_62994_row5_col8" class="data row5 col8" >2023-09-16 20:02:02</td>
#     </tr>
#     <tr>
#       <td id="T_62994_row6_col0" class="data row6 col0" >qaqortoq</td>
#       <td id="T_62994_row6_col1" class="data row6 col1" >60.72</td>
#       <td id="T_62994_row6_col2" class="data row6 col2" >-46.03</td>
#       <td id="T_62994_row6_col3" class="data row6 col3" >37.22° F</td>
#       <td id="T_62994_row6_col4" class="data row6 col4" >66%</td>
#       <td id="T_62994_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_62994_row6_col6" class="data row6 col6" >21.07</td>
#       <td id="T_62994_row6_col7" class="data row6 col7" >GL</td>
#       <td id="T_62994_row6_col8" class="data row6 col8" >2023-09-16 20:02:29</td>
#     </tr>
#     <tr>
#       <td id="T_62994_row7_col0" class="d

# %% [markdown]
# ### **Data Export to CSV File**

# %%
subroutine \
    .WriteDataFrameToCSVFile \
        (cityWeatherDataFrame,
         local_constant.WEATHER_DATA_FILE_PATH,
         local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Data Import from CSV File**

# %%
sampleCityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Display Sample City Weather DataFrame**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information from CSV File')
# Out:
# <style type="text/css">
# #T_f450d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_f450d_row0_col0, #T_f450d_row0_col1, #T_f450d_row0_col2, #T_f450d_row0_col3, #T_f450d_row0_col4, #T_f450d_row0_col5, #T_f450d_row0_col6, #T_f450d_row0_col7, #T_f450d_row0_col8, #T_f450d_row1_col0, #T_f450d_row1_col1, #T_f450d_row1_col2, #T_f450d_row1_col3, #T_f450d_row1_col4, #T_f450d_row1_col6, #T_f450d_row1_col7, #T_f450d_row1_col8, #T_f450d_row2_col0, #T_f450d_row2_col1, #T_f450d_row2_col2, #T_f450d_row2_col3, #T_f450d_row2_col5, #T_f450d_row2_col6, #T_f450d_row2_col7, #T_f450d_row2_col8, #T_f450d_row3_col0, #T_f450d_row3_col1, #T_f450d_row3_col2, #T_f450d_row3_col3, #T_f450d_row3_col4, #T_f450d_row3_col6, #T_f450d_row3_col7, #T_f450d_row3_col8, #T_f450d_row4_col0, #T_f450d_row4_col1, #T_f450d_row4_col2, #T_f450d_row4_col5, #T_f450d_row4_col7, #T_f450d_row4_col8, #T_f450d_row5_col0, #T_f450d_row5_col1, #T_f450d_row5_col2, #T_f450d_row5_col3, #T_f450d_row5_col7, #T_f450d_row5_col8, #T_f450d_row6_col0, #T_f450d_row6_col1, #T_f450d_row6_col2, #T_f450d_row6_col3, #T_f450d_row6_col4, #T_f450d_row6_col6, #T_f450d_row6_col7, #T_f450d_row6_col8, #T_f450d_row7_col0, #T_f450d_row7_col1, #T_f450d_row7_col2, #T_f450d_row7_col4, #T_f450d_row7_col5, #T_f450d_row7_col6, #T_f450d_row7_col7, #T_f450d_row7_col8, #T_f450d_row8_col0, #T_f450d_row8_col1, #T_f450d_row8_col2, #T_f450d_row8_col3, #T_f450d_row8_col4, #T_f450d_row8_col6, #T_f450d_row8_col7, #T_f450d_row8_col8, #T_f450d_row9_col0, #T_f450d_row9_col1, #T_f450d_row9_col2, #T_f450d_row9_col3, #T_f450d_row9_col4, #T_f450d_row9_col5, #T_f450d_row9_col6, #T_f450d_row9_col7, #T_f450d_row9_col8, #T_f450d_row10_col0, #T_f450d_row10_col1, #T_f450d_row10_col2, #T_f450d_row10_col3, #T_f450d_row10_col4, #T_f450d_row10_col5, #T_f450d_row10_col6, #T_f450d_row10_col7, #T_f450d_row10_col8, #T_f450d_row11_col0, #T_f450d_row11_col1, #T_f450d_row11_col2, #T_f450d_row11_col3, #T_f450d_row11_col4, #T_f450d_row11_col6, #T_f450d_row11_col7, #T_f450d_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_f450d_row1_col5, #T_f450d_row2_col4, #T_f450d_row4_col3, #T_f450d_row4_col6, #T_f450d_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_f450d_row3_col5, #T_f450d_row4_col4, #T_f450d_row5_col4, #T_f450d_row5_col5, #T_f450d_row5_col6, #T_f450d_row7_col3, #T_f450d_row8_col5, #T_f450d_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_f450d">
#   <caption>Table: 1.1: City Weather Information from CSV File</caption>
#   <thead>
#     <tr>
#       <th id="T_f450d_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_f450d_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_f450d_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_f450d_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_f450d_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_f450d_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_f450d_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_f450d_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_f450d_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f450d_row0_col0" class="data row0 col0" >albany</td>
#       <td id="T_f450d_row0_col1" class="data row0 col1" >42.60</td>
#       <td id="T_f450d_row0_col2" class="data row0 col2" >-73.97</td>
#       <td id="T_f450d_row0_col3" class="data row0 col3" >58.15° F</td>
#       <td id="T_f450d_row0_col4" class="data row0 col4" >81%</td>
#       <td id="T_f450d_row0_col5" class="data row0 col5" >11%</td>
#       <td id="T_f450d_row0_col6" class="data row0 col6" >1.99</td>
#       <td id="T_f450d_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_f450d_row0_col8" class="data row0 col8" >2023-09-16 20:03:46</td>
#     </tr>
#     <tr>
#       <td id="T_f450d_row1_col0" class="data row1 col0" >bethel</td>
#       <td id="T_f450d_row1_col1" class="data row1 col1" >41.37</td>
#       <td id="T_f450d_row1_col2" class="data row1 col2" >-73.41</td>
#       <td id="T_f450d_row1_col3" class="data row1 col3" >56.30° F</td>
#       <td id="T_f450d_row1_col4" class="data row1 col4" >80%</td>
#       <td id="T_f450d_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_f450d_row1_col6" class="data row1 col6" >4.61</td>
#       <td id="T_f450d_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_f450d_row1_col8" class="data row1 col8" >2023-09-16 19:58:04</td>
#     </tr>
#     <tr>
#       <td id="T_f450d_row2_col0" class="data row2 col0" >college</td>
#       <td id="T_f450d_row2_col1" class="data row2 col1" >64.86</td>
#       <td id="T_f450d_row2_col2" class="data row2 col2" >-147.80</td>
#       <td id="T_f450d_row2_col3" class="data row2 col3" >57.18° F</td>
#       <td id="T_f450d_row2_col4" class="data row2 col4" >48%</td>
#       <td id="T_f450d_row2_col5" class="data row2 col5" >40%</td>
#       <td id="T_f450d_row2_col6" class="data row2 col6" >4.61</td>
#       <td id="T_f450d_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_f450d_row2_col8" class="data row2 col8" >2023-09-16 20:00:00</td>
#     </tr>
#     <tr>
#       <td id="T_f450d_row3_col0" class="data row3 col0" >sisimiut</td>
#       <td id="T_f450d_row3_col1" class="data row3 col1" >66.94</td>
#       <td id="T_f450d_row3_col2" class="data row3 col2" >-53.67</td>
#       <td id="T_f450d_row3_col3" class="data row3 col3" >35.73° F</td>
#       <td id="T_f450d_row3_col4" class="data row3 col4" >74%</td>
#       <td id="T_f450d_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_f450d_row3_col6" class="data row3 col6" >3.56</td>
#       <td id="T_f450d_row3_col7" class="data row3 col7" >GL</td>
#       <td id="T_f450d_row3_col8" class="data row3 col8" >2023-09-16 20:07:38</td>
#     </tr>
#     <tr>
#       <td id="T_f450d_row4_col0" class="data row4 col0" >calvinia</td>
#       <td id="T_f450d_row4_col1" class="data row4 col1" >-31.47</td>
#       <td id="T_f450d_row4_col2" class="data row4 col2" >19.78</td>
#       <td id="T_f450d_row4_col3" class="data row4 col3" >35.40° F</td>
#       <td id="T_f450d_row4_col4" class="data row4 col4" >96%</td>
#       <td id="T_f450d_row4_col5" class="data row4 col5" >63%</td>
#       <td id="T_f450d_row4_col6" class="data row4 col6" >1.36</td>
#       <td id="T_f450d_row4_col7" class="data row4 col7" >ZA</td>
#       <td id="T_f450d_row4_col8" class="data row4 col8" >2023-09-16 20:07:38</td>
#     </tr>
#     <tr>
#       <td id="T_f450d_row5_col0" class="data row5 col0" >port-aux-francais</td>
#       <td id="T_f450d_row5_col1" class="data row5 col1" >-49.35</td>
#       <td id="T_f450d_row5_col2" class="data row5 col2" >70.22</td>
#       <td id="T_f450d_row5_col3" class="data row5 col3" >42.51° F</td>
#       <td id="T_f450d_row5_col4" class="data row5 col4" >96%</td>
#       <td id="T_f450d_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_f450d_row5_col6" class="data row5 col6" >36.04</td>
#       <td id="T_f450d_row5_col7" class="data row5 col7" >TF</td>
#       <td id="T_f450d_row5_col8" class="data row5 col8" >2023-09-16 20:02:02</td>
#     </tr>
#     <tr>
#       <td id="T_f450d_row6_col0" class="data row6 col0" >qaqortoq</td>
#       <td id="T_f450d_row6_col1" class="data row6 col1" >60.72</td>
#       <td id="T_f450d_row6_col2" class="data row6 col2" >-46.03</td>
#       <td id="T_f450d_row6_col3" class="data row6 col3" >37.22° F</td>
#       <td id="T_f450d_row6_col4" class="data row6 col4" >66%</td>
#       <td id="T_f450d_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_f450d_row6_col6" class="data row6 col6" >21.07</td>
#       <td id="T_f450d_row6_col7" class="data row6 col7" >GL</td>
#       <td id="T_f450d_row6_col8" class="data row6 col8" >2023-09-16 20:02:29</td>
#     </tr>
#     <tr>
#       <td id="T_f450d_row7_

# %% [markdown]
# ## **Section 1.2: Scatter Plots w/Regression**

# %% [markdown]
# ### **Temperature Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1: Temperature Vs. Latitude (Scatter Plot)')

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1.1: Temperature Vs. Latitude (Scatter Plot w/Regression)', 
         2, -48.0, 28.0)
# Out:
# r-value:     0.8399
# r-squared:   0.7055

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### Although this assignment is about linear regression, I notice that the independent variable, latitude, has a relationship with the dependent variable, temperature, just not a linear one.  With linear regression, we obtain a -0.1346 correlation; with quadratic regression, the correlation increases to 0.7879.  In practiice, analysts consider a 0.60-0.79 correlation to be strong.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.2.2: Humidity Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Cloudiness Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.2.3: Cloudiness Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.2.4: Wind Speed vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **City Weather Information Correlation Matrix**

# %%
frameDictionary \
    = {'Latitude': 
            cityWeatherDataFrame \
                ['Latitude'], 
       'Temperature': 
            cityWeatherDataFrame \
                ['Temperature'], 
       'Humidity': 
            cityWeatherDataFrame \
                ['Humidity'],
       'Cloudiness': 
            cityWeatherDataFrame \
                ['Cloudiness'],
       'Wind Speed':
            cityWeatherDataFrame \
                ['Wind Speed']}


function \
    .ReturnCorrelationTableStandardFormat \
        (pd \
             .DataFrame \
                 (frameDictionary),
         'Table 1.2.1: City Weather Correlation Matrix')
# Out:
# <style type="text/css">
# #T_f5e3b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_f5e3b_row0_col0, #T_f5e3b_row0_col1, #T_f5e3b_row0_col2, #T_f5e3b_row0_col3, #T_f5e3b_row0_col4, #T_f5e3b_row1_col0, #T_f5e3b_row1_col1, #T_f5e3b_row1_col2, #T_f5e3b_row1_col3, #T_f5e3b_row1_col4, #T_f5e3b_row2_col0, #T_f5e3b_row2_col1, #T_f5e3b_row2_col2, #T_f5e3b_row2_col3, #T_f5e3b_row2_col4, #T_f5e3b_row3_col0, #T_f5e3b_row3_col1, #T_f5e3b_row3_col2, #T_f5e3b_row3_col3, #T_f5e3b_row3_col4, #T_f5e3b_row4_col0, #T_f5e3b_row4_col1, #T_f5e3b_row4_col2, #T_f5e3b_row4_col3, #T_f5e3b_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_f5e3b">
#   <caption>Table 1.2.1: City Weather Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5e3b_level0_col0" class="col_heading level0 col0" >Latitude</th>
#       <th id="T_f5e3b_level0_col1" class="col_heading level0 col1" >Temperature</th>
#       <th id="T_f5e3b_level0_col2" class="col_heading level0 col2" >Humidity</th>
#       <th id="T_f5e3b_level0_col3" class="col_heading level0 col3" >Cloudiness</th>
#       <th id="T_f5e3b_level0_col4" class="col_heading level0 col4" >Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5e3b_level0_row0" class="row_heading level0 row0" >Latitude</th>
#       <td id="T_f5e3b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f5e3b_row0_col1" class="data row0 col1" >-0.282111</td>
#       <td id="T_f5e3b_row0_col2" class="data row0 col2" >0.084459</td>
#       <td id="T_f5e3b_row0_col3" class="data row0 col3" >0.197320</td>
#       <td id="T_f5e3b_row0_col4" class="data row0 col4" >-0.169953</td>
#     </tr>
#     <tr>
#       <th id="T_f5e3b_level0_row1" class="row_heading level0 row1" >Temperature</th>
#       <td id="T_f5e3b_row1_col0" class="data row1 col0" >-0.282111</td>
#       <td id="T_f5e3b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f5e3b_row1_col2" class="data row1 col2" >-0.254212</td>
#       <td id="T_f5e3b_row1_col3" class="data row1 col3" >-0.195077</td>
#       <td id="T_f5e3b_row1_col4" class="data row1 col4" >0.053613</td>
#     </tr>
#     <tr>
#       <th id="T_f5e3b_level0_row2" class="row_heading level0 row2" >Humidity</th>
#       <td id="T_f5e3b_row2_col0" class="data row2 col0" >0.084459</td>
#       <td id="T_f5e3b_row2_col1" class="data row2 col1" >-0.254212</td>
#       <td id="T_f5e3b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f5e3b_row2_col3" class="data row2 col3" >0.414553</td>
#       <td id="T_f5e3b_row2_col4" class="data row2 col4" >-0.050956</td>
#     </tr>
#     <tr>
#       <th id="T_f5e3b_level0_row3" class="row_heading level0 row3" >Cloudiness</th>
#       <td id="T_f5e3b_row3_col0" class="data row3 col0" >0.197320</td>
#       <td id="T_f5e3b_row3_col1" class="data row3 col1" >-0.195077</td>
#       <td id="T_f5e3b_row3_col2" class="data row3 col2" >0.414553</td>
#       <td id="T_f5e3b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f5e3b_row3_col4" class="data row3 col4" >0.054449</td>
#     </tr>
#     <tr>
#       <th id="T_f5e3b_level0_row4" class="row_heading level0 row4" >Wind Speed</th>
#       <td id="T_f5e3b_row4_col0" class="data row4 col0" >-0.169953</td>
#       <td id="T_f5e3b_row4_col1" class="data row4 col1" >0.053613</td>
#       <td id="T_f5e3b_row4_col2" class="data row4 col2" >-0.050956</td>
#       <td id="T_f5e3b_row4_col3" class="data row4 col3" >0.054449</td>
#       <td id="T_f5e3b_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Discussion about correlation:** YOUR RESPONSE HERE

# %% [markdown]
# ## **Section 1.3: Hemisphere Scatter Plots with Linear Regression**

# %% [markdown]
# ### **Northern Hemisphere City Weather Information**

# %%
northernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (northernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.1: City Weather Information (Northern Hemisphere)')
# Out:
# <style type="text/css">
# #T_2684b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_2684b_row0_col0, #T_2684b_row0_col1, #T_2684b_row0_col2, #T_2684b_row0_col3, #T_2684b_row0_col4, #T_2684b_row0_col5, #T_2684b_row0_col7, #T_2684b_row0_col8, #T_2684b_row1_col0, #T_2684b_row1_col1, #T_2684b_row1_col2, #T_2684b_row1_col3, #T_2684b_row1_col4, #T_2684b_row1_col6, #T_2684b_row1_col7, #T_2684b_row1_col8, #T_2684b_row2_col0, #T_2684b_row2_col1, #T_2684b_row2_col2, #T_2684b_row2_col3, #T_2684b_row2_col5, #T_2684b_row2_col6, #T_2684b_row2_col7, #T_2684b_row2_col8, #T_2684b_row3_col0, #T_2684b_row3_col1, #T_2684b_row3_col2, #T_2684b_row3_col4, #T_2684b_row3_col6, #T_2684b_row3_col7, #T_2684b_row3_col8, #T_2684b_row4_col0, #T_2684b_row4_col1, #T_2684b_row4_col2, #T_2684b_row4_col3, #T_2684b_row4_col4, #T_2684b_row4_col6, #T_2684b_row4_col7, #T_2684b_row4_col8, #T_2684b_row5_col0, #T_2684b_row5_col1, #T_2684b_row5_col2, #T_2684b_row5_col3, #T_2684b_row5_col4, #T_2684b_row5_col5, #T_2684b_row5_col6, #T_2684b_row5_col7, #T_2684b_row5_col8, #T_2684b_row6_col0, #T_2684b_row6_col1, #T_2684b_row6_col2, #T_2684b_row6_col3, #T_2684b_row6_col4, #T_2684b_row6_col5, #T_2684b_row6_col6, #T_2684b_row6_col7, #T_2684b_row6_col8, #T_2684b_row7_col0, #T_2684b_row7_col1, #T_2684b_row7_col2, #T_2684b_row7_col3, #T_2684b_row7_col4, #T_2684b_row7_col7, #T_2684b_row7_col8, #T_2684b_row8_col0, #T_2684b_row8_col1, #T_2684b_row8_col2, #T_2684b_row8_col3, #T_2684b_row8_col6, #T_2684b_row8_col7, #T_2684b_row8_col8, #T_2684b_row9_col0, #T_2684b_row9_col1, #T_2684b_row9_col2, #T_2684b_row9_col3, #T_2684b_row9_col4, #T_2684b_row9_col5, #T_2684b_row9_col6, #T_2684b_row9_col7, #T_2684b_row9_col8, #T_2684b_row10_col0, #T_2684b_row10_col1, #T_2684b_row10_col2, #T_2684b_row10_col4, #T_2684b_row10_col5, #T_2684b_row10_col6, #T_2684b_row10_col7, #T_2684b_row10_col8, #T_2684b_row11_col0, #T_2684b_row11_col1, #T_2684b_row11_col2, #T_2684b_row11_col3, #T_2684b_row11_col4, #T_2684b_row11_col6, #T_2684b_row11_col7, #T_2684b_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_2684b_row0_col6, #T_2684b_row1_col5, #T_2684b_row2_col4, #T_2684b_row3_col3, #T_2684b_row4_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_2684b_row3_col5, #T_2684b_row7_col5, #T_2684b_row7_col6, #T_2684b_row8_col4, #T_2684b_row8_col5, #T_2684b_row10_col3, #T_2684b_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_2684b">
#   <caption>Table: 1.3.1: City Weather Information (Northern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_2684b_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_2684b_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_2684b_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_2684b_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_2684b_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_2684b_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_2684b_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_2684b_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_2684b_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2684b_row0_col0" class="data row0 col0" >albany</td>
#       <td id="T_2684b_row0_col1" class="data row0 col1" >42.60</td>
#       <td id="T_2684b_row0_col2" class="data row0 col2" >-73.97</td>
#       <td id="T_2684b_row0_col3" class="data row0 col3" >58.15° F</td>
#       <td id="T_2684b_row0_col4" class="data row0 col4" >81%</td>
#       <td id="T_2684b_row0_col5" class="data row0 col5" >11%</td>
#       <td id="T_2684b_row0_col6" class="data row0 col6" >1.99</td>
#       <td id="T_2684b_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_2684b_row0_col8" class="data row0 col8" >2023-09-16 20:03:46</td>
#     </tr>
#     <tr>
#       <td id="T_2684b_row1_col0" class="data row1 col0" >bethel</td>
#       <td id="T_2684b_row1_col1" class="data row1 col1" >41.37</td>
#       <td id="T_2684b_row1_col2" class="data row1 col2" >-73.41</td>
#       <td id="T_2684b_row1_col3" class="data row1 col3" >56.30° F</td>
#       <td id="T_2684b_row1_col4" class="data row1 col4" >80%</td>
#       <td id="T_2684b_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_2684b_row1_col6" class="data row1 col6" >4.61</td>
#       <td id="T_2684b_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_2684b_row1_col8" class="data row1 col8" >2023-09-16 19:58:04</td>
#     </tr>
#     <tr>
#       <td id="T_2684b_row2_col0" class="data row2 col0" >college</td>
#       <td id="T_2684b_row2_col1" class="data row2 col1" >64.86</td>
#       <td id="T_2684b_row2_col2" class="data row2 col2" >-147.80</td>
#       <td id="T_2684b_row2_col3" class="data row2 col3" >57.18° F</td>
#       <td id="T_2684b_row2_col4" class="data row2 col4" >48%</td>
#       <td id="T_2684b_row2_col5" class="data row2 col5" >40%</td>
#       <td id="T_2684b_row2_col6" class="data row2 col6" >4.61</td>
#       <td id="T_2684b_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_2684b_row2_col8" class="data row2 col8" >2023-09-16 20:00:00</td>
#     </tr>
#     <tr>
#       <td id="T_2684b_row3_col0" class="data row3 col0" >sisimiut</td>
#       <td id="T_2684b_row3_col1" class="data row3 col1" >66.94</td>
#       <td id="T_2684b_row3_col2" class="data row3 col2" >-53.67</td>
#       <td id="T_2684b_row3_col3" class="data row3 col3" >35.73° F</td>
#       <td id="T_2684b_row3_col4" class="data row3 col4" >74%</td>
#       <td id="T_2684b_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_2684b_row3_col6" class="data row3 col6" >3.56</td>
#       <td id="T_2684b_row3_col7" class="data row3 col7" >GL</td>
#       <td id="T_2684b_row3_col8" class="data row3 col8" >2023-09-16 20:07:38</td>
#     </tr>
#     <tr>
#       <td id="T_2684b_row4_col0" class="data row4 col0" >qaqortoq</td>
#       <td id="T_2684b_row4_col1" class="data row4 col1" >60.72</td>
#       <td id="T_2684b_row4_col2" class="data row4 col2" >-46.03</td>
#       <td id="T_2684b_row4_col3" class="data row4 col3" >37.22° F</td>
#       <td id="T_2684b_row4_col4" class="data row4 col4" >66%</td>
#       <td id="T_2684b_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_2684b_row4_col6" class="data row4 col6" >21.07</td>
#       <td id="T_2684b_row4_col7" class="data row4 col7" >GL</td>
#       <td id="T_2684b_row4_col8" class="data row4 col8" >2023-09-16 20:02:29</td>
#     </tr>
#     <tr>
#       <td id="T_2684b_row5_col0" class="data row5 col0" >okha</td>
#       <td id="T_2684b_row5_col1" class="data row5 col1" >53.57</td>
#       <td id="T_2684b_row5_col2" class="data row5 col2" >142.95</td>
#       <td id="T_2684b_row5_col3" class="data row5 col3" >57.25° F</td>
#       <td id="T_2684b_row5_col4" class="data row5 col4" >54%</td>
#       <td id="T_2684b_row5_col5" class="data row5 col5" >53%</td>
#       <td id="T_2684b_row5_col6" class="data row5 col6" >16.96</td>
#       <td id="T_2684b_row5_col7" class="data row5 col7" >RU</td>
#       <td id="T_2684b_row5_col8" class="data row5 col8" >2023-09-16 20:03:57</td>
#     </tr>
#     <tr>
#       <td id="T_2684b_row6_col0" class="data row6 col0" >lihue</td>
#       <td id="T_2684b_row6_col1" class="data row6 col1" >21.98</td>
#       <td id="T_2684b_row6_col2" class="data row6 col2" >-159.37</td>
#       <td id="T_2684b_row6_col3" class="data row6 col3" >78.75° F</td>
#       <td id="T_2684b_row6_col4" class="data row6 col4" >84%</td>
#       <td id="T_2684b_row6_col5" class="data row6 col5" >33%</td>
#       <td id="T_2684b_row6_col6" class="data row6 col6" >11.81</td>
#       <td id="T_2684b_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_2684b_row6_col8" class="data row6 col8" >2023-09-16 20:02:41</td>
#     </tr>
#     <tr>
#       <td id="T_2684b_row7_col0"

# %% [markdown]
# ### **Southern Hemisphere City Weather Information**

# %%
southernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (southernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.2: City Weather Information (Southern Hemisphere)')
# Out:
# <style type="text/css">
# #T_ef8db caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_ef8db_row0_col0, #T_ef8db_row0_col1, #T_ef8db_row0_col2, #T_ef8db_row0_col3, #T_ef8db_row0_col4, #T_ef8db_row0_col5, #T_ef8db_row0_col7, #T_ef8db_row0_col8, #T_ef8db_row1_col0, #T_ef8db_row1_col1, #T_ef8db_row1_col2, #T_ef8db_row1_col3, #T_ef8db_row1_col4, #T_ef8db_row1_col6, #T_ef8db_row1_col7, #T_ef8db_row1_col8, #T_ef8db_row2_col0, #T_ef8db_row2_col1, #T_ef8db_row2_col2, #T_ef8db_row2_col3, #T_ef8db_row2_col5, #T_ef8db_row2_col6, #T_ef8db_row2_col7, #T_ef8db_row2_col8, #T_ef8db_row3_col0, #T_ef8db_row3_col1, #T_ef8db_row3_col2, #T_ef8db_row3_col4, #T_ef8db_row3_col6, #T_ef8db_row3_col7, #T_ef8db_row3_col8, #T_ef8db_row4_col0, #T_ef8db_row4_col1, #T_ef8db_row4_col2, #T_ef8db_row4_col3, #T_ef8db_row4_col4, #T_ef8db_row4_col6, #T_ef8db_row4_col7, #T_ef8db_row4_col8, #T_ef8db_row5_col0, #T_ef8db_row5_col1, #T_ef8db_row5_col2, #T_ef8db_row5_col3, #T_ef8db_row5_col4, #T_ef8db_row5_col5, #T_ef8db_row5_col6, #T_ef8db_row5_col7, #T_ef8db_row5_col8, #T_ef8db_row6_col0, #T_ef8db_row6_col1, #T_ef8db_row6_col2, #T_ef8db_row6_col3, #T_ef8db_row6_col4, #T_ef8db_row6_col5, #T_ef8db_row6_col6, #T_ef8db_row6_col7, #T_ef8db_row6_col8, #T_ef8db_row7_col0, #T_ef8db_row7_col1, #T_ef8db_row7_col2, #T_ef8db_row7_col3, #T_ef8db_row7_col4, #T_ef8db_row7_col7, #T_ef8db_row7_col8, #T_ef8db_row8_col0, #T_ef8db_row8_col1, #T_ef8db_row8_col2, #T_ef8db_row8_col3, #T_ef8db_row8_col6, #T_ef8db_row8_col7, #T_ef8db_row8_col8, #T_ef8db_row9_col0, #T_ef8db_row9_col1, #T_ef8db_row9_col2, #T_ef8db_row9_col3, #T_ef8db_row9_col4, #T_ef8db_row9_col5, #T_ef8db_row9_col6, #T_ef8db_row9_col7, #T_ef8db_row9_col8, #T_ef8db_row10_col0, #T_ef8db_row10_col1, #T_ef8db_row10_col2, #T_ef8db_row10_col4, #T_ef8db_row10_col5, #T_ef8db_row10_col6, #T_ef8db_row10_col7, #T_ef8db_row10_col8, #T_ef8db_row11_col0, #T_ef8db_row11_col1, #T_ef8db_row11_col2, #T_ef8db_row11_col3, #T_ef8db_row11_col4, #T_ef8db_row11_col6, #T_ef8db_row11_col7, #T_ef8db_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_ef8db_row0_col6, #T_ef8db_row1_col5, #T_ef8db_row2_col4, #T_ef8db_row3_col3, #T_ef8db_row4_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_ef8db_row3_col5, #T_ef8db_row7_col5, #T_ef8db_row7_col6, #T_ef8db_row8_col4, #T_ef8db_row8_col5, #T_ef8db_row10_col3, #T_ef8db_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_ef8db">
#   <caption>Table: 1.3.2: City Weather Information (Southern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_ef8db_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_ef8db_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_ef8db_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_ef8db_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_ef8db_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_ef8db_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_ef8db_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_ef8db_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_ef8db_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ef8db_row0_col0" class="data row0 col0" >albany</td>
#       <td id="T_ef8db_row0_col1" class="data row0 col1" >42.60</td>
#       <td id="T_ef8db_row0_col2" class="data row0 col2" >-73.97</td>
#       <td id="T_ef8db_row0_col3" class="data row0 col3" >58.15° F</td>
#       <td id="T_ef8db_row0_col4" class="data row0 col4" >81%</td>
#       <td id="T_ef8db_row0_col5" class="data row0 col5" >11%</td>
#       <td id="T_ef8db_row0_col6" class="data row0 col6" >1.99</td>
#       <td id="T_ef8db_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_ef8db_row0_col8" class="data row0 col8" >2023-09-16 20:03:46</td>
#     </tr>
#     <tr>
#       <td id="T_ef8db_row1_col0" class="data row1 col0" >bethel</td>
#       <td id="T_ef8db_row1_col1" class="data row1 col1" >41.37</td>
#       <td id="T_ef8db_row1_col2" class="data row1 col2" >-73.41</td>
#       <td id="T_ef8db_row1_col3" class="data row1 col3" >56.30° F</td>
#       <td id="T_ef8db_row1_col4" class="data row1 col4" >80%</td>
#       <td id="T_ef8db_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_ef8db_row1_col6" class="data row1 col6" >4.61</td>
#       <td id="T_ef8db_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_ef8db_row1_col8" class="data row1 col8" >2023-09-16 19:58:04</td>
#     </tr>
#     <tr>
#       <td id="T_ef8db_row2_col0" class="data row2 col0" >college</td>
#       <td id="T_ef8db_row2_col1" class="data row2 col1" >64.86</td>
#       <td id="T_ef8db_row2_col2" class="data row2 col2" >-147.80</td>
#       <td id="T_ef8db_row2_col3" class="data row2 col3" >57.18° F</td>
#       <td id="T_ef8db_row2_col4" class="data row2 col4" >48%</td>
#       <td id="T_ef8db_row2_col5" class="data row2 col5" >40%</td>
#       <td id="T_ef8db_row2_col6" class="data row2 col6" >4.61</td>
#       <td id="T_ef8db_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_ef8db_row2_col8" class="data row2 col8" >2023-09-16 20:00:00</td>
#     </tr>
#     <tr>
#       <td id="T_ef8db_row3_col0" class="data row3 col0" >sisimiut</td>
#       <td id="T_ef8db_row3_col1" class="data row3 col1" >66.94</td>
#       <td id="T_ef8db_row3_col2" class="data row3 col2" >-53.67</td>
#       <td id="T_ef8db_row3_col3" class="data row3 col3" >35.73° F</td>
#       <td id="T_ef8db_row3_col4" class="data row3 col4" >74%</td>
#       <td id="T_ef8db_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_ef8db_row3_col6" class="data row3 col6" >3.56</td>
#       <td id="T_ef8db_row3_col7" class="data row3 col7" >GL</td>
#       <td id="T_ef8db_row3_col8" class="data row3 col8" >2023-09-16 20:07:38</td>
#     </tr>
#     <tr>
#       <td id="T_ef8db_row4_col0" class="data row4 col0" >qaqortoq</td>
#       <td id="T_ef8db_row4_col1" class="data row4 col1" >60.72</td>
#       <td id="T_ef8db_row4_col2" class="data row4 col2" >-46.03</td>
#       <td id="T_ef8db_row4_col3" class="data row4 col3" >37.22° F</td>
#       <td id="T_ef8db_row4_col4" class="data row4 col4" >66%</td>
#       <td id="T_ef8db_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_ef8db_row4_col6" class="data row4 col6" >21.07</td>
#       <td id="T_ef8db_row4_col7" class="data row4 col7" >GL</td>
#       <td id="T_ef8db_row4_col8" class="data row4 col8" >2023-09-16 20:02:29</td>
#     </tr>
#     <tr>
#       <td id="T_ef8db_row5_col0" class="data row5 col0" >okha</td>
#       <td id="T_ef8db_row5_col1" class="data row5 col1" >53.57</td>
#       <td id="T_ef8db_row5_col2" class="data row5 col2" >142.95</td>
#       <td id="T_ef8db_row5_col3" class="data row5 col3" >57.25° F</td>
#       <td id="T_ef8db_row5_col4" class="data row5 col4" >54%</td>
#       <td id="T_ef8db_row5_col5" class="data row5 col5" >53%</td>
#       <td id="T_ef8db_row5_col6" class="data row5 col6" >16.96</td>
#       <td id="T_ef8db_row5_col7" class="data row5 col7" >RU</td>
#       <td id="T_ef8db_row5_col8" class="data row5 col8" >2023-09-16 20:03:57</td>
#     </tr>
#     <tr>
#       <td id="T_ef8db_row6_col0" class="data row6 col0" >lihue</td>
#       <td id="T_ef8db_row6_col1" class="data row6 col1" >21.98</td>
#       <td id="T_ef8db_row6_col2" class="data row6 col2" >-159.37</td>
#       <td id="T_ef8db_row6_col3" class="data row6 col3" >78.75° F</td>
#       <td id="T_ef8db_row6_col4" class="data row6 col4" >84%</td>
#       <td id="T_ef8db_row6_col5" class="data row6 col5" >33%</td>
#       <td id="T_ef8db_row6_col6" class="data row6 col6" >11.81</td>
#       <td id="T_ef8db_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_ef8db_row6_col8" class="data row6 col8" >2023-09-16 20:02:41</td>
#     </tr>
#     <tr>
#       <td id="T_ef8db_row7_col0"

# %% [markdown]
# ### **Temperature vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.1: Temperature vs. Latitude (Northern Hemisphere)',
         1, 2.0, 45.0)
# Out:
# r-value:     -0.8086
# r-squared:   0.6538

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.2: Temperature vs. Latitude (Southern Hemisphere)',
         1, -55.0, 85.0)
# Out:
# r-value:     0.7412
# r-squared:   0.5494

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### From the results of the linear regression, in the northern hemisphere, the latitude is negatively correlated with temperature; this negative correlation tells us that the two variables move in opposite directions: as latitude increases, the temperature drops, and vice versa.  In the southern hemisphers, the latitude is positively correlated with temperature: this positive correlation tells us that the two variables move in the same direction: as latitude increases, the temperature increases.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.3: Humidity vs. Latitude (Northern Hemisphere)',
         1, 45.0, 18.0)
# Out:
# r-value:     -0.0022
# r-squared:   0.0000

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.4: Humidity vs. Latitude (Southern Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     0.0688
# r-squared:   0.0047

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and humidity in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Cloudiness vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.5: Cloudiness vs. Latitude (Northern Hemisphere)',
         1, 16.0, 62.0)
# Out:
# r-value:     0.0860
# r-squared:   0.0074

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.6: Cloudiness vs. Latitude (Southern Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     0.0530
# r-squared:   0.0028

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and cloudiness in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.7: Wind Speed vs. Latitude (Northern Hemisphere)',
         1, 15.0, 22.0)
# Out:
# r-value:     0.0119
# r-squared:   0.0001

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.8: Wind Speed vs. Latitude (Southern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.1469
# r-squared:   0.0216

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and wind speed in either hemisphere.

# %%
#log_subroutine \
#    .EndProgramExecution()
