# %% [markdown]
# # WeatherPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, WeatherPy.ipynb, uses a Python script to 
 #      visualize the weather of over 500 cities of varying distances from the equator. 
 #      The script uses the citipy Python library and the openWeatherMap API to create 
 #      a representative model of weather across cities.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubRoutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'WeatherPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('WeatherPy')

# %% [markdown]
# # <br> **Section 1: Weather Data Acquisition**

# %% [markdown]
# ## **1.1: List of Cities**

# %%
citiesListOfStrings \
    = api_function \
        .ReturnCitiesList()

# %% [markdown]
# ## **1.2: Weather Data from List of Cities**

# %%
cityWeatherDataFrame \
    = api_function \
        .ReturnWeatherDataFrame \
            (citiesListOfStrings)

log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)
# Out:
# DATA RETRIEVAL FOR CITY WEATHER DATAFRAME BEGINS...
#
#
# PROCESSING RECORD #2 OF SET 1 FOR CITY, grytviken.
#
# PROCESSING RECORD #3 OF SET 1 FOR CITY, wanning.
#
# PROCESSING RECORD #4 OF SET 1 FOR CITY, bethel.
#
# PROCESSING RECORD #5 OF SET 1 FOR CITY, kodiak.
#
# PROCESSING RECORD #6 OF SET 1 FOR CITY, kingston.
#
# PROCESSING RECORD #7 OF SET 1 FOR CITY, fasa.
#
# PROCESSING RECORD #8 OF SET 1 FOR CITY, sehwan.
#
# PROCESSING RECORD #9 OF SET 1 FOR CITY, carnarvon.
#
# PROCESSING RECORD #10 OF SET 1 FOR CITY, albany.
#
# PROCESSING RECORD #11 OF SET 1 FOR CITY, adamstown.
#
# PROCESSING RECORD #12 OF SET 1 FOR CITY, sitka.
#
# PROCESSING RECORD #13 OF SET 1 FOR CITY, waitangi.
#
# PROCESSING RECORD #14 OF SET 1 FOR CITY, olonkinbyen.
#
# PROCESSING RECORD #15 OF SET 1 FOR CITY, nova sintra.
#
# PROCESSING RECORD #16 OF SET 1 FOR CITY, ranau.
#
# PROCESSING RECORD #17 OF SET 1 FOR CITY, sudbury.
#
# PROCESSING RECORD #18 OF SET 1 FOR CITY, margaret river.
#
# ...

# %% [markdown]
# ## **1.3: City Weather Data Set Records Count**

# %%
cityWeatherCountIntegerVariable \
    = cityWeatherDataFrame \
        ['City'] \
            .count()

print \
    (f"There are {cityWeatherCountIntegerVariable} " \
     + f"records in the city weather DataFrame.")
# Out:
# There are 561 records in the city weather DataFrame.

# %% [markdown]
# ## **1.4: Display City Weather Data Set**

# %%
captionString \
    = 'Table: 1.4: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_ffcc1 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# ...

# %% [markdown]
# ## **1.5: Display City Weather Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.5: City Weather Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Country)

# %% [markdown]
# ## **1.6: Export to CSV File**

# %%
subroutine \
    .WriteDataFrameToCSVFile \
        (cityWeatherDataFrame,
         local_constant \
             .WEATHER_DATA_FILE_PATH,
         local_constant \
             .WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ## **1.7: Data Import from CSV File**

# %%
sampleCityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant \
                 .WEATHER_DATA_FILE_PATH,
             local_constant \
                 .WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ## **1.8: Display Imported City Weather Data Set**

# %%
captionString \
    = 'Table: 1.8: Imported City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (sampleCityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_3fb94 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# ...

# %% [markdown]
# ## **1.9: Display Imported City Weather Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.9: Imported City Weather Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Country)

# %% [markdown]
# # **Section 2: Scatter Plots**

# %% [markdown]
# ## **2.1: Temperature vs. Latitude**

# %% [markdown]
# ### **Scatter Plot**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 2.1.1: Temperature Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Scatter Plot w/Regression**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 2.1.2: Temperature Vs. Latitude (Scatter Plot w/Regression)', 
         2, -48.0, 28.0)
# Out:
# r-value:     0.8640
# r-squared:   0.7464

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### Although this assignment is about linear regression, I notice that the independent variable, latitude, has a relationship with the dependent variable, temperature, just not a linear one.  With linear regression, we obtain a -0.1346 correlation; with quadratic regression, the correlation increases to 0.7879.  In practiice, analysts consider a 0.60-0.79 correlation to be strong.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ## **2.2: Humidity vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Humidity'],
         'Figure 2.2: Humidity Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ## **2.3: Cloudiness vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 2.3: Cloudiness Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ## **2.4: Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 2.4: Wind Speed vs. Latitude (Scatter Plot)')

# %% [markdown]
# ## **2.5: City Weather Data Set Correlation Matrix**

# %%
frameDictionary \
    = {'Latitude': cityWeatherDataFrame['Latitude'], 
       'Temperature': cityWeatherDataFrame['Temperature'], 
       'Humidity': cityWeatherDataFrame['Humidity'],
       'Cloudiness': cityWeatherDataFrame['Cloudiness'],
       'Wind Speed': cityWeatherDataFrame['Wind Speed']}

function \
    .ReturnCorrelationTableStandardFormat \
        (pd.DataFrame \
            (frameDictionary),
         'Table 2.5: City Weather Correlation Matrix')
# Out:
# <style type="text/css">
# #T_ace65 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_ace65_row0_col0, #T_ace65_row0_col1, #T_ace65_row0_col2, #T_ace65_row0_col3, #T_ace65_row0_col4, #T_ace65_row1_col0, #T_ace65_row1_col1, #T_ace65_row1_col2, #T_ace65_row1_col3, #T_ace65_row1_col4, #T_ace65_row2_col0, #T_ace65_row2_col1, #T_ace65_row2_col2, #T_ace65_row2_col3, #T_ace65_row2_col4, #T_ace65_row3_col0, #T_ace65_row3_col1, #T_ace65_row3_col2, #T_ace65_row3_col3, #T_ace65_row3_col4, #T_ace65_row4_col0, #T_ace65_row4_col1, #T_ace65_row4_col2, #T_ace65_row4_col3, #T_ace65_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_ace65">
#   <caption>Table 2.5: City Weather Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ace65_level0_col0" class="col_heading level0 col0" >Latitude</th>
# ...

# %% [markdown]
# # **Section 3: City Weather Data By Hemisphere**

# %% [markdown]
# ## **3.1: City Weather Data Set (Northern Hemisphere)**

# %%
northernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (northernCityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Data Set (Northern Hemisphere)**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 3.1: City Weather Data Set (Northern Hemisphere)')
# Out:
# <style type="text/css">
# #T_d8094 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# ...

# %% [markdown]
# ### **Display City Weather Locations (Northern Hemisphere)**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (northernCityWeatherDataFrame,
         'Figure 3.1: City Weather Locations (Northern Hemisphere)',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Country)

# %% [markdown]
# ## **3.2: City Weather Data Set (Southern Hemisphere)**

# %%
southernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (southernCityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Data Set (Southern Hemisphere)**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (southernCityWeatherDataFrame.head(12),
         'Table: 3.2: City Weather Information (Southern Hemisphere)')
# Out:
# <style type="text/css">
# #T_fd97a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# ...

# %% [markdown]
# ### **Display City Weather Locations (Southern Hemisphere)**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (southernCityWeatherDataFrame,
         'Figure 3.2: City Weather Locations (Southern Hemisphere)',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Country)

# %% [markdown]
# ## **3.3: City Weather Data Set (Eastern Hemisphere)**

# %%
easternCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Longitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (easternCityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Data Set (Eastern Hemisphere)**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (easternCityWeatherDataFrame.head(12),
         'Table: 3.3: City Weather Information (Eastern Hemisphere)')
# Out:
# <style type="text/css">
# #T_52594 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# ...

# %% [markdown]
# ### **Display City Weather Locations (Eastern Hemisphere)**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (easternCityWeatherDataFrame,
         'Figure 3.3: City Weather Locations (Eastern Hemisphere)',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Country)

# %% [markdown]
# ## **3.4: City Weather Data Set (Western Hemisphere)**

# %%
westernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Longitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (westernCityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Data Set (Western Hemisphere)**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (westernCityWeatherDataFrame.head(12),
         'Table: 3.4: City Weather Information (Western Hemisphere)')
# Out:
# <style type="text/css">
# #T_8c62b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# ...

# %% [markdown]
# ### **Display City Weather Locations (Western Hemisphere)**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (westernCityWeatherDataFrame,
         'Figure 3.4: City Weather Locations (Western Hemisphere)',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Country)

# %% [markdown]
# # **Section 4: Scatter Plots w/Linear Regression (Hemispheres)**

# %% [markdown]
# ## **4.1: Temperature vs. Latitude**

# %% [markdown]
# ### Display Temperature vs. Latitude (Northern Hemisphere)

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 4.1.1: Temperature vs. Latitude (Northern Hemisphere)',
         1, 2.0, 45.0)
# Out:
# r-value:     -0.8609
# r-squared:   0.7411

# %% [markdown]
#  ### Display Temperature vs. Latitude (Southern Hemisphere)

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 4.1.2: Temperature vs. Latitude (Southern Hemisphere)',
         1, -55.0, 85.0)
# Out:
# r-value:     0.6779
# r-squared:   0.4595

# %% [markdown]
#  ### Display Temperature vs. Latitude (Eastern Hemisphere)

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (easternCityWeatherDataFrame \
             ['Latitude'],
         easternCityWeatherDataFrame \
             ['Temperature'],
         'Figure 4.1.3: Temperature vs. Latitude (Eastern Hemisphere)',
         2, -55.0, 85.0)
# Out:
# r-value:     0.8627
# r-squared:   0.7442

# %% [markdown]
#  ### Display Temperature vs. Latitude (Western Hemisphere)

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (westernCityWeatherDataFrame \
             ['Latitude'],
         westernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 4.1.4: Temperature vs. Latitude (Western Hemisphere)',
         2, -55.0, 85.0)
# Out:
# r-value:     0.8803
# r-squared:   0.7749

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### From the results of the linear regression, in the northern hemisphere, the latitude is negatively correlated with temperature; this negative correlation tells us that the two variables move in opposite directions: as latitude increases, the temperature drops, and vice versa.  In the southern hemisphers, the latitude is positively correlated with temperature: this positive correlation tells us that the two variables move in the same direction: as latitude increases, the temperature increases.  From the results of the quadratic regression, in both the eastern and western hemispheres, the latitude is positively correlated with temperature. What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole. On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ## **4.2: Humidity vs. Latitude**

# %% [markdown]
# ### **Display Humidity vs. Latitude (Northern Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 4.2.1: Humidity vs. Latitude (Northern Hemisphere)',
         1, 45.0, 18.0)
# Out:
# r-value:     0.2663
# r-squared:   0.0709

# %% [markdown]
# ### **Display Humidity vs. Latitude (Southern Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 4.2.2: Humidity vs. Latitude (Southern Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     0.1652
# r-squared:   0.0273

# %% [markdown]
# ### **Display Humidity vs. Latitude (Eastern Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (easternCityWeatherDataFrame \
             ['Latitude'],
         easternCityWeatherDataFrame \
             ['Humidity'],
         'Figure 4.2.3: Humidity vs. Latitude (Eastern Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     0.3184
# r-squared:   0.1014

# %% [markdown]
# ### **Display Humidity vs. Latitude (Western Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (westernCityWeatherDataFrame \
             ['Latitude'],
         westernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 4.2.4: Humidity vs. Latitude (Western Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     0.1417
# r-squared:   0.0201

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and humidity in any hemisphere.

# %% [markdown]
# ## **4.3: Cloudiness vs. Latitude**

# %% [markdown]
# ### **Display Cloudiness vs. Latitude (Northern Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 4.3.1: Cloudiness vs. Latitude (Northern Hemisphere)',
         1, 16.0, 62.0)
# Out:
# r-value:     0.1942
# r-squared:   0.0377

# %% [markdown]
# ### **Display Cloudiness vs. Latitude (Southern Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 4.3.2: Cloudiness vs. Latitude (Southern Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     0.1969
# r-squared:   0.0388

# %% [markdown]
# ### **Display Cloudiness vs. Latitude (Eastern Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (easternCityWeatherDataFrame \
             ['Latitude'],
         easternCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 4.3.3: Cloudiness vs. Latitude (Eastern Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     0.1109
# r-squared:   0.0123

# %% [markdown]
# ### **Display Cloudiness vs. Latitude (Western Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (westernCityWeatherDataFrame \
             ['Latitude'],
         westernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 4.3.4: Cloudiness vs. Latitude (Western Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     0.1924
# r-squared:   0.0370

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and cloudiness in any hemisphere.

# %% [markdown]
# ## **4.4: Wind Speed vs. Latitude**

# %% [markdown]
# ### **Display Wind Speed vs. Latitude (Northern Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 4.4.1: Wind Speed vs. Latitude (Northern Hemisphere)',
         1, 15.0, 22.0)
# Out:
# r-value:     0.0775
# r-squared:   0.0060

# %% [markdown]
# ### **Display Wind Speed vs. Latitude (Southern Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 4.4.2: Wind Speed vs. Latitude (Southern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.1629
# r-squared:   0.0265

# %% [markdown]
# ### **Display Wind Speed vs. Latitude (Eastern Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (easternCityWeatherDataFrame \
             ['Latitude'],
         easternCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 4.4.3: Wind Speed vs. Latitude (Eastern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.0633
# r-squared:   0.0040

# %% [markdown]
# ### **Display Wind Speed vs. Latitude (Western Hemisphere)**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (westernCityWeatherDataFrame \
             ['Latitude'],
         westernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 4.4.4: Wind Speed vs. Latitude (Eastern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.1178
# r-squared:   0.0139

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and wind speed in any hemisphere.

# %%
#log_subroutine \
#    .EndProgramExecution()
