# %% [markdown]
# # WeatherPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, WeatherPy.ipynb, uses a Python script to 
 #      visualize the weather of over 500 cities of varying distances from the equator. 
 #      The script uses the citipy Python library and the openWeatherMap API to create 
 #      a representative model of weather across cities.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubRoutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'WeatherPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('WeatherPy')

# %% [markdown]
# # <br> **Section 1: Weather Variables and Latitude**

# %% [markdown]
# ## **Section 1.1: Data Acquisition**

# %% [markdown]
# ### **List of Cities**

# %%
citiesListOfStrings \
    = api_function \
        .ReturnCitiesList()

# %% [markdown]
# ### **Weather Data from List of Cities**

# %%
cityWeatherDataFrame \
    = api_function \
        .ReturnWeatherDataFrame \
            (citiesListOfStrings)
# Out:
# DATA RETRIEVAL FOR CITY WEATHER DATAFRAME BEGINS...
#
#
# PROCESSING RECORD #2 OF SET 1 FOR CITY, grytviken.
#
# PROCESSING RECORD #3 OF SET 1 FOR CITY, al 'alamayn.
#
# The script did not find the city, al 'alamayn. Skipping...
#
# PROCESSING RECORD #4 OF SET 1 FOR CITY, mansa.
#
# PROCESSING RECORD #5 OF SET 1 FOR CITY, toliara.
#
# PROCESSING RECORD #6 OF SET 1 FOR CITY, port lincoln.
#
# PROCESSING RECORD #7 OF SET 1 FOR CITY, taiohae.
#
# The script did not find the city, taiohae. Skipping...
#
# PROCESSING RECORD #8 OF SET 1 FOR CITY, baikunthpur.
#
# PROCESSING RECORD #9 OF SET 1 FOR CITY, bethel.
#
# PROCESSING RECORD #10 OF SET 1 FOR CITY, puerto natales.
#
# PROCESSING RECORD #11 OF SET 1 FOR CITY, whitehorse.
#
# PROCESSING RECORD #12 OF SET 1 FOR CITY, saipan.
#
# PROCESSING RECORD #13 OF SET 1 FOR CITY, yanchep.
#
# PROCESSING RECORD #14 OF SET 1 FOR CITY, adamstown.
#
# PROCESSING RECORD #15 OF SET 1 FOR CITY, east london.
#
# PROCESSING RECORD #16 OF SET 1 FOR CITY, sarangani.
#
# PROCESSING RECORD #17 OF SET 1 FOR CITY, remire-montjoly.
#
# PROCESSING RECORD #18 OF SET 1 FOR CITY, port mathurin.
#
# PROCESSING RECORD #19 OF SET 1 FOR CITY, taroa.
#
# PROCESSING RECORD #20 OF SET 1 FOR CITY, vredendal.
#
# PROCESSING RECORD #21 OF SET 1 FOR CITY, yellowknife.
#
# PROCESSING RECORD #22 OF SET 1 FOR CITY, evanston.
#
# PROCESSING RECORD #23 OF SET 1 FOR CITY, dryden.
#
# PROCESSING RECORD #24 OF SET 1 FOR CITY, ilulissat.
#
# PROCESSING RECORD #25 OF SET 1 FOR CITY, puerto ayora.
#
# PROCESSING RECORD #26 OF SET 1 FOR CITY, moama.
#
# PROCESSING RECORD #27 OF SET 1 FOR CITY, albany.
#
# PROCESSING RECORD #28 OF SET 1 FOR CITY, punta arenas.
#
# PROCESSING RECORD #29 OF SET 1 FOR CITY, blackmans bay.
#
# PROCESSING RECORD #30 OF SET 1 FOR CITY, badger.
#
# PROCESSING RECORD #31 OF SET 1 FOR CITY, ust-nera.
#
# PROCESSING RECORD #32 OF SET 1 FOR CITY, jamestown.
#
# PROCESSING RECORD #33 OF SET 1 FOR CITY, anacapri.
#
# PROCESSING RECORD #34 OF SET 1 FOR CITY, freetown.
#
# PROCESSING RECORD #35 OF SET 1 FOR CITY, armacao de buzios.
#
# PROCESSING RECORD #36 OF SET 1 FOR CITY, pinotepa nacional.
#
# PROCESSING RECORD #37 OF SET 1 FOR CITY, college.
#
# PROCESSING RECORD #38 OF SET 1 FOR CITY, nar'yan-mar.
#
# PROCESSING RECORD #39 OF SET 1 FOR CITY, invercargill.
#
# PROCESSING RECORD #40 OF SET 1 FOR CITY, cannonvale.
#
# PROCESSING RECORD #41 OF SET 1 FOR CITY, waitangi.
#
# PROCESSING RECORD #42 OF SET 1 FOR CITY, west island.
#
# PROCESSING RECORD #43 OF SET 1 FOR CITY, nadym.
#
# PROCESSING RECORD #44 OF SET 1 FOR CITY, stanley.
#
# PROCESSING RECORD #45 OF SET 1 FOR CITY, ushuaia.
#
# PROCESSING RECORD #46 OF SET 1 FOR CITY, bilibino.
#
# PROCESSING RECORD #47 OF SET 1 FOR CITY, lompoc.
#
# PROCESSING RECORD #48 OF SET 1 FOR CITY, arkhangel'sk.
#
# PROCESSING RECORD #49 OF SET 1 FOR CITY, aridaia.
#
# PROCESSING RECORD #50 OF SET 1 FOR CITY, isafjordur.
#
# PROCESSING RECORD #51 OF SET 1 FOR CITY, tournai.
#
# PROCESSING RECORD #1 OF SET 2 FOR CITY, gokwe.
#
# PROCESSING RECORD #2 OF SET 2 FOR CITY, port-aux-francais.
#
# PROCESSING RECORD #3 OF SET 2 FOR CITY, minas de marcona.
#
# PROCESSING RECORD #4 OF SET 2 FOR CITY, papatowai.
#
# PROCESSING RECORD #5 OF SET 2 FOR CITY, edinburgh of the seven seas.
#
# PROCESSING RECORD #6 OF SET 2 FOR CITY, tiksi.
#
# PROCESSING RECORD #7 OF SET 2 FOR CITY, tefe.
#
# PROCESSING RECORD #8 OF SET 2 FOR CITY, bredasdorp.
#
# PROCESSING RECORD #9 OF SET 2 FOR CITY, kafr ad dawwar.
#
# PROCESSING RECORD #10 OF SET 2 FOR CITY, tolanaro.
#
# PROCESSING RECORD #11 OF SET 2 FOR CITY, vorgashor.
#
# PROCESSING RECORD #12 OF SET 2 FOR CITY, borba.
#
# PROCESSING RECORD #13 OF SET 2 FOR CITY, la'ie.
#
# PROCESSING RECORD #14 OF SET 2 FOR CITY, gagliano del capo.
#
# PROCESSING RECORD #15 OF SET 2 FOR CITY, leava.
#
# PROCESSING RECORD #16 OF SET 2 FOR CITY, khandyga.
#
# PROCESSING RECORD #17 OF SET 2 FOR CITY, mosjoen.
#
# PROCESSING RECORD #18 OF SET 2 FOR CITY, iqaluit.
#
# PROCESSING RECORD #19 OF SET 2 FOR CITY, avarua.
#
# PROCESSING RECORD #20 OF SET 2 FOR CITY, quillacollo.
#
# PROCESSING RECORD #21 OF SET 2 FOR CITY, kerikeri.
#
# PROCESSING RECORD #22 OF SET 2 FOR CITY, diego de almagro.
#
# PROCESSING RECORD #23 OF SET 2 FOR CITY, lorengau.
#
# PROCESSING RECORD #24 OF SET 2 FOR CITY, bella union.
#
# PROCESSING RECORD #25 OF SET 2 FOR CITY, ar ruways.
#
# PROCESSING RECORD #26 OF SET 2 FOR CITY, whitecourt.
#
# PROCESSING RECORD #27 OF SET 2 FOR CITY, san patricio.
#
# PROCESSING RECORD #28 OF SET 2 FOR CITY, cockburn town.
#
# PROCESSING RECORD #29 OF SET 2 FOR CITY, vingt cinq.
#
# The script did not find the city, vingt cinq. Skipping...
#
# PROCESSING RECORD #30 OF SET 2 FOR CITY, siteki.
#
# PROCESSING RECORD #31 OF SET 2 FOR CITY, okhotsk.
#
# PROCESSING RECORD #32 OF SET 2 FOR CITY, bako.
#
# PROCESSING RECORD #33 OF SET 2 FOR CITY, qaqortoq.
#
# PROCESSING RECORD #34 OF SET 2 FOR CITY, alofi.
#
# PROCESSING RECORD #35 OF SET 2 FOR CITY, shenjiamen.
#
# PROCESSING RECORD #36 OF SET 2 FOR CITY, laguna.
#
# PROCESSING RECORD #37 OF SET 2 FOR CITY, warrnambool.
#
# PROCESSING RECORD #38 OF SET 2 FOR CITY, quellon.
#
# PROCESSING RECORD #39 OF SET 2 FOR CITY, hawaiian paradise park.
#
# PROCESSING RECORD #40 OF SET 2 FOR CITY, hoemul-li.
#
# PROCESSING RECORD #41 OF SET 2 FOR CITY, papao.
#
# PROCESSING RECORD #42 OF SET 2 FOR CITY, verkhnyaya khava.
#
# PROCESSING RECORD #43 OF SET 2 FOR CITY, talara.
#
# PROCESSING RECORD #44 OF SET 2 FOR CITY, natal.
#
# PROCESSING RECORD #45 OF SET 2 FOR CITY, kodiak.
#
# PROCESSING RECORD #46 OF SET 2 FOR CITY, tarinkot.
#
# PROCESSING RECORD #47 OF SET 2 FOR CITY, ribeira grande.
#
# PROCESSING RECORD #48 OF SET 2 FOR CITY, mount gambier.
#
# PROCESSING RECORD #49 OF SET 2 FOR CITY, port blair.
#
# PROCESSING RECORD #50 OF SET 2 FOR CITY, nanakuli.
#
# PROCESSING RECORD #1 OF SET 3 FOR CITY, utrik.
#
# PROCESSING RECORD #2 OF SET 3 FOR CITY, boyolangu.
#
# PROCESSING RECORD #3 OF SET 3 FOR CITY, pandan.
#
# PROCESSING RECORD #4 OF SET 3 FOR CITY, toktogul.
#
# PROCESSING RECORD #5 OF SET 3 FOR CITY, george town.
#
# PROCESSING RECORD #6 OF SET 3 FOR CITY, nova sintra.
#
# PROCESSING RECORD #7 OF SET 3 FOR CITY, karagandy.
#
# PROCESSING RECORD #8 OF SET 3 FOR CITY, leh.
#
# PROCESSING RECORD #9 OF SET 3 FOR CITY, morrope.
#
# PROCESSING RECORD #10 OF SET 3 FOR CITY, hamilton.
#
# PROCESSING RECORD #11 OF SET 3 FOR CITY, anadyr.
#
# PROCESSING RECORD #12 OF SET 3 FOR CITY, hilo.
#
# PROCESSING RECORD #13 OF SET 3 FOR CITY, atar.
#
# PROCESSING RECORD #14 OF SET 3 FOR CITY, johi.
#
# PROCESSING RECORD #15 OF SET 3 FOR CITY, palikir - national government center.
#
# PROCESSING RECORD #16 OF SET 3 FOR CITY, klichaw.
#
# PROCESSING RECORD #17 OF SET 3 FOR CITY, iskateley.
#
# PROCESSING RECORD #18 OF SET 3 FOR CITY, xilin hot.
#
# PROCESSING RECORD #19 OF SET 3 FOR CITY, pimentel.
#
# PROCESSING RECORD #20 OF SET 3 FOR CITY, 'ohonua.
#
# The script did not find the city, 'ohonua. Skipping...
#
# PROCESSING RECORD #21 OF SET 3 FOR CITY, esquina.
#
# PROCESSING RECORD #22 OF SET 3 FOR CITY, santa marta de ortigueira.
#
# PROCESSING RECORD #23 OF SET 3 FOR CITY, thompson.
#
# PROCESSING RECORD #24 OF SET 3 FOR CITY, tacoronte.
#
# PROCESSING RECORD #25 OF SET 3 FOR CITY, cam ranh.
#
# PROCESSING RECORD #26 OF SET 3 FOR CITY, smithers.
#
# PROCESSING RECORD #27 OF SET 3 FOR CITY, port elizabeth.
#
# PROCESSING RECORD #28 OF SET 3 FOR CITY, suva.
#
# PROCESSING RECORD #29 OF SET 3 FOR CITY, luderitz.
#
# PROCESSING RECORD #30 OF SET 3 FOR CITY, kodok.
#
# The script did not find the city, kodok. Skipping...
#
# PROCESSING RECORD #31 OF SET 3 FOR CITY, saint-philippe.
#
# PROCESSING RECORD #32 OF SET 3 FOR CITY, afaahiti.
#
# PROCESSING RECORD #33 OF SET 3 FOR CITY, lerwick.
#
# PROCESSING RECORD #34 OF SET 3 FOR CITY, arraial do cabo.
#
# PROCESSING RECORD #35 OF SET 3 FOR CITY, maragogi.
#
# PROCESSING RECORD #36 OF SET 3 FOR CITY, taltal.
#
# PROCESSING RECORD #37 OF SET 3 FOR CITY, dudinka.
#
# PROCESSING RECORD #38 OF SET 3 FOR CITY, kenai.
#
# PROCESSING RECORD #39 OF SET 3 FOR CITY, ola.
#
# PROCESSING RECORD #40 OF SET 3 FOR CITY, tobelo.
#
# PROCESSING RECORD #41 OF SET 3 FOR CITY, ginir.
#
# PROCESSING RECORD #42 OF SET 3 FOR CITY, antofagasta.
#
# PROCESSING RECORD #43 OF SET 3 FOR CITY, la passe.
#
# PROCESSING RECORD #44 OF SET 3 FOR CITY, zaozersk.
#
# PROCESSING RECORD #45 OF SET 3 FOR CITY, vrangel'.
#
# PROCESSING RECORD #46 OF SET 3 FOR CITY, aykhal.
#
# PROCESSING RECORD #47 OF SET 3 FOR CITY, yanam.
#
# PROCESSING RECORD #48 OF SET 3 FOR CITY, san luis de la loma.
#
# PROCESSING RECORD #49 OF SET 3 FOR CITY, dabakala.
# PROCESSING RECORD #50 OF SET 3 FOR CITY, tofol.
#
# PROCESSING RECORD #1 OF SET 4 FOR CITY, outapi.
#
# The script did not find the city, outapi. Skipping...
#
# PROCESSING RECORD #2 OF SET 4 FOR CITY, kharabali.
#
# PROCESSING RECORD #3 OF SET 4 FOR CITY, kaa-khem.
#
# PROCESSING RECORD #4 OF SET 4 FOR CITY, amursk.
#
# PROCESSING RECORD #5 OF SET 4 FOR CITY, fale old settlement.
#
# PROCESSING RECORD #6 OF SET 4 FOR CITY, tamanrasset.
#
# PROCESSING RECORD #7 OF SET 4 FOR CITY, al ghayzah.
#
# PROCESSING RECORD #8 OF SET 4 FOR CITY, tiznit.
#
# PROCESSING RECORD #9 OF SET 4 FOR CITY, pionerskiy.
#
# PROCESSING RECORD #10 OF SET 4 FOR CITY, bouarfa.
#
# PROCESSING RECORD #11 OF SET 4 FOR CITY, cuito.
#
# PROCESSING RECORD #12 OF SET 4 FOR CITY, petropavlovsk-kamchatsky.
#
# PROCESSING RECORD #13 OF SET 4 FOR CITY, concepcion.
#
# PROCESSING RECORD #14 OF SET 4 FOR CITY, krasnokamensk.
#
# PROCESSING RECORD #15 OF SET 4 FOR CITY, bikenibeu village.
#
# PROCESSING RECORD #16 OF SET 4 FOR CITY, am djarass.
#
# The script did not find the city, am djarass. Skipping...
#
# PROCESSING RECORD #17 OF SET 4 FOR CITY, siaton.
#
# PROCESSING RECORD #18 OF SET 4 FOR CITY, tan-tan.
#
# PROCESSING RECORD #19 OF SET 4 FOR CITY, dunedin.
#
# PROCESSING RECORD #20 OF SET 4 FOR CITY, lom sak.
#
# PROCESSING RECORD #21 OF SET 4 FOR CITY, sao felix do xingu.
#
# PROCESSING RECORD #22 OF SET 4 FOR CITY, ra's bayrut.
#
# PROCESSING RECORD #23 OF SET 4 FOR CITY, tralee.
#
# PROCESSING RECORD #24 OF SET 4 FOR CITY, christchurch.
#
# PROCESSING RECORD #25 OF SET 4 FOR CITY, melfort.
#
# PROCESSING RECORD #26 OF SET 4 FOR CITY, patterson.
#
# PROCESSING RECORD #27 OF SET 4 FOR CITY, kristiansund.
#
# PROCESSING RECORD #28 OF SET 4 FOR CITY, severo-yeniseyskiy.
#
# PROCESSING RECORD #29 OF SET 4 FOR CITY, suyo.
#
# PROCESSING RECORD #30 OF SET 4 FOR CITY, jabor.
#
# PROCESSING RECORD #31 OF SET 4 FOR CITY, weno.
#
# PROCESSING RECORD #32 OF SET 4 FOR CITY, marsh harbour.
#
# PROCESSING RECORD #33 OF SET 4 FOR CITY, belyye vody.
#
# PROCESSING RECORD #34 OF SET 4 FOR CITY, castello d'empuries.
#
# PROCESSING RECORD #35 OF SET 4 FOR CITY, puerto san carlos.
#
# The script did not find the city, puerto san carlos. Skipping...
#
# PROCESSING RECORD #36 OF SET 4 FOR CITY, olinda.
#
# PROCESSING RECORD #37 OF SET 4 FOR CITY, mezgor'e.
#
# The script did not find the city, mezgor'e. Skipping...
#
# PROCESSING RECORD #38 OF SET 4 FOR CITY, dongtai.
#
# PROCESSING RECORD #39 OF SET 4 FOR CITY, dabou.
#
# PROCESSING RECORD #40 OF SET 4 FOR CITY, hadibu.
#
# PROCESSING RECORD #41 OF SET 4 FOR CITY, san fernando de apure.
#
# PROCESSING RECORD #42 OF SET 4 FOR CITY, keelung.
#
# PROCESSING RECORD #43 OF SET 4 FOR CITY, margaret river.
#
# PROCESSING RECORD #44 OF SET 4 FOR CITY, tinogasta.
#
# PROCESSING RECORD #45 OF SET 4 FOR CITY, kota kinabalu.
#
# PROCESSING RECORD #46 OF SET 4 FOR CITY, saldanha.
#
# PROCESSING RECORD #47 OF SET 4 FOR CITY, sungjibaegam.
#
# PROCESSING RECORD #48 OF SET 4 FOR CITY, olonkinbyen.
#
# PROCESSING RECORD #49 OF SET 4 FOR CITY, tubarjal.
#
# PROCESSING RECORD #50 OF SET 4 FOR CITY, coahuayana de hidalgo.
#
# PROCESSING RECORD #1 OF SET 5 FOR CITY, shahr-e babak.
#
# PROCESSING RECORD #2 OF SET 5 FOR CITY, lihue.
#
# PROCESSING RECORD #3 OF SET 5 FOR CITY, cill airne.
#
# PROCESSING RECORD #4 OF SET 5 FOR CITY, banda aceh.
#
# PROCESSING RECORD #5 OF SET 5 FOR CITY, male.
#
# PROCESSING RECORD #6 OF SET 5 FOR CITY, sisimiut.
#
# PROCESSING RECORD #7 OF SET 5 FOR CITY, uttar char fasson.
#
# PROCESSING RECORD #8 OF SET 5 FOR CITY, katsuura.
#
# PROCESSING RECORD #9 OF SET 5 FOR CITY, mossel bay.
#
# PROCESSING RECORD #10 OF SET 5 FOR CITY, capbreton.
#
# PROCESSING RECORD #11 OF SET 5 FOR CITY, taunggyi.
#
# PROCESSING RECORD #12 OF SET 5 FOR CITY, malpica.
#
# PROCESSING RECORD #13 OF SET 5 FOR CITY, wailua homesteads.
#
# PROCESSING RECORD #14 OF SET 5 FOR CITY, jaru.
#
# PROCESSING RECORD #15 OF SET 5 FOR CITY, seven pagodas.
#
# PROCESSING RECORD #16 OF SET 5 FOR CITY, cao lanh.
#
# PROCESSING RECORD #17 OF SET 5 FOR CITY, nema.
#
# PROCESSING RECORD #18 OF SET 5 FOR CITY, keflavik.
#
# PROCESSING RECORD #19 OF SET 5 FOR CITY, vilyuysk.
#
# PROCESSING RECORD #20 OF SET 5 FOR CITY, rikaze.
#
# PROCESSING RECORD #21 OF SET 5 FOR CITY, broome.
#
# PROCESSING RECORD #22 OF SET 5 FOR CITY, khanty-mansiysk.
#
# PROCESSING RECORD #23 OF SET 5 FOR CITY, whistler.
#
# PROCESSING RECORD #24 OF SET 5 FOR CITY, malakal.
#
# PROCESSING RECORD #25 OF SET 5 FOR CITY, la ronge.
#
# PROCESSING RECORD #26 OF SET 5 FOR CITY, galliano.
#
# PROCESSING RECORD #27 OF SET 5 FOR CITY, banfora.
#
# PROCESSING RECORD #28 OF SET 5 FOR CITY, vilyuchinsk.
#
# PROCESSING RECORD #29 OF SET 5 FOR CITY, klyuchi.
#
# PROCESSING RECORD #30 OF SET 5 FOR CITY, excelsior springs.
#
# PROCESSING RECORD #31 OF SET 5 FOR CITY, kisesa.
#
# PROCESSING RECORD #32 OF SET 5 FOR CITY, katsuren-haebaru.
#
# PROCESSING RECORD #33 OF SET 5 FOR CITY, gorgan.
#
# PROCESSING RECORD #34 OF SET 5 FOR CITY, longyearbyen.
#
# PROCESSING RECORD #35 OF SET 5 FOR CITY, alice springs.
#
# PROCESSING RECORD #36 OF SET 5 FOR CITY, beledweyne.
#
# PROCESSING RECORD #37 OF SET 5 FOR CITY, isangel.
#
# PROCESSING RECORD #38 OF SET 5 FOR CITY, celestun.
#
# PROCESSING RECORD #39 OF SET 5 FOR CITY, bardai.
#
# PROCESSING RECORD #40 OF SET 5 FOR CITY, hasaki.
#
# PROCESSING RECORD #41 OF SET 5 FOR CITY, faya-largeau.
#
# PROCESSING RECORD #42 OF SET 5 FOR CITY, kapa'a.
#
# PROCESSING RECORD #43 OF SET 5 FOR CITY, manadhoo.
#
# PROCESSING RECORD #44 OF SET 5 FOR CITY, saacow.
#
# PROCESSING RECORD #45 OF SET 5 FOR CITY, mirny.
#
# PROCESSING RECORD #46 OF SET 5 FOR CITY, tasova.
#
# PROCESSING RECORD #47 OF SET 5 FOR CITY, stornoway.
#
# PROCESSING RECORD #48 OF SET 5 FOR CITY, lebu.
#
# PROCESSING RECORD #49 OF SET 5 FOR CITY, alesund.
#
# PROCESSING RECORD #50 OF SET 5 FOR CITY, kavieng.
#
# PROCESSING RECORD #1 OF SET 6 FOR CITY, malya.
#
# PROCESSING RECORD #2 OF SET 6 FOR CITY, guarapari.
#
# PROCESSING RECORD #3 OF SET 6 FOR CITY, champerico.
#
# PROCESSING RECORD #4 OF SET 6 FOR CITY, broken hill.
#
# PROCESSING RECORD #5 OF SET 6 FOR CITY, duyun.
#
# PROCESSING RECORD #6 OF SET 6 FOR CITY, vinhais.
#
# PROCESSING RECORD #7 OF SET 6 FOR CITY, phayakkhaphum phisai.
#
# PROCESSING RECORD #8 OF SET 6 FOR CITY, oum hadjer.
#
# PROCESSING RECORD #9 OF SET 6 FOR CITY, vallenar.
#
# PROCESSING RECORD #10 OF SET 6 FOR CITY, collie.
#
# PROCESSING RECORD #11 OF SET 6 FOR CITY, ancud.
#
# PROCESSING RECORD #12 OF SET 6 FOR CITY, westport.
#
# PROCESSING RECORD #13 OF SET 6 FOR CITY, flying fish cove.
#
# PROCESSING RECORD #14 OF SET 6 FOR CITY, beni.
#
# PROCESSING RECORD #15 OF SET 6 FOR CITY, hithadhoo.
#
# PROCESSING RECORD #16 OF SET 6 FOR CITY, nuriootpa.
#
# PROCESSING RECORD #17 OF SET 6 FOR CITY, gilgit.
#
# PROCESSING RECORD #18 OF SET 6 FOR CITY, tidjikja.
#
# PROCESSING RECORD #19 OF SET 6 FOR CITY, cargados carajos.
#
# The script did not find the city, cargados carajos. Skipping...
#
# PROCESSING RECORD #20 OF SET 6 FOR CITY, williams lake.
#
# PROCESSING RECORD #21 OF SET 6 FOR CITY, sungai penuh.
#
# PROCESSING RECORD #22 OF SET 6 FOR CITY, ahau.
#
# The script did not find the city, ahau. Skipping...
#
# PROCESSING RECORD #23 OF SET 6 FOR CITY, kyzyl.
#
# PROCESSING RECORD #24 OF SET 6 FOR CITY, batticaloa.
#
# PROCESSING RECORD #25 OF SET 6 FOR CITY, nizhneudinsk.
#
# PROCESSING RECORD #26 OF SET 6 FOR CITY, hugo.
#
# PROCESSING RECORD #27 OF SET 6 FOR CITY, ziro.
#
# PROCESSING RECORD #28 OF SET 6 FOR CITY, piti village.
#
# PROCESSING RECORD #29 OF SET 6 FOR CITY, shimanovsk.
#
# PROCESSING RECORD #30 OF SET 6 FOR CITY, puerto carreno.
#
# PROCESSING RECORD #31 OF SET 6 FOR CITY, lospalos.
#
# PROCESSING RECORD #32 OF SET 6 FOR CITY, sangamner.
#
# PROCESSING RECORD #33 OF SET 6 FOR CITY, susuman.
#
# PROCESSING RECORD #34 OF SET 6 FOR CITY, uturoa.
#
# PROCESSING RECORD #35 OF SET 6 FOR CITY, atasu.
#
# PROCESSING RECORD #36 OF SET 6 FOR CITY, naama.
#
# PROCESSING RECORD #37 OF SET 6 FOR CITY, petukhovo.
#
# PROCESSING RECORD #38 OF SET 6 FOR CITY, hobyo.
#
# PROCESSING RECORD #39 OF SET 6 FOR CITY, mermoz boabab.
#
# PROCESSING RECORD #40 OF SET 6 FOR CITY, kidal.
#
# PROCESSING RECORD #41 OF SET 6 FOR CITY, tranovaho.
#
# The script did not find the city, tranovaho. Skipping...
#
# PROCESSING RECORD #42 OF SET 6 FOR CITY, atafu village.
#
# PROCESSING RECORD #43 OF SET 6 FOR CITY, larache.
#
# PROCESSING RECORD #44 OF SET 6 FOR CITY, nova xavantina.
#
# PROCESSING RECORD #45 OF SET 6 FOR CITY, thunder bay.
#
# PROCESSING RECORD #46 OF SET 6 FOR CITY, pangody.
# PROCESSING RECORD #47 OF SET 6 FOR CITY, nagqu.
#
# PROCESSING RECORD #48 OF SET 6 FOR CITY, rabo de peixe.
#
# PROCESSING RECORD #49 OF SET 6 FOR CITY, chonchi.
#
# PROCESSING RECORD #50 OF SET 6 FOR CITY, sonoita.
#
# PROCESSING RECORD #1 OF SET 7 FOR CITY, coquimbo.
#
# PROCESSING RECORD #2 OF SET 7 FOR CITY, choyr.
#
# PROCESSING RECORD #3 OF SET 7 FOR CITY, lambton shores.
#
# The script did not find the city, lambton shores. Skipping...
#
# PROCESSING RECORD #4 OF SET 7 FOR CITY, san antonio de pale.
#
# PROCESSING RECORD #5 OF SET 7 FOR CITY, yeppoon.
#
# PROCESSING RECORD #6 OF SET 7 FOR CITY, qarazhal.
#
# PROCESSING RECORD #7 OF SET 7 FOR CITY, lucaya.
#
# PROCESSING RECORD #8 OF SET 7 FOR CITY, tobruk.
#
# PROCESSING RECORD #9 OF SET 7 FOR CITY, brokopondo.
#
# PROCESSING RECORD #10 OF SET 7 FOR CITY, santa ana.
#
# PROCESSING RECORD #11 OF SET 7 FOR CITY, arroyito.
#
# PROCESSING RECORD #12 OF SET 7 FOR CITY, ardestan.
#
# PROCESSING RECORD #13 OF SET 7 FOR CITY, bairnsdale.
#
# PROCESSING RECORD #14 OF SET 7 FOR CITY, buka.
#
# PROCESSING RECORD #15 OF SET 7 FOR CITY, nandyal.
#
# PROCESSING RECORD #16 OF SET 7 FOR CITY, nanning.
#
# PROCESSING RECORD #17 OF SET 7 FOR CITY, hoa binh.
#
# PROCESSING RECORD #18 OF SET 7 FOR CITY, garoowe.
#
# PROCESSING RECORD #19 OF SET 7 FOR CITY, qamdo.
#
# PROCESSING RECORD #20 OF SET 7 FOR CITY, itoman.
#
# PROCESSING RECORD #21 OF SET 7 FOR CITY, howrah.
#
# PROCESSING RECORD #22 OF SET 7 FOR CITY, puerto deseado.
#
# PROCESSING RECORD #23 OF SET 7 FOR CITY, hami.
#
# PROCESSING RECORD #24 OF SET 7 FOR CITY, polyarnyye zori.
#
# PROCESSING RECORD #25 OF SET 7 FOR CITY, vera.
#
# PROCESSING RECORD #26 OF SET 7 FOR CITY, zhalantun.
#
# PROCESSING RECORD #27 OF SET 7 FOR CITY, damulog.
#
# PROCESSING RECORD #28 OF SET 7 FOR CITY, udachny.
#
# PROCESSING RECORD #29 OF SET 7 FOR CITY, taulaga.
#
# PROCESSING RECORD #30 OF SET 7 FOR CITY, porto novo.
#
# PROCESSING RECORD #31 OF SET 7 FOR CITY, itacoatiara.
#
# PROCESSING RECORD #32 OF SET 7 FOR CITY, ta`u.
#
# PROCESSING RECORD #33 OF SET 7 FOR CITY, polyarnyy.
#
# PROCESSING RECORD #34 OF SET 7 FOR CITY, carnarvon.
#
# PROCESSING RECORD #35 OF SET 7 FOR CITY, egilsstadir.
#
# PROCESSING RECORD #36 OF SET 7 FOR CITY, gadzhiyevo.
#
# PROCESSING RECORD #37 OF SET 7 FOR CITY, lazaro cardenas.
#
# PROCESSING RECORD #38 OF SET 7 FOR CITY, dalandzadgad.
#
# PROCESSING RECORD #39 OF SET 7 FOR CITY, issia.
#
# PROCESSING RECORD #40 OF SET 7 FOR CITY, itaituba.
#
# PROCESSING RECORD #41 OF SET 7 FOR CITY, vetluzhskiy.
#
# PROCESSING RECORD #42 OF SET 7 FOR CITY, kone.
#
# PROCESSING RECORD #43 OF SET 7 FOR CITY, san andres.
#
# PROCESSING RECORD #44 OF SET 7 FOR CITY, nuku'alofa.
#
# PROCESSING RECORD #45 OF SET 7 FOR CITY, sur.
#
# PROCESSING RECORD #46 OF SET 7 FOR CITY, houghton.
#
# PROCESSING RECORD #47 OF SET 7 FOR CITY, imbituba.
#
# PROCESSING RECORD #48 OF SET 7 FOR CITY, chapaev.
#
# PROCESSING RECORD #49 OF SET 7 FOR CITY, betio village.
#
# PROCESSING RECORD #50 OF SET 7 FOR CITY, kapuskasing.
#
# PROCESSING RECORD #1 OF SET 8 FOR CITY, muravlenko.
#
# PROCESSING RECORD #2 OF SET 8 FOR CITY, garh maharaja.
#
# PROCESSING RECORD #3 OF SET 8 FOR CITY, gisborne.
#
# PROCESSING RECORD #4 OF SET 8 FOR CITY, ixtapa.
#
# PROCESSING RECORD #5 OF SET 8 FOR CITY, sungailiat.
#
# PROCESSING RECORD #6 OF SET 8 FOR CITY, al kharijah.
#
# PROCESSING RECORD #7 OF SET 8 FOR CITY, castlegar.
#
# PROCESSING RECORD #8 OF SET 8 FOR CITY, hovd.
#
# PROCESSING RECORD #9 OF SET 8 FOR CITY, kargasok.
#
# PROCESSING RECORD #10 OF SET 8 FOR CITY, enewetak.
#
# PROCESSING RECORD #11 OF SET 8 FOR CITY, constantia.
#
# PROCESSING RECORD #12 OF SET 8 FOR CITY, choibalsan.
#
# PROCESSING RECORD #13 OF SET 8 FOR CITY, mizdah.
#
# PROCESSING RECORD #14 OF SET 8 FOR CITY, dolores.
#
# PROCESSING RECORD #15 OF SET 8 FOR CITY, corlette.
#
# PROCESSING RECORD #16 OF SET 8 FOR CITY, maputo.
#
# PROCESSING RECORD #17 OF SET 8 FOR CITY, georgetown.
#
# PROCESSING RECORD #18 OF SET 8 FOR CITY, villa gesell.
#
# PROCESSING RECORD #19 OF SET 8 FOR CITY, barra de santo antonio.
#
# PROCESSING RECORD #20 OF SET 8 FOR CITY, nizhnesortymskiy.
#
# PROCESSING RECORD #21 OF SET 8 FOR CITY, cabo san lucas.
#
# PROCESSING RECORD #22 OF SET 8 FOR CITY, santa ana de yacuma.
#
# PROCESSING RECORD #23 OF SET 8 FOR CITY, ain sefra.
#
# PROCESSING RECORD #24 OF SET 8 FOR CITY, ashland.
#
# PROCESSING RECORD #25 OF SET 8 FOR CITY, tsiombe.
#
# PROCESSING RECORD #26 OF SET 8 FOR CITY, greymouth.
#
# PROCESSING RECORD #27 OF SET 8 FOR CITY, tanggu.
#
# PROCESSING RECORD #28 OF SET 8 FOR CITY, mahanoro.
#
# PROCESSING RECORD #29 OF SET 8 FOR CITY, shakawe.
#
# PROCESSING RECORD #30 OF SET 8 FOR CITY, gorodishche.
#
# PROCESSING RECORD #31 OF SET 8 FOR CITY, chocianow.
#
# PROCESSING RECORD #32 OF SET 8 FOR CITY, lewistown.
#
# PROCESSING RECORD #33 OF SET 8 FOR CITY, naliya.
#
# PROCESSING RECORD #34 OF SET 8 FOR CITY, carqueiranne.
#
# PROCESSING RECORD #35 OF SET 8 FOR CITY, labytnangi.
#
# PROCESSING RECORD #36 OF SET 8 FOR CITY, guer.
#
# PROCESSING RECORD #37 OF SET 8 FOR CITY, taber.
#
# PROCESSING RECORD #38 OF SET 8 FOR CITY, vanimo.
#
# PROCESSING RECORD #39 OF SET 8 FOR CITY, queenstown.
#
# PROCESSING RECORD #40 OF SET 8 FOR CITY, ajodhya.
#
# PROCESSING RECORD #41 OF SET 8 FOR CITY, gueltat zemmour.
#
# The script did not find the city, gueltat zemmour. Skipping...
#
# PROCESSING RECORD #42 OF SET 8 FOR CITY, labuan bajo.
#
# PROCESSING RECORD #43 OF SET 8 FOR CITY, bamboo flat.
#
# PROCESSING RECORD #44 OF SET 8 FOR CITY, sabang.
#
# PROCESSING RECORD #45 OF SET 8 FOR CITY, takoradi.
#
# PROCESSING RECORD #46 OF SET 8 FOR CITY, nadi.
#
# PROCESSING RECORD #47 OF SET 8 FOR CITY, kropachevo.
#
# PROCESSING RECORD #48 OF SET 8 FOR CITY, dzuunharaa.
#
# PROCESSING RECORD #49 OF SET 8 FOR CITY, tromso.
#
# PROCESSING RECORD #50 OF SET 8 FOR CITY, la gi.
#
# PROCESSING RECORD #1 OF SET 9 FOR CITY, kargil.
#
# PROCESSING RECORD #2 OF SET 9 FOR CITY, borgarnes.
#
# PROCESSING RECORD #3 OF SET 9 FOR CITY, hermanus.
#
# PROCESSING RECORD #4 OF SET 9 FOR CITY, lamu.
#
# PROCESSING RECORD #5 OF SET 9 FOR CITY, devinuwara.
#
# The script did not find the city, devinuwara. Skipping...
#
# PROCESSING RECORD #6 OF SET 9 FOR CITY, ulsteinvik.
#
# PROCESSING RECORD #7 OF SET 9 FOR CITY, karamay.
#
# The script did not find the city, karamay. Skipping...
#
# PROCESSING RECORD #8 OF SET 9 FOR CITY, maxixe.
#
# PROCESSING RECORD #9 OF SET 9 FOR CITY, carahue.
#
# PROCESSING RECORD #10 OF SET 9 FOR CITY, berdigestyakh.
#
# PROCESSING RECORD #11 OF SET 9 FOR CITY, risod.
#
# PROCESSING RECORD #12 OF SET 9 FOR CITY, troitsko-pechorsk.
#
# PROCESSING RECORD #13 OF SET 9 FOR CITY, sioux falls.
#
# PROCESSING RECORD #14 OF SET 9 FOR CITY, vila franca do campo.
#
# PROCESSING RECORD #15 OF SET 9 FOR CITY, vila velha.
#
# PROCESSING RECORD #16 OF SET 9 FOR CITY, pisco.
#
# PROCESSING RECORD #17 OF SET 9 FOR CITY, port saint john's.
#
# PROCESSING RECORD #18 OF SET 9 FOR CITY, ifakara.
#
# PROCESSING RECORD #19 OF SET 9 FOR CITY, el alto.
#
# PROCESSING RECORD #20 OF SET 9 FOR CITY, hluti.
#
# PROCESSING RECORD #21 OF SET 9 FOR CITY, shimoda.
#
# PROCESSING RECORD #22 OF SET 9 FOR CITY, nevada.
#
# PROCESSING RECORD #23 OF SET 9 FOR CITY, lloydminster.
#
# PROCESSING RECORD #24 OF SET 9 FOR CITY, stephenville.
#
# PROCESSING RECORD #25 OF SET 9 FOR CITY, mugia.
#
# PROCESSING RECORD #26 OF SET 9 FOR CITY, kulob.
#
# PROCESSING RECORD #27 OF SET 9 FOR CITY, guerrero negro.
#
# PROCESSING RECORD #28 OF SET 9 FOR CITY, olyokminsk.
#
# PROCESSING RECORD #29 OF SET 9 FOR CITY, rio grande.
#
# PROCESSING RECORD #30 OF SET 9 FOR CITY, siwa oasis.
#
# PROCESSING RECORD #31 OF SET 9 FOR CITY, ghat.
#
# PROCESSING RECORD #32 OF SET 9 FOR CITY, st. john's.
#
# PROCESSING RECORD #33 OF SET 9 FOR CITY, santa ines.
#
# PROCESSING RECORD #34 OF SET 9 FOR CITY, feltre.
#
# PROCESSING RECORD #35 OF SET 9 FOR CITY, port shepstone.
#
# PROCESSING RECORD #36 OF SET 9 FOR CITY, wang noi.
#
# PROCESSING RECORD #37 OF SET 9 FOR CITY, orcopampa.
#
# PROCESSING RECORD #38 OF SET 9 FOR CITY, haiku-pauwela.
#
# PROCESSING RECORD #39 OF SET 9 FOR CITY, takamaka.
#
# The script did not find the city, takamaka. Skipping...
#
# PROCESSING RECORD #40 OF SET 9 FOR CITY, alaghsas.
#
# PROCESSING RECORD #41 OF SET 9 FOR CITY, beau vallon.
#
# PROCESSING RECORD #42 OF SET 9 FOR CITY, aasiaat.
#
# PROCESSING RECORD #43 OF SET 9 FOR CITY, sayanogorsk.
#
# PROCESSING RECORD #44 OF SET 9 FOR CITY, bargara.
#
# The script did not find the city, bargara. Skipping...
#
# PROCESSING RECORD #45 OF SET 9 FOR CITY, tura.
# PROCESSING RECORD #46 OF SET 9 FOR CITY, kutum.
#
# PROCESSING RECORD #47 OF SET 9 FOR CITY, tabou.
#
# PROCESSING RECORD #48 OF SET 9 FOR CITY, manta.
#
# PROCESSING RECORD #49 OF SET 9 FOR CITY, vorkuta.
#
# PROCESSING RECORD #50 OF SET 9 FOR CITY, kurchatov.
#
# PROCESSING RECORD #1 OF SET 10 FOR CITY, zhangjiajie.
#
# PROCESSING RECORD #2 OF SET 10 FOR CITY, penzance.
#
# PROCESSING RECORD #3 OF SET 10 FOR CITY, moyale.
#
# PROCESSING RECORD #4 OF SET 10 FOR CITY, kailua-kona.
#
# PROCESSING RECORD #5 OF SET 10 FOR CITY, san-pedro.
#
# PROCESSING RECORD #6 OF SET 10 FOR CITY, mana.
#
# PROCESSING RECORD #7 OF SET 10 FOR CITY, kangding.
#
# PROCESSING RECORD #8 OF SET 10 FOR CITY, gurjaani.
#
# PROCESSING RECORD #9 OF SET 10 FOR CITY, beira.
#
# PROCESSING RECORD #10 OF SET 10 FOR CITY, chibougamau.
#
# PROCESSING RECORD #11 OF SET 10 FOR CITY, saveh.
#
# PROCESSING RECORD #12 OF SET 10 FOR CITY, al qaryatayn.
#
# PROCESSING RECORD #13 OF SET 10 FOR CITY, boa vista.
#
# PROCESSING RECORD #14 OF SET 10 FOR CITY, colby.
#
# PROCESSING RECORD #15 OF SET 10 FOR CITY, yelizovo.
#
# PROCESSING RECORD #16 OF SET 10 FOR CITY, lebyazh'ye.
#
# PROCESSING RECORD #17 OF SET 10 FOR CITY, guaraniacu.
#
# PROCESSING RECORD #18 OF SET 10 FOR CITY, canatlan.
#
# PROCESSING RECORD #19 OF SET 10 FOR CITY, pathein.
#
# PROCESSING RECORD #20 OF SET 10 FOR CITY, zouerate.
#
# PROCESSING RECORD #21 OF SET 10 FOR CITY, shizunai-furukawacho.
#
# PROCESSING RECORD #22 OF SET 10 FOR CITY, kovur.
#
# PROCESSING RECORD #23 OF SET 10 FOR CITY, san julian.
#
# PROCESSING RECORD #24 OF SET 10 FOR CITY, maloye ganyushkino.
#
# PROCESSING RECORD #25 OF SET 10 FOR CITY, kirakira.
#
# PROCESSING RECORD #26 OF SET 10 FOR CITY, chirpan.
#
# PROCESSING RECORD #27 OF SET 10 FOR CITY, cat ba.
#
# The script did not find the city, cat ba. Skipping...
#
# PROCESSING RECORD #28 OF SET 10 FOR CITY, saint-pierre.
#
# PROCESSING RECORD #29 OF SET 10 FOR CITY, selfoss.
#
# PROCESSING RECORD #30 OF SET 10 FOR CITY, touros.
#
# PROCESSING RECORD #31 OF SET 10 FOR CITY, crane.
#
# PROCESSING RECORD #32 OF SET 10 FOR CITY, sinabang.
#
# PROCESSING RECORD #33 OF SET 10 FOR CITY, qarauyl.
#
# PROCESSING RECORD #34 OF SET 10 FOR CITY, aromashevo.
#
# PROCESSING RECORD #35 OF SET 10 FOR CITY, yangor.
#
# The script did not find the city, yangor. Skipping...
#
# PROCESSING RECORD #36 OF SET 10 FOR CITY, mount darwin.
#
# PROCESSING RECORD #37 OF SET 10 FOR CITY, prince rupert.
#
# PROCESSING RECORD #38 OF SET 10 FOR CITY, port douglas.
#
# PROCESSING RECORD #39 OF SET 10 FOR CITY, orizona.
#
# PROCESSING RECORD #40 OF SET 10 FOR CITY, aras-asan.
#
# PROCESSING RECORD #41 OF SET 10 FOR CITY, sidi ifni.
#
# PROCESSING RECORD #42 OF SET 10 FOR CITY, shanhaiguan.
#
# PROCESSING RECORD #43 OF SET 10 FOR CITY, kondopoga.
#
# PROCESSING RECORD #44 OF SET 10 FOR CITY, san rafael.
#
# PROCESSING RECORD #45 OF SET 10 FOR CITY, howard springs.
#
# PROCESSING RECORD #46 OF SET 10 FOR CITY, al-`ula.
#
# The script did not find the city, al-`ula. Skipping...
#
# PROCESSING RECORD #47 OF SET 10 FOR CITY, grand-bassam.
#
# PROCESSING RECORD #48 OF SET 10 FOR CITY, chippewa falls.
#
# PROCESSING RECORD #49 OF SET 10 FOR CITY, qui nhon.
#
# PROCESSING RECORD #50 OF SET 10 FOR CITY, angaur state.
#
# PROCESSING RECORD #1 OF SET 11 FOR CITY, boguchany.
#
# PROCESSING RECORD #2 OF SET 11 FOR CITY, holualoa.
#
# PROCESSING RECORD #3 OF SET 11 FOR CITY, newman.
#
# PROCESSING RECORD #4 OF SET 11 FOR CITY, marang.
#
# PROCESSING RECORD #5 OF SET 11 FOR CITY, cepu.
#
# PROCESSING RECORD #6 OF SET 11 FOR CITY, colonia.
#
# PROCESSING RECORD #7 OF SET 11 FOR CITY, costa teguise.
#
# The script did not find the city, costa teguise. Skipping...
#
# PROCESSING RECORD #8 OF SET 11 FOR CITY, iwanai.
#
# PROCESSING RECORD #9 OF SET 11 FOR CITY, talnakh.
#
# PROCESSING RECORD #10 OF SET 11 FOR CITY, sao vicente.
#
# PROCESSING RECORD #11 OF SET 11 FOR CITY, nyala.
#
# PROCESSING RECORD #12 OF SET 11 FOR CITY, nafplio.
#
# PROCESSING RECORD #13 OF SET 11 FOR CITY, moyobamba.
#
# PROCESSING RECORD #14 OF SET 11 FOR CITY, nuuk.
#
# PROCESSING RECORD #15 OF SET 11 FOR CITY, belize city.
#
# PROCESSING RECORD #16 OF SET 11 FOR CITY, castanos.
#
# PROCESSING RECORD #17 OF SET 11 FOR CITY, solleftea.
#
# PROCESSING RECORD #18 OF SET 11 FOR CITY, malango.
#
# PROCESSING RECORD #19 OF SET 11 FOR CITY, puerto leguizamo.
#
# PROCESSING RECORD #20 OF SET 11 FOR CITY, codrington.
#
# PROCESSING RECORD #21 OF SET 11 FOR CITY, berezovyy.
#
# PROCESSING RECORD #22 OF SET 11 FOR CITY, formosa do rio preto.
#
# PROCESSING RECORD #23 OF SET 11 FOR CITY, khor.
#
# PROCESSING RECORD #24 OF SET 11 FOR CITY, zhumysker.
#
# PROCESSING RECORD #25 OF SET 11 FOR CITY, stade.
#
# PROCESSING RECORD #26 OF SET 11 FOR CITY, souillac.
#
# PROCESSING RECORD #27 OF SET 11 FOR CITY, tadine.
#
# PROCESSING RECORD #28 OF SET 11 FOR CITY, galesong.
#
# PROCESSING RECORD #29 OF SET 11 FOR CITY, ryotsu-minato.
#
# PROCESSING RECORD #30 OF SET 11 FOR CITY, motril.
#
# PROCESSING RECORD #31 OF SET 11 FOR CITY, nouadhibou.
#
# PROCESSING RECORD #32 OF SET 11 FOR CITY, new norfolk.
#
# PROCESSING RECORD #33 OF SET 11 FOR CITY, gevas.
#
# PROCESSING RECORD #34 OF SET 11 FOR CITY, nova vicosa.
#
# PROCESSING RECORD #35 OF SET 11 FOR CITY, saratamata.
#
# The script did not find the city, saratamata. Skipping...
#
# PROCESSING RECORD #36 OF SET 11 FOR CITY, yamada.
#
# PROCESSING RECORD #37 OF SET 11 FOR CITY, totness.
#
# PROCESSING RECORD #38 OF SET 11 FOR CITY, upper dir.
#
# PROCESSING RECORD #39 OF SET 11 FOR CITY, alenquer.
#
# PROCESSING RECORD #40 OF SET 11 FOR CITY, saskatoon.
#
# PROCESSING RECORD #41 OF SET 11 FOR CITY, neryungri.
#
# PROCESSING RECORD #42 OF SET 11 FOR CITY, tosno.
#
# PROCESSING RECORD #43 OF SET 11 FOR CITY, bubaque.
#
# PROCESSING RECORD #44 OF SET 11 FOR CITY, zhangatas.
#
# PROCESSING RECORD #45 OF SET 11 FOR CITY, coruripe.
#
# PROCESSING RECORD #46 OF SET 11 FOR CITY, ikedacho.
#
# PROCESSING RECORD #47 OF SET 11 FOR CITY, peniche.
#
# PROCESSING RECORD #48 OF SET 11 FOR CITY, yemva.
#
# PROCESSING RECORD #49 OF SET 11 FOR CITY, kudahuvadhoo.
#
# PROCESSING RECORD #50 OF SET 11 FOR CITY, karukh.
#
# PROCESSING RECORD #1 OF SET 12 FOR CITY, boulder city.
#
# PROCESSING RECORD #2 OF SET 12 FOR CITY, kryzhopil'.
#
# The script did not find the city, kryzhopil'. Skipping...
#
# PROCESSING RECORD #3 OF SET 12 FOR CITY, saiha.
#
# PROCESSING RECORD #4 OF SET 12 FOR CITY, summerside.
#
# PROCESSING RECORD #5 OF SET 12 FOR CITY, pangai.
#
# PROCESSING RECORD #6 OF SET 12 FOR CITY, bandar.
#
# PROCESSING RECORD #7 OF SET 12 FOR CITY, chibuto.
#
# PROCESSING RECORD #8 OF SET 12 FOR CITY, bambanglipuro.
#
# PROCESSING RECORD #9 OF SET 12 FOR CITY, kruisfontein.
#
# PROCESSING RECORD #10 OF SET 12 FOR CITY, safi.
#
# PROCESSING RECORD #11 OF SET 12 FOR CITY, tekane.
#
# The script did not find the city, tekane. Skipping...
#
# PROCESSING RECORD #12 OF SET 12 FOR CITY, haugesund.
#
# PROCESSING RECORD #13 OF SET 12 FOR CITY, tisma.
#
# PROCESSING RECORD #14 OF SET 12 FOR CITY, cuamba.
#
# PROCESSING RECORD #15 OF SET 12 FOR CITY, kolonia.
#
# PROCESSING RECORD #16 OF SET 12 FOR CITY, chardara.
#
# PROCESSING RECORD #17 OF SET 12 FOR CITY, mahalapye.
#
# PROCESSING RECORD #18 OF SET 12 FOR CITY, nzega.
#
# PROCESSING RECORD #19 OF SET 12 FOR CITY, laojunmiao.
#
# PROCESSING RECORD #20 OF SET 12 FOR CITY, muli.
#
# PROCESSING RECORD #21 OF SET 12 FOR CITY, sunnyside.
#
# PROCESSING RECORD #22 OF SET 12 FOR CITY, mocorito.
#
# PROCESSING RECORD #23 OF SET 12 FOR CITY, trinidad.
#
# PROCESSING RECORD #24 OF SET 12 FOR CITY, gamba.
#
# PROCESSING RECORD #25 OF SET 12 FOR CITY, ust-tsilma.
#
# PROCESSING RECORD #26 OF SET 12 FOR CITY, ilabaya.
#
# PROCESSING RECORD #27 OF SET 12 FOR CITY, talanga.
#
# PROCESSING RECORD #28 OF SET 12 FOR CITY, 'amran.
#
# The script did not find the city, 'amran. Skipping...
#
# PROCESSING RECORD #29 OF SET 12 FOR CITY, sa kaeo.
#
# PROCESSING RECORD #30 OF SET 12 FOR CITY, palopo.
#
# PROCESSING RECORD #31 OF SET 12 FOR CITY, letychiv.
#
# PROCESSING RECORD #32 OF SET 12 FOR CITY, acajutla.
#
# PROCESSING RECORD #33 OF SET 12 FOR CITY, pergine valsugana.
#
# PROCESSING RECORD #34 OF SET 12 FOR CITY, bireun.
#
# PROCESSING RECORD #35 OF SET 12 FOR CITY, xining.
#
# PROCESSING RECORD #36 OF SET 12 FOR CITY, mukah.
#
# The script did not find the city, mukah. Skipping...
#
# PROCESSING RECORD #37 OF SET 12 FOR CITY, itacarambi.
#
# PROCESSING RECORD #38 OF SET 12 FOR CITY, jayapura.
#
# PROCESSING RECORD #39 OF SET 12 FOR CITY, taungdwingyi.
#
# PROCESSING RECORD #40 OF SET 12 FOR CITY, medicine hat.
#
# PROCESSING RECORD #41 OF SET 12 FOR CITY, ekuvukeni.
# PROCESSING RECORD #42 OF SET 12 FOR CITY, sebastopol.
#
# PROCESSING RECORD #43 OF SET 12 FOR CITY, strezhevoy.
#
# PROCESSING RECORD #44 OF SET 12 FOR CITY, altai.
#
# PROCESSING RECORD #45 OF SET 12 FOR CITY, poso.
#
# PROCESSING RECORD #46 OF SET 12 FOR CITY, aoulef.
#
# PROCESSING RECORD #47 OF SET 12 FOR CITY, nayoro.
#
# PROCESSING RECORD #48 OF SET 12 FOR CITY, kerema.
#
# PROCESSING RECORD #49 OF SET 12 FOR CITY, mutoko.
#
# PROCESSING RECORD #50 OF SET 12 FOR CITY, praia da vitoria.
#
# PROCESSING RECORD #1 OF SET 13 FOR CITY, norton shores.
#
# PROCESSING RECORD #2 OF SET 13 FOR CITY, fort st. john.
#
# PROCESSING RECORD #3 OF SET 13 FOR CITY, fortaleza.
#
# PROCESSING RECORD #4 OF SET 13 FOR CITY, carlsbad.
#
# PROCESSING RECORD #5 OF SET 13 FOR CITY, rada tilly.
#
# PROCESSING RECORD #6 OF SET 13 FOR CITY, tokonou.
#
# PROCESSING RECORD #7 OF SET 13 FOR CITY, nichinan.
#
# PROCESSING RECORD #8 OF SET 13 FOR CITY, nabire.
#
# PROCESSING RECORD #9 OF SET 13 FOR CITY, phrai bueng.
#
# PROCESSING RECORD #10 OF SET 13 FOR CITY, nelson.
#
# PROCESSING RECORD #11 OF SET 13 FOR CITY, tazovsky.
#
# PROCESSING RECORD #12 OF SET 13 FOR CITY, bel ombre.
#
# PROCESSING RECORD #13 OF SET 13 FOR CITY, mount hagen.
#
# PROCESSING RECORD #14 OF SET 13 FOR CITY, mar del plata.
#
# PROCESSING RECORD #15 OF SET 13 FOR CITY, toga village.
#
# The script did not find the city, toga village. Skipping...
#
# PROCESSING RECORD #16 OF SET 13 FOR CITY, lautoka.
#
# PROCESSING RECORD #17 OF SET 13 FOR CITY, lagoa.
#
# PROCESSING RECORD #18 OF SET 13 FOR CITY, kavaratti.
#
# PROCESSING RECORD #19 OF SET 13 FOR CITY, bousso.
#
# PROCESSING RECORD #20 OF SET 13 FOR CITY, mandalgovi.
#
# PROCESSING RECORD #21 OF SET 13 FOR CITY, port alfred.
#
# PROCESSING RECORD #22 OF SET 13 FOR CITY, happy valley-goose bay.
#
# PROCESSING RECORD #23 OF SET 13 FOR CITY, gitega.
#
# PROCESSING RECORD #24 OF SET 13 FOR CITY, mount pearl.
#
# PROCESSING RECORD #25 OF SET 13 FOR CITY, nemuro.
#
# PROCESSING RECORD #26 OF SET 13 FOR CITY, nizhnyaya poyma.
#
# PROCESSING RECORD #27 OF SET 13 FOR CITY, san miguel de cauri.
#
# PROCESSING RECORD #28 OF SET 13 FOR CITY, monte patria.
#
# PROCESSING RECORD #29 OF SET 13 FOR CITY, harper.
#
# PROCESSING RECORD #30 OF SET 13 FOR CITY, mont-tremblant.
#
# PROCESSING RECORD #31 OF SET 13 FOR CITY, el nido.
#
# PROCESSING RECORD #32 OF SET 13 FOR CITY, muisne.
#
# PROCESSING RECORD #33 OF SET 13 FOR CITY, daru.
#
# PROCESSING RECORD #34 OF SET 13 FOR CITY, tutoia.
#
# PROCESSING RECORD #35 OF SET 13 FOR CITY, san pedro.
#
# PROCESSING RECORD #36 OF SET 13 FOR CITY, mogocha.
#
# PROCESSING RECORD #37 OF SET 13 FOR CITY, ete.
#
# PROCESSING RECORD #38 OF SET 13 FOR CITY, bac lieu.
#
# PROCESSING RECORD #39 OF SET 13 FOR CITY, callao.
#
# PROCESSING RECORD #40 OF SET 13 FOR CITY, ketchikan.
#
# PROCESSING RECORD #41 OF SET 13 FOR CITY, lyuban'.
#
# PROCESSING RECORD #42 OF SET 13 FOR CITY, huautla de jimenez.
#
# Data Retrieval for city weather DataFrame is complete.

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Records Count**

# %%
cityWeatherCountIntegerVariable \
    = cityWeatherDataFrame \
        ['City'] \
            .count()

print \
    (f"There are {cityWeatherCountIntegerVariable} " \
     + f"records in the city weather DataFrame.")
# Out:
# There are 614 records in the city weather DataFrame.

# %% [markdown]
# ### **Display City Weather DataFrame**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_de919 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_de919_row0_col0, #T_de919_row0_col1, #T_de919_row0_col2, #T_de919_row0_col4, #T_de919_row0_col5, #T_de919_row0_col6, #T_de919_row0_col7, #T_de919_row0_col8, #T_de919_row1_col0, #T_de919_row1_col1, #T_de919_row1_col2, #T_de919_row1_col3, #T_de919_row1_col4, #T_de919_row1_col5, #T_de919_row1_col6, #T_de919_row1_col7, #T_de919_row1_col8, #T_de919_row2_col0, #T_de919_row2_col1, #T_de919_row2_col2, #T_de919_row2_col3, #T_de919_row2_col4, #T_de919_row2_col7, #T_de919_row2_col8, #T_de919_row3_col0, #T_de919_row3_col1, #T_de919_row3_col2, #T_de919_row3_col3, #T_de919_row3_col4, #T_de919_row3_col5, #T_de919_row3_col6, #T_de919_row3_col7, #T_de919_row3_col8, #T_de919_row4_col0, #T_de919_row4_col1, #T_de919_row4_col2, #T_de919_row4_col3, #T_de919_row4_col4, #T_de919_row4_col5, #T_de919_row4_col6, #T_de919_row4_col7, #T_de919_row4_col8, #T_de919_row5_col0, #T_de919_row5_col1, #T_de919_row5_col2, #T_de919_row5_col3, #T_de919_row5_col6, #T_de919_row5_col7, #T_de919_row5_col8, #T_de919_row6_col0, #T_de919_row6_col1, #T_de919_row6_col2, #T_de919_row6_col3, #T_de919_row6_col5, #T_de919_row6_col6, #T_de919_row6_col7, #T_de919_row6_col8, #T_de919_row7_col0, #T_de919_row7_col1, #T_de919_row7_col2, #T_de919_row7_col3, #T_de919_row7_col4, #T_de919_row7_col5, #T_de919_row7_col6, #T_de919_row7_col7, #T_de919_row7_col8, #T_de919_row8_col0, #T_de919_row8_col1, #T_de919_row8_col2, #T_de919_row8_col5, #T_de919_row8_col6, #T_de919_row8_col7, #T_de919_row8_col8, #T_de919_row9_col0, #T_de919_row9_col1, #T_de919_row9_col2, #T_de919_row9_col3, #T_de919_row9_col4, #T_de919_row9_col5, #T_de919_row9_col6, #T_de919_row9_col7, #T_de919_row9_col8, #T_de919_row10_col0, #T_de919_row10_col1, #T_de919_row10_col2, #T_de919_row10_col3, #T_de919_row10_col4, #T_de919_row10_col5, #T_de919_row10_col7, #T_de919_row10_col8, #T_de919_row11_col0, #T_de919_row11_col1, #T_de919_row11_col2, #T_de919_row11_col3, #T_de919_row11_col4, #T_de919_row11_col6, #T_de919_row11_col7, #T_de919_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_de919_row0_col3, #T_de919_row2_col5, #T_de919_row6_col4, #T_de919_row10_col6, #T_de919_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_de919_row2_col6, #T_de919_row5_col4, #T_de919_row5_col5, #T_de919_row8_col3, #T_de919_row8_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_de919">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_de919_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_de919_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_de919_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_de919_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_de919_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_de919_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_de919_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_de919_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_de919_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_de919_row0_col0" class="data row0 col0" >grytviken</td>
#       <td id="T_de919_row0_col1" class="data row0 col1" >-54.28</td>
#       <td id="T_de919_row0_col2" class="data row0 col2" >-36.51</td>
#       <td id="T_de919_row0_col3" class="data row0 col3" >26.80° F</td>
#       <td id="T_de919_row0_col4" class="data row0 col4" >80%</td>
#       <td id="T_de919_row0_col5" class="data row0 col5" >53%</td>
#       <td id="T_de919_row0_col6" class="data row0 col6" >13.51</td>
#       <td id="T_de919_row0_col7" class="data row0 col7" >GS</td>
#       <td id="T_de919_row0_col8" class="data row0 col8" >2023-09-18 09:52:20</td>
#     </tr>
#     <tr>
#       <td id="T_de919_row1_col0" class="data row1 col0" >mansa</td>
#       <td id="T_de919_row1_col1" class="data row1 col1" >29.98</td>
#       <td id="T_de919_row1_col2" class="data row1 col2" >75.38</td>
#       <td id="T_de919_row1_col3" class="data row1 col3" >77.67° F</td>
#       <td id="T_de919_row1_col4" class="data row1 col4" >88%</td>
#       <td id="T_de919_row1_col5" class="data row1 col5" >78%</td>
#       <td id="T_de919_row1_col6" class="data row1 col6" >6.17</td>
#       <td id="T_de919_row1_col7" class="data row1 col7" >IN</td>
#       <td id="T_de919_row1_col8" class="data row1 col8" >2023-09-18 10:01:51</td>
#     </tr>
#     <tr>
#       <td id="T_de919_row2_col0" class="data row2 col0" >toliara</td>
#       <td id="T_de919_row2_col1" class="data row2 col1" >-23.35</td>
#       <td id="T_de919_row2_col2" class="data row2 col2" >43.67</td>
#       <td id="T_de919_row2_col3" class="data row2 col3" >76.57° F</td>
#       <td id="T_de919_row2_col4" class="data row2 col4" >63%</td>
#       <td id="T_de919_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_de919_row2_col6" class="data row2 col6" >20.27</td>
#       <td id="T_de919_row2_col7" class="data row2 col7" >MG</td>
#       <td id="T_de919_row2_col8" class="data row2 col8" >2023-09-18 09:53:54</td>
#     </tr>
#     <tr>
#       <td id="T_de919_row3_col0" class="data row3 col0" >port lincoln</td>
#       <td id="T_de919_row3_col1" class="data row3 col1" >-34.73</td>
#       <td id="T_de919_row3_col2" class="data row3 col2" >135.87</td>
#       <td id="T_de919_row3_col3" class="data row3 col3" >55.18° F</td>
#       <td id="T_de919_row3_col4" class="data row3 col4" >84%</td>
#       <td id="T_de919_row3_col5" class="data row3 col5" >87%</td>
#       <td id="T_de919_row3_col6" class="data row3 col6" >7.47</td>
#       <td id="T_de919_row3_col7" class="data row3 col7" >AU</td>
#       <td id="T_de919_row3_col8" class="data row3 col8" >2023-09-18 09:52:29</td>
#     </tr>
#     <tr>
#       <td id="T_de919_row4_col0" class="data row4 col0" >baikunthpur</td>
#       <td id="T_de919_row4_col1" class="data row4 col1" >23.25</td>
#       <td id="T_de919_row4_col2" class="data row4 col2" >82.55</td>
#       <td id="T_de919_row4_col3" class="data row4 col3" >75.74° F</td>
#       <td id="T_de919_row4_col4" class="data row4 col4" >85%</td>
#       <td id="T_de919_row4_col5" class="data row4 col5" >14%</td>
#       <td id="T_de919_row4_col6" class="data row4 col6" >2.59</td>
#       <td id="T_de919_row4_col7" class="data row4 col7" >IN</td>
#       <td id="T_de919_row4_col8" class="data row4 col8" >2023-09-18 10:01:52</td>
#     </tr>
#     <tr>
#       <td id="T_de919_row5_col0" class="data row5 col0" >bethel</td>
#       <td id="T_de919_row5_col1" class="data row5 col1" >41.37</td>
#       <td id="T_de919_row5_col2" class="data row5 col2" >-73.41</td>
#       <td id="T_de919_row5_col3" class="data row5 col3" >63.66° F</td>
#       <td id="T_de919_row5_col4" class="data row5 col4" >89%</td>
#       <td id="T_de919_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_de919_row5_col6" class="data row5 col6" >3.44</td>
#       <td id="T_de919_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_de919_row5_col8" class="data row5 col8" >2023-09-18 09:52:20</td>
#     </tr>
#     <tr>
#       <td id="T_de919_row6_col0" class="data row6 col0" >puerto natales</td>
#       <td id="T_de919_row6_col1" class="data row6 col1" >-51.72</td>
#       <td id="T_de919_row6_col2" class="data row6 col2" >-72.49</td>
#       <td id="T_de919_row6_col3" class="data row6 col3" >40.23° F</td>
#       <td id="T_de919_row6_col4" class="data row6 col4" >52%</td>
#       <td id="T_de919_row6_col5" class="data row6 col5" >36%</td>
#       <td id="T_de919_row6_col6" class="data row6 col6" >5.91</td>
#       <td id="T_de919_row6_col7" class="data row6 col7" >CL</td>
#       <td id="T_de919_row6_col8" class="data row6 col8" >2023-09-18 09:52:21</td>
#     </tr>
#     <tr>
#       <td id="T_de919_row7_col0" clas

# %% [markdown]
# ### **Data Export to CSV File**

# %%
subroutine \
    .WriteDataFrameToCSVFile \
        (cityWeatherDataFrame,
         local_constant.WEATHER_DATA_FILE_PATH,
         local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Data Import from CSV File**

# %%
sampleCityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Display Sample City Weather DataFrame**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information from CSV File')
# Out:
# <style type="text/css">
# #T_990b8 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_990b8_row0_col0, #T_990b8_row0_col1, #T_990b8_row0_col2, #T_990b8_row0_col4, #T_990b8_row0_col5, #T_990b8_row0_col6, #T_990b8_row0_col7, #T_990b8_row0_col8, #T_990b8_row1_col0, #T_990b8_row1_col1, #T_990b8_row1_col2, #T_990b8_row1_col3, #T_990b8_row1_col4, #T_990b8_row1_col5, #T_990b8_row1_col6, #T_990b8_row1_col7, #T_990b8_row1_col8, #T_990b8_row2_col0, #T_990b8_row2_col1, #T_990b8_row2_col2, #T_990b8_row2_col3, #T_990b8_row2_col4, #T_990b8_row2_col7, #T_990b8_row2_col8, #T_990b8_row3_col0, #T_990b8_row3_col1, #T_990b8_row3_col2, #T_990b8_row3_col3, #T_990b8_row3_col4, #T_990b8_row3_col5, #T_990b8_row3_col6, #T_990b8_row3_col7, #T_990b8_row3_col8, #T_990b8_row4_col0, #T_990b8_row4_col1, #T_990b8_row4_col2, #T_990b8_row4_col3, #T_990b8_row4_col4, #T_990b8_row4_col5, #T_990b8_row4_col6, #T_990b8_row4_col7, #T_990b8_row4_col8, #T_990b8_row5_col0, #T_990b8_row5_col1, #T_990b8_row5_col2, #T_990b8_row5_col3, #T_990b8_row5_col6, #T_990b8_row5_col7, #T_990b8_row5_col8, #T_990b8_row6_col0, #T_990b8_row6_col1, #T_990b8_row6_col2, #T_990b8_row6_col3, #T_990b8_row6_col5, #T_990b8_row6_col6, #T_990b8_row6_col7, #T_990b8_row6_col8, #T_990b8_row7_col0, #T_990b8_row7_col1, #T_990b8_row7_col2, #T_990b8_row7_col3, #T_990b8_row7_col4, #T_990b8_row7_col5, #T_990b8_row7_col6, #T_990b8_row7_col7, #T_990b8_row7_col8, #T_990b8_row8_col0, #T_990b8_row8_col1, #T_990b8_row8_col2, #T_990b8_row8_col5, #T_990b8_row8_col6, #T_990b8_row8_col7, #T_990b8_row8_col8, #T_990b8_row9_col0, #T_990b8_row9_col1, #T_990b8_row9_col2, #T_990b8_row9_col3, #T_990b8_row9_col4, #T_990b8_row9_col5, #T_990b8_row9_col6, #T_990b8_row9_col7, #T_990b8_row9_col8, #T_990b8_row10_col0, #T_990b8_row10_col1, #T_990b8_row10_col2, #T_990b8_row10_col3, #T_990b8_row10_col4, #T_990b8_row10_col5, #T_990b8_row10_col7, #T_990b8_row10_col8, #T_990b8_row11_col0, #T_990b8_row11_col1, #T_990b8_row11_col2, #T_990b8_row11_col3, #T_990b8_row11_col4, #T_990b8_row11_col6, #T_990b8_row11_col7, #T_990b8_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_990b8_row0_col3, #T_990b8_row2_col5, #T_990b8_row6_col4, #T_990b8_row10_col6, #T_990b8_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_990b8_row2_col6, #T_990b8_row5_col4, #T_990b8_row5_col5, #T_990b8_row8_col3, #T_990b8_row8_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_990b8">
#   <caption>Table: 1.1: City Weather Information from CSV File</caption>
#   <thead>
#     <tr>
#       <th id="T_990b8_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_990b8_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_990b8_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_990b8_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_990b8_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_990b8_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_990b8_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_990b8_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_990b8_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_990b8_row0_col0" class="data row0 col0" >grytviken</td>
#       <td id="T_990b8_row0_col1" class="data row0 col1" >-54.28</td>
#       <td id="T_990b8_row0_col2" class="data row0 col2" >-36.51</td>
#       <td id="T_990b8_row0_col3" class="data row0 col3" >26.80° F</td>
#       <td id="T_990b8_row0_col4" class="data row0 col4" >80%</td>
#       <td id="T_990b8_row0_col5" class="data row0 col5" >53%</td>
#       <td id="T_990b8_row0_col6" class="data row0 col6" >13.51</td>
#       <td id="T_990b8_row0_col7" class="data row0 col7" >GS</td>
#       <td id="T_990b8_row0_col8" class="data row0 col8" >2023-09-18 09:52:20</td>
#     </tr>
#     <tr>
#       <td id="T_990b8_row1_col0" class="data row1 col0" >mansa</td>
#       <td id="T_990b8_row1_col1" class="data row1 col1" >29.98</td>
#       <td id="T_990b8_row1_col2" class="data row1 col2" >75.38</td>
#       <td id="T_990b8_row1_col3" class="data row1 col3" >77.67° F</td>
#       <td id="T_990b8_row1_col4" class="data row1 col4" >88%</td>
#       <td id="T_990b8_row1_col5" class="data row1 col5" >78%</td>
#       <td id="T_990b8_row1_col6" class="data row1 col6" >6.17</td>
#       <td id="T_990b8_row1_col7" class="data row1 col7" >IN</td>
#       <td id="T_990b8_row1_col8" class="data row1 col8" >2023-09-18 10:01:51</td>
#     </tr>
#     <tr>
#       <td id="T_990b8_row2_col0" class="data row2 col0" >toliara</td>
#       <td id="T_990b8_row2_col1" class="data row2 col1" >-23.35</td>
#       <td id="T_990b8_row2_col2" class="data row2 col2" >43.67</td>
#       <td id="T_990b8_row2_col3" class="data row2 col3" >76.57° F</td>
#       <td id="T_990b8_row2_col4" class="data row2 col4" >63%</td>
#       <td id="T_990b8_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_990b8_row2_col6" class="data row2 col6" >20.27</td>
#       <td id="T_990b8_row2_col7" class="data row2 col7" >MG</td>
#       <td id="T_990b8_row2_col8" class="data row2 col8" >2023-09-18 09:53:54</td>
#     </tr>
#     <tr>
#       <td id="T_990b8_row3_col0" class="data row3 col0" >port lincoln</td>
#       <td id="T_990b8_row3_col1" class="data row3 col1" >-34.73</td>
#       <td id="T_990b8_row3_col2" class="data row3 col2" >135.87</td>
#       <td id="T_990b8_row3_col3" class="data row3 col3" >55.18° F</td>
#       <td id="T_990b8_row3_col4" class="data row3 col4" >84%</td>
#       <td id="T_990b8_row3_col5" class="data row3 col5" >87%</td>
#       <td id="T_990b8_row3_col6" class="data row3 col6" >7.47</td>
#       <td id="T_990b8_row3_col7" class="data row3 col7" >AU</td>
#       <td id="T_990b8_row3_col8" class="data row3 col8" >2023-09-18 09:52:29</td>
#     </tr>
#     <tr>
#       <td id="T_990b8_row4_col0" class="data row4 col0" >baikunthpur</td>
#       <td id="T_990b8_row4_col1" class="data row4 col1" >23.25</td>
#       <td id="T_990b8_row4_col2" class="data row4 col2" >82.55</td>
#       <td id="T_990b8_row4_col3" class="data row4 col3" >75.74° F</td>
#       <td id="T_990b8_row4_col4" class="data row4 col4" >85%</td>
#       <td id="T_990b8_row4_col5" class="data row4 col5" >14%</td>
#       <td id="T_990b8_row4_col6" class="data row4 col6" >2.59</td>
#       <td id="T_990b8_row4_col7" class="data row4 col7" >IN</td>
#       <td id="T_990b8_row4_col8" class="data row4 col8" >2023-09-18 10:01:52</td>
#     </tr>
#     <tr>
#       <td id="T_990b8_row5_col0" class="data row5 col0" >bethel</td>
#       <td id="T_990b8_row5_col1" class="data row5 col1" >41.37</td>
#       <td id="T_990b8_row5_col2" class="data row5 col2" >-73.41</td>
#       <td id="T_990b8_row5_col3" class="data row5 col3" >63.66° F</td>
#       <td id="T_990b8_row5_col4" class="data row5 col4" >89%</td>
#       <td id="T_990b8_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_990b8_row5_col6" class="data row5 col6" >3.44</td>
#       <td id="T_990b8_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_990b8_row5_col8" class="data row5 col8" >2023-09-18 09:52:20</td>
#     </tr>
#     <tr>
#       <td id="T_990b8_row6_col0" class="data row6 col0" >puerto natales</td>
#       <td id="T_990b8_row6_col1" class="data row6 col1" >-51.72</td>
#       <td id="T_990b8_row6_col2" class="data row6 col2" >-72.49</td>
#       <td id="T_990b8_row6_col3" class="data row6 col3" >40.23° F</td>
#       <td id="T_990b8_row6_col4" class="data row6 col4" >52%</td>
#       <td id="T_990b8_row6_col5" class="data row6 col5" >36%</td>
#       <td id="T_990b8_row6_col6" class="data row6 col6" >5.91</td>
#       <td id="T_990b8_row6_col7" class="data row6 col7" >CL</td>
#       <td id="T_990b8_row6_col8" class="data row6 col8" >2023-09-18 09:52:21</td>
#     </tr>
#     <tr>
#       <td id="T_990b8_r

# %% [markdown]
# ## **Section 1.2: Scatter Plots w/Regression**

# %% [markdown]
# ### **Temperature Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1: Temperature Vs. Latitude (Scatter Plot)')

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1.1: Temperature Vs. Latitude (Scatter Plot w/Regression)', 
         2, -48.0, 28.0)
# Out:
# r-value:     0.8402
# r-squared:   0.7059

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### Although this assignment is about linear regression, I notice that the independent variable, latitude, has a relationship with the dependent variable, temperature, just not a linear one.  With linear regression, we obtain a -0.1346 correlation; with quadratic regression, the correlation increases to 0.7879.  In practiice, analysts consider a 0.60-0.79 correlation to be strong.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.2.2: Humidity Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Cloudiness Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.2.3: Cloudiness Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.2.4: Wind Speed vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **City Weather Information Correlation Matrix**

# %%
frameDictionary \
    = {'Latitude': 
            cityWeatherDataFrame \
                ['Latitude'], 
       'Temperature': 
            cityWeatherDataFrame \
                ['Temperature'], 
       'Humidity': 
            cityWeatherDataFrame \
                ['Humidity'],
       'Cloudiness': 
            cityWeatherDataFrame \
                ['Cloudiness'],
       'Wind Speed':
            cityWeatherDataFrame \
                ['Wind Speed']}


function \
    .ReturnCorrelationTableStandardFormat \
        (pd \
             .DataFrame \
                 (frameDictionary),
         'Table 1.2.1: City Weather Correlation Matrix')
# Out:
# <style type="text/css">
# #T_b875b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b875b_row0_col0, #T_b875b_row0_col1, #T_b875b_row0_col2, #T_b875b_row0_col3, #T_b875b_row0_col4, #T_b875b_row1_col0, #T_b875b_row1_col1, #T_b875b_row1_col2, #T_b875b_row1_col3, #T_b875b_row1_col4, #T_b875b_row2_col0, #T_b875b_row2_col1, #T_b875b_row2_col2, #T_b875b_row2_col3, #T_b875b_row2_col4, #T_b875b_row3_col0, #T_b875b_row3_col1, #T_b875b_row3_col2, #T_b875b_row3_col3, #T_b875b_row3_col4, #T_b875b_row4_col0, #T_b875b_row4_col1, #T_b875b_row4_col2, #T_b875b_row4_col3, #T_b875b_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_b875b">
#   <caption>Table 1.2.1: City Weather Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b875b_level0_col0" class="col_heading level0 col0" >Latitude</th>
#       <th id="T_b875b_level0_col1" class="col_heading level0 col1" >Temperature</th>
#       <th id="T_b875b_level0_col2" class="col_heading level0 col2" >Humidity</th>
#       <th id="T_b875b_level0_col3" class="col_heading level0 col3" >Cloudiness</th>
#       <th id="T_b875b_level0_col4" class="col_heading level0 col4" >Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b875b_level0_row0" class="row_heading level0 row0" >Latitude</th>
#       <td id="T_b875b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b875b_row0_col1" class="data row0 col1" >-0.304592</td>
#       <td id="T_b875b_row0_col2" class="data row0 col2" >0.065449</td>
#       <td id="T_b875b_row0_col3" class="data row0 col3" >0.105866</td>
#       <td id="T_b875b_row0_col4" class="data row0 col4" >-0.137689</td>
#     </tr>
#     <tr>
#       <th id="T_b875b_level0_row1" class="row_heading level0 row1" >Temperature</th>
#       <td id="T_b875b_row1_col0" class="data row1 col0" >-0.304592</td>
#       <td id="T_b875b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b875b_row1_col2" class="data row1 col2" >-0.349550</td>
#       <td id="T_b875b_row1_col3" class="data row1 col3" >-0.162940</td>
#       <td id="T_b875b_row1_col4" class="data row1 col4" >0.067299</td>
#     </tr>
#     <tr>
#       <th id="T_b875b_level0_row2" class="row_heading level0 row2" >Humidity</th>
#       <td id="T_b875b_row2_col0" class="data row2 col0" >0.065449</td>
#       <td id="T_b875b_row2_col1" class="data row2 col1" >-0.349550</td>
#       <td id="T_b875b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b875b_row2_col3" class="data row2 col3" >0.397287</td>
#       <td id="T_b875b_row2_col4" class="data row2 col4" >-0.081206</td>
#     </tr>
#     <tr>
#       <th id="T_b875b_level0_row3" class="row_heading level0 row3" >Cloudiness</th>
#       <td id="T_b875b_row3_col0" class="data row3 col0" >0.105866</td>
#       <td id="T_b875b_row3_col1" class="data row3 col1" >-0.162940</td>
#       <td id="T_b875b_row3_col2" class="data row3 col2" >0.397287</td>
#       <td id="T_b875b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b875b_row3_col4" class="data row3 col4" >-0.026425</td>
#     </tr>
#     <tr>
#       <th id="T_b875b_level0_row4" class="row_heading level0 row4" >Wind Speed</th>
#       <td id="T_b875b_row4_col0" class="data row4 col0" >-0.137689</td>
#       <td id="T_b875b_row4_col1" class="data row4 col1" >0.067299</td>
#       <td id="T_b875b_row4_col2" class="data row4 col2" >-0.081206</td>
#       <td id="T_b875b_row4_col3" class="data row4 col3" >-0.026425</td>
#       <td id="T_b875b_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Discussion about correlation:** YOUR RESPONSE HERE

# %% [markdown]
# ## **Section 1.3: Hemisphere Scatter Plots with Linear Regression**

# %% [markdown]
# ### **Northern Hemisphere City Weather Information**

# %%
northernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (northernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.1: City Weather Information (Northern Hemisphere)')
# Out:
# <style type="text/css">
# #T_e3482 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_e3482_row0_col0, #T_e3482_row0_col1, #T_e3482_row0_col2, #T_e3482_row0_col3, #T_e3482_row0_col4, #T_e3482_row0_col5, #T_e3482_row0_col6, #T_e3482_row0_col7, #T_e3482_row0_col8, #T_e3482_row1_col0, #T_e3482_row1_col1, #T_e3482_row1_col2, #T_e3482_row1_col3, #T_e3482_row1_col4, #T_e3482_row1_col7, #T_e3482_row1_col8, #T_e3482_row2_col0, #T_e3482_row2_col1, #T_e3482_row2_col2, #T_e3482_row2_col3, #T_e3482_row2_col6, #T_e3482_row2_col7, #T_e3482_row2_col8, #T_e3482_row3_col0, #T_e3482_row3_col1, #T_e3482_row3_col2, #T_e3482_row3_col3, #T_e3482_row3_col4, #T_e3482_row3_col5, #T_e3482_row3_col6, #T_e3482_row3_col7, #T_e3482_row3_col8, #T_e3482_row4_col0, #T_e3482_row4_col1, #T_e3482_row4_col2, #T_e3482_row4_col3, #T_e3482_row4_col5, #T_e3482_row4_col7, #T_e3482_row4_col8, #T_e3482_row5_col0, #T_e3482_row5_col1, #T_e3482_row5_col2, #T_e3482_row5_col3, #T_e3482_row5_col4, #T_e3482_row5_col5, #T_e3482_row5_col6, #T_e3482_row5_col7, #T_e3482_row5_col8, #T_e3482_row6_col0, #T_e3482_row6_col1, #T_e3482_row6_col2, #T_e3482_row6_col5, #T_e3482_row6_col6, #T_e3482_row6_col7, #T_e3482_row6_col8, #T_e3482_row7_col0, #T_e3482_row7_col1, #T_e3482_row7_col2, #T_e3482_row7_col3, #T_e3482_row7_col4, #T_e3482_row7_col5, #T_e3482_row7_col6, #T_e3482_row7_col7, #T_e3482_row7_col8, #T_e3482_row8_col0, #T_e3482_row8_col1, #T_e3482_row8_col2, #T_e3482_row8_col3, #T_e3482_row8_col4, #T_e3482_row8_col6, #T_e3482_row8_col7, #T_e3482_row8_col8, #T_e3482_row9_col0, #T_e3482_row9_col1, #T_e3482_row9_col2, #T_e3482_row9_col3, #T_e3482_row9_col4, #T_e3482_row9_col5, #T_e3482_row9_col6, #T_e3482_row9_col7, #T_e3482_row9_col8, #T_e3482_row10_col0, #T_e3482_row10_col1, #T_e3482_row10_col2, #T_e3482_row10_col3, #T_e3482_row10_col4, #T_e3482_row10_col5, #T_e3482_row10_col6, #T_e3482_row10_col7, #T_e3482_row10_col8, #T_e3482_row11_col0, #T_e3482_row11_col1, #T_e3482_row11_col2, #T_e3482_row11_col4, #T_e3482_row11_col5, #T_e3482_row11_col6, #T_e3482_row11_col7, #T_e3482_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_e3482_row1_col5, #T_e3482_row1_col6, #T_e3482_row6_col4, #T_e3482_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_e3482_row2_col4, #T_e3482_row2_col5, #T_e3482_row4_col4, #T_e3482_row4_col6, #T_e3482_row6_col3, #T_e3482_row8_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_e3482">
#   <caption>Table: 1.3.1: City Weather Information (Northern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_e3482_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_e3482_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_e3482_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_e3482_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_e3482_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_e3482_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_e3482_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_e3482_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_e3482_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e3482_row0_col0" class="data row0 col0" >mansa</td>
#       <td id="T_e3482_row0_col1" class="data row0 col1" >29.98</td>
#       <td id="T_e3482_row0_col2" class="data row0 col2" >75.38</td>
#       <td id="T_e3482_row0_col3" class="data row0 col3" >77.67° F</td>
#       <td id="T_e3482_row0_col4" class="data row0 col4" >88%</td>
#       <td id="T_e3482_row0_col5" class="data row0 col5" >78%</td>
#       <td id="T_e3482_row0_col6" class="data row0 col6" >6.17</td>
#       <td id="T_e3482_row0_col7" class="data row0 col7" >IN</td>
#       <td id="T_e3482_row0_col8" class="data row0 col8" >2023-09-18 10:01:51</td>
#     </tr>
#     <tr>
#       <td id="T_e3482_row1_col0" class="data row1 col0" >baikunthpur</td>
#       <td id="T_e3482_row1_col1" class="data row1 col1" >23.25</td>
#       <td id="T_e3482_row1_col2" class="data row1 col2" >82.55</td>
#       <td id="T_e3482_row1_col3" class="data row1 col3" >75.74° F</td>
#       <td id="T_e3482_row1_col4" class="data row1 col4" >85%</td>
#       <td id="T_e3482_row1_col5" class="data row1 col5" >14%</td>
#       <td id="T_e3482_row1_col6" class="data row1 col6" >2.59</td>
#       <td id="T_e3482_row1_col7" class="data row1 col7" >IN</td>
#       <td id="T_e3482_row1_col8" class="data row1 col8" >2023-09-18 10:01:52</td>
#     </tr>
#     <tr>
#       <td id="T_e3482_row2_col0" class="data row2 col0" >bethel</td>
#       <td id="T_e3482_row2_col1" class="data row2 col1" >41.37</td>
#       <td id="T_e3482_row2_col2" class="data row2 col2" >-73.41</td>
#       <td id="T_e3482_row2_col3" class="data row2 col3" >63.66° F</td>
#       <td id="T_e3482_row2_col4" class="data row2 col4" >89%</td>
#       <td id="T_e3482_row2_col5" class="data row2 col5" >100%</td>
#       <td id="T_e3482_row2_col6" class="data row2 col6" >3.44</td>
#       <td id="T_e3482_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_e3482_row2_col8" class="data row2 col8" >2023-09-18 09:52:20</td>
#     </tr>
#     <tr>
#       <td id="T_e3482_row3_col0" class="data row3 col0" >whitehorse</td>
#       <td id="T_e3482_row3_col1" class="data row3 col1" >60.72</td>
#       <td id="T_e3482_row3_col2" class="data row3 col2" >-135.05</td>
#       <td id="T_e3482_row3_col3" class="data row3 col3" >40.64° F</td>
#       <td id="T_e3482_row3_col4" class="data row3 col4" >86%</td>
#       <td id="T_e3482_row3_col5" class="data row3 col5" >75%</td>
#       <td id="T_e3482_row3_col6" class="data row3 col6" >3.44</td>
#       <td id="T_e3482_row3_col7" class="data row3 col7" >CA</td>
#       <td id="T_e3482_row3_col8" class="data row3 col8" >2023-09-18 09:52:28</td>
#     </tr>
#     <tr>
#       <td id="T_e3482_row4_col0" class="data row4 col0" >saipan</td>
#       <td id="T_e3482_row4_col1" class="data row4 col1" >15.14</td>
#       <td id="T_e3482_row4_col2" class="data row4 col2" >145.70</td>
#       <td id="T_e3482_row4_col3" class="data row4 col3" >83.10° F</td>
#       <td id="T_e3482_row4_col4" class="data row4 col4" >89%</td>
#       <td id="T_e3482_row4_col5" class="data row4 col5" >40%</td>
#       <td id="T_e3482_row4_col6" class="data row4 col6" >16.11</td>
#       <td id="T_e3482_row4_col7" class="data row4 col7" >MP</td>
#       <td id="T_e3482_row4_col8" class="data row4 col8" >2023-09-18 09:52:31</td>
#     </tr>
#     <tr>
#       <td id="T_e3482_row5_col0" class="data row5 col0" >sarangani</td>
#       <td id="T_e3482_row5_col1" class="data row5 col1" >5.40</td>
#       <td id="T_e3482_row5_col2" class="data row5 col2" >125.46</td>
#       <td id="T_e3482_row5_col3" class="data row5 col3" >80.74° F</td>
#       <td id="T_e3482_row5_col4" class="data row5 col4" >76%</td>
#       <td id="T_e3482_row5_col5" class="data row5 col5" >68%</td>
#       <td id="T_e3482_row5_col6" class="data row5 col6" >3.87</td>
#       <td id="T_e3482_row5_col7" class="data row5 col7" >PH</td>
#       <td id="T_e3482_row5_col8" class="data row5 col8" >2023-09-18 10:01:54</td>
#     </tr>
#     <tr>
#       <td id="T_e3482_row6_col0" class="data row6 col0" >remire-montjoly</td>
#       <td id="T_e3482_row6_col1" class="data row6 col1" >4.92</td>
#       <td id="T_e3482_row6_col2" class="data row6 col2" >-52.27</td>
#       <td id="T_e3482_row6_col3" class="data row6 col3" >91.44° F</td>
#       <td id="T_e3482_row6_col4" class="data row6 col4" >58%</td>
#       <td id="T_e3482_row6_col5" class="data row6 col5" >40%</td>
#       <td id="T_e3482_row6_col6" class="data row6 col6" >12.66</td>
#       <td id="T_e3482_row6_col7" class="data row6 col7" >GF</td>
#       <td id="T_e3482_row6_col8" class="data row6 col8" >2023-09-18 09:52:48</td>
#     </tr>
#     <tr>
#       <td id="T_e3

# %% [markdown]
# ### **Southern Hemisphere City Weather Information**

# %%
southernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (southernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.2: City Weather Information (Southern Hemisphere)')
# Out:
# <style type="text/css">
# #T_31131 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_31131_row0_col0, #T_31131_row0_col1, #T_31131_row0_col2, #T_31131_row0_col3, #T_31131_row0_col4, #T_31131_row0_col5, #T_31131_row0_col6, #T_31131_row0_col7, #T_31131_row0_col8, #T_31131_row1_col0, #T_31131_row1_col1, #T_31131_row1_col2, #T_31131_row1_col3, #T_31131_row1_col4, #T_31131_row1_col7, #T_31131_row1_col8, #T_31131_row2_col0, #T_31131_row2_col1, #T_31131_row2_col2, #T_31131_row2_col3, #T_31131_row2_col6, #T_31131_row2_col7, #T_31131_row2_col8, #T_31131_row3_col0, #T_31131_row3_col1, #T_31131_row3_col2, #T_31131_row3_col3, #T_31131_row3_col4, #T_31131_row3_col5, #T_31131_row3_col6, #T_31131_row3_col7, #T_31131_row3_col8, #T_31131_row4_col0, #T_31131_row4_col1, #T_31131_row4_col2, #T_31131_row4_col3, #T_31131_row4_col5, #T_31131_row4_col7, #T_31131_row4_col8, #T_31131_row5_col0, #T_31131_row5_col1, #T_31131_row5_col2, #T_31131_row5_col3, #T_31131_row5_col4, #T_31131_row5_col5, #T_31131_row5_col6, #T_31131_row5_col7, #T_31131_row5_col8, #T_31131_row6_col0, #T_31131_row6_col1, #T_31131_row6_col2, #T_31131_row6_col5, #T_31131_row6_col6, #T_31131_row6_col7, #T_31131_row6_col8, #T_31131_row7_col0, #T_31131_row7_col1, #T_31131_row7_col2, #T_31131_row7_col3, #T_31131_row7_col4, #T_31131_row7_col5, #T_31131_row7_col6, #T_31131_row7_col7, #T_31131_row7_col8, #T_31131_row8_col0, #T_31131_row8_col1, #T_31131_row8_col2, #T_31131_row8_col3, #T_31131_row8_col4, #T_31131_row8_col6, #T_31131_row8_col7, #T_31131_row8_col8, #T_31131_row9_col0, #T_31131_row9_col1, #T_31131_row9_col2, #T_31131_row9_col3, #T_31131_row9_col4, #T_31131_row9_col5, #T_31131_row9_col6, #T_31131_row9_col7, #T_31131_row9_col8, #T_31131_row10_col0, #T_31131_row10_col1, #T_31131_row10_col2, #T_31131_row10_col3, #T_31131_row10_col4, #T_31131_row10_col5, #T_31131_row10_col6, #T_31131_row10_col7, #T_31131_row10_col8, #T_31131_row11_col0, #T_31131_row11_col1, #T_31131_row11_col2, #T_31131_row11_col4, #T_31131_row11_col5, #T_31131_row11_col6, #T_31131_row11_col7, #T_31131_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_31131_row1_col5, #T_31131_row1_col6, #T_31131_row6_col4, #T_31131_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_31131_row2_col4, #T_31131_row2_col5, #T_31131_row4_col4, #T_31131_row4_col6, #T_31131_row6_col3, #T_31131_row8_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_31131">
#   <caption>Table: 1.3.2: City Weather Information (Southern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_31131_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_31131_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_31131_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_31131_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_31131_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_31131_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_31131_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_31131_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_31131_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_31131_row0_col0" class="data row0 col0" >mansa</td>
#       <td id="T_31131_row0_col1" class="data row0 col1" >29.98</td>
#       <td id="T_31131_row0_col2" class="data row0 col2" >75.38</td>
#       <td id="T_31131_row0_col3" class="data row0 col3" >77.67° F</td>
#       <td id="T_31131_row0_col4" class="data row0 col4" >88%</td>
#       <td id="T_31131_row0_col5" class="data row0 col5" >78%</td>
#       <td id="T_31131_row0_col6" class="data row0 col6" >6.17</td>
#       <td id="T_31131_row0_col7" class="data row0 col7" >IN</td>
#       <td id="T_31131_row0_col8" class="data row0 col8" >2023-09-18 10:01:51</td>
#     </tr>
#     <tr>
#       <td id="T_31131_row1_col0" class="data row1 col0" >baikunthpur</td>
#       <td id="T_31131_row1_col1" class="data row1 col1" >23.25</td>
#       <td id="T_31131_row1_col2" class="data row1 col2" >82.55</td>
#       <td id="T_31131_row1_col3" class="data row1 col3" >75.74° F</td>
#       <td id="T_31131_row1_col4" class="data row1 col4" >85%</td>
#       <td id="T_31131_row1_col5" class="data row1 col5" >14%</td>
#       <td id="T_31131_row1_col6" class="data row1 col6" >2.59</td>
#       <td id="T_31131_row1_col7" class="data row1 col7" >IN</td>
#       <td id="T_31131_row1_col8" class="data row1 col8" >2023-09-18 10:01:52</td>
#     </tr>
#     <tr>
#       <td id="T_31131_row2_col0" class="data row2 col0" >bethel</td>
#       <td id="T_31131_row2_col1" class="data row2 col1" >41.37</td>
#       <td id="T_31131_row2_col2" class="data row2 col2" >-73.41</td>
#       <td id="T_31131_row2_col3" class="data row2 col3" >63.66° F</td>
#       <td id="T_31131_row2_col4" class="data row2 col4" >89%</td>
#       <td id="T_31131_row2_col5" class="data row2 col5" >100%</td>
#       <td id="T_31131_row2_col6" class="data row2 col6" >3.44</td>
#       <td id="T_31131_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_31131_row2_col8" class="data row2 col8" >2023-09-18 09:52:20</td>
#     </tr>
#     <tr>
#       <td id="T_31131_row3_col0" class="data row3 col0" >whitehorse</td>
#       <td id="T_31131_row3_col1" class="data row3 col1" >60.72</td>
#       <td id="T_31131_row3_col2" class="data row3 col2" >-135.05</td>
#       <td id="T_31131_row3_col3" class="data row3 col3" >40.64° F</td>
#       <td id="T_31131_row3_col4" class="data row3 col4" >86%</td>
#       <td id="T_31131_row3_col5" class="data row3 col5" >75%</td>
#       <td id="T_31131_row3_col6" class="data row3 col6" >3.44</td>
#       <td id="T_31131_row3_col7" class="data row3 col7" >CA</td>
#       <td id="T_31131_row3_col8" class="data row3 col8" >2023-09-18 09:52:28</td>
#     </tr>
#     <tr>
#       <td id="T_31131_row4_col0" class="data row4 col0" >saipan</td>
#       <td id="T_31131_row4_col1" class="data row4 col1" >15.14</td>
#       <td id="T_31131_row4_col2" class="data row4 col2" >145.70</td>
#       <td id="T_31131_row4_col3" class="data row4 col3" >83.10° F</td>
#       <td id="T_31131_row4_col4" class="data row4 col4" >89%</td>
#       <td id="T_31131_row4_col5" class="data row4 col5" >40%</td>
#       <td id="T_31131_row4_col6" class="data row4 col6" >16.11</td>
#       <td id="T_31131_row4_col7" class="data row4 col7" >MP</td>
#       <td id="T_31131_row4_col8" class="data row4 col8" >2023-09-18 09:52:31</td>
#     </tr>
#     <tr>
#       <td id="T_31131_row5_col0" class="data row5 col0" >sarangani</td>
#       <td id="T_31131_row5_col1" class="data row5 col1" >5.40</td>
#       <td id="T_31131_row5_col2" class="data row5 col2" >125.46</td>
#       <td id="T_31131_row5_col3" class="data row5 col3" >80.74° F</td>
#       <td id="T_31131_row5_col4" class="data row5 col4" >76%</td>
#       <td id="T_31131_row5_col5" class="data row5 col5" >68%</td>
#       <td id="T_31131_row5_col6" class="data row5 col6" >3.87</td>
#       <td id="T_31131_row5_col7" class="data row5 col7" >PH</td>
#       <td id="T_31131_row5_col8" class="data row5 col8" >2023-09-18 10:01:54</td>
#     </tr>
#     <tr>
#       <td id="T_31131_row6_col0" class="data row6 col0" >remire-montjoly</td>
#       <td id="T_31131_row6_col1" class="data row6 col1" >4.92</td>
#       <td id="T_31131_row6_col2" class="data row6 col2" >-52.27</td>
#       <td id="T_31131_row6_col3" class="data row6 col3" >91.44° F</td>
#       <td id="T_31131_row6_col4" class="data row6 col4" >58%</td>
#       <td id="T_31131_row6_col5" class="data row6 col5" >40%</td>
#       <td id="T_31131_row6_col6" class="data row6 col6" >12.66</td>
#       <td id="T_31131_row6_col7" class="data row6 col7" >GF</td>
#       <td id="T_31131_row6_col8" class="data row6 col8" >2023-09-18 09:52:48</td>
#     </tr>
#     <tr>
#       <td id="T_31

# %% [markdown]
# ### **Temperature vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.1: Temperature vs. Latitude (Northern Hemisphere)',
         1, 2.0, 45.0)
# Out:
# r-value:     -0.8009
# r-squared:   0.6415

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.2: Temperature vs. Latitude (Southern Hemisphere)',
         1, -55.0, 85.0)
# Out:
# r-value:     0.7936
# r-squared:   0.6297

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### From the results of the linear regression, in the northern hemisphere, the latitude is negatively correlated with temperature; this negative correlation tells us that the two variables move in opposite directions: as latitude increases, the temperature drops, and vice versa.  In the southern hemisphers, the latitude is positively correlated with temperature: this positive correlation tells us that the two variables move in the same direction: as latitude increases, the temperature increases.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.3: Humidity vs. Latitude (Northern Hemisphere)',
         1, 45.0, 18.0)
# Out:
# r-value:     -0.0027
# r-squared:   0.0000

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.4: Humidity vs. Latitude (Southern Hemisphere)',
         1, -55.0, 18.0)
# Out:
# r-value:     -0.0665
# r-squared:   0.0044

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and humidity in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Cloudiness vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.5: Cloudiness vs. Latitude (Northern Hemisphere)',
         1, 16.0, 62.0)
# Out:
# r-value:     -0.0374
# r-squared:   0.0014

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.6: Cloudiness vs. Latitude (Southern Hemisphere)',
         1, -48.0, 30.0)
# Out:
# r-value:     0.0388
# r-squared:   0.0015

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and cloudiness in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.7: Wind Speed vs. Latitude (Northern Hemisphere)',
         1, 15.0, 22.0)
# Out:
# r-value:     0.0370
# r-squared:   0.0014

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.8: Wind Speed vs. Latitude (Southern Hemisphere)',
         1, -55.0, 22.0)
# Out:
# r-value:     -0.0513
# r-squared:   0.0026

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and wind speed in either hemisphere.

# %%
#log_subroutine \
#    .EndProgramExecution()
