# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_eb91f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_eb91f_row0_col0, #T_eb91f_row0_col1, #T_eb91f_row0_col2, #T_eb91f_row0_col3, #T_eb91f_row0_col5, #T_eb91f_row0_col6, #T_eb91f_row0_col7, #T_eb91f_row0_col8, #T_eb91f_row1_col0, #T_eb91f_row1_col1, #T_eb91f_row1_col2, #T_eb91f_row1_col3, #T_eb91f_row1_col4, #T_eb91f_row1_col5, #T_eb91f_row1_col6, #T_eb91f_row1_col7, #T_eb91f_row1_col8, #T_eb91f_row2_col0, #T_eb91f_row2_col1, #T_eb91f_row2_col2, #T_eb91f_row2_col3, #T_eb91f_row2_col4, #T_eb91f_row2_col6, #T_eb91f_row2_col7, #T_eb91f_row2_col8, #T_eb91f_row3_col0, #T_eb91f_row3_col1, #T_eb91f_row3_col2, #T_eb91f_row3_col3, #T_eb91f_row3_col4, #T_eb91f_row3_col5, #T_eb91f_row3_col6, #T_eb91f_row3_col7, #T_eb91f_row3_col8, #T_eb91f_row4_col0, #T_eb91f_row4_col1, #T_eb91f_row4_col2, #T_eb91f_row4_col3, #T_eb91f_row4_col4, #T_eb91f_row4_col6, #T_eb91f_row4_col7, #T_eb91f_row4_col8, #T_eb91f_row5_col0, #T_eb91f_row5_col1, #T_eb91f_row5_col2, #T_eb91f_row5_col3, #T_eb91f_row5_col4, #T_eb91f_row5_col5, #T_eb91f_row5_col6, #T_eb91f_row5_col7, #T_eb91f_row5_col8, #T_eb91f_row6_col0, #T_eb91f_row6_col1, #T_eb91f_row6_col2, #T_eb91f_row6_col3, #T_eb91f_row6_col4, #T_eb91f_row6_col5, #T_eb91f_row6_col7, #T_eb91f_row6_col8, #T_eb91f_row7_col0, #T_eb91f_row7_col1, #T_eb91f_row7_col2, #T_eb91f_row7_col4, #T_eb91f_row7_col7, #T_eb91f_row7_col8, #T_eb91f_row8_col0, #T_eb91f_row8_col1, #T_eb91f_row8_col2, #T_eb91f_row8_col3, #T_eb91f_row8_col4, #T_eb91f_row8_col5, #T_eb91f_row8_col6, #T_eb91f_row8_col7, #T_eb91f_row8_col8, #T_eb91f_row9_col0, #T_eb91f_row9_col1, #T_eb91f_row9_col2, #T_eb91f_row9_col4, #T_eb91f_row9_col6, #T_eb91f_row9_col7, #T_eb91f_row9_col8, #T_eb91f_row10_col0, #T_eb91f_row10_col1, #T_eb91f_row10_col2, #T_eb91f_row10_col3, #T_eb91f_row10_col4, #T_eb91f_row10_col5, #T_eb91f_row10_col6, #T_eb91f_row10_col7, #T_eb91f_row10_col8, #T_eb91f_row11_col0, #T_eb91f_row11_col1, #T_eb91f_row11_col2, #T_eb91f_row11_col3, #T_eb91f_row11_col6, #T_eb91f_row11_col7, #T_eb91f_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_eb91f_row0_col4, #T_eb91f_row4_col5, #T_eb91f_row6_col6, #T_eb91f_row7_col3, #T_eb91f_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_eb91f_row2_col5, #T_eb91f_row7_col5, #T_eb91f_row7_col6, #T_eb91f_row9_col3, #T_eb91f_row11_col4, #T_eb91f_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_eb91f">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_eb91f_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_eb91f_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_eb91f_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_eb91f_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_eb91f_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_eb91f_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_eb91f_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_eb91f_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_eb91f_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eb91f_row0_col0" class="data row0 col0" >mount isa</td>
#       <td id="T_eb91f_row0_col1" class="data row0 col1" >-20.73</td>
#       <td id="T_eb91f_row0_col2" class="data row0 col2" >139.50</td>
#       <td id="T_eb91f_row0_col3" class="data row0 col3" >71.37° F</td>
#       <td id="T_eb91f_row0_col4" class="data row0 col4" >23%</td>
#       <td id="T_eb91f_row0_col5" class="data row0 col5" >2%</td>
#       <td id="T_eb91f_row0_col6" class="data row0 col6" >18.41</td>
#       <td id="T_eb91f_row0_col7" class="data row0 col7" >AU</td>
#       <td id="T_eb91f_row0_col8" class="data row0 col8" >2023-09-07 17:17:09</td>
#     </tr>
#     <tr>
#       <td id="T_eb91f_row1_col0" class="data row1 col0" >adamstown</td>
#       <td id="T_eb91f_row1_col1" class="data row1 col1" >-25.07</td>
#       <td id="T_eb91f_row1_col2" class="data row1 col2" >-130.10</td>
#       <td id="T_eb91f_row1_col3" class="data row1 col3" >65.75° F</td>
#       <td id="T_eb91f_row1_col4" class="data row1 col4" >73%</td>
#       <td id="T_eb91f_row1_col5" class="data row1 col5" >92%</td>
#       <td id="T_eb91f_row1_col6" class="data row1 col6" >17.58</td>
#       <td id="T_eb91f_row1_col7" class="data row1 col7" >PN</td>
#       <td id="T_eb91f_row1_col8" class="data row1 col8" >2023-09-07 17:17:09</td>
#     </tr>
#     <tr>
#       <td id="T_eb91f_row2_col0" class="data row2 col0" >cabo san lucas</td>
#       <td id="T_eb91f_row2_col1" class="data row2 col1" >22.89</td>
#       <td id="T_eb91f_row2_col2" class="data row2 col2" >-109.91</td>
#       <td id="T_eb91f_row2_col3" class="data row2 col3" >83.39° F</td>
#       <td id="T_eb91f_row2_col4" class="data row2 col4" >84%</td>
#       <td id="T_eb91f_row2_col5" class="data row2 col5" >100%</td>
#       <td id="T_eb91f_row2_col6" class="data row2 col6" >8.05</td>
#       <td id="T_eb91f_row2_col7" class="data row2 col7" >MX</td>
#       <td id="T_eb91f_row2_col8" class="data row2 col8" >2023-09-07 17:15:54</td>
#     </tr>
#     <tr>
#       <td id="T_eb91f_row3_col0" class="data row3 col0" >blackmans bay</td>
#       <td id="T_eb91f_row3_col1" class="data row3 col1" >-43.02</td>
#       <td id="T_eb91f_row3_col2" class="data row3 col2" >147.32</td>
#       <td id="T_eb91f_row3_col3" class="data row3 col3" >58.69° F</td>
#       <td id="T_eb91f_row3_col4" class="data row3 col4" >48%</td>
#       <td id="T_eb91f_row3_col5" class="data row3 col5" >4%</td>
#       <td id="T_eb91f_row3_col6" class="data row3 col6" >7.92</td>
#       <td id="T_eb91f_row3_col7" class="data row3 col7" >AU</td>
#       <td id="T_eb91f_row3_col8" class="data row3 col8" >2023-09-07 17:17:09</td>
#     </tr>
#     <tr>
#       <td id="T_eb91f_row4_col0" class="data row4 col0" >lucheng</td>
#       <td id="T_eb91f_row4_col1" class="data row4 col1" >31.23</td>
#       <td id="T_eb91f_row4_col2" class="data row4 col2" >117.28</td>
#       <td id="T_eb91f_row4_col3" class="data row4 col3" >76.60° F</td>
#       <td id="T_eb91f_row4_col4" class="data row4 col4" >84%</td>
#       <td id="T_eb91f_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_eb91f_row4_col6" class="data row4 col6" >8.19</td>
#       <td id="T_eb91f_row4_col7" class="data row4 col7" >CN</td>
#       <td id="T_eb91f_row4_col8" class="data row4 col8" >2023-09-07 17:17:09</td>
#     </tr>
#     <tr>
#       <td id="T_eb91f_row5_col0" class="data row5 col0" >fale old settlement</td>
#       <td id="T_eb91f_row5_col1" class="data row5 col1" >-9.39</td>
#       <td id="T_eb91f_row5_col2" class="data row5 col2" >-171.25</td>
#       <td id="T_eb91f_row5_col3" class="data row5 col3" >82.98° F</td>
#       <td id="T_eb91f_row5_col4" class="data row5 col4" >72%</td>
#       <td id="T_eb91f_row5_col5" class="data row5 col5" >67%</td>
#       <td id="T_eb91f_row5_col6" class="data row5 col6" >10.54</td>
#       <td id="T_eb91f_row5_col7" class="data row5 col7" >TK</td>
#       <td id="T_eb91f_row5_col8" class="data row5 col8" >2023-09-07 17:17:10</td>
#     </tr>
#     <tr>
#       <td id="T_eb91f_row6_col0" class="data row6 col0" >gebeit</td>
#       <td id="T_eb91f_row6_col1" class="data row6 col1" >21.07</td>
#       <td id="T_eb91f_row6_col2" class="data row6 col2" >36.32</td>
#       <td id="T_eb91f_row6_col3" class="data row6 col3" >85.32° F</td>
#       <td id="T_eb91f_row6_col4" class="data row6 col4" >26%</td>
#       <td id="T_eb91f_row6_col5" class="data row6 col5" >6%</td>
#       <td id="T_eb91f_row6_col6" class="data row6 col6" >4.27</td>
#       <td id="T_eb91f_row6_col7" class="data row6 col7" >SD</td>
#       <td id="T_eb91f_row6_col8" class="data row6 col8" >2023-09-07 17:17:10</td>
#     </tr>
#     <tr>
#       <td id="T_eb91f_

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 35) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 75), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 5), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_59374 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_59374_row0_col0, #T_59374_row0_col1, #T_59374_row0_col2, #T_59374_row0_col3, #T_59374_row0_col4, #T_59374_row0_col6, #T_59374_row0_col7, #T_59374_row0_col8, #T_59374_row1_col0, #T_59374_row1_col1, #T_59374_row1_col2, #T_59374_row1_col3, #T_59374_row1_col4, #T_59374_row1_col6, #T_59374_row1_col7, #T_59374_row1_col8, #T_59374_row2_col0, #T_59374_row2_col1, #T_59374_row2_col2, #T_59374_row2_col3, #T_59374_row2_col4, #T_59374_row2_col6, #T_59374_row2_col7, #T_59374_row2_col8, #T_59374_row3_col0, #T_59374_row3_col1, #T_59374_row3_col2, #T_59374_row3_col6, #T_59374_row3_col7, #T_59374_row3_col8, #T_59374_row4_col0, #T_59374_row4_col1, #T_59374_row4_col2, #T_59374_row4_col3, #T_59374_row4_col4, #T_59374_row4_col6, #T_59374_row4_col7, #T_59374_row4_col8, #T_59374_row5_col0, #T_59374_row5_col1, #T_59374_row5_col2, #T_59374_row5_col3, #T_59374_row5_col4, #T_59374_row5_col7, #T_59374_row5_col8, #T_59374_row6_col0, #T_59374_row6_col1, #T_59374_row6_col2, #T_59374_row6_col3, #T_59374_row6_col4, #T_59374_row6_col6, #T_59374_row6_col7, #T_59374_row6_col8, #T_59374_row7_col0, #T_59374_row7_col1, #T_59374_row7_col2, #T_59374_row7_col3, #T_59374_row7_col4, #T_59374_row7_col6, #T_59374_row7_col7, #T_59374_row7_col8, #T_59374_row8_col0, #T_59374_row8_col1, #T_59374_row8_col2, #T_59374_row8_col4, #T_59374_row8_col6, #T_59374_row8_col7, #T_59374_row8_col8, #T_59374_row9_col0, #T_59374_row9_col1, #T_59374_row9_col2, #T_59374_row9_col3, #T_59374_row9_col4, #T_59374_row9_col6, #T_59374_row9_col7, #T_59374_row9_col8, #T_59374_row10_col0, #T_59374_row10_col1, #T_59374_row10_col2, #T_59374_row10_col3, #T_59374_row10_col6, #T_59374_row10_col7, #T_59374_row10_col8, #T_59374_row11_col0, #T_59374_row11_col1, #T_59374_row11_col2, #T_59374_row11_col3, #T_59374_row11_col4, #T_59374_row11_col5, #T_59374_row11_col6, #T_59374_row11_col7, #T_59374_row11_col8, #T_59374_row12_col0, #T_59374_row12_col1, #T_59374_row12_col2, #T_59374_row12_col3, #T_59374_row12_col4, #T_59374_row12_col7, #T_59374_row12_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_59374_row0_col5, #T_59374_row1_col5, #T_59374_row3_col3, #T_59374_row3_col5, #T_59374_row4_col5, #T_59374_row5_col5, #T_59374_row6_col5, #T_59374_row7_col5, #T_59374_row8_col5, #T_59374_row9_col5, #T_59374_row10_col4, #T_59374_row12_col5, #T_59374_row12_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_59374_row2_col5, #T_59374_row3_col4, #T_59374_row5_col6, #T_59374_row8_col3, #T_59374_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_59374">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_59374_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_59374_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_59374_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_59374_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_59374_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_59374_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_59374_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_59374_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_59374_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_59374_row0_col0" class="data row0 col0" >longboat key</td>
#       <td id="T_59374_row0_col1" class="data row0 col1" >27.41</td>
#       <td id="T_59374_row0_col2" class="data row0 col2" >-82.66</td>
#       <td id="T_59374_row0_col3" class="data row0 col3" >84.49° F</td>
#       <td id="T_59374_row0_col4" class="data row0 col4" >59%</td>
#       <td id="T_59374_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_59374_row0_col6" class="data row0 col6" >6.91</td>
#       <td id="T_59374_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_59374_row0_col8" class="data row0 col8" >2023-09-07 17:17:25</td>
#     </tr>
#     <tr>
#       <td id="T_59374_row1_col0" class="data row1 col0" >palmas</td>
#       <td id="T_59374_row1_col1" class="data row1 col1" >-10.21</td>
#       <td id="T_59374_row1_col2" class="data row1 col2" >-48.36</td>
#       <td id="T_59374_row1_col3" class="data row1 col3" >84.07° F</td>
#       <td id="T_59374_row1_col4" class="data row1 col4" >51%</td>
#       <td id="T_59374_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_59374_row1_col6" class="data row1 col6" >5.75</td>
#       <td id="T_59374_row1_col7" class="data row1 col7" >BR</td>
#       <td id="T_59374_row1_col8" class="data row1 col8" >2023-09-07 17:17:42</td>
#     </tr>
#     <tr>
#       <td id="T_59374_row2_col0" class="data row2 col0" >camalu</td>
#       <td id="T_59374_row2_col1" class="data row2 col1" >30.85</td>
#       <td id="T_59374_row2_col2" class="data row2 col2" >-116.07</td>
#       <td id="T_59374_row2_col3" class="data row2 col3" >76.44° F</td>
#       <td id="T_59374_row2_col4" class="data row2 col4" >64%</td>
#       <td id="T_59374_row2_col5" class="data row2 col5" >3%</td>
#       <td id="T_59374_row2_col6" class="data row2 col6" >8.66</td>
#       <td id="T_59374_row2_col7" class="data row2 col7" >MX</td>
#       <td id="T_59374_row2_col8" class="data row2 col8" >2023-09-07 17:17:46</td>
#     </tr>
#     <tr>
#       <td id="T_59374_row3_col0" class="data row3 col0" >yunyang</td>
#       <td id="T_59374_row3_col1" class="data row3 col1" >33.45</td>
#       <td id="T_59374_row3_col2" class="data row3 col2" >112.71</td>
#       <td id="T_59374_row3_col3" class="data row3 col3" >76.21° F</td>
#       <td id="T_59374_row3_col4" class="data row3 col4" >72%</td>
#       <td id="T_59374_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_59374_row3_col6" class="data row3 col6" >3.49</td>
#       <td id="T_59374_row3_col7" class="data row3 col7" >CN</td>
#       <td id="T_59374_row3_col8" class="data row3 col8" >2023-09-07 17:18:00</td>
#     </tr>
#     <tr>
#       <td id="T_59374_row4_col0" class="data row4 col0" >commerce</td>
#       <td id="T_59374_row4_col1" class="data row4 col1" >34.00</td>
#       <td id="T_59374_row4_col2" class="data row4 col2" >-118.16</td>
#       <td id="T_59374_row4_col3" class="data row4 col3" >81.39° F</td>
#       <td id="T_59374_row4_col4" class="data row4 col4" >58%</td>
#       <td id="T_59374_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_59374_row4_col6" class="data row4 col6" >8.05</td>
#       <td id="T_59374_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_59374_row4_col8" class="data row4 col8" >2023-09-07 17:18:05</td>
#     </tr>
#     <tr>
#       <td id="T_59374_row5_col0" class="data row5 col0" >mersa matruh</td>
#       <td id="T_59374_row5_col1" class="data row5 col1" >31.35</td>
#       <td id="T_59374_row5_col2" class="data row5 col2" >27.25</td>
#       <td id="T_59374_row5_col3" class="data row5 col3" >80.87° F</td>
#       <td id="T_59374_row5_col4" class="data row5 col4" >66%</td>
#       <td id="T_59374_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_59374_row5_col6" class="data row5 col6" >9.84</td>
#       <td id="T_59374_row5_col7" class="data row5 col7" >EG</td>
#       <td id="T_59374_row5_col8" class="data row5 col8" >2023-09-07 17:18:12</td>
#     </tr>
#     <tr>
#       <td id="T_59374_row6_col0" class="data row6 col0" >lefka</td>
#       <td id="T_59374_row6_col1" class="data row6 col1" >35.11</td>
#       <td id="T_59374_row6_col2" class="data row6 col2" >32.85</td>
#       <td id="T_59374_row6_col3" class="data row6 col3" >77.61° F</td>
#       <td id="T_59374_row6_col4" class="data row6 col4" >50%</td>
#       <td id="T_59374_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_59374_row6_col6" class="data row6 col6" >3.18</td>
#       <td id="T_59374_row6_col7

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Zota Beach Resort in longboat key, US
#
#
# Located the following hotel...Hotel Triângulo Mineiro in palmas, BR
#
#
# Located the following hotel...Margaritaville in camalu, MX
#
#
# Located the following hotel...Doubletree Hotel in commerce, US
#
#
# Located the following hotel...صقور in mersa matruh, EG
#
#
# Located the following hotel...Aphrodite in lefka, CY
#
#
# Located the following hotel...Italian Inn Hotel in khalabat, PK
#
#
# Located the following hotel...Airborne Inn Lodging in fort bragg, US
#
#
# Located the following hotel...Mato Grosso Palace Hotel in cuiaba, BR
#
#
# Located the following hotel...Pacifik Appartels in kone, NC
#
#
# Located the following hotel...Quality Inn in thomaston, US
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_62e63 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_62e63_row0_col0, #T_62e63_row0_col1, #T_62e63_row0_col2, #T_62e63_row0_col3, #T_62e63_row0_col4, #T_62e63_row0_col6, #T_62e63_row0_col7, #T_62e63_row0_col8, #T_62e63_row0_col9, #T_62e63_row1_col0, #T_62e63_row1_col1, #T_62e63_row1_col2, #T_62e63_row1_col3, #T_62e63_row1_col4, #T_62e63_row1_col6, #T_62e63_row1_col7, #T_62e63_row1_col8, #T_62e63_row1_col9, #T_62e63_row2_col0, #T_62e63_row2_col1, #T_62e63_row2_col2, #T_62e63_row2_col4, #T_62e63_row2_col6, #T_62e63_row2_col7, #T_62e63_row2_col8, #T_62e63_row2_col9, #T_62e63_row3_col0, #T_62e63_row3_col1, #T_62e63_row3_col2, #T_62e63_row3_col3, #T_62e63_row3_col4, #T_62e63_row3_col6, #T_62e63_row3_col7, #T_62e63_row3_col8, #T_62e63_row3_col9, #T_62e63_row4_col0, #T_62e63_row4_col1, #T_62e63_row4_col2, #T_62e63_row4_col3, #T_62e63_row4_col7, #T_62e63_row4_col8, #T_62e63_row4_col9, #T_62e63_row5_col0, #T_62e63_row5_col1, #T_62e63_row5_col2, #T_62e63_row5_col3, #T_62e63_row5_col4, #T_62e63_row5_col6, #T_62e63_row5_col7, #T_62e63_row5_col8, #T_62e63_row5_col9, #T_62e63_row6_col0, #T_62e63_row6_col1, #T_62e63_row6_col2, #T_62e63_row6_col3, #T_62e63_row6_col4, #T_62e63_row6_col6, #T_62e63_row6_col7, #T_62e63_row6_col8, #T_62e63_row6_col9, #T_62e63_row7_col0, #T_62e63_row7_col1, #T_62e63_row7_col2, #T_62e63_row7_col4, #T_62e63_row7_col6, #T_62e63_row7_col7, #T_62e63_row7_col8, #T_62e63_row7_col9, #T_62e63_row8_col0, #T_62e63_row8_col1, #T_62e63_row8_col2, #T_62e63_row8_col3, #T_62e63_row8_col4, #T_62e63_row8_col6, #T_62e63_row8_col7, #T_62e63_row8_col8, #T_62e63_row8_col9, #T_62e63_row9_col0, #T_62e63_row9_col1, #T_62e63_row9_col2, #T_62e63_row9_col3, #T_62e63_row9_col6, #T_62e63_row9_col7, #T_62e63_row9_col8, #T_62e63_row9_col9, #T_62e63_row10_col0, #T_62e63_row10_col1, #T_62e63_row10_col2, #T_62e63_row10_col3, #T_62e63_row10_col4, #T_62e63_row10_col7, #T_62e63_row10_col8, #T_62e63_row10_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_62e63_row0_col5, #T_62e63_row1_col5, #T_62e63_row2_col3, #T_62e63_row3_col5, #T_62e63_row4_col5, #T_62e63_row5_col5, #T_62e63_row6_col5, #T_62e63_row7_col5, #T_62e63_row8_col5, #T_62e63_row9_col4, #T_62e63_row10_col5, #T_62e63_row10_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_62e63_row2_col5, #T_62e63_row4_col4, #T_62e63_row4_col6, #T_62e63_row7_col3, #T_62e63_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_62e63">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_62e63_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_62e63_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_62e63_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_62e63_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_62e63_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_62e63_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_62e63_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_62e63_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_62e63_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_62e63_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_62e63_row0_col0" class="data row0 col0" >longboat key</td>
#       <td id="T_62e63_row0_col1" class="data row0 col1" >27.41</td>
#       <td id="T_62e63_row0_col2" class="data row0 col2" >-82.66</td>
#       <td id="T_62e63_row0_col3" class="data row0 col3" >84.49° F</td>
#       <td id="T_62e63_row0_col4" class="data row0 col4" >59%</td>
#       <td id="T_62e63_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_62e63_row0_col6" class="data row0 col6" >6.91</td>
#       <td id="T_62e63_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_62e63_row0_col8" class="data row0 col8" >2023-09-07 17:17:25</td>
#       <td id="T_62e63_row0_col9" class="data row0 col9" >Zota Beach Resort</td>
#     </tr>
#     <tr>
#       <td id="T_62e63_row1_col0" class="data row1 col0" >palmas</td>
#       <td id="T_62e63_row1_col1" class="data row1 col1" >-10.21</td>
#       <td id="T_62e63_row1_col2" class="data row1 col2" >-48.36</td>
#       <td id="T_62e63_row1_col3" class="data row1 col3" >84.07° F</td>
#       <td id="T_62e63_row1_col4" class="data row1 col4" >51%</td>
#       <td id="T_62e63_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_62e63_row1_col6" class="data row1 col6" >5.75</td>
#       <td id="T_62e63_row1_col7" class="data row1 col7" >BR</td>
#       <td id="T_62e63_row1_col8" class="data row1 col8" >2023-09-07 17:17:42</td>
#       <td id="T_62e63_row1_col9" class="data row1 col9" >Hotel Triângulo Mineiro</td>
#     </tr>
#     <tr>
#       <td id="T_62e63_row2_col0" class="data row2 col0" >camalu</td>
#       <td id="T_62e63_row2_col1" class="data row2 col1" >30.85</td>
#       <td id="T_62e63_row2_col2" class="data row2 col2" >-116.07</td>
#       <td id="T_62e63_row2_col3" class="data row2 col3" >76.44° F</td>
#       <td id="T_62e63_row2_col4" class="data row2 col4" >64%</td>
#       <td id="T_62e63_row2_col5" class="data row2 col5" >3%</td>
#       <td id="T_62e63_row2_col6" class="data row2 col6" >8.66</td>
#       <td id="T_62e63_row2_col7" class="data row2 col7" >MX</td>
#       <td id="T_62e63_row2_col8" class="data row2 col8" >2023-09-07 17:17:46</td>
#       <td id="T_62e63_row2_col9" class="data row2 col9" >Margaritaville</td>
#     </tr>
#     <tr>
#       <td id="T_62e63_row3_col0" class="data row3 col0" >commerce</td>
#       <td id="T_62e63_row3_col1" class="data row3 col1" >34.00</td>
#       <td id="T_62e63_row3_col2" class="data row3 col2" >-118.16</td>
#       <td id="T_62e63_row3_col3" class="data row3 col3" >81.39° F</td>
#       <td id="T_62e63_row3_col4" class="data row3 col4" >58%</td>
#       <td id="T_62e63_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_62e63_row3_col6" class="data row3 col6" >8.05</td>
#       <td id="T_62e63_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_62e63_row3_col8" class="data row3 col8" >2023-09-07 17:18:05</td>
#       <td id="T_62e63_row3_col9" class="data row3 col9" >Doubletree Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_62e63_row4_col0" class="data row4 col0" >mersa matruh</td>
#       <td id="T_62e63_row4_col1" class="data row4 col1" >31.35</td>
#       <td id="T_62e63_row4_col2" class="data row4 col2" >27.25</td>
#       <td id="T_62e63_row4_col3" class="data row4 col3" >80.87° F</td>
#       <td id="T_62e63_row4_col4" class="data row4 col4" >66%</td>
#       <td id="T_62e63_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_62e63_row4_col6" class="data row4 col6" >9.84</td>
#       <td id="T_62e63_row4_col7" class="data row4 col7" >EG</td>
#       <td id="T_62e63_row4_col8" class="data row4 col8" >2023-09-07 17:18:12</td>
#       <td id="T_62e63_row4_col9" class="data row4 col9" >صقور</td>
#     </tr>
#     <tr>
#       <td id="T_62e63_row5_col0" class="data row5 col0" >lefka</td>
#       <td id="T_62e63_row5_col1" class="data row5 col1" >35.11</td>
#       <td id="T_62e63_row5_col2" class="data row5 col2" >32.85</td>
#       <td id="T_62e63_row5_col3" class="data row5 col3" >77.61° F</td>
#       <td id="T_62e63_row5_col4" class="data row5 col4" >50%</td>
#       <td id="T_62e63_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_62e63_row5_col6" class="data row5 col6" >3.18</td>
#       <td id="T_62e63_row5_col7" class="data row5 col7" >CY</td>
#       <td id="T_62e63_row5_col8" class="data row5 col8" >2023-09-07 17:18:48</td>
#       <td id="T_62e63_row5_col9" class="data row5 col9" >Aphrodite</td>
#     </tr>
#     <tr>
#       <td id="T_62e63_row6_col0" class="data row6 col0" >khalabat</td>
#       <td id="T_62e63_row6_col1" class="data row6 col1" >

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
