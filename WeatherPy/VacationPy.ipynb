# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_d5203 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d5203_row0_col0, #T_d5203_row0_col1, #T_d5203_row0_col2, #T_d5203_row0_col3, #T_d5203_row0_col4, #T_d5203_row0_col5, #T_d5203_row0_col7, #T_d5203_row0_col8, #T_d5203_row1_col0, #T_d5203_row1_col1, #T_d5203_row1_col2, #T_d5203_row1_col3, #T_d5203_row1_col4, #T_d5203_row1_col6, #T_d5203_row1_col7, #T_d5203_row1_col8, #T_d5203_row2_col0, #T_d5203_row2_col1, #T_d5203_row2_col2, #T_d5203_row2_col3, #T_d5203_row2_col4, #T_d5203_row2_col5, #T_d5203_row2_col6, #T_d5203_row2_col7, #T_d5203_row2_col8, #T_d5203_row3_col0, #T_d5203_row3_col1, #T_d5203_row3_col2, #T_d5203_row3_col3, #T_d5203_row3_col4, #T_d5203_row3_col6, #T_d5203_row3_col7, #T_d5203_row3_col8, #T_d5203_row4_col0, #T_d5203_row4_col1, #T_d5203_row4_col2, #T_d5203_row4_col3, #T_d5203_row4_col4, #T_d5203_row4_col5, #T_d5203_row4_col6, #T_d5203_row4_col7, #T_d5203_row4_col8, #T_d5203_row5_col0, #T_d5203_row5_col1, #T_d5203_row5_col2, #T_d5203_row5_col4, #T_d5203_row5_col5, #T_d5203_row5_col6, #T_d5203_row5_col7, #T_d5203_row5_col8, #T_d5203_row6_col0, #T_d5203_row6_col1, #T_d5203_row6_col2, #T_d5203_row6_col3, #T_d5203_row6_col5, #T_d5203_row6_col6, #T_d5203_row6_col7, #T_d5203_row6_col8, #T_d5203_row7_col0, #T_d5203_row7_col1, #T_d5203_row7_col2, #T_d5203_row7_col4, #T_d5203_row7_col5, #T_d5203_row7_col7, #T_d5203_row7_col8, #T_d5203_row8_col0, #T_d5203_row8_col1, #T_d5203_row8_col2, #T_d5203_row8_col3, #T_d5203_row8_col4, #T_d5203_row8_col6, #T_d5203_row8_col7, #T_d5203_row8_col8, #T_d5203_row9_col0, #T_d5203_row9_col1, #T_d5203_row9_col2, #T_d5203_row9_col3, #T_d5203_row9_col6, #T_d5203_row9_col7, #T_d5203_row9_col8, #T_d5203_row10_col0, #T_d5203_row10_col1, #T_d5203_row10_col2, #T_d5203_row10_col3, #T_d5203_row10_col4, #T_d5203_row10_col5, #T_d5203_row10_col6, #T_d5203_row10_col7, #T_d5203_row10_col8, #T_d5203_row11_col0, #T_d5203_row11_col1, #T_d5203_row11_col2, #T_d5203_row11_col3, #T_d5203_row11_col4, #T_d5203_row11_col5, #T_d5203_row11_col6, #T_d5203_row11_col7, #T_d5203_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_d5203_row0_col6, #T_d5203_row1_col5, #T_d5203_row3_col5, #T_d5203_row5_col3, #T_d5203_row6_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_d5203_row7_col3, #T_d5203_row7_col6, #T_d5203_row8_col5, #T_d5203_row9_col4, #T_d5203_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_d5203">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_d5203_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_d5203_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_d5203_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_d5203_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_d5203_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_d5203_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_d5203_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_d5203_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_d5203_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d5203_row0_col0" class="data row0 col0" >port-aux-francais</td>
#       <td id="T_d5203_row0_col1" class="data row0 col1" >-49.35</td>
#       <td id="T_d5203_row0_col2" class="data row0 col2" >70.22</td>
#       <td id="T_d5203_row0_col3" class="data row0 col3" >33.91° F</td>
#       <td id="T_d5203_row0_col4" class="data row0 col4" >69%</td>
#       <td id="T_d5203_row0_col5" class="data row0 col5" >98%</td>
#       <td id="T_d5203_row0_col6" class="data row0 col6" >24.56</td>
#       <td id="T_d5203_row0_col7" class="data row0 col7" >TF</td>
#       <td id="T_d5203_row0_col8" class="data row0 col8" >2023-09-03 10:52:58</td>
#     </tr>
#     <tr>
#       <td id="T_d5203_row1_col0" class="data row1 col0" >tura</td>
#       <td id="T_d5203_row1_col1" class="data row1 col1" >25.52</td>
#       <td id="T_d5203_row1_col2" class="data row1 col2" >90.22</td>
#       <td id="T_d5203_row1_col3" class="data row1 col3" >76.78° F</td>
#       <td id="T_d5203_row1_col4" class="data row1 col4" >90%</td>
#       <td id="T_d5203_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_d5203_row1_col6" class="data row1 col6" >3.80</td>
#       <td id="T_d5203_row1_col7" class="data row1 col7" >IN</td>
#       <td id="T_d5203_row1_col8" class="data row1 col8" >2023-09-03 10:52:58</td>
#     </tr>
#     <tr>
#       <td id="T_d5203_row2_col0" class="data row2 col0" >udachny</td>
#       <td id="T_d5203_row2_col1" class="data row2 col1" >66.42</td>
#       <td id="T_d5203_row2_col2" class="data row2 col2" >112.40</td>
#       <td id="T_d5203_row2_col3" class="data row2 col3" >41.45° F</td>
#       <td id="T_d5203_row2_col4" class="data row2 col4" >86%</td>
#       <td id="T_d5203_row2_col5" class="data row2 col5" >95%</td>
#       <td id="T_d5203_row2_col6" class="data row2 col6" >11.41</td>
#       <td id="T_d5203_row2_col7" class="data row2 col7" >RU</td>
#       <td id="T_d5203_row2_col8" class="data row2 col8" >2023-09-03 10:52:58</td>
#     </tr>
#     <tr>
#       <td id="T_d5203_row3_col0" class="data row3 col0" >thompson</td>
#       <td id="T_d5203_row3_col1" class="data row3 col1" >55.74</td>
#       <td id="T_d5203_row3_col2" class="data row3 col2" >-97.86</td>
#       <td id="T_d5203_row3_col3" class="data row3 col3" >64.56° F</td>
#       <td id="T_d5203_row3_col4" class="data row3 col4" >55%</td>
#       <td id="T_d5203_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_d5203_row3_col6" class="data row3 col6" >13.80</td>
#       <td id="T_d5203_row3_col7" class="data row3 col7" >CA</td>
#       <td id="T_d5203_row3_col8" class="data row3 col8" >2023-09-03 10:52:59</td>
#     </tr>
#     <tr>
#       <td id="T_d5203_row4_col0" class="data row4 col0" >west island</td>
#       <td id="T_d5203_row4_col1" class="data row4 col1" >-12.16</td>
#       <td id="T_d5203_row4_col2" class="data row4 col2" >96.82</td>
#       <td id="T_d5203_row4_col3" class="data row4 col3" >76.98° F</td>
#       <td id="T_d5203_row4_col4" class="data row4 col4" >78%</td>
#       <td id="T_d5203_row4_col5" class="data row4 col5" >40%</td>
#       <td id="T_d5203_row4_col6" class="data row4 col6" >12.66</td>
#       <td id="T_d5203_row4_col7" class="data row4 col7" >CC</td>
#       <td id="T_d5203_row4_col8" class="data row4 col8" >2023-09-03 10:52:59</td>
#     </tr>
#     <tr>
#       <td id="T_d5203_row5_col0" class="data row5 col0" >praia da vitoria</td>
#       <td id="T_d5203_row5_col1" class="data row5 col1" >38.73</td>
#       <td id="T_d5203_row5_col2" class="data row5 col2" >-27.07</td>
#       <td id="T_d5203_row5_col3" class="data row5 col3" >77.25° F</td>
#       <td id="T_d5203_row5_col4" class="data row5 col4" >73%</td>
#       <td id="T_d5203_row5_col5" class="data row5 col5" >20%</td>
#       <td id="T_d5203_row5_col6" class="data row5 col6" >2.46</td>
#       <td id="T_d5203_row5_col7" class="data row5 col7" >PT</td>
#       <td id="T_d5203_row5_col8" class="data row5 col8" >2023-09-03 10:52:59</td>
#     </tr>
#     <tr>
#       <td id="T_d5203_row6_col0" class="data row6 col0" >hawaiian paradise park</td>
#       <td id="T_d5203_row6_col1" class="data row6 col1" >19.59</td>
#       <td id="T_d5203_row6_col2" class="data row6 col2" >-154.97</td>
#       <td id="T_d5203_row6_col3" class="data row6 col3" >71.17° F</td>
#       <td id="T_d5203_row6_col4" class="data row6 col4" >93%</td>
#       <td id="T_d5203_row6_col5" class="data row6 col5" >40%</td>
#       <td id="T_d5203_row6_col6" class="data row6 col6" >8.05</td>
#       <td id="T_d5203_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_d5203_row6_col8" class="data row6 col8" >2023-09-03 10:52:59</td>
#     </tr>
#     <tr>
#       <td id=

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# The subroutine, DisplayHVPlotDataFrame, in source file, PyFunctions.py, was unable to display a formatted HVPlot.

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 35) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 75), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 5), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_e35ee caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_e35ee_row0_col0, #T_e35ee_row0_col1, #T_e35ee_row0_col2, #T_e35ee_row0_col3, #T_e35ee_row0_col4, #T_e35ee_row0_col5, #T_e35ee_row0_col6, #T_e35ee_row0_col7, #T_e35ee_row0_col8, #T_e35ee_row1_col0, #T_e35ee_row1_col1, #T_e35ee_row1_col2, #T_e35ee_row1_col3, #T_e35ee_row1_col4, #T_e35ee_row1_col6, #T_e35ee_row1_col7, #T_e35ee_row1_col8, #T_e35ee_row2_col0, #T_e35ee_row2_col1, #T_e35ee_row2_col2, #T_e35ee_row2_col3, #T_e35ee_row2_col4, #T_e35ee_row2_col6, #T_e35ee_row2_col7, #T_e35ee_row2_col8, #T_e35ee_row3_col0, #T_e35ee_row3_col1, #T_e35ee_row3_col2, #T_e35ee_row3_col3, #T_e35ee_row3_col4, #T_e35ee_row3_col6, #T_e35ee_row3_col7, #T_e35ee_row3_col8, #T_e35ee_row4_col0, #T_e35ee_row4_col1, #T_e35ee_row4_col2, #T_e35ee_row4_col4, #T_e35ee_row4_col6, #T_e35ee_row4_col7, #T_e35ee_row4_col8, #T_e35ee_row5_col0, #T_e35ee_row5_col1, #T_e35ee_row5_col2, #T_e35ee_row5_col3, #T_e35ee_row5_col4, #T_e35ee_row5_col6, #T_e35ee_row5_col7, #T_e35ee_row5_col8, #T_e35ee_row6_col0, #T_e35ee_row6_col1, #T_e35ee_row6_col2, #T_e35ee_row6_col3, #T_e35ee_row6_col4, #T_e35ee_row6_col6, #T_e35ee_row6_col7, #T_e35ee_row6_col8, #T_e35ee_row7_col0, #T_e35ee_row7_col1, #T_e35ee_row7_col2, #T_e35ee_row7_col3, #T_e35ee_row7_col4, #T_e35ee_row7_col7, #T_e35ee_row7_col8, #T_e35ee_row8_col0, #T_e35ee_row8_col1, #T_e35ee_row8_col2, #T_e35ee_row8_col3, #T_e35ee_row8_col6, #T_e35ee_row8_col7, #T_e35ee_row8_col8, #T_e35ee_row9_col0, #T_e35ee_row9_col1, #T_e35ee_row9_col2, #T_e35ee_row9_col3, #T_e35ee_row9_col4, #T_e35ee_row9_col6, #T_e35ee_row9_col7, #T_e35ee_row9_col8, #T_e35ee_row10_col0, #T_e35ee_row10_col1, #T_e35ee_row10_col2, #T_e35ee_row10_col3, #T_e35ee_row10_col4, #T_e35ee_row10_col6, #T_e35ee_row10_col7, #T_e35ee_row10_col8, #T_e35ee_row11_col0, #T_e35ee_row11_col1, #T_e35ee_row11_col2, #T_e35ee_row11_col4, #T_e35ee_row11_col6, #T_e35ee_row11_col7, #T_e35ee_row11_col8, #T_e35ee_row12_col0, #T_e35ee_row12_col1, #T_e35ee_row12_col2, #T_e35ee_row12_col3, #T_e35ee_row12_col4, #T_e35ee_row12_col6, #T_e35ee_row12_col7, #T_e35ee_row12_col8, #T_e35ee_row13_col0, #T_e35ee_row13_col1, #T_e35ee_row13_col2, #T_e35ee_row13_col3, #T_e35ee_row13_col7, #T_e35ee_row13_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_e35ee_row1_col5, #T_e35ee_row2_col5, #T_e35ee_row3_col5, #T_e35ee_row4_col5, #T_e35ee_row5_col5, #T_e35ee_row6_col5, #T_e35ee_row7_col5, #T_e35ee_row8_col5, #T_e35ee_row9_col5, #T_e35ee_row10_col5, #T_e35ee_row11_col3, #T_e35ee_row11_col5, #T_e35ee_row12_col5, #T_e35ee_row13_col4, #T_e35ee_row13_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_e35ee_row4_col3, #T_e35ee_row7_col6, #T_e35ee_row8_col4, #T_e35ee_row13_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_e35ee">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_e35ee_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_e35ee_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_e35ee_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_e35ee_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_e35ee_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_e35ee_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_e35ee_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_e35ee_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_e35ee_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e35ee_row0_col0" class="data row0 col0" >albany</td>
#       <td id="T_e35ee_row0_col1" class="data row0 col1" >42.60</td>
#       <td id="T_e35ee_row0_col2" class="data row0 col2" >-73.97</td>
#       <td id="T_e35ee_row0_col3" class="data row0 col3" >81.36° F</td>
#       <td id="T_e35ee_row0_col4" class="data row0 col4" >61%</td>
#       <td id="T_e35ee_row0_col5" class="data row0 col5" >1%</td>
#       <td id="T_e35ee_row0_col6" class="data row0 col6" >1.01</td>
#       <td id="T_e35ee_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_e35ee_row0_col8" class="data row0 col8" >2023-09-03 10:50:42</td>
#     </tr>
#     <tr>
#       <td id="T_e35ee_row1_col0" class="data row1 col0" >argo</td>
#       <td id="T_e35ee_row1_col1" class="data row1 col1" >37.63</td>
#       <td id="T_e35ee_row1_col2" class="data row1 col2" >22.73</td>
#       <td id="T_e35ee_row1_col3" class="data row1 col3" >81.79° F</td>
#       <td id="T_e35ee_row1_col4" class="data row1 col4" >43%</td>
#       <td id="T_e35ee_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_e35ee_row1_col6" class="data row1 col6" >1.30</td>
#       <td id="T_e35ee_row1_col7" class="data row1 col7" >GR</td>
#       <td id="T_e35ee_row1_col8" class="data row1 col8" >2023-09-03 10:53:26</td>
#     </tr>
#     <tr>
#       <td id="T_e35ee_row2_col0" class="data row2 col0" >bethel</td>
#       <td id="T_e35ee_row2_col1" class="data row2 col1" >41.37</td>
#       <td id="T_e35ee_row2_col2" class="data row2 col2" >-73.41</td>
#       <td id="T_e35ee_row2_col3" class="data row2 col3" >83.82° F</td>
#       <td id="T_e35ee_row2_col4" class="data row2 col4" >57%</td>
#       <td id="T_e35ee_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_e35ee_row2_col6" class="data row2 col6" >5.75</td>
#       <td id="T_e35ee_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_e35ee_row2_col8" class="data row2 col8" >2023-09-03 10:53:27</td>
#     </tr>
#     <tr>
#       <td id="T_e35ee_row3_col0" class="data row3 col0" >morehead city</td>
#       <td id="T_e35ee_row3_col1" class="data row3 col1" >34.72</td>
#       <td id="T_e35ee_row3_col2" class="data row3 col2" >-76.73</td>
#       <td id="T_e35ee_row3_col3" class="data row3 col3" >81.57° F</td>
#       <td id="T_e35ee_row3_col4" class="data row3 col4" >59%</td>
#       <td id="T_e35ee_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_e35ee_row3_col6" class="data row3 col6" >4.00</td>
#       <td id="T_e35ee_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_e35ee_row3_col8" class="data row3 col8" >2023-09-03 10:53:29</td>
#     </tr>
#     <tr>
#       <td id="T_e35ee_row4_col0" class="data row4 col0" >greenville</td>
#       <td id="T_e35ee_row4_col1" class="data row4 col1" >35.61</td>
#       <td id="T_e35ee_row4_col2" class="data row4 col2" >-77.37</td>
#       <td id="T_e35ee_row4_col3" class="data row4 col3" >85.75° F</td>
#       <td id="T_e35ee_row4_col4" class="data row4 col4" >52%</td>
#       <td id="T_e35ee_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_e35ee_row4_col6" class="data row4 col6" >5.01</td>
#       <td id="T_e35ee_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_e35ee_row4_col8" class="data row4 col8" >2023-09-03 10:51:23</td>
#     </tr>
#     <tr>
#       <td id="T_e35ee_row5_col0" class="data row5 col0" >broome</td>
#       <td id="T_e35ee_row5_col1" class="data row5 col1" >42.25</td>
#       <td id="T_e35ee_row5_col2" class="data row5 col2" >-75.83</td>
#       <td id="T_e35ee_row5_col3" class="data row5 col3" >82.33° F</td>
#       <td id="T_e35ee_row5_col4" class="data row5 col4" >66%</td>
#       <td id="T_e35ee_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_e35ee_row5_col6" class="data row5 col6" >6.91</td>
#       <td id="T_e35ee_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_e35ee_row5_col8" class="data row5 col8" >2023-09-03 10:53:40</td>
#     </tr>
#     <tr>
#       <td id="T_e35ee_row6_col0" class="data row6 col0" >tuba city</td>
#       <td id="T_e35ee_row6_col1" class="data row6 col1" >36.13</td>
#       <td id="T_e35ee_row6_col2" class="data row6 col2" >-111.24</td>
#       <td id="T_e35ee_row6_col3" class="data row6 col3" >77.47° F</td>
#       <td id="T_e35ee_row6_col4" class="dat

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# The subroutine, DisplayHVPlotDataFrame, in source file, PyFunctions.py, was unable to display a formatted HVPlot.

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Apollon Hotel in argo, GR
#
#
# Located the following hotel...Hampton Inn Danbury in bethel, US
#
#
# Located the following hotel...Bask Hotel Big Rock Landing, Trademark Collection by Wyndham in morehead city, US
#
#
# Located the following hotel...Quality Inn in greenville, US
#
#
# Located the following hotel...Quality Inn Navajo Nation in tuba city, US
#
#
# Located the following hotel...Chez Lily in saint-francois, FR
#
#
# Located the following hotel...Kona Seaside Hotel in kailua-kona, US
#
#
# Located the following hotel...Comfort Inn & Suites in corbin, US
#
#
# Located the following hotel...Deogarh Mahal in devgarh, IN
#
#
# Located the following hotel...Wingate by Wyndham Altoona in altoona, US
#
#
# Located the following hotel...هتل جهانگردى دامغان in damghan, IR
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_1a79e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_1a79e_row0_col0, #T_1a79e_row0_col1, #T_1a79e_row0_col2, #T_1a79e_row0_col3, #T_1a79e_row0_col4, #T_1a79e_row0_col6, #T_1a79e_row0_col7, #T_1a79e_row0_col8, #T_1a79e_row0_col9, #T_1a79e_row1_col0, #T_1a79e_row1_col1, #T_1a79e_row1_col2, #T_1a79e_row1_col3, #T_1a79e_row1_col4, #T_1a79e_row1_col6, #T_1a79e_row1_col7, #T_1a79e_row1_col8, #T_1a79e_row1_col9, #T_1a79e_row2_col0, #T_1a79e_row2_col1, #T_1a79e_row2_col2, #T_1a79e_row2_col3, #T_1a79e_row2_col4, #T_1a79e_row2_col6, #T_1a79e_row2_col7, #T_1a79e_row2_col8, #T_1a79e_row2_col9, #T_1a79e_row3_col0, #T_1a79e_row3_col1, #T_1a79e_row3_col2, #T_1a79e_row3_col4, #T_1a79e_row3_col6, #T_1a79e_row3_col7, #T_1a79e_row3_col8, #T_1a79e_row3_col9, #T_1a79e_row4_col0, #T_1a79e_row4_col1, #T_1a79e_row4_col2, #T_1a79e_row4_col3, #T_1a79e_row4_col4, #T_1a79e_row4_col6, #T_1a79e_row4_col7, #T_1a79e_row4_col8, #T_1a79e_row4_col9, #T_1a79e_row5_col0, #T_1a79e_row5_col1, #T_1a79e_row5_col2, #T_1a79e_row5_col3, #T_1a79e_row5_col4, #T_1a79e_row5_col7, #T_1a79e_row5_col8, #T_1a79e_row5_col9, #T_1a79e_row6_col0, #T_1a79e_row6_col1, #T_1a79e_row6_col2, #T_1a79e_row6_col3, #T_1a79e_row6_col6, #T_1a79e_row6_col7, #T_1a79e_row6_col8, #T_1a79e_row6_col9, #T_1a79e_row7_col0, #T_1a79e_row7_col1, #T_1a79e_row7_col2, #T_1a79e_row7_col3, #T_1a79e_row7_col4, #T_1a79e_row7_col6, #T_1a79e_row7_col7, #T_1a79e_row7_col8, #T_1a79e_row7_col9, #T_1a79e_row8_col0, #T_1a79e_row8_col1, #T_1a79e_row8_col2, #T_1a79e_row8_col4, #T_1a79e_row8_col6, #T_1a79e_row8_col7, #T_1a79e_row8_col8, #T_1a79e_row8_col9, #T_1a79e_row9_col0, #T_1a79e_row9_col1, #T_1a79e_row9_col2, #T_1a79e_row9_col3, #T_1a79e_row9_col4, #T_1a79e_row9_col6, #T_1a79e_row9_col7, #T_1a79e_row9_col8, #T_1a79e_row9_col9, #T_1a79e_row10_col0, #T_1a79e_row10_col1, #T_1a79e_row10_col2, #T_1a79e_row10_col3, #T_1a79e_row10_col7, #T_1a79e_row10_col8, #T_1a79e_row10_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_1a79e_row0_col5, #T_1a79e_row1_col5, #T_1a79e_row2_col5, #T_1a79e_row3_col5, #T_1a79e_row4_col5, #T_1a79e_row5_col5, #T_1a79e_row6_col5, #T_1a79e_row7_col5, #T_1a79e_row8_col3, #T_1a79e_row8_col5, #T_1a79e_row9_col5, #T_1a79e_row10_col4, #T_1a79e_row10_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_1a79e_row3_col3, #T_1a79e_row5_col6, #T_1a79e_row6_col4, #T_1a79e_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_1a79e">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_1a79e_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_1a79e_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_1a79e_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_1a79e_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_1a79e_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_1a79e_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_1a79e_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_1a79e_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_1a79e_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_1a79e_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1a79e_row0_col0" class="data row0 col0" >argo</td>
#       <td id="T_1a79e_row0_col1" class="data row0 col1" >37.63</td>
#       <td id="T_1a79e_row0_col2" class="data row0 col2" >22.73</td>
#       <td id="T_1a79e_row0_col3" class="data row0 col3" >81.79° F</td>
#       <td id="T_1a79e_row0_col4" class="data row0 col4" >43%</td>
#       <td id="T_1a79e_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_1a79e_row0_col6" class="data row0 col6" >1.30</td>
#       <td id="T_1a79e_row0_col7" class="data row0 col7" >GR</td>
#       <td id="T_1a79e_row0_col8" class="data row0 col8" >2023-09-03 10:53:26</td>
#       <td id="T_1a79e_row0_col9" class="data row0 col9" >Apollon Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_1a79e_row1_col0" class="data row1 col0" >bethel</td>
#       <td id="T_1a79e_row1_col1" class="data row1 col1" >41.37</td>
#       <td id="T_1a79e_row1_col2" class="data row1 col2" >-73.41</td>
#       <td id="T_1a79e_row1_col3" class="data row1 col3" >83.82° F</td>
#       <td id="T_1a79e_row1_col4" class="data row1 col4" >57%</td>
#       <td id="T_1a79e_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_1a79e_row1_col6" class="data row1 col6" >5.75</td>
#       <td id="T_1a79e_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_1a79e_row1_col8" class="data row1 col8" >2023-09-03 10:53:27</td>
#       <td id="T_1a79e_row1_col9" class="data row1 col9" >Hampton Inn Danbury</td>
#     </tr>
#     <tr>
#       <td id="T_1a79e_row2_col0" class="data row2 col0" >morehead city</td>
#       <td id="T_1a79e_row2_col1" class="data row2 col1" >34.72</td>
#       <td id="T_1a79e_row2_col2" class="data row2 col2" >-76.73</td>
#       <td id="T_1a79e_row2_col3" class="data row2 col3" >81.57° F</td>
#       <td id="T_1a79e_row2_col4" class="data row2 col4" >59%</td>
#       <td id="T_1a79e_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_1a79e_row2_col6" class="data row2 col6" >4.00</td>
#       <td id="T_1a79e_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_1a79e_row2_col8" class="data row2 col8" >2023-09-03 10:53:29</td>
#       <td id="T_1a79e_row2_col9" class="data row2 col9" >Bask Hotel Big Rock Landing, Trademark Collection by Wyndham</td>
#     </tr>
#     <tr>
#       <td id="T_1a79e_row3_col0" class="data row3 col0" >greenville</td>
#       <td id="T_1a79e_row3_col1" class="data row3 col1" >35.61</td>
#       <td id="T_1a79e_row3_col2" class="data row3 col2" >-77.37</td>
#       <td id="T_1a79e_row3_col3" class="data row3 col3" >85.75° F</td>
#       <td id="T_1a79e_row3_col4" class="data row3 col4" >52%</td>
#       <td id="T_1a79e_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_1a79e_row3_col6" class="data row3 col6" >5.01</td>
#       <td id="T_1a79e_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_1a79e_row3_col8" class="data row3 col8" >2023-09-03 10:51:23</td>
#       <td id="T_1a79e_row3_col9" class="data row3 col9" >Quality Inn</td>
#     </tr>
#     <tr>
#       <td id="T_1a79e_row4_col0" class="data row4 col0" >tuba city</td>
#       <td id="T_1a79e_row4_col1" class="data row4 col1" >36.13</td>
#       <td id="T_1a79e_row4_col2" class="data row4 col2" >-111.24</td>
#       <td id="T_1a79e_row4_col3" class="data row4 col3" >77.47° F</td>
#       <td id="T_1a79e_row4_col4" class="data row4 col4" >38%</td>
#       <td id="T_1a79e_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_1a79e_row4_col6" class="data row4 col6" >7.36</td>
#       <td id="T_1a79e_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_1a79e_row4_col8" class="data row4 col8" >2023-09-03 10:53:43</td>
#       <td id="T_1a79e_row4_col9" class="data row4 col9" >Quality Inn Navajo Nation</td>
#     </tr>
#     <tr>
#       <td id="T_1a79e_row5_col0" class="data row5 col0" >saint-francois</td>
#       <td id="T_1a79e_row5_col1" class="data row5 col1" >46.42</td>
#       <td id="T_1a79e_row5_col2" class="data row5 col2" >3.91</td>
#       <td id="T_1a79e_row5_col3" class="data row5 col3" >83.64° F</td>
#       <td id="T_1a79e_row5_col4" class="data row5 col4" >42%</td>
#       <td id="T_1a79e_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_1a79e_row5_col6" class="data row5 col6" >9.22</td>
#       <td id="T_1a79e_row5_col7" class="data row5 col7" >FR</td>
#       <td id="T_1a79e_row5_col8" class="data row5 col8" >2023-09-03 10:53:44</td>
#       <td id="T_1a79e_row5_col9" class="data row5 col9" >Chez Lily</td>
#     </tr>
#     <tr>
#       <td id="T_1a79e_row6_col0" class="data row6 col0" >kailua-kona</

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# The subroutine, DisplayHVPlotDataFrame, in source file, PyFunctions.py, was unable to display a formatted HVPlot.

# %%
#log_subroutine \
#    .EndProgramExecution()
