# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'

log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame,
         'Table: 1: City Weather Information')
# Out:
# <style type="text/css">
# #T_925f0 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_925f0_row0_col0, #T_925f0_row0_col1, #T_925f0_row0_col2, #T_925f0_row0_col3, #T_925f0_row0_col4, #T_925f0_row0_col6, #T_925f0_row0_col7, #T_925f0_row0_col8, #T_925f0_row1_col0, #T_925f0_row1_col1, #T_925f0_row1_col2, #T_925f0_row1_col3, #T_925f0_row1_col4, #T_925f0_row1_col5, #T_925f0_row1_col6, #T_925f0_row1_col7, #T_925f0_row1_col8, #T_925f0_row2_col0, #T_925f0_row2_col1, #T_925f0_row2_col2, #T_925f0_row2_col3, #T_925f0_row2_col4, #T_925f0_row2_col5, #T_925f0_row2_col6, #T_925f0_row2_col7, #T_925f0_row2_col8, #T_925f0_row3_col0, #T_925f0_row3_col1, #T_925f0_row3_col2, #T_925f0_row3_col3, #T_925f0_row3_col4, #T_925f0_row3_col5, #T_925f0_row3_col6, #T_925f0_row3_col7, #T_925f0_row3_col8, #T_925f0_row4_col0, #T_925f0_row4_col1, #T_925f0_row4_col2, #T_925f0_row4_col3, #T_925f0_row4_col4, #T_925f0_row4_col7, #T_925f0_row4_col8, #T_925f0_row5_col0, #T_925f0_row5_col1, #T_925f0_row5_col2, #T_925f0_row5_col3, #T_925f0_row5_col4, #T_925f0_row5_col5, #T_925f0_row5_col6, #T_925f0_row5_col7, #T_925f0_row5_col8, #T_925f0_row6_col0, #T_925f0_row6_col1, #T_925f0_row6_col2, #T_925f0_row6_col3, #T_925f0_row6_col4, #T_925f0_row6_col6, #T_925f0_row6_col7, #T_925f0_row6_col8, #T_925f0_row7_col0, #T_925f0_row7_col1, #T_925f0_row7_col2, #T_925f0_row7_col3, #T_925f0_row7_col4, #T_925f0_row7_col5, #T_925f0_row7_col6, #T_925f0_row7_col7, #T_925f0_row7_col8, #T_925f0_row8_col0, #T_925f0_row8_col1, #T_925f0_row8_col2, #T_925f0_row8_col6, #T_925f0_row8_col7, #T_925f0_row8_col8, #T_925f0_row9_col0, #T_925f0_row9_col1, #T_925f0_row9_col2, #T_925f0_row9_col3, #T_925f0_row9_col4, #T_925f0_row9_col5, #T_925f0_row9_col6, #T_925f0_row9_col7, #T_925f0_row9_col8, #T_925f0_row10_col0, #T_925f0_row10_col1, #T_925f0_row10_col2, #T_925f0_row10_col3, #T_925f0_row10_col4, #T_925f0_row10_col6, #T_925f0_row10_col7, #T_925f0_row10_col8, #T_925f0_row11_col0, #T_925f0_row11_col1, #T_925f0_row11_col2, #T_925f0_row11_col3, #T_925f0_row11_col4, #T_925f0_row11_col6, #T_925f0_row11_col7, #T_925f0_row11_col8, #T_925f0_row12_col0, #T_925f0_row12_col1, #T_925f0_row12_col2, #T_925f0_row12_col3, #T_925f0_row12_col4, #T_925f0_row12_col6, #T_925f0_row12_col7, #T_925f0_row12_col8, #T_925f0_row13_col0, #T_925f0_row13_col1, #T_925f0_row13_col2, #T_925f0_row13_col3, #T_925f0_row13_col4, #T_925f0_row13_col5, #T_925f0_row13_col6, #T_925f0_row13_col7, #T_925f0_row13_col8, #T_925f0_row14_col0, #T_925f0_row14_col1, #T_925f0_row14_col2, #T_925f0_row14_col3, #T_925f0_row14_col4, #T_925f0_row14_col5, #T_925f0_row14_col6, #T_925f0_row14_col7, #T_925f0_row14_col8, #T_925f0_row15_col0, #T_925f0_row15_col1, #T_925f0_row15_col2, #T_925f0_row15_col3, #T_925f0_row15_col4, #T_925f0_row15_col5, #T_925f0_row15_col6, #T_925f0_row15_col7, #T_925f0_row15_col8, #T_925f0_row16_col0, #T_925f0_row16_col1, #T_925f0_row16_col2, #T_925f0_row16_col3, #T_925f0_row16_col4, #T_925f0_row16_col5, #T_925f0_row16_col6, #T_925f0_row16_col7, #T_925f0_row16_col8, #T_925f0_row17_col0, #T_925f0_row17_col1, #T_925f0_row17_col2, #T_925f0_row17_col3, #T_925f0_row17_col4, #T_925f0_row17_col6, #T_925f0_row17_col7, #T_925f0_row17_col8, #T_925f0_row18_col0, #T_925f0_row18_col1, #T_925f0_row18_col2, #T_925f0_row18_col3, #T_925f0_row18_col6, #T_925f0_row18_col7, #T_925f0_row18_col8, #T_925f0_row19_col0, #T_925f0_row19_col1, #T_925f0_row19_col2, #T_925f0_row19_col3, #T_925f0_row19_col4, #T_925f0_row19_col5, #T_925f0_row19_col6, #T_925f0_row19_col7, #T_925f0_row19_col8, #T_925f0_row20_col0, #T_925f0_row20_col1, #T_925f0_row20_col2, #T_925f0_row20_col3, #T_925f0_row20_col4, #T_925f0_row20_col6, #T_925f0_row20_col7, #T_925f0_row20_col8, #T_925f0_row21_col0, #T_925f0_row21_col1, #T_925f0_row21_col2, #T_925f0_row21_col3, #T_925f0_row21_col4, #T_925f0_row21_col5, #T_925f0_row21_col6, #T_925f0_row21_col7, #T_925f0_row21_col8, #T_925f0_row22_col0, #T_925f0_row22_col1, #T_925f0_row22_col2, #T_925f0_row22_col3, #T_925f0_row22_col4, #T_925f0_row22_col5, #T_925f0_row22_col6, #T_925f0_row22_col7, #T_925f0_row22_col8, #T_925f0_row23_col0, #T_925f0_ ...

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions and Locations**

# %%
idealWeatherLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Humidity'] >= 35) \
                  & (idealWeatherLocationDataFrame['Humidity'] <= 75), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealWeatherLocationDataFrame['Cloudiness'] <= 5), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealWeatherLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealWeatherLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Weather Location Information**

# %%
idealWeatherLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealWeatherLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealWeatherLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Weather Location Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealWeatherLocationDataFrame,
         'Table: 2: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_d19ff caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d19ff_row0_col0, #T_d19ff_row0_col1, #T_d19ff_row0_col2, #T_d19ff_row0_col3, #T_d19ff_row0_col4, #T_d19ff_row0_col6, #T_d19ff_row0_col7, #T_d19ff_row0_col8, #T_d19ff_row1_col0, #T_d19ff_row1_col1, #T_d19ff_row1_col2, #T_d19ff_row1_col3, #T_d19ff_row1_col4, #T_d19ff_row1_col7, #T_d19ff_row1_col8, #T_d19ff_row2_col0, #T_d19ff_row2_col1, #T_d19ff_row2_col2, #T_d19ff_row2_col3, #T_d19ff_row2_col4, #T_d19ff_row2_col6, #T_d19ff_row2_col7, #T_d19ff_row2_col8, #T_d19ff_row3_col0, #T_d19ff_row3_col1, #T_d19ff_row3_col2, #T_d19ff_row3_col3, #T_d19ff_row3_col4, #T_d19ff_row3_col6, #T_d19ff_row3_col7, #T_d19ff_row3_col8, #T_d19ff_row4_col0, #T_d19ff_row4_col1, #T_d19ff_row4_col2, #T_d19ff_row4_col3, #T_d19ff_row4_col4, #T_d19ff_row4_col6, #T_d19ff_row4_col7, #T_d19ff_row4_col8, #T_d19ff_row5_col0, #T_d19ff_row5_col1, #T_d19ff_row5_col2, #T_d19ff_row5_col3, #T_d19ff_row5_col4, #T_d19ff_row5_col7, #T_d19ff_row5_col8, #T_d19ff_row6_col0, #T_d19ff_row6_col1, #T_d19ff_row6_col2, #T_d19ff_row6_col4, #T_d19ff_row6_col6, #T_d19ff_row6_col7, #T_d19ff_row6_col8, #T_d19ff_row7_col0, #T_d19ff_row7_col1, #T_d19ff_row7_col2, #T_d19ff_row7_col3, #T_d19ff_row7_col4, #T_d19ff_row7_col6, #T_d19ff_row7_col7, #T_d19ff_row7_col8, #T_d19ff_row8_col0, #T_d19ff_row8_col1, #T_d19ff_row8_col2, #T_d19ff_row8_col3, #T_d19ff_row8_col6, #T_d19ff_row8_col7, #T_d19ff_row8_col8, #T_d19ff_row9_col0, #T_d19ff_row9_col1, #T_d19ff_row9_col2, #T_d19ff_row9_col3, #T_d19ff_row9_col6, #T_d19ff_row9_col7, #T_d19ff_row9_col8, #T_d19ff_row10_col0, #T_d19ff_row10_col1, #T_d19ff_row10_col2, #T_d19ff_row10_col3, #T_d19ff_row10_col4, #T_d19ff_row10_col6, #T_d19ff_row10_col7, #T_d19ff_row10_col8, #T_d19ff_row11_col0, #T_d19ff_row11_col1, #T_d19ff_row11_col2, #T_d19ff_row11_col3, #T_d19ff_row11_col4, #T_d19ff_row11_col5, #T_d19ff_row11_col6, #T_d19ff_row11_col7, #T_d19ff_row11_col8, #T_d19ff_row12_col0, #T_d19ff_row12_col1, #T_d19ff_row12_col2, #T_d19ff_row12_col4, #T_d19ff_row12_col6, #T_d19ff_row12_col7, #T_d19ff_row12_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_d19ff_row0_col5, #T_d19ff_row1_col5, #T_d19ff_row2_col5, #T_d19ff_row3_col5, #T_d19ff_row4_col5, #T_d19ff_row5_col5, #T_d19ff_row5_col6, #T_d19ff_row6_col3, #T_d19ff_row6_col5, #T_d19ff_row8_col4, #T_d19ff_row8_col5, #T_d19ff_row9_col5, #T_d19ff_row10_col5, #T_d19ff_row12_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_d19ff_row1_col6, #T_d19ff_row7_col5, #T_d19ff_row9_col4, #T_d19ff_row12_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_d19ff">
#   <caption>Table: 2: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_d19ff_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_d19ff_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_d19ff_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_d19ff_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_d19ff_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_d19ff_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_d19ff_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_d19ff_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_d19ff_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d19ff_row0_col0" class="data row0 col0" >careiro da varzea</td>
#       <td id="T_d19ff_row0_col1" class="data row0 col1" >-3.20</td>
#       <td id="T_d19ff_row0_col2" class="data row0 col2" >-59.81</td>
#       <td id="T_d19ff_row0_col3" class="data row0 col3" >79.41° F</td>
#       <td id="T_d19ff_row0_col4" class="data row0 col4" >71%</td>
#       <td id="T_d19ff_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_d19ff_row0_col6" class="data row0 col6" >4.07</td>
#       <td id="T_d19ff_row0_col7" class="data row0 col7" >BR</td>
#       <td id="T_d19ff_row0_col8" class="data row0 col8" >2023-08-27 00:51:05</td>
#     </tr>
#     <tr>
#       <td id="T_d19ff_row1_col0" class="data row1 col0" >constantia</td>
#       <td id="T_d19ff_row1_col1" class="data row1 col1" >44.18</td>
#       <td id="T_d19ff_row1_col2" class="data row1 col2" >28.65</td>
#       <td id="T_d19ff_row1_col3" class="data row1 col3" >84.88° F</td>
#       <td id="T_d19ff_row1_col4" class="data row1 col4" >57%</td>
#       <td id="T_d19ff_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_d19ff_row1_col6" class="data row1 col6" >9.82</td>
#       <td id="T_d19ff_row1_col7" class="data row1 col7" >RO</td>
#       <td id="T_d19ff_row1_col8" class="data row1 col8" >2023-08-27 00:44:21</td>
#     </tr>
#     <tr>
#       <td id="T_d19ff_row2_col0" class="data row2 col0" >sirte</td>
#       <td id="T_d19ff_row2_col1" class="data row2 col1" >31.21</td>
#       <td id="T_d19ff_row2_col2" class="data row2 col2" >16.59</td>
#       <td id="T_d19ff_row2_col3" class="data row2 col3" >84.42° F</td>
#       <td id="T_d19ff_row2_col4" class="data row2 col4" >52%</td>
#       <td id="T_d19ff_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_d19ff_row2_col6" class="data row2 col6" >4.03</td>
#       <td id="T_d19ff_row2_col7" class="data row2 col7" >LY</td>
#       <td id="T_d19ff_row2_col8" class="data row2 col8" >2023-08-27 00:51:32</td>
#     </tr>
#     <tr>
#       <td id="T_d19ff_row3_col0" class="data row3 col0" >florence</td>
#       <td id="T_d19ff_row3_col1" class="data row3 col1" >43.77</td>
#       <td id="T_d19ff_row3_col2" class="data row3 col2" >11.25</td>
#       <td id="T_d19ff_row3_col3" class="data row3 col3" >81.55° F</td>
#       <td id="T_d19ff_row3_col4" class="data row3 col4" >60%</td>
#       <td id="T_d19ff_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_d19ff_row3_col6" class="data row3 col6" >8.05</td>
#       <td id="T_d19ff_row3_col7" class="data row3 col7" >IT</td>
#       <td id="T_d19ff_row3_col8" class="data row3 col8" >2023-08-27 00:51:42</td>
#     </tr>
#     <tr>
#       <td id="T_d19ff_row4_col0" class="data row4 col0" >belyy yar</td>
#       <td id="T_d19ff_row4_col1" class="data row4 col1" >53.60</td>
#       <td id="T_d19ff_row4_col2" class="data row4 col2" >91.39</td>
#       <td id="T_d19ff_row4_col3" class="data row4 col3" >78.69° F</td>
#       <td id="T_d19ff_row4_col4" class="data row4 col4" >53%</td>
#       <td id="T_d19ff_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_d19ff_row4_col6" class="data row4 col6" >4.47</td>
#       <td id="T_d19ff_row4_col7" class="data row4 col7" >RU</td>
#       <td id="T_d19ff_row4_col8" class="data row4 col8" >2023-08-27 00:51:57</td>
#     </tr>
#     <tr>
#       <td id="T_d19ff_row5_col0" class="data row5 col0" >kerrville</td>
#       <td id="T_d19ff_row5_col1" class="data row5 col1" >30.05</td>
#       <td id="T_d19ff_row5_col2" class="data row5 col2" >-99.14</td>
#       <td id="T_d19ff_row5_col3" class="data row5 col3" >77.94° F</td>
#       <td id="T_d19ff_row5_col4" class="data row5 col4" >57%</td>
#       <td id="T_d19ff_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_d19ff_row5_col6" class="data row5 col6" >0.00</td>
#       <td id="T_d19ff_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_d19ff_row5_col8" class="data row5 col8" >2023-08-27 00:52:24</td>
#     </tr>
#     <tr>
#       <td id="T_d19ff_row6_col0" class="data row6 col0" >bodaybo</td>
#       <td id="T_d19ff_row6_col1" class="data row6 col1" >57.85</td>
#       <td id="T_d19ff_row6_col2" class="data row6 col2" >114.19</td>
#       <td id="T_d19ff_row6_col3" class="data row6 col3" >77.52° F</td>
#       <td id="T_d19ff_row6_col4" class="data row6 col4" >45%</td>
#       <td id="T_d19ff_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_d19ff_row6_col6" class="data row6 col6" >1.43</td>
#       <td id="T_d19ff_row6_co

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealWeatherLocationDataFrame,
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealWeatherLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Pousada "Aldenora" in careiro da varzea, BR
#
#
# Located the following hotel...Hotel Chérica in constantia, RO
#
#
# Located the following hotel...فندق المدينة-سرت in sirte, LY
#
#
# Located the following hotel...Old bridge Apartment in florence, IT
#
#
# Located the following hotel...Inn Of The Hills in kerrville, US
#
#
# Located the following hotel...НОЙ in bodaybo, RU
#
#
# Located the following hotel...Kabash Inn in yambio, SS
#
#
# Located the following hotel...The Salt Raker Inn in cockburn town, TC
#
#
# Located the following hotel...Hotel Lux- Grand Gaube in grand gaube, MU
#
#
# Located the following hotel...Airotel Patras Smart in ovria, GR
#
#
# Located the following hotel...الفندق السياحى in misratah, LY
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3: Hotel Locations')
# Out:
# <style type="text/css">
# #T_14a2b caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_14a2b_row0_col0, #T_14a2b_row0_col1, #T_14a2b_row0_col2, #T_14a2b_row0_col3, #T_14a2b_row0_col4, #T_14a2b_row0_col6, #T_14a2b_row0_col7, #T_14a2b_row0_col8, #T_14a2b_row0_col9, #T_14a2b_row1_col0, #T_14a2b_row1_col1, #T_14a2b_row1_col2, #T_14a2b_row1_col3, #T_14a2b_row1_col4, #T_14a2b_row1_col7, #T_14a2b_row1_col8, #T_14a2b_row1_col9, #T_14a2b_row2_col0, #T_14a2b_row2_col1, #T_14a2b_row2_col2, #T_14a2b_row2_col3, #T_14a2b_row2_col4, #T_14a2b_row2_col6, #T_14a2b_row2_col7, #T_14a2b_row2_col8, #T_14a2b_row2_col9, #T_14a2b_row3_col0, #T_14a2b_row3_col1, #T_14a2b_row3_col2, #T_14a2b_row3_col3, #T_14a2b_row3_col4, #T_14a2b_row3_col6, #T_14a2b_row3_col7, #T_14a2b_row3_col8, #T_14a2b_row3_col9, #T_14a2b_row4_col0, #T_14a2b_row4_col1, #T_14a2b_row4_col2, #T_14a2b_row4_col3, #T_14a2b_row4_col4, #T_14a2b_row4_col7, #T_14a2b_row4_col8, #T_14a2b_row4_col9, #T_14a2b_row5_col0, #T_14a2b_row5_col1, #T_14a2b_row5_col2, #T_14a2b_row5_col6, #T_14a2b_row5_col7, #T_14a2b_row5_col8, #T_14a2b_row5_col9, #T_14a2b_row6_col0, #T_14a2b_row6_col1, #T_14a2b_row6_col2, #T_14a2b_row6_col3, #T_14a2b_row6_col4, #T_14a2b_row6_col6, #T_14a2b_row6_col7, #T_14a2b_row6_col8, #T_14a2b_row6_col9, #T_14a2b_row7_col0, #T_14a2b_row7_col1, #T_14a2b_row7_col2, #T_14a2b_row7_col3, #T_14a2b_row7_col6, #T_14a2b_row7_col7, #T_14a2b_row7_col8, #T_14a2b_row7_col9, #T_14a2b_row8_col0, #T_14a2b_row8_col1, #T_14a2b_row8_col2, #T_14a2b_row8_col3, #T_14a2b_row8_col4, #T_14a2b_row8_col6, #T_14a2b_row8_col7, #T_14a2b_row8_col8, #T_14a2b_row8_col9, #T_14a2b_row9_col0, #T_14a2b_row9_col1, #T_14a2b_row9_col2, #T_14a2b_row9_col3, #T_14a2b_row9_col4, #T_14a2b_row9_col5, #T_14a2b_row9_col6, #T_14a2b_row9_col7, #T_14a2b_row9_col8, #T_14a2b_row9_col9, #T_14a2b_row10_col0, #T_14a2b_row10_col1, #T_14a2b_row10_col2, #T_14a2b_row10_col4, #T_14a2b_row10_col6, #T_14a2b_row10_col7, #T_14a2b_row10_col8, #T_14a2b_row10_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_14a2b_row0_col5, #T_14a2b_row1_col5, #T_14a2b_row2_col5, #T_14a2b_row3_col5, #T_14a2b_row4_col5, #T_14a2b_row4_col6, #T_14a2b_row5_col3, #T_14a2b_row5_col4, #T_14a2b_row5_col5, #T_14a2b_row7_col5, #T_14a2b_row8_col5, #T_14a2b_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_14a2b_row1_col6, #T_14a2b_row6_col5, #T_14a2b_row7_col4, #T_14a2b_row10_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_14a2b">
#   <caption>Table: 3: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_14a2b_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_14a2b_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_14a2b_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_14a2b_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_14a2b_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_14a2b_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_14a2b_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_14a2b_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_14a2b_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_14a2b_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_14a2b_row0_col0" class="data row0 col0" >careiro da varzea</td>
#       <td id="T_14a2b_row0_col1" class="data row0 col1" >-3.20</td>
#       <td id="T_14a2b_row0_col2" class="data row0 col2" >-59.81</td>
#       <td id="T_14a2b_row0_col3" class="data row0 col3" >79.41° F</td>
#       <td id="T_14a2b_row0_col4" class="data row0 col4" >71%</td>
#       <td id="T_14a2b_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_14a2b_row0_col6" class="data row0 col6" >4.07</td>
#       <td id="T_14a2b_row0_col7" class="data row0 col7" >BR</td>
#       <td id="T_14a2b_row0_col8" class="data row0 col8" >2023-08-27 00:51:05</td>
#       <td id="T_14a2b_row0_col9" class="data row0 col9" >Pousada "Aldenora"</td>
#     </tr>
#     <tr>
#       <td id="T_14a2b_row1_col0" class="data row1 col0" >constantia</td>
#       <td id="T_14a2b_row1_col1" class="data row1 col1" >44.18</td>
#       <td id="T_14a2b_row1_col2" class="data row1 col2" >28.65</td>
#       <td id="T_14a2b_row1_col3" class="data row1 col3" >84.88° F</td>
#       <td id="T_14a2b_row1_col4" class="data row1 col4" >57%</td>
#       <td id="T_14a2b_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_14a2b_row1_col6" class="data row1 col6" >9.82</td>
#       <td id="T_14a2b_row1_col7" class="data row1 col7" >RO</td>
#       <td id="T_14a2b_row1_col8" class="data row1 col8" >2023-08-27 00:44:21</td>
#       <td id="T_14a2b_row1_col9" class="data row1 col9" >Hotel Chérica</td>
#     </tr>
#     <tr>
#       <td id="T_14a2b_row2_col0" class="data row2 col0" >sirte</td>
#       <td id="T_14a2b_row2_col1" class="data row2 col1" >31.21</td>
#       <td id="T_14a2b_row2_col2" class="data row2 col2" >16.59</td>
#       <td id="T_14a2b_row2_col3" class="data row2 col3" >84.42° F</td>
#       <td id="T_14a2b_row2_col4" class="data row2 col4" >52%</td>
#       <td id="T_14a2b_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_14a2b_row2_col6" class="data row2 col6" >4.03</td>
#       <td id="T_14a2b_row2_col7" class="data row2 col7" >LY</td>
#       <td id="T_14a2b_row2_col8" class="data row2 col8" >2023-08-27 00:51:32</td>
#       <td id="T_14a2b_row2_col9" class="data row2 col9" >فندق المدينة-سرت</td>
#     </tr>
#     <tr>
#       <td id="T_14a2b_row3_col0" class="data row3 col0" >florence</td>
#       <td id="T_14a2b_row3_col1" class="data row3 col1" >43.77</td>
#       <td id="T_14a2b_row3_col2" class="data row3 col2" >11.25</td>
#       <td id="T_14a2b_row3_col3" class="data row3 col3" >81.55° F</td>
#       <td id="T_14a2b_row3_col4" class="data row3 col4" >60%</td>
#       <td id="T_14a2b_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_14a2b_row3_col6" class="data row3 col6" >8.05</td>
#       <td id="T_14a2b_row3_col7" class="data row3 col7" >IT</td>
#       <td id="T_14a2b_row3_col8" class="data row3 col8" >2023-08-27 00:51:42</td>
#       <td id="T_14a2b_row3_col9" class="data row3 col9" >Old bridge Apartment</td>
#     </tr>
#     <tr>
#       <td id="T_14a2b_row4_col0" class="data row4 col0" >kerrville</td>
#       <td id="T_14a2b_row4_col1" class="data row4 col1" >30.05</td>
#       <td id="T_14a2b_row4_col2" class="data row4 col2" >-99.14</td>
#       <td id="T_14a2b_row4_col3" class="data row4 col3" >77.94° F</td>
#       <td id="T_14a2b_row4_col4" class="data row4 col4" >57%</td>
#       <td id="T_14a2b_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_14a2b_row4_col6" class="data row4 col6" >0.00</td>
#       <td id="T_14a2b_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_14a2b_row4_col8" class="data row4 col8" >2023-08-27 00:52:24</td>
#       <td id="T_14a2b_row4_col9" class="data row4 col9" >Inn Of The Hills</td>
#     </tr>
#     <tr>
#       <td id="T_14a2b_row5_col0" class="data row5 col0" >bodaybo</td>
#       <td id="T_14a2b_row5_col1" class="data row5 col1" >57.85</td>
#       <td id="T_14a2b_row5_col2" class="data row5 col2" >114.19</td>
#       <td id="T_14a2b_row5_col3" class="data row5 col3" >77.52° F</td>
#       <td id="T_14a2b_row5_col4" class="data row5 col4" >45%</td>
#       <td id="T_14a2b_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_14a2b_row5_col6" class="data row5 col6" >1.43</td>
#       <td id="T_14a2b_row5_col7" class="data row5 col7" >RU</td>
#       <td id="T_14a2b_row5_col8" class="data row5 col8" >2023-08-27 00:52:26</td>
#       <td id="T_14a2b_row5_col9" class="data row5 col9" >НОЙ</td>
#     </tr>
#     <tr>
#       <td id="T_14a2b_row6_col0" class="data row6 col0" >yambio</td>
#       <td id="T_14a2b_row6_col1" class="data row6 col1"

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
log_subroutine \
    .EndProgramExecution()
# Out:
# Program execution ends at 08/27/2023 00:56:31.
