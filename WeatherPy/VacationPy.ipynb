# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_a7b46 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_a7b46_row0_col0, #T_a7b46_row0_col1, #T_a7b46_row0_col2, #T_a7b46_row0_col4, #T_a7b46_row0_col5, #T_a7b46_row0_col7, #T_a7b46_row0_col8, #T_a7b46_row1_col0, #T_a7b46_row1_col1, #T_a7b46_row1_col2, #T_a7b46_row1_col3, #T_a7b46_row1_col4, #T_a7b46_row1_col5, #T_a7b46_row1_col6, #T_a7b46_row1_col7, #T_a7b46_row1_col8, #T_a7b46_row2_col0, #T_a7b46_row2_col1, #T_a7b46_row2_col2, #T_a7b46_row2_col5, #T_a7b46_row2_col6, #T_a7b46_row2_col7, #T_a7b46_row2_col8, #T_a7b46_row3_col0, #T_a7b46_row3_col1, #T_a7b46_row3_col2, #T_a7b46_row3_col3, #T_a7b46_row3_col4, #T_a7b46_row3_col6, #T_a7b46_row3_col7, #T_a7b46_row3_col8, #T_a7b46_row4_col0, #T_a7b46_row4_col1, #T_a7b46_row4_col2, #T_a7b46_row4_col3, #T_a7b46_row4_col4, #T_a7b46_row4_col7, #T_a7b46_row4_col8, #T_a7b46_row5_col0, #T_a7b46_row5_col1, #T_a7b46_row5_col2, #T_a7b46_row5_col3, #T_a7b46_row5_col5, #T_a7b46_row5_col6, #T_a7b46_row5_col7, #T_a7b46_row5_col8, #T_a7b46_row6_col0, #T_a7b46_row6_col1, #T_a7b46_row6_col2, #T_a7b46_row6_col3, #T_a7b46_row6_col4, #T_a7b46_row6_col5, #T_a7b46_row6_col6, #T_a7b46_row6_col7, #T_a7b46_row6_col8, #T_a7b46_row7_col0, #T_a7b46_row7_col1, #T_a7b46_row7_col2, #T_a7b46_row7_col3, #T_a7b46_row7_col4, #T_a7b46_row7_col6, #T_a7b46_row7_col7, #T_a7b46_row7_col8, #T_a7b46_row8_col0, #T_a7b46_row8_col1, #T_a7b46_row8_col2, #T_a7b46_row8_col3, #T_a7b46_row8_col4, #T_a7b46_row8_col5, #T_a7b46_row8_col6, #T_a7b46_row8_col7, #T_a7b46_row8_col8, #T_a7b46_row9_col0, #T_a7b46_row9_col1, #T_a7b46_row9_col2, #T_a7b46_row9_col3, #T_a7b46_row9_col4, #T_a7b46_row9_col5, #T_a7b46_row9_col6, #T_a7b46_row9_col7, #T_a7b46_row9_col8, #T_a7b46_row10_col0, #T_a7b46_row10_col1, #T_a7b46_row10_col2, #T_a7b46_row10_col3, #T_a7b46_row10_col4, #T_a7b46_row10_col5, #T_a7b46_row10_col6, #T_a7b46_row10_col7, #T_a7b46_row10_col8, #T_a7b46_row11_col0, #T_a7b46_row11_col1, #T_a7b46_row11_col2, #T_a7b46_row11_col3, #T_a7b46_row11_col4, #T_a7b46_row11_col5, #T_a7b46_row11_col6, #T_a7b46_row11_col7, #T_a7b46_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_a7b46_row0_col3, #T_a7b46_row2_col4, #T_a7b46_row3_col5, #T_a7b46_row4_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_a7b46_row0_col6, #T_a7b46_row2_col3, #T_a7b46_row4_col5, #T_a7b46_row5_col4, #T_a7b46_row7_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_a7b46">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_a7b46_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_a7b46_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_a7b46_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_a7b46_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_a7b46_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_a7b46_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_a7b46_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_a7b46_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_a7b46_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a7b46_row0_col0" class="data row0 col0" >port-aux-francais</td>
#       <td id="T_a7b46_row0_col1" class="data row0 col1" >-49.35</td>
#       <td id="T_a7b46_row0_col2" class="data row0 col2" >70.22</td>
#       <td id="T_a7b46_row0_col3" class="data row0 col3" >32.97° F</td>
#       <td id="T_a7b46_row0_col4" class="data row0 col4" >79%</td>
#       <td id="T_a7b46_row0_col5" class="data row0 col5" >89%</td>
#       <td id="T_a7b46_row0_col6" class="data row0 col6" >45.50</td>
#       <td id="T_a7b46_row0_col7" class="data row0 col7" >TF</td>
#       <td id="T_a7b46_row0_col8" class="data row0 col8" >2023-08-29 19:48:29</td>
#     </tr>
#     <tr>
#       <td id="T_a7b46_row1_col0" class="data row1 col0" >atafu village</td>
#       <td id="T_a7b46_row1_col1" class="data row1 col1" >-8.54</td>
#       <td id="T_a7b46_row1_col2" class="data row1 col2" >-172.52</td>
#       <td id="T_a7b46_row1_col3" class="data row1 col3" >83.14° F</td>
#       <td id="T_a7b46_row1_col4" class="data row1 col4" >78%</td>
#       <td id="T_a7b46_row1_col5" class="data row1 col5" >21%</td>
#       <td id="T_a7b46_row1_col6" class="data row1 col6" >15.77</td>
#       <td id="T_a7b46_row1_col7" class="data row1 col7" >TK</td>
#       <td id="T_a7b46_row1_col8" class="data row1 col8" >2023-08-29 19:45:03</td>
#     </tr>
#     <tr>
#       <td id="T_a7b46_row2_col0" class="data row2 col0" >kununurra</td>
#       <td id="T_a7b46_row2_col1" class="data row2 col1" >-15.77</td>
#       <td id="T_a7b46_row2_col2" class="data row2 col2" >128.73</td>
#       <td id="T_a7b46_row2_col3" class="data row2 col3" >91.38° F</td>
#       <td id="T_a7b46_row2_col4" class="data row2 col4" >17%</td>
#       <td id="T_a7b46_row2_col5" class="data row2 col5" >10%</td>
#       <td id="T_a7b46_row2_col6" class="data row2 col6" >17.27</td>
#       <td id="T_a7b46_row2_col7" class="data row2 col7" >AU</td>
#       <td id="T_a7b46_row2_col8" class="data row2 col8" >2023-08-29 19:48:30</td>
#     </tr>
#     <tr>
#       <td id="T_a7b46_row3_col0" class="data row3 col0" >papatowai</td>
#       <td id="T_a7b46_row3_col1" class="data row3 col1" >-46.56</td>
#       <td id="T_a7b46_row3_col2" class="data row3 col2" >169.47</td>
#       <td id="T_a7b46_row3_col3" class="data row3 col3" >55.53° F</td>
#       <td id="T_a7b46_row3_col4" class="data row3 col4" >60%</td>
#       <td id="T_a7b46_row3_col5" class="data row3 col5" >3%</td>
#       <td id="T_a7b46_row3_col6" class="data row3 col6" >5.93</td>
#       <td id="T_a7b46_row3_col7" class="data row3 col7" >NZ</td>
#       <td id="T_a7b46_row3_col8" class="data row3 col8" >2023-08-29 19:43:38</td>
#     </tr>
#     <tr>
#       <td id="T_a7b46_row4_col0" class="data row4 col0" >dadukou</td>
#       <td id="T_a7b46_row4_col1" class="data row4 col1" >26.55</td>
#       <td id="T_a7b46_row4_col2" class="data row4 col2" >101.71</td>
#       <td id="T_a7b46_row4_col3" class="data row4 col3" >66.45° F</td>
#       <td id="T_a7b46_row4_col4" class="data row4 col4" >89%</td>
#       <td id="T_a7b46_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_a7b46_row4_col6" class="data row4 col6" >2.24</td>
#       <td id="T_a7b46_row4_col7" class="data row4 col7" >CN</td>
#       <td id="T_a7b46_row4_col8" class="data row4 col8" >2023-08-29 19:48:31</td>
#     </tr>
#     <tr>
#       <td id="T_a7b46_row5_col0" class="data row5 col0" >kapuskasing</td>
#       <td id="T_a7b46_row5_col1" class="data row5 col1" >49.42</td>
#       <td id="T_a7b46_row5_col2" class="data row5 col2" >-82.43</td>
#       <td id="T_a7b46_row5_col3" class="data row5 col3" >44.60° F</td>
#       <td id="T_a7b46_row5_col4" class="data row5 col4" >93%</td>
#       <td id="T_a7b46_row5_col5" class="data row5 col5" >75%</td>
#       <td id="T_a7b46_row5_col6" class="data row5 col6" >4.61</td>
#       <td id="T_a7b46_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_a7b46_row5_col8" class="data row5 col8" >2023-08-29 19:44:02</td>
#     </tr>
#     <tr>
#       <td id="T_a7b46_row6_col0" class="data row6 col0" >edinburgh of the seven seas</td>
#       <td id="T_a7b46_row6_col1" class="data row6 col1" >-37.07</td>
#       <td id="T_a7b46_row6_col2" class="data row6 col2" >-12.31</td>
#       <td id="T_a7b46_row6_col3" class="data row6 col3" >51.01° F</td>
#       <td id="T_a7b46_row6_col4" class="data row6 col4" >57%</td>
#       <td id="T_a7b46_row6_col5" class="data row6 col5" >79%</td>
#       <td id="T_a7b46_row6_col6" class="data row6 col6" >23.35</td>
#       <td id="T_a7b46_row6_col7" class="data row6 col7" >SH</td>
#       <td id="T_a7b46_row6_col8" class="data row6 col8" >2023-08-29 19:48:33</td>
#     </tr>
#     <tr>

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 35) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 75), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 5), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_27caa caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_27caa_row0_col0, #T_27caa_row0_col1, #T_27caa_row0_col2, #T_27caa_row0_col3, #T_27caa_row0_col7, #T_27caa_row0_col8, #T_27caa_row1_col0, #T_27caa_row1_col1, #T_27caa_row1_col2, #T_27caa_row1_col6, #T_27caa_row1_col7, #T_27caa_row1_col8, #T_27caa_row2_col0, #T_27caa_row2_col1, #T_27caa_row2_col2, #T_27caa_row2_col3, #T_27caa_row2_col4, #T_27caa_row2_col6, #T_27caa_row2_col7, #T_27caa_row2_col8, #T_27caa_row3_col0, #T_27caa_row3_col1, #T_27caa_row3_col2, #T_27caa_row3_col3, #T_27caa_row3_col4, #T_27caa_row3_col5, #T_27caa_row3_col6, #T_27caa_row3_col7, #T_27caa_row3_col8, #T_27caa_row4_col0, #T_27caa_row4_col1, #T_27caa_row4_col2, #T_27caa_row4_col3, #T_27caa_row4_col4, #T_27caa_row4_col6, #T_27caa_row4_col7, #T_27caa_row4_col8, #T_27caa_row5_col0, #T_27caa_row5_col1, #T_27caa_row5_col2, #T_27caa_row5_col3, #T_27caa_row5_col6, #T_27caa_row5_col7, #T_27caa_row5_col8, #T_27caa_row6_col0, #T_27caa_row6_col1, #T_27caa_row6_col2, #T_27caa_row6_col3, #T_27caa_row6_col4, #T_27caa_row6_col7, #T_27caa_row6_col8, #T_27caa_row7_col0, #T_27caa_row7_col1, #T_27caa_row7_col2, #T_27caa_row7_col4, #T_27caa_row7_col6, #T_27caa_row7_col7, #T_27caa_row7_col8, #T_27caa_row8_col0, #T_27caa_row8_col1, #T_27caa_row8_col2, #T_27caa_row8_col3, #T_27caa_row8_col4, #T_27caa_row8_col6, #T_27caa_row8_col7, #T_27caa_row8_col8, #T_27caa_row9_col0, #T_27caa_row9_col1, #T_27caa_row9_col2, #T_27caa_row9_col3, #T_27caa_row9_col4, #T_27caa_row9_col6, #T_27caa_row9_col7, #T_27caa_row9_col8, #T_27caa_row10_col0, #T_27caa_row10_col1, #T_27caa_row10_col2, #T_27caa_row10_col3, #T_27caa_row10_col4, #T_27caa_row10_col6, #T_27caa_row10_col7, #T_27caa_row10_col8, #T_27caa_row11_col0, #T_27caa_row11_col1, #T_27caa_row11_col2, #T_27caa_row11_col3, #T_27caa_row11_col4, #T_27caa_row11_col6, #T_27caa_row11_col7, #T_27caa_row11_col8, #T_27caa_row12_col0, #T_27caa_row12_col1, #T_27caa_row12_col2, #T_27caa_row12_col3, #T_27caa_row12_col4, #T_27caa_row12_col5, #T_27caa_row12_col6, #T_27caa_row12_col7, #T_27caa_row12_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_27caa_row0_col4, #T_27caa_row6_col6, #T_27caa_row7_col3, #T_27caa_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_27caa_row0_col5, #T_27caa_row0_col6, #T_27caa_row1_col3, #T_27caa_row1_col4, #T_27caa_row1_col5, #T_27caa_row2_col5, #T_27caa_row4_col5, #T_27caa_row5_col4, #T_27caa_row5_col5, #T_27caa_row6_col5, #T_27caa_row7_col5, #T_27caa_row8_col5, #T_27caa_row10_col5, #T_27caa_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_27caa">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_27caa_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_27caa_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_27caa_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_27caa_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_27caa_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_27caa_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_27caa_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_27caa_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_27caa_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_27caa_row0_col0" class="data row0 col0" >chazuta</td>
#       <td id="T_27caa_row0_col1" class="data row0 col1" >-6.57</td>
#       <td id="T_27caa_row0_col2" class="data row0 col2" >-76.14</td>
#       <td id="T_27caa_row0_col3" class="data row0 col3" >81.45° F</td>
#       <td id="T_27caa_row0_col4" class="data row0 col4" >74%</td>
#       <td id="T_27caa_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_27caa_row0_col6" class="data row0 col6" >0.27</td>
#       <td id="T_27caa_row0_col7" class="data row0 col7" >PE</td>
#       <td id="T_27caa_row0_col8" class="data row0 col8" >2023-08-29 19:49:18</td>
#     </tr>
#     <tr>
#       <td id="T_27caa_row1_col0" class="data row1 col0" >khandyga</td>
#       <td id="T_27caa_row1_col1" class="data row1 col1" >62.67</td>
#       <td id="T_27caa_row1_col2" class="data row1 col2" >135.60</td>
#       <td id="T_27caa_row1_col3" class="data row1 col3" >76.28° F</td>
#       <td id="T_27caa_row1_col4" class="data row1 col4" >49%</td>
#       <td id="T_27caa_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_27caa_row1_col6" class="data row1 col6" >4.99</td>
#       <td id="T_27caa_row1_col7" class="data row1 col7" >RU</td>
#       <td id="T_27caa_row1_col8" class="data row1 col8" >2023-08-29 19:40:23</td>
#     </tr>
#     <tr>
#       <td id="T_27caa_row2_col0" class="data row2 col0" >wacheng</td>
#       <td id="T_27caa_row2_col1" class="data row2 col1" >33.78</td>
#       <td id="T_27caa_row2_col2" class="data row2 col2" >114.52</td>
#       <td id="T_27caa_row2_col3" class="data row2 col3" >81.19° F</td>
#       <td id="T_27caa_row2_col4" class="data row2 col4" >62%</td>
#       <td id="T_27caa_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_27caa_row2_col6" class="data row2 col6" >2.13</td>
#       <td id="T_27caa_row2_col7" class="data row2 col7" >CN</td>
#       <td id="T_27caa_row2_col8" class="data row2 col8" >2023-08-29 19:49:25</td>
#     </tr>
#     <tr>
#       <td id="T_27caa_row3_col0" class="data row3 col0" >pauini</td>
#       <td id="T_27caa_row3_col1" class="data row3 col1" >-7.71</td>
#       <td id="T_27caa_row3_col2" class="data row3 col2" >-66.98</td>
#       <td id="T_27caa_row3_col3" class="data row3 col3" >79.03° F</td>
#       <td id="T_27caa_row3_col4" class="data row3 col4" >60%</td>
#       <td id="T_27caa_row3_col5" class="data row3 col5" >1%</td>
#       <td id="T_27caa_row3_col6" class="data row3 col6" >0.87</td>
#       <td id="T_27caa_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_27caa_row3_col8" class="data row3 col8" >2023-08-29 19:41:04</td>
#     </tr>
#     <tr>
#       <td id="T_27caa_row4_col0" class="data row4 col0" >xianshuigu</td>
#       <td id="T_27caa_row4_col1" class="data row4 col1" >38.98</td>
#       <td id="T_27caa_row4_col2" class="data row4 col2" >117.38</td>
#       <td id="T_27caa_row4_col3" class="data row4 col3" >82.40° F</td>
#       <td id="T_27caa_row4_col4" class="data row4 col4" >51%</td>
#       <td id="T_27caa_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_27caa_row4_col6" class="data row4 col6" >4.47</td>
#       <td id="T_27caa_row4_col7" class="data row4 col7" >CN</td>
#       <td id="T_27caa_row4_col8" class="data row4 col8" >2023-08-29 19:49:39</td>
#     </tr>
#     <tr>
#       <td id="T_27caa_row5_col0" class="data row5 col0" >karystos</td>
#       <td id="T_27caa_row5_col1" class="data row5 col1" >38.01</td>
#       <td id="T_27caa_row5_col2" class="data row5 col2" >24.42</td>
#       <td id="T_27caa_row5_col3" class="data row5 col3" >81.18° F</td>
#       <td id="T_27caa_row5_col4" class="data row5 col4" >49%</td>
#       <td id="T_27caa_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_27caa_row5_col6" class="data row5 col6" >4.00</td>
#       <td id="T_27caa_row5_col7" class="data row5 col7" >GR</td>
#       <td id="T_27caa_row5_col8" class="data row5 col8" >2023-08-29 19:49:42</td>
#     </tr>
#     <tr>
#       <td id="T_27caa_row6_col0" class="data row6 col0" >long beach</td>
#       <td id="T_27caa_row6_col1" class="data row6 col1" >33.77</td>
#       <td id="T_27caa_row6_col2" class="data row6 col2" >-118.19</td>
#       <td id="T_27caa_row6_col3" class="data row6 col3" >78.53° F</td>
#       <td id="T_27caa_row6_col4" class="data row6 col4" >60%</td>
#       <td id="T_27caa_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_27caa_row6_col6" class="data row6 col6" >9.22</td>
#       <td id="T_27caa_row6_col7"

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Апельсин in khandyga, RU
#
#
# Located the following hotel...天津京基皇冠假日酒店 in xianshuigu, CN
#
#
# Located the following hotel...Galaxy Hotel in karystos, GR
#
#
# Located the following hotel...Westin in long beach, US
#
#
# Located the following hotel...Hampton Inn & Suites in patterson, US
#
#
# Located the following hotel...Hotel Acropolis in paros, GR
#
#
# Located the following hotel...Ивушка in kirensk, RU
#
#
# Located the following hotel...微山湖宾馆 in xiazhen, CN
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_2c4b5 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_2c4b5_row0_col0, #T_2c4b5_row0_col1, #T_2c4b5_row0_col2, #T_2c4b5_row0_col6, #T_2c4b5_row0_col7, #T_2c4b5_row0_col8, #T_2c4b5_row0_col9, #T_2c4b5_row1_col0, #T_2c4b5_row1_col1, #T_2c4b5_row1_col2, #T_2c4b5_row1_col3, #T_2c4b5_row1_col4, #T_2c4b5_row1_col6, #T_2c4b5_row1_col7, #T_2c4b5_row1_col8, #T_2c4b5_row1_col9, #T_2c4b5_row2_col0, #T_2c4b5_row2_col1, #T_2c4b5_row2_col2, #T_2c4b5_row2_col3, #T_2c4b5_row2_col6, #T_2c4b5_row2_col7, #T_2c4b5_row2_col8, #T_2c4b5_row2_col9, #T_2c4b5_row3_col0, #T_2c4b5_row3_col1, #T_2c4b5_row3_col2, #T_2c4b5_row3_col3, #T_2c4b5_row3_col4, #T_2c4b5_row3_col7, #T_2c4b5_row3_col8, #T_2c4b5_row3_col9, #T_2c4b5_row4_col0, #T_2c4b5_row4_col1, #T_2c4b5_row4_col2, #T_2c4b5_row4_col4, #T_2c4b5_row4_col6, #T_2c4b5_row4_col7, #T_2c4b5_row4_col8, #T_2c4b5_row4_col9, #T_2c4b5_row5_col0, #T_2c4b5_row5_col1, #T_2c4b5_row5_col2, #T_2c4b5_row5_col3, #T_2c4b5_row5_col6, #T_2c4b5_row5_col7, #T_2c4b5_row5_col8, #T_2c4b5_row5_col9, #T_2c4b5_row6_col0, #T_2c4b5_row6_col1, #T_2c4b5_row6_col2, #T_2c4b5_row6_col3, #T_2c4b5_row6_col4, #T_2c4b5_row6_col6, #T_2c4b5_row6_col7, #T_2c4b5_row6_col8, #T_2c4b5_row6_col9, #T_2c4b5_row7_col0, #T_2c4b5_row7_col1, #T_2c4b5_row7_col2, #T_2c4b5_row7_col3, #T_2c4b5_row7_col4, #T_2c4b5_row7_col7, #T_2c4b5_row7_col8, #T_2c4b5_row7_col9, #T_2c4b5_row8_col0, #T_2c4b5_row8_col1, #T_2c4b5_row8_col2, #T_2c4b5_row8_col3, #T_2c4b5_row8_col4, #T_2c4b5_row8_col6, #T_2c4b5_row8_col7, #T_2c4b5_row8_col8, #T_2c4b5_row8_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_2c4b5_row0_col3, #T_2c4b5_row0_col4, #T_2c4b5_row0_col5, #T_2c4b5_row1_col5, #T_2c4b5_row2_col4, #T_2c4b5_row2_col5, #T_2c4b5_row3_col5, #T_2c4b5_row4_col5, #T_2c4b5_row5_col5, #T_2c4b5_row6_col5, #T_2c4b5_row7_col5, #T_2c4b5_row7_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_2c4b5_row3_col6, #T_2c4b5_row4_col3, #T_2c4b5_row5_col4, #T_2c4b5_row8_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_2c4b5">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_2c4b5_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_2c4b5_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_2c4b5_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_2c4b5_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_2c4b5_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_2c4b5_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_2c4b5_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_2c4b5_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_2c4b5_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_2c4b5_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2c4b5_row0_col0" class="data row0 col0" >khandyga</td>
#       <td id="T_2c4b5_row0_col1" class="data row0 col1" >62.67</td>
#       <td id="T_2c4b5_row0_col2" class="data row0 col2" >135.60</td>
#       <td id="T_2c4b5_row0_col3" class="data row0 col3" >76.28° F</td>
#       <td id="T_2c4b5_row0_col4" class="data row0 col4" >49%</td>
#       <td id="T_2c4b5_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_2c4b5_row0_col6" class="data row0 col6" >4.99</td>
#       <td id="T_2c4b5_row0_col7" class="data row0 col7" >RU</td>
#       <td id="T_2c4b5_row0_col8" class="data row0 col8" >2023-08-29 19:40:23</td>
#       <td id="T_2c4b5_row0_col9" class="data row0 col9" >Апельсин</td>
#     </tr>
#     <tr>
#       <td id="T_2c4b5_row1_col0" class="data row1 col0" >xianshuigu</td>
#       <td id="T_2c4b5_row1_col1" class="data row1 col1" >38.98</td>
#       <td id="T_2c4b5_row1_col2" class="data row1 col2" >117.38</td>
#       <td id="T_2c4b5_row1_col3" class="data row1 col3" >82.40° F</td>
#       <td id="T_2c4b5_row1_col4" class="data row1 col4" >51%</td>
#       <td id="T_2c4b5_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_2c4b5_row1_col6" class="data row1 col6" >4.47</td>
#       <td id="T_2c4b5_row1_col7" class="data row1 col7" >CN</td>
#       <td id="T_2c4b5_row1_col8" class="data row1 col8" >2023-08-29 19:49:39</td>
#       <td id="T_2c4b5_row1_col9" class="data row1 col9" >天津京基皇冠假日酒店</td>
#     </tr>
#     <tr>
#       <td id="T_2c4b5_row2_col0" class="data row2 col0" >karystos</td>
#       <td id="T_2c4b5_row2_col1" class="data row2 col1" >38.01</td>
#       <td id="T_2c4b5_row2_col2" class="data row2 col2" >24.42</td>
#       <td id="T_2c4b5_row2_col3" class="data row2 col3" >81.18° F</td>
#       <td id="T_2c4b5_row2_col4" class="data row2 col4" >49%</td>
#       <td id="T_2c4b5_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_2c4b5_row2_col6" class="data row2 col6" >4.00</td>
#       <td id="T_2c4b5_row2_col7" class="data row2 col7" >GR</td>
#       <td id="T_2c4b5_row2_col8" class="data row2 col8" >2023-08-29 19:49:42</td>
#       <td id="T_2c4b5_row2_col9" class="data row2 col9" >Galaxy Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_2c4b5_row3_col0" class="data row3 col0" >long beach</td>
#       <td id="T_2c4b5_row3_col1" class="data row3 col1" >33.77</td>
#       <td id="T_2c4b5_row3_col2" class="data row3 col2" >-118.19</td>
#       <td id="T_2c4b5_row3_col3" class="data row3 col3" >78.53° F</td>
#       <td id="T_2c4b5_row3_col4" class="data row3 col4" >60%</td>
#       <td id="T_2c4b5_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_2c4b5_row3_col6" class="data row3 col6" >9.22</td>
#       <td id="T_2c4b5_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_2c4b5_row3_col8" class="data row3 col8" >2023-08-29 19:50:05</td>
#       <td id="T_2c4b5_row3_col9" class="data row3 col9" >Westin</td>
#     </tr>
#     <tr>
#       <td id="T_2c4b5_row4_col0" class="data row4 col0" >patterson</td>
#       <td id="T_2c4b5_row4_col1" class="data row4 col1" >37.47</td>
#       <td id="T_2c4b5_row4_col2" class="data row4 col2" >-121.13</td>
#       <td id="T_2c4b5_row4_col3" class="data row4 col3" >82.51° F</td>
#       <td id="T_2c4b5_row4_col4" class="data row4 col4" >53%</td>
#       <td id="T_2c4b5_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_2c4b5_row4_col6" class="data row4 col6" >7.45</td>
#       <td id="T_2c4b5_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_2c4b5_row4_col8" class="data row4 col8" >2023-08-29 19:50:10</td>
#       <td id="T_2c4b5_row4_col9" class="data row4 col9" >Hampton Inn & Suites</td>
#     </tr>
#     <tr>
#       <td id="T_2c4b5_row5_col0" class="data row5 col0" >paros</td>
#       <td id="T_2c4b5_row5_col1" class="data row5 col1" >37.08</td>
#       <td id="T_2c4b5_row5_col2" class="data row5 col2" >25.15</td>
#       <td id="T_2c4b5_row5_col3" class="data row5 col3" >78.39° F</td>
#       <td id="T_2c4b5_row5_col4" class="data row5 col4" >69%</td>
#       <td id="T_2c4b5_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_2c4b5_row5_col6" class="data row5 col6" >6.91</td>
#       <td id="T_2c4b5_row5_col7" class="data row5 col7" >GR</td>
#       <td id="T_2c4b5_row5_col8" class="data row5 col8" >2023-08-29 19:50:22</td>
#       <td id="T_2c4b5_row5_col9" class="data row5 col9" >Hotel Acropolis</td>
#     </tr>
#     <tr>
#       <td id="T_2c4b5_row6_col0" class="data row6 col0" >kirensk</td>
#       <td id="T_2c4b5_row6_col1" class="data row6 col1" >57.79</td>
#       <td id="T_2c4b5_row6_col2" class="data row6 col2" >108.11</td>
#       <td id="T_2c4b5_row6_col3" class="data row6 col3" >76.84° F</td>
#       <td id="T_2c4b5_row6_col4" class="data row6 col4" >51%</td>
#       <td id="T_2c4b5_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_2c4b5_row6_col6" class="data row6 col6" >3.80</td>
#       <td id="T_2c4b5_row6_col7" class="data row6 col7" >RU</td>
#       <td

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
