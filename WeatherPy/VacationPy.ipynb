# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame,
         'Table: 1: City Weather Information')
# Out:
# <style type="text/css">
# #T_0d269 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_0d269_row0_col0, #T_0d269_row0_col1, #T_0d269_row0_col2, #T_0d269_row0_col3, #T_0d269_row0_col4, #T_0d269_row0_col6, #T_0d269_row0_col7, #T_0d269_row0_col8, #T_0d269_row1_col0, #T_0d269_row1_col1, #T_0d269_row1_col2, #T_0d269_row1_col3, #T_0d269_row1_col4, #T_0d269_row1_col5, #T_0d269_row1_col6, #T_0d269_row1_col7, #T_0d269_row1_col8, #T_0d269_row2_col0, #T_0d269_row2_col1, #T_0d269_row2_col2, #T_0d269_row2_col3, #T_0d269_row2_col4, #T_0d269_row2_col5, #T_0d269_row2_col6, #T_0d269_row2_col7, #T_0d269_row2_col8, #T_0d269_row3_col0, #T_0d269_row3_col1, #T_0d269_row3_col2, #T_0d269_row3_col3, #T_0d269_row3_col4, #T_0d269_row3_col5, #T_0d269_row3_col6, #T_0d269_row3_col7, #T_0d269_row3_col8, #T_0d269_row4_col0, #T_0d269_row4_col1, #T_0d269_row4_col2, #T_0d269_row4_col3, #T_0d269_row4_col4, #T_0d269_row4_col5, #T_0d269_row4_col6, #T_0d269_row4_col7, #T_0d269_row4_col8, #T_
_col7, #T_0d269_row17_col8, #T_0d269_row18_col0, #T_0d269_row18_col1, #T_0d269_row18_col2, #T_0d269_row18_col3, #T_0d269_row18_col4, #T_0d269_row18_col5, #T_0d269_row18_col6, #T_0d269_row18_col7, #T_0d269_row18_col8, #T_0d269_row19_col0, #T_0d269_row19_col1, #T_0d269_row19_col2, #T_0d269_row19_col3, #T_0d269_row19_col4, #T_0d269_row19_col5, #T_0d269_row19_col6, #T_0d269_row19_col7, #T_0d269_row19_col8, #T_0d269_row20_col0, #T_0d269_row20_col1, #T_0d269_row20_col2, #T_0d269_row20_col3, #T_0d269_row20_col4, #T_0d269_row20_col5, #T_0d269_row20_col6, #T_0d269_row20_col7, #T_0d269_row20_col8, #T_0d269_row21_col0, #T_0d269_row21_col1, #T_0d269_row21_col2, #T_0d269_row21_col3, #T_0d269_row21_col4, #T_0d269_row21_col5, #T_0d269_row21_col7, #T_0d269_row21_col8, #T_0d269_row22_col0, #T_0d269_row22_col1, #T_0d269_row2 ...

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions and Locations**

# %%
idealWeatherLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Humidity'] >= 35) \
                  & (idealWeatherLocationDataFrame['Humidity'] <= 75), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealWeatherLocationDataFrame['Cloudiness'] <= 5), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealWeatherLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealWeatherLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Weather Location Information**

# %%
idealWeatherLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealWeatherLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealWeatherLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Weather Location Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealWeatherLocationDataFrame,
         'Table: 2: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_70cce caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_70cce_row0_col0, #T_70cce_row0_col1, #T_70cce_row0_col2, #T_70cce_row0_col3, #T_70cce_row0_col4, #T_70cce_row0_col6, #T_70cce_row0_col7, #T_70cce_row0_col8, #T_70cce_row1_col0, #T_70cce_row1_col1, #T_70cce_row1_col2, #T_70cce_row1_col3, #T_70cce_row1_col4, #T_70cce_row1_col7, #T_70cce_row1_col8, #T_70cce_row2_col0, #T_70cce_row2_col1, #T_70cce_row2_col2, #T_70cce_row2_col3, #T_70cce_row2_col6, #T_70cce_row2_col7, #T_70cce_row2_col8, #T_70cce_row3_col0, #T_70cce_row3_col1, #T_70cce_row3_col2, #T_70cce_row3_col3, #T_70cce_row3_col4, #T_70cce_row3_col6, #T_70cce_row3_col7, #T_70cce_row3_col8, #T_70cce_row4_col0, #T_70cce_row4_col1, #T_70cce_row4_col2, #T_70cce_row4_col4, #T_70cce_row4_col6, #T_70cce_row4_col7, #T_70cce_row4_col8, #T_70cce_row5_col0, #T_70cce_row5_col1, #T_70cce_row5_col2, #T_70cce_row5_col7, #T_70cce_row5_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_70cce_row0_col5, #T_70cce_row1_col5, #T_70cce_row2_col5, #T_70cce_row3_col5, #T_70cce_row5_col3, #T_70cce_row5_col4, #T_70cce_row5_col5, #T_70cce_row5_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_70cce_row1_col6, #T_70cce_row2_col4, #T_70cce_row4_col3, #T_70cce_row4_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_70cce">
#   <caption>Table: 2: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_70cce_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_70cce_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_70cce_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_70cce_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_70cce_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_70cce_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_70cce_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_70cce_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_70cce_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_70cce_row0_col0" class="data row0 col0" >fort mcmurray</td>
#       <td id="T_70cce_row0_col1" class="data row0 col1" >56.73</td>
#       <td id="T_70cce_row0_col2" class="data row0 col2" >-111.38</td>
#       <td id="T_70cce_row0_col3" class="data row0 col3" >78.31° F</td>
#       <td id="T_70cce_row0_col4" class="data row0 col4" >47%</td>
#       <td id="T_70cce_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_70cce_row0_col6" class="data row0 col6" >5.75</td>
#       <td id="T_70cce_row0_col7" class="data row0 col7" >CA</td>
#       <td id="T_70cce_row5_col1" class="data row5 col1" >28.22</td>
#       <td id="T_70cce_row5_col2" class="data row5 col2" >61.22</td>
#       <td id="T_70cce_row5_col3" class="data row5 col3" >77.52° F</td>
#       <td id="T_70cce_row5_col4" class="data row5 col4" >35%</td>
#       <td id="T_70cce_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_70cce_row5_col6" class="data row5 col6" >2.44</td>
#       <td id="T_70cce_row5_col7" class="data row5 col7" >IR</td>
#       <td id="T_70cce_row5_col8" class="data row5 col8" >2023-08-27 15:47:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealWeatherLocationDataFrame,
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealWeatherLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Nomad Hotel and Suites in fort mcmurray, CA
#
#
# Located the following hotel...North Vista Manor in hamilton, US
#
#
# Located the following hotel...Hotel Celeste in pachino, IT
#
#
# Located the following hotel...Smoha Zahran Haus (7th floor) in alexandria, EG
#
#
# Located the following hotel...Hotel Rainha do Vale in itaporanga, BR
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3: Hotel Locations')
# Out:
# <style type="text/css">
# #T_959a4 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_959a4_row0_col0, #T_959a4_row0_col1, #T_959a4_row0_col2, #T_959a4_row0_col4, #T_959a4_row0_col6, #T_959a4_row0_col7, #T_959a4_row0_col8, #T_959a4_row0_col9, #T_959a4_row1_col0, #T_959a4_row1_col1, #T_959a4_row1_col2, #T_959a4_row1_col3, #T_959a4_row1_col4, #T_959a4_row1_col7, #T_959a4_row1_col8, #T_959a4_row1_col9, #T_959a4_row2_col0, #T_959a4_row2_col1, #T_959a4_row2_col2, #T_959a4_row2_col3, #T_959a4_row2_col6, #T_959a4_row2_col7, #T_959a4_row2_col8, #T_959a4_row2_col9, #T_959a4_row3_col0, #T_959a4_row3_col1, #T_959a4_row3_col2, #T_959a4_row3_col3, #T_959a4_row3_col4, #T_959a4_row3_col6, #T_959a4_row3_col7, #T_959a4_row3_col8, #T_959a4_row3_col9, #T_959a4_row4_col0, #T_959a4_row4_col1, #T_959a4_row4_col2, #T_959a4_row4_col7, #T_959a4_row4_col8, #T_959a4_row4_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_959a4_row0_col3, #T_959a4_row0_col5, #T_959a4_row1_col5, #T_959a4_row2_col5, #T_959a4_row3_col5, #T_959a4_row4_col4, #T_959a4_row4_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_959a4_row1_col6, #T_959a4_row2_col4, #T_959a4_row4_col3, #T_959a4_row4_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_959a4">
#   <caption>Table: 3: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_959a4_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_959a4_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_959a4_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_959a4_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_959a4_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_959a4_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_959a4_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_959a4_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_959a4_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_959a4_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_959a4_row0_col0" class="data row0 col0" >fort mcmurray</td>
#       <td id="T_959a4_row0_col1" class="data row0 col1" >56.73</td>
#       <td id="T_959a4_row0_col2" class="data row0 col2" >-111.38</td>
#       <td id="T_959a4_row0_col3" class="data row0 col3" >78.31° F</td>
#       <td id="T_959a4_row0_col4" class="data row0 col4" >47%</td>
#       <td id="T_959a4_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_959a4_row0_col6" class="data row0 col6" >5.75</td>
#       <td id="T_959a4_row0_col7" class="data row0 col7" >CA</td>
#       <td id="T_959a4_row0_col8" class="data row0 col8" >2023-08-27 15:45:32</td>
#       <td id="T_959a4_row0_col9" class="data row0 col9" >Nomad Hotel and Suites</td>
#     </tr>
#     <tr>
#       <td id="T_959a4_row1_col0" class="data row1 col0" >hamilton</td>
#       <td id="T_959a4_row1_col1" class="data row1 col1" >39.18</td>
#       <td id="T_959a4_row1_col2" class="data row1 col2" >-84.53</td>
#       <td id="T_959a4_row1_col3" class="data row1 col3" >79.09° F</td>
#       <td id="T_959a4_row1_col4" class="data row1 col4" >61%</td>
#       <td id="T_959a4_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_959a4_row1_col6" class="data row1 col6" >9.22</td>
#       <td id="T_959a4_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_959a4_row1_col8" class="data row1 col8" >2023-08-27 15:40:02</td>
#       <td id="T_959a4_row1_col9" class="data row1 col9" >North Vista Manor</td>
#     </tr>
#     <tr>
#       <td id="T_959a4_row2_col0" class="data row2 col0" >pachino</td>
#       <td id="T_959a4_row2_col1" class="data row2 col1" >36.72</td>
#       <td id="T_959a4_row2_col2" class="data row2 col2" >15.09</td>
#       <td id="T_959a4_row2_col3" class="data row2 col3" >79.83° F</td>
#       <td id="T_959a4_row2_col4" class="data row2 col4" >73%</td>
#       <td id="T_959a4_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_959a4_row2_col6" class="data row2 col6" >5.99</td>
#       <td id="T_959a4_row2_col7" class="data row2 col7" >IT</td>
#       <td id="T_959a4_row2_col8" class="data row2 col8" >2023-08-27 15:46:44</td>
#       <td id="T_959a4_row2_col9" class="data row2 col9" >Hotel Celeste</td>
#     </tr>
#     <tr>
#       <td id="T_959a4_row3_col0" class="data row3 col0" >alexandria</td>
#       <td id="T_959a4_row3_col1" class="data row3 col1" >31.22</td>
#       <td id="T_959a4_row3_col2" class="data row3 col2" >29.96</td>
#       <td id="T_959a4_row3_col3" class="data row3 col3" >79.34° F</td>
#       <td id="T_959a4_row3_col4" class="data row3 col4" >71%</td>
#       <td id="T_959a4_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_959a4_row3_col6" class="data row3 col6" >7.52</td>
#       <td id="T_959a4_row3_col7" class="data row3 col7" >EG</td>
#       <td id="T_959a4_row3_col8" class="data row3 col8" >2023-08-27 15:46:49</td>
#       <td id="T_959a4_row3_col9" class="data row3 col9" >Smoha Zahran Haus (7th floor)</td>
#     </tr>
#     <tr>
#       <td id="T_959a4_row4_col0" class="data row4 col0" >itaporanga</td>
#       <td id="T_959a4_row4_col1" class="data row4 col1" >-7.30</td>
#       <td id="T_959a4_row4_col2" class="data row4 col2" >-38.15</td>
#       <td id="T_959a4_row4_col3" class="data row4 col3" >82.49° F</td>
#       <td id="T_959a4_row4_col4" class="data row4 col4" >36%</td>
#       <td id="T_959a4_row4_col5" class="data row4 col5" >4%</td>
#       <td id="T_959a4_row4_col6" class="data row4 col6" >3.53</td>
#       <td id="T_959a4_row4_col7" class="data row4 col7" >BR</td>
#       <td id="T_959a4_row4_col8" class="data row4 col8" >2023-08-27 15:47:16</td>
#       <td id="T_959a4_row4_col9" class="data row4 col9" >Hotel Rainha do Vale</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
