# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_729c7 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_729c7_row0_col0, #T_729c7_row0_col1, #T_729c7_row0_col2, #T_729c7_row0_col4, #T_729c7_row0_col5, #T_729c7_row0_col6, #T_729c7_row0_col7, #T_729c7_row0_col8, #T_729c7_row1_col0, #T_729c7_row1_col1, #T_729c7_row1_col2, #T_729c7_row1_col3, #T_729c7_row1_col4, #T_729c7_row1_col6, #T_729c7_row1_col7, #T_729c7_row1_col8, #T_729c7_row2_col0, #T_729c7_row2_col1, #T_729c7_row2_col2, #T_729c7_row2_col3, #T_729c7_row2_col4, #T_729c7_row2_col5, #T_729c7_row2_col6, #T_729c7_row2_col7, #T_729c7_row2_col8, #T_729c7_row3_col0, #T_729c7_row3_col1, #T_729c7_row3_col2, #T_729c7_row3_col3, #T_729c7_row3_col4, #T_729c7_row3_col6, #T_729c7_row3_col7, #T_729c7_row3_col8, #T_729c7_row4_col0, #T_729c7_row4_col1, #T_729c7_row4_col2, #T_729c7_row4_col3, #T_729c7_row4_col4, #T_729c7_row4_col5, #T_729c7_row4_col6, #T_729c7_row4_col7, #T_729c7_row4_col8, #T_729c7_row5_col0, #T_729c7_row5_col1, #T_729c7_row5_col2, #T_729c7_row5_col3, #T_729c7_row5_col4, #T_729c7_row5_col7, #T_729c7_row5_col8, #T_729c7_row6_col0, #T_729c7_row6_col1, #T_729c7_row6_col2, #T_729c7_row6_col3, #T_729c7_row6_col7, #T_729c7_row6_col8, #T_729c7_row7_col0, #T_729c7_row7_col1, #T_729c7_row7_col2, #T_729c7_row7_col3, #T_729c7_row7_col4, #T_729c7_row7_col5, #T_729c7_row7_col6, #T_729c7_row7_col7, #T_729c7_row7_col8, #T_729c7_row8_col0, #T_729c7_row8_col1, #T_729c7_row8_col2, #T_729c7_row8_col4, #T_729c7_row8_col6, #T_729c7_row8_col7, #T_729c7_row8_col8, #T_729c7_row9_col0, #T_729c7_row9_col1, #T_729c7_row9_col2, #T_729c7_row9_col3, #T_729c7_row9_col4, #T_729c7_row9_col6, #T_729c7_row9_col7, #T_729c7_row9_col8, #T_729c7_row10_col0, #T_729c7_row10_col1, #T_729c7_row10_col2, #T_729c7_row10_col3, #T_729c7_row10_col4, #T_729c7_row10_col5, #T_729c7_row10_col6, #T_729c7_row10_col7, #T_729c7_row10_col8, #T_729c7_row11_col0, #T_729c7_row11_col1, #T_729c7_row11_col2, #T_729c7_row11_col3, #T_729c7_row11_col6, #T_729c7_row11_col7, #T_729c7_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_729c7_row0_col3, #T_729c7_row5_col5, #T_729c7_row5_col6, #T_729c7_row8_col5, #T_729c7_row11_col4, #T_729c7_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_729c7_row1_col5, #T_729c7_row3_col5, #T_729c7_row6_col4, #T_729c7_row6_col5, #T_729c7_row6_col6, #T_729c7_row8_col3, #T_729c7_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_729c7">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_729c7_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_729c7_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_729c7_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_729c7_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_729c7_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_729c7_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_729c7_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_729c7_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_729c7_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_729c7_row0_col0" class="data row0 col0" >coahuayana de hidalgo</td>
#       <td id="T_729c7_row0_col1" class="data row0 col1" >18.70</td>
#       <td id="T_729c7_row0_col2" class="data row0 col2" >-103.66</td>
#       <td id="T_729c7_row0_col3" class="data row0 col3" >90.52° F</td>
#       <td id="T_729c7_row0_col4" class="data row0 col4" >63%</td>
#       <td id="T_729c7_row0_col5" class="data row0 col5" >58%</td>
#       <td id="T_729c7_row0_col6" class="data row0 col6" >5.32</td>
#       <td id="T_729c7_row0_col7" class="data row0 col7" >MX</td>
#       <td id="T_729c7_row0_col8" class="data row0 col8" >2023-09-01 12:10:41</td>
#     </tr>
#     <tr>
#       <td id="T_729c7_row1_col0" class="data row1 col0" >port elizabeth</td>
#       <td id="T_729c7_row1_col1" class="data row1 col1" >-33.92</td>
#       <td id="T_729c7_row1_col2" class="data row1 col2" >25.57</td>
#       <td id="T_729c7_row1_col3" class="data row1 col3" >53.89° F</td>
#       <td id="T_729c7_row1_col4" class="data row1 col4" >71%</td>
#       <td id="T_729c7_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_729c7_row1_col6" class="data row1 col6" >4.61</td>
#       <td id="T_729c7_row1_col7" class="data row1 col7" >ZA</td>
#       <td id="T_729c7_row1_col8" class="data row1 col8" >2023-09-01 11:58:29</td>
#     </tr>
#     <tr>
#       <td id="T_729c7_row2_col0" class="data row2 col0" >carnarvon</td>
#       <td id="T_729c7_row2_col1" class="data row2 col1" >-24.87</td>
#       <td id="T_729c7_row2_col2" class="data row2 col2" >113.63</td>
#       <td id="T_729c7_row2_col3" class="data row2 col3" >65.79° F</td>
#       <td id="T_729c7_row2_col4" class="data row2 col4" >74%</td>
#       <td id="T_729c7_row2_col5" class="data row2 col5" >3%</td>
#       <td id="T_729c7_row2_col6" class="data row2 col6" >9.37</td>
#       <td id="T_729c7_row2_col7" class="data row2 col7" >AU</td>
#       <td id="T_729c7_row2_col8" class="data row2 col8" >2023-09-01 12:07:01</td>
#     </tr>
#     <tr>
#       <td id="T_729c7_row3_col0" class="data row3 col0" >bethel</td>
#       <td id="T_729c7_row3_col1" class="data row3 col1" >41.37</td>
#       <td id="T_729c7_row3_col2" class="data row3 col2" >-73.41</td>
#       <td id="T_729c7_row3_col3" class="data row3 col3" >73.44° F</td>
#       <td id="T_729c7_row3_col4" class="data row3 col4" >53%</td>
#       <td id="T_729c7_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_729c7_row3_col6" class="data row3 col6" >2.19</td>
#       <td id="T_729c7_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_729c7_row3_col8" class="data row3 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_729c7_row4_col0" class="data row4 col0" >nuoro</td>
#       <td id="T_729c7_row4_col1" class="data row4 col1" >40.32</td>
#       <td id="T_729c7_row4_col2" class="data row4 col2" >9.33</td>
#       <td id="T_729c7_row4_col3" class="data row4 col3" >62.17° F</td>
#       <td id="T_729c7_row4_col4" class="data row4 col4" >86%</td>
#       <td id="T_729c7_row4_col5" class="data row4 col5" >90%</td>
#       <td id="T_729c7_row4_col6" class="data row4 col6" >3.62</td>
#       <td id="T_729c7_row4_col7" class="data row4 col7" >IT</td>
#       <td id="T_729c7_row4_col8" class="data row4 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_729c7_row5_col0" class="data row5 col0" >utrik</td>
#       <td id="T_729c7_row5_col1" class="data row5 col1" >11.23</td>
#       <td id="T_729c7_row5_col2" class="data row5 col2" >169.85</td>
#       <td id="T_729c7_row5_col3" class="data row5 col3" >82.76° F</td>
#       <td id="T_729c7_row5_col4" class="data row5 col4" >78%</td>
#       <td id="T_729c7_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_729c7_row5_col6" class="data row5 col6" >12.08</td>
#       <td id="T_729c7_row5_col7" class="data row5 col7" >MH</td>
#       <td id="T_729c7_row5_col8" class="data row5 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_729c7_row6_col0" class="data row6 col0" >albany</td>
#       <td id="T_729c7_row6_col1" class="data row6 col1" >42.60</td>
#       <td id="T_729c7_row6_col2" class="data row6 col2" >-73.97</td>
#       <td id="T_729c7_row6_col3" class="data row6 col3" >73.71° F</td>
#       <td id="T_729c7_row6_col4" class="data row6 col4" >51%</td>
#       <td id="T_729c7_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_729c7_row6_col6" class="data row6 col6" >1.99</td>
#       <td id="T_729c7_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_729c7_row6_col8" class="data row6 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_729c7_row7_col0" class="

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 35) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 75), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 5), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_b991e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b991e_row0_col0, #T_b991e_row0_col1, #T_b991e_row0_col2, #T_b991e_row0_col3, #T_b991e_row0_col6, #T_b991e_row0_col7, #T_b991e_row0_col8, #T_b991e_row1_col0, #T_b991e_row1_col1, #T_b991e_row1_col2, #T_b991e_row1_col3, #T_b991e_row1_col6, #T_b991e_row1_col7, #T_b991e_row1_col8, #T_b991e_row2_col0, #T_b991e_row2_col1, #T_b991e_row2_col2, #T_b991e_row2_col3, #T_b991e_row2_col4, #T_b991e_row2_col6, #T_b991e_row2_col7, #T_b991e_row2_col8, #T_b991e_row3_col0, #T_b991e_row3_col1, #T_b991e_row3_col2, #T_b991e_row3_col3, #T_b991e_row3_col4, #T_b991e_row3_col7, #T_b991e_row3_col8, #T_b991e_row4_col0, #T_b991e_row4_col1, #T_b991e_row4_col2, #T_b991e_row4_col3, #T_b991e_row4_col4, #T_b991e_row4_col6, #T_b991e_row4_col7, #T_b991e_row4_col8, #T_b991e_row5_col0, #T_b991e_row5_col1, #T_b991e_row5_col2, #T_b991e_row5_col3, #T_b991e_row5_col4, #T_b991e_row5_col7, #T_b991e_row5_col8, #T_b991e_row6_col0, #T_b991e_row6_col1, #T_b991e_row6_col2, #T_b991e_row6_col4, #T_b991e_row6_col6, #T_b991e_row6_col7, #T_b991e_row6_col8, #T_b991e_row7_col0, #T_b991e_row7_col1, #T_b991e_row7_col2, #T_b991e_row7_col4, #T_b991e_row7_col6, #T_b991e_row7_col7, #T_b991e_row7_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_b991e_row0_col4, #T_b991e_row2_col5, #T_b991e_row5_col6, #T_b991e_row7_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_b991e_row0_col5, #T_b991e_row1_col4, #T_b991e_row1_col5, #T_b991e_row3_col5, #T_b991e_row3_col6, #T_b991e_row4_col5, #T_b991e_row5_col5, #T_b991e_row6_col3, #T_b991e_row6_col5, #T_b991e_row7_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_b991e">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_b991e_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_b991e_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_b991e_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_b991e_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_b991e_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_b991e_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_b991e_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_b991e_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_b991e_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b991e_row0_col0" class="data row0 col0" >tyre</td>
#       <td id="T_b991e_row0_col1" class="data row0 col1" >33.27</td>
#       <td id="T_b991e_row0_col2" class="data row0 col2" >35.19</td>
#       <td id="T_b991e_row0_col3" class="data row0 col3" >81.12° F</td>
#       <td id="T_b991e_row0_col4" class="data row0 col4" >71%</td>
#       <td id="T_b991e_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_b991e_row0_col6" class="data row0 col6" >2.24</td>
#       <td id="T_b991e_row0_col7" class="data row0 col7" >LB</td>
#       <td id="T_b991e_row0_col8" class="data row0 col8" >2023-09-01 12:10:44</td>
#     </tr>
#     <tr>
#       <td id="T_b991e_row1_col0" class="data row1 col0" >hamilton</td>
#       <td id="T_b991e_row1_col1" class="data row1 col1" >39.18</td>
#       <td id="T_b991e_row1_col2" class="data row1 col2" >-84.53</td>
#       <td id="T_b991e_row1_col3" class="data row1 col3" >83.66° F</td>
#       <td id="T_b991e_row1_col4" class="data row1 col4" >46%</td>
#       <td id="T_b991e_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_b991e_row1_col6" class="data row1 col6" >3.44</td>
#       <td id="T_b991e_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_b991e_row1_col8" class="data row1 col8" >2023-09-01 12:08:13</td>
#     </tr>
#     <tr>
#       <td id="T_b991e_row2_col0" class="data row2 col0" >thompson</td>
#       <td id="T_b991e_row2_col1" class="data row2 col1" >55.74</td>
#       <td id="T_b991e_row2_col2" class="data row2 col2" >-97.86</td>
#       <td id="T_b991e_row2_col3" class="data row2 col3" >79.93° F</td>
#       <td id="T_b991e_row2_col4" class="data row2 col4" >48%</td>
#       <td id="T_b991e_row2_col5" class="data row2 col5" >4%</td>
#       <td id="T_b991e_row2_col6" class="data row2 col6" >5.08</td>
#       <td id="T_b991e_row2_col7" class="data row2 col7" >CA</td>
#       <td id="T_b991e_row2_col8" class="data row2 col8" >2023-09-01 12:07:27</td>
#     </tr>
#     <tr>
#       <td id="T_b991e_row3_col0" class="data row3 col0" >pana</td>
#       <td id="T_b991e_row3_col1" class="data row3 col1" >39.39</td>
#       <td id="T_b991e_row3_col2" class="data row3 col2" >-89.08</td>
#       <td id="T_b991e_row3_col3" class="data row3 col3" >80.29° F</td>
#       <td id="T_b991e_row3_col4" class="data row3 col4" >49%</td>
#       <td id="T_b991e_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_b991e_row3_col6" class="data row3 col6" >1.01</td>
#       <td id="T_b991e_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_b991e_row3_col8" class="data row3 col8" >2023-09-01 12:11:32</td>
#     </tr>
#     <tr>
#       <td id="T_b991e_row4_col0" class="data row4 col0" >metropolis</td>
#       <td id="T_b991e_row4_col1" class="data row4 col1" >37.15</td>
#       <td id="T_b991e_row4_col2" class="data row4 col2" >-88.73</td>
#       <td id="T_b991e_row4_col3" class="data row4 col3" >82.29° F</td>
#       <td id="T_b991e_row4_col4" class="data row4 col4" >62%</td>
#       <td id="T_b991e_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_b991e_row4_col6" class="data row4 col6" >3.44</td>
#       <td id="T_b991e_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_b991e_row4_col8" class="data row4 col8" >2023-09-01 12:11:34</td>
#     </tr>
#     <tr>
#       <td id="T_b991e_row5_col0" class="data row5 col0" >pitimbu</td>
#       <td id="T_b991e_row5_col1" class="data row5 col1" >-7.47</td>
#       <td id="T_b991e_row5_col2" class="data row5 col2" >-34.81</td>
#       <td id="T_b991e_row5_col3" class="data row5 col3" >82.99° F</td>
#       <td id="T_b991e_row5_col4" class="data row5 col4" >65%</td>
#       <td id="T_b991e_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_b991e_row5_col6" class="data row5 col6" >7.23</td>
#       <td id="T_b991e_row5_col7" class="data row5 col7" >BR</td>
#       <td id="T_b991e_row5_col8" class="data row5 col8" >2023-09-01 12:07:45</td>
#     </tr>
#     <tr>
#       <td id="T_b991e_row6_col0" class="data row6 col0" >greensburg</td>
#       <td id="T_b991e_row6_col1" class="data row6 col1" >40.30</td>
#       <td id="T_b991e_row6_col2" class="data row6 col2" >-79.54</td>
#       <td id="T_b991e_row6_col3" class="data row6 col3" >77.36° F</td>
#       <td id="T_b991e_row6_col4" class="data row6 col4" >51%</td>
#       <td id="T_b991e_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_b991e_row6_col6" class="data row6 col6" >3.00</td>
#       <td id="T_b991e_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_b991e_row6_col8" class="data row6 col8" >2023-09-01 12:11:27</td>
#     </tr>
#     <tr>
#       <td id="T_b991e_row7_col0" class="data row7 col0" >pierre</td>
#       <td id="T_b991e_row7_col1" class="data row7 col1" >44.37</td>
#       <td id="T_b991e_row7_col2" class="data row7 col2" >-100.35</td>
#       <td id="T_b991e_row7_col3" class="data row7 col3" >85.12° F</td>
#       <td id="T_b991e_row7_col4" class="data row7 col4" >48%</td>
#       <td id="T_b991e_row7_col5" class="data row7 col5" >0%</td>
#       <td id="T_b991e_row7_col6" class="data row7 col6" >6.91</td>
#       <td id="T_b991e_row7_col7" class="data row7 col7" >US</td>
#       <td id="T_b991e_row7_col8" class="data row7 col8" >2023-09-01 12:09:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...El Boutique Hotel in tyre, LB
#
#
# Located the following hotel...North Vista Manor in hamilton, US
#
#
# Located the following hotel...Thompson Inn in thompson, CA
#
#
# Located the following hotel...Lake Lawn Inn in pana, US
#
#
# Located the following hotel...Baymont Inn & Suites Metropolis in metropolis, US
#
#
# Located the following hotel...Pousada Brisa Mar in pitimbu, BR
#
#
# Located the following hotel...Red Roof Inn in greensburg, US
#
#
# Located the following hotel...Quality Inn in pierre, US
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_92ea1 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_92ea1_row0_col0, #T_92ea1_row0_col1, #T_92ea1_row0_col2, #T_92ea1_row0_col3, #T_92ea1_row0_col6, #T_92ea1_row0_col7, #T_92ea1_row0_col8, #T_92ea1_row0_col9, #T_92ea1_row1_col0, #T_92ea1_row1_col1, #T_92ea1_row1_col2, #T_92ea1_row1_col3, #T_92ea1_row1_col6, #T_92ea1_row1_col7, #T_92ea1_row1_col8, #T_92ea1_row1_col9, #T_92ea1_row2_col0, #T_92ea1_row2_col1, #T_92ea1_row2_col2, #T_92ea1_row2_col3, #T_92ea1_row2_col4, #T_92ea1_row2_col6, #T_92ea1_row2_col7, #T_92ea1_row2_col8, #T_92ea1_row2_col9, #T_92ea1_row3_col0, #T_92ea1_row3_col1, #T_92ea1_row3_col2, #T_92ea1_row3_col3, #T_92ea1_row3_col4, #T_92ea1_row3_col7, #T_92ea1_row3_col8, #T_92ea1_row3_col9, #T_92ea1_row4_col0, #T_92ea1_row4_col1, #T_92ea1_row4_col2, #T_92ea1_row4_col3, #T_92ea1_row4_col4, #T_92ea1_row4_col6, #T_92ea1_row4_col7, #T_92ea1_row4_col8, #T_92ea1_row4_col9, #T_92ea1_row5_col0, #T_92ea1_row5_col1, #T_92ea1_row5_col2, #T_92ea1_row5_col3, #T_92ea1_row5_col4, #T_92ea1_row5_col7, #T_92ea1_row5_col8, #T_92ea1_row5_col9, #T_92ea1_row6_col0, #T_92ea1_row6_col1, #T_92ea1_row6_col2, #T_92ea1_row6_col4, #T_92ea1_row6_col6, #T_92ea1_row6_col7, #T_92ea1_row6_col8, #T_92ea1_row6_col9, #T_92ea1_row7_col0, #T_92ea1_row7_col1, #T_92ea1_row7_col2, #T_92ea1_row7_col4, #T_92ea1_row7_col6, #T_92ea1_row7_col7, #T_92ea1_row7_col8, #T_92ea1_row7_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_92ea1_row0_col4, #T_92ea1_row2_col5, #T_92ea1_row5_col6, #T_92ea1_row7_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_92ea1_row0_col5, #T_92ea1_row1_col4, #T_92ea1_row1_col5, #T_92ea1_row3_col5, #T_92ea1_row3_col6, #T_92ea1_row4_col5, #T_92ea1_row5_col5, #T_92ea1_row6_col3, #T_92ea1_row6_col5, #T_92ea1_row7_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_92ea1">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_92ea1_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_92ea1_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_92ea1_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_92ea1_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_92ea1_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_92ea1_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_92ea1_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_92ea1_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_92ea1_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_92ea1_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_92ea1_row0_col0" class="data row0 col0" >tyre</td>
#       <td id="T_92ea1_row0_col1" class="data row0 col1" >33.27</td>
#       <td id="T_92ea1_row0_col2" class="data row0 col2" >35.19</td>
#       <td id="T_92ea1_row0_col3" class="data row0 col3" >81.12° F</td>
#       <td id="T_92ea1_row0_col4" class="data row0 col4" >71%</td>
#       <td id="T_92ea1_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_92ea1_row0_col6" class="data row0 col6" >2.24</td>
#       <td id="T_92ea1_row0_col7" class="data row0 col7" >LB</td>
#       <td id="T_92ea1_row0_col8" class="data row0 col8" >2023-09-01 12:10:44</td>
#       <td id="T_92ea1_row0_col9" class="data row0 col9" >El Boutique Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_92ea1_row1_col0" class="data row1 col0" >hamilton</td>
#       <td id="T_92ea1_row1_col1" class="data row1 col1" >39.18</td>
#       <td id="T_92ea1_row1_col2" class="data row1 col2" >-84.53</td>
#       <td id="T_92ea1_row1_col3" class="data row1 col3" >83.66° F</td>
#       <td id="T_92ea1_row1_col4" class="data row1 col4" >46%</td>
#       <td id="T_92ea1_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_92ea1_row1_col6" class="data row1 col6" >3.44</td>
#       <td id="T_92ea1_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_92ea1_row1_col8" class="data row1 col8" >2023-09-01 12:08:13</td>
#       <td id="T_92ea1_row1_col9" class="data row1 col9" >North Vista Manor</td>
#     </tr>
#     <tr>
#       <td id="T_92ea1_row2_col0" class="data row2 col0" >thompson</td>
#       <td id="T_92ea1_row2_col1" class="data row2 col1" >55.74</td>
#       <td id="T_92ea1_row2_col2" class="data row2 col2" >-97.86</td>
#       <td id="T_92ea1_row2_col3" class="data row2 col3" >79.93° F</td>
#       <td id="T_92ea1_row2_col4" class="data row2 col4" >48%</td>
#       <td id="T_92ea1_row2_col5" class="data row2 col5" >4%</td>
#       <td id="T_92ea1_row2_col6" class="data row2 col6" >5.08</td>
#       <td id="T_92ea1_row2_col7" class="data row2 col7" >CA</td>
#       <td id="T_92ea1_row2_col8" class="data row2 col8" >2023-09-01 12:07:27</td>
#       <td id="T_92ea1_row2_col9" class="data row2 col9" >Thompson Inn</td>
#     </tr>
#     <tr>
#       <td id="T_92ea1_row3_col0" class="data row3 col0" >pana</td>
#       <td id="T_92ea1_row3_col1" class="data row3 col1" >39.39</td>
#       <td id="T_92ea1_row3_col2" class="data row3 col2" >-89.08</td>
#       <td id="T_92ea1_row3_col3" class="data row3 col3" >80.29° F</td>
#       <td id="T_92ea1_row3_col4" class="data row3 col4" >49%</td>
#       <td id="T_92ea1_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_92ea1_row3_col6" class="data row3 col6" >1.01</td>
#       <td id="T_92ea1_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_92ea1_row3_col8" class="data row3 col8" >2023-09-01 12:11:32</td>
#       <td id="T_92ea1_row3_col9" class="data row3 col9" >Lake Lawn Inn</td>
#     </tr>
#     <tr>
#       <td id="T_92ea1_row4_col0" class="data row4 col0" >metropolis</td>
#       <td id="T_92ea1_row4_col1" class="data row4 col1" >37.15</td>
#       <td id="T_92ea1_row4_col2" class="data row4 col2" >-88.73</td>
#       <td id="T_92ea1_row4_col3" class="data row4 col3" >82.29° F</td>
#       <td id="T_92ea1_row4_col4" class="data row4 col4" >62%</td>
#       <td id="T_92ea1_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_92ea1_row4_col6" class="data row4 col6" >3.44</td>
#       <td id="T_92ea1_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_92ea1_row4_col8" class="data row4 col8" >2023-09-01 12:11:34</td>
#       <td id="T_92ea1_row4_col9" class="data row4 col9" >Baymont Inn & Suites Metropolis</td>
#     </tr>
#     <tr>
#       <td id="T_92ea1_row5_col0" class="data row5 col0" >pitimbu</td>
#       <td id="T_92ea1_row5_col1" class="data row5 col1" >-7.47</td>
#       <td id="T_92ea1_row5_col2" class="data row5 col2" >-34.81</td>
#       <td id="T_92ea1_row5_col3" class="data row5 col3" >82.99° F</td>
#       <td id="T_92ea1_row5_col4" class="data row5 col4" >65%</td>
#       <td id="T_92ea1_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_92ea1_row5_col6" class="data row5 col6" >7.23</td>
#       <td id="T_92ea1_row5_col7" class="data row5 col7" >BR</td>
#       <td id="T_92ea1_row5_col8" class="data row5 col8" >2023-09-01 12:07:45</td>
#       <td id="T_92ea1_row5_col9" class="data row5 col9" >Pousada Brisa Mar</td>
#     </tr>
#     <tr>
#       <td id="T_92ea1_row6_col0" class="data row6 col0" >greensburg</td>
#       <td id="T_92ea1_row6_col1" class="data row6 col1" >40.30</td>
#       <td id="T_92ea1_row6_col2" class="data row6 col2" >-79.54</td>
#       <td id="T_92ea1_row6_col3" class="data row6 col3" >77.36° F</td>
#       <td id="T_92ea1_row6_col4" class="data row6 col4" >51%</td>
#       <td id="T_92ea1_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_92ea1_row6_col6" class="data row6 col6" >3.00</td>
#       <td id="T_92ea1_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_92ea1_row6_col8" class="data row6 col8" >2023-09-01 12:11:27</td>
#       <td id="T_92ea1_row6_col9" class="data row6 col9" >Red Roof Inn</td>
#     </tr>
#     <tr>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
log_subroutine \
    .EndProgramExecution()
# Out:
# Program execution ends at 09/01/2023 12:15:08.
