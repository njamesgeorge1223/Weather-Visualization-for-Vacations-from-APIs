# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_933d5 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_933d5_row0_col0, #T_933d5_row0_col1, #T_933d5_row0_col2, #T_933d5_row0_col3, #T_933d5_row0_col4, #T_933d5_row0_col5, #T_933d5_row0_col6, #T_933d5_row0_col7, #T_933d5_row0_col8, #T_933d5_row1_col0, #T_933d5_row1_col1, #T_933d5_row1_col2, #T_933d5_row1_col3, #T_933d5_row1_col5, #T_933d5_row1_col6, #T_933d5_row1_col7, #T_933d5_row1_col8, #T_933d5_row2_col0, #T_933d5_row2_col1, #T_933d5_row2_col2, #T_933d5_row2_col3, #T_933d5_row2_col6, #T_933d5_row2_col7, #T_933d5_row2_col8, #T_933d5_row3_col0, #T_933d5_row3_col1, #T_933d5_row3_col2, #T_933d5_row3_col3, #T_933d5_row3_col4, #T_933d5_row3_col5, #T_933d5_row3_col6, #T_933d5_row3_col7, #T_933d5_row3_col8, #T_933d5_row4_col0, #T_933d5_row4_col1, #T_933d5_row4_col2, #T_933d5_row4_col4, #T_933d5_row4_col5, #T_933d5_row4_col7, #T_933d5_row4_col8, #T_933d5_row5_col0, #T_933d5_row5_col1, #T_933d5_row5_col2, #T_933d5_row5_col3, #T_933d5_row5_col4, #T_933d5_row5_col7, #T_933d5_row5_col8, #T_933d5_row6_col0, #T_933d5_row6_col1, #T_933d5_row6_col2, #T_933d5_row6_col4, #T_933d5_row6_col5, #T_933d5_row6_col6, #T_933d5_row6_col7, #T_933d5_row6_col8, #T_933d5_row7_col0, #T_933d5_row7_col1, #T_933d5_row7_col2, #T_933d5_row7_col3, #T_933d5_row7_col4, #T_933d5_row7_col5, #T_933d5_row7_col6, #T_933d5_row7_col7, #T_933d5_row7_col8, #T_933d5_row8_col0, #T_933d5_row8_col1, #T_933d5_row8_col2, #T_933d5_row8_col3, #T_933d5_row8_col4, #T_933d5_row8_col6, #T_933d5_row8_col7, #T_933d5_row8_col8, #T_933d5_row9_col0, #T_933d5_row9_col1, #T_933d5_row9_col2, #T_933d5_row9_col3, #T_933d5_row9_col4, #T_933d5_row9_col5, #T_933d5_row9_col6, #T_933d5_row9_col7, #T_933d5_row9_col8, #T_933d5_row10_col0, #T_933d5_row10_col1, #T_933d5_row10_col2, #T_933d5_row10_col3, #T_933d5_row10_col4, #T_933d5_row10_col6, #T_933d5_row10_col7, #T_933d5_row10_col8, #T_933d5_row11_col0, #T_933d5_row11_col1, #T_933d5_row11_col2, #T_933d5_row11_col3, #T_933d5_row11_col4, #T_933d5_row11_col5, #T_933d5_row11_col6, #T_933d5_row11_col7, #T_933d5_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_933d5_row1_col4, #T_933d5_row4_col6, #T_933d5_row5_col5, #T_933d5_row6_col3, #T_933d5_row8_col5, #T_933d5_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_933d5_row2_col4, #T_933d5_row2_col5, #T_933d5_row4_col3, #T_933d5_row5_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_933d5">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_933d5_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_933d5_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_933d5_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_933d5_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_933d5_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_933d5_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_933d5_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_933d5_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_933d5_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_933d5_row0_col0" class="data row0 col0" >bikenibeu village</td>
#       <td id="T_933d5_row0_col1" class="data row0 col1" >1.37</td>
#       <td id="T_933d5_row0_col2" class="data row0 col2" >173.12</td>
#       <td id="T_933d5_row0_col3" class="data row0 col3" >84.16° F</td>
#       <td id="T_933d5_row0_col4" class="data row0 col4" >76%</td>
#       <td id="T_933d5_row0_col5" class="data row0 col5" >22%</td>
#       <td id="T_933d5_row0_col6" class="data row0 col6" >14.36</td>
#       <td id="T_933d5_row0_col7" class="data row0 col7" >KI</td>
#       <td id="T_933d5_row0_col8" class="data row0 col8" >2023-08-31 13:49:59</td>
#     </tr>
#     <tr>
#       <td id="T_933d5_row1_col0" class="data row1 col0" >waitangi</td>
#       <td id="T_933d5_row1_col1" class="data row1 col1" >-43.95</td>
#       <td id="T_933d5_row1_col2" class="data row1 col2" >-176.56</td>
#       <td id="T_933d5_row1_col3" class="data row1 col3" >53.82° F</td>
#       <td id="T_933d5_row1_col4" class="data row1 col4" >89%</td>
#       <td id="T_933d5_row1_col5" class="data row1 col5" >2%</td>
#       <td id="T_933d5_row1_col6" class="data row1 col6" >1.99</td>
#       <td id="T_933d5_row1_col7" class="data row1 col7" >NZ</td>
#       <td id="T_933d5_row1_col8" class="data row1 col8" >2023-08-31 13:48:44</td>
#     </tr>
#     <tr>
#       <td id="T_933d5_row2_col0" class="data row2 col0" >bethel</td>
#       <td id="T_933d5_row2_col1" class="data row2 col1" >41.37</td>
#       <td id="T_933d5_row2_col2" class="data row2 col2" >-73.41</td>
#       <td id="T_933d5_row2_col3" class="data row2 col3" >73.92° F</td>
#       <td id="T_933d5_row2_col4" class="data row2 col4" >51%</td>
#       <td id="T_933d5_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_933d5_row2_col6" class="data row2 col6" >11.50</td>
#       <td id="T_933d5_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_933d5_row2_col8" class="data row2 col8" >2023-08-31 13:44:09</td>
#     </tr>
#     <tr>
#       <td id="T_933d5_row3_col0" class="data row3 col0" >holualoa</td>
#       <td id="T_933d5_row3_col1" class="data row3 col1" >19.62</td>
#       <td id="T_933d5_row3_col2" class="data row3 col2" >-155.95</td>
#       <td id="T_933d5_row3_col3" class="data row3 col3" >78.82° F</td>
#       <td id="T_933d5_row3_col4" class="data row3 col4" >71%</td>
#       <td id="T_933d5_row3_col5" class="data row3 col5" >75%</td>
#       <td id="T_933d5_row3_col6" class="data row3 col6" >14.97</td>
#       <td id="T_933d5_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_933d5_row3_col8" class="data row3 col8" >2023-08-31 13:49:52</td>
#     </tr>
#     <tr>
#       <td id="T_933d5_row4_col0" class="data row4 col0" >port-aux-francais</td>
#       <td id="T_933d5_row4_col1" class="data row4 col1" >-49.35</td>
#       <td id="T_933d5_row4_col2" class="data row4 col2" >70.22</td>
#       <td id="T_933d5_row4_col3" class="data row4 col3" >35.76° F</td>
#       <td id="T_933d5_row4_col4" class="data row4 col4" >72%</td>
#       <td id="T_933d5_row4_col5" class="data row4 col5" >81%</td>
#       <td id="T_933d5_row4_col6" class="data row4 col6" >32.61</td>
#       <td id="T_933d5_row4_col7" class="data row4 col7" >TF</td>
#       <td id="T_933d5_row4_col8" class="data row4 col8" >2023-08-31 13:48:43</td>
#     </tr>
#     <tr>
#       <td id="T_933d5_row5_col0" class="data row5 col0" >luocheng</td>
#       <td id="T_933d5_row5_col1" class="data row5 col1" >29.38</td>
#       <td id="T_933d5_row5_col2" class="data row5 col2" >104.03</td>
#       <td id="T_933d5_row5_col3" class="data row5 col3" >70.84° F</td>
#       <td id="T_933d5_row5_col4" class="data row5 col4" >85%</td>
#       <td id="T_933d5_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_933d5_row5_col6" class="data row5 col6" >0.27</td>
#       <td id="T_933d5_row5_col7" class="data row5 col7" >CN</td>
#       <td id="T_933d5_row5_col8" class="data row5 col8" >2023-08-31 13:58:31</td>
#     </tr>
#     <tr>
#       <td id="T_933d5_row6_col0" class="data row6 col0" >brisas de zicatela</td>
#       <td id="T_933d5_row6_col1" class="data row6 col1" >15.84</td>
#       <td id="T_933d5_row6_col2" class="data row6 col2" >-97.04</td>
#       <td id="T_933d5_row6_col3" class="data row6 col3" >86.79° F</td>
#       <td id="T_933d5_row6_col4" class="data row6 col4" >68%</td>
#       <td id="T_933d5_row6_col5" class="data row6 col5" >41%</td>
#       <td id="T_933d5_row6_col6" class="data row6 col6" >6.02</td>
#       <td id="T_933d5_row6_col7" class="data row6 col7" >MX</td>
#       <td id="T_933d5_row6_col8" class="data row6 col8" >2023-08-31 13:54:26</td>
#     </tr>
#     <tr>
#       <td id="T_9

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 35) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 75), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 5), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_4a416 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_4a416_row0_col0, #T_4a416_row0_col1, #T_4a416_row0_col2, #T_4a416_row0_col3, #T_4a416_row0_col5, #T_4a416_row0_col7, #T_4a416_row0_col8, #T_4a416_row1_col0, #T_4a416_row1_col1, #T_4a416_row1_col2, #T_4a416_row1_col3, #T_4a416_row1_col4, #T_4a416_row1_col5, #T_4a416_row1_col6, #T_4a416_row1_col7, #T_4a416_row1_col8, #T_4a416_row2_col0, #T_4a416_row2_col1, #T_4a416_row2_col2, #T_4a416_row2_col3, #T_4a416_row2_col6, #T_4a416_row2_col7, #T_4a416_row2_col8, #T_4a416_row3_col0, #T_4a416_row3_col1, #T_4a416_row3_col2, #T_4a416_row3_col4, #T_4a416_row3_col6, #T_4a416_row3_col7, #T_4a416_row3_col8, #T_4a416_row4_col0, #T_4a416_row4_col1, #T_4a416_row4_col2, #T_4a416_row4_col3, #T_4a416_row4_col7, #T_4a416_row4_col8, #T_4a416_row5_col0, #T_4a416_row5_col1, #T_4a416_row5_col2, #T_4a416_row5_col3, #T_4a416_row5_col4, #T_4a416_row5_col5, #T_4a416_row5_col6, #T_4a416_row5_col7, #T_4a416_row5_col8, #T_4a416_row6_col0, #T_4a416_row6_col1, #T_4a416_row6_col2, #T_4a416_row6_col4, #T_4a416_row6_col5, #T_4a416_row6_col6, #T_4a416_row6_col7, #T_4a416_row6_col8, #T_4a416_row7_col0, #T_4a416_row7_col1, #T_4a416_row7_col2, #T_4a416_row7_col3, #T_4a416_row7_col4, #T_4a416_row7_col5, #T_4a416_row7_col6, #T_4a416_row7_col7, #T_4a416_row7_col8, #T_4a416_row8_col0, #T_4a416_row8_col1, #T_4a416_row8_col2, #T_4a416_row8_col3, #T_4a416_row8_col4, #T_4a416_row8_col5, #T_4a416_row8_col6, #T_4a416_row8_col7, #T_4a416_row8_col8, #T_4a416_row9_col0, #T_4a416_row9_col1, #T_4a416_row9_col2, #T_4a416_row9_col3, #T_4a416_row9_col4, #T_4a416_row9_col6, #T_4a416_row9_col7, #T_4a416_row9_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_4a416_row0_col4, #T_4a416_row0_col6, #T_4a416_row2_col4, #T_4a416_row6_col3, #T_4a416_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_4a416_row2_col5, #T_4a416_row3_col3, #T_4a416_row3_col5, #T_4a416_row4_col4, #T_4a416_row4_col5, #T_4a416_row4_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_4a416">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_4a416_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_4a416_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_4a416_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_4a416_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_4a416_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_4a416_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_4a416_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_4a416_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_4a416_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4a416_row0_col0" class="data row0 col0" >barreirinhas</td>
#       <td id="T_4a416_row0_col1" class="data row0 col1" >-2.75</td>
#       <td id="T_4a416_row0_col2" class="data row0 col2" >-42.83</td>
#       <td id="T_4a416_row0_col3" class="data row0 col3" >78.85° F</td>
#       <td id="T_4a416_row0_col4" class="data row0 col4" >74%</td>
#       <td id="T_4a416_row0_col5" class="data row0 col5" >1%</td>
#       <td id="T_4a416_row0_col6" class="data row0 col6" >9.44</td>
#       <td id="T_4a416_row0_col7" class="data row0 col7" >BR</td>
#       <td id="T_4a416_row0_col8" class="data row0 col8" >2023-08-31 13:58:40</td>
#     </tr>
#     <tr>
#       <td id="T_4a416_row1_col0" class="data row1 col0" >isla vista</td>
#       <td id="T_4a416_row1_col1" class="data row1 col1" >34.41</td>
#       <td id="T_4a416_row1_col2" class="data row1 col2" >-119.86</td>
#       <td id="T_4a416_row1_col3" class="data row1 col3" >84.45° F</td>
#       <td id="T_4a416_row1_col4" class="data row1 col4" >64%</td>
#       <td id="T_4a416_row1_col5" class="data row1 col5" >1%</td>
#       <td id="T_4a416_row1_col6" class="data row1 col6" >6.35</td>
#       <td id="T_4a416_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_4a416_row1_col8" class="data row1 col8" >2023-08-31 13:58:40</td>
#     </tr>
#     <tr>
#       <td id="T_4a416_row2_col0" class="data row2 col0" >remire-montjoly</td>
#       <td id="T_4a416_row2_col1" class="data row2 col1" >4.92</td>
#       <td id="T_4a416_row2_col2" class="data row2 col2" >-52.27</td>
#       <td id="T_4a416_row2_col3" class="data row2 col3" >82.44° F</td>
#       <td id="T_4a416_row2_col4" class="data row2 col4" >74%</td>
#       <td id="T_4a416_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_4a416_row2_col6" class="data row2 col6" >2.30</td>
#       <td id="T_4a416_row2_col7" class="data row2 col7" >GF</td>
#       <td id="T_4a416_row2_col8" class="data row2 col8" >2023-08-31 13:48:51</td>
#     </tr>
#     <tr>
#       <td id="T_4a416_row3_col0" class="data row3 col0" >asmar</td>
#       <td id="T_4a416_row3_col1" class="data row3 col1" >35.03</td>
#       <td id="T_4a416_row3_col2" class="data row3 col2" >71.36</td>
#       <td id="T_4a416_row3_col3" class="data row3 col3" >77.97° F</td>
#       <td id="T_4a416_row3_col4" class="data row3 col4" >72%</td>
#       <td id="T_4a416_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_4a416_row3_col6" class="data row3 col6" >3.06</td>
#       <td id="T_4a416_row3_col7" class="data row3 col7" >AF</td>
#       <td id="T_4a416_row3_col8" class="data row3 col8" >2023-08-31 13:59:06</td>
#     </tr>
#     <tr>
#       <td id="T_4a416_row4_col0" class="data row4 col0" >la rinconada</td>
#       <td id="T_4a416_row4_col1" class="data row4 col1" >37.49</td>
#       <td id="T_4a416_row4_col2" class="data row4 col2" >-5.98</td>
#       <td id="T_4a416_row4_col3" class="data row4 col3" >81.00° F</td>
#       <td id="T_4a416_row4_col4" class="data row4 col4" >48%</td>
#       <td id="T_4a416_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_4a416_row4_col6" class="data row4 col6" >1.01</td>
#       <td id="T_4a416_row4_col7" class="data row4 col7" >ES</td>
#       <td id="T_4a416_row4_col8" class="data row4 col8" >2023-08-31 13:59:10</td>
#     </tr>
#     <tr>
#       <td id="T_4a416_row5_col0" class="data row5 col0" >sirsaganj</td>
#       <td id="T_4a416_row5_col1" class="data row5 col1" >27.05</td>
#       <td id="T_4a416_row5_col2" class="data row5 col2" >78.70</td>
#       <td id="T_4a416_row5_col3" class="data row5 col3" >84.45° F</td>
#       <td id="T_4a416_row5_col4" class="data row5 col4" >63%</td>
#       <td id="T_4a416_row5_col5" class="data row5 col5" >2%</td>
#       <td id="T_4a416_row5_col6" class="data row5 col6" >1.74</td>
#       <td id="T_4a416_row5_col7" class="data row5 col7" >IN</td>
#       <td id="T_4a416_row5_col8" class="data row5 col8" >2023-08-31 13:59:10</td>
#     </tr>
#     <tr>
#       <td id="T_4a416_row6_col0" class="data row6 col0" >dinajpur</td>
#       <td id="T_4a416_row6_col1" class="data row6 col1" >25.63</td>
#       <td id="T_4a416_row6_col2" class="data row6 col2" >88.64</td>
#       <td id="T_4a416_row6_col3" class="data row6 col3" >84.85° F</td>
#       <td id="T_4a416_row6_col4" class="data row6 col4" >64%</td>
#       <td id="T_4a416_row6_col5" class="data row6 col5" >1%</td>
#       <td id="T_4a416_row6_col6" class="data row6 col6" >2.48</td>
#       <td id="T_4a416_row6_col7" class="data row6 col7" >BD</td>
#       <td id="T_4a416_row6_col8" class="data row6 col8" >2023-08-31 13:59:36</td>
#     </tr>
#     <tr>
#       <td id="T_4a416_row7_col0" class="data row7 col0" >antioch</td>
#       <td id="T_4a416_row7_col1" class="data row7 col1" >36.21</td>
#       <td id="T_4a416_row7_col2" class="data row7 col2" >36.16</td>
#       <td id="T_4a416_row7_col3" class="data row7 col3" >80.42° F</td>
#       <td id="T_4a416_row7_col4" class="data row7 col4" >72%</td>
#       <td id="T_4a416_row7_col5" class="data row7 col5" >1%</td>
#       <td id="

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Pousada Matriz in barreirinhas, BR
#
#
# Located the following hotel...The Club & Guest House in isla vista, US
#
#
# Located the following hotel...Complexe Belova in remire-montjoly, GF
#
#
# Located the following hotel...Hotel Torre de los Guzmanes in la rinconada, ES
#
#
# Located the following hotel...VIP Guest House in dinajpur, BD
#
#
# Located the following hotel...The Great Antakya Hotel in antioch, TR
#
#
# Located the following hotel...Hale Koolau in la'ie, US
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_bc8b8 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_bc8b8_row0_col0, #T_bc8b8_row0_col1, #T_bc8b8_row0_col2, #T_bc8b8_row0_col7, #T_bc8b8_row0_col8, #T_bc8b8_row0_col9, #T_bc8b8_row1_col0, #T_bc8b8_row1_col1, #T_bc8b8_row1_col2, #T_bc8b8_row1_col3, #T_bc8b8_row1_col4, #T_bc8b8_row1_col6, #T_bc8b8_row1_col7, #T_bc8b8_row1_col8, #T_bc8b8_row1_col9, #T_bc8b8_row2_col0, #T_bc8b8_row2_col1, #T_bc8b8_row2_col2, #T_bc8b8_row2_col3, #T_bc8b8_row2_col6, #T_bc8b8_row2_col7, #T_bc8b8_row2_col8, #T_bc8b8_row2_col9, #T_bc8b8_row3_col0, #T_bc8b8_row3_col1, #T_bc8b8_row3_col2, #T_bc8b8_row3_col3, #T_bc8b8_row3_col7, #T_bc8b8_row3_col8, #T_bc8b8_row3_col9, #T_bc8b8_row4_col0, #T_bc8b8_row4_col1, #T_bc8b8_row4_col2, #T_bc8b8_row4_col4, #T_bc8b8_row4_col6, #T_bc8b8_row4_col7, #T_bc8b8_row4_col8, #T_bc8b8_row4_col9, #T_bc8b8_row5_col0, #T_bc8b8_row5_col1, #T_bc8b8_row5_col2, #T_bc8b8_row5_col3, #T_bc8b8_row5_col4, #T_bc8b8_row5_col6, #T_bc8b8_row5_col7, #T_bc8b8_row5_col8, #T_bc8b8_row5_col9, #T_bc8b8_row6_col0, #T_bc8b8_row6_col1, #T_bc8b8_row6_col2, #T_bc8b8_row6_col3, #T_bc8b8_row6_col4, #T_bc8b8_row6_col6, #T_bc8b8_row6_col7, #T_bc8b8_row6_col8, #T_bc8b8_row6_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_bc8b8_row0_col3, #T_bc8b8_row2_col5, #T_bc8b8_row3_col4, #T_bc8b8_row3_col5, #T_bc8b8_row3_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_bc8b8_row0_col4, #T_bc8b8_row0_col5, #T_bc8b8_row0_col6, #T_bc8b8_row1_col5, #T_bc8b8_row2_col4, #T_bc8b8_row4_col3, #T_bc8b8_row4_col5, #T_bc8b8_row5_col5, #T_bc8b8_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_bc8b8">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_bc8b8_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_bc8b8_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_bc8b8_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_bc8b8_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_bc8b8_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_bc8b8_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_bc8b8_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_bc8b8_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_bc8b8_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_bc8b8_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bc8b8_row0_col0" class="data row0 col0" >barreirinhas</td>
#       <td id="T_bc8b8_row0_col1" class="data row0 col1" >-2.75</td>
#       <td id="T_bc8b8_row0_col2" class="data row0 col2" >-42.83</td>
#       <td id="T_bc8b8_row0_col3" class="data row0 col3" >78.85° F</td>
#       <td id="T_bc8b8_row0_col4" class="data row0 col4" >74%</td>
#       <td id="T_bc8b8_row0_col5" class="data row0 col5" >1%</td>
#       <td id="T_bc8b8_row0_col6" class="data row0 col6" >9.44</td>
#       <td id="T_bc8b8_row0_col7" class="data row0 col7" >BR</td>
#       <td id="T_bc8b8_row0_col8" class="data row0 col8" >2023-08-31 13:58:40</td>
#       <td id="T_bc8b8_row0_col9" class="data row0 col9" >Pousada Matriz</td>
#     </tr>
#     <tr>
#       <td id="T_bc8b8_row1_col0" class="data row1 col0" >isla vista</td>
#       <td id="T_bc8b8_row1_col1" class="data row1 col1" >34.41</td>
#       <td id="T_bc8b8_row1_col2" class="data row1 col2" >-119.86</td>
#       <td id="T_bc8b8_row1_col3" class="data row1 col3" >84.45° F</td>
#       <td id="T_bc8b8_row1_col4" class="data row1 col4" >64%</td>
#       <td id="T_bc8b8_row1_col5" class="data row1 col5" >1%</td>
#       <td id="T_bc8b8_row1_col6" class="data row1 col6" >6.35</td>
#       <td id="T_bc8b8_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_bc8b8_row1_col8" class="data row1 col8" >2023-08-31 13:58:40</td>
#       <td id="T_bc8b8_row1_col9" class="data row1 col9" >The Club & Guest House</td>
#     </tr>
#     <tr>
#       <td id="T_bc8b8_row2_col0" class="data row2 col0" >remire-montjoly</td>
#       <td id="T_bc8b8_row2_col1" class="data row2 col1" >4.92</td>
#       <td id="T_bc8b8_row2_col2" class="data row2 col2" >-52.27</td>
#       <td id="T_bc8b8_row2_col3" class="data row2 col3" >82.44° F</td>
#       <td id="T_bc8b8_row2_col4" class="data row2 col4" >74%</td>
#       <td id="T_bc8b8_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_bc8b8_row2_col6" class="data row2 col6" >2.30</td>
#       <td id="T_bc8b8_row2_col7" class="data row2 col7" >GF</td>
#       <td id="T_bc8b8_row2_col8" class="data row2 col8" >2023-08-31 13:48:51</td>
#       <td id="T_bc8b8_row2_col9" class="data row2 col9" >Complexe Belova</td>
#     </tr>
#     <tr>
#       <td id="T_bc8b8_row3_col0" class="data row3 col0" >la rinconada</td>
#       <td id="T_bc8b8_row3_col1" class="data row3 col1" >37.49</td>
#       <td id="T_bc8b8_row3_col2" class="data row3 col2" >-5.98</td>
#       <td id="T_bc8b8_row3_col3" class="data row3 col3" >81.00° F</td>
#       <td id="T_bc8b8_row3_col4" class="data row3 col4" >48%</td>
#       <td id="T_bc8b8_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_bc8b8_row3_col6" class="data row3 col6" >1.01</td>
#       <td id="T_bc8b8_row3_col7" class="data row3 col7" >ES</td>
#       <td id="T_bc8b8_row3_col8" class="data row3 col8" >2023-08-31 13:59:10</td>
#       <td id="T_bc8b8_row3_col9" class="data row3 col9" >Hotel Torre de los Guzmanes</td>
#     </tr>
#     <tr>
#       <td id="T_bc8b8_row4_col0" class="data row4 col0" >dinajpur</td>
#       <td id="T_bc8b8_row4_col1" class="data row4 col1" >25.63</td>
#       <td id="T_bc8b8_row4_col2" class="data row4 col2" >88.64</td>
#       <td id="T_bc8b8_row4_col3" class="data row4 col3" >84.85° F</td>
#       <td id="T_bc8b8_row4_col4" class="data row4 col4" >64%</td>
#       <td id="T_bc8b8_row4_col5" class="data row4 col5" >1%</td>
#       <td id="T_bc8b8_row4_col6" class="data row4 col6" >2.48</td>
#       <td id="T_bc8b8_row4_col7" class="data row4 col7" >BD</td>
#       <td id="T_bc8b8_row4_col8" class="data row4 col8" >2023-08-31 13:59:36</td>
#       <td id="T_bc8b8_row4_col9" class="data row4 col9" >VIP Guest House</td>
#     </tr>
#     <tr>
#       <td id="T_bc8b8_row5_col0" class="data row5 col0" >antioch</td>
#       <td id="T_bc8b8_row5_col1" class="data row5 col1" >36.21</td>
#       <td id="T_bc8b8_row5_col2" class="data row5 col2" >36.16</td>
#       <td id="T_bc8b8_row5_col3" class="data row5 col3" >80.42° F</td>
#       <td id="T_bc8b8_row5_col4" class="data row5 col4" >72%</td>
#       <td id="T_bc8b8_row5_col5" class="data row5 col5" >1%</td>
#       <td id="T_bc8b8_row5_col6" class="data row5 col6" >5.50</td>
#       <td id="T_bc8b8_row5_col7" class="data row5 col7" >TR</td>
#       <td id="T_bc8b8_row5_col8" class="data row5 col8" >2023-08-31 13:55:21</td>
#       <td id="T_bc8b8_row5_col9" class="data row5 col9" >The Great Antakya Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_bc8b8_row6_col0" class="data row6 col0" >la'ie</td>
#       <td id="T_bc8b8_row6_col1" class="data row6 col1" >21.65</td>
#       <td id="T_bc8b8_row6_col2" class="data row6 col2" >-157.93</td>
#       <td id="T_bc8b8_row6_col3" class="data row6 col3" >82.56° F</td>
#       <td id="T_bc8b8_row6_col4" class="data row6 col4" >67%</td>
#       <td id="T_bc8b8_row6_col5" class="data row6 col5" >1%</td>
#       <td id="T_bc8b8_row6_col6" class="data row6 col6" >5.99</td>
#       <td id="T_bc8b8_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_bc8b8_row6_col8" class="data row6 col8" >2023-08-31 13:54:00</td>
#       <td id="T_bc8b8_row6_col9" class="data row6 col9" >Hale Koolau</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
