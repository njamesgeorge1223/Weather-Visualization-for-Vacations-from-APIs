# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (True)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame,
         'Table: 1: City Weather Information')
# Out:
# <style type="text/css">
# #T_e813e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_e813e_row0_col0, #T_e813e_row0_col1, #T_e813e_row0_col2, #T_e813e_row0_col3, #T_e813e_row0_col4, #T_e813e_row0_col5, #T_e813e_row0_col6, #T_e813e_row0_col7, #T_e813e_row0_col8, #T_e813e_row1_col0, #T_e813e_row1_col1, #T_e813e_row1_col2, #T_e813e_row1_col3, #T_e813e_row1_col4, #T_e813e_row1_col6, #T_e813e_row1_col7, #T_e813e_row1_col8, #T_e813e_row2_col0, #T_e813e_row2_col1, #T_e813e_row2_col2, #T_e813e_row2_col3, #T_e813e_row2_col4, #T_e813e_row2_col6, #T_e813e_row2_col7, #T_e813e_row2_col8, #T_e813e_row3_col0, #T_e813e_row3_col1, #T_e813e_row3_col2, #T_e813e_row3_col3, #T_e813e_row3_col4, #T_e813e_row3_col5, #T_e813e_row3_col6, #T_e813e_row3_col7, #T_e813e_row3_col8, #T_e813e_row4_col0, #T_e813e_row4_col1, #T_e813e_row4_col2, #T_e813e_row4_col3, #T_e813e_row4_col4, #T_e813e_row4_col5, #T_e813e_row4_col6, #T_e813e_row4_col7, #T_e813e_row4_col8, #T_e813e_row5_col0, #T_e813e_row5_col1, #T_e813e_row5_col2, #T_e813e_row5_col3, #T_e813e_row5_col4, #T_e813e_row5_col5, #T_e813e_row5_col6, #T_e813e_row5_col7, #T_e813e_row5_col8, #T_e813e_row6_col0, #T_e813e_row6_col1, #T_e813e_row6_col2, #T_e813e_row6_col3, #T_e813e_row6_col4, #T_e813e_row6_col6, #T_e813e_row6_col7, #T_e813e_row6_col8, #T_e813e_row7_col0, #T_e813e_row7_col1, #T_e813e_row7_col2, #T_e813e_row7_col3, #T_e813e_row7_col4, #T_e813e_row7_col5, #T_e813e_row7_col6, #T_e813e_row7_col7, #T_e813e_row7_col8, #T_e813e_row8_col0, #T_e813e_row8_col1, #T_e813e_row8_col2, #T_e813e_row8_col3, #T_e813e_row8_col4, #T_e813e_row8_col5, #T_e813e_row8_col6, #T_e813e_row8_col7, #T_e813e_row8_col8, #T_e813e_row9_col0, #T_e813e_row9_col1, #T_e813e_row9_col2, #T_e813e_row9_col3, #T_e813e_row9_col4, #T_e813e_row9_col5, #T_e813e_row9_col6, #T_e813e_row9_col7, #T_e813e_row9_col8, #T_e813e_row10_col0, #T_e813e_row10_col1, #T_e813e_row10_col2, #T_e813e_row10_col3, #T_e813e_row10_col4, #T_e813e_row10_col5, #T_e813e_row10_col6, #T_e813e_row10_col7, #T_e813e_row10_col8, #T_e813e_row11_col0, #T_e813e_row11_col1, #T_e813e_row11_col2, #T_e813e_row11_col3, #T_e813e_row11_col4, #T_e813e_row11_col6, #T_e813e_row11_col7, #T_e813e_row11_col8, #T_e813e_row12_col0, #T_e813e_row12_col1, #T_e813e_row12_col2, #T_e813e_row12_col3, #T_e813e_row12_col4, #T_e813e_row12_col6, #T_e813e_row12_col7, #T_e813e_row12_col8, #T_e813e_row13_col0, #T_e813e_row13_col1, #T_e813e_row13_col2, #T_e813e_row13_col3, #T_e813e_row13_col4, #T_e813e_row13_col6, #T_e813e_row13_col7, #T_e813e_row13_col8, #T_e813e_row14_col0, #T_e813e_row14_col1, #T_e813e_row14_col2, #T_e813e_row14_col3, #T_e813e_row14_col4, #T_e813e_row14_col5, #T_e813e_row14_col6, #T_e813e_row14_col7, #T_e813e_row14_col8, #T_e813e_row15_col0, #T_e813e_row15_col1, #T_e813e_row15_col2, #T_e813e_row15_col3, #T_e813e_row15_col4, #T_e813e_row15_col5, #T_e813e_row15_col6, #T_e813e_row15_col7, #T_e813e_row15_col8, #T_e813e_row16_col0, #T_e813e_row16_col1, #T_e813e_row16_col2, #T_e813e_row16_col3, #T_e813e_row16_col4, #T_e813e_row16_col6, #T_e813e_row16_col7, #T_e813e_row16_col8, #T_e813e_row17_col0, #T_e813e_row17_col1, #T_e813e_row17_col2, #T_e813e_row17_col3, #T_e813e_row17_col4, #T_e813e_row17_col6, #T_e813e_row17_col7, #T_e813e_row17_col8, #T_e813e_row18_col0, #T_e813e_row18_col1, #T_e813e_row18_col2, #T_e813e_row18_col4, #T_e813e_row18_col5, #T_e813e_row18_col6, #T_e813e_row18_col7, #T_e813e_row18_col8, #T_e813e_row19_col0, #T_e813e_row19_col1, #T_e813e_row19_col2, #T_e813e_row19_col3, #T_e813e_row19_col4, #T_e813e_row19_col6, #T_e813e_row19_col7, #T_e813e_row19_col8, #T_e813e_row20_col0, #T_e813e_row20_col1, #T_e813e_row20_col2, #T_e813e_row20_col3, #T_e813e_row20_col4, #T_e813e_row20_col6, #T_e813e_row20_col7, #T_e813e_row20_col8, #T_e813e_row21_col0, #T_e813e_row21_col1, #T_e813e_row21_col2, #T_e813e_row21_col3, #T_e813e_row21_col4, #T_e813e_row21_col5, #T_e813e_row21_col6, #T_e813e_row21_col7, #T_e813e_row21_col8, #T_e813e_row22_col0, #T_e813e_row22_col1, #T_e813e_row22_col2, #T_e813e_row22_col3, #T_e813e_row22_col4, #T_e813e_row22_col5, #T_e813e_row22_col6, #T_e813e_row2 ...

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions and Locations**

# %%
idealWeatherLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Humidity'] >= 35) \
                  & (idealWeatherLocationDataFrame['Humidity'] <= 75), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealWeatherLocationDataFrame['Cloudiness'] <= 5), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealWeatherLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealWeatherLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Weather Location Information**

# %%
idealWeatherLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealWeatherLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealWeatherLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Weather Location Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealWeatherLocationDataFrame,
         'Table: 2: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_3631d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_3631d_row0_col0, #T_3631d_row0_col1, #T_3631d_row0_col2, #T_3631d_row0_col3, #T_3631d_row0_col4, #T_3631d_row0_col6, #T_3631d_row0_col7, #T_3631d_row0_col8, #T_3631d_row1_col0, #T_3631d_row1_col1, #T_3631d_row1_col2, #T_3631d_row1_col3, #T_3631d_row1_col4, #T_3631d_row1_col6, #T_3631d_row1_col7, #T_3631d_row1_col8, #T_3631d_row2_col0, #T_3631d_row2_col1, #T_3631d_row2_col2, #T_3631d_row2_col3, #T_3631d_row2_col4, #T_3631d_row2_col6, #T_3631d_row2_col7, #T_3631d_row2_col8, #T_3631d_row3_col0, #T_3631d_row3_col1, #T_3631d_row3_col2, #T_3631d_row3_col3, #T_3631d_row3_col4, #T_3631d_row3_col7, #T_3631d_row3_col8, #T_3631d_row4_col0, #T_3631d_row4_col1, #T_3631d_row4_col2, #T_3631d_row4_col3, #T_3631d_row4_col4, #T_3631d_row4_col6, #T_3631d_row4_col7, #T_3631d_row4_col8, #T_3631d_row5_col0, #T_3631d_row5_col1, #T_3631d_row5_col2, #T_3631d_row5_col3, #T_3631d_row5_col4, #T_3631d_row5_col7, #T_3631d_row5_col8, #T_3631d_row6_col0, #T_3631d_row6_col1, #T_3631d_row6_col2, #T_3631d_row6_col3, #T_3631d_row6_col6, #T_3631d_row6_col7, #T_3631d_row6_col8, #T_3631d_row7_col0, #T_3631d_row7_col1, #T_3631d_row7_col2, #T_3631d_row7_col3, #T_3631d_row7_col4, #T_3631d_row7_col6, #T_3631d_row7_col7, #T_3631d_row7_col8, #T_3631d_row8_col0, #T_3631d_row8_col1, #T_3631d_row8_col2, #T_3631d_row8_col3, #T_3631d_row8_col6, #T_3631d_row8_col7, #T_3631d_row8_col8, #T_3631d_row9_col0, #T_3631d_row9_col1, #T_3631d_row9_col2, #T_3631d_row9_col4, #T_3631d_row9_col6, #T_3631d_row9_col7, #T_3631d_row9_col8, #T_3631d_row10_col0, #T_3631d_row10_col1, #T_3631d_row10_col2, #T_3631d_row10_col4, #T_3631d_row10_col6, #T_3631d_row10_col7, #T_3631d_row10_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_3631d_row0_col5, #T_3631d_row1_col5, #T_3631d_row2_col5, #T_3631d_row3_col5, #T_3631d_row4_col5, #T_3631d_row5_col6, #T_3631d_row6_col4, #T_3631d_row6_col5, #T_3631d_row7_col5, #T_3631d_row8_col5, #T_3631d_row9_col3, #T_3631d_row9_col5, #T_3631d_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_3631d_row3_col6, #T_3631d_row5_col5, #T_3631d_row8_col4, #T_3631d_row10_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_3631d">
#   <caption>Table: 2: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_3631d_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_3631d_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_3631d_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_3631d_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_3631d_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_3631d_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_3631d_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_3631d_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_3631d_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3631d_row0_col0" class="data row0 col0" >bethel</td>
#       <td id="T_3631d_row0_col1" class="data row0 col1" >41.37</td>
#       <td id="T_3631d_row0_col2" class="data row0 col2" >-73.41</td>
#       <td id="T_3631d_row0_col3" class="data row0 col3" >77.58° F</td>
#       <td id="T_3631d_row0_col4" class="data row0 col4" >67%</td>
#       <td id="T_3631d_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_3631d_row0_col6" class="data row0 col6" >3.44</td>
#       <td id="T_3631d_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_3631d_row0_col8" class="data row0 col8" >2023-08-27 14:26:40</td>
#     </tr>
#     <tr>
#       <td id="T_3631d_row1_col0" class="data row1 col0" >fort mcmurray</td>
#       <td id="T_3631d_row1_col1" class="data row1 col1" >56.73</td>
#       <td id="T_3631d_row1_col2" class="data row1 col2" >-111.38</td>
#       <td id="T_3631d_row1_col3" class="data row1 col3" >76.51° F</td>
#       <td id="T_3631d_row1_col4" class="data row1 col4" >50%</td>
#       <td id="T_3631d_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_3631d_row1_col6" class="data row1 col6" >3.44</td>
#       <td id="T_3631d_row1_col7" class="data row1 col7" >CA</td>
#       <td id="T_3631d_row1_col8" class="data row1 col8" >2023-08-27 14:27:15</td>
#     </tr>
#     <tr>
#       <td id="T_3631d_row2_col0" class="data row2 col0" >argostolion</td>
#       <td id="T_3631d_row2_col1" class="data row2 col1" >38.18</td>
#       <td id="T_3631d_row2_col2" class="data row2 col2" >20.49</td>
#       <td id="T_3631d_row2_col3" class="data row2 col3" >78.87° F</td>
#       <td id="T_3631d_row2_col4" class="data row2 col4" >73%</td>
#       <td id="T_3631d_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_3631d_row2_col6" class="data row2 col6" >4.61</td>
#       <td id="T_3631d_row2_col7" class="data row2 col7" >GR</td>
#       <td id="T_3631d_row2_col8" class="data row2 col8" >2023-08-27 14:34:17</td>
#     </tr>
#     <tr>
#       <td id="T_3631d_row3_col0" class="data row3 col0" >hamilton</td>
#       <td id="T_3631d_row3_col1" class="data row3 col1" >39.18</td>
#       <td id="T_3631d_row3_col2" class="data row3 col2" >-84.53</td>
#       <td id="T_3631d_row3_col3" class="data row3 col3" >80.83° F</td>
#       <td id="T_3631d_row3_col4" class="data row3 col4" >59%</td>
#       <td id="T_3631d_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_3631d_row3_col6" class="data row3 col6" >8.05</td>
#       <td id="T_3631d_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_3631d_row3_col8" class="data row3 col8" >2023-08-27 14:25:48</td>
#     </tr>
#     <tr>
#       <td id="T_3631d_row4_col0" class="data row4 col0" >alexandria</td>
#       <td id="T_3631d_row4_col1" class="data row4 col1" >31.22</td>
#       <td id="T_3631d_row4_col2" class="data row4 col2" >29.96</td>
#       <td id="T_3631d_row4_col3" class="data row4 col3" >79.34° F</td>
#       <td id="T_3631d_row4_col4" class="data row4 col4" >71%</td>
#       <td id="T_3631d_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_3631d_row4_col6" class="data row4 col6" >6.93</td>
#       <td id="T_3631d_row4_col7" class="data row4 col7" >EG</td>
#       <td id="T_3631d_row4_col8" class="data row4 col8" >2023-08-27 14:32:07</td>
#     </tr>
#     <tr>
#       <td id="T_3631d_row5_col0" class="data row5 col0" >rethymno</td>
#       <td id="T_3631d_row5_col1" class="data row5 col1" >35.36</td>
#       <td id="T_3631d_row5_col2" class="data row5 col2" >24.47</td>
#       <td id="T_3631d_row5_col3" class="data row5 col3" >78.42° F</td>
#       <td id="T_3631d_row5_col4" class="data row5 col4" >57%</td>
#       <td id="T_3631d_row5_col5" class="data row5 col5" >1%</td>
#       <td id="T_3631d_row5_col6" class="data row5 col6" >1.16</td>
#       <td id="T_3631d_row5_col7" class="data row5 col7" >GR</td>
#       <td id="T_3631d_row5_col8" class="data row5 col8" >2023-08-27 14:34:38</td>
#     </tr>
#     <tr>
#       <td id="T_3631d_row6_col0" class="data row6 col0" >holdrege</td>
#       <td id="T_3631d_row6_col1" class="data row6 col1" >40.44</td>
#       <td id="T_3631d_row6_col2" class="data row6 col2" >-99.37</td>
#       <td id="T_3631d_row6_col3" class="data row6 col3" >80.38° F</td>
#       <td id="T_3631d_row6_col4" class="data row6 col4" >49%</td>
#       <td id="T_3631d_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_3631d_row6_col6" class="data row6 col6" >6.91</td>
#       <td id="T_3631d_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_3631d_row6_col8" class="data row6 col8" >2023-08-27 14:34:43</td>
#     </tr>
#     <tr>
#       <td id="T_3631d_row7_col0" class="data row7 col0" >simeonovgrad</td>
#       <td id="T_3631d_row7_col1" class="data row7 col1" >42.03</td>
#       <td id="T_3631d_row7_col2" class="data row7 col2" >25.83</td>
#       <td id="T_3631d_row7_co

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealWeatherLocationDataFrame,
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealWeatherLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Hampton Inn Danbury in bethel, US
#
#
# Located the following hotel...Nomad Hotel and Suites in fort mcmurray, CA
#
#
# Located the following hotel...Ainos Hotel in argostolion, GR
#
#
# Located the following hotel...North Vista Manor in hamilton, US
#
#
# Located the following hotel...Smoha Zahran Haus (7th floor) in alexandria, EG
#
#
# Located the following hotel...Jo-An Palace in rethymno, GR
#
#
# Located the following hotel...Hotel Dale in holdrege, US
#
#
# Located the following hotel...Days Inn by Wyndham Oil City Conference Center in oil city, US
#
#
# Located the following hotel...the Hoxton in portland, US
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3: Hotel Locations')
# Out:
# <style type="text/css">
# #T_28647 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_28647_row0_col0, #T_28647_row0_col1, #T_28647_row0_col2, #T_28647_row0_col3, #T_28647_row0_col4, #T_28647_row0_col6, #T_28647_row0_col7, #T_28647_row0_col8, #T_28647_row0_col9, #T_28647_row1_col0, #T_28647_row1_col1, #T_28647_row1_col2, #T_28647_row1_col3, #T_28647_row1_col4, #T_28647_row1_col6, #T_28647_row1_col7, #T_28647_row1_col8, #T_28647_row1_col9, #T_28647_row2_col0, #T_28647_row2_col1, #T_28647_row2_col2, #T_28647_row2_col3, #T_28647_row2_col6, #T_28647_row2_col7, #T_28647_row2_col8, #T_28647_row2_col9, #T_28647_row3_col0, #T_28647_row3_col1, #T_28647_row3_col2, #T_28647_row3_col3, #T_28647_row3_col4, #T_28647_row3_col7, #T_28647_row3_col8, #T_28647_row3_col9, #T_28647_row4_col0, #T_28647_row4_col1, #T_28647_row4_col2, #T_28647_row4_col3, #T_28647_row4_col4, #T_28647_row4_col6, #T_28647_row4_col7, #T_28647_row4_col8, #T_28647_row4_col9, #T_28647_row5_col0, #T_28647_row5_col1, #T_28647_row5_col2, #T_28647_row5_col3, #T_28647_row5_col4, #T_28647_row5_col7, #T_28647_row5_col8, #T_28647_row5_col9, #T_28647_row6_col0, #T_28647_row6_col1, #T_28647_row6_col2, #T_28647_row6_col3, #T_28647_row6_col6, #T_28647_row6_col7, #T_28647_row6_col8, #T_28647_row6_col9, #T_28647_row7_col0, #T_28647_row7_col1, #T_28647_row7_col2, #T_28647_row7_col4, #T_28647_row7_col6, #T_28647_row7_col7, #T_28647_row7_col8, #T_28647_row7_col9, #T_28647_row8_col0, #T_28647_row8_col1, #T_28647_row8_col2, #T_28647_row8_col4, #T_28647_row8_col6, #T_28647_row8_col7, #T_28647_row8_col8, #T_28647_row8_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_28647_row0_col5, #T_28647_row1_col5, #T_28647_row2_col5, #T_28647_row3_col5, #T_28647_row4_col5, #T_28647_row5_col6, #T_28647_row6_col4, #T_28647_row6_col5, #T_28647_row7_col3, #T_28647_row7_col5, #T_28647_row8_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_28647_row2_col4, #T_28647_row3_col6, #T_28647_row5_col5, #T_28647_row8_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_28647">
#   <caption>Table: 3: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_28647_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_28647_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_28647_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_28647_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_28647_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_28647_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_28647_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_28647_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_28647_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_28647_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_28647_row0_col0" class="data row0 col0" >bethel</td>
#       <td id="T_28647_row0_col1" class="data row0 col1" >41.37</td>
#       <td id="T_28647_row0_col2" class="data row0 col2" >-73.41</td>
#       <td id="T_28647_row0_col3" class="data row0 col3" >77.58° F</td>
#       <td id="T_28647_row0_col4" class="data row0 col4" >67%</td>
#       <td id="T_28647_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_28647_row0_col6" class="data row0 col6" >3.44</td>
#       <td id="T_28647_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_28647_row0_col8" class="data row0 col8" >2023-08-27 14:26:40</td>
#       <td id="T_28647_row0_col9" class="data row0 col9" >Hampton Inn Danbury</td>
#     </tr>
#     <tr>
#       <td id="T_28647_row1_col0" class="data row1 col0" >fort mcmurray</td>
#       <td id="T_28647_row1_col1" class="data row1 col1" >56.73</td>
#       <td id="T_28647_row1_col2" class="data row1 col2" >-111.38</td>
#       <td id="T_28647_row1_col3" class="data row1 col3" >76.51° F</td>
#       <td id="T_28647_row1_col4" class="data row1 col4" >50%</td>
#       <td id="T_28647_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_28647_row1_col6" class="data row1 col6" >3.44</td>
#       <td id="T_28647_row1_col7" class="data row1 col7" >CA</td>
#       <td id="T_28647_row1_col8" class="data row1 col8" >2023-08-27 14:27:15</td>
#       <td id="T_28647_row1_col9" class="data row1 col9" >Nomad Hotel and Suites</td>
#     </tr>
#     <tr>
#       <td id="T_28647_row2_col0" class="data row2 col0" >argostolion</td>
#       <td id="T_28647_row2_col1" class="data row2 col1" >38.18</td>
#       <td id="T_28647_row2_col2" class="data row2 col2" >20.49</td>
#       <td id="T_28647_row2_col3" class="data row2 col3" >78.87° F</td>
#       <td id="T_28647_row2_col4" class="data row2 col4" >73%</td>
#       <td id="T_28647_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_28647_row2_col6" class="data row2 col6" >4.61</td>
#       <td id="T_28647_row2_col7" class="data row2 col7" >GR</td>
#       <td id="T_28647_row2_col8" class="data row2 col8" >2023-08-27 14:34:17</td>
#       <td id="T_28647_row2_col9" class="data row2 col9" >Ainos Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_28647_row3_col0" class="data row3 col0" >hamilton</td>
#       <td id="T_28647_row3_col1" class="data row3 col1" >39.18</td>
#       <td id="T_28647_row3_col2" class="data row3 col2" >-84.53</td>
#       <td id="T_28647_row3_col3" class="data row3 col3" >80.83° F</td>
#       <td id="T_28647_row3_col4" class="data row3 col4" >59%</td>
#       <td id="T_28647_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_28647_row3_col6" class="data row3 col6" >8.05</td>
#       <td id="T_28647_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_28647_row3_col8" class="data row3 col8" >2023-08-27 14:25:48</td>
#       <td id="T_28647_row3_col9" class="data row3 col9" >North Vista Manor</td>
#     </tr>
#     <tr>
#       <td id="T_28647_row4_col0" class="data row4 col0" >alexandria</td>
#       <td id="T_28647_row4_col1" class="data row4 col1" >31.22</td>
#       <td id="T_28647_row4_col2" class="data row4 col2" >29.96</td>
#       <td id="T_28647_row4_col3" class="data row4 col3" >79.34° F</td>
#       <td id="T_28647_row4_col4" class="data row4 col4" >71%</td>
#       <td id="T_28647_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_28647_row4_col6" class="data row4 col6" >6.93</td>
#       <td id="T_28647_row4_col7" class="data row4 col7" >EG</td>
#       <td id="T_28647_row4_col8" class="data row4 col8" >2023-08-27 14:32:07</td>
#       <td id="T_28647_row4_col9" class="data row4 col9" >Smoha Zahran Haus (7th floor)</td>
#     </tr>
#     <tr>
#       <td id="T_28647_row5_col0" class="data row5 col0" >rethymno</td>
#       <td id="T_28647_row5_col1" class="data row5 col1" >35.36</td>
#       <td id="T_28647_row5_col2" class="data row5 col2" >24.47</td>
#       <td id="T_28647_row5_col3" class="data row5 col3" >78.42° F</td>
#       <td id="T_28647_row5_col4" class="data row5 col4" >57%</td>
#       <td id="T_28647_row5_col5" class="data row5 col5" >1%</td>
#       <td id="T_28647_row5_col6" class="data row5 col6" >1.16</td>
#       <td id="T_28647_row5_col7" class="data row5 col7" >GR</td>
#       <td id="T_28647_row5_col8" class="data row5 col8" >2023-08-27 14:34:38</td>
#       <td id="T_28647_row5_col9" class="data row5 col9" >Jo-An Palace</td>
#     </tr>
#     <tr>
#       <td id="T_28647_row6_col0" class="data row6 col0" >holdrege</td>
#       <td id="T_28647_row6_col1" class="data row6 col1" >40.44</td>
#       <td id="T_28647_row6_col2" class="data row6 col2" >-99.37</td>
#       <td id="T_28647_row6_col3" class="data row6 col3" >80.38° F</td>
#       <td id="T_28647_row6_col4" class="data row6 col4" >49%</td>
#       <td id="T_28647_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_28647_row6_col6" class="data row6 col6" >6.91</td>
#       <td id="T_28647_row6_col7"

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
log_subroutine \
    .EndProgramExecution()
# Out:
# Program execution ends at 08/27/2023 14:39:51.
