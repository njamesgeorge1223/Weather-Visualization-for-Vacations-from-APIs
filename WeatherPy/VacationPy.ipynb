# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (True)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame,
         'Table: 1: City Weather Information')
# Out:
# <style type="text/css">
# #T_41c7f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_41c7f_row0_col0, #T_41c7f_row0_col1, #T_41c7f_row0_col2, #T_41c7f_row0_col3, #T_41c7f_row0_col4, #T_41c7f_row0_col5, #T_41c7f_row0_col6, #T_41c7f_row0_col7, #T_41c7f_row0_col8, #T_41c7f_row1_col0, #T_41c7f_row1_col1, #T_41c7f_row1_col2, #T_41c7f_row1_col3, #T_41c7f_row1_col4, #T_41c7f_row1_col5, #T_41c7f_row1_col6, #T_41c7f_row1_col7, #T_41c7f_row1_col8, #T_41c7f_row2_col0, #T_41c7f_row2_col1, #T_41c7f_row2_col2, #T_41c7f_row2_col3, #T_41c7f_row2_col4, #T_41c7f_row2_col5, #T_41c7f_row2_col6, #T_41c7f_row2_col7, #T_41c7f_row2_col8, #T_41c7f_row3_col0, #T_41c7f_row3_col1, #T_41c7f_row3_col2, #T_41c7f_row3_col3, #T_41c7f_row3_col6, #T_41c7f_row3_col7, #T_41c7f_row3_col8, #T_41c7f_row4_col0, #T_41c7f_row4_col1, #T_41c7f_row4_col2, #T_41c7f_row4_col4, #T_41c7f_row4_col5, #T_41c7f_row4_col6, #T_41c7f_row4_col7, #T_41c7f_row4_col8, #T_41c7f_row5_col0, #T_41c7f_row5_col1, #T_41c7f_row5_col2, #T_41c7f_row5_col3, #T_41c7f_row5_col4, #T_41c7f_row5_col5, #T_41c7f_row5_col6, #T_41c7f_row5_col7, #T_41c7f_row5_col8, #T_41c7f_row6_col0, #T_41c7f_row6_col1, #T_41c7f_row6_col2, #T_41c7f_row6_col3, #T_41c7f_row6_col4, #T_41c7f_row6_col5, #T_41c7f_row6_col6, #T_41c7f_row6_col7, #T_41c7f_row6_col8, #T_41c7f_row7_col0, #T_41c7f_row7_col1, #T_41c7f_row7_col2, #T_41c7f_row7_col3, #T_41c7f_row7_col4, #T_41c7f_row7_col6, #T_41c7f_row7_col7, #T_41c7f_row7_col8, #T_41c7f_row8_col0, #T_41c7f_row8_col1, #T_41c7f_row8_col2, #T_41c7f_row8_col3, #T_41c7f_row8_col4, #T_41c7f_row8_col6, #T_41c7f_row8_col7, #T_41c7f_row8_col8, #T_41c7f_row9_col0, #T_41c7f_row9_col1, #T_41c7f_row9_col2, #T_41c7f_row9_col3, #T_41c7f_row9_col4, #T_41c7f_row9_col5, #T_41c7f_row9_col6, #T_41c7f_row9_col7, #T_41c7f_row9_col8, #T_41c7f_row10_col0, #T_41c7f_row10_col1, #T_41c7f_row10_col2, #T_41c7f_row10_col3, #T_41c7f_row10_col4, #T_41c7f_row10_col5, #T_41c7f_row10_col6, #T_41c7f_row10_col7, #T_41c7f_row10_col8, #T_41c7f_row11_col0, #T_41c7f_row11_col1, #T_41c7f_row11_col2, #T_41c7f_row11_col3, #T_41c7f_row11_col4, #T_41c7f_row11_col5, #T_41c7f_row11_col6, #T_41c7f_row11_col7, #T_41c7f_row11_col8, #T_41c7f_row12_col0, #T_41c7f_row12_col1, #T_41c7f_row12_col2, #T_41c7f_row12_col3, #T_41c7f_row12_col4, #T_41c7f_row12_col6, #T_41c7f_row12_col7, #T_41c7f_row12_col8, #T_41c7f_row13_col0, #T_41c7f_row13_col1, #T_41c7f_row13_col2, #T_41c7f_row13_col3, #T_41c7f_row13_col4, #T_41c7f_row13_col6, #T_41c7f_row13_col7, #T_41c7f_row13_col8, #T_41c7f_row14_col0, #T_41c7f_row14_col1, #T_41c7f_row14_col2, #T_41c7f_row14_col3, #T_41c7f_row14_col4, #T_41c7f_row14_col5, #T_41c7f_row14_col6, #T_41c7f_row14_col7, #T_41c7f_row14_col8, #T_41c7f_row15_col0, #T_41c7f_row15_col1, #T_41c7f_row15_col2, #T_41c7f_row15_col3, #T_41c7f_row15_col4, #T_41c7f_row15_col6, #T_41c7f_row15_col7, #T_41c7f_row15_col8, #T_41c7f_row16_col0, #T_41c7f_row16_col1, #T_41c7f_row16_col2, #T_41c7f_row16_col3, #T_41c7f_row16_col4, #T_41c7f_row16_col6, #T_41c7f_row16_col7, #T_41c7f_row16_col8, #T_41c7f_row17_col0, #T_41c7f_row17_col1, #T_41c7f_row17_col2, #T_41c7f_row17_col3, #T_41c7f_row17_col4, #T_41c7f_row17_col6, #T_41c7f_row17_col7, #T_41c7f_row17_col8, #T_41c7f_row18_col0, #T_41c7f_row18_col1, #T_41c7f_row18_col2, #T_41c7f_row18_col3, #T_41c7f_row18_col4, #T_41c7f_row18_col5, #T_41c7f_row18_col6, #T_41c7f_row18_col7, #T_41c7f_row18_col8, #T_41c7f_row19_col0, #T_41c7f_row19_col1, #T_41c7f_row19_col2, #T_41c7f_row19_col3, #T_41c7f_row19_col4, #T_41c7f_row19_col5, #T_41c7f_row19_col6, #T_41c7f_row19_col7, #T_41c7f_row19_col8, #T_41c7f_row20_col0, #T_41c7f_row20_col1, #T_41c7f_row20_col2, #T_41c7f_row20_col3, #T_41c7f_row20_col4, #T_41c7f_row20_col5, #T_41c7f_row20_col6, #T_41c7f_row20_col7, #T_41c7f_row20_col8, #T_41c7f_row21_col0, #T_41c7f_row21_col1, #T_41c7f_row21_col2, #T_41c7f_row21_col3, #T_41c7f_row21_col4, #T_41c7f_row21_col5, #T_41c7f_row21_col6, #T_41c7f_row21_col7, #T_41c7f_row21_col8, #T_41c7f_row22_col0, #T_41c7f_row22_col1, #T_41c7f_row22_col2, #T_41c7f_row22_col3, #T_41c7f_row22_col4, #T_41c7f_row22_col7, #T_41c7f_ro ...

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions and Locations**

# %%
idealWeatherLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Humidity'] >= 35) \
                  & (idealWeatherLocationDataFrame['Humidity'] <= 75), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealWeatherLocationDataFrame['Cloudiness'] <= 5), :]

idealWeatherLocationDataFrame \
    = idealWeatherLocationDataFrame \
            .loc \
                [(idealWeatherLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealWeatherLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealWeatherLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Weather Location Information**

# %%
idealWeatherLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealWeatherLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealWeatherLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Weather Location Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealWeatherLocationDataFrame,
         'Table: 2: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_78324 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_78324_row0_col0, #T_78324_row0_col1, #T_78324_row0_col2, #T_78324_row0_col3, #T_78324_row0_col4, #T_78324_row0_col6, #T_78324_row0_col7, #T_78324_row0_col8, #T_78324_row1_col0, #T_78324_row1_col1, #T_78324_row1_col2, #T_78324_row1_col6, #T_78324_row1_col7, #T_78324_row1_col8, #T_78324_row2_col0, #T_78324_row2_col1, #T_78324_row2_col2, #T_78324_row2_col3, #T_78324_row2_col4, #T_78324_row2_col6, #T_78324_row2_col7, #T_78324_row2_col8, #T_78324_row3_col0, #T_78324_row3_col1, #T_78324_row3_col2, #T_78324_row3_col3, #T_78324_row3_col4, #T_78324_row3_col6, #T_78324_row3_col7, #T_78324_row3_col8, #T_78324_row4_col0, #T_78324_row4_col1, #T_78324_row4_col2, #T_78324_row4_col4, #T_78324_row4_col7, #T_78324_row4_col8, #T_78324_row5_col0, #T_78324_row5_col1, #T_78324_row5_col2, #T_78324_row5_col3, #T_78324_row5_col7, #T_78324_row5_col8, #T_78324_row6_col0, #T_78324_row6_col1, #T_78324_row6_col2, #T_78324_row6_col3, #T_78324_row6_col4, #T_78324_row6_col6, #T_78324_row6_col7, #T_78324_row6_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_78324_row0_col5, #T_78324_row1_col3, #T_78324_row1_col5, #T_78324_row2_col5, #T_78324_row3_col5, #T_78324_row4_col5, #T_78324_row5_col4, #T_78324_row5_col6, #T_78324_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_78324_row1_col4, #T_78324_row4_col3, #T_78324_row4_col6, #T_78324_row5_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_78324">
#   <caption>Table: 2: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_78324_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_78324_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_78324_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_78324_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_78324_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_78324_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_78324_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_78324_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_78324_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_78324_row0_col0" class="data row0 col0" >constantia</td>
#       <td id="T_78324_row0_col1" class="data row0 col1" >44.18</td>
#       <td id="T_78324_row0_col2" class="data row0 col2" >28.65</td>
#       <td id="T_78324_row0_col3" class="data row0 col3" >83.08° F</td>
#       <td id="T_78324_row0_col4" class="data row0 col4" >62%</td>
#       <td id="T_78324_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_78324_row0_col6" class="data row0 col6" >7.40</td>
#       <td id="T_78324_row0_col7" class="data row0 col7" >RO</td>
#       <td id="T_78324_row0_col8" class="data row0 col8" >2023-08-27 08:54:16</td>
#     </tr>
#     <tr>
#       <td id="T_78324_row1_col0" class="data row1 col0" >bethel</td>
#       <td id="T_78324_row1_col1" class="data row1 col1" >41.37</td>
#       <td id="T_78324_row1_col2" class="data row1 col2" >-73.41</td>
#       <td id="T_78324_row1_col3" class="data row1 col3" >76.03° F</td>
#       <td id="T_78324_row1_col4" class="data row1 col4" >69%</td>
#       <td id="T_78324_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_78324_row1_col6" class="data row1 col6" >8.05</td>
#       <td id="T_78324_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_78324_row1_col8" class="data row1 col8" >2023-08-27 08:54:18</td>
#     </tr>
#     <tr>
#       <td id="T_78324_row2_col0" class="data row2 col0" >fort meade</td>
#       <td id="T_78324_row2_col1" class="data row2 col1" >39.11</td>
#       <td id="T_78324_row2_col2" class="data row2 col2" >-76.74</td>
#       <td id="T_78324_row2_col3" class="data row2 col3" >82.80° F</td>
#       <td id="T_78324_row2_col4" class="data row2 col4" >61%</td>
#       <td id="T_78324_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_78324_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_78324_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_78324_row2_col8" class="data row2 col8" >2023-08-27 08:54:32</td>
#     </tr>
#     <tr>
#       <td id="T_78324_row3_col0" class="data row3 col0" >westport</td>
#       <td id="T_78324_row3_col1" class="data row3 col1" >41.14</td>
#       <td id="T_78324_row3_col2" class="data row3 col2" >-73.36</td>
#       <td id="T_78324_row3_col3" class="data row3 col3" >77.47° F</td>
#       <td id="T_78324_row3_col4" class="data row3 col4" >67%</td>
#       <td id="T_78324_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_78324_row3_col6" class="data row3 col6" >9.22</td>
#       <td id="T_78324_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_78324_row3_col8" class="data row3 col8" >2023-08-27 08:45:41</td>
#     </tr>
#     <tr>
#       <td id="T_78324_row4_col0" class="data row4 col0" >benghazi</td>
#       <td id="T_78324_row4_col1" class="data row4 col1" >32.12</td>
#       <td id="T_78324_row4_col2" class="data row4 col2" >20.07</td>
#       <td id="T_78324_row4_col3" class="data row4 col3" >83.39° F</td>
#       <td id="T_78324_row4_col4" class="data row4 col4" >67%</td>
#       <td id="T_78324_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_78324_row4_col6" class="data row4 col6" >9.82</td>
#       <td id="T_78324_row4_col7" class="data row4 col7" >LY</td>
#       <td id="T_78324_row4_col8" class="data row4 col8" >2023-08-27 08:55:10</td>
#     </tr>
#     <tr>
#       <td id="T_78324_row5_col0" class="data row5 col0" >rioblanco</td>
#       <td id="T_78324_row5_col1" class="data row5 col1" >3.53</td>
#       <td id="T_78324_row5_col2" class="data row5 col2" >-75.68</td>
#       <td id="T_78324_row5_col3" class="data row5 col3" >79.32° F</td>
#       <td id="T_78324_row5_col4" class="data row5 col4" >40%</td>
#       <td id="T_78324_row5_col5" class="data row5 col5" >4%</td>
#       <td id="T_78324_row5_col6" class="data row5 col6" >6.06</td>
#       <td id="T_78324_row5_col7" class="data row5 col7" >CO</td>
#       <td id="T_78324_row5_col8" class="data row5 col8" >2023-08-27 08:55:17</td>
#     </tr>
#     <tr>
#       <td id="T_78324_row6_col0" class="data row6 col0" >shchyolkino</td>
#       <td id="T_78324_row6_col1" class="data row6 col1" >45.43</td>
#       <td id="T_78324_row6_col2" class="data row6 col2" >35.82</td>
#       <td id="T_78324_row6_col3" class="data row6 col3" >78.19° F</td>
#       <td id="T_78324_row6_col4" class="data row6 col4" >51%</td>
#       <td id="T_78324_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_78324_row6_col6" class="data row6 col6" >7.54</td>
#       <td id="T_78324_row6_col7" class="data row6 col7" >UA</td>
#       <td id="T_78324_row6_col8" class="data row6 col8" >2023-08-27 08:55:42</td>
#     </tr>
#   </tbody>
# </table>

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealWeatherLocationDataFrame,
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealWeatherLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Hotel Chérica in constantia, RO
#
#
# Located the following hotel...Hampton Inn Danbury in bethel, US
#
#
# Located the following hotel...Candlewood Suites in fort meade, US
#
#
# Located the following hotel...Norwalk Inn and Conference Center in westport, US
#
#
# Located the following hotel...ترجاب in benghazi, LY
#
#
# Located the following hotel...Stella di mare in shchyolkino, UA
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3: Hotel Locations')
# Out:
# <style type="text/css">
# #T_c2169 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c2169_row0_col0, #T_c2169_row0_col1, #T_c2169_row0_col2, #T_c2169_row0_col3, #T_c2169_row0_col4, #T_c2169_row0_col6, #T_c2169_row0_col7, #T_c2169_row0_col8, #T_c2169_row0_col9, #T_c2169_row1_col0, #T_c2169_row1_col1, #T_c2169_row1_col2, #T_c2169_row1_col6, #T_c2169_row1_col7, #T_c2169_row1_col8, #T_c2169_row1_col9, #T_c2169_row2_col0, #T_c2169_row2_col1, #T_c2169_row2_col2, #T_c2169_row2_col3, #T_c2169_row2_col4, #T_c2169_row2_col7, #T_c2169_row2_col8, #T_c2169_row2_col9, #T_c2169_row3_col0, #T_c2169_row3_col1, #T_c2169_row3_col2, #T_c2169_row3_col3, #T_c2169_row3_col4, #T_c2169_row3_col6, #T_c2169_row3_col7, #T_c2169_row3_col8, #T_c2169_row3_col9, #T_c2169_row4_col0, #T_c2169_row4_col1, #T_c2169_row4_col2, #T_c2169_row4_col4, #T_c2169_row4_col7, #T_c2169_row4_col8, #T_c2169_row4_col9, #T_c2169_row5_col0, #T_c2169_row5_col1, #T_c2169_row5_col2, #T_c2169_row5_col3, #T_c2169_row5_col6, #T_c2169_row5_col7, #T_c2169_row5_col8, #T_c2169_row5_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_c2169_row0_col5, #T_c2169_row1_col5, #T_c2169_row2_col5, #T_c2169_row3_col5, #T_c2169_row4_col5, #T_c2169_row5_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
#   background-color: yellow;
# }
# #T_c2169_row1_col3, #T_c2169_row2_col6, #T_c2169_row5_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_c2169_row1_col4, #T_c2169_row4_col3, #T_c2169_row4_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_c2169">
#   <caption>Table: 3: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_c2169_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_c2169_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_c2169_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_c2169_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_c2169_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_c2169_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_c2169_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_c2169_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_c2169_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_c2169_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c2169_row0_col0" class="data row0 col0" >constantia</td>
#       <td id="T_c2169_row0_col1" class="data row0 col1" >44.18</td>
#       <td id="T_c2169_row0_col2" class="data row0 col2" >28.65</td>
#       <td id="T_c2169_row0_col3" class="data row0 col3" >83.08° F</td>
#       <td id="T_c2169_row0_col4" class="data row0 col4" >62%</td>
#       <td id="T_c2169_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_c2169_row0_col6" class="data row0 col6" >7.40</td>
#       <td id="T_c2169_row0_col7" class="data row0 col7" >RO</td>
#       <td id="T_c2169_row0_col8" class="data row0 col8" >2023-08-27 08:54:16</td>
#       <td id="T_c2169_row0_col9" class="data row0 col9" >Hotel Chérica</td>
#     </tr>
#     <tr>
#       <td id="T_c2169_row1_col0" class="data row1 col0" >bethel</td>
#       <td id="T_c2169_row1_col1" class="data row1 col1" >41.37</td>
#       <td id="T_c2169_row1_col2" class="data row1 col2" >-73.41</td>
#       <td id="T_c2169_row1_col3" class="data row1 col3" >76.03° F</td>
#       <td id="T_c2169_row1_col4" class="data row1 col4" >69%</td>
#       <td id="T_c2169_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_c2169_row1_col6" class="data row1 col6" >8.05</td>
#       <td id="T_c2169_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_c2169_row1_col8" class="data row1 col8" >2023-08-27 08:54:18</td>
#       <td id="T_c2169_row1_col9" class="data row1 col9" >Hampton Inn Danbury</td>
#     </tr>
#     <tr>
#       <td id="T_c2169_row2_col0" class="data row2 col0" >fort meade</td>
#       <td id="T_c2169_row2_col1" class="data row2 col1" >39.11</td>
#       <td id="T_c2169_row2_col2" class="data row2 col2" >-76.74</td>
#       <td id="T_c2169_row2_col3" class="data row2 col3" >82.80° F</td>
#       <td id="T_c2169_row2_col4" class="data row2 col4" >61%</td>
#       <td id="T_c2169_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_c2169_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_c2169_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_c2169_row2_col8" class="data row2 col8" >2023-08-27 08:54:32</td>
#       <td id="T_c2169_row2_col9" class="data row2 col9" >Candlewood Suites</td>
#     </tr>
#     <tr>
#       <td id="T_c2169_row3_col0" class="data row3 col0" >westport</td>
#       <td id="T_c2169_row3_col1" class="data row3 col1" >41.14</td>
#       <td id="T_c2169_row3_col2" class="data row3 col2" >-73.36</td>
#       <td id="T_c2169_row3_col3" class="data row3 col3" >77.47° F</td>
#       <td id="T_c2169_row3_col4" class="data row3 col4" >67%</td>
#       <td id="T_c2169_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_c2169_row3_col6" class="data row3 col6" >9.22</td>
#       <td id="T_c2169_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_c2169_row3_col8" class="data row3 col8" >2023-08-27 08:45:41</td>
#       <td id="T_c2169_row3_col9" class="data row3 col9" >Norwalk Inn and Conference Center</td>
#     </tr>
#     <tr>
#       <td id="T_c2169_row4_col0" class="data row4 col0" >benghazi</td>
#       <td id="T_c2169_row4_col1" class="data row4 col1" >32.12</td>
#       <td id="T_c2169_row4_col2" class="data row4 col2" >20.07</td>
#       <td id="T_c2169_row4_col3" class="data row4 col3" >83.39° F</td>
#       <td id="T_c2169_row4_col4" class="data row4 col4" >67%</td>
#       <td id="T_c2169_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_c2169_row4_col6" class="data row4 col6" >9.82</td>
#       <td id="T_c2169_row4_col7" class="data row4 col7" >LY</td>
#       <td id="T_c2169_row4_col8" class="data row4 col8" >2023-08-27 08:55:10</td>
#       <td id="T_c2169_row4_col9" class="data row4 col9" >ترجاب</td>
#     </tr>
#     <tr>
#       <td id="T_c2169_row5_col0" class="data row5 col0" >shchyolkino</td>
#       <td id="T_c2169_row5_col1" class="data row5 col1" >45.43</td>
#       <td id="T_c2169_row5_col2" class="data row5 col2" >35.82</td>
#       <td id="T_c2169_row5_col3" class="data row5 col3" >78.19° F</td>
#       <td id="T_c2169_row5_col4" class="data row5 col4" >51%</td>
#       <td id="T_c2169_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_c2169_row5_col6" class="data row5 col6" >7.54</td>
#       <td id="T_c2169_row5_col7" class="data row5 col7" >UA</td>
#       <td id="T_c2169_row5_col8" class="data row5 col8" >2023-08-27 08:55:42</td>
#       <td id="T_c2169_row5_col9" class="data row5 col9" >Stella di mare</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
log_subroutine \
    .EndProgramExecution()
# Out:
# Program execution ends at 08/27/2023 09:01:26.
