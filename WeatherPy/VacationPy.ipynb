# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame,
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_cc628 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_cc628_row0_col0, #T_cc628_row0_col1, #T_cc628_row0_col2, #T_cc628_row0_col3, #T_cc628_row0_col4, #T_cc628_row0_col6, #T_cc628_row0_col7, #T_cc628_row0_col8, #T_cc628_row1_col0, #T_cc628_row1_col1, #T_cc628_row1_col2, #T_cc628_row1_col3, #T_cc628_row1_col4, #T_cc628_row1_col6, #T_cc628_row1_col7, #T_cc628_row1_col8, #T_cc628_row2_col0, #T_cc628_row2_col1, #T_cc628_row2_col2, #T_cc628_row2_col3, #T_cc628_row2_col4, #T_cc628_row2_col5, #T_cc628_row2_col6, #T_cc628_row2_col7, #T_cc628_row2_col8, #T_cc628_row3_col0, #T_cc628_row3_col1, #T_cc628_row3_col2, #T_cc628_row3_col3, #T_cc628_row3_col4, #T_cc628_row3_col5, #T_cc628_row3_col6, #T_cc628_row3_col7, #T_cc628_row3_col8, #T_cc628_row4_col0, #T_cc628_row4_col1, #T_cc628_row4_col2, #T_cc628_row4_col3, #T_cc628_row4_col4, #T_cc628_row4_col6, #T_cc628_row4_col7, #T_cc628_row4_col8, #T_cc628_row5_col0, #T_cc628_row5_col1, #T_cc628_row5_col2, #T_cc628_row5_col3, #T_cc628_row5_col4, #T_cc628_row5_col6, #T_cc628_row5_col7, #T_cc628_row5_col8, #T_cc628_row6_col0, #T_cc628_row6_col1, #T_cc628_row6_col2, #T_cc628_row6_col3, #T_cc628_row6_col4, #T_cc628_row6_col5, #T_cc628_row6_col6, #T_cc628_row6_col7, #T_cc628_row6_col8, #T_cc628_row7_col0, #T_cc628_row7_col1, #T_cc628_row7_col2, #T_cc628_row7_col3, #T_cc628_row7_col4, #T_cc628_row7_col6, #T_cc628_row7_col7, #T_cc628_row7_col8, #T_cc628_row8_col0, #T_cc628_row8_col1, #T_cc628_row8_col2, #T_cc628_row8_col4, #T_cc628_row8_col5, #T_cc628_row8_col6, #T_cc628_row8_col7, #T_cc628_row8_col8, #T_cc628_row9_col0, #T_cc628_row9_col1, #T_cc628_row9_col2, #T_cc628_row9_col3, #T_cc628_row9_col4, #T_cc628_row9_col6, #T_cc628_row9_col7, #T_cc628_row9_col8, #T_cc628_row10_col0, #T_cc628_row10_col1, #T_cc628_row10_col2, #T_cc628_row10_col3, #T_cc628_row10_col4, #T_cc628_row10_col6, #T_cc628_row10_col7, #T_cc628_row10_col8, #T_cc628_row11_col0, #T_cc628_row11_col1, #T_cc628_row11_col2, #T_cc628_row11_col3, #T_cc628_row11_col4, #T_cc628_row11_col5, #T_cc628_row11_col6, #T_cc628_row11_col7, #T_cc628_row11_col8, #T_cc628_row12_col0, #T_cc628_row12_col1, #T_cc628_row12_col2, #T_cc628_row12_col3, #T_cc628_row12_col4, #T_cc628_row12_col5, #T_cc628_row12_col6, #T_cc628_row12_col7, #T_cc628_row12_col8, #T_cc628_row13_col0, #T_cc628_row13_col1, #T_cc628_row13_col2, #T_cc628_row13_col3, #T_cc628_row13_col4, #T_cc628_row13_col6, #T_cc628_row13_col7, #T_cc628_row13_col8, #T_cc628_row14_col0, #T_cc628_row14_col1, #T_cc628_row14_col2, #T_cc628_row14_col3, #T_cc628_row14_col4, #T_cc628_row14_col5, #T_cc628_row14_col6, #T_cc628_row14_col7, #T_cc628_row14_col8, #T_cc628_row15_col0, #T_cc628_row15_col1, #T_cc628_row15_col2, #T_cc628_row15_col3, #T_cc628_row15_col4, #T_cc628_row15_col5, #T_cc628_row15_col6, #T_cc628_row15_col7, #T_cc628_row15_col8, #T_cc628_row16_col0, #T_cc628_row16_col1, #T_cc628_row16_col2, #T_cc628_row16_col3, #T_cc628_row16_col4, #T_cc628_row16_col6, #T_cc628_row16_col7, #T_cc628_row16_col8, #T_cc628_row17_col0, #T_cc628_row17_col1, #T_cc628_row17_col2, #T_cc628_row17_col3, #T_cc628_row17_col4, #T_cc628_row17_col5, #T_cc628_row17_col6, #T_cc628_row17_col7, #T_cc628_row17_col8, #T_cc628_row18_col0, #T_cc628_row18_col1, #T_cc628_row18_col2, #T_cc628_row18_col3, #T_cc628_row18_col4, #T_cc628_row18_col6, #T_cc628_row18_col7, #T_cc628_row18_col8, #T_cc628_row19_col0, #T_cc628_row19_col1, #T_cc628_row19_col2, #T_cc628_row19_col3, #T_cc628_row19_col4, #T_cc628_row19_col6, #T_cc628_row19_col7, #T_cc628_row19_col8, #T_cc628_row20_col0, #T_cc628_row20_col1, #T_cc628_row20_col2, #T_cc628_row20_col3, #T_cc628_row20_col4, #T_cc628_row20_col5, #T_cc628_row20_col6, #T_cc628_row20_col7, #T_cc628_row20_col8, #T_cc628_row21_col0, #T_cc628_row21_col1, #T_cc628_row21_col2, #T_cc628_row21_col3, #T_cc628_row21_col4, #T_cc628_row21_col5, #T_cc628_row21_col6, #T_cc628_row21_col7, #T_cc628_row21_col8, #T_cc628_row22_col0, #T_cc628_row22_col1, #T_cc628_row22_col2, #T_cc628_row22_col3, #T_cc628_row22_col4, #T_cc628_row22_col5, #T_cc628_row22_col6, #T_cc628_row22_col7, #T_cc628_ ...

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 35) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 75), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 5), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_dea8a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_dea8a_row0_col0, #T_dea8a_row0_col1, #T_dea8a_row0_col2, #T_dea8a_row0_col4, #T_dea8a_row0_col5, #T_dea8a_row0_col6, #T_dea8a_row0_col7, #T_dea8a_row0_col8, #T_dea8a_row1_col0, #T_dea8a_row1_col1, #T_dea8a_row1_col2, #T_dea8a_row1_col3, #T_dea8a_row1_col4, #T_dea8a_row1_col7, #T_dea8a_row1_col8, #T_dea8a_row2_col0, #T_dea8a_row2_col1, #T_dea8a_row2_col2, #T_dea8a_row2_col4, #T_dea8a_row2_col6, #T_dea8a_row2_col7, #T_dea8a_row2_col8, #T_dea8a_row3_col0, #T_dea8a_row3_col1, #T_dea8a_row3_col2, #T_dea8a_row3_col3, #T_dea8a_row3_col6, #T_dea8a_row3_col7, #T_dea8a_row3_col8, #T_dea8a_row4_col0, #T_dea8a_row4_col1, #T_dea8a_row4_col2, #T_dea8a_row4_col3, #T_dea8a_row4_col4, #T_dea8a_row4_col6, #T_dea8a_row4_col7, #T_dea8a_row4_col8, #T_dea8a_row5_col0, #T_dea8a_row5_col1, #T_dea8a_row5_col2, #T_dea8a_row5_col3, #T_dea8a_row5_col4, #T_dea8a_row5_col6, #T_dea8a_row5_col7, #T_dea8a_row5_col8, #T_dea8a_row6_col0, #T_dea8a_row6_col1, #T_dea8a_row6_col2, #T_dea8a_row6_col3, #T_dea8a_row6_col7, #T_dea8a_row6_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_dea8a_row0_col3, #T_dea8a_row1_col6, #T_dea8a_row6_col4, #T_dea8a_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_dea8a_row1_col5, #T_dea8a_row2_col3, #T_dea8a_row2_col5, #T_dea8a_row3_col4, #T_dea8a_row3_col5, #T_dea8a_row4_col5, #T_dea8a_row5_col5, #T_dea8a_row6_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_dea8a">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_dea8a_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_dea8a_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_dea8a_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_dea8a_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_dea8a_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_dea8a_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_dea8a_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_dea8a_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_dea8a_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dea8a_row0_col0" class="data row0 col0" >la'ie</td>
#       <td id="T_dea8a_row0_col1" class="data row0 col1" >21.65</td>
#       <td id="T_dea8a_row0_col2" class="data row0 col2" >-157.93</td>
#       <td id="T_dea8a_row0_col3" class="data row0 col3" >84.87° F</td>
#       <td id="T_dea8a_row0_col4" class="data row0 col4" >63%</td>
#       <td id="T_dea8a_row0_col5" class="data row0 col5" >2%</td>
#       <td id="T_dea8a_row0_col6" class="data row0 col6" >7.00</td>
#       <td id="T_dea8a_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_dea8a_row0_col8" class="data row0 col8" >2023-08-29 16:17:04</td>
#     </tr>
#     <tr>
#       <td id="T_dea8a_row1_col0" class="data row1 col0" >khetri</td>
#       <td id="T_dea8a_row1_col1" class="data row1 col1" >27.98</td>
#       <td id="T_dea8a_row1_col2" class="data row1 col2" >75.80</td>
#       <td id="T_dea8a_row1_col3" class="data row1 col3" >78.89° F</td>
#       <td id="T_dea8a_row1_col4" class="data row1 col4" >63%</td>
#       <td id="T_dea8a_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_dea8a_row1_col6" class="data row1 col6" >9.78</td>
#       <td id="T_dea8a_row1_col7" class="data row1 col7" >IN</td>
#       <td id="T_dea8a_row1_col8" class="data row1 col8" >2023-08-29 16:21:39</td>
#     </tr>
#     <tr>
#       <td id="T_dea8a_row2_col0" class="data row2 col0" >centerville</td>
#       <td id="T_dea8a_row2_col1" class="data row2 col1" >39.63</td>
#       <td id="T_dea8a_row2_col2" class="data row2 col2" >-84.16</td>
#       <td id="T_dea8a_row2_col3" class="data row2 col3" >76.59° F</td>
#       <td id="T_dea8a_row2_col4" class="data row2 col4" >55%</td>
#       <td id="T_dea8a_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_dea8a_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_dea8a_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_dea8a_row2_col8" class="data row2 col8" >2023-08-29 16:21:43</td>
#     </tr>
#     <tr>
#       <td id="T_dea8a_row3_col0" class="data row3 col0" >hamilton</td>
#       <td id="T_dea8a_row3_col1" class="data row3 col1" >39.18</td>
#       <td id="T_dea8a_row3_col2" class="data row3 col2" >-84.53</td>
#       <td id="T_dea8a_row3_col3" class="data row3 col3" >78.62° F</td>
#       <td id="T_dea8a_row3_col4" class="data row3 col4" >49%</td>
#       <td id="T_dea8a_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_dea8a_row3_col6" class="data row3 col6" >6.91</td>
#       <td id="T_dea8a_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_dea8a_row3_col8" class="data row3 col8" >2023-08-29 16:21:58</td>
#     </tr>
#     <tr>
#       <td id="T_dea8a_row4_col0" class="data row4 col0" >boa vista</td>
#       <td id="T_dea8a_row4_col1" class="data row4 col1" >2.82</td>
#       <td id="T_dea8a_row4_col2" class="data row4 col2" >-60.67</td>
#       <td id="T_dea8a_row4_col3" class="data row4 col3" >84.18° F</td>
#       <td id="T_dea8a_row4_col4" class="data row4 col4" >61%</td>
#       <td id="T_dea8a_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_dea8a_row4_col6" class="data row4 col6" >5.75</td>
#       <td id="T_dea8a_row4_col7" class="data row4 col7" >BR</td>
#       <td id="T_dea8a_row4_col8" class="data row4 col8" >2023-08-29 16:22:09</td>
#     </tr>
#     <tr>
#       <td id="T_dea8a_row5_col0" class="data row5 col0" >whitecourt</td>
#       <td id="T_dea8a_row5_col1" class="data row5 col1" >54.15</td>
#       <td id="T_dea8a_row5_col2" class="data row5 col2" >-115.69</td>
#       <td id="T_dea8a_row5_col3" class="data row5 col3" >81.64° F</td>
#       <td id="T_dea8a_row5_col4" class="data row5 col4" >50%</td>
#       <td id="T_dea8a_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_dea8a_row5_col6" class="data row5 col6" >6.91</td>
#       <td id="T_dea8a_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_dea8a_row5_col8" class="data row5 col8" >2023-08-29 16:22:50</td>
#     </tr>
#     <tr>
#       <td id="T_dea8a_row6_col0" class="data row6 col0" >san cristobal</td>
#       <td id="T_dea8a_row6_col1" class="data row6 col1" >7.77</td>
#       <td id="T_dea8a_row6_col2" class="data row6 col2" >-72.22</td>
#       <td id="T_dea8a_row6_col3" class="data row6 col3" >80.78° F</td>
#       <td id="T_dea8a_row6_col4" class="data row6 col4" >72%</td>
#       <td id="T_dea8a_row6_col5" class="data row6 col5" >5%</td>
#       <td id="T_dea8a_row6_col6" class="data row6 col6" >4.81</td>
#       <td id="T_dea8a_row6_col7" class="data row6 col7" >VE</td>
#       <td id="T_dea8a_row6_col8" class="data row6 col8" >2023-08-29 16:23:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Hale Koolau in la'ie, US
#
#
# Located the following hotel...Saini Hotel in khetri, IN
#
#
# Located the following hotel...Holiday Inn Express & Suites in centerville, US
#
#
# Located the following hotel...North Vista Manor in hamilton, US
#
#
# Located the following hotel...Aipana Plaza Hotel in boa vista, BR
#
#
# Located the following hotel...Microtel Inn & Suites by Wyndham Whitecourt in whitecourt, CA
#
#
# Located the following hotel...Terra Sur in san cristobal, VE
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_f47fe caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_f47fe_row0_col0, #T_f47fe_row0_col1, #T_f47fe_row0_col2, #T_f47fe_row0_col4, #T_f47fe_row0_col5, #T_f47fe_row0_col6, #T_f47fe_row0_col7, #T_f47fe_row0_col8, #T_f47fe_row0_col9, #T_f47fe_row1_col0, #T_f47fe_row1_col1, #T_f47fe_row1_col2, #T_f47fe_row1_col3, #T_f47fe_row1_col4, #T_f47fe_row1_col7, #T_f47fe_row1_col8, #T_f47fe_row1_col9, #T_f47fe_row2_col0, #T_f47fe_row2_col1, #T_f47fe_row2_col2, #T_f47fe_row2_col4, #T_f47fe_row2_col6, #T_f47fe_row2_col7, #T_f47fe_row2_col8, #T_f47fe_row2_col9, #T_f47fe_row3_col0, #T_f47fe_row3_col1, #T_f47fe_row3_col2, #T_f47fe_row3_col3, #T_f47fe_row3_col6, #T_f47fe_row3_col7, #T_f47fe_row3_col8, #T_f47fe_row3_col9, #T_f47fe_row4_col0, #T_f47fe_row4_col1, #T_f47fe_row4_col2, #T_f47fe_row4_col3, #T_f47fe_row4_col4, #T_f47fe_row4_col6, #T_f47fe_row4_col7, #T_f47fe_row4_col8, #T_f47fe_row4_col9, #T_f47fe_row5_col0, #T_f47fe_row5_col1, #T_f47fe_row5_col2, #T_f47fe_row5_col3, #T_f47fe_row5_col4, #T_f47fe_row5_col6, #T_f47fe_row5_col7, #T_f47fe_row5_col8, #T_f47fe_row5_col9, #T_f47fe_row6_col0, #T_f47fe_row6_col1, #T_f47fe_row6_col2, #T_f47fe_row6_col3, #T_f47fe_row6_col7, #T_f47fe_row6_col8, #T_f47fe_row6_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_f47fe_row0_col3, #T_f47fe_row1_col6, #T_f47fe_row6_col4, #T_f47fe_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_f47fe_row1_col5, #T_f47fe_row2_col3, #T_f47fe_row2_col5, #T_f47fe_row3_col4, #T_f47fe_row3_col5, #T_f47fe_row4_col5, #T_f47fe_row5_col5, #T_f47fe_row6_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_f47fe">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_f47fe_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_f47fe_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_f47fe_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_f47fe_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_f47fe_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_f47fe_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_f47fe_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_f47fe_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_f47fe_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_f47fe_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f47fe_row0_col0" class="data row0 col0" >la'ie</td>
#       <td id="T_f47fe_row0_col1" class="data row0 col1" >21.65</td>
#       <td id="T_f47fe_row0_col2" class="data row0 col2" >-157.93</td>
#       <td id="T_f47fe_row0_col3" class="data row0 col3" >84.87° F</td>
#       <td id="T_f47fe_row0_col4" class="data row0 col4" >63%</td>
#       <td id="T_f47fe_row0_col5" class="data row0 col5" >2%</td>
#       <td id="T_f47fe_row0_col6" class="data row0 col6" >7.00</td>
#       <td id="T_f47fe_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_f47fe_row0_col8" class="data row0 col8" >2023-08-29 16:17:04</td>
#       <td id="T_f47fe_row0_col9" class="data row0 col9" >Hale Koolau</td>
#     </tr>
#     <tr>
#       <td id="T_f47fe_row1_col0" class="data row1 col0" >khetri</td>
#       <td id="T_f47fe_row1_col1" class="data row1 col1" >27.98</td>
#       <td id="T_f47fe_row1_col2" class="data row1 col2" >75.80</td>
#       <td id="T_f47fe_row1_col3" class="data row1 col3" >78.89° F</td>
#       <td id="T_f47fe_row1_col4" class="data row1 col4" >63%</td>
#       <td id="T_f47fe_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_f47fe_row1_col6" class="data row1 col6" >9.78</td>
#       <td id="T_f47fe_row1_col7" class="data row1 col7" >IN</td>
#       <td id="T_f47fe_row1_col8" class="data row1 col8" >2023-08-29 16:21:39</td>
#       <td id="T_f47fe_row1_col9" class="data row1 col9" >Saini Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_f47fe_row2_col0" class="data row2 col0" >centerville</td>
#       <td id="T_f47fe_row2_col1" class="data row2 col1" >39.63</td>
#       <td id="T_f47fe_row2_col2" class="data row2 col2" >-84.16</td>
#       <td id="T_f47fe_row2_col3" class="data row2 col3" >76.59° F</td>
#       <td id="T_f47fe_row2_col4" class="data row2 col4" >55%</td>
#       <td id="T_f47fe_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_f47fe_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_f47fe_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_f47fe_row2_col8" class="data row2 col8" >2023-08-29 16:21:43</td>
#       <td id="T_f47fe_row2_col9" class="data row2 col9" >Holiday Inn Express & Suites</td>
#     </tr>
#     <tr>
#       <td id="T_f47fe_row3_col0" class="data row3 col0" >hamilton</td>
#       <td id="T_f47fe_row3_col1" class="data row3 col1" >39.18</td>
#       <td id="T_f47fe_row3_col2" class="data row3 col2" >-84.53</td>
#       <td id="T_f47fe_row3_col3" class="data row3 col3" >78.62° F</td>
#       <td id="T_f47fe_row3_col4" class="data row3 col4" >49%</td>
#       <td id="T_f47fe_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_f47fe_row3_col6" class="data row3 col6" >6.91</td>
#       <td id="T_f47fe_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_f47fe_row3_col8" class="data row3 col8" >2023-08-29 16:21:58</td>
#       <td id="T_f47fe_row3_col9" class="data row3 col9" >North Vista Manor</td>
#     </tr>
#     <tr>
#       <td id="T_f47fe_row4_col0" class="data row4 col0" >boa vista</td>
#       <td id="T_f47fe_row4_col1" class="data row4 col1" >2.82</td>
#       <td id="T_f47fe_row4_col2" class="data row4 col2" >-60.67</td>
#       <td id="T_f47fe_row4_col3" class="data row4 col3" >84.18° F</td>
#       <td id="T_f47fe_row4_col4" class="data row4 col4" >61%</td>
#       <td id="T_f47fe_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_f47fe_row4_col6" class="data row4 col6" >5.75</td>
#       <td id="T_f47fe_row4_col7" class="data row4 col7" >BR</td>
#       <td id="T_f47fe_row4_col8" class="data row4 col8" >2023-08-29 16:22:09</td>
#       <td id="T_f47fe_row4_col9" class="data row4 col9" >Aipana Plaza Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_f47fe_row5_col0" class="data row5 col0" >whitecourt</td>
#       <td id="T_f47fe_row5_col1" class="data row5 col1" >54.15</td>
#       <td id="T_f47fe_row5_col2" class="data row5 col2" >-115.69</td>
#       <td id="T_f47fe_row5_col3" class="data row5 col3" >81.64° F</td>
#       <td id="T_f47fe_row5_col4" class="data row5 col4" >50%</td>
#       <td id="T_f47fe_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_f47fe_row5_col6" class="data row5 col6" >6.91</td>
#       <td id="T_f47fe_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_f47fe_row5_col8" class="data row5 col8" >2023-08-29 16:22:50</td>
#       <td id="T_f47fe_row5_col9" class="data row5 col9" >Microtel Inn & Suites by Wyndham Whitecourt</td>
#     </tr>
#     <tr>
#       <td id="T_f47fe_row6_col0" class="data row6 col0" >san cristobal</td>
#       <td id="T_f47fe_row6_col1" class="data row6 col1" >7.77</td>
#       <td id="T_f47fe_row6_col2" class="data row6 col2" >-72.22</td>
#       <td id="T_f47fe_row6_col3" class="data row6 col3" >80.78° F</td>
#       <td id="T_f47fe_row6_col4" class="data row6 col4" >72%</td>
#       <td id="T_f47fe_row6_col5" class="data row6 col5" >5%</td>
#       <td id="T_f47fe_row6_col6" class="data row6 col6" >4.81</td>
#       <td id="T_f47fe_row6_col7" class="data row6 col7" >VE</td>
#       <td id="T_f47fe_row6_col8" class="data row6 col8" >2023-08-29 16:23:05</td>
#       <td id="T_f47fe_row6_col9" class="data row6 col9" >Terra Sur</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
