# %% [markdown]
# # WeatherPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  WeatherPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, WeatherPy.ipynb, uses a Python script to 
 #      visualize the weather of over 500 cities of varying distances from the equator. 
 #      The script uses the citipy Python library and the openWeatherMap API to create 
 #      a representative model of weather across cities.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/12/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PySubroutines as subroutine
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'WeatherPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('WeatherPy')
# Out:
# Program execution begins...

# %% [markdown]
# # <br> **Section 1: Weather Variables and Latitude**

# %% [markdown]
# ## **Section 1.1: Data Acquisition**

# %% [markdown]
# ### **List of Cities**

# %%
citiesListOfStrings \
    = api_function \
        .ReturnCitiesList()

# %% [markdown]
# ### **Weather Data from List of Cities**

# %%
cityWeatherDataFrame \
    = api_function \
        .ReturnWeatherDataFrame \
            (citiesListOfStrings)
# Out:
# DATA RETRIEVAL FOR CITY WEATHER DATAFRAME BEGINS...
#
#
# PROCESSING RECORD #2 OF SET 1 FOR CITY, coahuayana de hidalgo.
#
# PROCESSING RECORD #3 OF SET 1 FOR CITY, port elizabeth.
#
# PROCESSING RECORD #4 OF SET 1 FOR CITY, carnarvon.
#
# PROCESSING RECORD #5 OF SET 1 FOR CITY, bethel.
#
# PROCESSING RECORD #6 OF SET 1 FOR CITY, taiohae.
#
# The script did not find the city, taiohae. Skipping...
#
# PROCESSING RECORD #7 OF SET 1 FOR CITY, nuoro.
#
# PROCESSING RECORD #8 OF SET 1 FOR CITY, utrik.
#
# PROCESSING RECORD #9 OF SET 1 FOR CITY, albany.
#
# PROCESSING RECORD #10 OF SET 1 FOR CITY, st. john's.
#
# PROCESSING RECORD #11 OF SET 1 FOR CITY, ust-nera.
#
# PROCESSING RECORD #12 OF SET 1 FOR CITY, tyre.
#
# PROCESSING RECORD #13 OF SET 1 FOR CITY, impfondo.
#
# PROCESSING RECORD #14 OF SET 1 FOR CITY, grytviken.
#
# PROCESSING RECORD #15 OF SET 1 FOR CITY, pecos.
#
# PROCESSING RECORD #16 OF SET 1 FOR CITY, ribeira grande.
#
# PROCESSING RECORD #17 OF SET 1 FOR CITY, thinadhoo.
#
# PROCESSING RECORD #18 OF SET 1 FOR CITY, tyuratam.
#
# PROCESSING RECORD #19 OF SET 1 FOR CITY, tanout.
#
# PROCESSING RECORD #20 OF SET 1 FOR CITY, port-aux-francais.
#
# PROCESSING RECORD #21 OF SET 1 FOR CITY, perigny.
#
# PROCESSING RECORD #22 OF SET 1 FOR CITY, whakatane.
#
# PROCESSING RECORD #23 OF SET 1 FOR CITY, hamilton.
#
# PROCESSING RECORD #24 OF SET 1 FOR CITY, puerto natales.
#
# PROCESSING RECORD #25 OF SET 1 FOR CITY, port mathurin.
#
# PROCESSING RECORD #26 OF SET 1 FOR CITY, iqaluit.
#
# PROCESSING RECORD #27 OF SET 1 FOR CITY, papatowai.
#
# PROCESSING RECORD #28 OF SET 1 FOR CITY, chonchi.
#
# PROCESSING RECORD #29 OF SET 1 FOR CITY, kourou.
#
# PROCESSING RECORD #30 OF SET 1 FOR CITY, college.
#
# PROCESSING RECORD #31 OF SET 1 FOR CITY, salalah.
#
# PROCESSING RECORD #32 OF SET 1 FOR CITY, candelaria.
#
# PROCESSING RECORD #33 OF SET 1 FOR CITY, saratamata.
#
# The script did not find the city, saratamata. Skipping...
#
# PROCESSING RECORD #34 OF SET 1 FOR CITY, taseyevo.
#
# PROCESSING RECORD #35 OF SET 1 FOR CITY, adamstown.
#
# PROCESSING RECORD #36 OF SET 1 FOR CITY, gadzhiyevo.
#
# PROCESSING RECORD #37 OF SET 1 FOR CITY, bilibino.
#
# PROCESSING RECORD #38 OF SET 1 FOR CITY, olyokminsk.
#
# PROCESSING RECORD #39 OF SET 1 FOR CITY, blackmans bay.
#
# PROCESSING RECORD #40 OF SET 1 FOR CITY, cova figueira.
#
# PROCESSING RECORD #41 OF SET 1 FOR CITY, okhotsk.
#
# PROCESSING RECORD #42 OF SET 1 FOR CITY, jamestown.
#
# PROCESSING RECORD #43 OF SET 1 FOR CITY, tiksi.
#
# PROCESSING RECORD #44 OF SET 1 FOR CITY, puerto baquerizo moreno.
#
# PROCESSING RECORD #45 OF SET 1 FOR CITY, nouadhibou.
#
# PROCESSING RECORD #46 OF SET 1 FOR CITY, pisco.
#
# PROCESSING RECORD #47 OF SET 1 FOR CITY, pine bluff.
#
# PROCESSING RECORD #48 OF SET 1 FOR CITY, tolanaro.
#
# PROCESSING RECORD #49 OF SET 1 FOR CITY, isafjordur.
#
# PROCESSING RECORD #50 OF SET 1 FOR CITY, ayaguz.
#
# The script did not find the city, ayaguz. Skipping...
#
# PROCESSING RECORD #51 OF SET 1 FOR CITY, asau village.
#
# The script did not find the city, asau village. Skipping...
#
# PROCESSING RECORD #1 OF SET 2 FOR CITY, bredasdorp.
#
# PROCESSING RECORD #2 OF SET 2 FOR CITY, bubaque.
#
# PROCESSING RECORD #3 OF SET 2 FOR CITY, sitka.
#
# PROCESSING RECORD #4 OF SET 2 FOR CITY, necochea.
#
# PROCESSING RECORD #5 OF SET 2 FOR CITY, kisiwani.
#
# PROCESSING RECORD #6 OF SET 2 FOR CITY, nova sintra.
#
# PROCESSING RECORD #7 OF SET 2 FOR CITY, luanda.
#
# PROCESSING RECORD #8 OF SET 2 FOR CITY, saipan.
#
# PROCESSING RECORD #9 OF SET 2 FOR CITY, putina.
#
# PROCESSING RECORD #10 OF SET 2 FOR CITY, banff.
#
# PROCESSING RECORD #11 OF SET 2 FOR CITY, stanley.
#
# PROCESSING RECORD #12 OF SET 2 FOR CITY, itoman.
#
# PROCESSING RECORD #13 OF SET 2 FOR CITY, qamdo.
#
# PROCESSING RECORD #14 OF SET 2 FOR CITY, sathupalli.
#
# PROCESSING RECORD #15 OF SET 2 FOR CITY, deir ez-zor.
#
# PROCESSING RECORD #16 OF SET 2 FOR CITY, badger.
#
# PROCESSING RECORD #17 OF SET 2 FOR CITY, new norfolk.
#
# PROCESSING RECORD #18 OF SET 2 FOR CITY, puerto ayora.
#
# PROCESSING RECORD #19 OF SET 2 FOR CITY, belyy yar.
#
# PROCESSING RECORD #20 OF SET 2 FOR CITY, waitangi.
#
# PROCESSING RECORD #21 OF SET 2 FOR CITY, novodvinsk.
#
# PROCESSING RECORD #22 OF SET 2 FOR CITY, saint-joseph.
#
# PROCESSING RECORD #23 OF SET 2 FOR CITY, malibu.
#
# PROCESSING RECORD #24 OF SET 2 FOR CITY, mormugao.
#
# PROCESSING RECORD #25 OF SET 2 FOR CITY, enewetak.
#
# PROCESSING RECORD #26 OF SET 2 FOR CITY, el rama.
#
# PROCESSING RECORD #27 OF SET 2 FOR CITY, san rafael.
#
# PROCESSING RECORD #28 OF SET 2 FOR CITY, invercargill.
#
# PROCESSING RECORD #29 OF SET 2 FOR CITY, west island.
#
# PROCESSING RECORD #30 OF SET 2 FOR CITY, kavieng.
#
# PROCESSING RECORD #31 OF SET 2 FOR CITY, lihue.
#
# PROCESSING RECORD #32 OF SET 2 FOR CITY, sakaraha.
#
# PROCESSING RECORD #33 OF SET 2 FOR CITY, nenjiang.
#
# PROCESSING RECORD #34 OF SET 2 FOR CITY, yola.
#
# PROCESSING RECORD #35 OF SET 2 FOR CITY, lompoc.
#
# PROCESSING RECORD #36 OF SET 2 FOR CITY, hook.
#
# PROCESSING RECORD #37 OF SET 2 FOR CITY, poyarkovo.
#
# PROCESSING RECORD #38 OF SET 2 FOR CITY, bayeux.
#
# PROCESSING RECORD #39 OF SET 2 FOR CITY, ilulissat.
#
# PROCESSING RECORD #40 OF SET 2 FOR CITY, acapulco de juarez.
#
# PROCESSING RECORD #41 OF SET 2 FOR CITY, toga village.
#
# The script did not find the city, toga village. Skipping...
#
# PROCESSING RECORD #42 OF SET 2 FOR CITY, mercedes.
#
# PROCESSING RECORD #43 OF SET 2 FOR CITY, viedma.
#
# PROCESSING RECORD #44 OF SET 2 FOR CITY, kolonia town.
#
# PROCESSING RECORD #45 OF SET 2 FOR CITY, yeppoon.
#
# PROCESSING RECORD #46 OF SET 2 FOR CITY, saint-pierre.
#
# PROCESSING RECORD #47 OF SET 2 FOR CITY, kodiak.
#
# PROCESSING RECORD #48 OF SET 2 FOR CITY, alotau.
#
# The script did not find the city, alotau. Skipping...
#
# PROCESSING RECORD #49 OF SET 2 FOR CITY, edinburgh of the seven seas.
#
# PROCESSING RECORD #50 OF SET 2 FOR CITY, udachny.
#
# PROCESSING RECORD #1 OF SET 3 FOR CITY, murzuq.
#
# PROCESSING RECORD #2 OF SET 3 FOR CITY, vilyuysk.
#
# PROCESSING RECORD #3 OF SET 3 FOR CITY, tsiombe.
#
# PROCESSING RECORD #4 OF SET 3 FOR CITY, vorgashor.
#
# PROCESSING RECORD #5 OF SET 3 FOR CITY, wailua homesteads.
#
# PROCESSING RECORD #6 OF SET 3 FOR CITY, tual.
#
# PROCESSING RECORD #7 OF SET 3 FOR CITY, olonkinbyen.
#
# PROCESSING RECORD #8 OF SET 3 FOR CITY, lerwick.
#
# PROCESSING RECORD #9 OF SET 3 FOR CITY, muromtsevo.
#
# PROCESSING RECORD #10 OF SET 3 FOR CITY, keflavik.
#
# PROCESSING RECORD #11 OF SET 3 FOR CITY, margaret river.
#
# PROCESSING RECORD #12 OF SET 3 FOR CITY, portland.
#
# PROCESSING RECORD #13 OF SET 3 FOR CITY, 'ohonua.
#
# The script did not find the city, 'ohonua. Skipping...
#
# PROCESSING RECORD #14 OF SET 3 FOR CITY, hithadhoo.
#
# PROCESSING RECORD #15 OF SET 3 FOR CITY, san patricio.
#
# PROCESSING RECORD #16 OF SET 3 FOR CITY, kayangel.
#
# PROCESSING RECORD #17 OF SET 3 FOR CITY, el calafate.
#
# PROCESSING RECORD #18 OF SET 3 FOR CITY, grand falls-windsor.
#
# PROCESSING RECORD #19 OF SET 3 FOR CITY, preobrazheniye.
#
# PROCESSING RECORD #20 OF SET 3 FOR CITY, petropavlovsk-kamchatsky.
#
# PROCESSING RECORD #21 OF SET 3 FOR CITY, gaspe.
#
# PROCESSING RECORD #22 OF SET 3 FOR CITY, merritt island.
#
# PROCESSING RECORD #23 OF SET 3 FOR CITY, burang.
#
# PROCESSING RECORD #24 OF SET 3 FOR CITY, vilyuchinsk.
#
# PROCESSING RECORD #25 OF SET 3 FOR CITY, turpan.
#
# PROCESSING RECORD #26 OF SET 3 FOR CITY, tomatlan.
#
# PROCESSING RECORD #27 OF SET 3 FOR CITY, qaqortoq.
#
# PROCESSING RECORD #28 OF SET 3 FOR CITY, hami.
#
# PROCESSING RECORD #29 OF SET 3 FOR CITY, punto fijo.
#
# PROCESSING RECORD #30 OF SET 3 FOR CITY, hirara.
#
# PROCESSING RECORD #31 OF SET 3 FOR CITY, lakatoro.
#
# PROCESSING RECORD #32 OF SET 3 FOR CITY, tura.
#
# PROCESSING RECORD #33 OF SET 3 FOR CITY, yuzhno-kurilsk.
#
# PROCESSING RECORD #34 OF SET 3 FOR CITY, altamont.
#
# PROCESSING RECORD #35 OF SET 3 FOR CITY, havre.
#
# PROCESSING RECORD #36 OF SET 3 FOR CITY, songyuan.
#
# PROCESSING RECORD #37 OF SET 3 FOR CITY, bolivar.
#
# PROCESSING RECORD #38 OF SET 3 FOR CITY, tralee.
#
# PROCESSING RECORD #39 OF SET 3 FOR CITY, east london.
#
# PROCESSING RECORD #40 OF SET 3 FOR CITY, hadibu.
#
# PROCESSING RECORD #41 OF SET 3 FOR CITY, hasaki.
#
# PROCESSING RECORD #42 OF SET 3 FOR CITY, tosontsengel.
#
# PROCESSING RECORD #43 OF SET 3 FOR CITY, aasiaat.
#
# PROCESSING RECORD #44 OF SET 3 FOR CITY, nova vicosa.
#
# PROCESSING RECORD #45 OF SET 3 FOR CITY, brandon.
#
# PROCESSING RECORD #46 OF SET 3 FOR CITY, yellowknife.
#
# PROCESSING RECORD #47 OF SET 3 FOR CITY, ushuaia.
# PROCESSING RECORD #48 OF SET 3 FOR CITY, lebu.
#
# PROCESSING RECORD #49 OF SET 3 FOR CITY, fale old settlement.
#
# PROCESSING RECORD #50 OF SET 3 FOR CITY, haiku-pauwela.
#
# PROCESSING RECORD #1 OF SET 4 FOR CITY, sebdou.
#
# PROCESSING RECORD #2 OF SET 4 FOR CITY, i-n-salah.
#
# PROCESSING RECORD #3 OF SET 4 FOR CITY, port macquarie.
#
# PROCESSING RECORD #4 OF SET 4 FOR CITY, suva.
#
# PROCESSING RECORD #5 OF SET 4 FOR CITY, felixstowe.
#
# PROCESSING RECORD #6 OF SET 4 FOR CITY, saint-philippe.
#
# PROCESSING RECORD #7 OF SET 4 FOR CITY, orkney.
#
# PROCESSING RECORD #8 OF SET 4 FOR CITY, great falls.
#
# PROCESSING RECORD #9 OF SET 4 FOR CITY, baoding.
#
# PROCESSING RECORD #10 OF SET 4 FOR CITY, tyukhtet.
#
# PROCESSING RECORD #11 OF SET 4 FOR CITY, claveria.
#
# PROCESSING RECORD #12 OF SET 4 FOR CITY, box elder.
#
# PROCESSING RECORD #13 OF SET 4 FOR CITY, were ilu.
#
# PROCESSING RECORD #14 OF SET 4 FOR CITY, inekar.
#
# The script did not find the city, inekar. Skipping...
#
# PROCESSING RECORD #15 OF SET 4 FOR CITY, bodo.
#
# PROCESSING RECORD #16 OF SET 4 FOR CITY, howrah.
#
# PROCESSING RECORD #17 OF SET 4 FOR CITY, jindabyne.
#
# PROCESSING RECORD #18 OF SET 4 FOR CITY, thulamahashi.
#
# PROCESSING RECORD #19 OF SET 4 FOR CITY, rongelap.
#
# PROCESSING RECORD #20 OF SET 4 FOR CITY, bac lieu.
#
# PROCESSING RECORD #21 OF SET 4 FOR CITY, kitimat.
#
# PROCESSING RECORD #22 OF SET 4 FOR CITY, makar'yev.
#
# PROCESSING RECORD #23 OF SET 4 FOR CITY, fortuna.
#
# PROCESSING RECORD #24 OF SET 4 FOR CITY, santa elena de uairen.
#
# PROCESSING RECORD #25 OF SET 4 FOR CITY, soio.
#
# PROCESSING RECORD #26 OF SET 4 FOR CITY, cidreira.
#
# PROCESSING RECORD #27 OF SET 4 FOR CITY, callao.
#
# PROCESSING RECORD #28 OF SET 4 FOR CITY, punta arenas.
#
# PROCESSING RECORD #29 OF SET 4 FOR CITY, cedeira.
#
# PROCESSING RECORD #30 OF SET 4 FOR CITY, massenya.
#
# PROCESSING RECORD #31 OF SET 4 FOR CITY, mechraa bel ksiri.
#
# PROCESSING RECORD #32 OF SET 4 FOR CITY, jutai.
#
# PROCESSING RECORD #33 OF SET 4 FOR CITY, sao raimundo das mangabeiras.
#
# PROCESSING RECORD #34 OF SET 4 FOR CITY, jingdezhen.
#
# PROCESSING RECORD #35 OF SET 4 FOR CITY, kingston.
#
# PROCESSING RECORD #36 OF SET 4 FOR CITY, hawaiian paradise park.
#
# PROCESSING RECORD #37 OF SET 4 FOR CITY, taoudenni.
#
# PROCESSING RECORD #38 OF SET 4 FOR CITY, luderitz.
#
# PROCESSING RECORD #39 OF SET 4 FOR CITY, kulia village.
#
# The script did not find the city, kulia village. Skipping...
#
# PROCESSING RECORD #40 OF SET 4 FOR CITY, belmonte.
#
# PROCESSING RECORD #41 OF SET 4 FOR CITY, nar'yan-mar.
#
# PROCESSING RECORD #42 OF SET 4 FOR CITY, vytegra.
#
# PROCESSING RECORD #43 OF SET 4 FOR CITY, usogorsk.
#
# PROCESSING RECORD #44 OF SET 4 FOR CITY, crucecita.
#
# PROCESSING RECORD #45 OF SET 4 FOR CITY, bahla'.
#
# The script did not find the city, bahla'. Skipping...
#
# PROCESSING RECORD #46 OF SET 4 FOR CITY, thompson.
#
# PROCESSING RECORD #47 OF SET 4 FOR CITY, longyearbyen.
#
# PROCESSING RECORD #48 OF SET 4 FOR CITY, puerto san carlos.
#
# The script did not find the city, puerto san carlos. Skipping...
#
# PROCESSING RECORD #49 OF SET 4 FOR CITY, palikir - national government center.
#
# PROCESSING RECORD #50 OF SET 4 FOR CITY, harnoli.
#
# PROCESSING RECORD #1 OF SET 5 FOR CITY, al jawf.
#
# PROCESSING RECORD #2 OF SET 5 FOR CITY, talnakh.
#
# PROCESSING RECORD #3 OF SET 5 FOR CITY, inhambane.
#
# PROCESSING RECORD #4 OF SET 5 FOR CITY, ballina.
#
# PROCESSING RECORD #5 OF SET 5 FOR CITY, klaksvik.
#
# PROCESSING RECORD #6 OF SET 5 FOR CITY, ormara.
#
# PROCESSING RECORD #7 OF SET 5 FOR CITY, plettenberg bay.
#
# PROCESSING RECORD #8 OF SET 5 FOR CITY, muzayri'.
#
# The script did not find the city, muzayri'. Skipping...
#
# PROCESSING RECORD #9 OF SET 5 FOR CITY, anadyr.
#
# PROCESSING RECORD #10 OF SET 5 FOR CITY, meulaboh.
#
# PROCESSING RECORD #11 OF SET 5 FOR CITY, boali.
#
# PROCESSING RECORD #12 OF SET 5 FOR CITY, armidale.
#
# PROCESSING RECORD #13 OF SET 5 FOR CITY, ghadamis.
#
# PROCESSING RECORD #14 OF SET 5 FOR CITY, avarua.
#
# PROCESSING RECORD #15 OF SET 5 FOR CITY, antalaha.
#
# PROCESSING RECORD #16 OF SET 5 FOR CITY, hermanus.
#
# PROCESSING RECORD #17 OF SET 5 FOR CITY, am timan.
#
# PROCESSING RECORD #18 OF SET 5 FOR CITY, ouricuri.
#
# PROCESSING RECORD #19 OF SET 5 FOR CITY, martapura.
#
# PROCESSING RECORD #20 OF SET 5 FOR CITY, shyryayeve.
#
# PROCESSING RECORD #21 OF SET 5 FOR CITY, harstad.
#
# PROCESSING RECORD #22 OF SET 5 FOR CITY, kruisfontein.
#
# PROCESSING RECORD #23 OF SET 5 FOR CITY, port blair.
#
# PROCESSING RECORD #24 OF SET 5 FOR CITY, padang.
#
# PROCESSING RECORD #25 OF SET 5 FOR CITY, mount isa.
#
# PROCESSING RECORD #26 OF SET 5 FOR CITY, kone.
#
# PROCESSING RECORD #27 OF SET 5 FOR CITY, uzhur.
#
# PROCESSING RECORD #28 OF SET 5 FOR CITY, atafu village.
#
# PROCESSING RECORD #29 OF SET 5 FOR CITY, rada tilly.
#
# PROCESSING RECORD #30 OF SET 5 FOR CITY, mejit.
#
# PROCESSING RECORD #31 OF SET 5 FOR CITY, ijuw.
#
# The script did not find the city, ijuw. Skipping...
#
# PROCESSING RECORD #32 OF SET 5 FOR CITY, tazacorte.
#
# PROCESSING RECORD #33 OF SET 5 FOR CITY, shalqar.
#
# PROCESSING RECORD #34 OF SET 5 FOR CITY, ulladulla.
#
# PROCESSING RECORD #35 OF SET 5 FOR CITY, queenstown.
#
# PROCESSING RECORD #36 OF SET 5 FOR CITY, ytyk-kyuyel'.
#
# The script did not find the city, ytyk-kyuyel'. Skipping...
#
# PROCESSING RECORD #37 OF SET 5 FOR CITY, pana.
#
# PROCESSING RECORD #38 OF SET 5 FOR CITY, kiunga.
#
# PROCESSING RECORD #39 OF SET 5 FOR CITY, mili.
#
# PROCESSING RECORD #40 OF SET 5 FOR CITY, atlantic beach.
#
# PROCESSING RECORD #41 OF SET 5 FOR CITY, la piedad.
#
# PROCESSING RECORD #42 OF SET 5 FOR CITY, la passe.
#
# PROCESSING RECORD #43 OF SET 5 FOR CITY, metropolis.
#
# PROCESSING RECORD #44 OF SET 5 FOR CITY, usinsk.
#
# PROCESSING RECORD #45 OF SET 5 FOR CITY, port alfred.
#
# PROCESSING RECORD #46 OF SET 5 FOR CITY, ha'il.
#
# PROCESSING RECORD #47 OF SET 5 FOR CITY, whitehorse.
#
# PROCESSING RECORD #48 OF SET 5 FOR CITY, ribas do rio pardo.
#
# PROCESSING RECORD #49 OF SET 5 FOR CITY, jilib.
#
# PROCESSING RECORD #50 OF SET 5 FOR CITY, yangshuo.
#
# PROCESSING RECORD #1 OF SET 6 FOR CITY, hluti.
#
# PROCESSING RECORD #2 OF SET 6 FOR CITY, brookings.
#
# PROCESSING RECORD #3 OF SET 6 FOR CITY, remire-montjoly.
#
# PROCESSING RECORD #4 OF SET 6 FOR CITY, zarghun shahr.
#
# PROCESSING RECORD #5 OF SET 6 FOR CITY, alice springs.
#
# PROCESSING RECORD #6 OF SET 6 FOR CITY, georgetown.
#
# PROCESSING RECORD #7 OF SET 6 FOR CITY, ungsang-nodongjagu.
#
# PROCESSING RECORD #8 OF SET 6 FOR CITY, ivdel'.
#
# PROCESSING RECORD #9 OF SET 6 FOR CITY, nemuro.
#
# PROCESSING RECORD #10 OF SET 6 FOR CITY, nicoya.
#
# PROCESSING RECORD #11 OF SET 6 FOR CITY, diego de almagro.
#
# PROCESSING RECORD #12 OF SET 6 FOR CITY, comodoro rivadavia.
#
# PROCESSING RECORD #13 OF SET 6 FOR CITY, kavaratti.
#
# PROCESSING RECORD #14 OF SET 6 FOR CITY, verdal.
#
# PROCESSING RECORD #15 OF SET 6 FOR CITY, bashtanka.
#
# PROCESSING RECORD #16 OF SET 6 FOR CITY, khandyga.
#
# PROCESSING RECORD #17 OF SET 6 FOR CITY, kalmunai.
#
# PROCESSING RECORD #18 OF SET 6 FOR CITY, inongo.
#
# PROCESSING RECORD #19 OF SET 6 FOR CITY, chadron.
#
# PROCESSING RECORD #20 OF SET 6 FOR CITY, bargara.
#
# The script did not find the city, bargara. Skipping...
#
# PROCESSING RECORD #21 OF SET 6 FOR CITY, sarny.
#
# PROCESSING RECORD #22 OF SET 6 FOR CITY, sola.
#
# PROCESSING RECORD #23 OF SET 6 FOR CITY, kununurra.
#
# PROCESSING RECORD #24 OF SET 6 FOR CITY, uturoa.
#
# PROCESSING RECORD #25 OF SET 6 FOR CITY, constantia.
#
# PROCESSING RECORD #26 OF SET 6 FOR CITY, gaiman.
#
# PROCESSING RECORD #27 OF SET 6 FOR CITY, mar del plata.
#
# PROCESSING RECORD #28 OF SET 6 FOR CITY, lupane.
#
# PROCESSING RECORD #29 OF SET 6 FOR CITY, valparaiso.
#
# PROCESSING RECORD #30 OF SET 6 FOR CITY, sao tome.
#
# PROCESSING RECORD #31 OF SET 6 FOR CITY, guarapari.
#
# PROCESSING RECORD #32 OF SET 6 FOR CITY, aracuai.
#
# PROCESSING RECORD #33 OF SET 6 FOR CITY, debark'.
#
# PROCESSING RECORD #34 OF SET 6 FOR CITY, mikuni.
#
# PROCESSING RECORD #35 OF SET 6 FOR CITY, alaghsas.
#
# PROCESSING RECORD #36 OF SET 6 FOR CITY, konarka.
#
# PROCESSING RECORD #37 OF SET 6 FOR CITY, bamboo flat.
#
# PROCESSING RECORD #38 OF SET 6 FOR CITY, marka.
#
# PROCESSING RECORD #39 OF SET 6 FOR CITY, eyl.
#
# PROCESSING RECORD #40 OF SET 6 FOR CITY, mahenge.
#
# PROCESSING RECORD #41 OF SET 6 FOR CITY, luckeesarai.
#
# PROCESSING RECORD #42 OF SET 6 FOR CITY, walvis bay.
#
# PROCESSING RECORD #43 OF SET 6 FOR CITY, kapuskasing.
#
# PROCESSING RECORD #44 OF SET 6 FOR CITY, lezoux.
#
# PROCESSING RECORD #45 OF SET 6 FOR CITY, cockburn town.
# PROCESSING RECORD #46 OF SET 6 FOR CITY, gorontalo.
#
# PROCESSING RECORD #47 OF SET 6 FOR CITY, uberlandia.
#
# PROCESSING RECORD #48 OF SET 6 FOR CITY, minab.
#
# PROCESSING RECORD #49 OF SET 6 FOR CITY, codrington.
#
# PROCESSING RECORD #50 OF SET 6 FOR CITY, carinhanha.
#
# PROCESSING RECORD #1 OF SET 7 FOR CITY, kratie.
#
# PROCESSING RECORD #2 OF SET 7 FOR CITY, hinton.
#
# PROCESSING RECORD #3 OF SET 7 FOR CITY, bondo.
#
# PROCESSING RECORD #4 OF SET 7 FOR CITY, nogliki.
#
# PROCESSING RECORD #5 OF SET 7 FOR CITY, amantea.
#
# PROCESSING RECORD #6 OF SET 7 FOR CITY, dudinka.
#
# PROCESSING RECORD #7 OF SET 7 FOR CITY, nkurenkuru.
#
# The script did not find the city, nkurenkuru. Skipping...
#
# PROCESSING RECORD #8 OF SET 7 FOR CITY, fort mcmurray.
#
# PROCESSING RECORD #9 OF SET 7 FOR CITY, awjilah.
#
# PROCESSING RECORD #10 OF SET 7 FOR CITY, porto murtinho.
#
# PROCESSING RECORD #11 OF SET 7 FOR CITY, vorkuta.
#
# PROCESSING RECORD #12 OF SET 7 FOR CITY, pangody.
#
# PROCESSING RECORD #13 OF SET 7 FOR CITY, tromso.
#
# PROCESSING RECORD #14 OF SET 7 FOR CITY, tranovaho.
#
# The script did not find the city, tranovaho. Skipping...
#
# PROCESSING RECORD #15 OF SET 7 FOR CITY, kontagora.
#
# PROCESSING RECORD #16 OF SET 7 FOR CITY, itanhem.
#
# PROCESSING RECORD #17 OF SET 7 FOR CITY, datong.
#
# PROCESSING RECORD #18 OF SET 7 FOR CITY, orito.
#
# PROCESSING RECORD #19 OF SET 7 FOR CITY, pitimbu.
#
# PROCESSING RECORD #20 OF SET 7 FOR CITY, yagry.
#
# The script did not find the city, yagry. Skipping...
#
# PROCESSING RECORD #21 OF SET 7 FOR CITY, sandnessjoen.
#
# PROCESSING RECORD #22 OF SET 7 FOR CITY, vadso.
#
# PROCESSING RECORD #23 OF SET 7 FOR CITY, cabo san lucas.
#
# PROCESSING RECORD #24 OF SET 7 FOR CITY, katsuren-haebaru.
#
# PROCESSING RECORD #25 OF SET 7 FOR CITY, nizao.
#
# PROCESSING RECORD #26 OF SET 7 FOR CITY, piti village.
#
# PROCESSING RECORD #27 OF SET 7 FOR CITY, westport.
#
# PROCESSING RECORD #28 OF SET 7 FOR CITY, santa terezinha.
#
# PROCESSING RECORD #29 OF SET 7 FOR CITY, arraial do cabo.
#
# PROCESSING RECORD #30 OF SET 7 FOR CITY, dhidhdhoo.
#
# PROCESSING RECORD #31 OF SET 7 FOR CITY, madimba.
#
# PROCESSING RECORD #32 OF SET 7 FOR CITY, victoria point.
#
# PROCESSING RECORD #33 OF SET 7 FOR CITY, el bauga.
#
# PROCESSING RECORD #34 OF SET 7 FOR CITY, guerrero negro.
#
# PROCESSING RECORD #35 OF SET 7 FOR CITY, stromstad.
#
# The script did not find the city, stromstad. Skipping...
#
# PROCESSING RECORD #36 OF SET 7 FOR CITY, antsiranana.
#
# PROCESSING RECORD #37 OF SET 7 FOR CITY, cozumel.
#
# PROCESSING RECORD #38 OF SET 7 FOR CITY, san ciro de acosta.
#
# PROCESSING RECORD #39 OF SET 7 FOR CITY, nizhneudinsk.
#
# PROCESSING RECORD #40 OF SET 7 FOR CITY, klyuchi.
#
# PROCESSING RECORD #41 OF SET 7 FOR CITY, karratha.
#
# PROCESSING RECORD #42 OF SET 7 FOR CITY, togur.
#
# PROCESSING RECORD #43 OF SET 7 FOR CITY, urrao.
#
# PROCESSING RECORD #44 OF SET 7 FOR CITY, valkeakoski.
#
# PROCESSING RECORD #45 OF SET 7 FOR CITY, tongchuanshi.
#
# PROCESSING RECORD #46 OF SET 7 FOR CITY, saldanha.
#
# PROCESSING RECORD #47 OF SET 7 FOR CITY, coihueco.
#
# PROCESSING RECORD #48 OF SET 7 FOR CITY, myeik.
#
# PROCESSING RECORD #49 OF SET 7 FOR CITY, uspenskoye.
#
# PROCESSING RECORD #50 OF SET 7 FOR CITY, richards bay.
#
# PROCESSING RECORD #1 OF SET 8 FOR CITY, colonia.
#
# PROCESSING RECORD #2 OF SET 8 FOR CITY, shingu.
#
# PROCESSING RECORD #3 OF SET 8 FOR CITY, paliano.
#
# PROCESSING RECORD #4 OF SET 8 FOR CITY, khromtau.
#
# PROCESSING RECORD #5 OF SET 8 FOR CITY, san luis de la loma.
#
# PROCESSING RECORD #6 OF SET 8 FOR CITY, joensuu.
#
# PROCESSING RECORD #7 OF SET 8 FOR CITY, el granada.
#
# PROCESSING RECORD #8 OF SET 8 FOR CITY, champerico.
#
# PROCESSING RECORD #9 OF SET 8 FOR CITY, liwonde.
#
# PROCESSING RECORD #10 OF SET 8 FOR CITY, oxapampa.
#
# PROCESSING RECORD #11 OF SET 8 FOR CITY, copala.
#
# PROCESSING RECORD #12 OF SET 8 FOR CITY, telemaco borba.
#
# PROCESSING RECORD #13 OF SET 8 FOR CITY, vershino-darasunskiy.
#
# PROCESSING RECORD #14 OF SET 8 FOR CITY, kimbe.
#
# PROCESSING RECORD #15 OF SET 8 FOR CITY, ponta delgada.
#
# PROCESSING RECORD #16 OF SET 8 FOR CITY, ulysses.
#
# PROCESSING RECORD #17 OF SET 8 FOR CITY, chalastra.
#
# PROCESSING RECORD #18 OF SET 8 FOR CITY, manokwari.
#
# PROCESSING RECORD #19 OF SET 8 FOR CITY, okha.
#
# PROCESSING RECORD #20 OF SET 8 FOR CITY, naranjal.
#
# PROCESSING RECORD #21 OF SET 8 FOR CITY, boa vista.
#
# PROCESSING RECORD #22 OF SET 8 FOR CITY, chinde.
#
# PROCESSING RECORD #23 OF SET 8 FOR CITY, altamira.
#
# PROCESSING RECORD #24 OF SET 8 FOR CITY, boma.
#
# PROCESSING RECORD #25 OF SET 8 FOR CITY, zaozersk.
#
# PROCESSING RECORD #26 OF SET 8 FOR CITY, alo.
#
# PROCESSING RECORD #27 OF SET 8 FOR CITY, porto novo.
#
# PROCESSING RECORD #28 OF SET 8 FOR CITY, guise.
#
# PROCESSING RECORD #29 OF SET 8 FOR CITY, selfoss.
#
# PROCESSING RECORD #30 OF SET 8 FOR CITY, coquimbo.
#
# PROCESSING RECORD #31 OF SET 8 FOR CITY, sabang.
#
# PROCESSING RECORD #32 OF SET 8 FOR CITY, dzuunharaa.
#
# PROCESSING RECORD #33 OF SET 8 FOR CITY, tarakan.
#
# PROCESSING RECORD #34 OF SET 8 FOR CITY, amahai.
#
# PROCESSING RECORD #35 OF SET 8 FOR CITY, villa ojo de agua.
#
# PROCESSING RECORD #36 OF SET 8 FOR CITY, bougouni.
#
# PROCESSING RECORD #37 OF SET 8 FOR CITY, nieuw amsterdam.
#
# PROCESSING RECORD #38 OF SET 8 FOR CITY, horana south.
#
# PROCESSING RECORD #39 OF SET 8 FOR CITY, metlili chaamba.
#
# PROCESSING RECORD #40 OF SET 8 FOR CITY, villamontes.
#
# PROCESSING RECORD #41 OF SET 8 FOR CITY, aioun.
#
# PROCESSING RECORD #42 OF SET 8 FOR CITY, ovruch.
#
# PROCESSING RECORD #43 OF SET 8 FOR CITY, paradip garh.
#
# PROCESSING RECORD #44 OF SET 8 FOR CITY, vallenar.
#
# PROCESSING RECORD #45 OF SET 8 FOR CITY, mount gambier.
#
# PROCESSING RECORD #46 OF SET 8 FOR CITY, kerikeri.
#
# PROCESSING RECORD #47 OF SET 8 FOR CITY, sinabang.
#
# PROCESSING RECORD #48 OF SET 8 FOR CITY, bikenibeu village.
#
# PROCESSING RECORD #49 OF SET 8 FOR CITY, nioki.
#
# PROCESSING RECORD #50 OF SET 8 FOR CITY, ta`u.
#
# PROCESSING RECORD #1 OF SET 9 FOR CITY, bolintin deal.
#
# PROCESSING RECORD #2 OF SET 9 FOR CITY, dzilam gonzalez.
#
# PROCESSING RECORD #3 OF SET 9 FOR CITY, oguta.
#
# PROCESSING RECORD #4 OF SET 9 FOR CITY, lau.
#
# PROCESSING RECORD #5 OF SET 9 FOR CITY, arteche.
#
# PROCESSING RECORD #6 OF SET 9 FOR CITY, satupa'itea.
#
# The script did not find the city, satupa'itea. Skipping...
#
# PROCESSING RECORD #7 OF SET 9 FOR CITY, wagar.
#
# PROCESSING RECORD #8 OF SET 9 FOR CITY, saint-flour.
#
# PROCESSING RECORD #9 OF SET 9 FOR CITY, tavda.
#
# PROCESSING RECORD #10 OF SET 9 FOR CITY, moyale.
#
# PROCESSING RECORD #11 OF SET 9 FOR CITY, dakhla.
#
# PROCESSING RECORD #12 OF SET 9 FOR CITY, savanna-la-mar.
#
# PROCESSING RECORD #13 OF SET 9 FOR CITY, elmendorf air force base.
#
# The script did not find the city, elmendorf air force base. Skipping...
#
# PROCESSING RECORD #14 OF SET 9 FOR CITY, brezina.
#
# PROCESSING RECORD #15 OF SET 9 FOR CITY, afaahiti.
#
# PROCESSING RECORD #16 OF SET 9 FOR CITY, santiago de cao.
#
# PROCESSING RECORD #17 OF SET 9 FOR CITY, port lincoln.
#
# PROCESSING RECORD #18 OF SET 9 FOR CITY, eten.
#
# PROCESSING RECORD #19 OF SET 9 FOR CITY, matoury.
#
# PROCESSING RECORD #20 OF SET 9 FOR CITY, holma.
#
# PROCESSING RECORD #21 OF SET 9 FOR CITY, weno.
#
# PROCESSING RECORD #22 OF SET 9 FOR CITY, tshabong.
#
# PROCESSING RECORD #23 OF SET 9 FOR CITY, andalgala.
#
# PROCESSING RECORD #24 OF SET 9 FOR CITY, naama.
#
# PROCESSING RECORD #25 OF SET 9 FOR CITY, bardai.
#
# PROCESSING RECORD #26 OF SET 9 FOR CITY, san juan de uraba.
#
# PROCESSING RECORD #27 OF SET 9 FOR CITY, bodaybo.
#
# PROCESSING RECORD #28 OF SET 9 FOR CITY, novyy urengoy.
#
# PROCESSING RECORD #29 OF SET 9 FOR CITY, ust'-ilimsk.
#
# PROCESSING RECORD #30 OF SET 9 FOR CITY, namibe.
#
# PROCESSING RECORD #31 OF SET 9 FOR CITY, balikesir.
#
# PROCESSING RECORD #32 OF SET 9 FOR CITY, vila franca do campo.
#
# PROCESSING RECORD #33 OF SET 9 FOR CITY, severo-yeniseyskiy.
#
# PROCESSING RECORD #34 OF SET 9 FOR CITY, duncan town.
#
# The script did not find the city, duncan town. Skipping...
#
# PROCESSING RECORD #35 OF SET 9 FOR CITY, kitzbuhel.
#
# PROCESSING RECORD #36 OF SET 9 FOR CITY, shubarshi.
#
# PROCESSING RECORD #37 OF SET 9 FOR CITY, chilliwack.
#
# PROCESSING RECORD #38 OF SET 9 FOR CITY, kihancha.
#
# PROCESSING RECORD #39 OF SET 9 FOR CITY, susuman.
#
# PROCESSING RECORD #40 OF SET 9 FOR CITY, dawson creek.
#
# PROCESSING RECORD #41 OF SET 9 FOR CITY, inari.
#
# PROCESSING RECORD #42 OF SET 9 FOR CITY, hultsfred.
#
# PROCESSING RECORD #43 OF SET 9 FOR CITY, lagodekhi.
# PROCESSING RECORD #44 OF SET 9 FOR CITY, reitz.
#
# PROCESSING RECORD #45 OF SET 9 FOR CITY, vanimo.
#
# PROCESSING RECORD #46 OF SET 9 FOR CITY, lionel town.
#
# PROCESSING RECORD #47 OF SET 9 FOR CITY, upington.
#
# PROCESSING RECORD #48 OF SET 9 FOR CITY, mazyr.
#
# PROCESSING RECORD #49 OF SET 9 FOR CITY, sittwe.
#
# PROCESSING RECORD #50 OF SET 9 FOR CITY, naze.
#
# PROCESSING RECORD #1 OF SET 10 FOR CITY, hailey.
#
# PROCESSING RECORD #2 OF SET 10 FOR CITY, fiambala.
#
# PROCESSING RECORD #3 OF SET 10 FOR CITY, auch.
#
# PROCESSING RECORD #4 OF SET 10 FOR CITY, yuli.
#
# PROCESSING RECORD #5 OF SET 10 FOR CITY, tangalle.
#
# PROCESSING RECORD #6 OF SET 10 FOR CITY, adre.
#
# PROCESSING RECORD #7 OF SET 10 FOR CITY, shawnee.
#
# PROCESSING RECORD #8 OF SET 10 FOR CITY, el nido.
#
# PROCESSING RECORD #9 OF SET 10 FOR CITY, medina.
#
# PROCESSING RECORD #10 OF SET 10 FOR CITY, greenville.
#
# PROCESSING RECORD #11 OF SET 10 FOR CITY, kisaran.
#
# PROCESSING RECORD #12 OF SET 10 FOR CITY, kletnya.
#
# PROCESSING RECORD #13 OF SET 10 FOR CITY, guiyang.
#
# PROCESSING RECORD #14 OF SET 10 FOR CITY, castelo do piaui.
#
# PROCESSING RECORD #15 OF SET 10 FOR CITY, greensburg.
#
# PROCESSING RECORD #16 OF SET 10 FOR CITY, ayr.
#
# PROCESSING RECORD #17 OF SET 10 FOR CITY, stony plain.
#
# PROCESSING RECORD #18 OF SET 10 FOR CITY, maych'ew.
#
# PROCESSING RECORD #19 OF SET 10 FOR CITY, lulea.
#
# PROCESSING RECORD #20 OF SET 10 FOR CITY, murray bridge.
#
# PROCESSING RECORD #21 OF SET 10 FOR CITY, satipo.
#
# PROCESSING RECORD #22 OF SET 10 FOR CITY, nguigmi.
#
# PROCESSING RECORD #23 OF SET 10 FOR CITY, taibet.
#
# The script did not find the city, taibet. Skipping...
#
# PROCESSING RECORD #24 OF SET 10 FOR CITY, sydney mines.
#
# PROCESSING RECORD #25 OF SET 10 FOR CITY, gurlan.
#
# PROCESSING RECORD #26 OF SET 10 FOR CITY, tafuna.
#
# PROCESSING RECORD #27 OF SET 10 FOR CITY, samoylovka.
#
# PROCESSING RECORD #28 OF SET 10 FOR CITY, miyanoura.
#
# The script did not find the city, miyanoura. Skipping...
#
# PROCESSING RECORD #29 OF SET 10 FOR CITY, rakops.
#
# PROCESSING RECORD #30 OF SET 10 FOR CITY, changli.
#
# PROCESSING RECORD #31 OF SET 10 FOR CITY, bukama.
#
# PROCESSING RECORD #32 OF SET 10 FOR CITY, villa paula de sarmiento.
#
# PROCESSING RECORD #33 OF SET 10 FOR CITY, ocean shores.
#
# PROCESSING RECORD #34 OF SET 10 FOR CITY, abu.
#
# PROCESSING RECORD #35 OF SET 10 FOR CITY, veseloyarsk.
#
# PROCESSING RECORD #36 OF SET 10 FOR CITY, chokwe.
#
# PROCESSING RECORD #37 OF SET 10 FOR CITY, labuan bajo.
#
# PROCESSING RECORD #38 OF SET 10 FOR CITY, khanpur mahar.
#
# PROCESSING RECORD #39 OF SET 10 FOR CITY, amos.
#
# PROCESSING RECORD #40 OF SET 10 FOR CITY, mahabe.
#
# The script did not find the city, mahabe. Skipping...
#
# PROCESSING RECORD #41 OF SET 10 FOR CITY, brisas de zicatela.
#
# PROCESSING RECORD #42 OF SET 10 FOR CITY, weihai.
#
# PROCESSING RECORD #43 OF SET 10 FOR CITY, mossel bay.
#
# PROCESSING RECORD #44 OF SET 10 FOR CITY, nishinoomote.
#
# PROCESSING RECORD #45 OF SET 10 FOR CITY, matamata.
#
# PROCESSING RECORD #46 OF SET 10 FOR CITY, port erin.
#
# PROCESSING RECORD #47 OF SET 10 FOR CITY, yatou.
#
# PROCESSING RECORD #48 OF SET 10 FOR CITY, al wajh.
#
# PROCESSING RECORD #49 OF SET 10 FOR CITY, neryungri.
#
# PROCESSING RECORD #50 OF SET 10 FOR CITY, hobyo.
#
# PROCESSING RECORD #1 OF SET 11 FOR CITY, quixada.
#
# PROCESSING RECORD #2 OF SET 11 FOR CITY, pierre.
#
# PROCESSING RECORD #3 OF SET 11 FOR CITY, labytnangi.
#
# PROCESSING RECORD #4 OF SET 11 FOR CITY, toropets.
#
# PROCESSING RECORD #5 OF SET 11 FOR CITY, mazouna.
#
# PROCESSING RECORD #6 OF SET 11 FOR CITY, aykhal.
#
# PROCESSING RECORD #7 OF SET 11 FOR CITY, port glaud.
#
# The script did not find the city, port glaud. Skipping...
#
# PROCESSING RECORD #8 OF SET 11 FOR CITY, ukiah.
#
# PROCESSING RECORD #9 OF SET 11 FOR CITY, lata.
#
# PROCESSING RECORD #10 OF SET 11 FOR CITY, akhuryan.
#
# PROCESSING RECORD #11 OF SET 11 FOR CITY, mugia.
#
# PROCESSING RECORD #12 OF SET 11 FOR CITY, kisangani.
#
# PROCESSING RECORD #13 OF SET 11 FOR CITY, itirucu.
#
# PROCESSING RECORD #14 OF SET 11 FOR CITY, shohimardon.
#
# PROCESSING RECORD #15 OF SET 11 FOR CITY, tobi village.
#
# The script did not find the city, tobi village. Skipping...
#
# PROCESSING RECORD #16 OF SET 11 FOR CITY, altar.
#
# PROCESSING RECORD #17 OF SET 11 FOR CITY, hangu.
#
# PROCESSING RECORD #18 OF SET 11 FOR CITY, khvansar.
#
# PROCESSING RECORD #19 OF SET 11 FOR CITY, jaraiz de la vera.
#
# PROCESSING RECORD #20 OF SET 11 FOR CITY, alderetes.
#
# PROCESSING RECORD #21 OF SET 11 FOR CITY, residencia moacir pu5bhv.
#
# The script did not find the city, residencia moacir pu5bhv. Skipping...
#
# PROCESSING RECORD #22 OF SET 11 FOR CITY, newcastle west.
#
# PROCESSING RECORD #23 OF SET 11 FOR CITY, narrabri.
#
# PROCESSING RECORD #24 OF SET 11 FOR CITY, iskateley.
#
# PROCESSING RECORD #25 OF SET 11 FOR CITY, ciudad constitucion.
#
# PROCESSING RECORD #26 OF SET 11 FOR CITY, mersa matruh.
#
# PROCESSING RECORD #27 OF SET 11 FOR CITY, fomboni.
#
# PROCESSING RECORD #28 OF SET 11 FOR CITY, koneurgench.
#
# The script did not find the city, koneurgench. Skipping...
#
# PROCESSING RECORD #29 OF SET 11 FOR CITY, lysyye gory.
#
# PROCESSING RECORD #30 OF SET 11 FOR CITY, leava.
#
# PROCESSING RECORD #31 OF SET 11 FOR CITY, malango.
#
# PROCESSING RECORD #32 OF SET 11 FOR CITY, kismayo.
#
# PROCESSING RECORD #33 OF SET 11 FOR CITY, kupang.
#
# PROCESSING RECORD #34 OF SET 11 FOR CITY, marsdijk.
#
# The script did not find the city, marsdijk. Skipping...
#
# PROCESSING RECORD #35 OF SET 11 FOR CITY, yayladagi.
#
# PROCESSING RECORD #36 OF SET 11 FOR CITY, banda aceh.
#
# PROCESSING RECORD #37 OF SET 11 FOR CITY, sao joao da barra.
#
# PROCESSING RECORD #38 OF SET 11 FOR CITY, cartagena.
#
# PROCESSING RECORD #39 OF SET 11 FOR CITY, general villegas.
#
# PROCESSING RECORD #40 OF SET 11 FOR CITY, tukums.
#
# PROCESSING RECORD #41 OF SET 11 FOR CITY, taro.
#
# PROCESSING RECORD #42 OF SET 11 FOR CITY, neijiang.
#
# PROCESSING RECORD #43 OF SET 11 FOR CITY, qarauyl.
#
# PROCESSING RECORD #44 OF SET 11 FOR CITY, pathein.
#
# PROCESSING RECORD #45 OF SET 11 FOR CITY, regina.
#
# PROCESSING RECORD #46 OF SET 11 FOR CITY, port augusta.
#
# PROCESSING RECORD #47 OF SET 11 FOR CITY, culaba.
#
# PROCESSING RECORD #48 OF SET 11 FOR CITY, flin flon.
#
# PROCESSING RECORD #49 OF SET 11 FOR CITY, villacanas.
#
# PROCESSING RECORD #50 OF SET 11 FOR CITY, warmbad.
#
# PROCESSING RECORD #1 OF SET 12 FOR CITY, darwin.
#
# PROCESSING RECORD #2 OF SET 12 FOR CITY, spring creek.
#
# PROCESSING RECORD #3 OF SET 12 FOR CITY, carbonear.
#
# PROCESSING RECORD #4 OF SET 12 FOR CITY, gremda.
#
# PROCESSING RECORD #5 OF SET 12 FOR CITY, hihifo.
#
# The script did not find the city, hihifo. Skipping...
#
# PROCESSING RECORD #6 OF SET 12 FOR CITY, xilin hot.
#
# PROCESSING RECORD #7 OF SET 12 FOR CITY, las tunas.
#
# PROCESSING RECORD #8 OF SET 12 FOR CITY, paracuru.
#
# PROCESSING RECORD #9 OF SET 12 FOR CITY, north platte.
#
# PROCESSING RECORD #10 OF SET 12 FOR CITY, eloy alfaro.
#
# PROCESSING RECORD #11 OF SET 12 FOR CITY, barah.
#
# PROCESSING RECORD #12 OF SET 12 FOR CITY, greifswald.
#
# PROCESSING RECORD #13 OF SET 12 FOR CITY, kulhudhuffushi.
#
# PROCESSING RECORD #14 OF SET 12 FOR CITY, muroto-misakicho.
#
# PROCESSING RECORD #15 OF SET 12 FOR CITY, aswan.
#
# PROCESSING RECORD #16 OF SET 12 FOR CITY, pariaman.
#
# PROCESSING RECORD #17 OF SET 12 FOR CITY, tuba city.
#
# PROCESSING RECORD #18 OF SET 12 FOR CITY, mohr.
#
# PROCESSING RECORD #19 OF SET 12 FOR CITY, guelmim.
#
# PROCESSING RECORD #20 OF SET 12 FOR CITY, gilgit.
#
# PROCESSING RECORD #21 OF SET 12 FOR CITY, port saint john's.
#
# PROCESSING RECORD #22 OF SET 12 FOR CITY, berdigestyakh.
#
# PROCESSING RECORD #23 OF SET 12 FOR CITY, ciranjang-hilir.
#
# PROCESSING RECORD #24 OF SET 12 FOR CITY, polillo.
#
# PROCESSING RECORD #25 OF SET 12 FOR CITY, salmon arm.
#
# PROCESSING RECORD #26 OF SET 12 FOR CITY, zapala.
#
# PROCESSING RECORD #27 OF SET 12 FOR CITY, ancud.
#
# PROCESSING RECORD #28 OF SET 12 FOR CITY, mollendo.
#
# PROCESSING RECORD #29 OF SET 12 FOR CITY, san sebastian de la gomera.
#
# PROCESSING RECORD #30 OF SET 12 FOR CITY, corumba.
#
# PROCESSING RECORD #31 OF SET 12 FOR CITY, kristiansund.
#
# PROCESSING RECORD #32 OF SET 12 FOR CITY, ambalangoda.
#
# PROCESSING RECORD #33 OF SET 12 FOR CITY, urangan.
#
# PROCESSING RECORD #34 OF SET 12 FOR CITY, kansk.
#
# PROCESSING RECORD #35 OF SET 12 FOR CITY, dongobesh.
#
# PROCESSING RECORD #36 OF SET 12 FOR CITY, karatau.
#
# PROCESSING RECORD #37 OF SET 12 FOR CITY, peniche.
#
# PROCESSING RECORD #38 OF SET 12 FOR CITY, ilovlya.
# PROCESSING RECORD #39 OF SET 12 FOR CITY, molteno.
#
# PROCESSING RECORD #40 OF SET 12 FOR CITY, siwa oasis.
#
# PROCESSING RECORD #41 OF SET 12 FOR CITY, mpika.
#
# PROCESSING RECORD #42 OF SET 12 FOR CITY, hotan.
#
# PROCESSING RECORD #43 OF SET 12 FOR CITY, marataizes.
#
# PROCESSING RECORD #44 OF SET 12 FOR CITY, ust'-kulom.
#
# PROCESSING RECORD #45 OF SET 12 FOR CITY, korla.
#
# PROCESSING RECORD #46 OF SET 12 FOR CITY, sona.
#
# PROCESSING RECORD #47 OF SET 12 FOR CITY, rikaze.
#
# PROCESSING RECORD #48 OF SET 12 FOR CITY, la'ie.
#
# PROCESSING RECORD #49 OF SET 12 FOR CITY, xinpu.
#
# PROCESSING RECORD #50 OF SET 12 FOR CITY, formosa do rio preto.
#
# PROCESSING RECORD #1 OF SET 13 FOR CITY, gobabis.
#
# PROCESSING RECORD #2 OF SET 13 FOR CITY, south hedland.
#
# Data Retrieval for city weather DataFrame is complete.

# %%
log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Records Count**

# %%
cityWeatherCountIntegerVariable \
    = cityWeatherDataFrame \
        ['City'] \
            .count()

print \
    (f"There are {cityWeatherCountIntegerVariable} " \
     + f"records in the city weather DataFrame.")
# Out:
# There are 571 records in the city weather DataFrame.

# %% [markdown]
# ### **Display City Weather DataFrame**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_cd50e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_cd50e_row0_col0, #T_cd50e_row0_col1, #T_cd50e_row0_col2, #T_cd50e_row0_col4, #T_cd50e_row0_col5, #T_cd50e_row0_col6, #T_cd50e_row0_col7, #T_cd50e_row0_col8, #T_cd50e_row1_col0, #T_cd50e_row1_col1, #T_cd50e_row1_col2, #T_cd50e_row1_col3, #T_cd50e_row1_col4, #T_cd50e_row1_col6, #T_cd50e_row1_col7, #T_cd50e_row1_col8, #T_cd50e_row2_col0, #T_cd50e_row2_col1, #T_cd50e_row2_col2, #T_cd50e_row2_col3, #T_cd50e_row2_col4, #T_cd50e_row2_col5, #T_cd50e_row2_col6, #T_cd50e_row2_col7, #T_cd50e_row2_col8, #T_cd50e_row3_col0, #T_cd50e_row3_col1, #T_cd50e_row3_col2, #T_cd50e_row3_col3, #T_cd50e_row3_col4, #T_cd50e_row3_col6, #T_cd50e_row3_col7, #T_cd50e_row3_col8, #T_cd50e_row4_col0, #T_cd50e_row4_col1, #T_cd50e_row4_col2, #T_cd50e_row4_col3, #T_cd50e_row4_col4, #T_cd50e_row4_col5, #T_cd50e_row4_col6, #T_cd50e_row4_col7, #T_cd50e_row4_col8, #T_cd50e_row5_col0, #T_cd50e_row5_col1, #T_cd50e_row5_col2, #T_cd50e_row5_col3, #T_cd50e_row5_col4, #T_cd50e_row5_col7, #T_cd50e_row5_col8, #T_cd50e_row6_col0, #T_cd50e_row6_col1, #T_cd50e_row6_col2, #T_cd50e_row6_col3, #T_cd50e_row6_col7, #T_cd50e_row6_col8, #T_cd50e_row7_col0, #T_cd50e_row7_col1, #T_cd50e_row7_col2, #T_cd50e_row7_col3, #T_cd50e_row7_col4, #T_cd50e_row7_col5, #T_cd50e_row7_col6, #T_cd50e_row7_col7, #T_cd50e_row7_col8, #T_cd50e_row8_col0, #T_cd50e_row8_col1, #T_cd50e_row8_col2, #T_cd50e_row8_col4, #T_cd50e_row8_col6, #T_cd50e_row8_col7, #T_cd50e_row8_col8, #T_cd50e_row9_col0, #T_cd50e_row9_col1, #T_cd50e_row9_col2, #T_cd50e_row9_col3, #T_cd50e_row9_col4, #T_cd50e_row9_col6, #T_cd50e_row9_col7, #T_cd50e_row9_col8, #T_cd50e_row10_col0, #T_cd50e_row10_col1, #T_cd50e_row10_col2, #T_cd50e_row10_col3, #T_cd50e_row10_col4, #T_cd50e_row10_col5, #T_cd50e_row10_col6, #T_cd50e_row10_col7, #T_cd50e_row10_col8, #T_cd50e_row11_col0, #T_cd50e_row11_col1, #T_cd50e_row11_col2, #T_cd50e_row11_col3, #T_cd50e_row11_col6, #T_cd50e_row11_col7, #T_cd50e_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_cd50e_row0_col3, #T_cd50e_row5_col5, #T_cd50e_row5_col6, #T_cd50e_row8_col5, #T_cd50e_row11_col4, #T_cd50e_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_cd50e_row1_col5, #T_cd50e_row3_col5, #T_cd50e_row6_col4, #T_cd50e_row6_col5, #T_cd50e_row6_col6, #T_cd50e_row8_col3, #T_cd50e_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_cd50e">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_cd50e_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_cd50e_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_cd50e_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_cd50e_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_cd50e_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_cd50e_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_cd50e_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_cd50e_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_cd50e_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cd50e_row0_col0" class="data row0 col0" >coahuayana de hidalgo</td>
#       <td id="T_cd50e_row0_col1" class="data row0 col1" >18.70</td>
#       <td id="T_cd50e_row0_col2" class="data row0 col2" >-103.66</td>
#       <td id="T_cd50e_row0_col3" class="data row0 col3" >90.52° F</td>
#       <td id="T_cd50e_row0_col4" class="data row0 col4" >63%</td>
#       <td id="T_cd50e_row0_col5" class="data row0 col5" >58%</td>
#       <td id="T_cd50e_row0_col6" class="data row0 col6" >5.32</td>
#       <td id="T_cd50e_row0_col7" class="data row0 col7" >MX</td>
#       <td id="T_cd50e_row0_col8" class="data row0 col8" >2023-09-01 12:10:41</td>
#     </tr>
#     <tr>
#       <td id="T_cd50e_row1_col0" class="data row1 col0" >port elizabeth</td>
#       <td id="T_cd50e_row1_col1" class="data row1 col1" >-33.92</td>
#       <td id="T_cd50e_row1_col2" class="data row1 col2" >25.57</td>
#       <td id="T_cd50e_row1_col3" class="data row1 col3" >53.89° F</td>
#       <td id="T_cd50e_row1_col4" class="data row1 col4" >71%</td>
#       <td id="T_cd50e_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_cd50e_row1_col6" class="data row1 col6" >4.61</td>
#       <td id="T_cd50e_row1_col7" class="data row1 col7" >ZA</td>
#       <td id="T_cd50e_row1_col8" class="data row1 col8" >2023-09-01 11:58:29</td>
#     </tr>
#     <tr>
#       <td id="T_cd50e_row2_col0" class="data row2 col0" >carnarvon</td>
#       <td id="T_cd50e_row2_col1" class="data row2 col1" >-24.87</td>
#       <td id="T_cd50e_row2_col2" class="data row2 col2" >113.63</td>
#       <td id="T_cd50e_row2_col3" class="data row2 col3" >65.79° F</td>
#       <td id="T_cd50e_row2_col4" class="data row2 col4" >74%</td>
#       <td id="T_cd50e_row2_col5" class="data row2 col5" >3%</td>
#       <td id="T_cd50e_row2_col6" class="data row2 col6" >9.37</td>
#       <td id="T_cd50e_row2_col7" class="data row2 col7" >AU</td>
#       <td id="T_cd50e_row2_col8" class="data row2 col8" >2023-09-01 12:07:01</td>
#     </tr>
#     <tr>
#       <td id="T_cd50e_row3_col0" class="data row3 col0" >bethel</td>
#       <td id="T_cd50e_row3_col1" class="data row3 col1" >41.37</td>
#       <td id="T_cd50e_row3_col2" class="data row3 col2" >-73.41</td>
#       <td id="T_cd50e_row3_col3" class="data row3 col3" >73.44° F</td>
#       <td id="T_cd50e_row3_col4" class="data row3 col4" >53%</td>
#       <td id="T_cd50e_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_cd50e_row3_col6" class="data row3 col6" >2.19</td>
#       <td id="T_cd50e_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_cd50e_row3_col8" class="data row3 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_cd50e_row4_col0" class="data row4 col0" >nuoro</td>
#       <td id="T_cd50e_row4_col1" class="data row4 col1" >40.32</td>
#       <td id="T_cd50e_row4_col2" class="data row4 col2" >9.33</td>
#       <td id="T_cd50e_row4_col3" class="data row4 col3" >62.17° F</td>
#       <td id="T_cd50e_row4_col4" class="data row4 col4" >86%</td>
#       <td id="T_cd50e_row4_col5" class="data row4 col5" >90%</td>
#       <td id="T_cd50e_row4_col6" class="data row4 col6" >3.62</td>
#       <td id="T_cd50e_row4_col7" class="data row4 col7" >IT</td>
#       <td id="T_cd50e_row4_col8" class="data row4 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_cd50e_row5_col0" class="data row5 col0" >utrik</td>
#       <td id="T_cd50e_row5_col1" class="data row5 col1" >11.23</td>
#       <td id="T_cd50e_row5_col2" class="data row5 col2" >169.85</td>
#       <td id="T_cd50e_row5_col3" class="data row5 col3" >82.76° F</td>
#       <td id="T_cd50e_row5_col4" class="data row5 col4" >78%</td>
#       <td id="T_cd50e_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_cd50e_row5_col6" class="data row5 col6" >12.08</td>
#       <td id="T_cd50e_row5_col7" class="data row5 col7" >MH</td>
#       <td id="T_cd50e_row5_col8" class="data row5 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_cd50e_row6_col0" class="data row6 col0" >albany</td>
#       <td id="T_cd50e_row6_col1" class="data row6 col1" >42.60</td>
#       <td id="T_cd50e_row6_col2" class="data row6 col2" >-73.97</td>
#       <td id="T_cd50e_row6_col3" class="data row6 col3" >73.71° F</td>
#       <td id="T_cd50e_row6_col4" class="data row6 col4" >51%</td>
#       <td id="T_cd50e_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_cd50e_row6_col6" class="data row6 col6" >1.99</td>
#       <td id="T_cd50e_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_cd50e_row6_col8" class="data row6 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_cd50e_row7_col0" class="

# %% [markdown]
# ### **Data Export to CSV File**

# %%
subroutine \
    .WriteDataFrameToCSVFile \
        (cityWeatherDataFrame,
         local_constant.WEATHER_DATA_FILE_PATH,
         local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Data Import from CSV File**

# %%
sampleCityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)

# %% [markdown]
# ### **Display Sample City Weather DataFrame**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information from CSV File')
# Out:
# <style type="text/css">
# #T_bb94d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_bb94d_row0_col0, #T_bb94d_row0_col1, #T_bb94d_row0_col2, #T_bb94d_row0_col4, #T_bb94d_row0_col5, #T_bb94d_row0_col6, #T_bb94d_row0_col7, #T_bb94d_row0_col8, #T_bb94d_row1_col0, #T_bb94d_row1_col1, #T_bb94d_row1_col2, #T_bb94d_row1_col3, #T_bb94d_row1_col4, #T_bb94d_row1_col6, #T_bb94d_row1_col7, #T_bb94d_row1_col8, #T_bb94d_row2_col0, #T_bb94d_row2_col1, #T_bb94d_row2_col2, #T_bb94d_row2_col3, #T_bb94d_row2_col4, #T_bb94d_row2_col5, #T_bb94d_row2_col6, #T_bb94d_row2_col7, #T_bb94d_row2_col8, #T_bb94d_row3_col0, #T_bb94d_row3_col1, #T_bb94d_row3_col2, #T_bb94d_row3_col3, #T_bb94d_row3_col4, #T_bb94d_row3_col6, #T_bb94d_row3_col7, #T_bb94d_row3_col8, #T_bb94d_row4_col0, #T_bb94d_row4_col1, #T_bb94d_row4_col2, #T_bb94d_row4_col3, #T_bb94d_row4_col4, #T_bb94d_row4_col5, #T_bb94d_row4_col6, #T_bb94d_row4_col7, #T_bb94d_row4_col8, #T_bb94d_row5_col0, #T_bb94d_row5_col1, #T_bb94d_row5_col2, #T_bb94d_row5_col3, #T_bb94d_row5_col4, #T_bb94d_row5_col7, #T_bb94d_row5_col8, #T_bb94d_row6_col0, #T_bb94d_row6_col1, #T_bb94d_row6_col2, #T_bb94d_row6_col3, #T_bb94d_row6_col7, #T_bb94d_row6_col8, #T_bb94d_row7_col0, #T_bb94d_row7_col1, #T_bb94d_row7_col2, #T_bb94d_row7_col3, #T_bb94d_row7_col4, #T_bb94d_row7_col5, #T_bb94d_row7_col6, #T_bb94d_row7_col7, #T_bb94d_row7_col8, #T_bb94d_row8_col0, #T_bb94d_row8_col1, #T_bb94d_row8_col2, #T_bb94d_row8_col4, #T_bb94d_row8_col6, #T_bb94d_row8_col7, #T_bb94d_row8_col8, #T_bb94d_row9_col0, #T_bb94d_row9_col1, #T_bb94d_row9_col2, #T_bb94d_row9_col3, #T_bb94d_row9_col4, #T_bb94d_row9_col6, #T_bb94d_row9_col7, #T_bb94d_row9_col8, #T_bb94d_row10_col0, #T_bb94d_row10_col1, #T_bb94d_row10_col2, #T_bb94d_row10_col3, #T_bb94d_row10_col4, #T_bb94d_row10_col5, #T_bb94d_row10_col6, #T_bb94d_row10_col7, #T_bb94d_row10_col8, #T_bb94d_row11_col0, #T_bb94d_row11_col1, #T_bb94d_row11_col2, #T_bb94d_row11_col3, #T_bb94d_row11_col6, #T_bb94d_row11_col7, #T_bb94d_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_bb94d_row0_col3, #T_bb94d_row5_col5, #T_bb94d_row5_col6, #T_bb94d_row8_col5, #T_bb94d_row11_col4, #T_bb94d_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_bb94d_row1_col5, #T_bb94d_row3_col5, #T_bb94d_row6_col4, #T_bb94d_row6_col5, #T_bb94d_row6_col6, #T_bb94d_row8_col3, #T_bb94d_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_bb94d">
#   <caption>Table: 1.1: City Weather Information from CSV File</caption>
#   <thead>
#     <tr>
#       <th id="T_bb94d_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_bb94d_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_bb94d_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_bb94d_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_bb94d_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_bb94d_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_bb94d_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_bb94d_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_bb94d_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bb94d_row0_col0" class="data row0 col0" >coahuayana de hidalgo</td>
#       <td id="T_bb94d_row0_col1" class="data row0 col1" >18.70</td>
#       <td id="T_bb94d_row0_col2" class="data row0 col2" >-103.66</td>
#       <td id="T_bb94d_row0_col3" class="data row0 col3" >90.52° F</td>
#       <td id="T_bb94d_row0_col4" class="data row0 col4" >63%</td>
#       <td id="T_bb94d_row0_col5" class="data row0 col5" >58%</td>
#       <td id="T_bb94d_row0_col6" class="data row0 col6" >5.32</td>
#       <td id="T_bb94d_row0_col7" class="data row0 col7" >MX</td>
#       <td id="T_bb94d_row0_col8" class="data row0 col8" >2023-09-01 12:10:41</td>
#     </tr>
#     <tr>
#       <td id="T_bb94d_row1_col0" class="data row1 col0" >port elizabeth</td>
#       <td id="T_bb94d_row1_col1" class="data row1 col1" >-33.92</td>
#       <td id="T_bb94d_row1_col2" class="data row1 col2" >25.57</td>
#       <td id="T_bb94d_row1_col3" class="data row1 col3" >53.89° F</td>
#       <td id="T_bb94d_row1_col4" class="data row1 col4" >71%</td>
#       <td id="T_bb94d_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_bb94d_row1_col6" class="data row1 col6" >4.61</td>
#       <td id="T_bb94d_row1_col7" class="data row1 col7" >ZA</td>
#       <td id="T_bb94d_row1_col8" class="data row1 col8" >2023-09-01 11:58:29</td>
#     </tr>
#     <tr>
#       <td id="T_bb94d_row2_col0" class="data row2 col0" >carnarvon</td>
#       <td id="T_bb94d_row2_col1" class="data row2 col1" >-24.87</td>
#       <td id="T_bb94d_row2_col2" class="data row2 col2" >113.63</td>
#       <td id="T_bb94d_row2_col3" class="data row2 col3" >65.79° F</td>
#       <td id="T_bb94d_row2_col4" class="data row2 col4" >74%</td>
#       <td id="T_bb94d_row2_col5" class="data row2 col5" >3%</td>
#       <td id="T_bb94d_row2_col6" class="data row2 col6" >9.37</td>
#       <td id="T_bb94d_row2_col7" class="data row2 col7" >AU</td>
#       <td id="T_bb94d_row2_col8" class="data row2 col8" >2023-09-01 12:07:01</td>
#     </tr>
#     <tr>
#       <td id="T_bb94d_row3_col0" class="data row3 col0" >bethel</td>
#       <td id="T_bb94d_row3_col1" class="data row3 col1" >41.37</td>
#       <td id="T_bb94d_row3_col2" class="data row3 col2" >-73.41</td>
#       <td id="T_bb94d_row3_col3" class="data row3 col3" >73.44° F</td>
#       <td id="T_bb94d_row3_col4" class="data row3 col4" >53%</td>
#       <td id="T_bb94d_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_bb94d_row3_col6" class="data row3 col6" >2.19</td>
#       <td id="T_bb94d_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_bb94d_row3_col8" class="data row3 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_bb94d_row4_col0" class="data row4 col0" >nuoro</td>
#       <td id="T_bb94d_row4_col1" class="data row4 col1" >40.32</td>
#       <td id="T_bb94d_row4_col2" class="data row4 col2" >9.33</td>
#       <td id="T_bb94d_row4_col3" class="data row4 col3" >62.17° F</td>
#       <td id="T_bb94d_row4_col4" class="data row4 col4" >86%</td>
#       <td id="T_bb94d_row4_col5" class="data row4 col5" >90%</td>
#       <td id="T_bb94d_row4_col6" class="data row4 col6" >3.62</td>
#       <td id="T_bb94d_row4_col7" class="data row4 col7" >IT</td>
#       <td id="T_bb94d_row4_col8" class="data row4 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_bb94d_row5_col0" class="data row5 col0" >utrik</td>
#       <td id="T_bb94d_row5_col1" class="data row5 col1" >11.23</td>
#       <td id="T_bb94d_row5_col2" class="data row5 col2" >169.85</td>
#       <td id="T_bb94d_row5_col3" class="data row5 col3" >82.76° F</td>
#       <td id="T_bb94d_row5_col4" class="data row5 col4" >78%</td>
#       <td id="T_bb94d_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_bb94d_row5_col6" class="data row5 col6" >12.08</td>
#       <td id="T_bb94d_row5_col7" class="data row5 col7" >MH</td>
#       <td id="T_bb94d_row5_col8" class="data row5 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_bb94d_row6_col0" class="data row6 col0" >albany</td>
#       <td id="T_bb94d_row6_col1" class="data row6 col1" >42.60</td>
#       <td id="T_bb94d_row6_col2" class="data row6 col2" >-73.97</td>
#       <td id="T_bb94d_row6_col3" class="data row6 col3" >73.71° F</td>
#       <td id="T_bb94d_row6_col4" class="data row6 col4" >51%</td>
#       <td id="T_bb94d_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_bb94d_row6_col6" class="data row6 col6" >1.99</td>
#       <td id="T_bb94d_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_bb94d_row6_col8" class="data row6 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_bb94d_row7

# %% [markdown]
# ## **Section 1.2: Scatter Plots w/Regression**

# %% [markdown]
# ### **Temperature Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1: Temperature Vs. Latitude (Scatter Plot)')

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.2.1.1: Temperature Vs. Latitude (Scatter Plot w/Regression)', 
         2, -48.0, 30.0)
# Out:
# r-value:     0.7791
# r-squared:   0.6069

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### Although this assignment is about linear regression, I notice that the independent variable, latitude, has a relationship with the dependent variable, temperature, just not a linear one.  With linear regression, we obtain a -0.1346 correlation; with quadratic regression, the correlation increases to 0.7879.  In practiice, analysts consider a 0.60-0.79 correlation to be strong.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.2.2: Humidity Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Cloudiness Vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.2.3: Cloudiness Vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (cityWeatherDataFrame \
             ['Latitude'],
         cityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.2.4: Wind Speed vs. Latitude (Scatter Plot)')

# %% [markdown]
# ### **City Weather Information Correlation Matrix**

# %%
frameDictionary \
    = {'Latitude': 
            cityWeatherDataFrame \
                ['Latitude'], 
       'Temperature': 
            cityWeatherDataFrame \
                ['Temperature'], 
       'Humidity': 
            cityWeatherDataFrame \
                ['Humidity'],
       'Cloudiness': 
            cityWeatherDataFrame \
                ['Cloudiness'],
       'Wind Speed':
            cityWeatherDataFrame \
                ['Wind Speed']}


function \
    .ReturnCorrelationTableStandardFormat \
        (pd \
             .DataFrame \
                 (frameDictionary),
         'Table 1.2.1: City Weather Correlation Matrix')
# Out:
# <style type="text/css">
# #T_ff638 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_ff638_row0_col0, #T_ff638_row0_col1, #T_ff638_row0_col2, #T_ff638_row0_col3, #T_ff638_row0_col4, #T_ff638_row1_col0, #T_ff638_row1_col1, #T_ff638_row1_col2, #T_ff638_row1_col3, #T_ff638_row1_col4, #T_ff638_row2_col0, #T_ff638_row2_col1, #T_ff638_row2_col2, #T_ff638_row2_col3, #T_ff638_row2_col4, #T_ff638_row3_col0, #T_ff638_row3_col1, #T_ff638_row3_col2, #T_ff638_row3_col3, #T_ff638_row3_col4, #T_ff638_row4_col0, #T_ff638_row4_col1, #T_ff638_row4_col2, #T_ff638_row4_col3, #T_ff638_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_ff638">
#   <caption>Table 1.2.1: City Weather Correlation Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff638_level0_col0" class="col_heading level0 col0" >Latitude</th>
#       <th id="T_ff638_level0_col1" class="col_heading level0 col1" >Temperature</th>
#       <th id="T_ff638_level0_col2" class="col_heading level0 col2" >Humidity</th>
#       <th id="T_ff638_level0_col3" class="col_heading level0 col3" >Cloudiness</th>
#       <th id="T_ff638_level0_col4" class="col_heading level0 col4" >Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff638_level0_row0" class="row_heading level0 row0" >Latitude</th>
#       <td id="T_ff638_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ff638_row0_col1" class="data row0 col1" >-0.092508</td>
#       <td id="T_ff638_row0_col2" class="data row0 col2" >0.051280</td>
#       <td id="T_ff638_row0_col3" class="data row0 col3" >-0.007358</td>
#       <td id="T_ff638_row0_col4" class="data row0 col4" >-0.097733</td>
#     </tr>
#     <tr>
#       <th id="T_ff638_level0_row1" class="row_heading level0 row1" >Temperature</th>
#       <td id="T_ff638_row1_col0" class="data row1 col0" >-0.092508</td>
#       <td id="T_ff638_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ff638_row1_col2" class="data row1 col2" >-0.433064</td>
#       <td id="T_ff638_row1_col3" class="data row1 col3" >-0.125360</td>
#       <td id="T_ff638_row1_col4" class="data row1 col4" >0.102196</td>
#     </tr>
#     <tr>
#       <th id="T_ff638_level0_row2" class="row_heading level0 row2" >Humidity</th>
#       <td id="T_ff638_row2_col0" class="data row2 col0" >0.051280</td>
#       <td id="T_ff638_row2_col1" class="data row2 col1" >-0.433064</td>
#       <td id="T_ff638_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ff638_row2_col3" class="data row2 col3" >0.359934</td>
#       <td id="T_ff638_row2_col4" class="data row2 col4" >-0.085151</td>
#     </tr>
#     <tr>
#       <th id="T_ff638_level0_row3" class="row_heading level0 row3" >Cloudiness</th>
#       <td id="T_ff638_row3_col0" class="data row3 col0" >-0.007358</td>
#       <td id="T_ff638_row3_col1" class="data row3 col1" >-0.125360</td>
#       <td id="T_ff638_row3_col2" class="data row3 col2" >0.359934</td>
#       <td id="T_ff638_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ff638_row3_col4" class="data row3 col4" >0.053423</td>
#     </tr>
#     <tr>
#       <th id="T_ff638_level0_row4" class="row_heading level0 row4" >Wind Speed</th>
#       <td id="T_ff638_row4_col0" class="data row4 col0" >-0.097733</td>
#       <td id="T_ff638_row4_col1" class="data row4 col1" >0.102196</td>
#       <td id="T_ff638_row4_col2" class="data row4 col2" >-0.085151</td>
#       <td id="T_ff638_row4_col3" class="data row4 col3" >0.053423</td>
#       <td id="T_ff638_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Discussion about correlation:** YOUR RESPONSE HERE

# %% [markdown]
# ## **Section 1.3: Hemisphere Scatter Plots with Linear Regression**

# %% [markdown]
# ### **Northern Hemisphere City Weather Information**

# %%
northernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              >= 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (northernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.1: City Weather Information (Northern Hemisphere)')
# Out:
# <style type="text/css">
# #T_1fa12 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_1fa12_row0_col0, #T_1fa12_row0_col1, #T_1fa12_row0_col2, #T_1fa12_row0_col3, #T_1fa12_row0_col4, #T_1fa12_row0_col5, #T_1fa12_row0_col6, #T_1fa12_row0_col7, #T_1fa12_row0_col8, #T_1fa12_row1_col0, #T_1fa12_row1_col1, #T_1fa12_row1_col2, #T_1fa12_row1_col3, #T_1fa12_row1_col4, #T_1fa12_row1_col6, #T_1fa12_row1_col7, #T_1fa12_row1_col8, #T_1fa12_row2_col0, #T_1fa12_row2_col1, #T_1fa12_row2_col2, #T_1fa12_row2_col3, #T_1fa12_row2_col4, #T_1fa12_row2_col5, #T_1fa12_row2_col6, #T_1fa12_row2_col7, #T_1fa12_row2_col8, #T_1fa12_row3_col0, #T_1fa12_row3_col1, #T_1fa12_row3_col2, #T_1fa12_row3_col3, #T_1fa12_row3_col4, #T_1fa12_row3_col6, #T_1fa12_row3_col7, #T_1fa12_row3_col8, #T_1fa12_row4_col0, #T_1fa12_row4_col1, #T_1fa12_row4_col2, #T_1fa12_row4_col3, #T_1fa12_row4_col4, #T_1fa12_row4_col7, #T_1fa12_row4_col8, #T_1fa12_row5_col0, #T_1fa12_row5_col1, #T_1fa12_row5_col2, #T_1fa12_row5_col3, #T_1fa12_row5_col4, #T_1fa12_row5_col5, #T_1fa12_row5_col6, #T_1fa12_row5_col7, #T_1fa12_row5_col8, #T_1fa12_row6_col0, #T_1fa12_row6_col1, #T_1fa12_row6_col2, #T_1fa12_row6_col6, #T_1fa12_row6_col7, #T_1fa12_row6_col8, #T_1fa12_row7_col0, #T_1fa12_row7_col1, #T_1fa12_row7_col2, #T_1fa12_row7_col3, #T_1fa12_row7_col4, #T_1fa12_row7_col6, #T_1fa12_row7_col7, #T_1fa12_row7_col8, #T_1fa12_row8_col0, #T_1fa12_row8_col1, #T_1fa12_row8_col2, #T_1fa12_row8_col3, #T_1fa12_row8_col4, #T_1fa12_row8_col5, #T_1fa12_row8_col6, #T_1fa12_row8_col7, #T_1fa12_row8_col8, #T_1fa12_row9_col0, #T_1fa12_row9_col1, #T_1fa12_row9_col2, #T_1fa12_row9_col7, #T_1fa12_row9_col8, #T_1fa12_row10_col0, #T_1fa12_row10_col1, #T_1fa12_row10_col2, #T_1fa12_row10_col3, #T_1fa12_row10_col4, #T_1fa12_row10_col5, #T_1fa12_row10_col6, #T_1fa12_row10_col7, #T_1fa12_row10_col8, #T_1fa12_row11_col0, #T_1fa12_row11_col1, #T_1fa12_row11_col2, #T_1fa12_row11_col3, #T_1fa12_row11_col4, #T_1fa12_row11_col6, #T_1fa12_row11_col7, #T_1fa12_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_1fa12_row1_col5, #T_1fa12_row4_col5, #T_1fa12_row4_col6, #T_1fa12_row6_col3, #T_1fa12_row7_col5, #T_1fa12_row9_col4, #T_1fa12_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_1fa12_row3_col5, #T_1fa12_row6_col4, #T_1fa12_row6_col5, #T_1fa12_row9_col3, #T_1fa12_row9_col6, #T_1fa12_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_1fa12">
#   <caption>Table: 1.3.1: City Weather Information (Northern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_1fa12_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_1fa12_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_1fa12_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_1fa12_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_1fa12_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_1fa12_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_1fa12_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_1fa12_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_1fa12_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1fa12_row0_col0" class="data row0 col0" >coahuayana de hidalgo</td>
#       <td id="T_1fa12_row0_col1" class="data row0 col1" >18.70</td>
#       <td id="T_1fa12_row0_col2" class="data row0 col2" >-103.66</td>
#       <td id="T_1fa12_row0_col3" class="data row0 col3" >90.52° F</td>
#       <td id="T_1fa12_row0_col4" class="data row0 col4" >63%</td>
#       <td id="T_1fa12_row0_col5" class="data row0 col5" >58%</td>
#       <td id="T_1fa12_row0_col6" class="data row0 col6" >5.32</td>
#       <td id="T_1fa12_row0_col7" class="data row0 col7" >MX</td>
#       <td id="T_1fa12_row0_col8" class="data row0 col8" >2023-09-01 12:10:41</td>
#     </tr>
#     <tr>
#       <td id="T_1fa12_row1_col0" class="data row1 col0" >bethel</td>
#       <td id="T_1fa12_row1_col1" class="data row1 col1" >41.37</td>
#       <td id="T_1fa12_row1_col2" class="data row1 col2" >-73.41</td>
#       <td id="T_1fa12_row1_col3" class="data row1 col3" >73.44° F</td>
#       <td id="T_1fa12_row1_col4" class="data row1 col4" >53%</td>
#       <td id="T_1fa12_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_1fa12_row1_col6" class="data row1 col6" >2.19</td>
#       <td id="T_1fa12_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_1fa12_row1_col8" class="data row1 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_1fa12_row2_col0" class="data row2 col0" >nuoro</td>
#       <td id="T_1fa12_row2_col1" class="data row2 col1" >40.32</td>
#       <td id="T_1fa12_row2_col2" class="data row2 col2" >9.33</td>
#       <td id="T_1fa12_row2_col3" class="data row2 col3" >62.17° F</td>
#       <td id="T_1fa12_row2_col4" class="data row2 col4" >86%</td>
#       <td id="T_1fa12_row2_col5" class="data row2 col5" >90%</td>
#       <td id="T_1fa12_row2_col6" class="data row2 col6" >3.62</td>
#       <td id="T_1fa12_row2_col7" class="data row2 col7" >IT</td>
#       <td id="T_1fa12_row2_col8" class="data row2 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_1fa12_row3_col0" class="data row3 col0" >utrik</td>
#       <td id="T_1fa12_row3_col1" class="data row3 col1" >11.23</td>
#       <td id="T_1fa12_row3_col2" class="data row3 col2" >169.85</td>
#       <td id="T_1fa12_row3_col3" class="data row3 col3" >82.76° F</td>
#       <td id="T_1fa12_row3_col4" class="data row3 col4" >78%</td>
#       <td id="T_1fa12_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_1fa12_row3_col6" class="data row3 col6" >12.08</td>
#       <td id="T_1fa12_row3_col7" class="data row3 col7" >MH</td>
#       <td id="T_1fa12_row3_col8" class="data row3 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_1fa12_row4_col0" class="data row4 col0" >albany</td>
#       <td id="T_1fa12_row4_col1" class="data row4 col1" >42.60</td>
#       <td id="T_1fa12_row4_col2" class="data row4 col2" >-73.97</td>
#       <td id="T_1fa12_row4_col3" class="data row4 col3" >73.71° F</td>
#       <td id="T_1fa12_row4_col4" class="data row4 col4" >51%</td>
#       <td id="T_1fa12_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_1fa12_row4_col6" class="data row4 col6" >1.99</td>
#       <td id="T_1fa12_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_1fa12_row4_col8" class="data row4 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_1fa12_row5_col0" class="data row5 col0" >st. john's</td>
#       <td id="T_1fa12_row5_col1" class="data row5 col1" >47.56</td>
#       <td id="T_1fa12_row5_col2" class="data row5 col2" >-52.71</td>
#       <td id="T_1fa12_row5_col3" class="data row5 col3" >55.87° F</td>
#       <td id="T_1fa12_row5_col4" class="data row5 col4" >63%</td>
#       <td id="T_1fa12_row5_col5" class="data row5 col5" >75%</td>
#       <td id="T_1fa12_row5_col6" class="data row5 col6" >10.36</td>
#       <td id="T_1fa12_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_1fa12_row5_col8" class="data row5 col8" >2023-09-01 12:06:08</td>
#     </tr>
#     <tr>
#       <td id="T_1fa12_row6_col0" class="data row6 col0" >ust-nera</td>
#       <td id="T_1fa12_row6_col1" class="data row6 col1" >64.57</td>
#       <td id="T_1fa12_row6_col2" class="data row6 col2" >143.20</td>
#       <td id="T_1fa12_row6_col3" class="data row6 col3" >30.04° F</td>
#       <td id="T_1fa12_row6_col4" class="data row6 col4" >96%</td>
#       <td id="T_1fa12_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_1fa12_row6_col6" class="data row6 col6" >9.31</td>
#       <td id="T_1fa12_row6_col7" class="data row6 col7" >RU</td>
#       <td id="T_1fa12_row6_col8" class="data row6 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_1f

# %% [markdown]
# ### **Southern Hemisphere City Weather Information**

# %%
southernCityWeatherDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame
                  ['Latitude'] 
              < 0.0), :]


log_function \
    .DebugReturnObjectWriteObject \
        (southernCityWeatherDataFrame)

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (northernCityWeatherDataFrame.head(12),
         'Table: 1.3.2: City Weather Information (Southern Hemisphere)')
# Out:
# <style type="text/css">
# #T_ba5da caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_ba5da_row0_col0, #T_ba5da_row0_col1, #T_ba5da_row0_col2, #T_ba5da_row0_col3, #T_ba5da_row0_col4, #T_ba5da_row0_col5, #T_ba5da_row0_col6, #T_ba5da_row0_col7, #T_ba5da_row0_col8, #T_ba5da_row1_col0, #T_ba5da_row1_col1, #T_ba5da_row1_col2, #T_ba5da_row1_col3, #T_ba5da_row1_col4, #T_ba5da_row1_col6, #T_ba5da_row1_col7, #T_ba5da_row1_col8, #T_ba5da_row2_col0, #T_ba5da_row2_col1, #T_ba5da_row2_col2, #T_ba5da_row2_col3, #T_ba5da_row2_col4, #T_ba5da_row2_col5, #T_ba5da_row2_col6, #T_ba5da_row2_col7, #T_ba5da_row2_col8, #T_ba5da_row3_col0, #T_ba5da_row3_col1, #T_ba5da_row3_col2, #T_ba5da_row3_col3, #T_ba5da_row3_col4, #T_ba5da_row3_col6, #T_ba5da_row3_col7, #T_ba5da_row3_col8, #T_ba5da_row4_col0, #T_ba5da_row4_col1, #T_ba5da_row4_col2, #T_ba5da_row4_col3, #T_ba5da_row4_col4, #T_ba5da_row4_col7, #T_ba5da_row4_col8, #T_ba5da_row5_col0, #T_ba5da_row5_col1, #T_ba5da_row5_col2, #T_ba5da_row5_col3, #T_ba5da_row5_col4, #T_ba5da_row5_col5, #T_ba5da_row5_col6, #T_ba5da_row5_col7, #T_ba5da_row5_col8, #T_ba5da_row6_col0, #T_ba5da_row6_col1, #T_ba5da_row6_col2, #T_ba5da_row6_col6, #T_ba5da_row6_col7, #T_ba5da_row6_col8, #T_ba5da_row7_col0, #T_ba5da_row7_col1, #T_ba5da_row7_col2, #T_ba5da_row7_col3, #T_ba5da_row7_col4, #T_ba5da_row7_col6, #T_ba5da_row7_col7, #T_ba5da_row7_col8, #T_ba5da_row8_col0, #T_ba5da_row8_col1, #T_ba5da_row8_col2, #T_ba5da_row8_col3, #T_ba5da_row8_col4, #T_ba5da_row8_col5, #T_ba5da_row8_col6, #T_ba5da_row8_col7, #T_ba5da_row8_col8, #T_ba5da_row9_col0, #T_ba5da_row9_col1, #T_ba5da_row9_col2, #T_ba5da_row9_col7, #T_ba5da_row9_col8, #T_ba5da_row10_col0, #T_ba5da_row10_col1, #T_ba5da_row10_col2, #T_ba5da_row10_col3, #T_ba5da_row10_col4, #T_ba5da_row10_col5, #T_ba5da_row10_col6, #T_ba5da_row10_col7, #T_ba5da_row10_col8, #T_ba5da_row11_col0, #T_ba5da_row11_col1, #T_ba5da_row11_col2, #T_ba5da_row11_col3, #T_ba5da_row11_col4, #T_ba5da_row11_col6, #T_ba5da_row11_col7, #T_ba5da_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_ba5da_row1_col5, #T_ba5da_row4_col5, #T_ba5da_row4_col6, #T_ba5da_row6_col3, #T_ba5da_row7_col5, #T_ba5da_row9_col4, #T_ba5da_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_ba5da_row3_col5, #T_ba5da_row6_col4, #T_ba5da_row6_col5, #T_ba5da_row9_col3, #T_ba5da_row9_col6, #T_ba5da_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_ba5da">
#   <caption>Table: 1.3.2: City Weather Information (Southern Hemisphere)</caption>
#   <thead>
#     <tr>
#       <th id="T_ba5da_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_ba5da_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_ba5da_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_ba5da_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_ba5da_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_ba5da_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_ba5da_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_ba5da_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_ba5da_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ba5da_row0_col0" class="data row0 col0" >coahuayana de hidalgo</td>
#       <td id="T_ba5da_row0_col1" class="data row0 col1" >18.70</td>
#       <td id="T_ba5da_row0_col2" class="data row0 col2" >-103.66</td>
#       <td id="T_ba5da_row0_col3" class="data row0 col3" >90.52° F</td>
#       <td id="T_ba5da_row0_col4" class="data row0 col4" >63%</td>
#       <td id="T_ba5da_row0_col5" class="data row0 col5" >58%</td>
#       <td id="T_ba5da_row0_col6" class="data row0 col6" >5.32</td>
#       <td id="T_ba5da_row0_col7" class="data row0 col7" >MX</td>
#       <td id="T_ba5da_row0_col8" class="data row0 col8" >2023-09-01 12:10:41</td>
#     </tr>
#     <tr>
#       <td id="T_ba5da_row1_col0" class="data row1 col0" >bethel</td>
#       <td id="T_ba5da_row1_col1" class="data row1 col1" >41.37</td>
#       <td id="T_ba5da_row1_col2" class="data row1 col2" >-73.41</td>
#       <td id="T_ba5da_row1_col3" class="data row1 col3" >73.44° F</td>
#       <td id="T_ba5da_row1_col4" class="data row1 col4" >53%</td>
#       <td id="T_ba5da_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_ba5da_row1_col6" class="data row1 col6" >2.19</td>
#       <td id="T_ba5da_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_ba5da_row1_col8" class="data row1 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_ba5da_row2_col0" class="data row2 col0" >nuoro</td>
#       <td id="T_ba5da_row2_col1" class="data row2 col1" >40.32</td>
#       <td id="T_ba5da_row2_col2" class="data row2 col2" >9.33</td>
#       <td id="T_ba5da_row2_col3" class="data row2 col3" >62.17° F</td>
#       <td id="T_ba5da_row2_col4" class="data row2 col4" >86%</td>
#       <td id="T_ba5da_row2_col5" class="data row2 col5" >90%</td>
#       <td id="T_ba5da_row2_col6" class="data row2 col6" >3.62</td>
#       <td id="T_ba5da_row2_col7" class="data row2 col7" >IT</td>
#       <td id="T_ba5da_row2_col8" class="data row2 col8" >2023-09-01 12:10:42</td>
#     </tr>
#     <tr>
#       <td id="T_ba5da_row3_col0" class="data row3 col0" >utrik</td>
#       <td id="T_ba5da_row3_col1" class="data row3 col1" >11.23</td>
#       <td id="T_ba5da_row3_col2" class="data row3 col2" >169.85</td>
#       <td id="T_ba5da_row3_col3" class="data row3 col3" >82.76° F</td>
#       <td id="T_ba5da_row3_col4" class="data row3 col4" >78%</td>
#       <td id="T_ba5da_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_ba5da_row3_col6" class="data row3 col6" >12.08</td>
#       <td id="T_ba5da_row3_col7" class="data row3 col7" >MH</td>
#       <td id="T_ba5da_row3_col8" class="data row3 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_ba5da_row4_col0" class="data row4 col0" >albany</td>
#       <td id="T_ba5da_row4_col1" class="data row4 col1" >42.60</td>
#       <td id="T_ba5da_row4_col2" class="data row4 col2" >-73.97</td>
#       <td id="T_ba5da_row4_col3" class="data row4 col3" >73.71° F</td>
#       <td id="T_ba5da_row4_col4" class="data row4 col4" >51%</td>
#       <td id="T_ba5da_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_ba5da_row4_col6" class="data row4 col6" >1.99</td>
#       <td id="T_ba5da_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_ba5da_row4_col8" class="data row4 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_ba5da_row5_col0" class="data row5 col0" >st. john's</td>
#       <td id="T_ba5da_row5_col1" class="data row5 col1" >47.56</td>
#       <td id="T_ba5da_row5_col2" class="data row5 col2" >-52.71</td>
#       <td id="T_ba5da_row5_col3" class="data row5 col3" >55.87° F</td>
#       <td id="T_ba5da_row5_col4" class="data row5 col4" >63%</td>
#       <td id="T_ba5da_row5_col5" class="data row5 col5" >75%</td>
#       <td id="T_ba5da_row5_col6" class="data row5 col6" >10.36</td>
#       <td id="T_ba5da_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_ba5da_row5_col8" class="data row5 col8" >2023-09-01 12:06:08</td>
#     </tr>
#     <tr>
#       <td id="T_ba5da_row6_col0" class="data row6 col0" >ust-nera</td>
#       <td id="T_ba5da_row6_col1" class="data row6 col1" >64.57</td>
#       <td id="T_ba5da_row6_col2" class="data row6 col2" >143.20</td>
#       <td id="T_ba5da_row6_col3" class="data row6 col3" >30.04° F</td>
#       <td id="T_ba5da_row6_col4" class="data row6 col4" >96%</td>
#       <td id="T_ba5da_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_ba5da_row6_col6" class="data row6 col6" >9.31</td>
#       <td id="T_ba5da_row6_col7" class="data row6 col7" >RU</td>
#       <td id="T_ba5da_row6_col8" class="data row6 col8" >2023-09-01 12:10:43</td>
#     </tr>
#     <tr>
#       <td id="T_ba

# %% [markdown]
# ### **Temperature vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.1: Temperature vs. Latitude (Northern Hemisphere)',
         1, 2.0, 45.0)
# Out:
# r-value:     -0.7119
# r-squared:   0.5068

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Temperature'],
         'Figure 1.3.2: Temperature vs. Latitude (Southern Hemisphere)',
         1, -55.0, 85.0)
# Out:
# r-value:     0.7181
# r-squared:   0.5157

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### From the results of the linear regression, in the northern hemisphere, the latitude is negatively correlated with temperature; this negative correlation tells us that the two variables move in opposite directions: as latitude increases, the temperature drops, and vice versa.  In the southern hemisphers, the latitude is positively correlated with temperature: this positive correlation tells us that the two variables move in the same direction: as latitude increases, the temperature increases.  What does this mean?  The maximum temperature is hottest at the equator and cools down as we move towards either the North Pole or the South Pole.  On top of that, while correlation tells us there is a relationship between two variables, it does not indicate cause and effect.

# %% [markdown]
# ### **Humidity vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.3: Humidity vs. Latitude (Northern Hemisphere)',
         1, 0.0, 18.0)
# Out:
# r-value:     0.0091
# r-squared:   0.0001

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Humidity'],
         'Figure 1.3.4: Humidity vs. Latitude (Southern Hemisphere)',
         1, -55.0, 25.0)
# Out:
# r-value:     -0.0322
# r-squared:   0.0010

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and humidity in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Cloudiness vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.5: Cloudiness vs. Latitude (Northern Hemisphere)',
         1, 16.0, 62.0)
# Out:
# r-value:     -0.0887
# r-squared:   0.0079

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Cloudiness'],
         'Figure 1.3.6: Cloudiness vs. Latitude (Southern Hemisphere)',
         1, -45.0, 65.0)
# Out:
# r-value:     -0.1554
# r-squared:   0.0241

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and cloudiness in either hemisphere.

# %% [markdown]
# ### **Northern Hemisphere: Wind Speed vs. Latitude**

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (northernCityWeatherDataFrame \
             ['Latitude'],
         northernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.7: Wind Speed vs. Latitude (Northern Hemisphere)',
         1, 2.0, 22.0)
# Out:
# r-value:     -0.0591
# r-squared:   0.0035

# %%
subroutine \
    .DisplayMatplotlibScatterPlotFromXYSeries \
        (southernCityWeatherDataFrame \
             ['Latitude'],
         southernCityWeatherDataFrame \
             ['Wind Speed'],
         'Figure 1.3.8: Wind Speed vs. Latitude (Southern Hemisphere)',
         1, -55.0, 24.0)
# Out:
# r-value:     -0.1149
# r-squared:   0.0132

# %% [markdown]
# ## **Discussion about the linear relationship:**
# ### According to these scatter plots and regression lines, there is no linear relationship between latitude and wind speed in either hemisphere.

# %%
log_subroutine \
    .EndProgramExecution()
# Out:
# Program execution ends at 09/01/2023 12:12:57.
