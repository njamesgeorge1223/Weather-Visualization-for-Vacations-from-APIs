# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function
import VacationPySubRoutines as local_subroutine

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


local_subroutine.SetVacationTemperatureRange(70, 95)

local_subroutine.SetVacationHumidityRange(35, 65)

local_subroutine.SetVacationCloudinessRange(0, 10)

local_subroutine.SetVacationWindPSpeedRange(0, 10)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Vacation Data Acquisition**

# %% [markdown]
# ## **1.1: Data Import from CSV File**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant \
                 .WEATHER_DATA_FILE_PATH,
             local_constant \
                 .WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ## **1.2: Display City Weather Data Set**

# %%
captionString \
    = 'Table: 1.2: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_2d56f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_2d56f_row0_col0, #T_2d56f_row0_col1, #T_2d56f_row0_col2, #T_2d56f_row0_col4, #T_2d56f_row0_col5, #T_2d56f_row0_col6, #T_2d56f_row0_col7, #T_2d56f_row0_col8, #T_2d56f_row1_col0, #T_2d56f_row1_col1, #T_2d56f_row1_col2, #T_2d56f_row1_col3, #T_2d56f_row1_col4, #T_2d56f_row1_col6, #T_2d56f_row1_col7, #T_2d56f_row1_col8, #T_2d56f_row2_col0, #T_2d56f_row2_col1, #T_2d56f_row2_col2, #T_2d56f_row2_col3, #T_2d56f_row2_col4, #T_2d56f_row2_col6, #T_2d56f_row2_col7, #T_2d56f_row2_col8, #T_2d56f_row3_col0, #T_2d56f_row3_col1, #T_2d56f_row3_col2, #T_2d56f_row3_col3, #T_2d56f_row3_col4, #T_2d56f_row3_col6, #T_2d56f_row3_col7, #T_2d56f_row3_col8, #T_2d56f_row4_col0, #T_2d56f_row4_col1, #T_2d56f_row4_col2, #T_2d56f_row4_col4, #T_2d56f_row4_col5, #T_2d56f_row4_col6, #T_2d56f_row4_col7, #T_2d56f_row4_col8, #T_2d56f_row5_col0, #T_2d56f_row5_col1, #T_2d56f_row5_col2, #T_2d56f_row5_col3, #T_2d56f_row5_col4, #T_2d56f_row5_col6, #T_2d56f_row5_col7, #T_2d56f_row5_col8, #T_2d56f_row6_col0, #T_2d56f_row6_col1, #T_2d56f_row6_col2, #T_2d56f_row6_col3, #T_2d56f_row6_col5, #T_2d56f_row6_col7, #T_2d56f_row6_col8, #T_2d56f_row7_col0, #T_2d56f_row7_col1, #T_2d56f_row7_col2, #T_2d56f_row7_col3, #T_2d56f_row7_col4, #T_2d56f_row7_col6, #T_2d56f_row7_col7, #T_2d56f_row7_col8, #T_2d56f_row8_col0, #T_2d56f_row8_col1, #T_2d56f_row8_col2, #T_2d56f_row8_col3, #T_2d56f_row8_col4, #T_2d56f_row8_col6, #T_2d56f_row8_col7, #T_2d56f_row8_col8, #T_2d56f_row9_col0, #T_2d56f_row9_col1, #T_2d56f_row9_col2, #T_2d56f_row9_col3, #T_2d56f_row9_col4, #T_2d56f_row9_col7, #T_2d56f_row9_col8, #T_2d56f_row10_col0, #T_2d56f_row10_col1, #T_2d56f_row10_col2, #T_2d56f_row10_col3, #T_2d56f_row10_col4, #T_2d56f_row10_col6, #T_2d56f_row10_col7, #T_2d56f_row10_col8, #T_2d56f_row11_col0, #T_2d56f_row11_col1, #T_2d56f_row11_col2, #T_2d56f_row11_col3, #T_2d56f_row11_col6, #T_2d56f_row11_col7, #T_2d56f_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_2d56f_row0_col3, #T_2d56f_row2_col5, #T_2d56f_row5_col5, #T_2d56f_row6_col4, #T_2d56f_row6_col6, #T_2d56f_row7_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_2d56f_row1_col5, #T_2d56f_row3_col5, #T_2d56f_row4_col3, #T_2d56f_row8_col5, #T_2d56f_row9_col5, #T_2d56f_row9_col6, #T_2d56f_row10_col5, #T_2d56f_row11_col4, #T_2d56f_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_2d56f">
#   <caption>Table: 1.2: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_2d56f_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_2d56f_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_2d56f_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_2d56f_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_2d56f_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_2d56f_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_2d56f_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_2d56f_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_2d56f_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2d56f_row0_col0" class="data row0 col0" >grytviken</td>
#       <td id="T_2d56f_row0_col1" class="data row0 col1" >-54.28</td>
#       <td id="T_2d56f_row0_col2" class="data row0 col2" >-36.51</td>
#       <td id="T_2d56f_row0_col3" class="data row0 col3" >39.06° F</td>
#       <td id="T_2d56f_row0_col4" class="data row0 col4" >72%</td>
#       <td id="T_2d56f_row0_col5" class="data row0 col5" >3%</td>
#       <td id="T_2d56f_row0_col6" class="data row0 col6" >4.63</td>
#       <td id="T_2d56f_row0_col7" class="data row0 col7" >GS</td>
#       <td id="T_2d56f_row0_col8" class="data row0 col8" >2023-11-07 19:00:59</td>
#     </tr>
#     <tr>
#       <td id="T_2d56f_row1_col0" class="data row1 col0" >wanning</td>
#       <td id="T_2d56f_row1_col1" class="data row1 col1" >18.80</td>
#       <td id="T_2d56f_row1_col2" class="data row1 col2" >110.40</td>
#       <td id="T_2d56f_row1_col3" class="data row1 col3" >78.21° F</td>
#       <td id="T_2d56f_row1_col4" class="data row1 col4" >89%</td>
#       <td id="T_2d56f_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_2d56f_row1_col6" class="data row1 col6" >6.60</td>
#       <td id="T_2d56f_row1_col7" class="data row1 col7" >CN</td>
#       <td id="T_2d56f_row1_col8" class="data row1 col8" >2023-11-07 19:06:23</td>
#     </tr>
#     <tr>
#       <td id="T_2d56f_row2_col0" class="data row2 col0" >bethel</td>
#       <td id="T_2d56f_row2_col1" class="data row2 col1" >41.37</td>
#       <td id="T_2d56f_row2_col2" class="data row2 col2" >-73.41</td>
#       <td id="T_2d56f_row2_col3" class="data row2 col3" >53.69° F</td>
#       <td id="T_2d56f_row2_col4" class="data row2 col4" >56%</td>
#       <td id="T_2d56f_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_2d56f_row2_col6" class="data row2 col6" >10.36</td>
#       <td id="T_2d56f_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_2d56f_row2_col8" class="data row2 col8" >2023-11-07 19:05:38</td>
#     </tr>
#     <tr>
#       <td id="T_2d56f_row3_col0" class="data row3 col0" >kodiak</td>
#       <td id="T_2d56f_row3_col1" class="data row3 col1" >57.79</td>
#       <td id="T_2d56f_row3_col2" class="data row3 col2" >-152.41</td>
#       <td id="T_2d56f_row3_col3" class="data row3 col3" >42.31° F</td>
#       <td id="T_2d56f_row3_col4" class="data row3 col4" >87%</td>
#       <td id="T_2d56f_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_2d56f_row3_col6" class="data row3 col6" >16.11</td>
#       <td id="T_2d56f_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_2d56f_row3_col8" class="data row3 col8" >2023-11-07 19:01:01</td>
#     </tr>
#     <tr>
#       <td id="T_2d56f_row4_col0" class="data row4 col0" >kingston</td>
#       <td id="T_2d56f_row4_col1" class="data row4 col1" >18.00</td>
#       <td id="T_2d56f_row4_col2" class="data row4 col2" >-76.79</td>
#       <td id="T_2d56f_row4_col3" class="data row4 col3" >80.58° F</td>
#       <td id="T_2d56f_row4_col4" class="data row4 col4" >89%</td>
#       <td id="T_2d56f_row4_col5" class="data row4 col5" >20%</td>
#       <td id="T_2d56f_row4_col6" class="data row4 col6" >8.05</td>
#       <td id="T_2d56f_row4_col7" class="data row4 col7" >JM</td>
#       <td id="T_2d56f_row4_col8" class="data row4 col8" >2023-11-07 19:06:24</td>
#     </tr>
#     <tr>
#       <td id="T_2d56f_row5_col0" class="data row5 col0" >fasa</td>
#       <td id="T_2d56f_row5_col1" class="data row5 col1" >28.94</td>
#       <td id="T_2d56f_row5_col2" class="data row5 col2" >53.65</td>
#       <td id="T_2d56f_row5_col3" class="data row5 col3" >45.64° F</td>
#       <td id="T_2d56f_row5_col4" class="data row5 col4" >66%</td>
#       <td id="T_2d56f_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_2d56f_row5_col6" class="data row5 col6" >4.61</td>
#       <td id="T_2d56f_row5_col7" class="data row5 col7" >IR</td>
#       <td id="T_2d56f_row5_col8" class="data row5 col8" >2023-11-07 19:06:24</td>
#     </tr>
#     <tr>
#       <td id="T_2d56f_row6_col0" class="data row6 col0" >sehwan</td>
#       <td id="T_2d56f_row6_col1" class="data row6 col1" >26.43</td>
#       <td id="T_2d56f_row6_col2" class="data row6 col2" >67.86</td>
#       <td id="T_2d56f_row6_col3" class="data row6 col3" >77.09° F</td>
#       <td id="T_2d56f_row6_col4" class="data row6 col4" >40%</td>
#       <td id="T_2d56f_row6_col5" class="data row6 col5" >7%</td>
#       <td id="T_2d56f_row6_col6" class="data row6 col6" >1.50</td>
#       <td id="T_2d56f_row6_col7" class="data row6 col7" >PK</td>
#       <td id="T_2d56f_row6_col8" class="data row6 col8" >2023-11-07 19:06:24</td>
#     </tr>
#     <tr>
#       <td id="T_2d56f_row7_col0" class="data row7 col0" >c

# %% [markdown]
# ## **1.3: Display City Weather Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.3: City Weather Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Desired Weather Locations**

# %% [markdown]
# ## **2.1: Establish Desired Weather Conditions for Vacation Locations**

# %%
vacationDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame['Temperature'] \
                >= local_constant \
                      .weatherConditionsDictionary \
                          ['temperatureIntegerList'][0]) \
                 & (cityWeatherDataFrame['Temperature'] \
                        <= local_constant \
                              .weatherConditionsDictionary \
                                  ['temperatureIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Humidity'] \
                      >= local_constant \
                          .weatherConditionsDictionary \
                              ['humidityIntegerList'][0]) \
                  & (vacationDataFrame['Humidity'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                  ['humidityIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Cloudiness'] \
                      >= local_constant \
                            .weatherConditionsDictionary \
                                ['cloudinessIntegerList'][0]) \
                  & (vacationDataFrame['Cloudiness'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                    ['cloudinessIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Wind Speed'] \
                      >= local_constant \
                            .weatherConditionsDictionary \
                                ['windSpeedIntegerList'][0]) 
                  & (vacationDataFrame['Wind Speed'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                    ['windSpeedIntegerList'][1]), :]


log_function \
    .DebugReturnObjectWriteObject \
        (vacationDataFrame)

# %% [markdown]
# ## **2.2: Clean Vacation Data Set**

# %%
vacationDataFrame \
        .dropna \
            (inplace = True)

vacationDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (vacationDataFrame)

# %% [markdown]
# ## **2.3: Display Vacation Data Set**

# %%
captionString \
    = 'Table: 2.3: Vacation Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (vacationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_b7041 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b7041_row0_col0, #T_b7041_row0_col1, #T_b7041_row0_col2, #T_b7041_row0_col3, #T_b7041_row0_col4, #T_b7041_row0_col5, #T_b7041_row0_col6, #T_b7041_row0_col7, #T_b7041_row0_col8, #T_b7041_row1_col0, #T_b7041_row1_col1, #T_b7041_row1_col2, #T_b7041_row1_col3, #T_b7041_row1_col4, #T_b7041_row1_col6, #T_b7041_row1_col7, #T_b7041_row1_col8, #T_b7041_row2_col0, #T_b7041_row2_col1, #T_b7041_row2_col2, #T_b7041_row2_col4, #T_b7041_row2_col5, #T_b7041_row2_col6, #T_b7041_row2_col7, #T_b7041_row2_col8, #T_b7041_row3_col0, #T_b7041_row3_col1, #T_b7041_row3_col2, #T_b7041_row3_col3, #T_b7041_row3_col7, #T_b7041_row3_col8, #T_b7041_row4_col0, #T_b7041_row4_col1, #T_b7041_row4_col2, #T_b7041_row4_col3, #T_b7041_row4_col4, #T_b7041_row4_col5, #T_b7041_row4_col6, #T_b7041_row4_col7, #T_b7041_row4_col8, #T_b7041_row5_col0, #T_b7041_row5_col1, #T_b7041_row5_col2, #T_b7041_row5_col3, #T_b7041_row5_col4, #T_b7041_row5_col6, #T_b7041_row5_col7, #T_b7041_row5_col8, #T_b7041_row6_col0, #T_b7041_row6_col1, #T_b7041_row6_col2, #T_b7041_row6_col3, #T_b7041_row6_col4, #T_b7041_row6_col5, #T_b7041_row6_col6, #T_b7041_row6_col7, #T_b7041_row6_col8, #T_b7041_row7_col0, #T_b7041_row7_col1, #T_b7041_row7_col2, #T_b7041_row7_col3, #T_b7041_row7_col4, #T_b7041_row7_col6, #T_b7041_row7_col7, #T_b7041_row7_col8, #T_b7041_row8_col0, #T_b7041_row8_col1, #T_b7041_row8_col2, #T_b7041_row8_col3, #T_b7041_row8_col7, #T_b7041_row8_col8, #T_b7041_row9_col0, #T_b7041_row9_col1, #T_b7041_row9_col2, #T_b7041_row9_col4, #T_b7041_row9_col6, #T_b7041_row9_col7, #T_b7041_row9_col8, #T_b7041_row10_col0, #T_b7041_row10_col1, #T_b7041_row10_col2, #T_b7041_row10_col3, #T_b7041_row10_col4, #T_b7041_row10_col5, #T_b7041_row10_col6, #T_b7041_row10_col7, #T_b7041_row10_col8, #T_b7041_row11_col0, #T_b7041_row11_col1, #T_b7041_row11_col2, #T_b7041_row11_col3, #T_b7041_row11_col4, #T_b7041_row11_col6, #T_b7041_row11_col7, #T_b7041_row11_col8, #T_b7041_row12_col0, #T_b7041_row12_col1, #T_b7041_row12_col2, #T_b7041_row12_col3, #T_b7041_row12_col4, #T_b7041_row12_col5, #T_b7041_row12_col6, #T_b7041_row12_col7, #T_b7041_row12_col8, #T_b7041_row13_col0, #T_b7041_row13_col1, #T_b7041_row13_col2, #T_b7041_row13_col3, #T_b7041_row13_col4, #T_b7041_row13_col6, #T_b7041_row13_col7, #T_b7041_row13_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_b7041_row1_col5, #T_b7041_row3_col4, #T_b7041_row3_col6, #T_b7041_row5_col5, #T_b7041_row7_col5, #T_b7041_row8_col5, #T_b7041_row9_col3, #T_b7041_row9_col5, #T_b7041_row11_col5, #T_b7041_row13_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_b7041_row2_col3, #T_b7041_row3_col5, #T_b7041_row8_col4, #T_b7041_row8_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_b7041">
#   <caption>Table: 2.3: Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_b7041_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_b7041_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_b7041_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_b7041_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_b7041_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_b7041_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_b7041_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_b7041_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_b7041_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b7041_row0_col0" class="data row0 col0" >sehwan</td>
#       <td id="T_b7041_row0_col1" class="data row0 col1" >26.43</td>
#       <td id="T_b7041_row0_col2" class="data row0 col2" >67.86</td>
#       <td id="T_b7041_row0_col3" class="data row0 col3" >77.09° F</td>
#       <td id="T_b7041_row0_col4" class="data row0 col4" >40%</td>
#       <td id="T_b7041_row0_col5" class="data row0 col5" >7%</td>
#       <td id="T_b7041_row0_col6" class="data row0 col6" >1.50</td>
#       <td id="T_b7041_row0_col7" class="data row0 col7" >PK</td>
#       <td id="T_b7041_row0_col8" class="data row0 col8" >2023-11-07 19:06:24</td>
#     </tr>
#     <tr>
#       <td id="T_b7041_row1_col0" class="data row1 col0" >ad dabbah</td>
#       <td id="T_b7041_row1_col1" class="data row1 col1" >18.05</td>
#       <td id="T_b7041_row1_col2" class="data row1 col2" >30.95</td>
#       <td id="T_b7041_row1_col3" class="data row1 col3" >76.32° F</td>
#       <td id="T_b7041_row1_col4" class="data row1 col4" >52%</td>
#       <td id="T_b7041_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_b7041_row1_col6" class="data row1 col6" >8.28</td>
#       <td id="T_b7041_row1_col7" class="data row1 col7" >SD</td>
#       <td id="T_b7041_row1_col8" class="data row1 col8" >2023-11-07 19:06:44</td>
#     </tr>
#     <tr>
#       <td id="T_b7041_row2_col0" class="data row2 col0" >katabu</td>
#       <td id="T_b7041_row2_col1" class="data row2 col1" >-4.93</td>
#       <td id="T_b7041_row2_col2" class="data row2 col2" >122.52</td>
#       <td id="T_b7041_row2_col3" class="data row2 col3" >92.10° F</td>
#       <td id="T_b7041_row2_col4" class="data row2 col4" >43%</td>
#       <td id="T_b7041_row2_col5" class="data row2 col5" >5%</td>
#       <td id="T_b7041_row2_col6" class="data row2 col6" >1.66</td>
#       <td id="T_b7041_row2_col7" class="data row2 col7" >ID</td>
#       <td id="T_b7041_row2_col8" class="data row2 col8" >2023-11-07 19:07:03</td>
#     </tr>
#     <tr>
#       <td id="T_b7041_row3_col0" class="data row3 col0" >youkounkoun</td>
#       <td id="T_b7041_row3_col1" class="data row3 col1" >12.53</td>
#       <td id="T_b7041_row3_col2" class="data row3 col2" >-13.13</td>
#       <td id="T_b7041_row3_col3" class="data row3 col3" >75.45° F</td>
#       <td id="T_b7041_row3_col4" class="data row3 col4" >35%</td>
#       <td id="T_b7041_row3_col5" class="data row3 col5" >8%</td>
#       <td id="T_b7041_row3_col6" class="data row3 col6" >0.43</td>
#       <td id="T_b7041_row3_col7" class="data row3 col7" >GN</td>
#       <td id="T_b7041_row3_col8" class="data row3 col8" >2023-11-07 19:07:04</td>
#     </tr>
#     <tr>
#       <td id="T_b7041_row4_col0" class="data row4 col0" >kendari</td>
#       <td id="T_b7041_row4_col1" class="data row4 col1" >-3.94</td>
#       <td id="T_b7041_row4_col2" class="data row4 col2" >122.50</td>
#       <td id="T_b7041_row4_col3" class="data row4 col3" >90.46° F</td>
#       <td id="T_b7041_row4_col4" class="data row4 col4" >48%</td>
#       <td id="T_b7041_row4_col5" class="data row4 col5" >4%</td>
#       <td id="T_b7041_row4_col6" class="data row4 col6" >4.50</td>
#       <td id="T_b7041_row4_col7" class="data row4 col7" >ID</td>
#       <td id="T_b7041_row4_col8" class="data row4 col8" >2023-11-07 19:08:08</td>
#     </tr>
#     <tr>
#       <td id="T_b7041_row5_col0" class="data row5 col0" >naharlagun</td>
#       <td id="T_b7041_row5_col1" class="data row5 col1" >27.10</td>
#       <td id="T_b7041_row5_col2" class="data row5 col2" >93.70</td>
#       <td id="T_b7041_row5_col3" class="data row5 col3" >70.75° F</td>
#       <td id="T_b7041_row5_col4" class="data row5 col4" >51%</td>
#       <td id="T_b7041_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_b7041_row5_col6" class="data row5 col6" >0.94</td>
#       <td id="T_b7041_row5_col7" class="data row5 col7" >IN</td>
#       <td id="T_b7041_row5_col8" class="data row5 col8" >2023-11-07 19:08:13</td>
#     </tr>
#     <tr>
#       <td id="T_b7041_row6_col0" class="data row6 col0" >ormara</td>
#       <td id="T_b7041_row6_col1" class="data row6 col1" >25.21</td>
#       <td id="T_b7041_row6_col2" class="data row6 col2" >64.64</td>
#       <td id="T_b7041_row6_col3" class="data row6 col3" >77.97° F</td>
#       <td id="T_b7041_row6_col4" class="data row6 co

# %% [markdown]
# ## **2.4: Display Vacation Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (vacationDataFrame,
         'Figure 2.4: Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ## **3.1: Add Hotel Column to DataFrame**

# %%
hotelDataFrame \
    = vacationDataFrame.copy()

hotelDataFrame \
    ['Hotel Name'] \
        = pd.Series \
            (dtype= 'str')

hotelDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelDataFrame)

# %% [markdown]
# ## **3.2: Find Hotel Locations**

# %%
updatedHotelDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (hotelDataFrame,
             'Hotel Name',
             'accommodation.hotel',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedHotelDataFrame)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Dum Dastagir Resthouse in sehwan, PK
#
#
# Located the following hotel...City Hotel Kendari in kendari, ID
#
#
# Located the following hotel...Hotel Park in naharlagun, IN
#
#
# Located the following hotel...Hotel Mejorada Mérida in merida, MX
#
#
# Located the following hotel...Hapuwani Hotel in mulanje, MW
#
#
# Located the following hotel...Winlight Hotel in bhamo, MM
#
#
# hotel search complete

# %% [markdown]
# ## **3.3: Display Hotel Data Set**

# %%
captionString \
    = 'Table: 3.3: Hotel Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedHotelDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_41e24 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_41e24_row0_col0, #T_41e24_row0_col1, #T_41e24_row0_col2, #T_41e24_row0_col3, #T_41e24_row0_col6, #T_41e24_row0_col7, #T_41e24_row0_col8, #T_41e24_row0_col9, #T_41e24_row1_col0, #T_41e24_row1_col1, #T_41e24_row1_col2, #T_41e24_row1_col4, #T_41e24_row1_col5, #T_41e24_row1_col6, #T_41e24_row1_col7, #T_41e24_row1_col8, #T_41e24_row1_col9, #T_41e24_row2_col0, #T_41e24_row2_col1, #T_41e24_row2_col2, #T_41e24_row2_col4, #T_41e24_row2_col7, #T_41e24_row2_col8, #T_41e24_row2_col9, #T_41e24_row3_col0, #T_41e24_row3_col1, #T_41e24_row3_col2, #T_41e24_row3_col3, #T_41e24_row3_col7, #T_41e24_row3_col8, #T_41e24_row3_col9, #T_41e24_row4_col0, #T_41e24_row4_col1, #T_41e24_row4_col2, #T_41e24_row4_col3, #T_41e24_row4_col4, #T_41e24_row4_col5, #T_41e24_row4_col6, #T_41e24_row4_col7, #T_41e24_row4_col8, #T_41e24_row4_col9, #T_41e24_row5_col0, #T_41e24_row5_col1, #T_41e24_row5_col2, #T_41e24_row5_col3, #T_41e24_row5_col4, #T_41e24_row5_col6, #T_41e24_row5_col7, #T_41e24_row5_col8, #T_41e24_row5_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_41e24_row0_col4, #T_41e24_row2_col3, #T_41e24_row2_col5, #T_41e24_row2_col6, #T_41e24_row3_col5, #T_41e24_row5_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_41e24_row0_col5, #T_41e24_row1_col3, #T_41e24_row3_col4, #T_41e24_row3_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_41e24">
#   <caption>Table: 3.3: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_41e24_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_41e24_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_41e24_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_41e24_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_41e24_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_41e24_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_41e24_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_41e24_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_41e24_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_41e24_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_41e24_row0_col0" class="data row0 col0" >sehwan</td>
#       <td id="T_41e24_row0_col1" class="data row0 col1" >26.43</td>
#       <td id="T_41e24_row0_col2" class="data row0 col2" >67.86</td>
#       <td id="T_41e24_row0_col3" class="data row0 col3" >77.09° F</td>
#       <td id="T_41e24_row0_col4" class="data row0 col4" >40%</td>
#       <td id="T_41e24_row0_col5" class="data row0 col5" >7%</td>
#       <td id="T_41e24_row0_col6" class="data row0 col6" >1.50</td>
#       <td id="T_41e24_row0_col7" class="data row0 col7" >PK</td>
#       <td id="T_41e24_row0_col8" class="data row0 col8" >2023-11-07 19:06:24</td>
#       <td id="T_41e24_row0_col9" class="data row0 col9" >Dum Dastagir Resthouse</td>
#     </tr>
#     <tr>
#       <td id="T_41e24_row1_col0" class="data row1 col0" >kendari</td>
#       <td id="T_41e24_row1_col1" class="data row1 col1" >-3.94</td>
#       <td id="T_41e24_row1_col2" class="data row1 col2" >122.50</td>
#       <td id="T_41e24_row1_col3" class="data row1 col3" >90.46° F</td>
#       <td id="T_41e24_row1_col4" class="data row1 col4" >48%</td>
#       <td id="T_41e24_row1_col5" class="data row1 col5" >4%</td>
#       <td id="T_41e24_row1_col6" class="data row1 col6" >4.50</td>
#       <td id="T_41e24_row1_col7" class="data row1 col7" >ID</td>
#       <td id="T_41e24_row1_col8" class="data row1 col8" >2023-11-07 19:08:08</td>
#       <td id="T_41e24_row1_col9" class="data row1 col9" >City Hotel Kendari</td>
#     </tr>
#     <tr>
#       <td id="T_41e24_row2_col0" class="data row2 col0" >naharlagun</td>
#       <td id="T_41e24_row2_col1" class="data row2 col1" >27.10</td>
#       <td id="T_41e24_row2_col2" class="data row2 col2" >93.70</td>
#       <td id="T_41e24_row2_col3" class="data row2 col3" >70.75° F</td>
#       <td id="T_41e24_row2_col4" class="data row2 col4" >51%</td>
#       <td id="T_41e24_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_41e24_row2_col6" class="data row2 col6" >0.94</td>
#       <td id="T_41e24_row2_col7" class="data row2 col7" >IN</td>
#       <td id="T_41e24_row2_col8" class="data row2 col8" >2023-11-07 19:08:13</td>
#       <td id="T_41e24_row2_col9" class="data row2 col9" >Hotel Park</td>
#     </tr>
#     <tr>
#       <td id="T_41e24_row3_col0" class="data row3 col0" >merida</td>
#       <td id="T_41e24_row3_col1" class="data row3 col1" >20.97</td>
#       <td id="T_41e24_row3_col2" class="data row3 col2" >-89.62</td>
#       <td id="T_41e24_row3_col3" class="data row3 col3" >77.02° F</td>
#       <td id="T_41e24_row3_col4" class="data row3 col4" >65%</td>
#       <td id="T_41e24_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_41e24_row3_col6" class="data row3 col6" >9.22</td>
#       <td id="T_41e24_row3_col7" class="data row3 col7" >MX</td>
#       <td id="T_41e24_row3_col8" class="data row3 col8" >2023-11-07 19:05:10</td>
#       <td id="T_41e24_row3_col9" class="data row3 col9" >Hotel Mejorada Mérida</td>
#     </tr>
#     <tr>
#       <td id="T_41e24_row4_col0" class="data row4 col0" >mulanje</td>
#       <td id="T_41e24_row4_col1" class="data row4 col1" >-16.03</td>
#       <td id="T_41e24_row4_col2" class="data row4 col2" >35.50</td>
#       <td id="T_41e24_row4_col3" class="data row4 col3" >77.00° F</td>
#       <td id="T_41e24_row4_col4" class="data row4 col4" >59%</td>
#       <td id="T_41e24_row4_col5" class="data row4 col5" >3%</td>
#       <td id="T_41e24_row4_col6" class="data row4 col6" >6.96</td>
#       <td id="T_41e24_row4_col7" class="data row4 col7" >MW</td>
#       <td id="T_41e24_row4_col8" class="data row4 col8" >2023-11-07 19:08:55</td>
#       <td id="T_41e24_row4_col9" class="data row4 col9" >Hapuwani Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_41e24_row5_col0" class="data row5 col0" >bhamo</td>
#       <td id="T_41e24_row5_col1" class="data row5 col1" >24.27</td>
#       <td id="T_41e24_row5_col2" class="data row5 col2" >97.23</td>
#       <td id="T_41e24_row5_col3" class="data row5 col3" >74.55° F</td>
#       <td id="T_41e24_row5_col4" class="data row5 col4" >58%</td>
#       <td id="T_41e24_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_41e24_row5_col6" class="data row5 col6" >1.88</td>
#       <td id="T_41e24_row5_col7" class="data row5 col7" >MM</td>
#       <td id="T_41e24_row5_col8" class="data row5 col8" >2023-11-07 19:09:11</td>
#       <td id="T_41e24_row5_col9" class="data row5 col9" >Winlight Hotel</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **3.4: Display Hotel Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelDataFrame,
         'Figure 3.4: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %% [markdown]
# # <br> **Section 4: Restaurant Locations**

# %% [markdown]
# ## **4.1: Add Restaurant Column to DataFrame**

# %%
resturantDataFrame \
    = updatedHotelDataFrame.copy()

resturantDataFrame \
    ['Restaurant Name'] \
        = pd.Series \
            (dtype= 'str')

resturantDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (resturantDataFrame)

# %% [markdown]
# ## **4.2: Find Restaurant Locations**

# %%
updatedResturantDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (resturantDataFrame,
             'Restaurant Name',
             'catering.restaurant',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedResturantDataFrame)
# Out:
# Starting restaurant search...
#
#
# Located the following restaurant...Lajpal Restaurant in sehwan, PK
#
#
# Located the following restaurant...RM. Pangkep in kendari, ID
#
#
# Located the following restaurant...NERIST Students' Canteen in naharlagun, IN
#
#
# Located the following restaurant...El Templo in merida, MX
#
#
# Located the following restaurant...Tasty Food Restaurant in mulanje, MW
#
#
# Located the following restaurant...ရွှေမူဆယ် in bhamo, MM
#
#
# restaurant search complete

# %% [markdown]
# ## **4.3: Display Restaurant Data Set**

# %%
captionString \
    = 'Table: 4.3: Restaurant Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedResturantDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_601ab caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_601ab_row0_col0, #T_601ab_row0_col1, #T_601ab_row0_col2, #T_601ab_row0_col3, #T_601ab_row0_col6, #T_601ab_row0_col7, #T_601ab_row0_col8, #T_601ab_row0_col9, #T_601ab_row0_col10, #T_601ab_row1_col0, #T_601ab_row1_col1, #T_601ab_row1_col2, #T_601ab_row1_col4, #T_601ab_row1_col5, #T_601ab_row1_col6, #T_601ab_row1_col7, #T_601ab_row1_col8, #T_601ab_row1_col9, #T_601ab_row1_col10, #T_601ab_row2_col0, #T_601ab_row2_col1, #T_601ab_row2_col2, #T_601ab_row2_col4, #T_601ab_row2_col7, #T_601ab_row2_col8, #T_601ab_row2_col9, #T_601ab_row2_col10, #T_601ab_row3_col0, #T_601ab_row3_col1, #T_601ab_row3_col2, #T_601ab_row3_col3, #T_601ab_row3_col7, #T_601ab_row3_col8, #T_601ab_row3_col9, #T_601ab_row3_col10, #T_601ab_row4_col0, #T_601ab_row4_col1, #T_601ab_row4_col2, #T_601ab_row4_col3, #T_601ab_row4_col4, #T_601ab_row4_col5, #T_601ab_row4_col6, #T_601ab_row4_col7, #T_601ab_row4_col8, #T_601ab_row4_col9, #T_601ab_row4_col10, #T_601ab_row5_col0, #T_601ab_row5_col1, #T_601ab_row5_col2, #T_601ab_row5_col3, #T_601ab_row5_col4, #T_601ab_row5_col6, #T_601ab_row5_col7, #T_601ab_row5_col8, #T_601ab_row5_col9, #T_601ab_row5_col10 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_601ab_row0_col4, #T_601ab_row2_col3, #T_601ab_row2_col5, #T_601ab_row2_col6, #T_601ab_row3_col5, #T_601ab_row5_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_601ab_row0_col5, #T_601ab_row1_col3, #T_601ab_row3_col4, #T_601ab_row3_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_601ab">
#   <caption>Table: 4.3: Restaurant Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_601ab_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_601ab_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_601ab_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_601ab_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_601ab_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_601ab_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_601ab_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_601ab_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_601ab_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_601ab_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#       <th id="T_601ab_level0_col10" class="col_heading level0 col10" >Restaurant Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_601ab_row0_col0" class="data row0 col0" >sehwan</td>
#       <td id="T_601ab_row0_col1" class="data row0 col1" >26.43</td>
#       <td id="T_601ab_row0_col2" class="data row0 col2" >67.86</td>
#       <td id="T_601ab_row0_col3" class="data row0 col3" >77.09° F</td>
#       <td id="T_601ab_row0_col4" class="data row0 col4" >40%</td>
#       <td id="T_601ab_row0_col5" class="data row0 col5" >7%</td>
#       <td id="T_601ab_row0_col6" class="data row0 col6" >1.50</td>
#       <td id="T_601ab_row0_col7" class="data row0 col7" >PK</td>
#       <td id="T_601ab_row0_col8" class="data row0 col8" >2023-11-07 19:06:24</td>
#       <td id="T_601ab_row0_col9" class="data row0 col9" >Dum Dastagir Resthouse</td>
#       <td id="T_601ab_row0_col10" class="data row0 col10" >Lajpal Restaurant</td>
#     </tr>
#     <tr>
#       <td id="T_601ab_row1_col0" class="data row1 col0" >kendari</td>
#       <td id="T_601ab_row1_col1" class="data row1 col1" >-3.94</td>
#       <td id="T_601ab_row1_col2" class="data row1 col2" >122.50</td>
#       <td id="T_601ab_row1_col3" class="data row1 col3" >90.46° F</td>
#       <td id="T_601ab_row1_col4" class="data row1 col4" >48%</td>
#       <td id="T_601ab_row1_col5" class="data row1 col5" >4%</td>
#       <td id="T_601ab_row1_col6" class="data row1 col6" >4.50</td>
#       <td id="T_601ab_row1_col7" class="data row1 col7" >ID</td>
#       <td id="T_601ab_row1_col8" class="data row1 col8" >2023-11-07 19:08:08</td>
#       <td id="T_601ab_row1_col9" class="data row1 col9" >City Hotel Kendari</td>
#       <td id="T_601ab_row1_col10" class="data row1 col10" >RM. Pangkep</td>
#     </tr>
#     <tr>
#       <td id="T_601ab_row2_col0" class="data row2 col0" >naharlagun</td>
#       <td id="T_601ab_row2_col1" class="data row2 col1" >27.10</td>
#       <td id="T_601ab_row2_col2" class="data row2 col2" >93.70</td>
#       <td id="T_601ab_row2_col3" class="data row2 col3" >70.75° F</td>
#       <td id="T_601ab_row2_col4" class="data row2 col4" >51%</td>
#       <td id="T_601ab_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_601ab_row2_col6" class="data row2 col6" >0.94</td>
#       <td id="T_601ab_row2_col7" class="data row2 col7" >IN</td>
#       <td id="T_601ab_row2_col8" class="data row2 col8" >2023-11-07 19:08:13</td>
#       <td id="T_601ab_row2_col9" class="data row2 col9" >Hotel Park</td>
#       <td id="T_601ab_row2_col10" class="data row2 col10" >NERIST Students' Canteen</td>
#     </tr>
#     <tr>
#       <td id="T_601ab_row3_col0" class="data row3 col0" >merida</td>
#       <td id="T_601ab_row3_col1" class="data row3 col1" >20.97</td>
#       <td id="T_601ab_row3_col2" class="data row3 col2" >-89.62</td>
#       <td id="T_601ab_row3_col3" class="data row3 col3" >77.02° F</td>
#       <td id="T_601ab_row3_col4" class="data row3 col4" >65%</td>
#       <td id="T_601ab_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_601ab_row3_col6" class="data row3 col6" >9.22</td>
#       <td id="T_601ab_row3_col7" class="data row3 col7" >MX</td>
#       <td id="T_601ab_row3_col8" class="data row3 col8" >2023-11-07 19:05:10</td>
#       <td id="T_601ab_row3_col9" class="data row3 col9" >Hotel Mejorada Mérida</td>
#       <td id="T_601ab_row3_col10" class="data row3 col10" >El Templo</td>
#     </tr>
#     <tr>
#       <td id="T_601ab_row4_col0" class="data row4 col0" >mulanje</td>
#       <td id="T_601ab_row4_col1" class="data row4 col1" >-16.03</td>
#       <td id="T_601ab_row4_col2" class="data row4 col2" >35.50</td>
#       <td id="T_601ab_row4_col3" class="data row4 col3" >77.00° F</td>
#       <td id="T_601ab_row4_col4" class="data row4 col4" >59%</td>
#       <td id="T_601ab_row4_col5" class="data row4 col5" >3%</td>
#       <td id="T_601ab_row4_col6" class="data row4 col6" >6.96</td>
#       <td id="T_601ab_row4_col7" class="data row4 col7" >MW</td>
#       <td id="T_601ab_row4_col8" class="data row4 col8" >2023-11-07 19:08:55</td>
#       <td id="T_601ab_row4_col9" class="data row4 col9" >Hapuwani Hotel</td>
#       <td id="T_601ab_row4_col10" class="data row4 col10" >Tasty Food Restaurant</td>
#     </tr>
#     <tr>
#       <td id="T_601ab_row5_col0" class="data row5 col0" >bhamo</td>
#       <td id="T_601ab_row5_col1" class="data row5 col1" >24.27</td>
#       <td id="T_601ab_row5_col2" class="data row5 col2" >97.23</td>
#       <td id="T_601ab_row5_col3" class="data row5 col3" >74.55° F</td>
#       <td id="T_601ab_row5_col4" class="data row5 col4" >58%</td>
#       <td id="T_601ab_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_601ab_row5_col6" class="data row5 col6" >1.88</td>
#       <td id="T_601ab_row5_col7" class="data row5 col7" >MM</td>
#       <td id="T_601ab_row5_col8" class="data row5 col8" >2023-11-07 19:09:11</td>
#       <td id="T_601ab_row5_col9" class="data row5 col9" >Winlight Hotel</td>
#       <td id="T_601ab_row5_col10" class="data row5 col10" >ရွှေမူဆယ်</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **4.4: Display Restaurant Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Hotel Name', 
       'Restaurant Name'
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedResturantDataFrame,
         'Figure 4.4: Restaurant Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name)

# %% [markdown]
# # <br> **Section 5: Tourism Attraction Locations**

# %% [markdown]
# ## **5.1: Add Tourism Attraction Column to DataFrame**

# %%
tourismAttractionDataFrame \
    = updatedResturantDataFrame.copy()

tourismAttractionDataFrame \
    ['Tourism Attraction'] \
        = pd.Series \
            (dtype= 'str')

tourismAttractionDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (tourismAttractionDataFrame)

# %% [markdown]
# ## **5.2: Find Tourism Attraction Locations**

# %%
updatedTourismAttractionDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (tourismAttractionDataFrame,
             'Tourism Attraction',
             'tourism.attraction',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedTourismAttractionDataFrame)
# Out:
# Starting tourism attraction search...
#
#
# Located the following tourism attraction...Galeria Merida in merida, MX
#
#
# Located the following tourism attraction...Curios in mulanje, MW
#
#
# Located the following tourism attraction...Local Market in bhamo, MM
#
#
# tourism attraction search complete

# %% [markdown]
# ## **5.3: Display Tourism Attraction Data Set**

# %%
captionString \
    = 'Table: 5.3: Tourism Attraction Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedTourismAttractionDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_0301c caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_0301c_row0_col0, #T_0301c_row0_col1, #T_0301c_row0_col2, #T_0301c_row0_col7, #T_0301c_row0_col8, #T_0301c_row0_col9, #T_0301c_row0_col10, #T_0301c_row0_col11, #T_0301c_row1_col0, #T_0301c_row1_col1, #T_0301c_row1_col2, #T_0301c_row1_col3, #T_0301c_row1_col4, #T_0301c_row1_col6, #T_0301c_row1_col7, #T_0301c_row1_col8, #T_0301c_row1_col9, #T_0301c_row1_col10, #T_0301c_row1_col11, #T_0301c_row2_col0, #T_0301c_row2_col1, #T_0301c_row2_col2, #T_0301c_row2_col7, #T_0301c_row2_col8, #T_0301c_row2_col9, #T_0301c_row2_col10, #T_0301c_row2_col11 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_0301c_row0_col3, #T_0301c_row0_col4, #T_0301c_row0_col6, #T_0301c_row1_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_0301c_row0_col5, #T_0301c_row2_col3, #T_0301c_row2_col4, #T_0301c_row2_col5, #T_0301c_row2_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_0301c">
#   <caption>Table: 5.3: Tourism Attraction Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_0301c_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_0301c_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_0301c_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_0301c_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_0301c_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_0301c_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_0301c_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_0301c_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_0301c_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_0301c_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#       <th id="T_0301c_level0_col10" class="col_heading level0 col10" >Restaurant Name</th>
#       <th id="T_0301c_level0_col11" class="col_heading level0 col11" >Tourism Attraction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0301c_row0_col0" class="data row0 col0" >merida</td>
#       <td id="T_0301c_row0_col1" class="data row0 col1" >20.97</td>
#       <td id="T_0301c_row0_col2" class="data row0 col2" >-89.62</td>
#       <td id="T_0301c_row0_col3" class="data row0 col3" >77.02° F</td>
#       <td id="T_0301c_row0_col4" class="data row0 col4" >65%</td>
#       <td id="T_0301c_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_0301c_row0_col6" class="data row0 col6" >9.22</td>
#       <td id="T_0301c_row0_col7" class="data row0 col7" >MX</td>
#       <td id="T_0301c_row0_col8" class="data row0 col8" >2023-11-07 19:05:10</td>
#       <td id="T_0301c_row0_col9" class="data row0 col9" >Hotel Mejorada Mérida</td>
#       <td id="T_0301c_row0_col10" class="data row0 col10" >El Templo</td>
#       <td id="T_0301c_row0_col11" class="data row0 col11" >Galeria Merida</td>
#     </tr>
#     <tr>
#       <td id="T_0301c_row1_col0" class="data row1 col0" >mulanje</td>
#       <td id="T_0301c_row1_col1" class="data row1 col1" >-16.03</td>
#       <td id="T_0301c_row1_col2" class="data row1 col2" >35.50</td>
#       <td id="T_0301c_row1_col3" class="data row1 col3" >77.00° F</td>
#       <td id="T_0301c_row1_col4" class="data row1 col4" >59%</td>
#       <td id="T_0301c_row1_col5" class="data row1 col5" >3%</td>
#       <td id="T_0301c_row1_col6" class="data row1 col6" >6.96</td>
#       <td id="T_0301c_row1_col7" class="data row1 col7" >MW</td>
#       <td id="T_0301c_row1_col8" class="data row1 col8" >2023-11-07 19:08:55</td>
#       <td id="T_0301c_row1_col9" class="data row1 col9" >Hapuwani Hotel</td>
#       <td id="T_0301c_row1_col10" class="data row1 col10" >Tasty Food Restaurant</td>
#       <td id="T_0301c_row1_col11" class="data row1 col11" >Curios</td>
#     </tr>
#     <tr>
#       <td id="T_0301c_row2_col0" class="data row2 col0" >bhamo</td>
#       <td id="T_0301c_row2_col1" class="data row2 col1" >24.27</td>
#       <td id="T_0301c_row2_col2" class="data row2 col2" >97.23</td>
#       <td id="T_0301c_row2_col3" class="data row2 col3" >74.55° F</td>
#       <td id="T_0301c_row2_col4" class="data row2 col4" >58%</td>
#       <td id="T_0301c_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_0301c_row2_col6" class="data row2 col6" >1.88</td>
#       <td id="T_0301c_row2_col7" class="data row2 col7" >MM</td>
#       <td id="T_0301c_row2_col8" class="data row2 col8" >2023-11-07 19:09:11</td>
#       <td id="T_0301c_row2_col9" class="data row2 col9" >Winlight Hotel</td>
#       <td id="T_0301c_row2_col10" class="data row2 col10" >ရွှေမူဆယ်</td>
#       <td id="T_0301c_row2_col11" class="data row2 col11" >Local Market</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **5.4: Display Tourism Attraction Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Hotel Name', 
       'Restaurant Name',
       'Tourism Attraction',
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedTourismAttractionDataFrame,
         'Figure 5.4: Tourism Attraction Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Restaurant Name,Tourism Attraction,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
