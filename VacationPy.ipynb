# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
captionString \
    = 'Table: 1.1: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_b61b8 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b61b8_row0_col0, #T_b61b8_row0_col1, #T_b61b8_row0_col2, #T_b61b8_row0_col3, #T_b61b8_row0_col4, #T_b61b8_row0_col6, #T_b61b8_row0_col7, #T_b61b8_row0_col8, #T_b61b8_row1_col0, #T_b61b8_row1_col1, #T_b61b8_row1_col2, #T_b61b8_row1_col3, #T_b61b8_row1_col5, #T_b61b8_row1_col6, #T_b61b8_row1_col7, #T_b61b8_row1_col8, #T_b61b8_row2_col0, #T_b61b8_row2_col1, #T_b61b8_row2_col2, #T_b61b8_row2_col3, #T_b61b8_row2_col4, #T_b61b8_row2_col6, #T_b61b8_row2_col7, #T_b61b8_row2_col8, #T_b61b8_row3_col0, #T_b61b8_row3_col1, #T_b61b8_row3_col2, #T_b61b8_row3_col3, #T_b61b8_row3_col4, #T_b61b8_row3_col6, #T_b61b8_row3_col7, #T_b61b8_row3_col8, #T_b61b8_row4_col0, #T_b61b8_row4_col1, #T_b61b8_row4_col2, #T_b61b8_row4_col3, #T_b61b8_row4_col4, #T_b61b8_row4_col7, #T_b61b8_row4_col8, #T_b61b8_row5_col0, #T_b61b8_row5_col1, #T_b61b8_row5_col2, #T_b61b8_row5_col3, #T_b61b8_row5_col4, #T_b61b8_row5_col5, #T_b61b8_row5_col6, #T_b61b8_row5_col7, #T_b61b8_row5_col8, #T_b61b8_row6_col0, #T_b61b8_row6_col1, #T_b61b8_row6_col2, #T_b61b8_row6_col3, #T_b61b8_row6_col4, #T_b61b8_row6_col6, #T_b61b8_row6_col7, #T_b61b8_row6_col8, #T_b61b8_row7_col0, #T_b61b8_row7_col1, #T_b61b8_row7_col2, #T_b61b8_row7_col5, #T_b61b8_row7_col6, #T_b61b8_row7_col7, #T_b61b8_row7_col8, #T_b61b8_row8_col0, #T_b61b8_row8_col1, #T_b61b8_row8_col2, #T_b61b8_row8_col3, #T_b61b8_row8_col4, #T_b61b8_row8_col5, #T_b61b8_row8_col6, #T_b61b8_row8_col7, #T_b61b8_row8_col8, #T_b61b8_row9_col0, #T_b61b8_row9_col1, #T_b61b8_row9_col2, #T_b61b8_row9_col3, #T_b61b8_row9_col4, #T_b61b8_row9_col6, #T_b61b8_row9_col7, #T_b61b8_row9_col8, #T_b61b8_row10_col0, #T_b61b8_row10_col1, #T_b61b8_row10_col2, #T_b61b8_row10_col3, #T_b61b8_row10_col4, #T_b61b8_row10_col6, #T_b61b8_row10_col7, #T_b61b8_row10_col8, #T_b61b8_row11_col0, #T_b61b8_row11_col1, #T_b61b8_row11_col2, #T_b61b8_row11_col4, #T_b61b8_row11_col7, #T_b61b8_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_b61b8_row0_col5, #T_b61b8_row1_col4, #T_b61b8_row2_col5, #T_b61b8_row4_col5, #T_b61b8_row6_col5, #T_b61b8_row7_col3, #T_b61b8_row9_col5, #T_b61b8_row11_col5, #T_b61b8_row11_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_b61b8_row3_col5, #T_b61b8_row4_col6, #T_b61b8_row7_col4, #T_b61b8_row10_col5, #T_b61b8_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_b61b8">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_b61b8_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_b61b8_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_b61b8_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_b61b8_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_b61b8_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_b61b8_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_b61b8_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_b61b8_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_b61b8_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b61b8_row0_col0" class="data row0 col0" >kralendijk</td>
#       <td id="T_b61b8_row0_col1" class="data row0 col1" >12.15</td>
#       <td id="T_b61b8_row0_col2" class="data row0 col2" >-68.27</td>
#       <td id="T_b61b8_row0_col3" class="data row0 col3" >84.18° F</td>
#       <td id="T_b61b8_row0_col4" class="data row0 col4" >79%</td>
#       <td id="T_b61b8_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_b61b8_row0_col6" class="data row0 col6" >12.66</td>
#       <td id="T_b61b8_row0_col7" class="data row0 col7" >BQ</td>
#       <td id="T_b61b8_row0_col8" class="data row0 col8" >2023-09-22 20:40:41</td>
#     </tr>
#     <tr>
#       <td id="T_b61b8_row1_col0" class="data row1 col0" >adamstown</td>
#       <td id="T_b61b8_row1_col1" class="data row1 col1" >-25.07</td>
#       <td id="T_b61b8_row1_col2" class="data row1 col2" >-130.10</td>
#       <td id="T_b61b8_row1_col3" class="data row1 col3" >69.26° F</td>
#       <td id="T_b61b8_row1_col4" class="data row1 col4" >88%</td>
#       <td id="T_b61b8_row1_col5" class="data row1 col5" >2%</td>
#       <td id="T_b61b8_row1_col6" class="data row1 col6" >15.30</td>
#       <td id="T_b61b8_row1_col7" class="data row1 col7" >PN</td>
#       <td id="T_b61b8_row1_col8" class="data row1 col8" >2023-09-22 20:37:43</td>
#     </tr>
#     <tr>
#       <td id="T_b61b8_row2_col0" class="data row2 col0" >yellowknife</td>
#       <td id="T_b61b8_row2_col1" class="data row2 col1" >62.46</td>
#       <td id="T_b61b8_row2_col2" class="data row2 col2" >-114.35</td>
#       <td id="T_b61b8_row2_col3" class="data row2 col3" >64.42° F</td>
#       <td id="T_b61b8_row2_col4" class="data row2 col4" >68%</td>
#       <td id="T_b61b8_row2_col5" class="data row2 col5" >100%</td>
#       <td id="T_b61b8_row2_col6" class="data row2 col6" >14.97</td>
#       <td id="T_b61b8_row2_col7" class="data row2 col7" >CA</td>
#       <td id="T_b61b8_row2_col8" class="data row2 col8" >2023-09-22 20:40:41</td>
#     </tr>
#     <tr>
#       <td id="T_b61b8_row3_col0" class="data row3 col0" >pisco</td>
#       <td id="T_b61b8_row3_col1" class="data row3 col1" >-13.70</td>
#       <td id="T_b61b8_row3_col2" class="data row3 col2" >-76.22</td>
#       <td id="T_b61b8_row3_col3" class="data row3 col3" >64.45° F</td>
#       <td id="T_b61b8_row3_col4" class="data row3 col4" >82%</td>
#       <td id="T_b61b8_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_b61b8_row3_col6" class="data row3 col6" >10.36</td>
#       <td id="T_b61b8_row3_col7" class="data row3 col7" >PE</td>
#       <td id="T_b61b8_row3_col8" class="data row3 col8" >2023-09-22 20:36:16</td>
#     </tr>
#     <tr>
#       <td id="T_b61b8_row4_col0" class="data row4 col0" >bilibino</td>
#       <td id="T_b61b8_row4_col1" class="data row4 col1" >68.05</td>
#       <td id="T_b61b8_row4_col2" class="data row4 col2" >166.44</td>
#       <td id="T_b61b8_row4_col3" class="data row4 col3" >38.98° F</td>
#       <td id="T_b61b8_row4_col4" class="data row4 col4" >82%</td>
#       <td id="T_b61b8_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_b61b8_row4_col6" class="data row4 col6" >0.25</td>
#       <td id="T_b61b8_row4_col7" class="data row4 col7" >RU</td>
#       <td id="T_b61b8_row4_col8" class="data row4 col8" >2023-09-22 20:34:33</td>
#     </tr>
#     <tr>
#       <td id="T_b61b8_row5_col0" class="data row5 col0" >queenstown</td>
#       <td id="T_b61b8_row5_col1" class="data row5 col1" >-31.90</td>
#       <td id="T_b61b8_row5_col2" class="data row5 col2" >26.88</td>
#       <td id="T_b61b8_row5_col3" class="data row5 col3" >45.99° F</td>
#       <td id="T_b61b8_row5_col4" class="data row5 col4" >87%</td>
#       <td id="T_b61b8_row5_col5" class="data row5 col5" >69%</td>
#       <td id="T_b61b8_row5_col6" class="data row5 col6" >2.39</td>
#       <td id="T_b61b8_row5_col7" class="data row5 col7" >ZA</td>
#       <td id="T_b61b8_row5_col8" class="data row5 col8" >2023-09-22 20:40:42</td>
#     </tr>
#     <tr>
#       <td id="T_b61b8_row6_col0" class="data row6 col0" >lamarque</td>
#       <td id="T_b61b8_row6_col1" class="data row6 col1" >-39.42</td>
#       <td id="T_b61b8_row6_col2" class="data row6 col2" >-65.70</td>
#       <td id="T_b61b8_row6_col3" class="data row6 col3" >52.90° F</td>
#       <td id="T_b61b8_row6_col4" class="data row6 col4" >79%</td>
#       <td id="T_b61b8_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_b61b8_row6_col6" class="data row6 col6" >11.30</td>
#       <td id="T_b61b8_row6_col7" class="data row6 col7" >AR</td>
#       <td id="T_b61b8_row6_col8" class="data row6 col8" >2023-09-22 20:40:42</td>
#     </tr>
#     <tr>
#       <td id="T_b61b8_row7_col0

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 93), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 40) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 70), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 10), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
captionString \
    = 'Table: 2.1: Ideal Vacation Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (idealVacationLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_e096d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_e096d_row0_col0, #T_e096d_row0_col1, #T_e096d_row0_col2, #T_e096d_row0_col3, #T_e096d_row0_col4, #T_e096d_row0_col6, #T_e096d_row0_col7, #T_e096d_row0_col8, #T_e096d_row1_col0, #T_e096d_row1_col1, #T_e096d_row1_col2, #T_e096d_row1_col3, #T_e096d_row1_col4, #T_e096d_row1_col7, #T_e096d_row1_col8, #T_e096d_row2_col0, #T_e096d_row2_col1, #T_e096d_row2_col2, #T_e096d_row2_col6, #T_e096d_row2_col7, #T_e096d_row2_col8, #T_e096d_row3_col0, #T_e096d_row3_col1, #T_e096d_row3_col2, #T_e096d_row3_col4, #T_e096d_row3_col6, #T_e096d_row3_col7, #T_e096d_row3_col8, #T_e096d_row4_col0, #T_e096d_row4_col1, #T_e096d_row4_col2, #T_e096d_row4_col3, #T_e096d_row4_col4, #T_e096d_row4_col6, #T_e096d_row4_col7, #T_e096d_row4_col8, #T_e096d_row5_col0, #T_e096d_row5_col1, #T_e096d_row5_col2, #T_e096d_row5_col3, #T_e096d_row5_col6, #T_e096d_row5_col7, #T_e096d_row5_col8, #T_e096d_row6_col0, #T_e096d_row6_col1, #T_e096d_row6_col2, #T_e096d_row6_col3, #T_e096d_row6_col4, #T_e096d_row6_col7, #T_e096d_row6_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_e096d_row0_col5, #T_e096d_row1_col5, #T_e096d_row2_col4, #T_e096d_row3_col3, #T_e096d_row4_col5, #T_e096d_row6_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_e096d_row1_col6, #T_e096d_row2_col3, #T_e096d_row2_col5, #T_e096d_row3_col5, #T_e096d_row5_col4, #T_e096d_row5_col5, #T_e096d_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_e096d">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_e096d_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_e096d_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_e096d_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_e096d_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_e096d_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_e096d_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_e096d_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_e096d_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_e096d_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e096d_row0_col0" class="data row0 col0" >malango</td>
#       <td id="T_e096d_row0_col1" class="data row0 col1" >-2.96</td>
#       <td id="T_e096d_row0_col2" class="data row0 col2" >119.90</td>
#       <td id="T_e096d_row0_col3" class="data row0 col3" >85.08° F</td>
#       <td id="T_e096d_row0_col4" class="data row0 col4" >48%</td>
#       <td id="T_e096d_row0_col5" class="data row0 col5" >10%</td>
#       <td id="T_e096d_row0_col6" class="data row0 col6" >5.73</td>
#       <td id="T_e096d_row0_col7" class="data row0 col7" >ID</td>
#       <td id="T_e096d_row0_col8" class="data row0 col8" >2023-09-22 20:35:57</td>
#     </tr>
#     <tr>
#       <td id="T_e096d_row1_col0" class="data row1 col0" >tomohon</td>
#       <td id="T_e096d_row1_col1" class="data row1 col1" >1.33</td>
#       <td id="T_e096d_row1_col2" class="data row1 col2" >124.84</td>
#       <td id="T_e096d_row1_col3" class="data row1 col3" >85.14° F</td>
#       <td id="T_e096d_row1_col4" class="data row1 col4" >49%</td>
#       <td id="T_e096d_row1_col5" class="data row1 col5" >10%</td>
#       <td id="T_e096d_row1_col6" class="data row1 col6" >2.73</td>
#       <td id="T_e096d_row1_col7" class="data row1 col7" >ID</td>
#       <td id="T_e096d_row1_col8" class="data row1 col8" >2023-09-22 20:40:55</td>
#     </tr>
#     <tr>
#       <td id="T_e096d_row2_col0" class="data row2 col0" >darnah</td>
#       <td id="T_e096d_row2_col1" class="data row2 col1" >32.77</td>
#       <td id="T_e096d_row2_col2" class="data row2 col2" >22.64</td>
#       <td id="T_e096d_row2_col3" class="data row2 col3" >76.37° F</td>
#       <td id="T_e096d_row2_col4" class="data row2 col4" >63%</td>
#       <td id="T_e096d_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_e096d_row2_col6" class="data row2 col6" >6.44</td>
#       <td id="T_e096d_row2_col7" class="data row2 col7" >LY</td>
#       <td id="T_e096d_row2_col8" class="data row2 col8" >2023-09-22 20:41:46</td>
#     </tr>
#     <tr>
#       <td id="T_e096d_row3_col0" class="data row3 col0" >pecan plantation</td>
#       <td id="T_e096d_row3_col1" class="data row3 col1" >32.36</td>
#       <td id="T_e096d_row3_col2" class="data row3 col2" >-97.68</td>
#       <td id="T_e096d_row3_col3" class="data row3 col3" >85.32° F</td>
#       <td id="T_e096d_row3_col4" class="data row3 col4" >57%</td>
#       <td id="T_e096d_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_e096d_row3_col6" class="data row3 col6" >8.05</td>
#       <td id="T_e096d_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_e096d_row3_col8" class="data row3 col8" >2023-09-22 20:41:54</td>
#     </tr>
#     <tr>
#       <td id="T_e096d_row4_col0" class="data row4 col0" >taco pozo</td>
#       <td id="T_e096d_row4_col1" class="data row4 col1" >-25.62</td>
#       <td id="T_e096d_row4_col2" class="data row4 col2" >-63.28</td>
#       <td id="T_e096d_row4_col3" class="data row4 col3" >81.28° F</td>
#       <td id="T_e096d_row4_col4" class="data row4 col4" >57%</td>
#       <td id="T_e096d_row4_col5" class="data row4 col5" >10%</td>
#       <td id="T_e096d_row4_col6" class="data row4 col6" >7.76</td>
#       <td id="T_e096d_row4_col7" class="data row4 col7" >AR</td>
#       <td id="T_e096d_row4_col8" class="data row4 col8" >2023-09-22 20:41:56</td>
#     </tr>
#     <tr>
#       <td id="T_e096d_row5_col0" class="data row5 col0" >argo</td>
#       <td id="T_e096d_row5_col1" class="data row5 col1" >37.63</td>
#       <td id="T_e096d_row5_col2" class="data row5 col2" >22.73</td>
#       <td id="T_e096d_row5_col3" class="data row5 col3" >76.89° F</td>
#       <td id="T_e096d_row5_col4" class="data row5 col4" >45%</td>
#       <td id="T_e096d_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_e096d_row5_col6" class="data row5 col6" >3.22</td>
#       <td id="T_e096d_row5_col7" class="data row5 col7" >GR</td>
#       <td id="T_e096d_row5_col8" class="data row5 col8" >2023-09-22 20:38:01</td>
#     </tr>
#     <tr>
#       <td id="T_e096d_row6_col0" class="data row6 col0" >petrolina</td>
#       <td id="T_e096d_row6_col1" class="data row6 col1" >-9.40</td>
#       <td id="T_e096d_row6_col2" class="data row6 col2" >-40.50</td>
#       <td id="T_e096d_row6_col3" class="data row6 col3" >80.65° F</td>
#       <td id="T_e096d_row6_col4" class="data row6 col4" >50%</td>
#       <td id="T_e096d_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_e096d_row6_col6" class="data row6 col6" >9.22</td>
#       <td id="T_e096d_row6_col7" class="data row6 col7" >BR</td>
#       <td id="T_e096d_row6_col8" class="data row6 col8" >2023-09-22 20:42:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Madarana in malango, ID
#
#
# Located the following hotel...Okoy Flower Garden Resort in tomohon, ID
#
#
# Located the following hotel...فندق الفردوس in darnah, LY
#
#
# Located the following hotel...Hospedaje El Camionero in taco pozo, AR
#
#
# Located the following hotel...Apollon Hotel in argo, GR
#
#
# Located the following hotel...Neuman in petrolina, BR
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
captionString \
    = 'Table: 3.1: Hotel Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedHotelLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_3c68d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_3c68d_row0_col0, #T_3c68d_row0_col1, #T_3c68d_row0_col2, #T_3c68d_row0_col3, #T_3c68d_row0_col4, #T_3c68d_row0_col6, #T_3c68d_row0_col7, #T_3c68d_row0_col8, #T_3c68d_row0_col9, #T_3c68d_row1_col0, #T_3c68d_row1_col1, #T_3c68d_row1_col2, #T_3c68d_row1_col4, #T_3c68d_row1_col7, #T_3c68d_row1_col8, #T_3c68d_row1_col9, #T_3c68d_row2_col0, #T_3c68d_row2_col1, #T_3c68d_row2_col2, #T_3c68d_row2_col6, #T_3c68d_row2_col7, #T_3c68d_row2_col8, #T_3c68d_row2_col9, #T_3c68d_row3_col0, #T_3c68d_row3_col1, #T_3c68d_row3_col2, #T_3c68d_row3_col3, #T_3c68d_row3_col4, #T_3c68d_row3_col6, #T_3c68d_row3_col7, #T_3c68d_row3_col8, #T_3c68d_row3_col9, #T_3c68d_row4_col0, #T_3c68d_row4_col1, #T_3c68d_row4_col2, #T_3c68d_row4_col3, #T_3c68d_row4_col6, #T_3c68d_row4_col7, #T_3c68d_row4_col8, #T_3c68d_row4_col9, #T_3c68d_row5_col0, #T_3c68d_row5_col1, #T_3c68d_row5_col2, #T_3c68d_row5_col3, #T_3c68d_row5_col4, #T_3c68d_row5_col7, #T_3c68d_row5_col8, #T_3c68d_row5_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_3c68d_row0_col5, #T_3c68d_row1_col3, #T_3c68d_row1_col5, #T_3c68d_row2_col4, #T_3c68d_row3_col5, #T_3c68d_row5_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_3c68d_row1_col6, #T_3c68d_row2_col3, #T_3c68d_row2_col5, #T_3c68d_row4_col4, #T_3c68d_row4_col5, #T_3c68d_row5_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_3c68d">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_3c68d_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_3c68d_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_3c68d_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_3c68d_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_3c68d_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_3c68d_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_3c68d_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_3c68d_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_3c68d_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_3c68d_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3c68d_row0_col0" class="data row0 col0" >malango</td>
#       <td id="T_3c68d_row0_col1" class="data row0 col1" >-2.96</td>
#       <td id="T_3c68d_row0_col2" class="data row0 col2" >119.90</td>
#       <td id="T_3c68d_row0_col3" class="data row0 col3" >85.08° F</td>
#       <td id="T_3c68d_row0_col4" class="data row0 col4" >48%</td>
#       <td id="T_3c68d_row0_col5" class="data row0 col5" >10%</td>
#       <td id="T_3c68d_row0_col6" class="data row0 col6" >5.73</td>
#       <td id="T_3c68d_row0_col7" class="data row0 col7" >ID</td>
#       <td id="T_3c68d_row0_col8" class="data row0 col8" >2023-09-22 20:35:57</td>
#       <td id="T_3c68d_row0_col9" class="data row0 col9" >Madarana</td>
#     </tr>
#     <tr>
#       <td id="T_3c68d_row1_col0" class="data row1 col0" >tomohon</td>
#       <td id="T_3c68d_row1_col1" class="data row1 col1" >1.33</td>
#       <td id="T_3c68d_row1_col2" class="data row1 col2" >124.84</td>
#       <td id="T_3c68d_row1_col3" class="data row1 col3" >85.14° F</td>
#       <td id="T_3c68d_row1_col4" class="data row1 col4" >49%</td>
#       <td id="T_3c68d_row1_col5" class="data row1 col5" >10%</td>
#       <td id="T_3c68d_row1_col6" class="data row1 col6" >2.73</td>
#       <td id="T_3c68d_row1_col7" class="data row1 col7" >ID</td>
#       <td id="T_3c68d_row1_col8" class="data row1 col8" >2023-09-22 20:40:55</td>
#       <td id="T_3c68d_row1_col9" class="data row1 col9" >Okoy Flower Garden Resort</td>
#     </tr>
#     <tr>
#       <td id="T_3c68d_row2_col0" class="data row2 col0" >darnah</td>
#       <td id="T_3c68d_row2_col1" class="data row2 col1" >32.77</td>
#       <td id="T_3c68d_row2_col2" class="data row2 col2" >22.64</td>
#       <td id="T_3c68d_row2_col3" class="data row2 col3" >76.37° F</td>
#       <td id="T_3c68d_row2_col4" class="data row2 col4" >63%</td>
#       <td id="T_3c68d_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_3c68d_row2_col6" class="data row2 col6" >6.44</td>
#       <td id="T_3c68d_row2_col7" class="data row2 col7" >LY</td>
#       <td id="T_3c68d_row2_col8" class="data row2 col8" >2023-09-22 20:41:46</td>
#       <td id="T_3c68d_row2_col9" class="data row2 col9" >فندق الفردوس</td>
#     </tr>
#     <tr>
#       <td id="T_3c68d_row3_col0" class="data row3 col0" >taco pozo</td>
#       <td id="T_3c68d_row3_col1" class="data row3 col1" >-25.62</td>
#       <td id="T_3c68d_row3_col2" class="data row3 col2" >-63.28</td>
#       <td id="T_3c68d_row3_col3" class="data row3 col3" >81.28° F</td>
#       <td id="T_3c68d_row3_col4" class="data row3 col4" >57%</td>
#       <td id="T_3c68d_row3_col5" class="data row3 col5" >10%</td>
#       <td id="T_3c68d_row3_col6" class="data row3 col6" >7.76</td>
#       <td id="T_3c68d_row3_col7" class="data row3 col7" >AR</td>
#       <td id="T_3c68d_row3_col8" class="data row3 col8" >2023-09-22 20:41:56</td>
#       <td id="T_3c68d_row3_col9" class="data row3 col9" >Hospedaje El Camionero</td>
#     </tr>
#     <tr>
#       <td id="T_3c68d_row4_col0" class="data row4 col0" >argo</td>
#       <td id="T_3c68d_row4_col1" class="data row4 col1" >37.63</td>
#       <td id="T_3c68d_row4_col2" class="data row4 col2" >22.73</td>
#       <td id="T_3c68d_row4_col3" class="data row4 col3" >76.89° F</td>
#       <td id="T_3c68d_row4_col4" class="data row4 col4" >45%</td>
#       <td id="T_3c68d_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_3c68d_row4_col6" class="data row4 col6" >3.22</td>
#       <td id="T_3c68d_row4_col7" class="data row4 col7" >GR</td>
#       <td id="T_3c68d_row4_col8" class="data row4 col8" >2023-09-22 20:38:01</td>
#       <td id="T_3c68d_row4_col9" class="data row4 col9" >Apollon Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_3c68d_row5_col0" class="data row5 col0" >petrolina</td>
#       <td id="T_3c68d_row5_col1" class="data row5 col1" >-9.40</td>
#       <td id="T_3c68d_row5_col2" class="data row5 col2" >-40.50</td>
#       <td id="T_3c68d_row5_col3" class="data row5 col3" >80.65° F</td>
#       <td id="T_3c68d_row5_col4" class="data row5 col4" >50%</td>
#       <td id="T_3c68d_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_3c68d_row5_col6" class="data row5 col6" >9.22</td>
#       <td id="T_3c68d_row5_col7" class="data row5 col7" >BR</td>
#       <td id="T_3c68d_row5_col8" class="data row5 col8" >2023-09-22 20:42:22</td>
#       <td id="T_3c68d_row5_col9" class="data row5 col9" >Neuman</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
