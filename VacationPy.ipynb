# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function
import VacationPySubRoutines as local_subroutine

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


local_subroutine.SetVacationTemperatureRange(70, 95)

local_subroutine.SetVacationHumidityRange(35, 65)

local_subroutine.SetVacationCloudinessRange(0, 10)

local_subroutine.SetVacationWindPSpeedRange(0, 10)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Vacation Data Acquisition**

# %% [markdown]
# ## **1.1: Data Import from CSV File**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant \
                 .WEATHER_DATA_FILE_PATH,
             local_constant \
                 .WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ## **1.2: Display City Weather Data Set**

# %%
captionString \
    = 'Table: 1.2: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_03d7c caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_03d7c_row0_col0, #T_03d7c_row0_col1, #T_03d7c_row0_col2, #T_03d7c_row0_col4, #T_03d7c_row0_col6, #T_03d7c_row0_col7, #T_03d7c_row0_col8, #T_03d7c_row1_col0, #T_03d7c_row1_col1, #T_03d7c_row1_col2, #T_03d7c_row1_col3, #T_03d7c_row1_col4, #T_03d7c_row1_col6, #T_03d7c_row1_col7, #T_03d7c_row1_col8, #T_03d7c_row2_col0, #T_03d7c_row2_col1, #T_03d7c_row2_col2, #T_03d7c_row2_col3, #T_03d7c_row2_col4, #T_03d7c_row2_col6, #T_03d7c_row2_col7, #T_03d7c_row2_col8, #T_03d7c_row3_col0, #T_03d7c_row3_col1, #T_03d7c_row3_col2, #T_03d7c_row3_col3, #T_03d7c_row3_col4, #T_03d7c_row3_col7, #T_03d7c_row3_col8, #T_03d7c_row4_col0, #T_03d7c_row4_col1, #T_03d7c_row4_col2, #T_03d7c_row4_col6, #T_03d7c_row4_col7, #T_03d7c_row4_col8, #T_03d7c_row5_col0, #T_03d7c_row5_col1, #T_03d7c_row5_col2, #T_03d7c_row5_col3, #T_03d7c_row5_col4, #T_03d7c_row5_col5, #T_03d7c_row5_col6, #T_03d7c_row5_col7, #T_03d7c_row5_col8, #T_03d7c_row6_col0, #T_03d7c_row6_col1, #T_03d7c_row6_col2, #T_03d7c_row6_col3, #T_03d7c_row6_col4, #T_03d7c_row6_col5, #T_03d7c_row6_col6, #T_03d7c_row6_col7, #T_03d7c_row6_col8, #T_03d7c_row7_col0, #T_03d7c_row7_col1, #T_03d7c_row7_col2, #T_03d7c_row7_col3, #T_03d7c_row7_col6, #T_03d7c_row7_col7, #T_03d7c_row7_col8, #T_03d7c_row8_col0, #T_03d7c_row8_col1, #T_03d7c_row8_col2, #T_03d7c_row8_col3, #T_03d7c_row8_col6, #T_03d7c_row8_col7, #T_03d7c_row8_col8, #T_03d7c_row9_col0, #T_03d7c_row9_col1, #T_03d7c_row9_col2, #T_03d7c_row9_col3, #T_03d7c_row9_col4, #T_03d7c_row9_col5, #T_03d7c_row9_col6, #T_03d7c_row9_col7, #T_03d7c_row9_col8, #T_03d7c_row10_col0, #T_03d7c_row10_col1, #T_03d7c_row10_col2, #T_03d7c_row10_col3, #T_03d7c_row10_col4, #T_03d7c_row10_col6, #T_03d7c_row10_col7, #T_03d7c_row10_col8, #T_03d7c_row11_col0, #T_03d7c_row11_col1, #T_03d7c_row11_col2, #T_03d7c_row11_col3, #T_03d7c_row11_col4, #T_03d7c_row11_col5, #T_03d7c_row11_col7, #T_03d7c_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_03d7c_row0_col3, #T_03d7c_row0_col5, #T_03d7c_row1_col5, #T_03d7c_row2_col5, #T_03d7c_row3_col5, #T_03d7c_row7_col4, #T_03d7c_row7_col5, #T_03d7c_row8_col4, #T_03d7c_row8_col5, #T_03d7c_row10_col5, #T_03d7c_row11_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_03d7c_row3_col6, #T_03d7c_row4_col3, #T_03d7c_row4_col4, #T_03d7c_row4_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_03d7c">
#   <caption>Table: 1.2: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_03d7c_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_03d7c_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_03d7c_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_03d7c_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_03d7c_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_03d7c_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_03d7c_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_03d7c_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_03d7c_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_03d7c_row0_col0" class="data row0 col0" >lihue</td>
#       <td id="T_03d7c_row0_col1" class="data row0 col1" >21.98</td>
#       <td id="T_03d7c_row0_col2" class="data row0 col2" >-159.37</td>
#       <td id="T_03d7c_row0_col3" class="data row0 col3" >77.14° F</td>
#       <td id="T_03d7c_row0_col4" class="data row0 col4" >82%</td>
#       <td id="T_03d7c_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_03d7c_row0_col6" class="data row0 col6" >12.66</td>
#       <td id="T_03d7c_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_03d7c_row0_col8" class="data row0 col8" >2023-10-01 23:10:20</td>
#     </tr>
#     <tr>
#       <td id="T_03d7c_row1_col0" class="data row1 col0" >olonkinbyen</td>
#       <td id="T_03d7c_row1_col1" class="data row1 col1" >70.92</td>
#       <td id="T_03d7c_row1_col2" class="data row1 col2" >-8.72</td>
#       <td id="T_03d7c_row1_col3" class="data row1 col3" >32.43° F</td>
#       <td id="T_03d7c_row1_col4" class="data row1 col4" >92%</td>
#       <td id="T_03d7c_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_03d7c_row1_col6" class="data row1 col6" >18.34</td>
#       <td id="T_03d7c_row1_col7" class="data row1 col7" >SJ</td>
#       <td id="T_03d7c_row1_col8" class="data row1 col8" >2023-10-01 23:09:31</td>
#     </tr>
#     <tr>
#       <td id="T_03d7c_row2_col0" class="data row2 col0" >udachny</td>
#       <td id="T_03d7c_row2_col1" class="data row2 col1" >66.42</td>
#       <td id="T_03d7c_row2_col2" class="data row2 col2" >112.40</td>
#       <td id="T_03d7c_row2_col3" class="data row2 col3" >30.45° F</td>
#       <td id="T_03d7c_row2_col4" class="data row2 col4" >92%</td>
#       <td id="T_03d7c_row2_col5" class="data row2 col5" >100%</td>
#       <td id="T_03d7c_row2_col6" class="data row2 col6" >17.29</td>
#       <td id="T_03d7c_row2_col7" class="data row2 col7" >RU</td>
#       <td id="T_03d7c_row2_col8" class="data row2 col8" >2023-10-01 23:12:44</td>
#     </tr>
#     <tr>
#       <td id="T_03d7c_row3_col0" class="data row3 col0" >hawaiian paradise park</td>
#       <td id="T_03d7c_row3_col1" class="data row3 col1" >19.59</td>
#       <td id="T_03d7c_row3_col2" class="data row3 col2" >-154.97</td>
#       <td id="T_03d7c_row3_col3" class="data row3 col3" >74.62° F</td>
#       <td id="T_03d7c_row3_col4" class="data row3 col4" >88%</td>
#       <td id="T_03d7c_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_03d7c_row3_col6" class="data row3 col6" >1.99</td>
#       <td id="T_03d7c_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_03d7c_row3_col8" class="data row3 col8" >2023-10-01 23:09:45</td>
#     </tr>
#     <tr>
#       <td id="T_03d7c_row4_col0" class="data row4 col0" >tiksi</td>
#       <td id="T_03d7c_row4_col1" class="data row4 col1" >71.69</td>
#       <td id="T_03d7c_row4_col2" class="data row4 col2" >128.87</td>
#       <td id="T_03d7c_row4_col3" class="data row4 col3" >24.01° F</td>
#       <td id="T_03d7c_row4_col4" class="data row4 col4" >77%</td>
#       <td id="T_03d7c_row4_col5" class="data row4 col5" >11%</td>
#       <td id="T_03d7c_row4_col6" class="data row4 col6" >2.66</td>
#       <td id="T_03d7c_row4_col7" class="data row4 col7" >RU</td>
#       <td id="T_03d7c_row4_col8" class="data row4 col8" >2023-10-01 23:09:28</td>
#     </tr>
#     <tr>
#       <td id="T_03d7c_row5_col0" class="data row5 col0" >tsiombe</td>
#       <td id="T_03d7c_row5_col1" class="data row5 col1" >-25.30</td>
#       <td id="T_03d7c_row5_col2" class="data row5 col2" >45.48</td>
#       <td id="T_03d7c_row5_col3" class="data row5 col3" >68.83° F</td>
#       <td id="T_03d7c_row5_col4" class="data row5 col4" >80%</td>
#       <td id="T_03d7c_row5_col5" class="data row5 col5" >79%</td>
#       <td id="T_03d7c_row5_col6" class="data row5 col6" >12.71</td>
#       <td id="T_03d7c_row5_col7" class="data row5 col7" >MG</td>
#       <td id="T_03d7c_row5_col8" class="data row5 col8" >2023-10-01 23:10:12</td>
#     </tr>
#     <tr>
#       <td id="T_03d7c_row6_col0" class="data row6 col0" >grand falls-windsor</td>
#       <td id="T_03d7c_row6_col1" class="data row6 col1" >48.93</td>
#       <td id="T_03d7c_row6_col2" class="data row6 col2" >-55.66</td>
#       <td id="T_03d7c_row6_col3" class="data row6 col3" >53.51° F</td>
#       <td id="T_03d7c_row6_col4" class="data row6 col4" >91%</td>
#       <td id="T_03d7c_row6_col5" class="data row6 col5" >52%</td>
#       <td id="T_03d7c_row6_col6" class="data row6 col6" >2.28</td>
#       <td id="T_03d7c_row6_col7" class="data row6 col7" >CA</td>
#       <td id="T_03d7c_row6_col8" class="data row6 col8" >2023-10-01 23:10:16</td>
#     </tr>
#     <tr>
#       <td id="T_03d

# %% [markdown]
# ## **1.3: Display City Weather Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.3: City Weather Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Desired Weather Locations**

# %% [markdown]
# ## **2.1: Establish Desired Weather Conditions for Vacation Locations**

# %%
vacationDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame['Temperature'] \
                >= local_constant \
                      .weatherConditionsDictionary \
                          ['temperatureIntegerList'][0]) \
                 & (cityWeatherDataFrame['Temperature'] \
                        <= local_constant \
                              .weatherConditionsDictionary \
                                  ['temperatureIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Humidity'] \
                      >= local_constant \
                          .weatherConditionsDictionary \
                              ['humidityIntegerList'][0]) \
                  & (vacationDataFrame['Humidity'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                  ['humidityIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Cloudiness'] \
                      >= local_constant \
                            .weatherConditionsDictionary \
                                ['cloudinessIntegerList'][0]) \
                  & (vacationDataFrame['Cloudiness'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                    ['cloudinessIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Wind Speed'] \
                      >= local_constant \
                            .weatherConditionsDictionary \
                                ['windSpeedIntegerList'][0]) 
                  & (vacationDataFrame['Wind Speed'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                    ['windSpeedIntegerList'][1]), :]


log_function \
    .DebugReturnObjectWriteObject \
        (vacationDataFrame)

# %% [markdown]
# ## **2.2: Clean Vacation Data Set**

# %%
vacationDataFrame \
        .dropna \
            (inplace = True)

vacationDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (vacationDataFrame)

# %% [markdown]
# ## **2.3: Display Vacation Data Set**

# %%
captionString \
    = 'Table: 2.3: Vacation Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (vacationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_677e2 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_677e2_row0_col0, #T_677e2_row0_col1, #T_677e2_row0_col2, #T_677e2_row0_col3, #T_677e2_row0_col4, #T_677e2_row0_col6, #T_677e2_row0_col7, #T_677e2_row0_col8, #T_677e2_row1_col0, #T_677e2_row1_col1, #T_677e2_row1_col2, #T_677e2_row1_col3, #T_677e2_row1_col4, #T_677e2_row1_col5, #T_677e2_row1_col6, #T_677e2_row1_col7, #T_677e2_row1_col8, #T_677e2_row2_col0, #T_677e2_row2_col1, #T_677e2_row2_col2, #T_677e2_row2_col3, #T_677e2_row2_col4, #T_677e2_row2_col6, #T_677e2_row2_col7, #T_677e2_row2_col8, #T_677e2_row3_col0, #T_677e2_row3_col1, #T_677e2_row3_col2, #T_677e2_row3_col3, #T_677e2_row3_col5, #T_677e2_row3_col6, #T_677e2_row3_col7, #T_677e2_row3_col8, #T_677e2_row4_col0, #T_677e2_row4_col1, #T_677e2_row4_col2, #T_677e2_row4_col3, #T_677e2_row4_col5, #T_677e2_row4_col6, #T_677e2_row4_col7, #T_677e2_row4_col8, #T_677e2_row5_col0, #T_677e2_row5_col1, #T_677e2_row5_col2, #T_677e2_row5_col3, #T_677e2_row5_col4, #T_677e2_row5_col6, #T_677e2_row5_col7, #T_677e2_row5_col8, #T_677e2_row6_col0, #T_677e2_row6_col1, #T_677e2_row6_col2, #T_677e2_row6_col3, #T_677e2_row6_col4, #T_677e2_row6_col6, #T_677e2_row6_col7, #T_677e2_row6_col8, #T_677e2_row7_col0, #T_677e2_row7_col1, #T_677e2_row7_col2, #T_677e2_row7_col3, #T_677e2_row7_col4, #T_677e2_row7_col6, #T_677e2_row7_col7, #T_677e2_row7_col8, #T_677e2_row8_col0, #T_677e2_row8_col1, #T_677e2_row8_col2, #T_677e2_row8_col4, #T_677e2_row8_col6, #T_677e2_row8_col7, #T_677e2_row8_col8, #T_677e2_row9_col0, #T_677e2_row9_col1, #T_677e2_row9_col2, #T_677e2_row9_col3, #T_677e2_row9_col4, #T_677e2_row9_col6, #T_677e2_row9_col7, #T_677e2_row9_col8, #T_677e2_row10_col0, #T_677e2_row10_col1, #T_677e2_row10_col2, #T_677e2_row10_col3, #T_677e2_row10_col4, #T_677e2_row10_col6, #T_677e2_row10_col7, #T_677e2_row10_col8, #T_677e2_row11_col0, #T_677e2_row11_col1, #T_677e2_row11_col2, #T_677e2_row11_col4, #T_677e2_row11_col7, #T_677e2_row11_col8, #T_677e2_row12_col0, #T_677e2_row12_col1, #T_677e2_row12_col2, #T_677e2_row12_col3, #T_677e2_row12_col4, #T_677e2_row12_col6, #T_677e2_row12_col7, #T_677e2_row12_col8, #T_677e2_row13_col0, #T_677e2_row13_col1, #T_677e2_row13_col2, #T_677e2_row13_col3, #T_677e2_row13_col4, #T_677e2_row13_col7, #T_677e2_row13_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_677e2_row0_col5, #T_677e2_row3_col4, #T_677e2_row11_col3, #T_677e2_row11_col5, #T_677e2_row13_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_677e2_row2_col5, #T_677e2_row4_col4, #T_677e2_row5_col5, #T_677e2_row6_col5, #T_677e2_row7_col5, #T_677e2_row8_col3, #T_677e2_row8_col5, #T_677e2_row9_col5, #T_677e2_row10_col5, #T_677e2_row11_col6, #T_677e2_row12_col5, #T_677e2_row13_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_677e2">
#   <caption>Table: 2.3: Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_677e2_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_677e2_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_677e2_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_677e2_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_677e2_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_677e2_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_677e2_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_677e2_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_677e2_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_677e2_row0_col0" class="data row0 col0" >baise city</td>
#       <td id="T_677e2_row0_col1" class="data row0 col1" >23.90</td>
#       <td id="T_677e2_row0_col2" class="data row0 col2" >106.61</td>
#       <td id="T_677e2_row0_col3" class="data row0 col3" >90.99° F</td>
#       <td id="T_677e2_row0_col4" class="data row0 col4" >53%</td>
#       <td id="T_677e2_row0_col5" class="data row0 col5" >8%</td>
#       <td id="T_677e2_row0_col6" class="data row0 col6" >5.19</td>
#       <td id="T_677e2_row0_col7" class="data row0 col7" >CN</td>
#       <td id="T_677e2_row0_col8" class="data row0 col8" >2023-10-01 23:15:31</td>
#     </tr>
#     <tr>
#       <td id="T_677e2_row1_col0" class="data row1 col0" >al qadarif</td>
#       <td id="T_677e2_row1_col1" class="data row1 col1" >14.03</td>
#       <td id="T_677e2_row1_col2" class="data row1 col2" >35.38</td>
#       <td id="T_677e2_row1_col3" class="data row1 col3" >83.07° F</td>
#       <td id="T_677e2_row1_col4" class="data row1 col4" >62%</td>
#       <td id="T_677e2_row1_col5" class="data row1 col5" >1%</td>
#       <td id="T_677e2_row1_col6" class="data row1 col6" >8.21</td>
#       <td id="T_677e2_row1_col7" class="data row1 col7" >SD</td>
#       <td id="T_677e2_row1_col8" class="data row1 col8" >2023-10-01 23:15:34</td>
#     </tr>
#     <tr>
#       <td id="T_677e2_row2_col0" class="data row2 col0" >gaigeturi</td>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ## **3.1: Add Hotel Column to DataFrame**

# %%
hotelDataFrame \
    = vacationDataFrame.copy()

hotelDataFrame \
    ['Hotel Name'] \
        = pd.Series \
            (dtype= 'str')

hotelDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelDataFrame)

# %% [markdown]
# ## **3.2: Find Hotel Locations**

# %%
updatedHotelDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (hotelDataFrame,
             'Hotel Name',
             'accommodation.hotel',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedHotelDataFrame)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...梦之源大酒店 in baise city, CN
#
#
# Located the following hotel...Alhwad Hotel in al qadarif, SD
#
#
# Located the following hotel...제주 토비스콘도 in gaigeturi, KR
#
#
# Located the following hotel...فندق تاج العرب in al ghayzah, YE
#
#
# Located the following hotel...هتل رستوران سیراف in bushehr, IR
#
#
# Located the following hotel...Boston Hotel in port lincoln, AU
#
#
# Located the following hotel...Hotel Celeste in pachino, IT
#
#
# Located the following hotel...Quality Inn in brookings, US
#
#
# Located the following hotel...The Beach Hotel in aldinga beach, AU
#
#
# Located the following hotel...DoubleTree in abilene, US
#
#
# Located the following hotel...Zota Beach Resort in longboat key, US
#
#
# Located the following hotel...Ramada in urangan, AU
#
#
# hotel search complete

# %% [markdown]
# ## **3.3: Display Hotel Data Set**

# %%
captionString \
    = 'Table: 3.3: Hotel Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedHotelDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_9ffad caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_9ffad_row0_col0, #T_9ffad_row0_col1, #T_9ffad_row0_col2, #T_9ffad_row0_col4, #T_9ffad_row0_col6, #T_9ffad_row0_col7, #T_9ffad_row0_col8, #T_9ffad_row0_col9, #T_9ffad_row1_col0, #T_9ffad_row1_col1, #T_9ffad_row1_col2, #T_9ffad_row1_col3, #T_9ffad_row1_col4, #T_9ffad_row1_col5, #T_9ffad_row1_col6, #T_9ffad_row1_col7, #T_9ffad_row1_col8, #T_9ffad_row1_col9, #T_9ffad_row2_col0, #T_9ffad_row2_col1, #T_9ffad_row2_col2, #T_9ffad_row2_col3, #T_9ffad_row2_col4, #T_9ffad_row2_col6, #T_9ffad_row2_col7, #T_9ffad_row2_col8, #T_9ffad_row2_col9, #T_9ffad_row3_col0, #T_9ffad_row3_col1, #T_9ffad_row3_col2, #T_9ffad_row3_col3, #T_9ffad_row3_col5, #T_9ffad_row3_col6, #T_9ffad_row3_col7, #T_9ffad_row3_col8, #T_9ffad_row3_col9, #T_9ffad_row4_col0, #T_9ffad_row4_col1, #T_9ffad_row4_col2, #T_9ffad_row4_col3, #T_9ffad_row4_col6, #T_9ffad_row4_col7, #T_9ffad_row4_col8, #T_9ffad_row4_col9, #T_9ffad_row5_col0, #T_9ffad_row5_col1, #T_9ffad_row5_col2, #T_9ffad_row5_col3, #T_9ffad_row5_col4, #T_9ffad_row5_col6, #T_9ffad_row5_col7, #T_9ffad_row5_col8, #T_9ffad_row5_col9, #T_9ffad_row6_col0, #T_9ffad_row6_col1, #T_9ffad_row6_col2, #T_9ffad_row6_col3, #T_9ffad_row6_col4, #T_9ffad_row6_col6, #T_9ffad_row6_col7, #T_9ffad_row6_col8, #T_9ffad_row6_col9, #T_9ffad_row7_col0, #T_9ffad_row7_col1, #T_9ffad_row7_col2, #T_9ffad_row7_col4, #T_9ffad_row7_col6, #T_9ffad_row7_col7, #T_9ffad_row7_col8, #T_9ffad_row7_col9, #T_9ffad_row8_col0, #T_9ffad_row8_col1, #T_9ffad_row8_col2, #T_9ffad_row8_col3, #T_9ffad_row8_col4, #T_9ffad_row8_col7, #T_9ffad_row8_col8, #T_9ffad_row8_col9, #T_9ffad_row9_col0, #T_9ffad_row9_col1, #T_9ffad_row9_col2, #T_9ffad_row9_col3, #T_9ffad_row9_col4, #T_9ffad_row9_col6, #T_9ffad_row9_col7, #T_9ffad_row9_col8, #T_9ffad_row9_col9, #T_9ffad_row10_col0, #T_9ffad_row10_col1, #T_9ffad_row10_col2, #T_9ffad_row10_col3, #T_9ffad_row10_col4, #T_9ffad_row10_col6, #T_9ffad_row10_col7, #T_9ffad_row10_col8, #T_9ffad_row10_col9, #T_9ffad_row11_col0, #T_9ffad_row11_col1, #T_9ffad_row11_col2, #T_9ffad_row11_col3, #T_9ffad_row11_col4, #T_9ffad_row11_col7, #T_9ffad_row11_col8, #T_9ffad_row11_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_9ffad_row0_col3, #T_9ffad_row0_col5, #T_9ffad_row3_col4, #T_9ffad_row11_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_9ffad_row2_col5, #T_9ffad_row4_col4, #T_9ffad_row4_col5, #T_9ffad_row5_col5, #T_9ffad_row6_col5, #T_9ffad_row7_col3, #T_9ffad_row7_col5, #T_9ffad_row8_col5, #T_9ffad_row8_col6, #T_9ffad_row9_col5, #T_9ffad_row10_col5, #T_9ffad_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_9ffad">
#   <caption>Table: 3.3: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_9ffad_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_9ffad_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_9ffad_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_9ffad_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_9ffad_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_9ffad_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_9ffad_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_9ffad_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_9ffad_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_9ffad_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T
#     <tr>
#       <td id="T_9ffad_row4_col0" class="data row4 col0" >bushehr</td>
#       <td id="T_9ffad_row4_col1" class="data row4 col1" >28.97</td>
#       <td id="T_9ffad_row4_col2" class="data row4 col2" >50.84</td>
#       <td id="T_9ffad_row4_col3" class="data row4 col3" >89.69° F</td>
#       <td id="T_9ffad_row4_col4" class="data row4 col4" >37%</td>
#       <td id="T_9ffad_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_9ffad_row4_col6" class="data row4 col6" >9.22</td>
#       <td id="T_9ffad_row4_col7" class="data row4 col7" >IR</td>
#       <td id="T_9ffad_row4_col8" class="data row4 col8" >2023-10-01 23:15:51</td>
#       <td id="T_9ffad_row4_col9" class="data row4 col9" >هتل رستوران سیراف</td>
#     </tr>
#     <tr>
#       <td id="T_9ffad_row5_col0" class="data row5 col0" >port lincoln</td>
#       <td id="T_9ffad_row5_col1" class="data row5 col1" >-34.73</td>
#       <td id="T_9ffad_row5_col2" class="data row5 col2" >135.87</td>
#       <td id="T_9ffad_row5_col3" class="data row5 col3" >78.12° F</td>
#       <td id="T_9ffad_row5_col4" class="data row5 col4" >42%</td>
#       <td id="T_9ffad_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_9ffad_row5_col6" class="data row5 col6" >8.19</td>
#       <td id="T_9ffad_row5_col7" class="data row5 col7" >AU</td>
#       <td id="T_9ffad_row5_col8" class="data row5 col8" >2023-10-01 23:09:34</td>
#       <td id="T_9ffa

# %% [markdown]
# ## **3.4: Display Hotel Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelDataFrame,
         'Figure 3.4: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %% [markdown]
# # <br> **Section 4: Restaurant Locations**

# %% [markdown]
# ## **4.1: Add Restaurant Column to DataFrame**

# %%
resturantDataFrame \
    = updatedHotelDataFrame.copy()

resturantDataFrame \
    ['Restaurant Name'] \
        = pd.Series \
            (dtype= 'str')

resturantDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (resturantDataFrame)

# %% [markdown]
# ## **4.2: Find Restaurant Locations**

# %%
updatedResturantDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (resturantDataFrame,
             'Restaurant Name',
             'catering.restaurant',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedResturantDataFrame)
# Out:
# Starting restaurant search...
#
#
# Located the following restaurant...Wardar restuarant (A good fresh fried meat place) in al qadarif, SD
#
#
# Located the following restaurant...Jeju Bandibul Handam in gaigeturi, KR
#
#
# Located the following restaurant...مطعم عدن in al ghayzah, YE
#
#
# Located the following restaurant...جگرکی خاتون in bushehr, IR
#
#
# Located the following restaurant...The Marina Hotel in port lincoln, AU
#
#
# Located the following restaurant...L'Approdo in pachino, IT
#
#
# Located the following restaurant...Pizza Hut in brookings, US
#
#
# Located the following restaurant...Star of Greece in aldinga beach, AU
#
#
# Located the following restaurant...Cypress Street Station in abilene, US
#
#
# Located the following restaurant...Harry's Gourmet Deli in longboat key, US
#
#
# Located the following restaurant...Pier in urangan, AU
#
#
# restaurant search complete

# %% [markdown]
# ## **4.3: Display Restaurant Data Set**

# %%
captionString \
    = 'Table: 4.3: Restaurant Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedResturantDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_0c2b6 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_0c2b6_row0_col0, #T_0c2b6_row0_col1, #T_0c2b6_row0_col2, #T_0c2b6_row0_col3, #T_0c2b6_row0_col4, #T_0c2b6_row0_col5, #T_0c2b6_row0_col6, #T_0c2b6_row0_col7, #T_0c2b6_row0_col8, #T_0c2b6_row0_col9, #T_0c2b6_row0_col10, #T_0c2b6_row1_col0, #T_0c2b6_row1_col1, #T_0c2b6_row1_col2, #T_0c2b6_row1_col3, #T_0c2b6_row1_col4, #T_0c2b6_row1_col6, #T_0c2b6_row1_col7, #T_0c2b6_row1_col8, #T_0c2b6_row1_col9, #T_0c2b6_row1_col10, #T_0c2b6_row2_col0, #T_0c2b6_row2_col1, #T_0c2b6_row2_col2, #T_0c2b6_row2_col3, #T_0c2b6_row2_col6, #T_0c2b6_row2_col7, #T_0c2b6_row2_col8, #T_0c2b6_row2_col9, #T_0c2b6_row2_col10, #T_0c2b6_row3_col0, #T_0c2b6_row3_col1, #T_0c2b6_row3_col2, #T_0c2b6_row3_col6, #T_0c2b6_row3_col7, #T_0c2b6_row3_col8, #T_0c2b6_row3_col9, #T_0c2b6_row3_col10, #T_0c2b6_row4_col0, #T_0c2b6_row4_col1, #T_0c2b6_row4_col2, #T_0c2b6_row4_col3, #T_0c2b6_row4_col4, #T_0c2b6_row4_col6, #T_0c2b6_row4_col7, #T_0c2b6_row4_col8, #T_0c2b6_row4_col9, #T_0c2b6_row4_col10, #T_0c2b6_row5_col0, #T_0c2b6_row5_col1, #T_0c2b6_row5_col2, #T_0c2b6_row5_col3, #T_0c2b6_row5_col4, #T_0c2b6_row5_col6, #T_0c2b6_row5_col7, #T_0c2b6_row5_col8, #T_0c2b6_row5_col9, #T_0c2b6_row5_col10, #T_0c2b6_row6_col0, #T_0c2b6_row6_col1, #T_0c2b6_row6_col2, #T_0c2b6_row6_col4, #T_0c2b6_row6_col6, #T_0c2b6_row6_col7, #T_0c2b6_row6_col8, #T_0c2b6_row6_col9, #T_0c2b6_row6_col10, #T_0c2b6_row7_col0, #T_0c2b6_row7_col1, #T_0c2b6_row7_col2, #T_0c2b6_row7_col3, #T_0c2b6_row7_col4, #T_0c2b6_row7_col7, #T_0c2b6_row7_col8, #T_0c2b6_row7_col9, #T_0c2b6_row7_col10, #T_0c2b6_row8_col0, #T_0c2b6_row8_col1, #T_0c2b6_row8_col2, #T_0c2b6_row8_col3, #T_0c2b6_row8_col4, #T_0c2b6_row8_col6, #T_0c2b6_row8_col7, #T_0c2b6_row8_col8, #T_0c2b6_row8_col9, #T_0c2b6_row8_col10, #T_0c2b6_row9_col0, #T_0c2b6_row9_col1, #T_0c2b6_row9_col2, #T_0c2b6_row9_col3, #T_0c2b6_row9_col4, #T_0c2b6_row9_col6, #T_0c2b6_row9_col7, #T_0c2b6_row9_col8, #T_0c2b6_row9_col9, #T_0c2b6_row9_col10, #T_0c2b6_row10_col0, #T_0c2b6_row10_col1, #T_0c2b6_row10_col2, #T_0c2b6_row10_col3, #T_0c2b6_row10_col4, #T_0c2b6_row10_col7, #T_0c2b6_row10_col8, #T_0c2b6_row10_col9, #T_0c2b6_row10_col10 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_0c2b6_row1_col5, #T_0c2b6_row3_col4, #T_0c2b6_row3_col5, #T_0c2b6_row4_col5, #T_0c2b6_row5_col5, #T_0c2b6_row6_col3, #T_0c2b6_row6_col5, #T_0c2b6_row7_col5, #T_0c2b6_row7_col6, #T_0c2b6_row8_col5, #T_0c2b6_row9_col5, #T_0c2b6_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_0c2b6_row2_col4, #T_0c2b6_row2_col5, #T_0c2b6_row3_col3, #T_0c2b6_row10_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_0c2b6">
#   <caption>Table: 4.3: Restaurant Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_0c2b6_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_0c2b6_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_0c2b6_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_0c2b6_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_0c2b6_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_0c2b6_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_0c2b6_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_0c2b6_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_0c2b6_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_0c2b6_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#       <th id="T_0c2b6_level0_col10" class="col_heading level0 col10" >Restaurant Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0c2b6_row0_col0" class="data row0 col0" >al qadarif</td>
#       <td id="T_0c2b6_row0_col1" class="data row0 col1" >14.03</td>
#       <td id="T_0c2b6_row0_col2" class="data row0 col2" >35.38</td>
#       <td id="T_0c2b6_row0_col3" class="data row0 col3" >83.07° F</td>
#       <td id="T_0c2b6_row0_col4" class="data row0 col4" >62%</td>
#       <td id="T_0c2b6_row0_col5" class="data row0 col5" >1%</td>
#       <td id="T_0c2b6_row0_col6" class="data row0 col6" >8.21</td>
#       <td id="T_0c2b6_row0_col7" class="data row0 col7" >SD</td>
#       <td id="T_0c2b6_row0_col8" class="data row0 col8" >2023-10-01 23:15:34</td>
#       <td id="T_0c2b6_row0_col9" class="data row0 col9" >Alhwad Hotel</td>
#       <td id="T_0c2b6_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_0c2b6_row4_col6" class="data row4 col6" >8.19</td>
#       <td id="T_0c2b6_row4_col7" class="data row4 col7" >AU</td>
#       <td id="T_0c2b6_row4_col8" class="data row4 col8" >2023-10-01 23:09:34</td>
#       <td id="T_0c2b6_row4_col9" class="data row4 col9" >Boston Hotel</td>
#       <td id="T_0c2b6_row4_col10" class="data row4 col10" >The Marina Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_0c2b6_row5_col0" class="data row5 col0" >pachino</td>
#       <td id="T_0c2b6_r

# %% [markdown]
# ## **4.4: Display Restaurant Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Hotel Name', 
       'Restaurant Name'
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedResturantDataFrame,
         'Figure 4.4: Restaurant Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name)

# %% [markdown]
# # <br> **Section 5: Tourism Attraction Locations**

# %% [markdown]
# ## **5.1: Add Tourism Attraction Column to DataFrame**

# %%
tourismAttractionDataFrame \
    = updatedResturantDataFrame.copy()

tourismAttractionDataFrame \
    ['Tourism Attraction'] \
        = pd.Series \
            (dtype= 'str')

tourismAttractionDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (tourismAttractionDataFrame)

# %% [markdown]
# ## **5.2: Find Tourism Attraction Locations**

# %%
updatedTourismAttractionDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (tourismAttractionDataFrame,
             'Tourism Attraction',
             'tourism.attraction',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedTourismAttractionDataFrame)
# Out:
# Starting tourism attraction search...
#
#
# Located the following tourism attraction...Sudanese Red Crescent Society in al qadarif, SD
#
#
# Located the following tourism attraction...Aewol coastal walk in gaigeturi, KR
#
#
# Located the following tourism attraction...قبر ژنرال in bushehr, IR
#
#
# Located the following tourism attraction...Old Mill Lookout in port lincoln, AU
#
#
# Located the following tourism attraction...Tonnara di Marzamemi in pachino, IT
#
#
# Located the following tourism attraction...Touchdown Jesus in brookings, US
#
#
# Located the following tourism attraction...Maslin Beach in aldinga beach, AU
#
#
# Located the following tourism attraction...Flamingo With Sunglasses in abilene, US
#
#
# Located the following tourism attraction...Public Beach Access Point in longboat key, US
#
#
# Located the following tourism attraction...Freedom Whale Watch and Charters in urangan, AU
#
#
# tourism attraction search complete

# %% [markdown]
# ## **5.3: Display Tourism Attraction Data Set**

# %%
captionString \
    = 'Table: 5.3: Tourism Attraction Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedTourismAttractionDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_a4e68 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
{
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_a4e68_row1_col5, #T_a4e68_row2_col4, #T_a4e68_row2_col5, #T_a4e68_row3_col5, #T_a4e68_row4_col5, #T_a4e68_row5_col3, #T_a4e68_row5_col5, #T_a4e68_row6_col5, #T_a4e68_row6_col6, #T_a4e68_row7_col5, #T_a4e68_row8_col5, #T_a4e68_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_a4e68">
#   <caption>Table: 5.3: Tourism Attraction Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_a4e68_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_a4e68_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_a4e68_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_a4e68_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_a4e68_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_a4e68_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_a4e68_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_a4e68_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_a4e68_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_a4e68_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#       <th id="T_a4e68_level0_col10" class="col_heading level0 col10" >Restaurant Name</th>
#       <th id="T_a4e68_level0_col11" class="col_heading level0 col11" >Tourism Attraction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a4e68_row0_col0" class="data row0 col0" >al qadarif</td>
#       <td id="T_a4e68_row0_col1" class="data row0 col1" >14.03</td>
#       <td id="T_a4e68_row0_col2" class="data row0 col2" >35.38</td>
#       <td id="T_a4e68_row0_col3" class="data row0 col3" >83.07° F</td>
#       <td id="T_a4e68_row0_col4" class="data row0 col4" >62%</td>
#       <td id="T_a4e68_row0_col5" class="data row0 col5" >1%</td>
#       <td id="T_a4e68_row0_col6" class="data row0 col6" >8.21</td>
#       <td id="T_a4e68_row0_col7" class="data row0 col7" >SD</td>
#       <td id="T_a4e68_row0_col8" class="data row0 col8" >2023-10-01 23:15:34</td>
#       <td id="T_a4e68_row0_col9" class="data row0 col9" >Alhwad Hotel</td>
#       <td id="T_a4e68_row0_col10" class="data row0 col10" >Wardar restuarant (A good fresh fried meat place)</td>
#       <td id="T_a4e68_row0_col11" class="data row0 col11" >Sudanese Red Crescent Society</td>
#     </tr>
#     <tr>
#       <td id="T_a4e68_row1_col0" class="data row1 col0" >gaigeturi</td>
#       <td id="T_a4e68_row1_col1" class="data row1 col1" >33.46</td>
#       <td id="T_a4e68_row1_col2" class="data row1 col2" >126.32</td>
#       <td id="T_a4e68_row1_col3" class="data row1 col3" >73.45° F</td>
#       <td id="T_a4e68_row1_col4" class="data row1 col4" >40%</td>
#       <td id="T_a4e68_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_a4e68_row1_col6" class="data row1 col6" >9.22</td>
#       <td id="T_a4e68_row1_col7" class="data row1 col7" >KR</td>
#       <td id="T_a4e68_row1_col8" class="data row1 col8" >2023-10-01 23:15:46</td>
#       <td id="T_a4e68_row1_col9" class="data row1 col9" >제주 토비스콘도</td>
#       <td id="T_a4e68_row1_col10" class="data row1 col10" >Jeju Bandibul Handam</td>
#       <td id="T_a4e68_row1_col11" class="data row1 col11" >Aewol coastal walk</td>
#     </tr>
#     <tr>
#       <td id="T_a4e68_row2_col0" class="data row2 col0" >bushehr</td>
#       <td id="T_a4e68_row2_col1" class="data row2 col1" >28.97</td>
#       <td id="T_a4e68_row2_col2" class="data row2 col2" >50.84</td>
#       <td id="T_a4e68_row2_col3" class="data row2 col3" >89.69° F</td>
#       <td id="T_a4e68_row2_col4" class="data row2 col4" >37%</td>
#       <td id="T_a4e68_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_a4e68_row2_col6" class="data row2 col6" >9.22</td>
#       <td id="T_a4e68_row2_col7" class="data row2 col7" >IR</td>
#       <td id="T_a4e68_row2_col8" class="data row2 col8" >2023-10-01 23:15:51</td>
#       <td id="T_a4e68_row2_col9" class="data row2 col9" >هتل رستوران سیراف</td>
#       <td id="T_a4e68_row2_col10" class="data row2 col10" >جگرکی خاتون</td>
#       <td id="T_a4e68_row2_col11" class="data row2 col11" >قبر ژنرال</td>
#     </tr>
#     <tr>
#       <td id="T_a4e68_row3_col0" class="data row3 col0" >port lincoln</td>
#       <td id="T_a4e68_row3_col1" class="data row3 col1" >-34.73</td>
#       <td id="T_a4e68_row3_col2" class="data row3 col2" >135.87</td>
#       <td id="T_a4e68_row3_col3" class="data row3 col3" >78.12° F</td>
#       <td id="T_a4e68_row3_col4" class="data row3 col4" >42%</td>
#       <td id="T_a4e68_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_a4e68_row3_col6" class="data row3 col6" >8.19</td>
#       <td id="T_a4e68_row3_col7" class="data row3 col7" >AU</td>
#       <td id="T_a4e68_row3_col8" class="data row3 col8" >2023-10-01 23:09:34</td>
#       <td id="T_a4e68_row3_col9" class="data row3 col9" >Boston Hotel</td>
#       <td id="T_a4e68_row3_col10" class="data row3 col10" >The Marina Hotel</td>
#       <td id="T_a4e68_row3_col11" class="data row3 col11" >Old Mill Lookout</td>
#     </tr>
#     <tr>
#       <td id="T_a4e68_row4_col0" class="data row4 col0" >pachino</td>
#       <td id="T_a4e68_row4_col1" class="data row4 col1" >36.72</td>
#       <td id="T_a4e68_row4_col2" class="data row4 col2" >15.09</td>
#       <td id="T_a4e68_row4_col3" class="data row4 col3" >72.05° F</td>
#       <td id="T_a4e68_row4_col4" class="data row4 col4" >62%</td>
#       <td id="T_a4e68_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_a4e68_row4_col6" class="data row4 col6" >6.02</td>

# %% [markdown]
# ## **5.4: Display Tourism Attraction Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Hotel Name', 
       'Restaurant Name',
       'Tourism Attraction',
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedTourismAttractionDataFrame,
         'Figure 5.4: Tourism Attraction Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Restaurant Name,Tourism Attraction,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
