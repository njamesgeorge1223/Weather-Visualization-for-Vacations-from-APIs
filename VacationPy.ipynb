# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function
import VacationPySubRoutines as local_subroutine

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


local_subroutine.SetVacationTemperatureRange(70, 95)

local_subroutine.SetVacationHumidityRange(35, 65)

local_subroutine.SetVacationCloudinessRange(0, 10)

local_subroutine.SetVacationWindPSpeedRange(0, 10)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Vacation Data Acquisition**

# %% [markdown]
# ## **1.1: Data Import from CSV File**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant \
                 .WEATHER_DATA_FILE_PATH,
             local_constant \
                 .WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ## **1.2: Display City Weather Data Set**

# %%
captionString \
    = 'Table: 1.2: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_056ed caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_056ed_row0_col0, #T_056ed_row0_col1, #T_056ed_row0_col2, #T_056ed_row0_col4, #T_056ed_row0_col5, #T_056ed_row0_col6, #T_056ed_row0_col7, #T_056ed_row0_col8, #T_056ed_row1_col0, #T_056ed_row1_col1, #T_056ed_row1_col2, #T_056ed_row1_col3, #T_056ed_row1_col4, #T_056ed_row1_col6, #T_056ed_row1_col7, #T_056ed_row1_col8, #T_056ed_row2_col0, #T_056ed_row2_col1, #T_056ed_row2_col2, #T_056ed_row2_col3, #T_056ed_row2_col4, #T_056ed_row2_col7, #T_056ed_row2_col8, #T_056ed_row3_col0, #T_056ed_row3_col1, #T_056ed_row3_col2, #T_056ed_row3_col3, #T_056ed_row3_col4, #T_056ed_row3_col6, #T_056ed_row3_col7, #T_056ed_row3_col8, #T_056ed_row4_col0, #T_056ed_row4_col1, #T_056ed_row4_col2, #T_056ed_row4_col3, #T_056ed_row4_col4, #T_056ed_row4_col5, #T_056ed_row4_col6, #T_056ed_row4_col7, #T_056ed_row4_col8, #T_056ed_row5_col0, #T_056ed_row5_col1, #T_056ed_row5_col2, #T_056ed_row5_col3, #T_056ed_row5_col4, #T_056ed_row5_col6, #T_056ed_row5_col7, #T_056ed_row5_col8, #T_056ed_row6_col0, #T_056ed_row6_col1, #T_056ed_row6_col2, #T_056ed_row6_col3, #T_056ed_row6_col4, #T_056ed_row6_col7, #T_056ed_row6_col8, #T_056ed_row7_col0, #T_056ed_row7_col1, #T_056ed_row7_col2, #T_056ed_row7_col3, #T_056ed_row7_col4, #T_056ed_row7_col5, #T_056ed_row7_col6, #T_056ed_row7_col7, #T_056ed_row7_col8, #T_056ed_row8_col0, #T_056ed_row8_col1, #T_056ed_row8_col2, #T_056ed_row8_col3, #T_056ed_row8_col4, #T_056ed_row8_col5, #T_056ed_row8_col6, #T_056ed_row8_col7, #T_056ed_row8_col8, #T_056ed_row9_col0, #T_056ed_row9_col1, #T_056ed_row9_col2, #T_056ed_row9_col3, #T_056ed_row9_col6, #T_056ed_row9_col7, #T_056ed_row9_col8, #T_056ed_row10_col0, #T_056ed_row10_col1, #T_056ed_row10_col2, #T_056ed_row10_col3, #T_056ed_row10_col4, #T_056ed_row10_col6, #T_056ed_row10_col7, #T_056ed_row10_col8, #T_056ed_row11_col0, #T_056ed_row11_col1, #T_056ed_row11_col2, #T_056ed_row11_col5, #T_056ed_row11_col6, #T_056ed_row11_col7, #T_056ed_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_056ed_row0_col3, #T_056ed_row1_col5, #T_056ed_row2_col5, #T_056ed_row2_col6, #T_056ed_row3_col5, #T_056ed_row5_col5, #T_056ed_row10_col5, #T_056ed_row11_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_056ed_row6_col5, #T_056ed_row6_col6, #T_056ed_row9_col4, #T_056ed_row9_col5, #T_056ed_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_056ed">
#   <caption>Table: 1.2: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_056ed_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_056ed_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_056ed_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_056ed_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_056ed_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_056ed_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_056ed_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_056ed_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_056ed_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_056ed_row0_col0" class="data row0 col0" >copala</td>
#       <td id="T_056ed_row0_col1" class="data row0 col1" >16.65</td>
#       <td id="T_056ed_row0_col2" class="data row0 col2" >-98.98</td>
#       <td id="T_056ed_row0_col3" class="data row0 col3" >83.97° F</td>
#       <td id="T_056ed_row0_col4" class="data row0 col4" >63%</td>
#       <td id="T_056ed_row0_col5" class="data row0 col5" >24%</td>
#       <td id="T_056ed_row0_col6" class="data row0 col6" >4.61</td>
#       <td id="T_056ed_row0_col7" class="data row0 col7" >MX</td>
#       <td id="T_056ed_row0_col8" class="data row0 col8" >2023-11-25 15:05:36</td>
#     </tr>
#     <tr>
#       <td id="T_056ed_row1_col0" class="data row1 col0" >waitangi</td>
#       <td id="T_056ed_row1_col1" class="data row1 col1" >-43.95</td>
#       <td id="T_056ed_row1_col2" class="data row1 col2" >-176.56</td>
#       <td id="T_056ed_row1_col3" class="data row1 col3" >61.83° F</td>
#       <td id="T_056ed_row1_col4" class="data row1 col4" >97%</td>
#       <td id="T_056ed_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_056ed_row1_col6" class="data row1 col6" >8.01</td>
#       <td id="T_056ed_row1_col7" class="data row1 col7" >NZ</td>
#       <td id="T_056ed_row1_col8" class="data row1 col8" >2023-11-25 15:05:36</td>
#     </tr>
#     <tr>
#       <td id="T_056ed_row2_col0" class="data row2 col0" >adamstown</td>
#       <td id="T_056ed_row2_col1" class="data row2 col1" >-25.07</td>
#       <td id="T_056ed_row2_col2" class="data row2 col2" >-130.10</td>
#       <td id="T_056ed_row2_col3" class="data row2 col3" >71.20° F</td>
#       <td id="T_056ed_row2_col4" class="data row2 col4" >82%</td>
#       <td id="T_056ed_row2_col5" class="data row2 col5" >100%</td>
#       <td id="T_056ed_row2_col6" class="data row2 col6" >24.72</td>
#       <td id="T_056ed_row2_col7" class="data row2 col7" >PN</td>
#       <td id="T_056ed_row2_col8" class="data row2 col8" >2023-11-25 15:05:36</td>
#     </tr>
#     <tr>
#       <td id="T_056ed_row3_col0" class="data row3 col0" >labrador city</td>
#       <td id="T_056ed_row3_col1" class="data row3 col1" >52.95</td>
#       <td id="T_056ed_row3_col2" class="data row3 col2" >-66.91</td>
#       <td id="T_056ed_row3_col3" class="data row3 col3" >12.11° F</td>
#       <td id="T_056ed_row3_col4" class="data row3 col4" >62%</td>
#       <td id="T_056ed_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_056ed_row3_col6" class="data row3 col6" >17.27</td>
#       <td id="T_056ed_row3_col7" class="data row3 col7" >CA</td>
#       <td id="T_056ed_row3_col8" class="data row3 col8" >2023-11-25 15:03:00</td>
#     </tr>
#     <tr>
#       <td id="T_056ed_row4_col0" class="data row4 col0" >puerto natales</td>
#       <td id="T_056ed_row4_col1" class="data row4 col1" >-51.72</td>
#       <td id="T_056ed_row4_col2" class="data row4 col2" >-72.49</td>
#       <td id="T_056ed_row4_col3" class="data row4 col3" >45.37° F</td>
#       <td id="T_056ed_row4_col4" class="data row4 col4" >81%</td>
#       <td id="T_056ed_row4_col5" class="data row4 col5" >42%</td>
#       <td id="T_056ed_row4_col6" class="data row4 col6" >18.45</td>
#       <td id="T_056ed_row4_col7" class="data row4 col7" >CL</td>
#       <td id="T_056ed_row4_col8" class="data row4 col8" >2023-11-25 15:05:37</td>
#     </tr>
#     <tr>
#       <td id="T_056ed_row5_col0" class="data row5 col0" >whitehorse</td>
#       <td id="T_056ed_row5_col1" class="data row5 col1" >60.72</td>
#       <td id="T_056ed_row5_col2" class="data row5 col2" >-135.05</td>
#       <td id="T_056ed_row5_col3" class="data row5 col3" >30.63° F</td>
#       <td id="T_056ed_row5_col4" class="data row5 col4" >92%</td>
#       <td id="T_056ed_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_056ed_row5_col6" class="data row5 col6" >2.30</td>
#       <td id="T_056ed_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_056ed_row5_col8" class="data row5 col8" >2023-11-25 15:01:48</td>
#     </tr>
#     <tr>
#       <td id="T_056ed_row6_col0" class="data row6 col0" >bethel</td>
#       <td id="T_056ed_row6_col1" class="data row6 col1" >41.37</td>
#       <td id="T_056ed_row6_col2" class="data row6 col2" >-73.41</td>
#       <td id="T_056ed_row6_col3" class="data row6 col3" >32.50° F</td>
#       <td id="T_056ed_row6_col4" class="data row6 col4" >58%</td>
#       <td id="T_056ed_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_056ed_row6_col6" class="data row6 col6" >0.00</td>
#       <td id="T_056ed_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_056ed_row6_col8" class="data row6 col8" >2023-11-25 15:02:38</td>
#     </tr>
#     <tr>
#       <td id="T_056ed_row7

# %% [markdown]
# ## **1.3: Display City Weather Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.3: City Weather Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Desired Weather Locations**

# %% [markdown]
# ## **2.1: Establish Desired Weather Conditions for Vacation Locations**

# %%
vacationDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame['Temperature'] \
                >= local_constant \
                      .weatherConditionsDictionary \
                          ['temperatureIntegerList'][0]) \
                 & (cityWeatherDataFrame['Temperature'] \
                        <= local_constant \
                              .weatherConditionsDictionary \
                                  ['temperatureIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Humidity'] \
                      >= local_constant \
                          .weatherConditionsDictionary \
                              ['humidityIntegerList'][0]) \
                  & (vacationDataFrame['Humidity'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                  ['humidityIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Cloudiness'] \
                      >= local_constant \
                            .weatherConditionsDictionary \
                                ['cloudinessIntegerList'][0]) \
                  & (vacationDataFrame['Cloudiness'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                    ['cloudinessIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Wind Speed'] \
                      >= local_constant \
                            .weatherConditionsDictionary \
                                ['windSpeedIntegerList'][0]) 
                  & (vacationDataFrame['Wind Speed'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                    ['windSpeedIntegerList'][1]), :]


log_function \
    .DebugReturnObjectWriteObject \
        (vacationDataFrame)

# %% [markdown]
# ## **2.2: Clean Vacation Data Set**

# %%
vacationDataFrame \
        .dropna \
            (inplace = True)

vacationDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (vacationDataFrame)

# %% [markdown]
# ## **2.3: Display Vacation Data Set**

# %%
captionString \
    = 'Table: 2.3: Vacation Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (vacationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_d19da caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d19da_row0_col0, #T_d19da_row0_col1, #T_d19da_row0_col2, #T_d19da_row0_col3, #T_d19da_row0_col4, #T_d19da_row0_col6, #T_d19da_row0_col7, #T_d19da_row0_col8, #T_d19da_row1_col0, #T_d19da_row1_col1, #T_d19da_row1_col2, #T_d19da_row1_col4, #T_d19da_row1_col6, #T_d19da_row1_col7, #T_d19da_row1_col8, #T_d19da_row2_col0, #T_d19da_row2_col1, #T_d19da_row2_col2, #T_d19da_row2_col3, #T_d19da_row2_col4, #T_d19da_row2_col6, #T_d19da_row2_col7, #T_d19da_row2_col8, #T_d19da_row3_col0, #T_d19da_row3_col1, #T_d19da_row3_col2, #T_d19da_row3_col3, #T_d19da_row3_col4, #T_d19da_row3_col6, #T_d19da_row3_col7, #T_d19da_row3_col8, #T_d19da_row4_col0, #T_d19da_row4_col1, #T_d19da_row4_col2, #T_d19da_row4_col3, #T_d19da_row4_col7, #T_d19da_row4_col8, #T_d19da_row5_col0, #T_d19da_row5_col1, #T_d19da_row5_col2, #T_d19da_row5_col3, #T_d19da_row5_col4, #T_d19da_row5_col6, #T_d19da_row5_col7, #T_d19da_row5_col8, #T_d19da_row6_col0, #T_d19da_row6_col1, #T_d19da_row6_col2, #T_d19da_row6_col3, #T_d19da_row6_col4, #T_d19da_row6_col6, #T_d19da_row6_col7, #T_d19da_row6_col8, #T_d19da_row7_col0, #T_d19da_row7_col1, #T_d19da_row7_col2, #T_d19da_row7_col3, #T_d19da_row7_col4, #T_d19da_row7_col7, #T_d19da_row7_col8, #T_d19da_row8_col0, #T_d19da_row8_col1, #T_d19da_row8_col2, #T_d19da_row8_col6, #T_d19da_row8_col7, #T_d19da_row8_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_d19da_row0_col5, #T_d19da_row1_col3, #T_d19da_row1_col5, #T_d19da_row2_col5, #T_d19da_row3_col5, #T_d19da_row4_col5, #T_d19da_row4_col6, #T_d19da_row5_col5, #T_d19da_row6_col5, #T_d19da_row7_col5, #T_d19da_row8_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_d19da_row4_col4, #T_d19da_row7_col6, #T_d19da_row8_col3, #T_d19da_row8_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_d19da">
#   <caption>Table: 2.3: Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_d19da_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_d19da_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_d19da_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_d19da_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_d19da_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_d19da_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_d19da_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_d19da_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_d19da_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d19da_row0_col0" class="data row0 col0" >sultanah</td>
#       <td id="T_d19da_row0_col1" class="data row0 col1" >24.49</td>
#       <td id="T_d19da_row0_col2" class="data row0 col2" >39.59</td>
#       <td id="T_d19da_row0_col3" class="data row0 col3" >75.65° F</td>
#       <td id="T_d19da_row0_col4" class="data row0 col4" >57%</td>
#       <td id="T_d19da_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_d19da_row0_col6" class="data row0 col6" >5.75</td>
#       <td id="T_d19da_row0_col7" class="data row0 col7" >SA</td>
#       <td id="T_d19da_row0_col8" class="data row0 col8" >2023-11-25 15:05:50</td>
#     </tr>
#     <tr>
#       <td id="T_d19da_row1_col0" class="data row1 col0" >illapel</td>
#       <td id="T_d19da_row1_col1" class="data row1 col1" >-31.63</td>
#       <td id="T_d19da_row1_col2" class="data row1 col2" >-71.17</td>
#       <td id="T_d19da_row1_col3" class="data row1 col3" >74.59° F</td>
#       <td id="T_d19da_row1_col4" class="data row1 col4" >44%</td>
#       <td id="T_d19da_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_d19da_row1_col6" class="data row1 col6" >6.73</td>
#       <td id="T_d19da_row1_col7" class="data row1 col7" >CL</td>
#       <td id="T_d19da_row1_col8" class="data row1 col8" >2023-11-25 15:06:00</td>
#     </tr>
#     <tr>
#       <td id="T_d19da_row2_col0" class="data row2 col0" >mermoz boabab</td>
#       <td id="T_d19da_row2_col1" class="data row2 col1" >14.71</td>
#       <td id="T_d19da_row2_col2" class="data row2 col2" >-17.48</td>
#       <td id="T_d19da_row2_col3" class="data row2 col3" >78.58° F</td>
#       <td id="T_d19da_row2_col4" class="data row2 col4" >61%</td>
#       <td id="T_d19da_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_d19da_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_d19da_row2_col7" class="data row2 col7" >SN</td>
#       <td id="T_d19da_row2_col8" class="data row2 col8" >2023-11-25 15:06:01</td>
#     </tr>
#     <tr>
#       <td id="T_d19da_row3_col0" class="data row3 col0" >coahuayana de hidalgo</td>
#       <td id="T_d19da_row3_col1" class="data row3 col1" >18.70</td>
#       <td id="T_d19da_row3_col2" class="data row3 col2" >-103.66</td>
#       <td id="T_d19da_row3_col3" class="data row3 col3" >84.79° F</td>
#       <td id="T_d19da_row3_col4" class="data row3 col4" >53%</td>
#       <td id="T_d19da_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_d19da_row3_col6" class="data row3 col6" >4.74</td>
#       <td id="T_d19da_row3_col7" class="data row3 col7" >MX</td>
#       <td id="T_d19da_row3_col8" class="data row3 col8" >2023-11-25 15:06:25</td>
#     </tr>
#     <tr>
#       <td id="T_d19da_row4_col0" class="data row4 col0" >jeddah</td>
#       <td id="T_d19da_row4_col1" class="data row4 col1" >21.52</td>
#       <td id="T_d19da_row4_col2" class="data row4 col2" >39.22</td>
#       <td id="T_d19da_row4_col3" class="data row4 col3" >82.26° F</td>
#       <td id="T_d19da_row4_col4" class="data row4 col4" >65%</td>
#       <td id="T_d19da_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_d19da_row4_col6" class="data row4 col6" >3.44</td>
#       <td id="T_d19da_row4_col7" class="data row4 col7" >SA</td>
#       <td id="T_d19da_row4_col8" class="data row4 col8" >2023-11-25 15:03:46</td>
#     </tr>
#     <tr>
#       <td id="T_d19da_row5_col0" class="data row5 col0" >lazaro cardenas</td>
#       <td id="T_d19da_row5_col1" class="data row5 col1" >17.96</td>
#       <td id="T_d19da_row5_col2" class="data row5 col2" >-102.20</td>
#       <td id="T_d19da_row5_col3" class="data row5 col3" >85.15° F</td>
#       <td id="T_d19da_row5_col4" class="data row5 col4" >57%</td>
#       <td id="T_d19da_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_d19da_row5_col6" class="data row5 col6" >5.39</td>
#       <td id="T_d19da_row5_col7" class="data row5 col7" >MX</td>
#       <td id="T_d19da_row5_col8" class="data row5 col8" >2023-11-25 15:03:59</td>
#     </tr>
#     <tr>
#       <td id="T_d19da_row6_col0" class="data row6 col0" >ixtapa</td>
#       <td id="T_d19da_row6_col1" class="data row6 col1" >20.70</td>
#       <td id="T_d19da_row6_col2" class="data row6 col2" >-105.20</td>
#       <td id="T_d19da_row6_col3" class="data row6 col3" >81.63° F</td>
#       <td id="T_d19da_row6_col4" class="data row6 col4" >61%</td>
#       <td id="T_d19da_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_d19da_row6_col6" class="data row6 col6" >9.22</td>
#       <td id="T_d19da_row6_col7" class="data row6 col7" >MX</td>
#       <td id="T_d19da_row6_col8" class="data row6 col8" >2023-11-25 15:07:08</td>
#     </tr>
#     <tr>
#       <td id="T_d19da_row7_col0" class="data row7 col0" >bubaque</td>
#       <td id="T_d19da_row7_col1" class="data row7 col1" >11.28</td>
#       <td id="T_d19da_row7_col2" class="data row7 col2" >-15.83</td>
#       <td id="T_d19da_row7_col3" class="data row7 col3" >82.96° F</td>
#       <td id="T_d19da_row7_col4" class="data row7 col4" >46%</td>
#       <td id="T_d19da_row7_col5" class="data row7 col5" >0%</td>
#       <td id="T_d19da_row7_col6" class="data row7 col6" >10.00</td>
#       <td id="T_d19da_row7_col7" class="data row7 col7" >GW</td>
#       <td id="T_d19da_row7_col8" class="data row7 col8"

# %% [markdown]
# ## **2.4: Display Vacation Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (vacationDataFrame,
         'Figure 2.4: Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ## **3.1: Add Hotel Column to DataFrame**

# %%
hotelDataFrame \
    = vacationDataFrame.copy()

hotelDataFrame \
    ['Hotel Name'] \
        = pd.Series \
            (dtype= 'str')

hotelDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelDataFrame)

# %% [markdown]
# ## **3.2: Find Hotel Locations**

# %%
updatedHotelDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (hotelDataFrame,
             'Hotel Name',
             'accommodation.hotel',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedHotelDataFrame)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...فندق جلنار in sultanah, SA
#
#
# Located the following hotel...Domingo Ortiz de Rosas in illapel, CL
#
#
# Located the following hotel...La maison blanche in mermoz boabab, SN
#
#
# Located the following hotel...فندق الاندلس in jeddah, SA
#
#
# Located the following hotel...Hotel Sol del Pacífico in lazaro cardenas, MX
#
#
# Located the following hotel...Ma. Cristina in ixtapa, MX
#
#
# Located the following hotel...Chez Julio in bubaque, GW
#
#
# Located the following hotel...Hotel Hacienda Vieja Tomatlan in tomatlan, MX
#
#
# hotel search complete

# %% [markdown]
# ## **3.3: Display Hotel Data Set**

# %%
captionString \
    = 'Table: 3.3: Hotel Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedHotelDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_3fba4 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_3fba4_row0_col0, #T_3fba4_row0_col1, #T_3fba4_row0_col2, #T_3fba4_row0_col3, #T_3fba4_row0_col4, #T_3fba4_row0_col6, #T_3fba4_row0_col7, #T_3fba4_row0_col8, #T_3fba4_row0_col9, #T_3fba4_row1_col0, #T_3fba4_row1_col1, #T_3fba4_row1_col2, #T_3fba4_row1_col4, #T_3fba4_row1_col6, #T_3fba4_row1_col7, #T_3fba4_row1_col8, #T_3fba4_row1_col9, #T_3fba4_row2_col0, #T_3fba4_row2_col1, #T_3fba4_row2_col2, #T_3fba4_row2_col3, #T_3fba4_row2_col4, #T_3fba4_row2_col6, #T_3fba4_row2_col7, #T_3fba4_row2_col8, #T_3fba4_row2_col9, #T_3fba4_row3_col0, #T_3fba4_row3_col1, #T_3fba4_row3_col2, #T_3fba4_row3_col3, #T_3fba4_row3_col7, #T_3fba4_row3_col8, #T_3fba4_row3_col9, #T_3fba4_row4_col0, #T_3fba4_row4_col1, #T_3fba4_row4_col2, #T_3fba4_row4_col3, #T_3fba4_row4_col4, #T_3fba4_row4_col6, #T_3fba4_row4_col7, #T_3fba4_row4_col8, #T_3fba4_row4_col9, #T_3fba4_row5_col0, #T_3fba4_row5_col1, #T_3fba4_row5_col2, #T_3fba4_row5_col3, #T_3fba4_row5_col4, #T_3fba4_row5_col6, #T_3fba4_row5_col7, #T_3fba4_row5_col8, #T_3fba4_row5_col9, #T_3fba4_row6_col0, #T_3fba4_row6_col1, #T_3fba4_row6_col2, #T_3fba4_row6_col3, #T_3fba4_row6_col4, #T_3fba4_row6_col7, #T_3fba4_row6_col8, #T_3fba4_row6_col9, #T_3fba4_row7_col0, #T_3fba4_row7_col1, #T_3fba4_row7_col2, #T_3fba4_row7_col6, #T_3fba4_row7_col7, #T_3fba4_row7_col8, #T_3fba4_row7_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_3fba4_row0_col5, #T_3fba4_row1_col3, #T_3fba4_row1_col5, #T_3fba4_row2_col5, #T_3fba4_row3_col5, #T_3fba4_row3_col6, #T_3fba4_row4_col5, #T_3fba4_row5_col5, #T_3fba4_row6_col5, #T_3fba4_row7_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_3fba4_row3_col4, #T_3fba4_row6_col6, #T_3fba4_row7_col3, #T_3fba4_row7_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_3fba4">
#   <caption>Table: 3.3: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_3fba4_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_3fba4_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_3fba4_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_3fba4_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_3fba4_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_3fba4_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_3fba4_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_3fba4_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_3fba4_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_3fba4_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3fba4_row0_col0" class="data row0 col0" >sultanah</td>
#       <td id="T_3fba4_row0_col1" class="data row0 col1" >24.49</td>
#       <td id="T_3fba4_row0_col2" class="data row0 col2" >39.59</td>
#       <td id="T_3fba4_row0_col3" class="data row0 col3" >75.65° F</td>
#       <td id="T_3fba4_row0_col4" class="data row0 col4" >57%</td>
#       <td id="T_3fba4_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_3fba4_row0_col6" class="data row0 col6" >5.75</td>
#       <td id="T_3fba4_row0_col7" class="data row0 col7" >SA</td>
#       <td id="T_3fba4_row0_col8" class="data row0 col8" >2023-11-25 15:05:50</td>
#       <td id="T_3fba4_row0_col9" class="data row0 col9" >فندق جلنار</td>
#     </tr>
#     <tr>
#       <td id="T_3fba4_row1_col0" class="data row1 col0" >illapel</td>
#       <td id="T_3fba4_row1_col1" class="data row1 col1" >-31.63</td>
#       <td id="T_3fba4_row1_col2" class="data row1 col2" >-71.17</td>
#       <td id="T_3fba4_row1_col3" class="data row1 col3" >74.59° F</td>
#       <td id="T_3fba4_row1_col4" class="data row1 col4" >44%</td>
#       <td id="T_3fba4_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_3fba4_row1_col6" class="data row1 col6" >6.73</td>
#       <td id="T_3fba4_row1_col7" class="data row1 col7" >CL</td>
#       <td id="T_3fba4_row1_col8" class="data row1 col8" >2023-11-25 15:06:00</td>
#       <td id="T_3fba4_row1_col9" class="data row1 col9" >Domingo Ortiz de Rosas</td>
#     </tr>
#     <tr>
#       <td id="T_3fba4_row2_col0" class="data row2 col0" >mermoz boabab</td>
#       <td id="T_3fba4_row2_col1" class="data row2 col1" >14.71</td>
#       <td id="T_3fba4_row2_col2" class="data row2 col2" >-17.48</td>
#       <td id="T_3fba4_row2_col3" class="data row2 col3" >78.58° F</td>
#       <td id="T_3fba4_row2_col4" class="data row2 col4" >61%</td>
#       <td id="T_3fba4_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_3fba4_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_3fba4_row2_col7" class="data row2 col7" >SN</td>
#       <td id="T_3fba4_row2_col8" class="data row2 col8" >2023-11-25 15:06:01</td>
#       <td id="T_3fba4_row2_col9" class="data row2 col9" >La maison blanche</td>
#     </tr>
#     <tr>
#       <td id="T_3fba4_row3_col0" class="data row3 col0" >jeddah</td>
#       <td id="T_3fba4_row3_col1" class="data row3 col1" >21.52</td>
#       <td id="T_3fba4_row3_col2" class="data row3 col2" >39.22</td>
#       <td id="T_3fba4_row3_col3" class="data row3 col3" >82.26° F</td>
#       <td id="T_3fba4_row3_col4" class="data row3 col4" >65%</td>
#       <td id="T_3fba4_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_3fba4_row3_col6" class="data row3 col6" >3.44</td>
#       <td id="T_3fba4_row3_col7" class="data row3 col7" >SA</td>
#       <td id="T_3fba4_row3_col8" class="data row3 col8" >2023-11-25 15:03:46</td>
#       <td id="T_3fba4_row3_col9" class="data row3 col9" >فندق الاندلس</td>
#     </tr>
#     <tr>
#       <td id="T_3fba4_row4_col0" class="data row4 col0" >lazaro cardenas</td>
#       <td id="T_3fba4_row4_col1" class="data row4 col1" >17.96</td>
#       <td id="T_3fba4_row4_col2" class="data row4 col2" >-102.20</td>
#       <td id="T_3fba4_row4_col3" class="data row4 col3" >85.15° F</td>
#       <td id="T_3fba4_row4_col4" class="data row4 col4" >57%</td>
#       <td id="T_3fba4_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_3fba4_row4_col6" class="data row4 col6" >5.39</td>
#       <td id="T_3fba4_row4_col7" class="data row4 col7" >MX</td>
#       <td id="T_3fba4_row4_col8" class="data row4 col8" >2023-11-25 15:03:59</td>
#       <td id="T_3fba4_row4_col9" class="data row4 col9" >Hotel Sol del Pacífico</td>
#     </tr>
#     <tr>
#       <td id="T_3fba4_row5_col0" class="data row5 col0" >ixtapa</td>
#       <td id="T_3fba4_row5_col1" class="data row5 col1" >20.70</td>
#       <td id="T_3fba4_row5_col2" class="data row5 col2" >-105.20</td>
#       <td id="T_3fba4_row5_col3" class="data row5 col3" >81.63° F</td>
#       <td id="T_3fba4_row5_col4" class="data row5 col4" >61%</td>
#       <td id="T_3fba4_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_3fba4_row5_col6" class="data row5 col6" >9.22</td>
#       <td id="T_3fba4_row5_col7" class="data row5 col7" >MX</td>
#       <td id="T_3fba4_row5_col8" class="data row5 col8" >2023-11-25 15:07:08</td>
#       <td id="T_3fba4_row5_col9" class="data row5 col9" >Ma. Cristina</td>
#     </tr>
#     <tr>
#       <td id="T_3fba4_row6_col0" class="data row6 col0" >bubaque</td>
#       <td id="T_3fba4_row6_col1" class="data row6 col1" >11.28</td>
#       <td id="T_3fba4_row6_col2" class="data row6 col2" >-15.83</td>
#       <td id="T_3fba4_row6_col3" class="data row6 col3" >82.96° F</td>
#       <td id="T_3fba4_row6_col4" class="data row6 col4" >46%</td>
#       <td id="T_3fba4_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_3fba4_row6_col6" class="data row6 col6" >10.00</td>
#       <td id="T_3fba4_row6_col7" class="data row6 col7" >GW</td>
#       <td id="T_3fba4_row6_col8" class="data row6 col8" >2023-11-25 15:04:17</td>
#       <td id="T_3fba4_row6_col9" class="data row6 col9" >Chez Julio</td>
#     </tr>
#     <tr>

# %% [markdown]
# ## **3.4: Display Hotel Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelDataFrame,
         'Figure 3.4: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %% [markdown]
# # <br> **Section 4: Restaurant Locations**

# %% [markdown]
# ## **4.1: Add Restaurant Column to DataFrame**

# %%
resturantDataFrame \
    = updatedHotelDataFrame.copy()

resturantDataFrame \
    ['Restaurant Name'] \
        = pd.Series \
            (dtype= 'str')

resturantDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (resturantDataFrame)

# %% [markdown]
# ## **4.2: Find Restaurant Locations**

# %%
updatedResturantDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (resturantDataFrame,
             'Restaurant Name',
             'catering.restaurant',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedResturantDataFrame)
# Out:
# Starting restaurant search...
#
#
# Located the following restaurant...Fairuz Turkish Restaurant in sultanah, SA
#
#
# Located the following restaurant...Bar Restaurant Nico in illapel, CL
#
#
# Located the following restaurant...La pizzaola in mermoz boabab, SN
#
#
# Located the following restaurant...فول عباس in jeddah, SA
#
#
# Located the following restaurant...Mariscos Mazatlán in lazaro cardenas, MX
#
#
# Located the following restaurant...Mariscos Valentino's in ixtapa, MX
#
#
# Located the following restaurant...Chez Malaika in bubaque, GW
#
#
# restaurant search complete

# %% [markdown]
# ## **4.3: Display Restaurant Data Set**

# %%
captionString \
    = 'Table: 4.3: Restaurant Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedResturantDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_e9bdf caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_e9bdf_row0_col0, #T_e9bdf_row0_col1, #T_e9bdf_row0_col2, #T_e9bdf_row0_col3, #T_e9bdf_row0_col4, #T_e9bdf_row0_col6, #T_e9bdf_row0_col7, #T_e9bdf_row0_col8, #T_e9bdf_row0_col9, #T_e9bdf_row0_col10, #T_e9bdf_row1_col0, #T_e9bdf_row1_col1, #T_e9bdf_row1_col2, #T_e9bdf_row1_col6, #T_e9bdf_row1_col7, #T_e9bdf_row1_col8, #T_e9bdf_row1_col9, #T_e9bdf_row1_col10, #T_e9bdf_row2_col0, #T_e9bdf_row2_col1, #T_e9bdf_row2_col2, #T_e9bdf_row2_col3, #T_e9bdf_row2_col4, #T_e9bdf_row2_col6, #T_e9bdf_row2_col7, #T_e9bdf_row2_col8, #T_e9bdf_row2_col9, #T_e9bdf_row2_col10, #T_e9bdf_row3_col0, #T_e9bdf_row3_col1, #T_e9bdf_row3_col2, #T_e9bdf_row3_col3, #T_e9bdf_row3_col7, #T_e9bdf_row3_col8, #T_e9bdf_row3_col9, #T_e9bdf_row3_col10, #T_e9bdf_row4_col0, #T_e9bdf_row4_col1, #T_e9bdf_row4_col2, #T_e9bdf_row4_col4, #T_e9bdf_row4_col6, #T_e9bdf_row4_col7, #T_e9bdf_row4_col8, #T_e9bdf_row4_col9, #T_e9bdf_row4_col10, #T_e9bdf_row5_col0, #T_e9bdf_row5_col1, #T_e9bdf_row5_col2, #T_e9bdf_row5_col3, #T_e9bdf_row5_col4, #T_e9bdf_row5_col6, #T_e9bdf_row5_col7, #T_e9bdf_row5_col8, #T_e9bdf_row5_col9, #T_e9bdf_row5_col10, #T_e9bdf_row6_col0, #T_e9bdf_row6_col1, #T_e9bdf_row6_col2, #T_e9bdf_row6_col3, #T_e9bdf_row6_col4, #T_e9bdf_row6_col7, #T_e9bdf_row6_col8, #T_e9bdf_row6_col9, #T_e9bdf_row6_col10 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_e9bdf_row0_col5, #T_e9bdf_row1_col5, #T_e9bdf_row2_col5, #T_e9bdf_row3_col5, #T_e9bdf_row4_col5, #T_e9bdf_row5_col5, #T_e9bdf_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
#   background-color: yellow;
# }
# #T_e9bdf_row1_col3, #T_e9bdf_row1_col4, #T_e9bdf_row3_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_e9bdf_row3_col4, #T_e9bdf_row4_col3, #T_e9bdf_row6_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_e9bdf">
#   <caption>Table: 4.3: Restaurant Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_e9bdf_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_e9bdf_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_e9bdf_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_e9bdf_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_e9bdf_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_e9bdf_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_e9bdf_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_e9bdf_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_e9bdf_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_e9bdf_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#       <th id="T_e9bdf_level0_col10" class="col_heading level0 col10" >Restaurant Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e9bdf_row0_col0" class="data row0 col0" >sultanah</td>
#       <td id="T_e9bdf_row0_col1" class="data row0 col1" >24.49</td>
#       <td id="T_e9bdf_row0_col2" class="data row0 col2" >39.59</td>
#       <td id="T_e9bdf_row0_col3" class="data row0 col3" >75.65° F</td>
#       <td id="T_e9bdf_row0_col4" class="data row0 col4" >57%</td>
#       <td id="T_e9bdf_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_e9bdf_row0_col6" class="data row0 col6" >5.75</td>
#       <td id="T_e9bdf_row0_col7" class="data row0 col7" >SA</td>
#       <td id="T_e9bdf_row0_col8" class="data row0 col8" >2023-11-25 15:05:50</td>
#       <td id="T_e9bdf_row0_col9" class="data row0 col9" >فندق جلنار</td>
#       <td id="T_e9bdf_row0_col10" class="data row0 col10" >Fairuz Turkish Restaurant</td>
#     </tr>
#     <tr>
#       <td id="T_e9bdf_row1_col0" class="data row1 col0" >illapel</td>
#       <td id="T_e9bdf_row1_col1" class="data row1 col1" >-31.63</td>
#       <td id="T_e9bdf_row1_col2" class="data row1 col2" >-71.17</td>
#       <td id="T_e9bdf_row1_col3" class="data row1 col3" >74.59° F</td>
#       <td id="T_e9bdf_row1_col4" class="data row1 col4" >44%</td>
#       <td id="T_e9bdf_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_e9bdf_row1_col6" class="data row1 col6" >6.73</td>
#       <td id="T_e9bdf_row1_col7" class="data row1 col7" >CL</td>
#       <td id="T_e9bdf_row1_col8" class="data row1 col8" >2023-11-25 15:06:00</td>
#       <td id="T_e9bdf_row1_col9" class="data row1 col9" >Domingo Ortiz de Rosas</td>
#       <td id="T_e9bdf_row1_col10" class="data row1 col10" >Bar Restaurant Nico</td>
#     </tr>
#     <tr>
#       <td id="T_e9bdf_row2_col0" class="data row2 col0" >mermoz boabab</td>
#       <td id="T_e9bdf_row2_col1" class="data row2 col1" >14.71</td>
#       <td id="T_e9bdf_row2_col2" class="data row2 col2" >-17.48</td>
#       <td id="T_e9bdf_row2_col3" class="data row2 col3" >78.58° F</td>
#       <td id="T_e9bdf_row2_col4" class="data row2 col4" >61%</td>
#       <td id="T_e9bdf_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_e9bdf_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_e9bdf_row2_col7" class="data row2 col7" >SN</td>
#       <td id="T_e9bdf_row2_col8" class="data row2 col8" >2023-11-25 15:06:01</td>
#       <td id="T_e9bdf_row2_col9" class="data row2 col9" >La maison blanche</td>
#       <td id="T_e9bdf_row2_col10" class="data row2 col10" >La pizzaola</td>
#     </tr>
#     <tr>
#       <td id="T_e9bdf_row3_col0" class="data row3 col0" >jeddah</td>
#       <td id="T_e9bdf_row3_col1" class="data row3 col1" >21.52</td>
#       <td id="T_e9bdf_row3_col2" class="data row3 col2" >39.22</td>
#       <td id="T_e9bdf_row3_col3" class="data row3 col3" >82.26° F</td>
#       <td id="T_e9bdf_row3_col4" class="data row3 col4" >65%</td>
#       <td id="T_e9bdf_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_e9bdf_row3_col6" class="data row3 col6" >3.44</td>
#       <td id="T_e9bdf_row3_col7" class="data row3 col7" >SA</td>
#       <td id="T_e9bdf_row3_col8" class="data row3 col8" >2023-11-25 15:03:46</td>
#       <td id="T_e9bdf_row3_col9" class="data row3 col9" >فندق الاندلس</td>
#       <td id="T_e9bdf_row3_col10" class="data row3 col10" >فول عباس</td>
#     </tr>
#     <tr>
#       <td id="T_e9bdf_row4_col0" class="data row4 col0" >lazaro cardenas</td>
#       <td id="T_e9bdf_row4_col1" class="data row4 col1" >17.96</td>
#       <td id="T_e9bdf_row4_col2" class="data row4 col2" >-102.20</td>
#       <td id="T_e9bdf_row4_col3" class="data row4 col3" >85.15° F</td>
#       <td id="T_e9bdf_row4_col4" class="data row4 col4" >57%</td>
#       <td id="T_e9bdf_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_e9bdf_row4_col6" class="data row4 col6" >5.39</td>
#       <td id="T_e9bdf_row4_col7" class="data row4 col7" >MX</td>
#       <td id="T_e9bdf_row4_col8" class="data row4 col8" >2023-11-25 15:03:59</td>
#       <td id="T_e9bdf_row4_col9" class="data row4 col9" >Hotel Sol del Pacífico</td>
#       <td id="T_e9bdf_row4_col10" class="data row4 col10" >Mariscos Mazatlán</td>
#     </tr>
#     <tr>
#       <td id="T_e9bdf_row5_col0" class="data row5 col0" >ixtapa</td>
#       <td id="T_e9bdf_row5_col1" class="data row5 col1" >20.70</td>
#       <td id="T_e9bdf_row5_col2" class="data row5 col2" >-105.20</td>
#       <td id="T_e9bdf_row5_col3" class="data row5 col3" >81.63° F</td>
#       <td id="T_e9bdf_row5_col4" class="data row5 col4" >61%</td>
#       <td id="T_e9bdf_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_e9bdf_row5_col6" class="data row5 col6" >9.22</td>
#       <td id="T_e9bdf_row5_col7" class="data row5 col7" >MX</td>
#       <td id="T_e9bdf_row5_col8" class="data row5 col8" >2023-11-25 15:07:08</td>
#       <td id="T_e9bdf_row5_col9" class="data row5 col9" >Ma. Cristina</td>
#       <td id="T_e9bdf_row5_col10" class="data row5 col10" >Mariscos Valentino's</td>
#     </tr>
#     <tr>
#       <td id="T_e9bdf_row6_col0" class="data row6 col0" >bubaque</

# %% [markdown]
# ## **4.4: Display Restaurant Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Hotel Name', 
       'Restaurant Name'
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedResturantDataFrame,
         'Figure 4.4: Restaurant Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name)

# %% [markdown]
# # <br> **Section 5: Tourism Attraction Locations**

# %% [markdown]
# ## **5.1: Add Tourism Attraction Column to DataFrame**

# %%
tourismAttractionDataFrame \
    = updatedResturantDataFrame.copy()

tourismAttractionDataFrame \
    ['Tourism Attraction'] \
        = pd.Series \
            (dtype= 'str')

tourismAttractionDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (tourismAttractionDataFrame)

# %% [markdown]
# ## **5.2: Find Tourism Attraction Locations**

# %%
updatedTourismAttractionDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (tourismAttractionDataFrame,
             'Tourism Attraction',
             'tourism.attraction',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedTourismAttractionDataFrame)
# Out:
# Starting tourism attraction search...
#
#
# Located the following tourism attraction...ウフド山  古戦場跡 in sultanah, SA
#
#
# Located the following tourism attraction...Waru Studio in mermoz boabab, SN
#
#
# Located the following tourism attraction...Khuzam Palace Main Gate in jeddah, SA
#
#
# Located the following tourism attraction...Kiosko Pérgola municipal in lazaro cardenas, MX
#
#
# Located the following tourism attraction...Espiral de piedra in ixtapa, MX
#
#
# Located the following tourism attraction...Porto di Bane in bubaque, GW
#
#
# tourism attraction search complete

# %% [markdown]
# ## **5.3: Display Tourism Attraction Data Set**

# %%
captionString \
    = 'Table: 5.3: Tourism Attraction Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedTourismAttractionDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_77b11 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_77b11_row0_col0, #T_77b11_row0_col1, #T_77b11_row0_col2, #T_77b11_row0_col4, #T_77b11_row0_col6, #T_77b11_row0_col7, #T_77b11_row0_col8, #T_77b11_row0_col9, #T_77b11_row0_col10, #T_77b11_row0_col11, #T_77b11_row1_col0, #T_77b11_row1_col1, #T_77b11_row1_col2, #T_77b11_row1_col3, #T_77b11_row1_col4, #T_77b11_row1_col6, #T_77b11_row1_col7, #T_77b11_row1_col8, #T_77b11_row1_col9, #T_77b11_row1_col10, #T_77b11_row1_col11, #T_77b11_row2_col0, #T_77b11_row2_col1, #T_77b11_row2_col2, #T_77b11_row2_col3, #T_77b11_row2_col7, #T_77b11_row2_col8, #T_77b11_row2_col9, #T_77b11_row2_col10, #T_77b11_row2_col11, #T_77b11_row3_col0, #T_77b11_row3_col1, #T_77b11_row3_col2, #T_77b11_row3_col4, #T_77b11_row3_col6, #T_77b11_row3_col7, #T_77b11_row3_col8, #T_77b11_row3_col9, #T_77b11_row3_col10, #T_77b11_row3_col11, #T_77b11_row4_col0, #T_77b11_row4_col1, #T_77b11_row4_col2, #T_77b11_row4_col3, #T_77b11_row4_col4, #T_77b11_row4_col6, #T_77b11_row4_col7, #T_77b11_row4_col8, #T_77b11_row4_col9, #T_77b11_row4_col10, #T_77b11_row4_col11, #T_77b11_row5_col0, #T_77b11_row5_col1, #T_77b11_row5_col2, #T_77b11_row5_col3, #T_77b11_row5_col7, #T_77b11_row5_col8, #T_77b11_row5_col9, #T_77b11_row5_col10, #T_77b11_row5_col11 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_77b11_row0_col3, #T_77b11_row2_col6, #T_77b11_row5_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_77b11_row0_col5, #T_77b11_row1_col5, #T_77b11_row2_col5, #T_77b11_row3_col5, #T_77b11_row4_col5, #T_77b11_row5_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
#   background-color: yellow;
# }
# #T_77b11_row2_col4, #T_77b11_row3_col3, #T_77b11_row5_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_77b11">
#   <caption>Table: 5.3: Tourism Attraction Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_77b11_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_77b11_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_77b11_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_77b11_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_77b11_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_77b11_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_77b11_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_77b11_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_77b11_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_77b11_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#       <th id="T_77b11_level0_col10" class="col_heading level0 col10" >Restaurant Name</th>
#       <th id="T_77b11_level0_col11" class="col_heading level0 col11" >Tourism Attraction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_77b11_row0_col0" class="data row0 col0" >sultanah</td>
#       <td id="T_77b11_row0_col1" class="data row0 col1" >24.49</td>
#       <td id="T_77b11_row0_col2" class="data row0 col2" >39.59</td>
#       <td id="T_77b11_row0_col3" class="data row0 col3" >75.65° F</td>
#       <td id="T_77b11_row0_col4" class="data row0 col4" >57%</td>
#       <td id="T_77b11_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_77b11_row0_col6" class="data row0 col6" >5.75</td>
#       <td id="T_77b11_row0_col7" class="data row0 col7" >SA</td>
#       <td id="T_77b11_row0_col8" class="data row0 col8" >2023-11-25 15:05:50</td>
#       <td id="T_77b11_row0_col9" class="data row0 col9" >فندق جلنار</td>
#       <td id="T_77b11_row0_col10" class="data row0 col10" >Fairuz Turkish Restaurant</td>
#       <td id="T_77b11_row0_col11" class="data row0 col11" >ウフド山  古戦場跡</td>
#     </tr>
#     <tr>
#       <td id="T_77b11_row1_col0" class="data row1 col0" >mermoz boabab</td>
#       <td id="T_77b11_row1_col1" class="data row1 col1" >14.71</td>
#       <td id="T_77b11_row1_col2" class="data row1 col2" >-17.48</td>
#       <td id="T_77b11_row1_col3" class="data row1 col3" >78.58° F</td>
#       <td id="T_77b11_row1_col4" class="data row1 col4" >61%</td>
#       <td id="T_77b11_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_77b11_row1_col6" class="data row1 col6" >6.91</td>
#       <td id="T_77b11_row1_col7" class="data row1 col7" >SN</td>
#       <td id="T_77b11_row1_col8" class="data row1 col8" >2023-11-25 15:06:01</td>
#       <td id="T_77b11_row1_col9" class="data row1 col9" >La maison blanche</td>
#       <td id="T_77b11_row1_col10" class="data row1 col10" >La pizzaola</td>
#       <td id="T_77b11_row1_col11" class="data row1 col11" >Waru Studio</td>
#     </tr>
#     <tr>
#       <td id="T_77b11_row2_col0" class="data row2 col0" >jeddah</td>
#       <td id="T_77b11_row2_col1" class="data row2 col1" >21.52</td>
#       <td id="T_77b11_row2_col2" class="data row2 col2" >39.22</td>
#       <td id="T_77b11_row2_col3" class="data row2 col3" >82.26° F</td>
#       <td id="T_77b11_row2_col4" class="data row2 col4" >65%</td>
#       <td id="T_77b11_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_77b11_row2_col6" class="data row2 col6" >3.44</td>
#       <td id="T_77b11_row2_col7" class="data row2 col7" >SA</td>
#       <td id="T_77b11_row2_col8" class="data row2 col8" >2023-11-25 15:03:46</td>
#       <td id="T_77b11_row2_col9" class="data row2 col9" >فندق الاندلس</td>
#       <td id="T_77b11_row2_col10" class="data row2 col10" >فول عباس</td>
#       <td id="T_77b11_row2_col11" class="data row2 col11" >Khuzam Palace Main Gate</td>
#     </tr>
#     <tr>
#       <td id="T_77b11_row3_col0" class="data row3 col0" >lazaro cardenas</td>
#       <td id="T_77b11_row3_col1" class="data row3 col1" >17.96</td>
#       <td id="T_77b11_row3_col2" class="data row3 col2" >-102.20</td>
#       <td id="T_77b11_row3_col3" class="data row3 col3" >85.15° F</td>
#       <td id="T_77b11_row3_col4" class="data row3 col4" >57%</td>
#       <td id="T_77b11_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_77b11_row3_col6" class="data row3 col6" >5.39</td>
#       <td id="T_77b11_row3_col7" class="data row3 col7" >MX</td>
#       <td id="T_77b11_row3_col8" class="data row3 col8" >2023-11-25 15:03:59</td>
#       <td id="T_77b11_row3_col9" class="data row3 col9" >Hotel Sol del Pacífico</td>
#       <td id="T_77b11_row3_col10" class="data row3 col10" >Mariscos Mazatlán</td>
#       <td id="T_77b11_row3_col11" class="data row3 col11" >Kiosko Pérgola municipal</td>
#     </tr>
#     <tr>
#       <td id="T_77b11_row4_col0" class="data row4 col0" >ixtapa</td>
#       <td id="T_77b11_row4_col1" class="data row4 col1" >20.70</td>
#       <td id="T_77b11_row4_col2" class="data row4 col2" >-105.20</td>
#       <td id="T_77b11_row4_col3" class="data row4 col3" >81.63° F</td>
#       <td id="T_77b11_row4_col4" class="data row4 col4" >61%</td>
#       <td id="T_77b11_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_77b11_row4_col6" class="data row4 col6" >9.22</td>
#       <td id="T_77b11_row4_col7" class="data row4 col7" >MX</td>
#       <td id="T_77b11_row4_col8" class="data row4 col8" >2023-11-25 15:07:08</td>
#       <td id="T_77b11_row4_col9" class="data row4 col9" >Ma. Cristina</td>
#       <td id="T_77b11_row4_col10" class="data row4 col10" >Mariscos Valentino's</td>
#       <td id="T_77b11_row4_col11" class="data row4 col11" >Espiral de piedra</td>
#     </tr>
#     <tr>
#       <td id="T_77b11_row5_col0" class="data row5 col0" >bubaque</td>
#       <td id="T_77b11_row5_col1" class="data row5 col1" >11.28</td>
#       <td id="T_77b11_row5_col2" class="data row5 col2" >-15.83</td>
#       <td id="T_77b11_row5_col3" class="data row5 col3" >82.96° F</td>
#       <td id="T_77b11_row5_col4" class="data row5 col4" >46%</td>
#       <td id="T_77b11_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_77b11_row5_col6" class="data row5 co

# %% [markdown]
# ## **5.4: Display Tourism Attraction Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Hotel Name', 
       'Restaurant Name',
       'Tourism Attraction',
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedTourismAttractionDataFrame,
         'Figure 5.4: Tourism Attraction Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Restaurant Name,Tourism Attraction,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
