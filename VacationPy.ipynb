# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
captionString \
    = 'Table: 1.1: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_7f8de caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_7f8de_row0_col0, #T_7f8de_row0_col1, #T_7f8de_row0_col2, #T_7f8de_row0_col4, #T_7f8de_row0_col5, #T_7f8de_row0_col6, #T_7f8de_row0_col7, #T_7f8de_row0_col8, #T_7f8de_row1_col0, #T_7f8de_row1_col1, #T_7f8de_row1_col2, #T_7f8de_row1_col3, #T_7f8de_row1_col4, #T_7f8de_row1_col5, #T_7f8de_row1_col6, #T_7f8de_row1_col7, #T_7f8de_row1_col8, #T_7f8de_row2_col0, #T_7f8de_row2_col1, #T_7f8de_row2_col2, #T_7f8de_row2_col3, #T_7f8de_row2_col4, #T_7f8de_row2_col6, #T_7f8de_row2_col7, #T_7f8de_row2_col8, #T_7f8de_row3_col0, #T_7f8de_row3_col1, #T_7f8de_row3_col2, #T_7f8de_row3_col3, #T_7f8de_row3_col4, #T_7f8de_row3_col5, #T_7f8de_row3_col7, #T_7f8de_row3_col8, #T_7f8de_row4_col0, #T_7f8de_row4_col1, #T_7f8de_row4_col2, #T_7f8de_row4_col3, #T_7f8de_row4_col6, #T_7f8de_row4_col7, #T_7f8de_row4_col8, #T_7f8de_row5_col0, #T_7f8de_row5_col1, #T_7f8de_row5_col2, #T_7f8de_row5_col3, #T_7f8de_row5_col6, #T_7f8de_row5_col7, #T_7f8de_row5_col8, #T_7f8de_row6_col0, #T_7f8de_row6_col1, #T_7f8de_row6_col2, #T_7f8de_row6_col3, #T_7f8de_row6_col4, #T_7f8de_row6_col6, #T_7f8de_row6_col7, #T_7f8de_row6_col8, #T_7f8de_row7_col0, #T_7f8de_row7_col1, #T_7f8de_row7_col2, #T_7f8de_row7_col3, #T_7f8de_row7_col4, #T_7f8de_row7_col5, #T_7f8de_row7_col6, #T_7f8de_row7_col7, #T_7f8de_row7_col8, #T_7f8de_row8_col0, #T_7f8de_row8_col1, #T_7f8de_row8_col2, #T_7f8de_row8_col3, #T_7f8de_row8_col4, #T_7f8de_row8_col6, #T_7f8de_row8_col7, #T_7f8de_row8_col8, #T_7f8de_row9_col0, #T_7f8de_row9_col1, #T_7f8de_row9_col2, #T_7f8de_row9_col3, #T_7f8de_row9_col4, #T_7f8de_row9_col5, #T_7f8de_row9_col6, #T_7f8de_row9_col7, #T_7f8de_row9_col8, #T_7f8de_row10_col0, #T_7f8de_row10_col1, #T_7f8de_row10_col2, #T_7f8de_row10_col3, #T_7f8de_row10_col4, #T_7f8de_row10_col7, #T_7f8de_row10_col8, #T_7f8de_row11_col0, #T_7f8de_row11_col1, #T_7f8de_row11_col2, #T_7f8de_row11_col4, #T_7f8de_row11_col5, #T_7f8de_row11_col6, #T_7f8de_row11_col7, #T_7f8de_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_7f8de_row0_col3, #T_7f8de_row2_col5, #T_7f8de_row3_col6, #T_7f8de_row5_col4, #T_7f8de_row5_col5, #T_7f8de_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_7f8de_row4_col4, #T_7f8de_row4_col5, #T_7f8de_row8_col5, #T_7f8de_row10_col5, #T_7f8de_row10_col6, #T_7f8de_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_7f8de">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_7f8de_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_7f8de_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_7f8de_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_7f8de_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_7f8de_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_7f8de_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_7f8de_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_7f8de_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_7f8de_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f8de_row0_col0" class="data row0 col0" >grytviken</td>
#       <td id="T_7f8de_row0_col1" class="data row0 col1" >-54.28</td>
#       <td id="T_7f8de_row0_col2" class="data row0 col2" >-36.51</td>
#       <td id="T_7f8de_row0_col3" class="data row0 col3" >28.22° F</td>
#       <td id="T_7f8de_row0_col4" class="data row0 col4" >81%</td>
#       <td id="T_7f8de_row0_col5" class="data row0 col5" >24%</td>
#       <td id="T_7f8de_row0_col6" class="data row0 col6" >9.19</td>
#       <td id="T_7f8de_row0_col7" class="data row0 col7" >GS</td>
#       <td id="T_7f8de_row0_col8" class="data row0 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_7f8de_row1_col0" class="data row1 col0" >bandar lampung</td>
#       <td id="T_7f8de_row1_col1" class="data row1 col1" >-5.43</td>
#       <td id="T_7f8de_row1_col2" class="data row1 col2" >105.26</td>
#       <td id="T_7f8de_row1_col3" class="data row1 col3" >81.45° F</td>
#       <td id="T_7f8de_row1_col4" class="data row1 col4" >62%</td>
#       <td id="T_7f8de_row1_col5" class="data row1 col5" >1%</td>
#       <td id="T_7f8de_row1_col6" class="data row1 col6" >3.85</td>
#       <td id="T_7f8de_row1_col7" class="data row1 col7" >ID</td>
#       <td id="T_7f8de_row1_col8" class="data row1 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_7f8de_row2_col0" class="data row2 col0" >pisco</td>
#       <td id="T_7f8de_row2_col1" class="data row2 col1" >-13.70</td>
#       <td id="T_7f8de_row2_col2" class="data row2 col2" >-76.22</td>
#       <td id="T_7f8de_row2_col3" class="data row2 col3" >66.25° F</td>
#       <td id="T_7f8de_row2_col4" class="data row2 col4" >82%</td>
#       <td id="T_7f8de_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_7f8de_row2_col6" class="data row2 col6" >17.27</td>
#       <td id="T_7f8de_row2_col7" class="data row2 col7" >PE</td>
#       <td id="T_7f8de_row2_col8" class="data row2 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_7f8de_row3_col0" class="data row3 col0" >albany</td>
#       <td id="T_7f8de_row3_col1" class="data row3 col1" >42.60</td>
#       <td id="T_7f8de_row3_col2" class="data row3 col2" >-73.97</td>
#       <td id="T_7f8de_row3_col3" class="data row3 col3" >52.59° F</td>
#       <td id="T_7f8de_row3_col4" class="data row3 col4" >88%</td>
#       <td id="T_7f8de_row3_col5" class="data row3 col5" >98%</td>
#       <td id="T_7f8de_row3_col6" class="data row3 col6" >1.01</td>
#       <td id="T_7f8de_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_7f8de_row3_col8" class="data row3 col8" >2023-09-26 17:28:56</td>
#     </tr>
#     <tr>
#       <td id="T_7f8de_row4_col0" class="data row4 col0" >lemvig</td>
#       <td id="T_7f8de_row4_col1" class="data row4 col1" >56.55</td>
#       <td id="T_7f8de_row4_col2" class="data row4 col2" >8.31</td>
#       <td id="T_7f8de_row4_col3" class="data row4 col3" >59.14° F</td>
#       <td id="T_7f8de_row4_col4" class="data row4 col4" >90%</td>
#       <td id="T_7f8de_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_7f8de_row4_col6" class="data row4 col6" >11.90</td>
#       <td id="T_7f8de_row4_col7" class="data row4 col7" >DK</td>
#       <td id="T_7f8de_row4_col8" class="data row4 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_7f8de_row5_col0" class="data row5 col0" >aspen</td>
#       <td id="T_7f8de_row5_col1" class="data row5 col1" >39.19</td>
#       <td id="T_7f8de_row5_col2" class="data row5 col2" >-106.82</td>
#       <td id="T_7f8de_row5_col3" class="data row5 col3" >71.04° F</td>
#       <td id="T_7f8de_row5_col4" class="data row5 col4" >15%</td>
#       <td id="T_7f8de_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_7f8de_row5_col6" class="data row5 col6" >8.05</td>
#       <td id="T_7f8de_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_7f8de_row5_col8" class="data row5 col8" >2023-09-26 17:28:42</td>
#     </tr>
#     <tr>
#       <td id="T_7f8de_row6_col0" class="data row6 col0" >luderitz</td>
#       <td id="T_7f8de_row6_col1" class="data row6 col1" >-26.65</td>
#       <td id="T_7f8de_row6_col2" class="data row6 col2" >15.16</td>
#       <td id="T_7f8de_row6_col3" class="data row6 col3" >63.48° F</td>
#       <td id="T_7f8de_row6_col4" class="data row6 col4" >47%</td>
#       <td id="T_7f8de_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_7f8de_row6_col6" class="data row6 col6" >12.91</td>
#       <td id="T_7f8de_row6_col7" class="data row6 col7" >nan</td>
#       <td id="T_7f8de_row6_col8" class="data row6 col8" >2023-09-26 17:33:04</td>
#     </tr>
#     <tr>
#       <td id="T_7f8de_row7_col0" class="data row7

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 93), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 40) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 70), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 10), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
captionString \
    = 'Table: 2.1: Ideal Vacation Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (idealVacationLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_c22cc caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c22cc_row0_col0, #T_c22cc_row0_col1, #T_c22cc_row0_col2, #T_c22cc_row0_col3, #T_c22cc_row0_col4, #T_c22cc_row0_col5, #T_c22cc_row0_col6, #T_c22cc_row0_col7, #T_c22cc_row0_col8, #T_c22cc_row1_col0, #T_c22cc_row1_col1, #T_c22cc_row1_col2, #T_c22cc_row1_col3, #T_c22cc_row1_col4, #T_c22cc_row1_col7, #T_c22cc_row1_col8, #T_c22cc_row2_col0, #T_c22cc_row2_col1, #T_c22cc_row2_col2, #T_c22cc_row2_col3, #T_c22cc_row2_col4, #T_c22cc_row2_col6, #T_c22cc_row2_col7, #T_c22cc_row2_col8, #T_c22cc_row3_col0, #T_c22cc_row3_col1, #T_c22cc_row3_col2, #T_c22cc_row3_col3, #T_c22cc_row3_col4, #T_c22cc_row3_col5, #T_c22cc_row3_col6, #T_c22cc_row3_col7, #T_c22cc_row3_col8, #T_c22cc_row4_col0, #T_c22cc_row4_col1, #T_c22cc_row4_col2, #T_c22cc_row4_col3, #T_c22cc_row4_col4, #T_c22cc_row4_col6, #T_c22cc_row4_col7, #T_c22cc_row4_col8, #T_c22cc_row5_col0, #T_c22cc_row5_col1, #T_c22cc_row5_col2, #T_c22cc_row5_col3, #T_c22cc_row5_col4, #T_c22cc_row5_col5, #T_c22cc_row5_col6, #T_c22cc_row5_col7, #T_c22cc_row5_col8, #T_c22cc_row6_col0, #T_c22cc_row6_col1, #T_c22cc_row6_col2, #T_c22cc_row6_col3, #T_c22cc_row6_col4, #T_c22cc_row6_col6, #T_c22cc_row6_col7, #T_c22cc_row6_col8, #T_c22cc_row7_col0, #T_c22cc_row7_col1, #T_c22cc_row7_col2, #T_c22cc_row7_col3, #T_c22cc_row7_col4, #T_c22cc_row7_col7, #T_c22cc_row7_col8, #T_c22cc_row8_col0, #T_c22cc_row8_col1, #T_c22cc_row8_col2, #T_c22cc_row8_col3, #T_c22cc_row8_col4, #T_c22cc_row8_col5, #T_c22cc_row8_col6, #T_c22cc_row8_col7, #T_c22cc_row8_col8, #T_c22cc_row9_col0, #T_c22cc_row9_col1, #T_c22cc_row9_col2, #T_c22cc_row9_col3, #T_c22cc_row9_col4, #T_c22cc_row9_col5, #T_c22cc_row9_col6, #T_c22cc_row9_col7, #T_c22cc_row9_col8, #T_c22cc_row10_col0, #T_c22cc_row10_col1, #T_c22cc_row10_col2, #T_c22cc_row10_col3, #T_c22cc_row10_col4, #T_c22cc_row10_col5, #T_c22cc_row10_col6, #T_c22cc_row10_col7, #T_c22cc_row10_col8, #T_c22cc_row11_col0, #T_c22cc_row11_col1, #T_c22cc_row11_col2, #T_c22cc_row11_col3, #T_c22cc_row11_col4, #T_c22cc_row11_col5, #T_c22cc_row11_col6, #T_c22cc_row11_col7, #T_c22cc_row11_col8, #T_c22cc_row12_col0, #T_c22cc_row12_col1, #T_c22cc_row12_col2, #T_c22cc_row12_col3, #T_c22cc_row12_col4, #T_c22cc_row12_col5, #T_c22cc_row12_col7, #T_c22cc_row12_col8, #T_c22cc_row13_col0, #T_c22cc_row13_col1, #T_c22cc_row13_col2, #T_c22cc_row13_col3, #T_c22cc_row13_col4, #T_c22cc_row13_col6, #T_c22cc_row13_col7, #T_c22cc_row13_col8, #T_c22cc_row14_col0, #T_c22cc_row14_col1, #T_c22cc_row14_col2, #T_c22cc_row14_col4, #T_c22cc_row14_col6, #T_c22cc_row14_col7, #T_c22cc_row14_col8, #T_c22cc_row15_col0, #T_c22cc_row15_col1, #T_c22cc_row15_col2, #T_c22cc_row15_col3, #T_c22cc_row15_col6, #T_c22cc_row15_col7, #T_c22cc_row15_col8, #T_c22cc_row16_col0, #T_c22cc_row16_col1, #T_c22cc_row16_col2, #T_c22cc_row16_col3, #T_c22cc_row16_col6, #T_c22cc_row16_col7, #T_c22cc_row16_col8, #T_c22cc_row17_col0, #T_c22cc_row17_col1, #T_c22cc_row17_col2, #T_c22cc_row17_col3, #T_c22cc_row17_col4, #T_c22cc_row17_col5, #T_c22cc_row17_col6, #T_c22cc_row17_col7, #T_c22cc_row17_col8, #T_c22cc_row18_col0, #T_c22cc_row18_col1, #T_c22cc_row18_col2, #T_c22cc_row18_col4, #T_c22cc_row18_col6, #T_c22cc_row18_col7, #T_c22cc_row18_col8, #T_c22cc_row19_col0, #T_c22cc_row19_col1, #T_c22cc_row19_col2, #T_c22cc_row19_col3, #T_c22cc_row19_col4, #T_c22cc_row19_col5, #T_c22cc_row19_col6, #T_c22cc_row19_col7, #T_c22cc_row19_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_c22cc_row1_col5, #T_c22cc_row2_col5, #T_c22cc_row6_col5, #T_c22cc_row7_col5, #T_c22cc_row7_col6, #T_c22cc_row13_col5, #T_c22cc_row14_col5, #T_c22cc_row15_col5, #T_c22cc_row16_col4, #T_c22cc_row16_col5, #T_c22cc_row18_col3, #T_c22cc_row18_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_c22cc_row1_col6, #T_c22cc_row4_col5, #T_c22cc_row12_col6, #T_c22cc_row14_col3, #T_c22cc_row15_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_c22cc">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_c22cc_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_c22cc_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_c22cc_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_c22cc_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_c22cc_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_c22cc_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_c22cc_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_c22cc_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_c22cc_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c22cc_row0_col0" class="data row0 col0" >bandar lampung</td>
#       <td id="T_c22cc_row0_col1" class="data row0 col1" >-5.43</td>
#       <td id="T_c22cc_row0_col2" class="data row0 col2" >105.26</td>
#       <td id="T_c22cc_row0_col3" class="data row0 col3" >81.45° F</td>
#       <td id="T_c22cc_row0_col4" class="data row0 col4" >62%</td>
#       <td id="T_c22cc_row0_col5" class="data row0 col5" >1%</td>
#       <td id="T_c22cc_row0_col6" class="data row0 col6" >3.85</td>
#       <td id="T_c22cc_row0_col7" class="data row0 col7" >ID</td>
#       <td id="T_c22cc_row0_col8" class="data row0 col8" >2023-09-26 17:33:03</td>
#     </tr>
#     <tr>
#       <td id="T_c22cc_row1_col0" class="data row1 col0" >port isabel</td>
#       <td id="T_c22cc_row1_col1" class="data row1 col1" >26.07</td>
#       <td id="T_c22cc_row1_col2" class="data row1 col2" >-97.21</td>
#       <td id="T_c22cc_row1_col3" class="data row1 col3" >85.93° F</td>
#       <td id="T_c22cc_row1_col4" class="data row1 col4" >69%</td>
#       <td id="T_c22cc_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_c22cc_row1_col6" class="data row1 col6" >9.22</td>
#       <td id="T_c22cc_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_c22cc_row1_col8" class="data row1 col8" >2023-09-26 17:33:07</td>
#     </tr>
#     <tr>
#       <td id="T_c22cc_row2_col0" class="data row2 col0" >as saffaniyah</td>
#       <td id="T_c22cc_row2_col1" class="data row2 col1" >27.97</td>
#       <td id="T_c22cc_row2_col2" class="data row2 col2" >48.73</td>
#       <td id="T_c22cc_row2_col3" class="data row2 col3" >84.02° F</td>
#       <td id="T_c22cc_row2_col4" class="data row2 col4" >53%</td>
#       <td id="T_c22cc_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_c22cc_row2_col6" class="data row2 col6" >5.93</td>
#       <td id="T_c22cc_row2_col7" class="data row2 col7" >SA</td>
#       <td id="T_c22cc_row2_col8" class="data row2 col8" >2023-09-26 17:33:11</td>
#     </tr>
#     <tr>
#       <td id="T_c22cc_row3_col0" class="data row3 col0" >pandan</td>
#       <td id="T_c22cc_row3_col1" class="data row3 col1" >14.05</td>
#       <td id="T_c22cc_row3_col2" class="data row3 col2" >124.17</td>
#       <td id="T_c22cc_row3_col3" class="data row3 col3" >84.85° F</td>
#       <td id="T_c22cc_row3_col4" class="data row3 col4" >69%</td>
#       <td id="T_c22cc_row3_col5" class="data row3 col5" >6%</td>
#       <td id="T_c22cc_row3_col6" class="data row3 col6" >4.52</td>
#       <td id="T_c22cc_row3_col7" class="data row3 col7" >PH</td>
#       <td id="T_c22cc_row3_col8" class="data row3 col8" >2023-09-26 17:33:18</td>
#     </tr>
#     <tr>
#       <td id="T_c22cc_row4_col0" class="data row4 col0" >bhuj</td>
#       <td id="T_c22cc_row4_col1" class="data row4 col1" >23.27</td>
#       <td id="T_c22cc_row4_col2" class="data row4 col2" >69.67</td>
#       <td id="T_c22cc_row4_col3" class="data row4 col3" >79.48° F</td>
#       <td id="T_c22cc_row4_col4" class="data row4 col4" >67%</td>
#       <td id="T_c22cc_row4_col5" class="data row4 col5" >9%</td>
#       <td id="T_c22cc_row4_col6" class="data row4 col6"

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Grand Anugerah in bandar lampung, ID
#
#
# Located the following hotel...Queen Isabel Inn in port isabel, US
#
#
# Located the following hotel...Hotel Prince in bhuj, IN
#
#
# Located the following hotel...Juddi Hotel in pasni, PK
#
#
# Located the following hotel...Costa Nova Apartments in noosa heads, AU
#
#
# Located the following hotel...割烹･民宿 初音 in takanabe, JP
#
#
# Located the following hotel...The Esplanade Hotel in port hedland, AU
#
#
# Located the following hotel...Hotel Sultan in sampit, ID
#
#
# Located the following hotel...Ballina Beach Resort in east ballina, AU
#
#
# Located the following hotel...Swiss-Belhotel in palangkaraya, ID
#
#
# Located the following hotel...Kununurra Country Club Resort in kununurra, AU
#
#
# Located the following hotel...OYO Mid City Hotel in hisar, IN
#
#
# Located the following hotel...هتل فارابی in kish, IR
#
#
# Located the following hotel...ホテルニューパレス in shingu, JP
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
captionString \
    = 'Table: 3.1: Hotel Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedHotelLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_ea673 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_ea673_row0_col0, #T_ea673_row0_col1, #T_ea673_row0_col2, #T_ea673_row0_col3, #T_ea673_row0_col4, #T_ea673_row0_col5, #T_ea673_row0_col6, #T_ea673_row0_col7, #T_ea673_row0_col8, #T_ea673_row0_col9, #T_ea673_row1_col0, #T_ea673_row1_col1, #T_ea673_row1_col2, #T_ea673_row1_col3, #T_ea673_row1_col4, #T_ea673_row1_col7, #T_ea673_row1_col8, #T_ea673_row1_col9, #T_ea673_row2_col0, #T_ea673_row2_col1, #T_ea673_row2_col2, #T_ea673_row2_col3, #T_ea673_row2_col4, #T_ea673_row2_col6, #T_ea673_row2_col7, #T_ea673_row2_col8, #T_ea673_row2_col9, #T_ea673_row3_col0, #T_ea673_row3_col1, #T_ea673_row3_col2, #T_ea673_row3_col4, #T_ea673_row3_col5, #T_ea673_row3_col6, #T_ea673_row3_col7, #T_ea673_row3_col8, #T_ea673_row3_col9, #T_ea673_row4_col0, #T_ea673_row4_col1, #T_ea673_row4_col2, #T_ea673_row4_col3, #T_ea673_row4_col4, #T_ea673_row4_col6, #T_ea673_row4_col7, #T_ea673_row4_col8, #T_ea673_row4_col9, #T_ea673_row5_col0, #T_ea673_row5_col1, #T_ea673_row5_col2, #T_ea673_row5_col3, #T_ea673_row5_col4, #T_ea673_row5_col7, #T_ea673_row5_col8, #T_ea673_row5_col9, #T_ea673_row6_col0, #T_ea673_row6_col1, #T_ea673_row6_col2, #T_ea673_row6_col3, #T_ea673_row6_col5, #T_ea673_row6_col6, #T_ea673_row6_col7, #T_ea673_row6_col8, #T_ea673_row6_col9, #T_ea673_row7_col0, #T_ea673_row7_col1, #T_ea673_row7_col2, #T_ea673_row7_col3, #T_ea673_row7_col4, #T_ea673_row7_col5, #T_ea673_row7_col6, #T_ea673_row7_col7, #T_ea673_row7_col8, #T_ea673_row7_col9, #T_ea673_row8_col0, #T_ea673_row8_col1, #T_ea673_row8_col2, #T_ea673_row8_col3, #T_ea673_row8_col5, #T_ea673_row8_col6, #T_ea673_row8_col7, #T_ea673_row8_col8, #T_ea673_row8_col9, #T_ea673_row9_col0, #T_ea673_row9_col1, #T_ea673_row9_col2, #T_ea673_row9_col3, #T_ea673_row9_col4, #T_ea673_row9_col5, #T_ea673_row9_col6, #T_ea673_row9_col7, #T_ea673_row9_col8, #T_ea673_row9_col9, #T_ea673_row10_col0, #T_ea673_row10_col1, #T_ea673_row10_col2, #T_ea673_row10_col3, #T_ea673_row10_col4, #T_ea673_row10_col5, #T_ea673_row10_col7, #T_ea673_row10_col8, #T_ea673_row10_col9, #T_ea673_row11_col0, #T_ea673_row11_col1, #T_ea673_row11_col2, #T_ea673_row11_col3, #T_ea673_row11_col4, #T_ea673_row11_col6, #T_ea673_row11_col7, #T_ea673_row11_col8, #T_ea673_row11_col9, #T_ea673_row12_col0, #T_ea673_row12_col1, #T_ea673_row12_col2, #T_ea673_row12_col6, #T_ea673_row12_col7, #T_ea673_row12_col8, #T_ea673_row12_col9, #T_ea673_row13_col0, #T_ea673_row13_col1, #T_ea673_row13_col2, #T_ea673_row13_col3, #T_ea673_row13_col4, #T_ea673_row13_col5, #T_ea673_row13_col6, #T_ea673_row13_col7, #T_ea673_row13_col8, #T_ea673_row13_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_ea673_row1_col5, #T_ea673_row3_col3, #T_ea673_row4_col5, #T_ea673_row5_col5, #T_ea673_row5_col6, #T_ea673_row6_col4, #T_ea673_row8_col4, #T_ea673_row11_col5, #T_ea673_row12_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_ea673_row1_col6, #T_ea673_row2_col5, #T_ea673_row10_col6, #T_ea673_row12_col3, #T_ea673_row12_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_ea673">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_ea673_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_ea673_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_ea673_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_ea673_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_ea673_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_ea673_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_ea673_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_ea673_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_ea673_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_ea673_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ea673_row0_col0" class="data row0 col0" >bandar lampung</td>
#       <td id="T_ea673_row0_col1" class="data row0 col1" >-5.43</td>
#       <td id="T_ea673_row0_col2" class="data row0 col2" >105.26</td>
#       <td id="T_ea673_row0_col3" class="data row0 col3" >81.45° F</td>
#       <td id="T_ea673_row0_col4" class="data row0 col4" >62%</td>
#       <td id="T_ea673_row0_col5" class="data row0 col5" >1%</td>
#       <td id="T_ea673_row0_col6" class="data row0 col6" >3.85</td>
#       <td id="T_ea673_row0_col7" class="data row0 col7" >ID</td>
#       <td id="T_ea673_row0_col8" class="data row0 col8" >2023-09-26 17:33:03</td>
#       <td id="T_ea673_row0_col9" class="data row0 col9" >Grand Anugerah</td>
#     </tr>
#     <tr>
#       <td id="T_ea673_row1_col0" class="data row1 col0" >port isabel</td>
#       <td id="T_ea673_row1_col1" class="data row1 col1" >26.07</td>
#       <td id="T_ea673_row1_col2" class="data row1 col2" >-97.21</td>
#       <td id="T_ea673_row1_col3" class="data row1 col3" >85.93° F</td>
#       <td id="T_ea673_row1_col4" class="data row1 col4" >69%</td>
#       <td id="T_ea673_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_ea673_row1_col6" class="data row1 col6" >9.22</td>
#       <td id="T_ea673_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_ea673_row1_col8" class="data row1 col8" >2023-09-26 17:33:07</td>
#       <td id="T_ea673_row1_col9" class="data row1 col9" >Queen Isabel Inn</td>
#     </tr>
#     <tr>
#       <td id="T_ea673_row2_col0" class="data row2 col0" >bhuj</td>
#       <td id="T_ea673_row2_col1" class="data row2 col1" >23.27</td>
#       <td id="T_ea673_row2_col2" class="data row2 col2" >69.67</td>
#       <td id="T_ea673_row2_col3" class="data row2 col3" >79.48° F</td>
#       <td id="T_ea673_row2_col4" class="data row2 col4" >67%</td>
#       <td id="T_ea673_row2_col5" class="data row2 col5" >9%</td>
#       <td id="T_ea673_row2_col6" class="data row2 col6" >5.01</td>
#       <td id="T_ea673_row2_col7" class="data row2 col7" >IN</td>
#       <td id="T_ea673_row2_col8" class="data row2 col8" >2023-09-26 17:33:30</td>
#       <td id="T_ea673_row2_col9" class="data row2 col9" >Hotel Prince</td>
#     </tr>
#     <tr>
#       <td id="T_ea673_row3_col0" class="data row3 col0" >pasni</td>
#       <td id="T_ea673_row3_col1" class="data row3 col1" >25.26</td>
#       <td id="T_ea673_row3_col2" class="data row3 col2" >63.47</td>
#       <td id="T_ea673_row3_col3" class="data row3 col3" >78.85° F</td>
#       <td id="T_ea673_row3_col4" class="data row3 col4" >61%</td>
#       <td id="T_ea673_row3_col5" class="data row3 col5" >5%</td>
#       <td id="T_ea673_row3_col6" class="data row3 col6" >5.12</td>
#       <td id="T_ea673_row3_col7" class="data row3 col7" >PK</td>
#       <td id="T_ea673_row3_col8" class="data row3 col8" >2023-09-26 17:33:45</td>
#       <td id="T_ea673_row3_col9" class="data row3 col9" >Juddi Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_ea673_row4_col0" class="data row4 col0" >noosa heads</td>
#       <td id="T_ea673_row4_col1" class="data row4 col1" >-26.38</td>
#       <td id="T_ea673_row4_col2" class="data row4 col2" >153.15</td>
#       <td id="T_ea673_row4_col3" class="data row4 col3" >79.48° F</td>
#       <td id="T_ea673_row4_col4" class="data row4 col4" >53%</td>
#       <td id="T_ea673_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_ea673_row4_col6" class="data row4 col6" >7.16</td>
#       <td id="T_ea673_row4_col7" class="data row4 col7" >AU</td>
#       <td id="T_ea673_row4_col8" class="data row4 col8" >2023-09-26 17:33:46</td>
#       <td id="T_ea673_row4_col9" class="data row4 col9" >Costa Nova Apartments</td>
#     </tr>
#     <tr>
#       <td id="T_ea673_row5_col0" class="data row5 col0" >takanabe</td>
#       <td id="T_ea673_row5_col1" class="data row5 col1" >32.13</td>
#       <td id="T_ea673_row5_col2" class="data row5 col2" >131.50</td>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
