# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_6e398 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_6e398_row0_col0, #T_6e398_row0_col1, #T_6e398_row0_col2, #T_6e398_row0_col3, #T_6e398_row0_col4, #T_6e398_row0_col6, #T_6e398_row0_col7, #T_6e398_row0_col8, #T_6e398_row1_col0, #T_6e398_row1_col1, #T_6e398_row1_col2, #T_6e398_row1_col3, #T_6e398_row1_col4, #T_6e398_row1_col5, #T_6e398_row1_col6, #T_6e398_row1_col7, #T_6e398_row1_col8, #T_6e398_row2_col0, #T_6e398_row2_col1, #T_6e398_row2_col2, #T_6e398_row2_col3, #T_6e398_row2_col4, #T_6e398_row2_col5, #T_6e398_row2_col6, #T_6e398_row2_col7, #T_6e398_row2_col8, #T_6e398_row3_col0, #T_6e398_row3_col1, #T_6e398_row3_col2, #T_6e398_row3_col3, #T_6e398_row3_col4, #T_6e398_row3_col6, #T_6e398_row3_col7, #T_6e398_row3_col8, #T_6e398_row4_col0, #T_6e398_row4_col1, #T_6e398_row4_col2, #T_6e398_row4_col3, #T_6e398_row4_col4, #T_6e398_row4_col5, #T_6e398_row4_col7, #T_6e398_row4_col8, #T_6e398_row5_col0, #T_6e398_row5_col1, #T_6e398_row5_col2, #T_6e398_row5_col3, #T_6e398_row5_col4, #T_6e398_row5_col6, #T_6e398_row5_col7, #T_6e398_row5_col8, #T_6e398_row6_col0, #T_6e398_row6_col1, #T_6e398_row6_col2, #T_6e398_row6_col3, #T_6e398_row6_col4, #T_6e398_row6_col7, #T_6e398_row6_col8, #T_6e398_row7_col0, #T_6e398_row7_col1, #T_6e398_row7_col2, #T_6e398_row7_col3, #T_6e398_row7_col4, #T_6e398_row7_col7, #T_6e398_row7_col8, #T_6e398_row8_col0, #T_6e398_row8_col1, #T_6e398_row8_col2, #T_6e398_row8_col4, #T_6e398_row8_col5, #T_6e398_row8_col6, #T_6e398_row8_col7, #T_6e398_row8_col8, #T_6e398_row9_col0, #T_6e398_row9_col1, #T_6e398_row9_col2, #T_6e398_row9_col3, #T_6e398_row9_col4, #T_6e398_row9_col5, #T_6e398_row9_col6, #T_6e398_row9_col7, #T_6e398_row9_col8, #T_6e398_row10_col0, #T_6e398_row10_col1, #T_6e398_row10_col2, #T_6e398_row10_col6, #T_6e398_row10_col7, #T_6e398_row10_col8, #T_6e398_row11_col0, #T_6e398_row11_col1, #T_6e398_row11_col2, #T_6e398_row11_col3, #T_6e398_row11_col5, #T_6e398_row11_col6, #T_6e398_row11_col7, #T_6e398_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_6e398_row0_col5, #T_6e398_row3_col5, #T_6e398_row4_col6, #T_6e398_row5_col5, #T_6e398_row6_col5, #T_6e398_row10_col3, #T_6e398_row10_col5, #T_6e398_row11_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_6e398_row6_col6, #T_6e398_row7_col5, #T_6e398_row7_col6, #T_6e398_row8_col3, #T_6e398_row10_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_6e398">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_6e398_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_6e398_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_6e398_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_6e398_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_6e398_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_6e398_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_6e398_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_6e398_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_6e398_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6e398_row0_col0" class="data row0 col0" >margaret river</td>
#       <td id="T_6e398_row0_col1" class="data row0 col1" >-33.95</td>
#       <td id="T_6e398_row0_col2" class="data row0 col2" >115.07</td>
#       <td id="T_6e398_row0_col3" class="data row0 col3" >60.98° F</td>
#       <td id="T_6e398_row0_col4" class="data row0 col4" >78%</td>
#       <td id="T_6e398_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_6e398_row0_col6" class="data row0 col6" >19.24</td>
#       <td id="T_6e398_row0_col7" class="data row0 col7" >AU</td>
#       <td id="T_6e398_row0_col8" class="data row0 col8" >2023-09-14 11:43:18</td>
#     </tr>
#     <tr>
#       <td id="T_6e398_row1_col0" class="data row1 col0" >edinburgh of the seven seas</td>
#       <td id="T_6e398_row1_col1" class="data row1 col1" >-37.07</td>
#       <td id="T_6e398_row1_col2" class="data row1 col2" >-12.31</td>
#       <td id="T_6e398_row1_col3" class="data row1 col3" >51.91° F</td>
#       <td id="T_6e398_row1_col4" class="data row1 col4" >68%</td>
#       <td id="T_6e398_row1_col5" class="data row1 col5" >55%</td>
#       <td id="T_6e398_row1_col6" class="data row1 col6" >15.23</td>
#       <td id="T_6e398_row1_col7" class="data row1 col7" >SH</td>
#       <td id="T_6e398_row1_col8" class="data row1 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_6e398_row2_col0" class="data row2 col0" >nova sintra</td>
#       <td id="T_6e398_row2_col1" class="data row2 col1" >14.87</td>
#       <td id="T_6e398_row2_col2" class="data row2 col2" >-24.72</td>
#       <td id="T_6e398_row2_col3" class="data row2 col3" >75.85° F</td>
#       <td id="T_6e398_row2_col4" class="data row2 col4" >82%</td>
#       <td id="T_6e398_row2_col5" class="data row2 col5" >9%</td>
#       <td id="T_6e398_row2_col6" class="data row2 col6" >13.87</td>
#       <td id="T_6e398_row2_col7" class="data row2 col7" >CV</td>
#       <td id="T_6e398_row2_col8" class="data row2 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_6e398_row3_col0" class="data row3 col0" >adamstown</td>
#       <td id="T_6e398_row3_col1" class="data row3 col1" >-25.07</td>
#       <td id="T_6e398_row3_col2" class="data row3 col2" >-130.10</td>
#       <td id="T_6e398_row3_col3" class="data row3 col3" >64.40° F</td>
#       <td id="T_6e398_row3_col4" class="data row3 col4" >57%</td>
#       <td id="T_6e398_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_6e398_row3_col6" class="data row3 col6" >20.40</td>
#       <td id="T_6e398_row3_col7" class="data row3 col7" >PN</td>
#       <td id="T_6e398_row3_col8" class="data row3 col8" >2023-09-14 11:43:19</td>
#     </tr>
#     <tr>
#       <td id="T_6e398_row4_col0" class="data row4 col0" >port-aux-francais</td>
#       <td id="T_6e398_row4_col1" class="data row4 col1" >-49.35</td>
#       <td id="T_6e398_row4_col2" class="data row4 col2" >70.22</td>
#       <td id="T_6e398_row4_col3" class="data row4 col3" >38.30° F</td>
#       <td id="T_6e398_row4_col4" class="data row4 col4" >85%</td>
#       <td id="T_6e398_row4_col5" class="data row4 col5" >94%</td>
#       <td id="T_6e398_row4_col6" class="data row4 col6" >36.46</td>
#       <td id="T_6e398_row4_col7" class="data row4 col7" >TF</td>
#       <td id="T_6e398_row4_col8" class="data row4 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <tr>
#       <td id="T_6e398_row5_col0" class="data row5 col0" >afaahiti</td>
#       <td id="T_6e398_row5_col1" class="data row5 col1" >-17.75</td>
#       <td id="T_6e398_row5_col2" class="data row5 col2" >-149.28</td>
#       <td id="T_6e398_row5_col3" class="data row5 col3" >71.47° F</td>
#       <td id="T_6e398_row5_col4" class="data row5 col4" >90%</td>
#       <td id="T_6e398_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_6e398_row5_col6" class="data row5 col6" >20.71</td>
#       <td id="T_6e398_row5_col7" class="data row5 col7" >PF</td>
#       <td id="T_6e398_row5_col8" class="data row5 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <tr>
#       <td id="T_6e398_row6_col0" class="data row6 col0" >lompoc</td>
#       <td id="T_6e398_row6_col1" class="data row6 col1" >34.64</td>
#       <td id="T_6e398_row6_col2" class="data row6 col2" >-120.46</td>
#       <td id="T_6e398_row6_col3" class="data row6 col3" >65.59° F</td>
#       <td id="T_6e398_row6_col4" class="data row6 col4" >83%</td>
#       <td id="T_6e398_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_6e398_row6_col6" class="data row6 col6" >1.99</td>
#       <td id="T_6e398_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_6e398_row6_col8" class="data row6 col8" >2023-09-14 11:43:20</td>
#     </tr>
#     <

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 35) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 75), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 5), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_0250a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_0250a_row0_col0, #T_0250a_row0_col1, #T_0250a_row0_col2, #T_0250a_row0_col3, #T_0250a_row0_col4, #T_0250a_row0_col6, #T_0250a_row0_col7, #T_0250a_row0_col8, #T_0250a_row1_col0, #T_0250a_row1_col1, #T_0250a_row1_col2, #T_0250a_row1_col3, #T_0250a_row1_col7, #T_0250a_row1_col8, #T_0250a_row2_col0, #T_0250a_row2_col1, #T_0250a_row2_col2, #T_0250a_row2_col3, #T_0250a_row2_col6, #T_0250a_row2_col7, #T_0250a_row2_col8, #T_0250a_row3_col0, #T_0250a_row3_col1, #T_0250a_row3_col2, #T_0250a_row3_col4, #T_0250a_row3_col6, #T_0250a_row3_col7, #T_0250a_row3_col8, #T_0250a_row4_col0, #T_0250a_row4_col1, #T_0250a_row4_col2, #T_0250a_row4_col3, #T_0250a_row4_col4, #T_0250a_row4_col6, #T_0250a_row4_col7, #T_0250a_row4_col8, #T_0250a_row5_col0, #T_0250a_row5_col1, #T_0250a_row5_col2, #T_0250a_row5_col4, #T_0250a_row5_col6, #T_0250a_row5_col7, #T_0250a_row5_col8, #T_0250a_row6_col0, #T_0250a_row6_col1, #T_0250a_row6_col2, #T_0250a_row6_col3, #T_0250a_row6_col4, #T_0250a_row6_col5, #T_0250a_row6_col6, #T_0250a_row6_col7, #T_0250a_row6_col8, #T_0250a_row7_col0, #T_0250a_row7_col1, #T_0250a_row7_col2, #T_0250a_row7_col3, #T_0250a_row7_col7, #T_0250a_row7_col8, #T_0250a_row8_col0, #T_0250a_row8_col1, #T_0250a_row8_col2, #T_0250a_row8_col3, #T_0250a_row8_col4, #T_0250a_row8_col6, #T_0250a_row8_col7, #T_0250a_row8_col8, #T_0250a_row9_col0, #T_0250a_row9_col1, #T_0250a_row9_col2, #T_0250a_row9_col3, #T_0250a_row9_col6, #T_0250a_row9_col7, #T_0250a_row9_col8, #T_0250a_row10_col0, #T_0250a_row10_col1, #T_0250a_row10_col2, #T_0250a_row10_col3, #T_0250a_row10_col4, #T_0250a_row10_col6, #T_0250a_row10_col7, #T_0250a_row10_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_0250a_row0_col5, #T_0250a_row3_col5, #T_0250a_row4_col5, #T_0250a_row5_col3, #T_0250a_row5_col5, #T_0250a_row7_col4, #T_0250a_row7_col5, #T_0250a_row7_col6, #T_0250a_row8_col5, #T_0250a_row9_col4, #T_0250a_row9_col5, #T_0250a_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_0250a_row1_col4, #T_0250a_row1_col5, #T_0250a_row1_col6, #T_0250a_row2_col4, #T_0250a_row2_col5, #T_0250a_row3_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_0250a">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_0250a_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_0250a_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_0250a_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_0250a_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_0250a_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_0250a_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_0250a_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_0250a_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_0250a_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0250a_row0_col0" class="data row0 col0" >shekhupura</td>
#       <td id="T_0250a_row0_col1" class="data row0 col1" >31.71</td>
#       <td id="T_0250a_row0_col2" class="data row0 col2" >73.98</td>
#       <td id="T_0250a_row0_col3" class="data row0 col3" >84.25° F</td>
#       <td id="T_0250a_row0_col4" class="data row0 col4" >62%</td>
#       <td id="T_0250a_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_0250a_row0_col6" class="data row0 col6" >7.23</td>
#       <td id="T_0250a_row0_col7" class="data row0 col7" >PK</td>
#       <td id="T_0250a_row0_col8" class="data row0 col8" >2023-09-14 11:43:35</td>
#     </tr>
#     <tr>
#       <td id="T_0250a_row1_col0" class="data row1 col0" >maragogi</td>
#       <td id="T_0250a_row1_col1" class="data row1 col1" >-9.01</td>
#       <td id="T_0250a_row1_col2" class="data row1 col2" >-35.22</td>
#       <td id="T_0250a_row1_col3" class="data row1 col3" >78.39° F</td>
#       <td id="T_0250a_row1_col4" class="data row1 col4" >75%</td>
#       <td id="T_0250a_row1_col5" class="data row1 col5" >5%</td>
#       <td id="T_0250a_row1_col6" class="data row1 col6" >9.69</td>
#       <td id="T_0250a_row1_col7" class="data row1 col7" >BR</td>
#       <td id="T_0250a_row1_col8" class="data row1 col8" >2023-09-14 11:43:39</td>
#     </tr>
#     <tr>
#       <td id="T_0250a_row2_col0" class="data row2 col0" >fale old settlement</td>
#       <td id="T_0250a_row2_col1" class="data row2 col1" >-9.39</td>
#       <td id="T_0250a_row2_col2" class="data row2 col2" >-171.25</td>
#       <td id="T_0250a_row2_col3" class="data row2 col3" >82.67° F</td>
#       <td id="T_0250a_row2_col4" class="data row2 col4" >75%</td>
#       <td id="T_0250a_row2_col5" class="data row2 col5" >5%</td>
#       <td id="T_0250a_row2_col6" class="data row2 col6" >8.30</td>
#       <td id="T_0250a_row2_col7" class="data row2 col7" >TK</td>
#       <td id="T_0250a_row2_col8" class="data row2 col8" >2023-09-14 11:43:44</td>
#     </tr>
#     <tr>
#       <td id="T_0250a_row3_col0" class="data row3 col0" >san angelo</td>
#       <td id="T_0250a_row3_col1" class="data row3 col1" >31.46</td>
#       <td id="T_0250a_row3_col2" class="data row3 col2" >-100.44</td>
#       <td id="T_0250a_row3_col3" class="data row3 col3" >85.37° F</td>
#       <td id="T_0250a_row3_col4" class="data row3 col4" >62%</td>
#       <td id="T_0250a_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_0250a_row3_col6" class="data row3 col6" >5.75</td>
#       <td id="T_0250a_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_0250a_row3_col8" class="data row3 col8" >2023-09-14 11:36:47</td>
#     </tr>
#     <tr>
#       <td id="T_0250a_row4_col0" class="data row4 col0" >holualoa</td>
#       <td id="T_0250a_row4_col1" class="data row4 col1" >19.62</td>
#       <td id="T_0250a_row4_col2" class="data row4 col2" >-155.95</td>
#       <td id="T_0250a_row4_col3" class="data row4 col3" >77.74° F</td>
#       <td id="T_0250a_row4_col4" class="data row4 col4" >72%</td>
#       <td id="T_0250a_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_0250a_row4_col6" class="data row4 col6" >6.91</td>
#       <td id="T_0250a_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_0250a_row4_col8" class="data row4 col8" >2023-09-14 11:43:52</td>
#     </tr>
#     <tr>
#       <td id="T_0250a_row5_col0" class="data row5 col0" >retreat</td>
#       <td id="T_0250a_row5_col1" class="data row5 col1" >38.82</td>
#       <td id="T_0250a_row5_col2" class="data row5 col2" >-85.85</td>
#       <td id="T_0250a_row5_col3" class="data row5 col3" >76.41° F</td>
#       <td id="T_0250a_row5_col4" class="data row5 col4" >46%</td>
#       <td id="T_0250a_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_0250a_row5_col6" class="data row5 col6" >4.00</td>
#       <td id="T_0250a_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_0250a_row5_col8" class="data row5 col8" >2023-09-14 11:44:01</td>
#     </tr>
#     <tr>
#       <td id="T_0250a_row6_col0" class="data row6 col0" >atafu village</td>
#       <td id="T_0250a_row6_col1" class="data row6 col1" >-8.54</td>
#       <td id="T_0250a_row6_col2" class="data row6 col2" >-172.52</td>
#       <td id="T_0250a_row6_col3" class="data row6 col3" >82.90° F</td>
#       <td id="T_0250a_row6_col4" class="data row6 col4" >73%</td>
#       <td id="T_0250a_row6_col5" class="data row6 col5" >3%</td>
#       <td id="T_0250a_row6_col6" class="data row6 col6" >8.99</td>
#       <td id="T_0250a_row6_col7" class="data row6 col7" >TK</td>
#       <td id="T_0250a_row6_col8" class="data row6 col8" >2023-09-14 11:34:03</td>
#     </tr>
#     <tr>
#       <td id="T_0250a_row7_col0" class="data row7 col0" >weiser</td>
#       <td id="T_0250a_row7_col1" class="data row7 col1" >44.25</td>
#       <td id="T_0250a_row7_col2" class="data row7 col2" >-116.97</td>
#       <td id="T

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...City Hotel in shekhupura, PK
#
#
# Located the following hotel...Pousada Mariluz in maragogi, BR
#
#
# Located the following hotel...Hilton Hotel in san angelo, US
#
#
# Located the following hotel...Kona Hotel in holualoa, US
#
#
# Located the following hotel...Puerto Palmeras in puerto maldonado, PE
#
#
# Located the following hotel...Hotel Pilar Plaza in zaragoza, ES
#
#
# Located the following hotel...Kona Seaside Hotel in kailua-kona, US
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_18fe7 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_18fe7_row0_col0, #T_18fe7_row0_col1, #T_18fe7_row0_col2, #T_18fe7_row0_col3, #T_18fe7_row0_col4, #T_18fe7_row0_col6, #T_18fe7_row0_col7, #T_18fe7_row0_col8, #T_18fe7_row0_col9, #T_18fe7_row1_col0, #T_18fe7_row1_col1, #T_18fe7_row1_col2, #T_18fe7_row1_col3, #T_18fe7_row1_col7, #T_18fe7_row1_col8, #T_18fe7_row1_col9, #T_18fe7_row2_col0, #T_18fe7_row2_col1, #T_18fe7_row2_col2, #T_18fe7_row2_col4, #T_18fe7_row2_col6, #T_18fe7_row2_col7, #T_18fe7_row2_col8, #T_18fe7_row2_col9, #T_18fe7_row3_col0, #T_18fe7_row3_col1, #T_18fe7_row3_col2, #T_18fe7_row3_col4, #T_18fe7_row3_col6, #T_18fe7_row3_col7, #T_18fe7_row3_col8, #T_18fe7_row3_col9, #T_18fe7_row4_col0, #T_18fe7_row4_col1, #T_18fe7_row4_col2, #T_18fe7_row4_col3, #T_18fe7_row4_col4, #T_18fe7_row4_col6, #T_18fe7_row4_col7, #T_18fe7_row4_col8, #T_18fe7_row4_col9, #T_18fe7_row5_col0, #T_18fe7_row5_col1, #T_18fe7_row5_col2, #T_18fe7_row5_col3, #T_18fe7_row5_col7, #T_18fe7_row5_col8, #T_18fe7_row5_col9, #T_18fe7_row6_col0, #T_18fe7_row6_col1, #T_18fe7_row6_col2, #T_18fe7_row6_col3, #T_18fe7_row6_col4, #T_18fe7_row6_col6, #T_18fe7_row6_col7, #T_18fe7_row6_col8, #T_18fe7_row6_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_18fe7_row0_col5, #T_18fe7_row2_col5, #T_18fe7_row3_col3, #T_18fe7_row3_col5, #T_18fe7_row4_col5, #T_18fe7_row5_col4, #T_18fe7_row5_col5, #T_18fe7_row5_col6, #T_18fe7_row6_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_18fe7_row1_col4, #T_18fe7_row1_col5, #T_18fe7_row1_col6, #T_18fe7_row2_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_18fe7">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_18fe7_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_18fe7_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_18fe7_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_18fe7_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_18fe7_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_18fe7_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_18fe7_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_18fe7_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_18fe7_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_18fe7_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_18fe7_row0_col0" class="data row0 col0" >shekhupura</td>
#       <td id="T_18fe7_row0_col1" class="data row0 col1" >31.71</td>
#       <td id="T_18fe7_row0_col2" class="data row0 col2" >73.98</td>
#       <td id="T_18fe7_row0_col3" class="data row0 col3" >84.25° F</td>
#       <td id="T_18fe7_row0_col4" class="data row0 col4" >62%</td>
#       <td id="T_18fe7_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_18fe7_row0_col6" class="data row0 col6" >7.23</td>
#       <td id="T_18fe7_row0_col7" class="data row0 col7" >PK</td>
#       <td id="T_18fe7_row0_col8" class="data row0 col8" >2023-09-14 11:43:35</td>
#       <td id="T_18fe7_row0_col9" class="data row0 col9" >City Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_18fe7_row1_col0" class="data row1 col0" >maragogi</td>
#       <td id="T_18fe7_row1_col1" class="data row1 col1" >-9.01</td>
#       <td id="T_18fe7_row1_col2" class="data row1 col2" >-35.22</td>
#       <td id="T_18fe7_row1_col3" class="data row1 col3" >78.39° F</td>
#       <td id="T_18fe7_row1_col4" class="data row1 col4" >75%</td>
#       <td id="T_18fe7_row1_col5" class="data row1 col5" >5%</td>
#       <td id="T_18fe7_row1_col6" class="data row1 col6" >9.69</td>
#       <td id="T_18fe7_row1_col7" class="data row1 col7" >BR</td>
#       <td id="T_18fe7_row1_col8" class="data row1 col8" >2023-09-14 11:43:39</td>
#       <td id="T_18fe7_row1_col9" class="data row1 col9" >Pousada Mariluz</td>
#     </tr>
#     <tr>
#       <td id="T_18fe7_row2_col0" class="data row2 col0" >san angelo</td>
#       <td id="T_18fe7_row2_col1" class="data row2 col1" >31.46</td>
#       <td id="T_18fe7_row2_col2" class="data row2 col2" >-100.44</td>
#       <td id="T_18fe7_row2_col3" class="data row2 col3" >85.37° F</td>
#       <td id="T_18fe7_row2_col4" class="data row2 col4" >62%</td>
#       <td id="T_18fe7_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_18fe7_row2_col6" class="data row2 col6" >5.75</td>
#       <td id="T_18fe7_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_18fe7_row2_col8" class="data row2 col8" >2023-09-14 11:36:47</td>
#       <td id="T_18fe7_row2_col9" class="data row2 col9" >Hilton Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_18fe7_row3_col0" class="data row3 col0" >holualoa</td>
#       <td id="T_18fe7_row3_col1" class="data row3 col1" >19.62</td>
#       <td id="T_18fe7_row3_col2" class="data row3 col2" >-155.95</td>
#       <td id="T_18fe7_row3_col3" class="data row3 col3" >77.74° F</td>
#       <td id="T_18fe7_row3_col4" class="data row3 col4" >72%</td>
#       <td id="T_18fe7_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_18fe7_row3_col6" class="data row3 col6" >6.91</td>
#       <td id="T_18fe7_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_18fe7_row3_col8" class="data row3 col8" >2023-09-14 11:43:52</td>
#       <td id="T_18fe7_row3_col9" class="data row3 col9" >Kona Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_18fe7_row4_col0" class="data row4 col0" >puerto maldonado</td>
#       <td id="T_18fe7_row4_col1" class="data row4 col1" >-12.60</td>
#       <td id="T_18fe7_row4_col2" class="data row4 col2" >-69.18</td>
#       <td id="T_18fe7_row4_col3" class="data row4 col3" >81.00° F</td>
#       <td id="T_18fe7_row4_col4" class="data row4 col4" >44%</td>
#       <td id="T_18fe7_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_18fe7_row4_col6" class="data row4 col6" >5.75</td>
#       <td id="T_18fe7_row4_col7" class="data row4 col7" >PE</td>
#       <td id="T_18fe7_row4_col8" class="data row4 col8" >2023-09-14 11:44:48</td>
#       <td id="T_18fe7_row4_col9" class="data row4 col9" >Puerto Palmeras</td>
#     </tr>
#     <tr>
#       <td id="T_18fe7_row5_col0" class="data row5 col0" >zaragoza</td>
#       <td id="T_18fe7_row5_col1" class="data row5 col1" >41.66</td>
#       <td id="T_18fe7_row5_col2" class="data row5 col2" >-0.88</td>
#       <td id="T_18fe7_row5_col3" class="data row5 col3" >80.85° F</td>
#       <td id="T_18fe7_row5_col4" class="data row5 col4" >38%</td>
#       <td id="T_18fe7_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_18fe7_row5_col6" class="data row5 col6" >4.61</td>
#       <td id="T_18fe7_row5_col7" class="data row5 col7" >ES</td>
#       <td id="T_18fe7_row5_col8" class="data row5 col8" >2023-09-14 11:42:29</td>
#       <td id="T_18fe7_row5_col9" class="data row5 col9" >Hotel Pilar Plaza</td>
#     </tr>
#     <tr>
#       <td id="T_18fe7_row6_col0" class="data row6 col0" >kailua-kona</td>
#       <td id="T_18fe7_row6_col1" class="data row6 col1" >19.64</td>
#       <td id="T_18fe7_row6_col2" class="data row6 col2" >-156.00</td>
#       <td id="T_18fe7_row6_col3" class="data row6 col3" >81.50° F</td>
#       <td id="T_18fe7_row6_col4" class="data row6 col4" >72%</td>
#       <td id="T_18fe7_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_18fe7_row6_col6" class="data row6 col6" >6.91</td>
#       <td id="T_18fe7_row6_col7" class="data row6 col7" >US</td>
#       <td id="T_18fe7_row6_col8" class="data row6 col8" >2023-09-14 11:45:05</td>
#       <td id="T_18fe7_row6_col9" class="data row6 col9" >Kona Seaside Hotel</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
