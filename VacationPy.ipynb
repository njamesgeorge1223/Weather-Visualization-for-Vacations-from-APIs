# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
captionString \
    = 'Table: 1.1: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_11709 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_11709_row0_col0, #T_11709_row0_col1, #T_11709_row0_col2, #T_11709_row0_col3, #T_11709_row0_col4, #T_11709_row0_col7, #T_11709_row0_col8, #T_11709_row1_col0, #T_11709_row1_col1, #T_11709_row1_col2, #T_11709_row1_col4, #T_11709_row1_col5, #T_11709_row1_col6, #T_11709_row1_col7, #T_11709_row1_col8, #T_11709_row2_col0, #T_11709_row2_col1, #T_11709_row2_col2, #T_11709_row2_col3, #T_11709_row2_col4, #T_11709_row2_col6, #T_11709_row2_col7, #T_11709_row2_col8, #T_11709_row3_col0, #T_11709_row3_col1, #T_11709_row3_col2, #T_11709_row3_col4, #T_11709_row3_col5, #T_11709_row3_col6, #T_11709_row3_col7, #T_11709_row3_col8, #T_11709_row4_col0, #T_11709_row4_col1, #T_11709_row4_col2, #T_11709_row4_col3, #T_11709_row4_col4, #T_11709_row4_col7, #T_11709_row4_col8, #T_11709_row5_col0, #T_11709_row5_col1, #T_11709_row5_col2, #T_11709_row5_col3, #T_11709_row5_col4, #T_11709_row5_col5, #T_11709_row5_col6, #T_11709_row5_col7, #T_11709_row5_col8, #T_11709_row6_col0, #T_11709_row6_col1, #T_11709_row6_col2, #T_11709_row6_col3, #T_11709_row6_col4, #T_11709_row6_col5, #T_11709_row6_col6, #T_11709_row6_col7, #T_11709_row6_col8, #T_11709_row7_col0, #T_11709_row7_col1, #T_11709_row7_col2, #T_11709_row7_col3, #T_11709_row7_col4, #T_11709_row7_col6, #T_11709_row7_col7, #T_11709_row7_col8, #T_11709_row8_col0, #T_11709_row8_col1, #T_11709_row8_col2, #T_11709_row8_col3, #T_11709_row8_col5, #T_11709_row8_col6, #T_11709_row8_col7, #T_11709_row8_col8, #T_11709_row9_col0, #T_11709_row9_col1, #T_11709_row9_col2, #T_11709_row9_col3, #T_11709_row9_col4, #T_11709_row9_col5, #T_11709_row9_col6, #T_11709_row9_col7, #T_11709_row9_col8, #T_11709_row10_col0, #T_11709_row10_col1, #T_11709_row10_col2, #T_11709_row10_col3, #T_11709_row10_col4, #T_11709_row10_col5, #T_11709_row10_col6, #T_11709_row10_col7, #T_11709_row10_col8, #T_11709_row11_col0, #T_11709_row11_col1, #T_11709_row11_col2, #T_11709_row11_col3, #T_11709_row11_col6, #T_11709_row11_col7, #T_11709_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_11709_row0_col5, #T_11709_row3_col3, #T_11709_row4_col5, #T_11709_row4_col6, #T_11709_row7_col5, #T_11709_row11_col4, #T_11709_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_11709_row0_col6, #T_11709_row1_col3, #T_11709_row2_col5, #T_11709_row8_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_11709">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_11709_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_11709_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_11709_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_11709_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_11709_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_11709_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_11709_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_11709_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_11709_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_11709_row0_col0" class="data row0 col0" >ust'-barguzin</td>
#       <td id="T_11709_row0_col1" class="data row0 col1" >53.45</td>
#       <td id="T_11709_row0_col2" class="data row0 col2" >108.98</td>
#       <td id="T_11709_row0_col3" class="data row0 col3" >52.56° F</td>
#       <td id="T_11709_row0_col4" class="data row0 col4" >89%</td>
#       <td id="T_11709_row0_col5" class="data row0 col5" >100%</td>
#       <td id="T_11709_row0_col6" class="data row0 col6" >4.18</td>
#       <td id="T_11709_row0_col7" class="data row0 col7" >RU</td>
#       <td id="T_11709_row0_col8" class="data row0 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_11709_row1_col0" class="data row1 col0" >longyearbyen</td>
#       <td id="T_11709_row1_col1" class="data row1 col1" >78.22</td>
#       <td id="T_11709_row1_col2" class="data row1 col2" >15.64</td>
#       <td id="T_11709_row1_col3" class="data row1 col3" >22.84° F</td>
#       <td id="T_11709_row1_col4" class="data row1 col4" >80%</td>
#       <td id="T_11709_row1_col5" class="data row1 col5" >20%</td>
#       <td id="T_11709_row1_col6" class="data row1 col6" >5.75</td>
#       <td id="T_11709_row1_col7" class="data row1 col7" >SJ</td>
#       <td id="T_11709_row1_col8" class="data row1 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_11709_row2_col0" class="data row2 col0" >lebu</td>
#       <td id="T_11709_row2_col1" class="data row2 col1" >-37.62</td>
#       <td id="T_11709_row2_col2" class="data row2 col2" >-73.65</td>
#       <td id="T_11709_row2_col3" class="data row2 col3" >52.09° F</td>
#       <td id="T_11709_row2_col4" class="data row2 col4" >65%</td>
#       <td id="T_11709_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_11709_row2_col6" class="data row2 col6" >12.62</td>
#       <td id="T_11709_row2_col7" class="data row2 col7" >CL</td>
#       <td id="T_11709_row2_col8" class="data row2 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_11709_row3_col0" class="data row3 col0" >carutapera</td>
#       <td id="T_11709_row3_col1" class="data row3 col1" >-1.20</td>
#       <td id="T_11709_row3_col2" class="data row3 col2" >-46.02</td>
#       <td id="T_11709_row3_col3" class="data row3 col3" >86.38° F</td>
#       <td id="T_11709_row3_col4" class="data row3 col4" >63%</td>
#       <td id="T_11709_row3_col5" class="data row3 col5" >3%</td>
#       <td id="T_11709_row3_col6" class="data row3 col6" >12.64</td>
#       <td id="T_11709_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_11709_row3_col8" class="data row3 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_11709_row4_col0" class="data row4 col0" >alofi</td>
#       <td id="T_11709_row4_col1" class="data row4 col1" >-19.06</td>
#       <td id="T_11709_row4_col2" class="data row4 col2" >-169.92</td>
#       <td id="T_11709_row4_col3" class="data row4 col3" >71.49° F</td>
#       <td id="T_11709_row4_col4" class="data row4 col4" >68%</td>
#       <td id="T_11709_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_11709_row4_col6" class="data row4 col6" >19.57</td>
#       <td id="T_11709_row4_col7" class="data row4 col7" >NU</td>
#       <td id="T_11709_row4_col8" class="data row4 col8" >2023-09-23 11:54:04</td>
#     </tr>
#     <tr>
#       <td id="T_11709_row5_col0" class="data row5 col0" >teteven</td>
#       <td id="T_11709_row5_col1" class="data row5 col1" >42.92</td>
#       <td id="T_11709_row5_col2" class="data row5 col2" >24.27</td>
#       <td id="T_11709_row5_col3" class="data row5 col3" >74.39° F</td>
#       <td id="T_11709_row5_col4" class="data row5 col4" >45%</td>
#       <td id="T_11709_row5_col5" class="data row5 col5" >16%</td>
#       <td id="T_11709_row5_col6" class="data row5 col6" >6.40</td>
#       <td id="T_11709_row5_col7" class="data row5 col7" >BG</td>
#       <td id="T_11709_row5_col8" class="data row5 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_11709_row6_col0" class="data row6 col0" >morondava</td>
#       <td id="T_11709_row6_col1" class="data row6 col1" >-20.28</td>
#       <td id="T_11709_row6_col2" class="data row6 col2" >44.28</td>
#       <td id="T_11709_row6_col3" class="data row6 col3" >77.72° F</td>
#       <td id="T_11709_row6_col4" class="data row6 col4" >83%</td>
#       <td id="T_11709_row6_col5" class="data row6 col5" >69%</td>
#       <td id="T_11709_row6_col6" class="data row6 col6" >4.90</td>
#       <td id="T_11709_row6_col7" class="data row6 col7" >MG</td>
#       <td id="T_11709_row6_col8" class="data row6 col8" >2023-09-23 11:54:05</td>
#     </tr>
#     <tr>
#       <td id="T_11709_row7_col0" class="

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 93), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 40) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 70), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 10), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
captionString \
    = 'Table: 2.1: Ideal Vacation Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (idealVacationLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_54ea7 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_54ea7_row0_col0, #T_54ea7_row0_col1, #T_54ea7_row0_col2, #T_54ea7_row0_col3, #T_54ea7_row0_col4, #T_54ea7_row0_col7, #T_54ea7_row0_col8, #T_54ea7_row1_col0, #T_54ea7_row1_col1, #T_54ea7_row1_col2, #T_54ea7_row1_col3, #T_54ea7_row1_col4, #T_54ea7_row1_col6, #T_54ea7_row1_col7, #T_54ea7_row1_col8, #T_54ea7_row2_col0, #T_54ea7_row2_col1, #T_54ea7_row2_col2, #T_54ea7_row2_col4, #T_54ea7_row2_col6, #T_54ea7_row2_col7, #T_54ea7_row2_col8, #T_54ea7_row3_col0, #T_54ea7_row3_col1, #T_54ea7_row3_col2, #T_54ea7_row3_col3, #T_54ea7_row3_col4, #T_54ea7_row3_col5, #T_54ea7_row3_col6, #T_54ea7_row3_col7, #T_54ea7_row3_col8, #T_54ea7_row4_col0, #T_54ea7_row4_col1, #T_54ea7_row4_col2, #T_54ea7_row4_col3, #T_54ea7_row4_col4, #T_54ea7_row4_col6, #T_54ea7_row4_col7, #T_54ea7_row4_col8, #T_54ea7_row5_col0, #T_54ea7_row5_col1, #T_54ea7_row5_col2, #T_54ea7_row5_col4, #T_54ea7_row5_col7, #T_54ea7_row5_col8, #T_54ea7_row6_col0, #T_54ea7_row6_col1, #T_54ea7_row6_col2, #T_54ea7_row6_col3, #T_54ea7_row6_col6, #T_54ea7_row6_col7, #T_54ea7_row6_col8, #T_54ea7_row7_col0, #T_54ea7_row7_col1, #T_54ea7_row7_col2, #T_54ea7_row7_col3, #T_54ea7_row7_col6, #T_54ea7_row7_col7, #T_54ea7_row7_col8, #T_54ea7_row8_col0, #T_54ea7_row8_col1, #T_54ea7_row8_col2, #T_54ea7_row8_col3, #T_54ea7_row8_col4, #T_54ea7_row8_col5, #T_54ea7_row8_col6, #T_54ea7_row8_col7, #T_54ea7_row8_col8, #T_54ea7_row9_col0, #T_54ea7_row9_col1, #T_54ea7_row9_col2, #T_54ea7_row9_col3, #T_54ea7_row9_col4, #T_54ea7_row9_col6, #T_54ea7_row9_col7, #T_54ea7_row9_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_54ea7_row0_col5, #T_54ea7_row0_col6, #T_54ea7_row2_col3, #T_54ea7_row7_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_54ea7_row1_col5, #T_54ea7_row2_col5, #T_54ea7_row4_col5, #T_54ea7_row5_col3, #T_54ea7_row5_col5, #T_54ea7_row5_col6, #T_54ea7_row6_col4, #T_54ea7_row6_col5, #T_54ea7_row7_col5, #T_54ea7_row9_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_54ea7">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_54ea7_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_54ea7_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_54ea7_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_54ea7_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_54ea7_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_54ea7_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_54ea7_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_54ea7_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_54ea7_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_54ea7_row0_col0" class="data row0 col0" >brisas de zicatela</td>
#       <td id="T_54ea7_row0_col1" class="data row0 col1" >15.84</td>
#       <td id="T_54ea7_row0_col2" class="data row0 col2" >-97.04</td>
#       <td id="T_54ea7_row0_col3" class="data row0 col3" >88.54° F</td>
#       <td id="T_54ea7_row0_col4" class="data row0 col4" >66%</td>
#       <td id="T_54ea7_row0_col5" class="data row0 col5" >8%</td>
#       <td id="T_54ea7_row0_col6" class="data row0 col6" >8.59</td>
#       <td id="T_54ea7_row0_col7" class="data row0 col7" >MX</td>
#       <td id="T_54ea7_row0_col8" class="data row0 col8" >2023-09-23 11:54:43</td>
#     </tr>
#     <tr>
#       <td id="T_54ea7_row1_col0" class="data row1 col0" >alexandria</td>
#       <td id="T_54ea7_row1_col1" class="data row1 col1" >31.22</td>
#       <td id="T_54ea7_row1_col2" class="data row1 col2" >29.96</td>
#       <td id="T_54ea7_row1_col3" class="data row1 col3" >77.54° F</td>
#       <td id="T_54ea7_row1_col4" class="data row1 col4" >65%</td>
#       <td id="T_54ea7_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_54ea7_row1_col6" class="data row1 col6" >7.09</td>
#       <td id="T_54ea7_row1_col7" class="data row1 col7" >EG</td>
#       <td id="T_54ea7_row1_col8" class="data row1 col8" >2023-09-23 11:46:38</td>
#     </tr>
#     <tr>
#       <td id="T_54ea7_row2_col0" class="data row2 col0" >manicore</td>
#       <td id="T_54ea7_row2_col1" class="data row2 col1" >-5.81</td>
#       <td id="T_54ea7_row2_col2" class="data row2 col2" >-61.30</td>
#       <td id="T_54ea7_row2_col3" class="data row2 col3" >91.35° F</td>
#       <td id="T_54ea7_row2_col4" class="data row2 col4" >49%</td>
#       <td id="T_54ea7_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_54ea7_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_54ea7_row2_col7" class="data row2 col7" >BR</td>
#       <td id="T_54ea7_row2_col8" class="data row2 col8" >2023-09-23 11:55:04</td>
#     </tr>
#     <tr>
#       <td id="T_54ea7_row3_col0" class="data row3 col0" >kaura namoda</td>
#       <td id="T_54ea7_row3_col1" class="data row3 col1" >12.59</td>
#       <td id="T_54ea7_row3_col2" class="data row3 col2" >6.58</td>
#       <td id="T_54ea7_row3_col3" class="data row3 col3" >85.86° F</td>
#       <td id="T_54ea7_row3_col4" class="data row3 col4" >53%</td>
#       <td id="T_54ea7_row3_col5" class="data row3 col5" >7%</td>
#       <td id="T_54ea7_row3_col6" class="data row3 col6" >5.75</td>
#       <td id="T_54ea7_row3_col7" class="data row3 col7" >NG</td>
#       <td id="T_54ea7_row3_col8" class="data row3 col8" >2023-09-23 11:55:15</td>
#     </tr>
#     <tr>
#       <td id="T_54ea7_row4_col0" class="data row4 col0" >rethymno</td>
#       <td id="T_54ea7_row4_col1" class="data row4 col1" >35.36</td>
#       <td id="T_54ea7_row4_col2" class="data row4 col2" >24.47</td>
#       <td id="T_54ea7_row4_col3" class="data row4 col3" >76.62° F</td>
#       <td id="T_54ea7_row4_col4" class="data row4 col4" >49%</td>
#       <td id="T_54ea7_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_54ea7_row4_col6" class="data row4 col6" >4.12</td>
#       <td id="T_54ea7_row4_col7" class="data row4 col7" >GR</td>
#       <td id="T_54ea7_row4_col8" class="data row4 col8" >2023-09-23 11:55:22</td>
#     </tr>
#     <tr>
#       <td id="T_54ea7_row5_col0" class="data row5 col0" >moires</td>
#       <td id="T_54ea7_row5_col1" class="data row5 col1" >35.05</td>
#       <td id="T_54ea7_row5_col2" class="data row5 col2" >24.87</td>
#       <td id="T_54ea7_row5_col3" class="data row5 col3" >76.28° F</td>
#       <td id="T_54ea7_row5_col4" class="data row5 col4" >58%</td>
#       <td id="T_54ea7_row5_col5" class="data row5 col5" >0%</td>
#       <td id="T_54ea7_row5_col6" class="data row5 col6" >3.00</td>
#       <td id="T_54ea7_row5_col7" class="data row5 col7" >GR</td>
#       <td id="T_54ea7_row5_col8" class="data row5 col8" >2023-09-23 11:55:28</td>
#     </tr>
#     <tr>
#       <td id="T_54ea7_row6_col0" class="data row6 col0" >barkhan</td>
#       <td id="T_54ea7_row6_col1" class="data row6 col1" >29.90</td>
#       <td id="T_54ea7_row6_col2" class="data row6 col2" >69.53</td>
#       <td id="T_54ea7_row6_col3" class="data row6 col3" >79.27° F</td>
#       <td id="T_54ea7_row6_col4" class="data row6 col4" >48%</td>
#       <td id="T_54ea7_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_54ea7_row6_col6" class="data row6 col6" >6.24</td>
#       <td id="T_54ea7_row6_col7" class="data row6 col7" >PK</td>
#       <td id="T_54ea7_row6_col8" class="data row6 col8" >2023-09-23 11:55:35</td>
#     </tr>
#     <tr>
#       <td id="T_54ea7_row7_col0" class="data row7 col0" >ocos</td>
#       <td id="T_54ea7_row7_col1" class="data row7 col1" >14.51</td>
#       <td id="T_54ea7_row7_col2" class="data row7 col2" >-92.19</td>
#       <td id="T_54ea7_row7_col3" class="data row7 col3" >87.12° F</td>
#       <td id="T_54ea7_row7_col4" class="data row7 col4" >68%</td>
#       <td id="T_54ea7_row7_col5" class="data row7 col5" >0%</td>
#       <td id="T_54ea

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Casa de Olas in brisas de zicatela, MX
#
#
# Located the following hotel...Smoha Zahran Haus (7th floor) in alexandria, EG
#
#
# Located the following hotel...Jo-An Palace in rethymno, GR
#
#
# Located the following hotel...Hotel Olympic in moires, GR
#
#
# Located the following hotel...La Quinta Inn & Suites by Wyndham Festus - St. Louis South in festus, US
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
captionString \
    = 'Table: 3.1: Hotel Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedHotelLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_4c7b3 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_4c7b3_row0_col0, #T_4c7b3_row0_col1, #T_4c7b3_row0_col2, #T_4c7b3_row0_col7, #T_4c7b3_row0_col8, #T_4c7b3_row0_col9, #T_4c7b3_row1_col0, #T_4c7b3_row1_col1, #T_4c7b3_row1_col2, #T_4c7b3_row1_col3, #T_4c7b3_row1_col4, #T_4c7b3_row1_col6, #T_4c7b3_row1_col7, #T_4c7b3_row1_col8, #T_4c7b3_row1_col9, #T_4c7b3_row2_col0, #T_4c7b3_row2_col1, #T_4c7b3_row2_col2, #T_4c7b3_row2_col3, #T_4c7b3_row2_col6, #T_4c7b3_row2_col7, #T_4c7b3_row2_col8, #T_4c7b3_row2_col9, #T_4c7b3_row3_col0, #T_4c7b3_row3_col1, #T_4c7b3_row3_col2, #T_4c7b3_row3_col4, #T_4c7b3_row3_col7, #T_4c7b3_row3_col8, #T_4c7b3_row3_col9, #T_4c7b3_row4_col0, #T_4c7b3_row4_col1, #T_4c7b3_row4_col2, #T_4c7b3_row4_col3, #T_4c7b3_row4_col5, #T_4c7b3_row4_col6, #T_4c7b3_row4_col7, #T_4c7b3_row4_col8, #T_4c7b3_row4_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_4c7b3_row0_col3, #T_4c7b3_row0_col4, #T_4c7b3_row0_col5, #T_4c7b3_row0_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_4c7b3_row1_col5, #T_4c7b3_row2_col4, #T_4c7b3_row2_col5, #T_4c7b3_row3_col3, #T_4c7b3_row3_col5, #T_4c7b3_row3_col6, #T_4c7b3_row4_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_4c7b3">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_4c7b3_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_4c7b3_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_4c7b3_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_4c7b3_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_4c7b3_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_4c7b3_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_4c7b3_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_4c7b3_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_4c7b3_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_4c7b3_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4c7b3_row0_col0" class="data row0 col0" >brisas de zicatela</td>
#       <td id="T_4c7b3_row0_col1" class="data row0 col1" >15.84</td>
#       <td id="T_4c7b3_row0_col2" class="data row0 col2" >-97.04</td>
#       <td id="T_4c7b3_row0_col3" class="data row0 col3" >88.54° F</td>
#       <td id="T_4c7b3_row0_col4" class="data row0 col4" >66%</td>
#       <td id="T_4c7b3_row0_col5" class="data row0 col5" >8%</td>
#       <td id="T_4c7b3_row0_col6" class="data row0 col6" >8.59</td>
#       <td id="T_4c7b3_row0_col7" class="data row0 col7" >MX</td>
#       <td id="T_4c7b3_row0_col8" class="data row0 col8" >2023-09-23 11:54:43</td>
#       <td id="T_4c7b3_row0_col9" class="data row0 col9" >Casa de Olas</td>
#     </tr>
#     <tr>
#       <td id="T_4c7b3_row1_col0" class="data row1 col0" >alexandria</td>
#       <td id="T_4c7b3_row1_col1" class="data row1 col1" >31.22</td>
#       <td id="T_4c7b3_row1_col2" class="data row1 col2" >29.96</td>
#       <td id="T_4c7b3_row1_col3" class="data row1 col3" >77.54° F</td>
#       <td id="T_4c7b3_row1_col4" class="data row1 col4" >65%</td>
#       <td id="T_4c7b3_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_4c7b3_row1_col6" class="data row1 col6" >7.09</td>
#       <td id="T_4c7b3_row1_col7" class="data row1 col7" >EG</td>
#       <td id="T_4c7b3_row1_col8" class="data row1 col8" >2023-09-23 11:46:38</td>
#       <td id="T_4c7b3_row1_col9" class="data row1 col9" >Smoha Zahran Haus (7th floor)</td>
#     </tr>
#     <tr>
#       <td id="T_4c7b3_row2_col0" class="data row2 col0" >rethymno</td>
#       <td id="T_4c7b3_row2_col1" class="data row2 col1" >35.36</td>
#       <td id="T_4c7b3_row2_col2" class="data row2 col2" >24.47</td>
#       <td id="T_4c7b3_row2_col3" class="data row2 col3" >76.62° F</td>
#       <td id="T_4c7b3_row2_col4" class="data row2 col4" >49%</td>
#       <td id="T_4c7b3_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_4c7b3_row2_col6" class="data row2 col6" >4.12</td>
#       <td id="T_4c7b3_row2_col7" class="data row2 col7" >GR</td>
#       <td id="T_4c7b3_row2_col8" class="data row2 col8" >2023-09-23 11:55:22</td>
#       <td id="T_4c7b3_row2_col9" class="data row2 col9" >Jo-An Palace</td>
#     </tr>
#     <tr>
#       <td id="T_4c7b3_row3_col0" class="data row3 col0" >moires</td>
#       <td id="T_4c7b3_row3_col1" class="data row3 col1" >35.05</td>
#       <td id="T_4c7b3_row3_col2" class="data row3 col2" >24.87</td>
#       <td id="T_4c7b3_row3_col3" class="data row3 col3" >76.28° F</td>
#       <td id="T_4c7b3_row3_col4" class="data row3 col4" >58%</td>
#       <td id="T_4c7b3_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_4c7b3_row3_col6" class="data row3 col6" >3.00</td>
#       <td id="T_4c7b3_row3_col7" class="data row3 col7" >GR</td>
#       <td id="T_4c7b3_row3_col8" class="data row3 col8" >2023-09-23 11:55:28</td>
#       <td id="T_4c7b3_row3_col9" class="data row3 col9" >Hotel Olympic</td>
#     </tr>
#     <tr>
#       <td id="T_4c7b3_row4_col0" class="data row4 col0" >festus</td>
#       <td id="T_4c7b3_row4_col1" class="data row4 col1" >38.22</td>
#       <td id="T_4c7b3_row4_col2" class="data row4 col2" >-90.40</td>
#       <td id="T_4c7b3_row4_col3" class="data row4 col3" >86.04° F</td>
#       <td id="T_4c7b3_row4_col4" class="data row4 col4" >49%</td>
#       <td id="T_4c7b3_row4_col5" class="data row4 col5" >2%</td>
#       <td id="T_4c7b3_row4_col6" class="data row4 col6" >7.34</td>
#       <td id="T_4c7b3_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_4c7b3_row4_col8" class="data row4 col8" >2023-09-23 11:52:12</td>
#       <td id="T_4c7b3_row4_col9" class="data row4 col9" >La Quinta Inn & Suites by Wyndham Festus - St. Louis South</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
