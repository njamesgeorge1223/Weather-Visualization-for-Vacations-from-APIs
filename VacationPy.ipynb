# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_073cd caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_073cd_row0_col0, #T_073cd_row0_col1, #T_073cd_row0_col2, #T_073cd_row0_col3, #T_073cd_row0_col4, #T_073cd_row0_col5, #T_073cd_row0_col6, #T_073cd_row0_col7, #T_073cd_row0_col8, #T_073cd_row1_col0, #T_073cd_row1_col1, #T_073cd_row1_col2, #T_073cd_row1_col3, #T_073cd_row1_col4, #T_073cd_row1_col5, #T_073cd_row1_col6, #T_073cd_row1_col7, #T_073cd_row1_col8, #T_073cd_row2_col0, #T_073cd_row2_col1, #T_073cd_row2_col2, #T_073cd_row2_col3, #T_073cd_row2_col4, #T_073cd_row2_col5, #T_073cd_row2_col6, #T_073cd_row2_col7, #T_073cd_row2_col8, #T_073cd_row3_col0, #T_073cd_row3_col1, #T_073cd_row3_col2, #T_073cd_row3_col3, #T_073cd_row3_col4, #T_073cd_row3_col5, #T_073cd_row3_col7, #T_073cd_row3_col8, #T_073cd_row4_col0, #T_073cd_row4_col1, #T_073cd_row4_col2, #T_073cd_row4_col3, #T_073cd_row4_col4, #T_073cd_row4_col7, #T_073cd_row4_col8, #T_073cd_row5_col0, #T_073cd_row5_col1, #T_073cd_row5_col2, #T_073cd_row5_col3, #T_073cd_row5_col6, #T_073cd_row5_col7, #T_073cd_row5_col8, #T_073cd_row6_col0, #T_073cd_row6_col1, #T_073cd_row6_col2, #T_073cd_row6_col3, #T_073cd_row6_col4, #T_073cd_row6_col5, #T_073cd_row6_col6, #T_073cd_row6_col7, #T_073cd_row6_col8, #T_073cd_row7_col0, #T_073cd_row7_col1, #T_073cd_row7_col2, #T_073cd_row7_col4, #T_073cd_row7_col5, #T_073cd_row7_col6, #T_073cd_row7_col7, #T_073cd_row7_col8, #T_073cd_row8_col0, #T_073cd_row8_col1, #T_073cd_row8_col2, #T_073cd_row8_col3, #T_073cd_row8_col4, #T_073cd_row8_col5, #T_073cd_row8_col6, #T_073cd_row8_col7, #T_073cd_row8_col8, #T_073cd_row9_col0, #T_073cd_row9_col1, #T_073cd_row9_col2, #T_073cd_row9_col5, #T_073cd_row9_col6, #T_073cd_row9_col7, #T_073cd_row9_col8, #T_073cd_row10_col0, #T_073cd_row10_col1, #T_073cd_row10_col2, #T_073cd_row10_col3, #T_073cd_row10_col4, #T_073cd_row10_col5, #T_073cd_row10_col6, #T_073cd_row10_col7, #T_073cd_row10_col8, #T_073cd_row11_col0, #T_073cd_row11_col1, #T_073cd_row11_col2, #T_073cd_row11_col3, #T_073cd_row11_col4, #T_073cd_row11_col6, #T_073cd_row11_col7, #T_073cd_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_073cd_row3_col6, #T_073cd_row7_col3, #T_073cd_row9_col4, #T_073cd_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_073cd_row4_col5, #T_073cd_row4_col6, #T_073cd_row5_col4, #T_073cd_row5_col5, #T_073cd_row9_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_073cd">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_073cd_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_073cd_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_073cd_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_073cd_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_073cd_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_073cd_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_073cd_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_073cd_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_073cd_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_073cd_row0_col0" class="data row0 col0" >longyearbyen</td>
#       <td id="T_073cd_row0_col1" class="data row0 col1" >78.22</td>
#       <td id="T_073cd_row0_col2" class="data row0 col2" >15.64</td>
#       <td id="T_073cd_row0_col3" class="data row0 col3" >33.64° F</td>
#       <td id="T_073cd_row0_col4" class="data row0 col4" >86%</td>
#       <td id="T_073cd_row0_col5" class="data row0 col5" >75%</td>
#       <td id="T_073cd_row0_col6" class="data row0 col6" >5.75</td>
#       <td id="T_073cd_row0_col7" class="data row0 col7" >SJ</td>
#       <td id="T_073cd_row0_col8" class="data row0 col8" >2023-09-13 00:04:25</td>
#     </tr>
#     <tr>
#       <td id="T_073cd_row1_col0" class="data row1 col0" >stanley</td>
#       <td id="T_073cd_row1_col1" class="data row1 col1" >54.87</td>
#       <td id="T_073cd_row1_col2" class="data row1 col2" >-1.70</td>
#       <td id="T_073cd_row1_col3" class="data row1 col3" >44.24° F</td>
#       <td id="T_073cd_row1_col4" class="data row1 col4" >92%</td>
#       <td id="T_073cd_row1_col5" class="data row1 col5" >20%</td>
#       <td id="T_073cd_row1_col6" class="data row1 col6" >4.61</td>
#       <td id="T_073cd_row1_col7" class="data row1 col7" >GB</td>
#       <td id="T_073cd_row1_col8" class="data row1 col8" >2023-09-13 00:04:26</td>
#     </tr>
#     <tr>
#       <td id="T_073cd_row2_col0" class="data row2 col0" >waitangi</td>
#       <td id="T_073cd_row2_col1" class="data row2 col1" >-43.95</td>
#       <td id="T_073cd_row2_col2" class="data row2 col2" >-176.56</td>
#       <td id="T_073cd_row2_col3" class="data row2 col3" >48.81° F</td>
#       <td id="T_073cd_row2_col4" class="data row2 col4" >79%</td>
#       <td id="T_073cd_row2_col5" class="data row2 col5" >13%</td>
#       <td id="T_073cd_row2_col6" class="data row2 col6" >13.00</td>
#       <td id="T_073cd_row2_col7" class="data row2 col7" >NZ</td>
#       <td id="T_073cd_row2_col8" class="data row2 col8" >2023-09-13 00:04:26</td>
#     </tr>
#     <tr>
#       <td id="T_073cd_row3_col0" class="data row3 col0" >bethel</td>
#       <td id="T_073cd_row3_col1" class="data row3 col1" >41.37</td>
#       <td id="T_073cd_row3_col2" class="data row3 col2" >-73.41</td>
#       <td id="T_073cd_row3_col3" class="data row3 col3" >65.48° F</td>
#       <td id="T_073cd_row3_col4" class="data row3 col4" >89%</td>
#       <td id="T_073cd_row3_col5" class="data row3 col5" >40%</td>
#       <td id="T_073cd_row3_col6" class="data row3 col6" >0.00</td>
#       <td id="T_073cd_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_073cd_row3_col8" class="data row3 col8" >2023-09-13 00:04:26</td>
#     </tr>
#     <tr>
#       <td id="T_073cd_row4_col0" class="data row4 col0" >aykhal</td>
#       <td id="T_073cd_row4_col1" class="data row4 col1" >66.00</td>
#       <td id="T_073cd_row4_col2" class="data row4 col2" >111.50</td>
#       <td id="T_073cd_row4_col3" class="data row4 col3" >37.45° F</td>
#       <td id="T_073cd_row4_col4" class="data row4 col4" >79%</td>
#       <td id="T_073cd_row4_col5" class="data row4 col5" >100%</td>
#       <td id="T_073cd_row4_col6" class="data row4 col6" >26.84</td>
#       <td id="T_073cd_row4_col7" class="data row4 col7" >RU</td>
#       <td id="T_073cd_row4_col8" class="data row4 col8" >2023-09-13 00:04:26</td>
#     </tr>
#     <tr>
#       <td id="T_073cd_row5_col0" class="data row5 col0" >lumphat</td>
#       <td id="T_073cd_row5_col1" class="data row5 col1" >13.49</td>
#       <td id="T_073cd_row5_col2" class="data row5 col2" >106.98</td>
#       <td id="T_073cd_row5_col3" class="data row5 col3" >75.76° F</td>
#       <td id="T_073cd_row5_col4" class="data row5 col4" >97%</td>
#       <td id="T_073cd_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_073cd_row5_col6" class="data row5 col6" >4.61</td>
#       <td id="T_073cd_row5_col7" class="data row5 col7" >KH</td>
#       <td id="T_073cd_row5_col8" class="data row5 col8" >2023-09-13 00:04:27</td>
#     </tr>
#     <tr>
#       <td id="T_073cd_row6_col0" class="data row6 col0" >fale old settlement</td>
#       <td id="T_073cd_row6_col1" class="data row6 col1" >-9.39</td>
#       <td id="T_073cd_row6_col2" class="data row6 col2" >-171.25</td>
#       <td id="T_073cd_row6_col3" class="data row6 col3" >83.08° F</td>
#       <td id="T_073cd_row6_col4" class="data row6 col4" >78%</td>
#       <td id="T_073cd_row6_col5" class="data row6 col5" >6%</td>
#       <td id="T_073cd_row6_col6" class="data row6 col6" >16.26</td>
#       <td id="T_073cd_row6_col7" class="data row6 col7" >TK</td>
#       <td id="T_073cd_row6_col8" class="data row6 col8" >2023-09-13 00:04:27</td>
#     </tr>
#     <tr>
#       <td id="T_073cd_row7_col0" c

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 35) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 75), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 5), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_1ef1d caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_1ef1d_row0_col0, #T_1ef1d_row0_col1, #T_1ef1d_row0_col2, #T_1ef1d_row0_col3, #T_1ef1d_row0_col4, #T_1ef1d_row0_col6, #T_1ef1d_row0_col7, #T_1ef1d_row0_col8, #T_1ef1d_row1_col0, #T_1ef1d_row1_col1, #T_1ef1d_row1_col2, #T_1ef1d_row1_col6, #T_1ef1d_row1_col7, #T_1ef1d_row1_col8, #T_1ef1d_row2_col0, #T_1ef1d_row2_col1, #T_1ef1d_row2_col2, #T_1ef1d_row2_col3, #T_1ef1d_row2_col4, #T_1ef1d_row2_col6, #T_1ef1d_row2_col7, #T_1ef1d_row2_col8, #T_1ef1d_row3_col0, #T_1ef1d_row3_col1, #T_1ef1d_row3_col2, #T_1ef1d_row3_col3, #T_1ef1d_row3_col6, #T_1ef1d_row3_col7, #T_1ef1d_row3_col8, #T_1ef1d_row4_col0, #T_1ef1d_row4_col1, #T_1ef1d_row4_col2, #T_1ef1d_row4_col4, #T_1ef1d_row4_col7, #T_1ef1d_row4_col8, #T_1ef1d_row5_col0, #T_1ef1d_row5_col1, #T_1ef1d_row5_col2, #T_1ef1d_row5_col3, #T_1ef1d_row5_col4, #T_1ef1d_row5_col5, #T_1ef1d_row5_col6, #T_1ef1d_row5_col7, #T_1ef1d_row5_col8, #T_1ef1d_row6_col0, #T_1ef1d_row6_col1, #T_1ef1d_row6_col2, #T_1ef1d_row6_col3, #T_1ef1d_row6_col5, #T_1ef1d_row6_col6, #T_1ef1d_row6_col7, #T_1ef1d_row6_col8, #T_1ef1d_row7_col0, #T_1ef1d_row7_col1, #T_1ef1d_row7_col2, #T_1ef1d_row7_col3, #T_1ef1d_row7_col4, #T_1ef1d_row7_col6, #T_1ef1d_row7_col7, #T_1ef1d_row7_col8, #T_1ef1d_row8_col0, #T_1ef1d_row8_col1, #T_1ef1d_row8_col2, #T_1ef1d_row8_col3, #T_1ef1d_row8_col4, #T_1ef1d_row8_col7, #T_1ef1d_row8_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_1ef1d_row0_col5, #T_1ef1d_row2_col5, #T_1ef1d_row3_col4, #T_1ef1d_row3_col5, #T_1ef1d_row4_col3, #T_1ef1d_row4_col5, #T_1ef1d_row8_col5, #T_1ef1d_row8_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_1ef1d_row1_col3, #T_1ef1d_row1_col4, #T_1ef1d_row1_col5, #T_1ef1d_row4_col6, #T_1ef1d_row6_col4, #T_1ef1d_row7_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_1ef1d">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_1ef1d_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_1ef1d_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_1ef1d_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_1ef1d_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_1ef1d_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_1ef1d_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_1ef1d_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_1ef1d_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_1ef1d_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1ef1d_row0_col0" class="data row0 col0" >tongchuanshi</td>
#       <td id="T_1ef1d_row0_col1" class="data row0 col1" >35.08</td>
#       <td id="T_1ef1d_row0_col2" class="data row0 col2" >109.09</td>
#       <td id="T_1ef1d_row0_col3" class="data row0 col3" >79.30° F</td>
#       <td id="T_1ef1d_row0_col4" class="data row0 col4" >48%</td>
#       <td id="T_1ef1d_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_1ef1d_row0_col6" class="data row0 col6" >8.75</td>
#       <td id="T_1ef1d_row0_col7" class="data row0 col7" >CN</td>
#       <td id="T_1ef1d_row0_col8" class="data row0 col8" >2023-09-13 00:04:28</td>
#     </tr>
#     <tr>
#       <td id="T_1ef1d_row1_col0" class="data row1 col0" >san patricio</td>
#       <td id="T_1ef1d_row1_col1" class="data row1 col1" >28.02</td>
#       <td id="T_1ef1d_row1_col2" class="data row1 col2" >-97.52</td>
#       <td id="T_1ef1d_row1_col3" class="data row1 col3" >81.50° F</td>
#       <td id="T_1ef1d_row1_col4" class="data row1 col4" >70%</td>
#       <td id="T_1ef1d_row1_col5" class="data row1 col5" >5%</td>
#       <td id="T_1ef1d_row1_col6" class="data row1 col6" >5.68</td>
#       <td id="T_1ef1d_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_1ef1d_row1_col8" class="data row1 col8" >2023-09-13 00:04:49</td>
#     </tr>
#     <tr>
#       <td id="T_1ef1d_row2_col0" class="data row2 col0" >arenapolis</td>
#       <td id="T_1ef1d_row2_col1" class="data row2 col1" >-14.45</td>
#       <td id="T_1ef1d_row2_col2" class="data row2 col2" >-56.85</td>
#       <td id="T_1ef1d_row2_col3" class="data row2 col3" >78.46° F</td>
#       <td id="T_1ef1d_row2_col4" class="data row2 col4" >39%</td>
#       <td id="T_1ef1d_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_1ef1d_row2_col6" class="data row2 col6" >4.23</td>
#       <td id="T_1ef1d_row2_col7" class="data row2 col7" >BR</td>
#       <td id="T_1ef1d_row2_col8" class="data row2 col8" >2023-09-13 00:02:16</td>
#     </tr>
#     <tr>
#       <td id="T_1ef1d_row3_col0" class="data row3 col0" >kara suu</td>
#       <td id="T_1ef1d_row3_col1" class="data row3 col1" >40.70</td>
#       <td id="T_1ef1d_row3_col2" class="data row3 col2" >72.87</td>
#       <td id="T_1ef1d_row3_col3" class="data row3 col3" >78.76° F</td>
#       <td id="T_1ef1d_row3_col4" class="data row3 col4" >36%</td>
#       <td id="T_1ef1d_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_1ef1d_row3_col6" class="data row3 col6" >4.47</td>
#       <td id="T_1ef1d_row3_col7" class="data row3 col7" >KG</td>
#       <td id="T_1ef1d_row3_col8" class="data row3 col8" >2023-09-13 00:05:12</td>
#     </tr>
#     <tr>
#       <td id="T_1ef1d_row4_col0" class="data row4 col0" >al bardiyah</td>
#       <td id="T_1ef1d_row4_col1" class="data row4 col1" >31.76</td>
#       <td id="T_1ef1d_row4_col2" class="data row4 col2" >25.09</td>
#       <td id="T_1ef1d_row4_col3" class="data row4 col3" >77.36° F</td>
#       <td id="T_1ef1d_row4_col4" class="data row4 col4" >65%</td>
#       <td id="T_1ef1d_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_1ef1d_row4_col6" class="data row4 col6" >9.48</td>
#       <td id="T_1ef1d_row4_col7" class="data row4 col7" >LY</td>
#       <td id="T_1ef1d_row4_col8" class="data row4 col8" >2023-09-13 00:05:42</td>
#     </tr>
#     <tr>
#       <td id="T_1ef1d_row5_col0" class="data row5 col0" >mananjary</td>
#       <td id="T_1ef1d_row5_col1" class="data row5 col1" >-21.22</td>
#       <td id="T_1ef1d_row5_col2" class="data row5 col2" >48.33</td>
#       <td id="T_1ef1d_row5_col3" class="data row5 col3" >77.81° F</td>
#       <td id="T_1ef1d_row5_col4" class="data row5 col4" >57%</td>
#       <td id="T_1ef1d_row5_col5" class="data row5 col5" >4%</td>
#       <td id="T_1ef1d_row5_col6" class="data row5 col6" >3.09</td>
#       <td id="T_1ef1d_row5_col7" class="data row5 col7" >MG</td>
#       <td id="T_1ef1d_row5_col8" class="data row5 col8" >2023-09-13 00:05:46</td>
#     </tr>
#     <tr>
#       <td id="T_1ef1d_row6_col0" class="data row6 col0" >ciudad sabinas hidalgo</td>
#       <td id="T_1ef1d_row6_col1" class="data row6 col1" >26.50</td>
#       <td id="T_1ef1d_row6_col2" class="data row6 col2" >-100.17</td>
#       <td id="T_1ef1d_row6_col3" class="data row6 col3" >77.99° F</td>
#       <td id="T_1ef1d_row6_col4" class="data row6 col4" >70%</td>
#       <td id="T_1ef1d_row6_col5" class="data row6 col5" >4%</td>
#       <td id="T_1ef1d_row6_col6" class="data row6 col6" >4.32</td>
#       <td id="T_1ef1d_row6_col7" class="data row6 col7" >MX</td>
#       <td id="T_1ef1d_row6_col8" class="data row6 col8" >2023-09-13 00:05:32</td>
#     </tr>
#     <tr>
#       <td id="T_1ef1d_row7_col0" class="data row7 col0" >manakara</td>
#       <td id="T_1ef1d_row7_col1" class="data row7 col1" >-22.13</td>
#       <td id="T_1ef1d_row7_col2" class="data row7 col2" >48.02</td>
#       <td id="T_1ef1d_row7_col3" class="data row7 col3" >77.76° F</td>
#       <td id="T_1ef1d_row7_col4" class="data row7 col4" >59%</td>
#       <td id="T_1ef1d_row7_col5" class="data row7 col5" >5%</td>
#       <td id="T_1ef1d_row7_col6" class="data row7 col6" >5.17</td>
#       <td id="T_1ef1d_row7_col7" class="data row7 col7" >MG</td>
#       <td id="T_1ef1d_row7_col8" class="dat

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...فندق البردي in al bardiyah, LY
#
#
# Located the following hotel...Ideal Hotel Annexe in mananjary, MG
#
#
# Located the following hotel...La Fogata in ciudad sabinas hidalgo, MX
#
#
# Located the following hotel...Hotel H1 in manakara, MG
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_8d5b8 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_8d5b8_row0_col0, #T_8d5b8_row0_col1, #T_8d5b8_row0_col2, #T_8d5b8_row0_col6, #T_8d5b8_row0_col7, #T_8d5b8_row0_col8, #T_8d5b8_row0_col9, #T_8d5b8_row1_col0, #T_8d5b8_row1_col1, #T_8d5b8_row1_col2, #T_8d5b8_row1_col4, #T_8d5b8_row1_col7, #T_8d5b8_row1_col8, #T_8d5b8_row1_col9, #T_8d5b8_row2_col0, #T_8d5b8_row2_col1, #T_8d5b8_row2_col2, #T_8d5b8_row2_col3, #T_8d5b8_row2_col4, #T_8d5b8_row2_col5, #T_8d5b8_row2_col7, #T_8d5b8_row2_col8, #T_8d5b8_row2_col9, #T_8d5b8_row3_col0, #T_8d5b8_row3_col1, #T_8d5b8_row3_col2, #T_8d5b8_row3_col3, #T_8d5b8_row3_col5, #T_8d5b8_row3_col6, #T_8d5b8_row3_col7, #T_8d5b8_row3_col8, #T_8d5b8_row3_col9, #T_8d5b8_row4_col0, #T_8d5b8_row4_col1, #T_8d5b8_row4_col2, #T_8d5b8_row4_col3, #T_8d5b8_row4_col4, #T_8d5b8_row4_col6, #T_8d5b8_row4_col7, #T_8d5b8_row4_col8, #T_8d5b8_row4_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_8d5b8_row0_col3, #T_8d5b8_row1_col6, #T_8d5b8_row3_col4, #T_8d5b8_row4_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_8d5b8_row0_col4, #T_8d5b8_row0_col5, #T_8d5b8_row1_col3, #T_8d5b8_row1_col5, #T_8d5b8_row2_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_8d5b8">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_8d5b8_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_8d5b8_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_8d5b8_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_8d5b8_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_8d5b8_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_8d5b8_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_8d5b8_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_8d5b8_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_8d5b8_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_8d5b8_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8d5b8_row0_col0" class="data row0 col0" >kara suu</td>
#       <td id="T_8d5b8_row0_col1" class="data row0 col1" >40.70</td>
#       <td id="T_8d5b8_row0_col2" class="data row0 col2" >72.87</td>
#       <td id="T_8d5b8_row0_col3" class="data row0 col3" >78.76° F</td>
#       <td id="T_8d5b8_row0_col4" class="data row0 col4" >36%</td>
#       <td id="T_8d5b8_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_8d5b8_row0_col6" class="data row0 col6" >4.47</td>
#       <td id="T_8d5b8_row0_col7" class="data row0 col7" >KG</td>
#       <td id="T_8d5b8_row0_col8" class="data row0 col8" >2023-09-13 00:05:12</td>
#       <td id="T_8d5b8_row0_col9" class="data row0 col9" >فندق البردي</td>
#     </tr>
#     <tr>
#       <td id="T_8d5b8_row1_col0" class="data row1 col0" >al bardiyah</td>
#       <td id="T_8d5b8_row1_col1" class="data row1 col1" >31.76</td>
#       <td id="T_8d5b8_row1_col2" class="data row1 col2" >25.09</td>
#       <td id="T_8d5b8_row1_col3" class="data row1 col3" >77.36° F</td>
#       <td id="T_8d5b8_row1_col4" class="data row1 col4" >65%</td>
#       <td id="T_8d5b8_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_8d5b8_row1_col6" class="data row1 col6" >9.48</td>
#       <td id="T_8d5b8_row1_col7" class="data row1 col7" >LY</td>
#       <td id="T_8d5b8_row1_col8" class="data row1 col8" >2023-09-13 00:05:42</td>
#       <td id="T_8d5b8_row1_col9" class="data row1 col9" >Ideal Hotel Annexe</td>
#     </tr>
#     <tr>
#       <td id="T_8d5b8_row2_col0" class="data row2 col0" >mananjary</td>
#       <td id="T_8d5b8_row2_col1" class="data row2 col1" >-21.22</td>
#       <td id="T_8d5b8_row2_col2" class="data row2 col2" >48.33</td>
#       <td id="T_8d5b8_row2_col3" class="data row2 col3" >77.81° F</td>
#       <td id="T_8d5b8_row2_col4" class="data row2 col4" >57%</td>
#       <td id="T_8d5b8_row2_col5" class="data row2 col5" >4%</td>
#       <td id="T_8d5b8_row2_col6" class="data row2 col6" >3.09</td>
#       <td id="T_8d5b8_row2_col7" class="data row2 col7" >MG</td>
#       <td id="T_8d5b8_row2_col8" class="data row2 col8" >2023-09-13 00:05:46</td>
#       <td id="T_8d5b8_row2_col9" class="data row2 col9" >La Fogata</td>
#     </tr>
#     <tr>
#       <td id="T_8d5b8_row3_col0" class="data row3 col0" >ciudad sabinas hidalgo</td>
#       <td id="T_8d5b8_row3_col1" class="data row3 col1" >26.50</td>
#       <td id="T_8d5b8_row3_col2" class="data row3 col2" >-100.17</td>
#       <td id="T_8d5b8_row3_col3" class="data row3 col3" >77.99° F</td>
#       <td id="T_8d5b8_row3_col4" class="data row3 col4" >70%</td>
#       <td id="T_8d5b8_row3_col5" class="data row3 col5" >4%</td>
#       <td id="T_8d5b8_row3_col6" class="data row3 col6" >4.32</td>
#       <td id="T_8d5b8_row3_col7" class="data row3 col7" >MX</td>
#       <td id="T_8d5b8_row3_col8" class="data row3 col8" >2023-09-13 00:05:32</td>
#       <td id="T_8d5b8_row3_col9" class="data row3 col9" >Hotel H1</td>
#     </tr>
#     <tr>
#       <td id="T_8d5b8_row4_col0" class="data row4 col0" >manakara</td>
#       <td id="T_8d5b8_row4_col1" class="data row4 col1" >-22.13</td>
#       <td id="T_8d5b8_row4_col2" class="data row4 col2" >48.02</td>
#       <td id="T_8d5b8_row4_col3" class="data row4 col3" >77.76° F</td>
#       <td id="T_8d5b8_row4_col4" class="data row4 col4" >59%</td>
#       <td id="T_8d5b8_row4_col5" class="data row4 col5" >5%</td>
#       <td id="T_8d5b8_row4_col6" class="data row4 col6" >5.17</td>
#       <td id="T_8d5b8_row4_col7" class="data row4 col7" >MG</td>
#       <td id="T_8d5b8_row4_col8" class="data row4 col8" >2023-09-13 00:06:13</td>
#       <td id="T_8d5b8_row4_col9" class="data row4 col9" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
