# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_148e9 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_148e9_row0_col0, #T_148e9_row0_col1, #T_148e9_row0_col2, #T_148e9_row0_col3, #T_148e9_row0_col4, #T_148e9_row0_col5, #T_148e9_row0_col6, #T_148e9_row0_col7, #T_148e9_row0_col8, #T_148e9_row1_col0, #T_148e9_row1_col1, #T_148e9_row1_col2, #T_148e9_row1_col4, #T_148e9_row1_col5, #T_148e9_row1_col6, #T_148e9_row1_col7, #T_148e9_row1_col8, #T_148e9_row2_col0, #T_148e9_row2_col1, #T_148e9_row2_col2, #T_148e9_row2_col3, #T_148e9_row2_col4, #T_148e9_row2_col7, #T_148e9_row2_col8, #T_148e9_row3_col0, #T_148e9_row3_col1, #T_148e9_row3_col2, #T_148e9_row3_col3, #T_148e9_row3_col4, #T_148e9_row3_col6, #T_148e9_row3_col7, #T_148e9_row3_col8, #T_148e9_row4_col0, #T_148e9_row4_col1, #T_148e9_row4_col2, #T_148e9_row4_col3, #T_148e9_row4_col4, #T_148e9_row4_col6, #T_148e9_row4_col7, #T_148e9_row4_col8, #T_148e9_row5_col0, #T_148e9_row5_col1, #T_148e9_row5_col2, #T_148e9_row5_col3, #T_148e9_row5_col4, #T_148e9_row5_col6, #T_148e9_row5_col7, #T_148e9_row5_col8, #T_148e9_row6_col0, #T_148e9_row6_col1, #T_148e9_row6_col2, #T_148e9_row6_col3, #T_148e9_row6_col4, #T_148e9_row6_col5, #T_148e9_row6_col6, #T_148e9_row6_col7, #T_148e9_row6_col8, #T_148e9_row7_col0, #T_148e9_row7_col1, #T_148e9_row7_col2, #T_148e9_row7_col3, #T_148e9_row7_col4, #T_148e9_row7_col6, #T_148e9_row7_col7, #T_148e9_row7_col8, #T_148e9_row8_col0, #T_148e9_row8_col1, #T_148e9_row8_col2, #T_148e9_row8_col3, #T_148e9_row8_col5, #T_148e9_row8_col7, #T_148e9_row8_col8, #T_148e9_row9_col0, #T_148e9_row9_col1, #T_148e9_row9_col2, #T_148e9_row9_col5, #T_148e9_row9_col6, #T_148e9_row9_col7, #T_148e9_row9_col8, #T_148e9_row10_col0, #T_148e9_row10_col1, #T_148e9_row10_col2, #T_148e9_row10_col3, #T_148e9_row10_col4, #T_148e9_row10_col5, #T_148e9_row10_col6, #T_148e9_row10_col7, #T_148e9_row10_col8, #T_148e9_row11_col0, #T_148e9_row11_col1, #T_148e9_row11_col2, #T_148e9_row11_col3, #T_148e9_row11_col4, #T_148e9_row11_col6, #T_148e9_row11_col7, #T_148e9_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_148e9_row1_col3, #T_148e9_row4_col5, #T_148e9_row8_col6, #T_148e9_row9_col4, #T_148e9_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_148e9_row2_col5, #T_148e9_row2_col6, #T_148e9_row3_col5, #T_148e9_row5_col5, #T_148e9_row7_col5, #T_148e9_row8_col4, #T_148e9_row9_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_148e9">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_148e9_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_148e9_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_148e9_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_148e9_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_148e9_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_148e9_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_148e9_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_148e9_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_148e9_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_148e9_row0_col0" class="data row0 col0" >wailua homesteads</td>
#       <td id="T_148e9_row0_col1" class="data row0 col1" >22.07</td>
#       <td id="T_148e9_row0_col2" class="data row0 col2" >-159.38</td>
#       <td id="T_148e9_row0_col3" class="data row0 col3" >81.50° F</td>
#       <td id="T_148e9_row0_col4" class="data row0 col4" >66%</td>
#       <td id="T_148e9_row0_col5" class="data row0 col5" >20%</td>
#       <td id="T_148e9_row0_col6" class="data row0 col6" >9.22</td>
#       <td id="T_148e9_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_148e9_row0_col8" class="data row0 col8" >2023-09-15 14:11:22</td>
#     </tr>
#     <tr>
#       <td id="T_148e9_row1_col0" class="data row1 col0" >puerto natales</td>
#       <td id="T_148e9_row1_col1" class="data row1 col1" >-51.72</td>
#       <td id="T_148e9_row1_col2" class="data row1 col2" >-72.49</td>
#       <td id="T_148e9_row1_col3" class="data row1 col3" >40.68° F</td>
#       <td id="T_148e9_row1_col4" class="data row1 col4" >69%</td>
#       <td id="T_148e9_row1_col5" class="data row1 col5" >10%</td>
#       <td id="T_148e9_row1_col6" class="data row1 col6" >8.03</td>
#       <td id="T_148e9_row1_col7" class="data row1 col7" >CL</td>
#       <td id="T_148e9_row1_col8" class="data row1 col8" >2023-09-15 14:06:49</td>
#     </tr>
#     <tr>
#       <td id="T_148e9_row2_col0" class="data row2 col0" >adamstown</td>
#       <td id="T_148e9_row2_col1" class="data row2 col1" >-25.07</td>
#       <td id="T_148e9_row2_col2" class="data row2 col2" >-130.10</td>
#       <td id="T_148e9_row2_col3" class="data row2 col3" >64.47° F</td>
#       <td id="T_148e9_row2_col4" class="data row2 col4" >82%</td>
#       <td id="T_148e9_row2_col5" class="data row2 col5" >100%</td>
#       <td id="T_148e9_row2_col6" class="data row2 col6" >27.13</td>
#       <td id="T_148e9_row2_col7" class="data row2 col7" >PN</td>
#       <td id="T_148e9_row2_col8" class="data row2 col8" >2023-09-15 14:11:22</td>
#     </tr>
#     <tr>
#       <td id="T_148e9_row3_col0" class="data row3 col0" >waitangi</td>
#       <td id="T_148e9_row3_col1" class="data row3 col1" >-43.95</td>
#       <td id="T_148e9_row3_col2" class="data row3 col2" >-176.56</td>
#       <td id="T_148e9_row3_col3" class="data row3 col3" >49.82° F</td>
#       <td id="T_148e9_row3_col4" class="data row3 col4" >74%</td>
#       <td id="T_148e9_row3_col5" class="data row3 col5" >100%</td>
#       <td id="T_148e9_row3_col6" class="data row3 col6" >11.99</td>
#       <td id="T_148e9_row3_col7" class="data row3 col7" >NZ</td>
#       <td id="T_148e9_row3_col8" class="data row3 col8" >2023-09-15 14:08:45</td>
#     </tr>
#     <tr>
#       <td id="T_148e9_row4_col0" class="data row4 col0" >port lincoln</td>
#       <td id="T_148e9_row4_col1" class="data row4 col1" >-34.73</td>
#       <td id="T_148e9_row4_col2" class="data row4 col2" >135.87</td>
#       <td id="T_148e9_row4_col3" class="data row4 col3" >54.77° F</td>
#       <td id="T_148e9_row4_col4" class="data row4 col4" >59%</td>
#       <td id="T_148e9_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_148e9_row4_col6" class="data row4 col6" >8.30</td>
#       <td id="T_148e9_row4_col7" class="data row4 col7" >AU</td>
#       <td id="T_148e9_row4_col8" class="data row4 col8" >2023-09-15 14:11:22</td>
#     </tr>
#     <tr>
#       <td id="T_148e9_row5_col0" class="data row5 col0" >onega</td>
#       <td id="T_148e9_row5_col1" class="data row5 col1" >63.91</td>
#       <td id="T_148e9_row5_col2" class="data row5 col2" >38.14</td>
#       <td id="T_148e9_row5_col3" class="data row5 col3" >47.86° F</td>
#       <td id="T_148e9_row5_col4" class="data row5 col4" >73%</td>
#       <td id="T_148e9_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_148e9_row5_col6" class="data row5 col6" >3.89</td>
#       <td id="T_148e9_row5_col7" class="data row5 col7" >RU</td>
#       <td id="T_148e9_row5_col8" class="data row5 col8" >2023-09-15 14:11:22</td>
#     </tr>
#     <tr>
#       <td id="T_148e9_row6_col0" class="data row6 col0" >mutsu</td>
#       <td id="T_148e9_row6_col1" class="data row6 col1" >41.29</td>
#       <td id="T_148e9_row6_col2" class="data row6 col2" >141.22</td>
#       <td id="T_148e9_row6_col3" class="data row6 col3" >68.07° F</td>
#       <td id="T_148e9_row6_col4" class="data row6 col4" >92%</td>
#       <td id="T_148e9_row6_col5" class="data row6 col5" >84%</td>
#       <td id="T_148e9_row6_col6" class="data row6 col6" >3.00</td>
#       <td id="T_148e9_row6_col7" class="data row6 col7" >JP</td>
#       <td id="T_148e9_row6_col8" class="data row6 col8" >2023-09-15 14:11:23</td>
#     </tr>
#     <tr>
#       <td id="T_148e9_ro

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 86), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 35) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 75), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 5), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_33388 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_33388_row0_col0, #T_33388_row0_col1, #T_33388_row0_col2, #T_33388_row0_col7, #T_33388_row0_col8, #T_33388_row1_col0, #T_33388_row1_col1, #T_33388_row1_col2, #T_33388_row1_col3, #T_33388_row1_col7, #T_33388_row1_col8, #T_33388_row2_col0, #T_33388_row2_col1, #T_33388_row2_col2, #T_33388_row2_col4, #T_33388_row2_col6, #T_33388_row2_col7, #T_33388_row2_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_33388_row0_col3, #T_33388_row0_col4, #T_33388_row0_col6, #T_33388_row1_col5, #T_33388_row2_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_33388_row0_col5, #T_33388_row1_col4, #T_33388_row1_col6, #T_33388_row2_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_33388">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_33388_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_33388_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_33388_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_33388_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_33388_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_33388_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_33388_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_33388_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_33388_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_33388_row0_col0" class="data row0 col0" >recani</td>
#       <td id="T_33388_row0_col1" class="data row0 col1" >31.28</td>
#       <td id="T_33388_row0_col2" class="data row0 col2" >-4.27</td>
#       <td id="T_33388_row0_col3" class="data row0 col3" >83.82° F</td>
#       <td id="T_33388_row0_col4" class="data row0 col4" >40%</td>
#       <td id="T_33388_row0_col5" class="data row0 col5" >1%</td>
#       <td id="T_33388_row0_col6" class="data row0 col6" >2.51</td>
#       <td id="T_33388_row0_col7" class="data row0 col7" >MA</td>
#       <td id="T_33388_row0_col8" class="data row0 col8" >2023-09-15 14:12:42</td>
#     </tr>
#     <tr>
#       <td id="T_33388_row1_col0" class="data row1 col0" >marsa alam</td>
#       <td id="T_33388_row1_col1" class="data row1 col1" >25.08</td>
#       <td id="T_33388_row1_col2" class="data row1 col2" >34.89</td>
#       <td id="T_33388_row1_col3" class="data row1 col3" >84.34° F</td>
#       <td id="T_33388_row1_col4" class="data row1 col4" >54%</td>
#       <td id="T_33388_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_33388_row1_col6" class="data row1 col6" >9.60</td>
#       <td id="T_33388_row1_col7" class="data row1 col7" >EG</td>
#       <td id="T_33388_row1_col8" class="data row1 col8" >2023-09-15 14:12:59</td>
#     </tr>
#     <tr>
#       <td id="T_33388_row2_col0" class="data row2 col0" >laguna</td>
#       <td id="T_33388_row2_col1" class="data row2 col1" >38.42</td>
#       <td id="T_33388_row2_col2" class="data row2 col2" >-121.42</td>
#       <td id="T_33388_row2_col3" class="data row2 col3" >84.60° F</td>
#       <td id="T_33388_row2_col4" class="data row2 col4" >45%</td>
#       <td id="T_33388_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_33388_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_33388_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_33388_row2_col8" class="data row2 col8" >2023-09-15 14:13:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Hotel Merzouga in recani, MA
#
#
# Located the following hotel...Blue House Hotel in marsa alam, EG
#
#
# Located the following hotel...Holiday Inn Express & Suites in laguna, US
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_f3233 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_f3233_row0_col0, #T_f3233_row0_col1, #T_f3233_row0_col2, #T_f3233_row0_col7, #T_f3233_row0_col8, #T_f3233_row0_col9, #T_f3233_row1_col0, #T_f3233_row1_col1, #T_f3233_row1_col2, #T_f3233_row1_col3, #T_f3233_row1_col7, #T_f3233_row1_col8, #T_f3233_row1_col9, #T_f3233_row2_col0, #T_f3233_row2_col1, #T_f3233_row2_col2, #T_f3233_row2_col4, #T_f3233_row2_col6, #T_f3233_row2_col7, #T_f3233_row2_col8, #T_f3233_row2_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_f3233_row0_col3, #T_f3233_row0_col4, #T_f3233_row0_col6, #T_f3233_row1_col5, #T_f3233_row2_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_f3233_row0_col5, #T_f3233_row1_col4, #T_f3233_row1_col6, #T_f3233_row2_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_f3233">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_f3233_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_f3233_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_f3233_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_f3233_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_f3233_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_f3233_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_f3233_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_f3233_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_f3233_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_f3233_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3233_row0_col0" class="data row0 col0" >recani</td>
#       <td id="T_f3233_row0_col1" class="data row0 col1" >31.28</td>
#       <td id="T_f3233_row0_col2" class="data row0 col2" >-4.27</td>
#       <td id="T_f3233_row0_col3" class="data row0 col3" >83.82° F</td>
#       <td id="T_f3233_row0_col4" class="data row0 col4" >40%</td>
#       <td id="T_f3233_row0_col5" class="data row0 col5" >1%</td>
#       <td id="T_f3233_row0_col6" class="data row0 col6" >2.51</td>
#       <td id="T_f3233_row0_col7" class="data row0 col7" >MA</td>
#       <td id="T_f3233_row0_col8" class="data row0 col8" >2023-09-15 14:12:42</td>
#       <td id="T_f3233_row0_col9" class="data row0 col9" >Hotel Merzouga</td>
#     </tr>
#     <tr>
#       <td id="T_f3233_row1_col0" class="data row1 col0" >marsa alam</td>
#       <td id="T_f3233_row1_col1" class="data row1 col1" >25.08</td>
#       <td id="T_f3233_row1_col2" class="data row1 col2" >34.89</td>
#       <td id="T_f3233_row1_col3" class="data row1 col3" >84.34° F</td>
#       <td id="T_f3233_row1_col4" class="data row1 col4" >54%</td>
#       <td id="T_f3233_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_f3233_row1_col6" class="data row1 col6" >9.60</td>
#       <td id="T_f3233_row1_col7" class="data row1 col7" >EG</td>
#       <td id="T_f3233_row1_col8" class="data row1 col8" >2023-09-15 14:12:59</td>
#       <td id="T_f3233_row1_col9" class="data row1 col9" >Blue House Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_f3233_row2_col0" class="data row2 col0" >laguna</td>
#       <td id="T_f3233_row2_col1" class="data row2 col1" >38.42</td>
#       <td id="T_f3233_row2_col2" class="data row2 col2" >-121.42</td>
#       <td id="T_f3233_row2_col3" class="data row2 col3" >84.60° F</td>
#       <td id="T_f3233_row2_col4" class="data row2 col4" >45%</td>
#       <td id="T_f3233_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_f3233_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_f3233_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_f3233_row2_col8" class="data row2 col8" >2023-09-15 14:13:01</td>
#       <td id="T_f3233_row2_col9" class="data row2 col9" >Holiday Inn Express & Suites</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
