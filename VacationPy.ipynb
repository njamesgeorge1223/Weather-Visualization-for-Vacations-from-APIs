# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (cityWeatherDataFrame.head(12),
         'Table: 1.1: City Weather Information')
# Out:
# <style type="text/css">
# #T_2088f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_2088f_row0_col0, #T_2088f_row0_col1, #T_2088f_row0_col2, #T_2088f_row0_col4, #T_2088f_row0_col5, #T_2088f_row0_col6, #T_2088f_row0_col7, #T_2088f_row0_col8, #T_2088f_row1_col0, #T_2088f_row1_col1, #T_2088f_row1_col2, #T_2088f_row1_col3, #T_2088f_row1_col4, #T_2088f_row1_col5, #T_2088f_row1_col6, #T_2088f_row1_col7, #T_2088f_row1_col8, #T_2088f_row2_col0, #T_2088f_row2_col1, #T_2088f_row2_col2, #T_2088f_row2_col3, #T_2088f_row2_col4, #T_2088f_row2_col7, #T_2088f_row2_col8, #T_2088f_row3_col0, #T_2088f_row3_col1, #T_2088f_row3_col2, #T_2088f_row3_col3, #T_2088f_row3_col4, #T_2088f_row3_col5, #T_2088f_row3_col6, #T_2088f_row3_col7, #T_2088f_row3_col8, #T_2088f_row4_col0, #T_2088f_row4_col1, #T_2088f_row4_col2, #T_2088f_row4_col3, #T_2088f_row4_col4, #T_2088f_row4_col5, #T_2088f_row4_col6, #T_2088f_row4_col7, #T_2088f_row4_col8, #T_2088f_row5_col0, #T_2088f_row5_col1, #T_2088f_row5_col2, #T_2088f_row5_col3, #T_2088f_row5_col6, #T_2088f_row5_col7, #T_2088f_row5_col8, #T_2088f_row6_col0, #T_2088f_row6_col1, #T_2088f_row6_col2, #T_2088f_row6_col3, #T_2088f_row6_col5, #T_2088f_row6_col6, #T_2088f_row6_col7, #T_2088f_row6_col8, #T_2088f_row7_col0, #T_2088f_row7_col1, #T_2088f_row7_col2, #T_2088f_row7_col3, #T_2088f_row7_col4, #T_2088f_row7_col5, #T_2088f_row7_col6, #T_2088f_row7_col7, #T_2088f_row7_col8, #T_2088f_row8_col0, #T_2088f_row8_col1, #T_2088f_row8_col2, #T_2088f_row8_col5, #T_2088f_row8_col6, #T_2088f_row8_col7, #T_2088f_row8_col8, #T_2088f_row9_col0, #T_2088f_row9_col1, #T_2088f_row9_col2, #T_2088f_row9_col3, #T_2088f_row9_col4, #T_2088f_row9_col5, #T_2088f_row9_col6, #T_2088f_row9_col7, #T_2088f_row9_col8, #T_2088f_row10_col0, #T_2088f_row10_col1, #T_2088f_row10_col2, #T_2088f_row10_col3, #T_2088f_row10_col4, #T_2088f_row10_col5, #T_2088f_row10_col7, #T_2088f_row10_col8, #T_2088f_row11_col0, #T_2088f_row11_col1, #T_2088f_row11_col2, #T_2088f_row11_col3, #T_2088f_row11_col4, #T_2088f_row11_col6, #T_2088f_row11_col7, #T_2088f_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_2088f_row0_col3, #T_2088f_row2_col5, #T_2088f_row6_col4, #T_2088f_row10_col6, #T_2088f_row11_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_2088f_row2_col6, #T_2088f_row5_col4, #T_2088f_row5_col5, #T_2088f_row8_col3, #T_2088f_row8_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_2088f">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_2088f_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_2088f_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_2088f_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_2088f_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_2088f_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_2088f_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_2088f_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_2088f_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_2088f_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2088f_row0_col0" class="data row0 col0" >grytviken</td>
#       <td id="T_2088f_row0_col1" class="data row0 col1" >-54.28</td>
#       <td id="T_2088f_row0_col2" class="data row0 col2" >-36.51</td>
#       <td id="T_2088f_row0_col3" class="data row0 col3" >26.80° F</td>
#       <td id="T_2088f_row0_col4" class="data row0 col4" >80%</td>
#       <td id="T_2088f_row0_col5" class="data row0 col5" >53%</td>
#       <td id="T_2088f_row0_col6" class="data row0 col6" >13.51</td>
#       <td id="T_2088f_row0_col7" class="data row0 col7" >GS</td>
#       <td id="T_2088f_row0_col8" class="data row0 col8" >2023-09-18 09:52:20</td>
#     </tr>
#     <tr>
#       <td id="T_2088f_row1_col0" class="data row1 col0" >mansa</td>
#       <td id="T_2088f_row1_col1" class="data row1 col1" >29.98</td>
#       <td id="T_2088f_row1_col2" class="data row1 col2" >75.38</td>
#       <td id="T_2088f_row1_col3" class="data row1 col3" >77.67° F</td>
#       <td id="T_2088f_row1_col4" class="data row1 col4" >88%</td>
#       <td id="T_2088f_row1_col5" class="data row1 col5" >78%</td>
#       <td id="T_2088f_row1_col6" class="data row1 col6" >6.17</td>
#       <td id="T_2088f_row1_col7" class="data row1 col7" >IN</td>
#       <td id="T_2088f_row1_col8" class="data row1 col8" >2023-09-18 10:01:51</td>
#     </tr>
#     <tr>
#       <td id="T_2088f_row2_col0" class="data row2 col0" >toliara</td>
#       <td id="T_2088f_row2_col1" class="data row2 col1" >-23.35</td>
#       <td id="T_2088f_row2_col2" class="data row2 col2" >43.67</td>
#       <td id="T_2088f_row2_col3" class="data row2 col3" >76.57° F</td>
#       <td id="T_2088f_row2_col4" class="data row2 col4" >63%</td>
#       <td id="T_2088f_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_2088f_row2_col6" class="data row2 col6" >20.27</td>
#       <td id="T_2088f_row2_col7" class="data row2 col7" >MG</td>
#       <td id="T_2088f_row2_col8" class="data row2 col8" >2023-09-18 09:53:54</td>
#     </tr>
#     <tr>
#       <td id="T_2088f_row3_col0" class="data row3 col0" >port lincoln</td>
#       <td id="T_2088f_row3_col1" class="data row3 col1" >-34.73</td>
#       <td id="T_2088f_row3_col2" class="data row3 col2" >135.87</td>
#       <td id="T_2088f_row3_col3" class="data row3 col3" >55.18° F</td>
#       <td id="T_2088f_row3_col4" class="data row3 col4" >84%</td>
#       <td id="T_2088f_row3_col5" class="data row3 col5" >87%</td>
#       <td id="T_2088f_row3_col6" class="data row3 col6" >7.47</td>
#       <td id="T_2088f_row3_col7" class="data row3 col7" >AU</td>
#       <td id="T_2088f_row3_col8" class="data row3 col8" >2023-09-18 09:52:29</td>
#     </tr>
#     <tr>
#       <td id="T_2088f_row4_col0" class="data row4 col0" >baikunthpur</td>
#       <td id="T_2088f_row4_col1" class="data row4 col1" >23.25</td>
#       <td id="T_2088f_row4_col2" class="data row4 col2" >82.55</td>
#       <td id="T_2088f_row4_col3" class="data row4 col3" >75.74° F</td>
#       <td id="T_2088f_row4_col4" class="data row4 col4" >85%</td>
#       <td id="T_2088f_row4_col5" class="data row4 col5" >14%</td>
#       <td id="T_2088f_row4_col6" class="data row4 col6" >2.59</td>
#       <td id="T_2088f_row4_col7" class="data row4 col7" >IN</td>
#       <td id="T_2088f_row4_col8" class="data row4 col8" >2023-09-18 10:01:52</td>
#     </tr>
#     <tr>
#       <td id="T_2088f_row5_col0" class="data row5 col0" >bethel</td>
#       <td id="T_2088f_row5_col1" class="data row5 col1" >41.37</td>
#       <td id="T_2088f_row5_col2" class="data row5 col2" >-73.41</td>
#       <td id="T_2088f_row5_col3" class="data row5 col3" >63.66° F</td>
#       <td id="T_2088f_row5_col4" class="data row5 col4" >89%</td>
#       <td id="T_2088f_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_2088f_row5_col6" class="data row5 col6" >3.44</td>
#       <td id="T_2088f_row5_col7" class="data row5 col7" >US</td>
#       <td id="T_2088f_row5_col8" class="data row5 col8" >2023-09-18 09:52:20</td>
#     </tr>
#     <tr>
#       <td id="T_2088f_row6_col0" class="data row6 col0" >puerto natales</td>
#       <td id="T_2088f_row6_col1" class="data row6 col1" >-51.72</td>
#       <td id="T_2088f_row6_col2" class="data row6 col2" >-72.49</td>
#       <td id="T_2088f_row6_col3" class="data row6 col3" >40.23° F</td>
#       <td id="T_2088f_row6_col4" class="data row6 col4" >52%</td>
#       <td id="T_2088f_row6_col5" class="data row6 col5" >36%</td>
#       <td id="T_2088f_row6_col6" class="data row6 col6" >5.91</td>
#       <td id="T_2088f_row6_col7" class="data row6 col7" >CL</td>
#       <td id="T_2088f_row6_col8" class="data row6 col8" >2023-09-18 09:52:21</td>
#     </tr>
#     <tr>
#       <td id="T_2088f_row7_col0" clas

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 93), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 40) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 70), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 10), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (idealVacationLocationDataFrame,
         'Table: 2.1: Ideal Vacation Locations')
# Out:
# <style type="text/css">
# #T_e4feb caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_e4feb_row0_col0, #T_e4feb_row0_col1, #T_e4feb_row0_col2, #T_e4feb_row0_col3, #T_e4feb_row0_col6, #T_e4feb_row0_col7, #T_e4feb_row0_col8, #T_e4feb_row1_col0, #T_e4feb_row1_col1, #T_e4feb_row1_col2, #T_e4feb_row1_col3, #T_e4feb_row1_col4, #T_e4feb_row1_col6, #T_e4feb_row1_col7, #T_e4feb_row1_col8, #T_e4feb_row2_col0, #T_e4feb_row2_col1, #T_e4feb_row2_col2, #T_e4feb_row2_col3, #T_e4feb_row2_col4, #T_e4feb_row2_col6, #T_e4feb_row2_col7, #T_e4feb_row2_col8, #T_e4feb_row3_col0, #T_e4feb_row3_col1, #T_e4feb_row3_col2, #T_e4feb_row3_col6, #T_e4feb_row3_col7, #T_e4feb_row3_col8, #T_e4feb_row4_col0, #T_e4feb_row4_col1, #T_e4feb_row4_col2, #T_e4feb_row4_col3, #T_e4feb_row4_col4, #T_e4feb_row4_col5, #T_e4feb_row4_col6, #T_e4feb_row4_col7, #T_e4feb_row4_col8, #T_e4feb_row5_col0, #T_e4feb_row5_col1, #T_e4feb_row5_col2, #T_e4feb_row5_col3, #T_e4feb_row5_col4, #T_e4feb_row5_col5, #T_e4feb_row5_col6, #T_e4feb_row5_col7, #T_e4feb_row5_col8, #T_e4feb_row6_col0, #T_e4feb_row6_col1, #T_e4feb_row6_col2, #T_e4feb_row6_col3, #T_e4feb_row6_col4, #T_e4feb_row6_col7, #T_e4feb_row6_col8, #T_e4feb_row7_col0, #T_e4feb_row7_col1, #T_e4feb_row7_col2, #T_e4feb_row7_col3, #T_e4feb_row7_col4, #T_e4feb_row7_col7, #T_e4feb_row7_col8, #T_e4feb_row8_col0, #T_e4feb_row8_col1, #T_e4feb_row8_col2, #T_e4feb_row8_col3, #T_e4feb_row8_col4, #T_e4feb_row8_col5, #T_e4feb_row8_col6, #T_e4feb_row8_col7, #T_e4feb_row8_col8, #T_e4feb_row9_col0, #T_e4feb_row9_col1, #T_e4feb_row9_col2, #T_e4feb_row9_col4, #T_e4feb_row9_col5, #T_e4feb_row9_col6, #T_e4feb_row9_col7, #T_e4feb_row9_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_e4feb_row0_col4, #T_e4feb_row1_col5, #T_e4feb_row6_col6, #T_e4feb_row9_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_e4feb_row0_col5, #T_e4feb_row2_col5, #T_e4feb_row3_col3, #T_e4feb_row3_col4, #T_e4feb_row3_col5, #T_e4feb_row6_col5, #T_e4feb_row7_col5, #T_e4feb_row7_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_e4feb">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_e4feb_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_e4feb_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_e4feb_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_e4feb_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_e4feb_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_e4feb_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_e4feb_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_e4feb_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_e4feb_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e4feb_row0_col0" class="data row0 col0" >kafr ad dawwar</td>
#       <td id="T_e4feb_row0_col1" class="data row0 col1" >31.13</td>
#       <td id="T_e4feb_row0_col2" class="data row0 col2" >30.13</td>
#       <td id="T_e4feb_row0_col3" class="data row0 col3" >81.07° F</td>
#       <td id="T_e4feb_row0_col4" class="data row0 col4" >69%</td>
#       <td id="T_e4feb_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_e4feb_row0_col6" class="data row0 col6" >8.77</td>
#       <td id="T_e4feb_row0_col7" class="data row0 col7" >EG</td>
#       <td id="T_e4feb_row0_col8" class="data row0 col8" >2023-09-18 10:02:04</td>
#     </tr>
#     <tr>
#       <td id="T_e4feb_row1_col0" class="data row1 col0" >coahuayana de hidalgo</td>
#       <td id="T_e4feb_row1_col1" class="data row1 col1" >18.70</td>
#       <td id="T_e4feb_row1_col2" class="data row1 col2" >-103.66</td>
#       <td id="T_e4feb_row1_col3" class="data row1 col3" >90.03° F</td>
#       <td id="T_e4feb_row1_col4" class="data row1 col4" >54%</td>
#       <td id="T_e4feb_row1_col5" class="data row1 col5" >8%</td>
#       <td id="T_e4feb_row1_col6" class="data row1 col6" >3.31</td>
#       <td id="T_e4feb_row1_col7" class="data row1 col7" >MX</td>
#       <td id="T_e4feb_row1_col8" class="data row1 col8" >2023-09-18 09:58:44</td>
#     </tr>
#     <tr>
#       <td id="T_e4feb_row2_col0" class="data row2 col0" >galliano</td>
#       <td id="T_e4feb_row2_col1" class="data row2 col1" >29.44</td>
#       <td id="T_e4feb_row2_col2" class="data row2 col2" >-90.30</td>
#       <td id="T_e4feb_row2_col3" class="data row2 col3" >87.76° F</td>
#       <td id="T_e4feb_row2_col4" class="data row2 col4" >51%</td>
#       <td id="T_e4feb_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_e4feb_row2_col6" class="data row2 col6" >6.91</td>
#       <td id="T_e4feb_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_e4feb_row2_col8" class="data row2 col8" >2023-09-18 09:59:08</td>
#     </tr>
#     <tr>
#       <td id="T_e4feb_row3_col0" class="data row3 col0" >excelsior springs</td>
#       <td id="T_e4feb_row3_col1" class="data row3 col1" >39.34</td>
#       <td id="T_e4feb_row3_col2" class="data row3 col2" >-94.23</td>
#       <td id="T_e4feb_row3_col3" class="data row3 col3" >77.05° F</td>
#       <td id="T_e4feb_row3_col4" class="data row3 col4" >41%</td>
#       <td id="T_e4feb_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_e4feb_row3_col6" class="data row3 col6" >6.91</td>
#       <td id="T_e4feb_row3_col7" class="data row3 col7" >US</td>
#       <td id="T_e4feb_row3_col8" class="data row3 col8" >2023-09-18 10:00:58</td>
#     </tr>
#     <tr>
#       <td id="T_e4feb_row4_col0" class="data row4 col0" >lazaro cardenas</td>
#       <td id="T_e4feb_row4_col1" class="data row4 col1" >17.96</td>
#       <td id="T_e4feb_row4_col2" class="data row4 col2" >-102.20</td>
#       <td id="T_e4feb_row4_col3" class="data row4 col3" >86.65° F</td>
#       <td id="T_e4feb_row4_col4" class="data row4 col4" >58%</td>
#       <td id="T_e4feb_row4_col5" class="data row4 col5" >6%</td>
#       <td id="T_e4feb_row4_col6" class="data row4 col6" >3.20</td>
#       <td id="T_e4feb_row4_col7" class="data row4 col7" >MX</td>
#       <td id="T_e4feb_row4_col8" class="data row4 col8" >2023-09-18 09:53:49</td>
#     </tr>
#     <tr>
#       <td id="T_e4feb_row5_col0" class="data row5 col0" >imbituba</td>
#       <td id="T_e4feb_row5_col1" class="data row5 col1" >-28.24</td>
#       <td id="T_e4feb_row5_col2" class="data row5 col2" >-48.67</td>
#       <td id="T_e4feb_row5_col3" class="data row5 col3" >83.86° F</td>
#       <td id="T_e4feb_row5_col4" class="data row5 col4" >42%</td>
#       <td id="T_e4feb_row5_col5" class="data row5 col5" >2%</td>
#       <td id="T_e4feb_row5_col6" class="data row5 col6" >8.30</td>
#       <td id="T_e4feb_row5_col7" class="data row5 col7" >BR</td>
#       <td id="T_e4feb_row5_col8" class="data row5 col8" >2023-09-18 09:58:41</td>
#     </tr>
#     <tr>
#       <td id="T_e4feb_row6_col0" class="data row6 col0" >cabo san lucas</td>
#       <td id="T_e4feb_row6_col1" class="data row6 col1" >22.89</td>
#       <td id="T_e4feb_row6_col2" class="data row6 col2" >-109.91</td>
#       <td id="T_e4feb_row6_col3" class="data row6 col3" >89.22° F</td>
#       <td id="T_e4feb_row6_col4" class="data row6 col4" >61%</td>
#       <td id="T_e4feb_row6_col5" class="data row6 col5" >0%</td>
#       <td id="T_e4feb_row6_col6" class="data row6 col6" >9.22</td>
#       <td id="T_e4feb_row6_col7" class="data row6 col7" >MX</td>
#       <td id="T_e4feb_row6_col8" class="data row6 col8" >2023-09-18 10:03:44</td>
#     </tr>
#     <tr>
#       <td id="T_e4feb_row7_col0" class="data row7 col0" >castanos</td>
#       <td id="T_e4feb_row7_col1" class="data row7 col1" >26.78</td>
#       <td id="T_e4feb_row7_col2" class="data row7 col2" >-101.42</td>
#       <td id="T_e4feb_row7_col3" class="data row7 col3" >81.91° F</td>
#       <td id="T_e4feb_row7_col4" class="data row7 col4" >51%</td>
#       <td id="T_e4feb_row7_col5" class="dat

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Fairfield Inn & Suites by Marriott Cut Off-Galliano in galliano, US
#
#
# Located the following hotel...The Elms Hotel and Spa in excelsior springs, US
#
#
# Located the following hotel...Hotel Sol del Pacífico in lazaro cardenas, MX
#
#
# Located the following hotel...Silvestre Praia Hotel in imbituba, BR
#
#
# Located the following hotel...Comfort Rooms in cabo san lucas, MX
#
#
# Located the following hotel...La Cuarteria Hotel Boutique in mocorito, MX
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
local_function \
    .ReturnCityWeatherStylerObjectStandardFormat \
        (updatedHotelLocationDataFrame,
         'Table: 3.1: Hotel Locations')
# Out:
# <style type="text/css">
# #T_bd7ed caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_bd7ed_row0_col0, #T_bd7ed_row0_col1, #T_bd7ed_row0_col2, #T_bd7ed_row0_col3, #T_bd7ed_row0_col4, #T_bd7ed_row0_col6, #T_bd7ed_row0_col7, #T_bd7ed_row0_col8, #T_bd7ed_row0_col9, #T_bd7ed_row1_col0, #T_bd7ed_row1_col1, #T_bd7ed_row1_col2, #T_bd7ed_row1_col6, #T_bd7ed_row1_col7, #T_bd7ed_row1_col8, #T_bd7ed_row1_col9, #T_bd7ed_row2_col0, #T_bd7ed_row2_col1, #T_bd7ed_row2_col2, #T_bd7ed_row2_col3, #T_bd7ed_row2_col4, #T_bd7ed_row2_col5, #T_bd7ed_row2_col6, #T_bd7ed_row2_col7, #T_bd7ed_row2_col8, #T_bd7ed_row2_col9, #T_bd7ed_row3_col0, #T_bd7ed_row3_col1, #T_bd7ed_row3_col2, #T_bd7ed_row3_col3, #T_bd7ed_row3_col4, #T_bd7ed_row3_col5, #T_bd7ed_row3_col6, #T_bd7ed_row3_col7, #T_bd7ed_row3_col8, #T_bd7ed_row3_col9, #T_bd7ed_row4_col0, #T_bd7ed_row4_col1, #T_bd7ed_row4_col2, #T_bd7ed_row4_col3, #T_bd7ed_row4_col7, #T_bd7ed_row4_col8, #T_bd7ed_row4_col9, #T_bd7ed_row5_col0, #T_bd7ed_row5_col1, #T_bd7ed_row5_col2, #T_bd7ed_row5_col4, #T_bd7ed_row5_col7, #T_bd7ed_row5_col8, #T_bd7ed_row5_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_bd7ed_row0_col5, #T_bd7ed_row1_col3, #T_bd7ed_row1_col4, #T_bd7ed_row1_col5, #T_bd7ed_row4_col5, #T_bd7ed_row5_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_bd7ed_row4_col4, #T_bd7ed_row4_col6, #T_bd7ed_row5_col3, #T_bd7ed_row5_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_bd7ed">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_bd7ed_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_bd7ed_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_bd7ed_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_bd7ed_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_bd7ed_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_bd7ed_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_bd7ed_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_bd7ed_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_bd7ed_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_bd7ed_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bd7ed_row0_col0" class="data row0 col0" >galliano</td>
#       <td id="T_bd7ed_row0_col1" class="data row0 col1" >29.44</td>
#       <td id="T_bd7ed_row0_col2" class="data row0 col2" >-90.30</td>
#       <td id="T_bd7ed_row0_col3" class="data row0 col3" >87.76° F</td>
#       <td id="T_bd7ed_row0_col4" class="data row0 col4" >51%</td>
#       <td id="T_bd7ed_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_bd7ed_row0_col6" class="data row0 col6" >6.91</td>
#       <td id="T_bd7ed_row0_col7" class="data row0 col7" >US</td>
#       <td id="T_bd7ed_row0_col8" class="data row0 col8" >2023-09-18 09:59:08</td>
#       <td id="T_bd7ed_row0_col9" class="data row0 col9" >Fairfield Inn & Suites by Marriott Cut Off-Galliano</td>
#     </tr>
#     <tr>
#       <td id="T_bd7ed_row1_col0" class="data row1 col0" >excelsior springs</td>
#       <td id="T_bd7ed_row1_col1" class="data row1 col1" >39.34</td>
#       <td id="T_bd7ed_row1_col2" class="data row1 col2" >-94.23</td>
#       <td id="T_bd7ed_row1_col3" class="data row1 col3" >77.05° F</td>
#       <td id="T_bd7ed_row1_col4" class="data row1 col4" >41%</td>
#       <td id="T_bd7ed_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_bd7ed_row1_col6" class="data row1 col6" >6.91</td>
#       <td id="T_bd7ed_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_bd7ed_row1_col8" class="data row1 col8" >2023-09-18 10:00:58</td>
#       <td id="T_bd7ed_row1_col9" class="data row1 col9" >The Elms Hotel and Spa</td>
#     </tr>
#     <tr>
#       <td id="T_bd7ed_row2_col0" class="data row2 col0" >lazaro cardenas</td>
#       <td id="T_bd7ed_row2_col1" class="data row2 col1" >17.96</td>
#       <td id="T_bd7ed_row2_col2" class="data row2 col2" >-102.20</td>
#       <td id="T_bd7ed_row2_col3" class="data row2 col3" >86.65° F</td>
#       <td id="T_bd7ed_row2_col4" class="data row2 col4" >58%</td>
#       <td id="T_bd7ed_row2_col5" class="data row2 col5" >6%</td>
#       <td id="T_bd7ed_row2_col6" class="data row2 col6" >3.20</td>
#       <td id="T_bd7ed_row2_col7" class="data row2 col7" >MX</td>
#       <td id="T_bd7ed_row2_col8" class="data row2 col8" >2023-09-18 09:53:49</td>
#       <td id="T_bd7ed_row2_col9" class="data row2 col9" >Hotel Sol del Pacífico</td>
#     </tr>
#     <tr>
#       <td id="T_bd7ed_row3_col0" class="data row3 col0" >imbituba</td>
#       <td id="T_bd7ed_row3_col1" class="data row3 col1" >-28.24</td>
#       <td id="T_bd7ed_row3_col2" class="data row3 col2" >-48.67</td>
#       <td id="T_bd7ed_row3_col3" class="data row3 col3" >83.86° F</td>
#       <td id="T_bd7ed_row3_col4" class="data row3 col4" >42%</td>
#       <td id="T_bd7ed_row3_col5" class="data row3 col5" >2%</td>
#       <td id="T_bd7ed_row3_col6" class="data row3 col6" >8.30</td>
#       <td id="T_bd7ed_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_bd7ed_row3_col8" class="data row3 col8" >2023-09-18 09:58:41</td>
#       <td id="T_bd7ed_row3_col9" class="data row3 col9" >Silvestre Praia Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_bd7ed_row4_col0" class="data row4 col0" >cabo san lucas</td>
#       <td id="T_bd7ed_row4_col1" class="data row4 col1" >22.89</td>
#       <td id="T_bd7ed_row4_col2" class="data row4 col2" >-109.91</td>
#       <td id="T_bd7ed_row4_col3" class="data row4 col3" >89.22° F</td>
#       <td id="T_bd7ed_row4_col4" class="data row4 col4" >61%</td>
#       <td id="T_bd7ed_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_bd7ed_row4_col6" class="data row4 col6" >9.22</td>
#       <td id="T_bd7ed_row4_col7" class="data row4 col7" >MX</td>
#       <td id="T_bd7ed_row4_col8" class="data row4 col8" >2023-09-18 10:03:44</td>
#       <td id="T_bd7ed_row4_col9" class="data row4 col9" >Comfort Rooms</td>
#     </tr>
#     <tr>
#       <td id="T_bd7ed_row5_col0" class="data row5 col0" >mocorito</td>
#       <td id="T_bd7ed_row5_col1" class="data row5 col1" >25.48</td>
#       <td id="T_bd7ed_row5_col2" class="data row5 col2" >-107.92</td>
#       <td id="T_bd7ed_row5_col3" class="data row5 col3" >92.21° F</td>
#       <td id="T_bd7ed_row5_col4" class="data row5 col4" >52%</td>
#       <td id="T_bd7ed_row5_col5" class="data row5 col5" >7%</td>
#       <td id="T_bd7ed_row5_col6" class="data row5 col6" >2.57</td>
#       <td id="T_bd7ed_row5_col7" class="data row5 col7" >MX</td>
#       <td id="T_bd7ed_row5_col8" class="data row5 col8" >2023-09-18 10:04:54</td>
#       <td id="T_bd7ed_row5_col9" class="data row5 col9" >La Cuarteria Hotel Boutique</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
