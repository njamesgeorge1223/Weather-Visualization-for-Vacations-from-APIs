# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant \
                 .WEATHER_DATA_FILE_PATH,
             local_constant \
                 .WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
captionString \
    = 'Table: 1.1: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_c23f8 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_c23f8_row0_col0, #T_c23f8_row0_col1, #T_c23f8_row0_col2, #T_c23f8_row0_col3, #T_c23f8_row0_col4, #T_c23f8_row0_col5, #T_c23f8_row0_col7, #T_c23f8_row0_col8, #T_c23f8_row1_col0, #T_c23f8_row1_col1, #T_c23f8_row1_col2, #T_c23f8_row1_col4, #T_c23f8_row1_col6, #T_c23f8_row1_col7, #T_c23f8_row1_col8, #T_c23f8_row2_col0, #T_c23f8_row2_col1, #T_c23f8_row2_col2, #T_c23f8_row2_col3, #T_c23f8_row2_col4, #T_c23f8_row2_col6, #T_c23f8_row2_col7, #T_c23f8_row2_col8, #T_c23f8_row3_col0, #T_c23f8_row3_col1, #T_c23f8_row3_col2, #T_c23f8_row3_col3, #T_c23f8_row3_col4, #T_c23f8_row3_col5, #T_c23f8_row3_col6, #T_c23f8_row3_col7, #T_c23f8_row3_col8, #T_c23f8_row4_col0, #T_c23f8_row4_col1, #T_c23f8_row4_col2, #T_c23f8_row4_col3, #T_c23f8_row4_col4, #T_c23f8_row4_col5, #T_c23f8_row4_col6, #T_c23f8_row4_col7, #T_c23f8_row4_col8, #T_c23f8_row5_col0, #T_c23f8_row5_col1, #T_c23f8_row5_col2, #T_c23f8_row5_col5, #T_c23f8_row5_col6, #T_c23f8_row5_col7, #T_c23f8_row5_col8, #T_c23f8_row6_col0, #T_c23f8_row6_col1, #T_c23f8_row6_col2, #T_c23f8_row6_col3, #T_c23f8_row6_col4, #T_c23f8_row6_col5, #T_c23f8_row6_col6, #T_c23f8_row6_col7, #T_c23f8_row6_col8, #T_c23f8_row7_col0, #T_c23f8_row7_col1, #T_c23f8_row7_col2, #T_c23f8_row7_col3, #T_c23f8_row7_col6, #T_c23f8_row7_col7, #T_c23f8_row7_col8, #T_c23f8_row8_col0, #T_c23f8_row8_col1, #T_c23f8_row8_col2, #T_c23f8_row8_col3, #T_c23f8_row8_col4, #T_c23f8_row8_col7, #T_c23f8_row8_col8, #T_c23f8_row9_col0, #T_c23f8_row9_col1, #T_c23f8_row9_col2, #T_c23f8_row9_col3, #T_c23f8_row9_col4, #T_c23f8_row9_col6, #T_c23f8_row9_col7, #T_c23f8_row9_col8, #T_c23f8_row10_col0, #T_c23f8_row10_col1, #T_c23f8_row10_col2, #T_c23f8_row10_col3, #T_c23f8_row10_col5, #T_c23f8_row10_col6, #T_c23f8_row10_col7, #T_c23f8_row10_col8, #T_c23f8_row11_col0, #T_c23f8_row11_col1, #T_c23f8_row11_col2, #T_c23f8_row11_col3, #T_c23f8_row11_col4, #T_c23f8_row11_col5, #T_c23f8_row11_col6, #T_c23f8_row11_col7, #T_c23f8_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_c23f8_row0_col6, #T_c23f8_row2_col5, #T_c23f8_row5_col3, #T_c23f8_row7_col5, #T_c23f8_row9_col5, #T_c23f8_row10_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_c23f8_row1_col3, #T_c23f8_row1_col5, #T_c23f8_row5_col4, #T_c23f8_row7_col4, #T_c23f8_row8_col5, #T_c23f8_row8_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_c23f8">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_c23f8_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_c23f8_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_c23f8_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_c23f8_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_c23f8_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_c23f8_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_c23f8_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_c23f8_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_c23f8_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c23f8_row0_col0" class="data row0 col0" >bondo</td>
#       <td id="T_c23f8_row0_col1" class="data row0 col1" >3.81</td>
#       <td id="T_c23f8_row0_col2" class="data row0 col2" >23.69</td>
#       <td id="T_c23f8_row0_col3" class="data row0 col3" >70.16° F</td>
#       <td id="T_c23f8_row0_col4" class="data row0 col4" >99%</td>
#       <td id="T_c23f8_row0_col5" class="data row0 col5" >87%</td>
#       <td id="T_c23f8_row0_col6" class="data row0 col6" >1.57</td>
#       <td id="T_c23f8_row0_col7" class="data row0 col7" >CD</td>
#       <td id="T_c23f8_row0_col8" class="data row0 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_c23f8_row1_col0" class="data row1 col0" >uribia</td>
#       <td id="T_c23f8_row1_col1" class="data row1 col1" >11.71</td>
#       <td id="T_c23f8_row1_col2" class="data row1 col2" >-72.27</td>
#       <td id="T_c23f8_row1_col3" class="data row1 col3" >84.61° F</td>
#       <td id="T_c23f8_row1_col4" class="data row1 col4" >71%</td>
#       <td id="T_c23f8_row1_col5" class="data row1 col5" >100%</td>
#       <td id="T_c23f8_row1_col6" class="data row1 col6" >5.41</td>
#       <td id="T_c23f8_row1_col7" class="data row1 col7" >CO</td>
#       <td id="T_c23f8_row1_col8" class="data row1 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_c23f8_row2_col0" class="data row2 col0" >saldanha</td>
#       <td id="T_c23f8_row2_col1" class="data row2 col1" >-33.01</td>
#       <td id="T_c23f8_row2_col2" class="data row2 col2" >17.94</td>
#       <td id="T_c23f8_row2_col3" class="data row2 col3" >42.85° F</td>
#       <td id="T_c23f8_row2_col4" class="data row2 col4" >77%</td>
#       <td id="T_c23f8_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_c23f8_row2_col6" class="data row2 col6" >11.86</td>
#       <td id="T_c23f8_row2_col7" class="data row2 col7" >ZA</td>
#       <td id="T_c23f8_row2_col8" class="data row2 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_c23f8_row3_col0" class="data row3 col0" >el calafate</td>
#       <td id="T_c23f8_row3_col1" class="data row3 col1" >-50.34</td>
#       <td id="T_c23f8_row3_col2" class="data row3 col2" >-72.28</td>
#       <td id="T_c23f8_row3_col3" class="data row3 col3" >37.27° F</td>
#       <td id="T_c23f8_row3_col4" class="data row3 col4" >70%</td>
#       <td id="T_c23f8_row3_col5" class="data row3 col5" >18%</td>
#       <td id="T_c23f8_row3_col6" class="data row3 col6" >3.38</td>
#       <td id="T_c23f8_row3_col7" class="data row3 col7" >AR</td>
#       <td id="T_c23f8_row3_col8" class="data row3 col8" >2023-09-30 21:28:11</td>
#     </tr>
#     <tr>
#       <td id="T_c23f8_row4_col0" class="data row4 col0" >edinburgh of the seven seas</td>
#       <td id="T_c23f8_row4_col1" class="data row4 col1" >-37.07</td>
#       <td id="T_c23f8_row4_col2" class="data row4 col2" >-12.31</td>
#       <td id="T_c23f8_row4_col3" class="data row4 col3" >50.23° F</td>
#       <td id="T_c23f8_row4_col4" class="data row4 col4" >69%</td>
#       <td id="T_c23f8_row4_col5" class="data row4 col5" >92%</td>
#       <td id="T_c23f8_row4_col6" class="data row4 col6" >30.85</td>
#       <td id="T_c23f8_row4_col7" class="data row4 col7" >SH</td>
#       <td id="T_c23f8_row4_col8" class="data row4 col8" >2023-09-30 21:28:12</td>
#     </tr>
#     <tr>
#       <td id="T_c23f8_row5_col0" class="data row5 col0" >thompson</td>
#       <td id="T_c23f8_row5_col1" class="data row5 col1" >55.74</td>
#       <td id="T_c23f8_row5_col2" class="data row5 col2" >-97.86</td>
#       <td id="T_c23f8_row5_col3" class="data row5 col3" >33.96° F</td>
#       <td id="T_c23f8_row5_col4" class="data row5 col4" >100%</td>
#       <td id="T_c23f8_row5_col5" class="data row5 col5" >75%</td>
#       <td id="T_c23f8_row5_col6" class="data row5 col6" >2.30</td>
#       <td id="T_c23f8_row5_col7" class="data row5 col7" >CA</td>
#       <td id="T_c23f8_row5_col8" class="data row5 col8" >2023-09-30 21:26:07</td>
#     </tr>
#     <tr>
#       <td id="T_c23f8_row6_col0" class="data row6 col0" >waitangi</td>
#       <td id="T_c23f8_row6_col1" class="data row6 col1" >-43.95</td>
#       <td id="T_c23f8_row6_col2" class="data row6 col2" >-176.56</td>
#       <td id="T_c23f8_row6_col3" class="data row6 col3" >50.83° F</td>
#       <td id="T_c23f8_row6_col4" class="data row6 col4" >79%</td>
#       <td id="T_c23f8_row6_col5" class="data row6 col5" >22%</td>
#       <td id="T_c23f8_row6_col6" class="data row6 col6" >11.01</td>
#       <td id="T_c23f8_row6_col7" class="data row6 col7" >NZ</td>
#       <td id="T_c23f8_row6_col8" class="data row6 col8" >2023-09-30 21:28:12</td>
#     </tr>
#     <tr>
#       <td id="T_c23f8_row

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 93), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 40) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 70), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 10), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
captionString \
    = 'Table: 2.1: Ideal Vacation Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (idealVacationLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_f9cfe caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_f9cfe_row0_col0, #T_f9cfe_row0_col1, #T_f9cfe_row0_col2, #T_f9cfe_row0_col4, #T_f9cfe_row0_col5, #T_f9cfe_row0_col6, #T_f9cfe_row0_col7, #T_f9cfe_row0_col8, #T_f9cfe_row1_col0, #T_f9cfe_row1_col1, #T_f9cfe_row1_col2, #T_f9cfe_row1_col3, #T_f9cfe_row1_col5, #T_f9cfe_row1_col7, #T_f9cfe_row1_col8, #T_f9cfe_row2_col0, #T_f9cfe_row2_col1, #T_f9cfe_row2_col2, #T_f9cfe_row2_col3, #T_f9cfe_row2_col4, #T_f9cfe_row2_col7, #T_f9cfe_row2_col8, #T_f9cfe_row3_col0, #T_f9cfe_row3_col1, #T_f9cfe_row3_col2, #T_f9cfe_row3_col4, #T_f9cfe_row3_col6, #T_f9cfe_row3_col7, #T_f9cfe_row3_col8, #T_f9cfe_row4_col0, #T_f9cfe_row4_col1, #T_f9cfe_row4_col2, #T_f9cfe_row4_col3, #T_f9cfe_row4_col4, #T_f9cfe_row4_col6, #T_f9cfe_row4_col7, #T_f9cfe_row4_col8, #T_f9cfe_row5_col0, #T_f9cfe_row5_col1, #T_f9cfe_row5_col2, #T_f9cfe_row5_col3, #T_f9cfe_row5_col5, #T_f9cfe_row5_col6, #T_f9cfe_row5_col7, #T_f9cfe_row5_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_f9cfe_row0_col3, #T_f9cfe_row1_col6, #T_f9cfe_row3_col5, #T_f9cfe_row4_col5, #T_f9cfe_row5_col4 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_f9cfe_row1_col4, #T_f9cfe_row2_col5, #T_f9cfe_row2_col6, #T_f9cfe_row3_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_f9cfe">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_f9cfe_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_f9cfe_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_f9cfe_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_f9cfe_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_f9cfe_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_f9cfe_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_f9cfe_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_f9cfe_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_f9cfe_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f9cfe_row0_col0" class="data row0 col0" >kone</td>
#       <td id="T_f9cfe_row0_col1" class="data row0 col1" >-21.06</td>
#       <td id="T_f9cfe_row0_col2" class="data row0 col2" >164.87</td>
#       <td id="T_f9cfe_row0_col3" class="data row0 col3" >76.77° F</td>
#       <td id="T_f9cfe_row0_col4" class="data row0 col4" >46%</td>
#       <td id="T_f9cfe_row0_col5" class="data row0 col5" >8%</td>
#       <td id="T_f9cfe_row0_col6" class="data row0 col6" >8.90</td>
#       <td id="T_f9cfe_row0_col7" class="data row0 col7" >NC</td>
#       <td id="T_f9cfe_row0_col8" class="data row0 col8" >2023-09-30 21:28:42</td>
#     </tr>
#     <tr>
#       <td id="T_f9cfe_row1_col0" class="data row1 col0" >port sudan</td>
#       <td id="T_f9cfe_row1_col1" class="data row1 col1" >19.62</td>
#       <td id="T_f9cfe_row1_col2" class="data row1 col2" >37.22</td>
#       <td id="T_f9cfe_row1_col3" class="data row1 col3" >84.24° F</td>
#       <td id="T_f9cfe_row1_col4" class="data row1 col4" >67%</td>
#       <td id="T_f9cfe_row1_col5" class="data row1 col5" >6%</td>
#       <td id="T_f9cfe_row1_col6" class="data row1 col6" >1.86</td>
#       <td id="T_f9cfe_row1_col7" class="data row1 col7" >SD</td>
#       <td id="T_f9cfe_row1_col8" class="data row1 col8" >2023-09-30 21:28:53</td>
#     </tr>
#     <tr>
#       <td id="T_f9cfe_row2_col0" class="data row2 col0" >yilan</td>
#       <td id="T_f9cfe_row2_col1" class="data row2 col1" >24.76</td>
#       <td id="T_f9cfe_row2_col2" class="data row2 col2" >121.75</td>
#       <td id="T_f9cfe_row2_col3" class="data row2 col3" >87.10° F</td>
#       <td id="T_f9cfe_row2_col4" class="data row2 col4" >57%</td>
#       <td id="T_f9cfe_row2_col5" class="data row2 col5" >10%</td>
#       <td id="T_f9cfe_row2_col6" class="data row2 col6" >9.19</td>
#       <td id="T_f9cfe_row2_col7" class="data row2 col7" >TW</td>
#       <td id="T_f9cfe_row2_col8" class="data row2 col8" >2023-09-30 21:29:30</td>
#     </tr>
#     <tr>
#       <td id="T_f9cfe_row3_col0" class="data row3 col0" >boa vista</td>
#       <td id="T_f9cfe_row3_col1" class="data row3 col1" >2.82</td>
#       <td id="T_f9cfe_row3_col2" class="data row3 col2" >-60.67</td>
#       <td id="T_f9cfe_row3_col3" class="data row3 col3" >87.78° F</td>
#       <td id="T_f9cfe_row3_col4" class="data row3 col4" >48%</td>
#       <td id="T_f9cfe_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_f9cfe_row3_col6" class="data row3 col6" >5.75</td>
#       <td id="T_f9cfe_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_f9cfe_row3_col8" class="data row3 col8" >2023-09-30 21:29:32</td>
#     </tr>
#     <tr>
#       <td id="T_f9cfe_row4_col0" class="data row4 col0" >chiredzi</td>
#       <td id="T_f9cfe_row4_col1" class="data row4 col1" >-21.05</td>
#       <td id="T_f9cfe_row4_col2" class="data row4 col2" >31.67</td>
#       <td id="T_f9cfe_row4_col3" class="data row4 col3" >77.27° F</td>
#       <td id="T_f9cfe_row4_col4" class="data row4 col4" >43%</td>
#       <td id="T_f9cfe_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_f9cfe_row4_col6" class="data row4 col6" >4.25</td>
#       <td id="T_f9cfe_row4_col7" class="data row4 col7" >ZW</td>
#       <td id="T_f9cfe_row4_col8" class="data row4 col8" >2023-09-30 21:29:37</td>
#     </tr>
#     <tr>
#       <td id="T_f9cfe_row5_col0" class="data row5 col0" >nhamunda</td>
#       <td id="T_f9cfe_row5_col1" class="data row5 col1" >-2.19</td>
#       <td id="T_f9cfe_row5_col2" class="data row5 col2" >-56.71</td>
#       <td id="T_f9cfe_row5_col3" class="data row5 col3" >81.18° F</td>
#       <td id="T_f9cfe_row5_col4" class="data row5 col4" >41%</td>
#       <td id="T_f9cfe_row5_col5" class="data row5 col5" >8%</td>
#       <td id="T_f9cfe_row5_col6" class="data row5 col6" >3.51</td>
#       <td id="T_f9cfe_row5_col7" class="data row5 col7" >BR</td>
#       <td id="T_f9cfe_row5_col8" class="data row5 col8" >2023-09-30 21:30:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd.Series \
            (dtype= 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Pacifik Appartels in kone, NC
#
#
# Located the following hotel...Ranya Hotel in port sudan, SD
#
#
# Located the following hotel...蘭城晶英酒店(6-11F) in yilan, TW
#
#
# Located the following hotel...Aipana Plaza Hotel in boa vista, BR
#
#
# Located the following hotel...Nesbitt Arms Hotel in chiredzi, ZW
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
captionString \
    = 'Table: 3.1: Hotel Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedHotelLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_db585 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_db585_row0_col0, #T_db585_row0_col1, #T_db585_row0_col2, #T_db585_row0_col4, #T_db585_row0_col5, #T_db585_row0_col6, #T_db585_row0_col7, #T_db585_row0_col8, #T_db585_row0_col9, #T_db585_row1_col0, #T_db585_row1_col1, #T_db585_row1_col2, #T_db585_row1_col3, #T_db585_row1_col5, #T_db585_row1_col7, #T_db585_row1_col8, #T_db585_row1_col9, #T_db585_row2_col0, #T_db585_row2_col1, #T_db585_row2_col2, #T_db585_row2_col3, #T_db585_row2_col4, #T_db585_row2_col7, #T_db585_row2_col8, #T_db585_row2_col9, #T_db585_row3_col0, #T_db585_row3_col1, #T_db585_row3_col2, #T_db585_row3_col4, #T_db585_row3_col6, #T_db585_row3_col7, #T_db585_row3_col8, #T_db585_row3_col9, #T_db585_row4_col0, #T_db585_row4_col1, #T_db585_row4_col2, #T_db585_row4_col3, #T_db585_row4_col6, #T_db585_row4_col7, #T_db585_row4_col8, #T_db585_row4_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_db585_row0_col3, #T_db585_row1_col6, #T_db585_row3_col5, #T_db585_row4_col4, #T_db585_row4_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_db585_row1_col4, #T_db585_row2_col5, #T_db585_row2_col6, #T_db585_row3_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_db585">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_db585_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_db585_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_db585_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_db585_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_db585_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_db585_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_db585_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_db585_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_db585_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_db585_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_db585_row0_col0" class="data row0 col0" >kone</td>
#       <td id="T_db585_row0_col1" class="data row0 col1" >-21.06</td>
#       <td id="T_db585_row0_col2" class="data row0 col2" >164.87</td>
#       <td id="T_db585_row0_col3" class="data row0 col3" >76.77° F</td>
#       <td id="T_db585_row0_col4" class="data row0 col4" >46%</td>
#       <td id="T_db585_row0_col5" class="data row0 col5" >8%</td>
#       <td id="T_db585_row0_col6" class="data row0 col6" >8.90</td>
#       <td id="T_db585_row0_col7" class="data row0 col7" >NC</td>
#       <td id="T_db585_row0_col8" class="data row0 col8" >2023-09-30 21:28:42</td>
#       <td id="T_db585_row0_col9" class="data row0 col9" >Pacifik Appartels</td>
#     </tr>
#     <tr>
#       <td id="T_db585_row1_col0" class="data row1 col0" >port sudan</td>
#       <td id="T_db585_row1_col1" class="data row1 col1" >19.62</td>
#       <td id="T_db585_row1_col2" class="data row1 col2" >37.22</td>
#       <td id="T_db585_row1_col3" class="data row1 col3" >84.24° F</td>
#       <td id="T_db585_row1_col4" class="data row1 col4" >67%</td>
#       <td id="T_db585_row1_col5" class="data row1 col5" >6%</td>
#       <td id="T_db585_row1_col6" class="data row1 col6" >1.86</td>
#       <td id="T_db585_row1_col7" class="data row1 col7" >SD</td>
#       <td id="T_db585_row1_col8" class="data row1 col8" >2023-09-30 21:28:53</td>
#       <td id="T_db585_row1_col9" class="data row1 col9" >Ranya Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_db585_row2_col0" class="data row2 col0" >yilan</td>
#       <td id="T_db585_row2_col1" class="data row2 col1" >24.76</td>
#       <td id="T_db585_row2_col2" class="data row2 col2" >121.75</td>
#       <td id="T_db585_row2_col3" class="data row2 col3" >87.10° F</td>
#       <td id="T_db585_row2_col4" class="data row2 col4" >57%</td>
#       <td id="T_db585_row2_col5" class="data row2 col5" >10%</td>
#       <td id="T_db585_row2_col6" class="data row2 col6" >9.19</td>
#       <td id="T_db585_row2_col7" class="data row2 col7" >TW</td>
#       <td id="T_db585_row2_col8" class="data row2 col8" >2023-09-30 21:29:30</td>
#       <td id="T_db585_row2_col9" class="data row2 col9" >蘭城晶英酒店(6-11F)</td>
#     </tr>
#     <tr>
#       <td id="T_db585_row3_col0" class="data row3 col0" >boa vista</td>
#       <td id="T_db585_row3_col1" class="data row3 col1" >2.82</td>
#       <td id="T_db585_row3_col2" class="data row3 col2" >-60.67</td>
#       <td id="T_db585_row3_col3" class="data row3 col3" >87.78° F</td>
#       <td id="T_db585_row3_col4" class="data row3 col4" >48%</td>
#       <td id="T_db585_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_db585_row3_col6" class="data row3 col6" >5.75</td>
#       <td id="T_db585_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_db585_row3_col8" class="data row3 col8" >2023-09-30 21:29:32</td>
#       <td id="T_db585_row3_col9" class="data row3 col9" >Aipana Plaza Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_db585_row4_col0" class="data row4 col0" >chiredzi</td>
#       <td id="T_db585_row4_col1" class="data row4 col1" >-21.05</td>
#       <td id="T_db585_row4_col2" class="data row4 col2" >31.67</td>
#       <td id="T_db585_row4_col3" class="data row4 col3" >77.27° F</td>
#       <td id="T_db585_row4_col4" class="data row4 col4" >43%</td>
#       <td id="T_db585_row4_col5" class="data row4 col5" >0%</td>
#       <td id="T_db585_row4_col6" class="data row4 col6" >4.25</td>
#       <td id="T_db585_row4_col7" class="data row4 col7" >ZW</td>
#       <td id="T_db585_row4_col8" class="data row4 col8" >2023-09-30 21:29:37</td>
#       <td id="T_db585_row4_col9" class="data row4 col9" >Nesbitt Arms Hotel</td>
#     </tr>
#   </tbody>
# </table>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
