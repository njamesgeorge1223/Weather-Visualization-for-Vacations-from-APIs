# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Data Acquisition**

# %% [markdown]
# ### **Load CSV File into DataFrame**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant.WEATHER_DATA_FILE_PATH,
             local_constant.WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ### **Display City Weather Information**

# %%
captionString \
    = 'Table: 1.1: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_4d068 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_4d068_row0_col0, #T_4d068_row0_col1, #T_4d068_row0_col2, #T_4d068_row0_col3, #T_4d068_row0_col4, #T_4d068_row0_col5, #T_4d068_row0_col7, #T_4d068_row0_col8, #T_4d068_row1_col0, #T_4d068_row1_col1, #T_4d068_row1_col2, #T_4d068_row1_col3, #T_4d068_row1_col4, #T_4d068_row1_col5, #T_4d068_row1_col6, #T_4d068_row1_col7, #T_4d068_row1_col8, #T_4d068_row2_col0, #T_4d068_row2_col1, #T_4d068_row2_col2, #T_4d068_row2_col3, #T_4d068_row2_col5, #T_4d068_row2_col6, #T_4d068_row2_col7, #T_4d068_row2_col8, #T_4d068_row3_col0, #T_4d068_row3_col1, #T_4d068_row3_col2, #T_4d068_row3_col3, #T_4d068_row3_col4, #T_4d068_row3_col5, #T_4d068_row3_col7, #T_4d068_row3_col8, #T_4d068_row4_col0, #T_4d068_row4_col1, #T_4d068_row4_col2, #T_4d068_row4_col4, #T_4d068_row4_col5, #T_4d068_row4_col6, #T_4d068_row4_col7, #T_4d068_row4_col8, #T_4d068_row5_col0, #T_4d068_row5_col1, #T_4d068_row5_col2, #T_4d068_row5_col3, #T_4d068_row5_col4, #T_4d068_row5_col5, #T_4d068_row5_col6, #T_4d068_row5_col7, #T_4d068_row5_col8, #T_4d068_row6_col0, #T_4d068_row6_col1, #T_4d068_row6_col2, #T_4d068_row6_col3, #T_4d068_row6_col4, #T_4d068_row6_col6, #T_4d068_row6_col7, #T_4d068_row6_col8, #T_4d068_row7_col0, #T_4d068_row7_col1, #T_4d068_row7_col2, #T_4d068_row7_col3, #T_4d068_row7_col6, #T_4d068_row7_col7, #T_4d068_row7_col8, #T_4d068_row8_col0, #T_4d068_row8_col1, #T_4d068_row8_col2, #T_4d068_row8_col3, #T_4d068_row8_col4, #T_4d068_row8_col5, #T_4d068_row8_col6, #T_4d068_row8_col7, #T_4d068_row8_col8, #T_4d068_row9_col0, #T_4d068_row9_col1, #T_4d068_row9_col2, #T_4d068_row9_col3, #T_4d068_row9_col4, #T_4d068_row9_col6, #T_4d068_row9_col7, #T_4d068_row9_col8, #T_4d068_row10_col0, #T_4d068_row10_col1, #T_4d068_row10_col2, #T_4d068_row10_col3, #T_4d068_row10_col4, #T_4d068_row10_col6, #T_4d068_row10_col7, #T_4d068_row10_col8, #T_4d068_row11_col0, #T_4d068_row11_col1, #T_4d068_row11_col2, #T_4d068_row11_col4, #T_4d068_row11_col5, #T_4d068_row11_col6, #T_4d068_row11_col7, #T_4d068_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_4d068_row0_col6, #T_4d068_row2_col4, #T_4d068_row7_col5, #T_4d068_row11_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_4d068_row3_col6, #T_4d068_row4_col3, #T_4d068_row6_col5, #T_4d068_row7_col4, #T_4d068_row9_col5, #T_4d068_row10_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_4d068">
#   <caption>Table: 1.1: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_4d068_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_4d068_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_4d068_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_4d068_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_4d068_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_4d068_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_4d068_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_4d068_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_4d068_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4d068_row0_col0" class="data row0 col0" >kapuskasing</td>
#       <td id="T_4d068_row0_col1" class="data row0 col1" >49.42</td>
#       <td id="T_4d068_row0_col2" class="data row0 col2" >-82.43</td>
#       <td id="T_4d068_row0_col3" class="data row0 col3" >57.20° F</td>
#       <td id="T_4d068_row0_col4" class="data row0 col4" >72%</td>
#       <td id="T_4d068_row0_col5" class="data row0 col5" >20%</td>
#       <td id="T_4d068_row0_col6" class="data row0 col6" >3.44</td>
#       <td id="T_4d068_row0_col7" class="data row0 col7" >CA</td>
#       <td id="T_4d068_row0_col8" class="data row0 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_4d068_row1_col0" class="data row1 col0" >salinopolis</td>
#       <td id="T_4d068_row1_col1" class="data row1 col1" >-0.61</td>
#       <td id="T_4d068_row1_col2" class="data row1 col2" >-47.36</td>
#       <td id="T_4d068_row1_col3" class="data row1 col3" >80.89° F</td>
#       <td id="T_4d068_row1_col4" class="data row1 col4" >76%</td>
#       <td id="T_4d068_row1_col5" class="data row1 col5" >3%</td>
#       <td id="T_4d068_row1_col6" class="data row1 col6" >12.24</td>
#       <td id="T_4d068_row1_col7" class="data row1 col7" >BR</td>
#       <td id="T_4d068_row1_col8" class="data row1 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_4d068_row2_col0" class="data row2 col0" >alofi</td>
#       <td id="T_4d068_row2_col1" class="data row2 col1" >-19.06</td>
#       <td id="T_4d068_row2_col2" class="data row2 col2" >-169.92</td>
#       <td id="T_4d068_row2_col3" class="data row2 col3" >78.69° F</td>
#       <td id="T_4d068_row2_col4" class="data row2 col4" >65%</td>
#       <td id="T_4d068_row2_col5" class="data row2 col5" >40%</td>
#       <td id="T_4d068_row2_col6" class="data row2 col6" >13.80</td>
#       <td id="T_4d068_row2_col7" class="data row2 col7" >NU</td>
#       <td id="T_4d068_row2_col8" class="data row2 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_4d068_row3_col0" class="data row3 col0" >port-aux-francais</td>
#       <td id="T_4d068_row3_col1" class="data row3 col1" >-49.35</td>
#       <td id="T_4d068_row3_col2" class="data row3 col2" >70.22</td>
#       <td id="T_4d068_row3_col3" class="data row3 col3" >35.19° F</td>
#       <td id="T_4d068_row3_col4" class="data row3 col4" >83%</td>
#       <td id="T_4d068_row3_col5" class="data row3 col5" >49%</td>
#       <td id="T_4d068_row3_col6" class="data row3 col6" >42.64</td>
#       <td id="T_4d068_row3_col7" class="data row3 col7" >TF</td>
#       <td id="T_4d068_row3_col8" class="data row3 col8" >2023-09-26 17:57:11</td>
#     </tr>
#     <tr>
#       <td id="T_4d068_row4_col0" class="data row4 col0" >saipan</td>
#       <td id="T_4d068_row4_col1" class="data row4 col1" >15.14</td>
#       <td id="T_4d068_row4_col2" class="data row4 col2" >145.70</td>
#       <td id="T_4d068_row4_col3" class="data row4 col3" >83.10° F</td>
#       <td id="T_4d068_row4_col4" class="data row4 col4" >89%</td>
#       <td id="T_4d068_row4_col5" class="data row4 col5" >40%</td>
#       <td id="T_4d068_row4_col6" class="data row4 col6" >6.91</td>
#       <td id="T_4d068_row4_col7" class="data row4 col7" >MP</td>
#       <td id="T_4d068_row4_col8" class="data row4 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_4d068_row5_col0" class="data row5 col0" >ushuaia</td>
#       <td id="T_4d068_row5_col1" class="data row5 col1" >-54.80</td>
#       <td id="T_4d068_row5_col2" class="data row5 col2" >-68.30</td>
#       <td id="T_4d068_row5_col3" class="data row5 col3" >37.06° F</td>
#       <td id="T_4d068_row5_col4" class="data row5 col4" >70%</td>
#       <td id="T_4d068_row5_col5" class="data row5 col5" >40%</td>
#       <td id="T_4d068_row5_col6" class="data row5 col6" >21.85</td>
#       <td id="T_4d068_row5_col7" class="data row5 col7" >AR</td>
#       <td id="T_4d068_row5_col8" class="data row5 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_4d068_row6_col0" class="data row6 col0" >tazovsky</td>
#       <td id="T_4d068_row6_col1" class="data row6 col1" >67.47</td>
#       <td id="T_4d068_row6_col2" class="data row6 col2" >78.70</td>
#       <td id="T_4d068_row6_col3" class="data row6 col3" >32.47° F</td>
#       <td id="T_4d068_row6_col4" class="data row6 col4" >75%</td>
#       <td id="T_4d068_row6_col5" class="data row6 col5" >100%</td>
#       <td id="T_4d068_row6_col6" class="data row6 col6" >12.84</td>
#       <td id="T_4d068_row6_col7" class="data row6 col7" >RU</td>
#       <td id="T_4d068_row6_col8" class="data row6 col8" >2023-09-26 17:57:12</td>
#     </tr>
#     <tr>
#       <td id="T_4d068_row7_col0"

# %% [markdown]
# ### Display City Weather Information on Map (Humidity Determines Point Size)

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.1: City Weather Information on Map',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Ideal Weather Locations**

# %% [markdown]
# ### **Establish Ideal Weather Conditions for Vacation Locations**

# %%
idealVacationLocationDataFrame \
    = cityWeatherDataFrame \
            .loc \
                [(cityWeatherDataFrame['Temperature'] >= 76) \
                 & (cityWeatherDataFrame['Temperature'] <= 93), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Humidity'] >= 40) \
                  & (idealVacationLocationDataFrame['Humidity'] <= 70), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Cloudiness'] >= 0) \
                  & (idealVacationLocationDataFrame['Cloudiness'] <= 10), :]

idealVacationLocationDataFrame \
    = idealVacationLocationDataFrame \
            .loc \
                [(idealVacationLocationDataFrame['Wind Speed'] >= 0) 
                  & (idealVacationLocationDataFrame['Wind Speed'] <= 10), :]


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Clean Ideal Vacation Locations**

# %%
idealVacationLocationDataFrame \
        .dropna \
            (inplace \
                = True)

idealVacationLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (idealVacationLocationDataFrame)

# %% [markdown]
# ### **Display Ideal Vacation Locations**

# %%
captionString \
    = 'Table: 2.1: Ideal Vacation Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (idealVacationLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_fda6a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_fda6a_row0_col0, #T_fda6a_row0_col1, #T_fda6a_row0_col2, #T_fda6a_row0_col3, #T_fda6a_row0_col4, #T_fda6a_row0_col6, #T_fda6a_row0_col7, #T_fda6a_row0_col8, #T_fda6a_row1_col0, #T_fda6a_row1_col1, #T_fda6a_row1_col2, #T_fda6a_row1_col3, #T_fda6a_row1_col4, #T_fda6a_row1_col6, #T_fda6a_row1_col7, #T_fda6a_row1_col8, #T_fda6a_row2_col0, #T_fda6a_row2_col1, #T_fda6a_row2_col2, #T_fda6a_row2_col3, #T_fda6a_row2_col4, #T_fda6a_row2_col7, #T_fda6a_row2_col8, #T_fda6a_row3_col0, #T_fda6a_row3_col1, #T_fda6a_row3_col2, #T_fda6a_row3_col3, #T_fda6a_row3_col4, #T_fda6a_row3_col6, #T_fda6a_row3_col7, #T_fda6a_row3_col8, #T_fda6a_row4_col0, #T_fda6a_row4_col1, #T_fda6a_row4_col2, #T_fda6a_row4_col3, #T_fda6a_row4_col4, #T_fda6a_row4_col5, #T_fda6a_row4_col6, #T_fda6a_row4_col7, #T_fda6a_row4_col8, #T_fda6a_row5_col0, #T_fda6a_row5_col1, #T_fda6a_row5_col2, #T_fda6a_row5_col5, #T_fda6a_row5_col6, #T_fda6a_row5_col7, #T_fda6a_row5_col8, #T_fda6a_row6_col0, #T_fda6a_row6_col1, #T_fda6a_row6_col2, #T_fda6a_row6_col3, #T_fda6a_row6_col4, #T_fda6a_row6_col5, #T_fda6a_row6_col6, #T_fda6a_row6_col7, #T_fda6a_row6_col8, #T_fda6a_row7_col0, #T_fda6a_row7_col1, #T_fda6a_row7_col2, #T_fda6a_row7_col3, #T_fda6a_row7_col4, #T_fda6a_row7_col6, #T_fda6a_row7_col7, #T_fda6a_row7_col8, #T_fda6a_row8_col0, #T_fda6a_row8_col1, #T_fda6a_row8_col2, #T_fda6a_row8_col3, #T_fda6a_row8_col4, #T_fda6a_row8_col6, #T_fda6a_row8_col7, #T_fda6a_row8_col8, #T_fda6a_row9_col0, #T_fda6a_row9_col1, #T_fda6a_row9_col2, #T_fda6a_row9_col7, #T_fda6a_row9_col8, #T_fda6a_row10_col0, #T_fda6a_row10_col1, #T_fda6a_row10_col2, #T_fda6a_row10_col3, #T_fda6a_row10_col4, #T_fda6a_row10_col5, #T_fda6a_row10_col6, #T_fda6a_row10_col7, #T_fda6a_row10_col8, #T_fda6a_row11_col0, #T_fda6a_row11_col1, #T_fda6a_row11_col2, #T_fda6a_row11_col3, #T_fda6a_row11_col5, #T_fda6a_row11_col6, #T_fda6a_row11_col7, #T_fda6a_row11_col8, #T_fda6a_row12_col0, #T_fda6a_row12_col1, #T_fda6a_row12_col2, #T_fda6a_row12_col4, #T_fda6a_row12_col6, #T_fda6a_row12_col7, #T_fda6a_row12_col8, #T_fda6a_row13_col0, #T_fda6a_row13_col1, #T_fda6a_row13_col2, #T_fda6a_row13_col3, #T_fda6a_row13_col4, #T_fda6a_row13_col5, #T_fda6a_row13_col6, #T_fda6a_row13_col7, #T_fda6a_row13_col8, #T_fda6a_row14_col0, #T_fda6a_row14_col1, #T_fda6a_row14_col2, #T_fda6a_row14_col3, #T_fda6a_row14_col4, #T_fda6a_row14_col6, #T_fda6a_row14_col7, #T_fda6a_row14_col8, #T_fda6a_row15_col0, #T_fda6a_row15_col1, #T_fda6a_row15_col2, #T_fda6a_row15_col3, #T_fda6a_row15_col4, #T_fda6a_row15_col6, #T_fda6a_row15_col7, #T_fda6a_row15_col8, #T_fda6a_row16_col0, #T_fda6a_row16_col1, #T_fda6a_row16_col2, #T_fda6a_row16_col3, #T_fda6a_row16_col4, #T_fda6a_row16_col6, #T_fda6a_row16_col7, #T_fda6a_row16_col8, #T_fda6a_row17_col0, #T_fda6a_row17_col1, #T_fda6a_row17_col2, #T_fda6a_row17_col3, #T_fda6a_row17_col4, #T_fda6a_row17_col6, #T_fda6a_row17_col7, #T_fda6a_row17_col8, #T_fda6a_row18_col0, #T_fda6a_row18_col1, #T_fda6a_row18_col2, #T_fda6a_row18_col3, #T_fda6a_row18_col4, #T_fda6a_row18_col5, #T_fda6a_row18_col6, #T_fda6a_row18_col7, #T_fda6a_row18_col8, #T_fda6a_row19_col0, #T_fda6a_row19_col1, #T_fda6a_row19_col2, #T_fda6a_row19_col3, #T_fda6a_row19_col4, #T_fda6a_row19_col6, #T_fda6a_row19_col7, #T_fda6a_row19_col8, #T_fda6a_row20_col0, #T_fda6a_row20_col1, #T_fda6a_row20_col2, #T_fda6a_row20_col3, #T_fda6a_row20_col4, #T_fda6a_row20_col5, #T_fda6a_row20_col6, #T_fda6a_row20_col7, #T_fda6a_row20_col8, #T_fda6a_row21_col0, #T_fda6a_row21_col1, #T_fda6a_row21_col2, #T_fda6a_row21_col3, #T_fda6a_row21_col4, #T_fda6a_row21_col5, #T_fda6a_row21_col6, #T_fda6a_row21_col7, #T_fda6a_row21_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_fda6a_row0_col5, #T_fda6a_row2_col5, #T_fda6a_row2_col6, #T_fda6a_row3_col5, #T_fda6a_row5_col3, #T_fda6a_row5_col4, #T_fda6a_row7_col5, #T_fda6a_row8_col5, #T_fda6a_row9_col3, #T_fda6a_row9_col5, #T_fda6a_row12_col5, #T_fda6a_row14_col5, #T_fda6a_row15_col5, #T_fda6a_row16_col5, #T_fda6a_row17_col5, #T_fda6a_row19_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_fda6a_row1_col5, #T_fda6a_row9_col4, #T_fda6a_row9_col6, #T_fda6a_row11_col4, #T_fda6a_row12_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_fda6a">
#   <caption>Table: 2.1: Ideal Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_fda6a_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_fda6a_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_fda6a_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_fda6a_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_fda6a_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_fda6a_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_fda6a_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_fda6a_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_fda6a_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fda6a_row0_col0" class="data row0 col0" >springwood</td>
#       <td id="T_fda6a_row0_col1" class="data row0 col1" >-27.61</td>
#       <td id="T_fda6a_row0_col2" class="data row0 col2" >153.13</td>
#       <td id="T_fda6a_row0_col3" class="data row0 col3" >80.31° F</td>
#       <td id="T_fda6a_row0_col4" class="data row0 col4" >44%</td>
#       <td id="T_fda6a_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_fda6a_row0_col6" class="data row0 col6" >3.00</td>
#       <td id="T_fda6a_row0_col7" class="data row0 col7" >AU</td>
#       <td id="T_fda6a_row0_col8" class="data row0 col8" >2023-09-26 17:57:16</td>
#     </tr>
#     <tr>
#       <td id="T_fda6a_row1_col0" class="data row1 col0" >la'ie</td>
#       <td id="T_fda6a_row1_col1" class="data row1 col1" >21.65</td>
#       <td id="T_fda6a_row1_col2" class="data row1 col2" >-157.93</td>
#       <td id="T_fda6a_row1_col3" class="data row1 col3" >83.08° F</td>
#       <td id="T_fda6a_row1_col4" class="data row1 col4" >65%</td>
#       <td id="T_fda6a_row1_col5" class="data row1 col5" >10%</td>
#       <td id="T_fda6a_row1_col6" class="data row1 col6" >8.99</td>
#       <td id="T_fda6a_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_fda6a_row1_col8" class="data row1 col8" >2023-09-26 17:57:24</td>
#     </tr>
#     <tr>
#       <td id="T_fda6a_row2_col0" class="data row2 col0" >karaton</td>
#       <td id="T_fda6a_row2_col1" class="data row2 col1" >-6.34</td>
#       <td id="T_fda6a_row2_col2" class="data row2 col2" >106.10</td>
#       <td id="T_fda6a_row2_col3" class="data row2 col3" >83.08° F</td>
#       <td id="T_fda6a_row2_col4" class="data row2 col4" >53%</td>
#       <td id="T_fda6a_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_fda6a_row2_col6" class="data row2 col6" >0.51</td>
#       <td id="T_fda6a_row2_col7" class="data row2 col7" >ID</td>
#       <td id="T_fda6a_row2_col8" class="data row2 col8" >2023-09-26 17:57:31</td>
#     </tr>
#     <tr>
#       <td id="T_fda6a_row3_col0" class="data row3 col0" >yilan</td>
#       <td id="T_fda6a_row3_col1" class="data row3 col1" >24.76</td>
#       <td id="T_fda6a_row3_col2" class="data row3 col2" >121.75</td>
#       <td id="T_fda6a_row3_col3" class="data row3 col3" >86.85° F</td>
#       <td id="T_fda6a_row3_col4" class="data row3 col4" >64%</td>
#       <td id="T_fda6a_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_fda6a_row3_col6" class="data row3 col6" >4.97</td>
#       <td id="T_fda6a_row3_col7" class="data row3 col7" >TW</td>
#       <td id="T_fda6a_row3_col8" class="data row3 col8" >2023-09-26 17:57:33</td>
#     </tr>
#     <tr>
#       <td id="T_fda6a_row4_col0" class="data row4 col0" >east ballina</td>
#       <td id="T_fda6a

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (idealVacationLocationDataFrame,
         'Figure 2.1: Ideal Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ### **Hotel Location DataFrame**

# %%
hotelLocationDataFrame \
    = idealVacationLocationDataFrame.copy()

hotelLocationDataFrame \
    ['Hotel Name'] \
        = pd \
            .Series \
                (dtype \
                    = 'str')

hotelLocationDataFrame \
    .reset_index \
        (drop \
            = True, 
         inplace \
            = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelLocationDataFrame)

# %% [markdown]
# ### ***Hotel Location Determination***

# %%
updatedHotelLocationDataFrame \
    = api_function \
        .ReturnUpdatedHotelLocationDataFrame \
            (hotelLocationDataFrame,
             'accommodation.hotel',
             10000)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Hotel Gloria in springwood, AU
#
#
# Located the following hotel...Hale Koolau in la'ie, US
#
#
# Located the following hotel...HOTEL HORISON ALTAMA in karaton, ID
#
#
# Located the following hotel...蘭城晶英酒店(6-11F) in yilan, TW
#
#
# Located the following hotel...Ballina Beach Resort in east ballina, AU
#
#
# Located the following hotel...Pacifik Appartels in kone, NC
#
#
# Located the following hotel...The Esplanade Hotel in port hedland, AU
#
#
# Located the following hotel...Tri-L-Lodging.com in stephenville, US
#
#
# Located the following hotel...La Gaviota in manta, EC
#
#
# Located the following hotel...Aipana Plaza Hotel in boa vista, BR
#
#
# Located the following hotel...Holiday Inn Express in santa ana, US
#
#
# Located the following hotel...Ningrat traditional hotel in bangkalan, ID
#
#
# Located the following hotel...Janta Cafe & Restaurant in barmer, IN
#
#
# Located the following hotel...ホテルニューパレス in shingu, JP
#
#
# Hotel search complete

# %% [markdown]
# ### **Display Hotel Information**

# %%
captionString \
    = 'Table: 3.1: Hotel Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedHotelLocationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_7f37f caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_7f37f_row0_col0, #T_7f37f_row0_col1, #T_7f37f_row0_col2, #T_7f37f_row0_col3, #T_7f37f_row0_col4, #T_7f37f_row0_col6, #T_7f37f_row0_col7, #T_7f37f_row0_col8, #T_7f37f_row0_col9, #T_7f37f_row1_col0, #T_7f37f_row1_col1, #T_7f37f_row1_col2, #T_7f37f_row1_col3, #T_7f37f_row1_col4, #T_7f37f_row1_col6, #T_7f37f_row1_col7, #T_7f37f_row1_col8, #T_7f37f_row1_col9, #T_7f37f_row2_col0, #T_7f37f_row2_col1, #T_7f37f_row2_col2, #T_7f37f_row2_col3, #T_7f37f_row2_col4, #T_7f37f_row2_col7, #T_7f37f_row2_col8, #T_7f37f_row2_col9, #T_7f37f_row3_col0, #T_7f37f_row3_col1, #T_7f37f_row3_col2, #T_7f37f_row3_col3, #T_7f37f_row3_col4, #T_7f37f_row3_col6, #T_7f37f_row3_col7, #T_7f37f_row3_col8, #T_7f37f_row3_col9, #T_7f37f_row4_col0, #T_7f37f_row4_col1, #T_7f37f_row4_col2, #T_7f37f_row4_col3, #T_7f37f_row4_col4, #T_7f37f_row4_col5, #T_7f37f_row4_col6, #T_7f37f_row4_col7, #T_7f37f_row4_col8, #T_7f37f_row4_col9, #T_7f37f_row5_col0, #T_7f37f_row5_col1, #T_7f37f_row5_col2, #T_7f37f_row5_col5, #T_7f37f_row5_col6, #T_7f37f_row5_col7, #T_7f37f_row5_col8, #T_7f37f_row5_col9, #T_7f37f_row6_col0, #T_7f37f_row6_col1, #T_7f37f_row6_col2, #T_7f37f_row6_col3, #T_7f37f_row6_col4, #T_7f37f_row6_col5, #T_7f37f_row6_col6, #T_7f37f_row6_col7, #T_7f37f_row6_col8, #T_7f37f_row6_col9, #T_7f37f_row7_col0, #T_7f37f_row7_col1, #T_7f37f_row7_col2, #T_7f37f_row7_col3, #T_7f37f_row7_col4, #T_7f37f_row7_col6, #T_7f37f_row7_col7, #T_7f37f_row7_col8, #T_7f37f_row7_col9, #T_7f37f_row8_col0, #T_7f37f_row8_col1, #T_7f37f_row8_col2, #T_7f37f_row8_col3, #T_7f37f_row8_col4, #T_7f37f_row8_col6, #T_7f37f_row8_col7, #T_7f37f_row8_col8, #T_7f37f_row8_col9, #T_7f37f_row9_col0, #T_7f37f_row9_col1, #T_7f37f_row9_col2, #T_7f37f_row9_col7, #T_7f37f_row9_col8, #T_7f37f_row9_col9, #T_7f37f_row10_col0, #T_7f37f_row10_col1, #T_7f37f_row10_col2, #T_7f37f_row10_col4, #T_7f37f_row10_col6, #T_7f37f_row10_col7, #T_7f37f_row10_col8, #T_7f37f_row10_col9, #T_7f37f_row11_col0, #T_7f37f_row11_col1, #T_7f37f_row11_col2, #T_7f37f_row11_col3, #T_7f37f_row11_col4, #T_7f37f_row11_col6, #T_7f37f_row11_col7, #T_7f37f_row11_col8, #T_7f37f_row11_col9, #T_7f37f_row12_col0, #T_7f37f_row12_col1, #T_7f37f_row12_col2, #T_7f37f_row12_col3, #T_7f37f_row12_col4, #T_7f37f_row12_col5, #T_7f37f_row12_col6, #T_7f37f_row12_col7, #T_7f37f_row12_col8, #T_7f37f_row12_col9, #T_7f37f_row13_col0, #T_7f37f_row13_col1, #T_7f37f_row13_col2, #T_7f37f_row13_col3, #T_7f37f_row13_col4, #T_7f37f_row13_col6, #T_7f37f_row13_col7, #T_7f37f_row13_col8, #T_7f37f_row13_col9, #T_7f37f_row14_col0, #T_7f37f_row14_col1, #T_7f37f_row14_col2, #T_7f37f_row14_col3, #T_7f37f_row14_col4, #T_7f37f_row14_col5, #T_7f37f_row14_col6, #T_7f37f_row14_col7, #T_7f37f_row14_col8, #T_7f37f_row14_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_7f37f_row0_col5, #T_7f37f_row2_col5, #T_7f37f_row2_col6, #T_7f37f_row3_col5, #T_7f37f_row5_col3, #T_7f37f_row5_col4, #T_7f37f_row7_col5, #T_7f37f_row8_col5, #T_7f37f_row9_col3, #T_7f37f_row9_col5, #T_7f37f_row10_col5, #T_7f37f_row11_col5, #T_7f37f_row13_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_7f37f_row1_col5, #T_7f37f_row9_col4, #T_7f37f_row9_col6, #T_7f37f_row10_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_7f37f">
#   <caption>Table: 3.1: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_7f37f_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_7f37f_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_7f37f_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_7f37f_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_7f37f_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_7f37f_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_7f37f_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_7f37f_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_7f37f_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_7f37f_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f37f_row0_col0" class="data row0 col0" >springwood</td>
#       <td id="T_7f37f_row0_col1" class="data row0 col1" >-27.61</td>
#       <td id="T_7f37f_row0_col2" class="data row0 col2" >153.13</td>
#       <td id="T_7f37f_row0_col3" class="data row0 col3" >80.31° F</td>
#       <td id="T_7f37f_row0_col4" class="data row0 col4" >44%</td>
#       <td id="T_7f37f_row0_col5" class="data row0 col5" >0%</td>
#       <td id="T_7f37f_row0_col6" class="data row0 col6" >3.00</td>
#       <td id="T_7f37f_row0_col7" class="data row0 col7" >AU</td>
#       <td id="T_7f37f_row0_col8" class="data row0 col8" >2023-09-26 17:57:16</td>
#       <td id="T_7f37f_row0_col9" class="data row0 col9" >Hotel Gloria</td>
#     </tr>
#     <tr>
#       <td id="T_7f37f_row1_col0" class="data row1 col0" >la'ie</td>
#       <td id="T_7f37f_row1_col1" class="data row1 col1" >21.65</td>
#       <td id="T_7f37f_row1_col2" class="data row1 col2" >-157.93</td>
#       <td id="T_7f37f_row1_col3" class="data row1 col3" >83.08° F</td>
#       <td id="T_7f37f_row1_col4" class="data row1 col4" >65%</td>
#       <td id="T_7f37f_row1_col5" class="data row1 col5" >10%</td>
#       <td id="T_7f37f_row1_col6" class="data row1 col6" >8.99</td>
#       <td id="T_7f37f_row1_col7" class="data row1 col7" >US</td>
#       <td id="T_7f37f_row1_col8" class="data row1 col8" >2023-09-26 17:57:24</td>
#       <td id="T_7f37f_row1_col9" class="data row1 col9" >Hale Koolau</td>
#     </tr>
#     <tr>
#       <td id="T_7f37f_row2_col0" class="data row2 col0" >karaton</td>
#       <td id="T_7f37f_row2_col1" class="data row2 col1" >-6.34</td>
#       <td id="T_7f37f_row2_col2" class="data row2 col2" >106.10</td>
#       <td id="T_7f37f_row2_col3" class="data row2 col3" >83.08° F</td>
#       <td id="T_7f37f_row2_col4" class="data row2 col4" >53%</td>
#       <td id="T_7f37f_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_7f37f_row2_col6" class="data row2 col6" >0.51</td>
#       <td id="T_7f37f_row2_col7" class="data row2 col7" >ID</td>
#       <td id="T_7f37f_row2_col8" class="data row2 col8" >2023-09-26 17:57:31</td>
#       <td id="T_7f37f_row2_col9" class="data row2 col9" >HOTEL HORISON ALTAMA</td>
#     </tr>
#     <tr>
#       <td id="T_7f37f_row3_col0" class="data row3 col0" >yilan</td>
#       <td id="T_7f37f_row3_col1" class="data row3 col1" >24.76</td>
#       <td id="T_7f37f_row3_col2" class="data row3 col2" >121.75</td>
#       <td id="T_7f37f_row3_col3" class="data row3 col3" >86.85° F</td>
#       <td id="T_7f37f_row3_col4" class="data row3 col4" >64%</td>
#       <td id="T_7f37f_row3_col5" class="data row3 col5" >0%</td>
#       <td id="T_7f37f_row3_col6" class="data row3 col6" >4.97</td>
#       <td id="T_7f37f_row3_col7" class="data row3 col7" >TW</td>
#       <td id="T_7f37f_row3_col8" class="data row3 col8" >2023-09-26 17:57:33</td>
#       <td id="T_7f37f_row3_col9" class="data row3 col9" >蘭城晶英酒店(6-11F)</td>
#     </tr>
#     <tr>
#       <td id="T_7f37f_row4_col0" class="data row4 col0" >east ballina</td>
#       <td id="T_7f37f_row4_col1" class="data row4 col1" >-28.87</td>
#       <td id="T_7f37f_row4_col2" class="data row4 col2" >153.58</td>
#       <td id="T_7f37f_row4_col3" class="data row4 col3" >83.80° F</td>
#       <td id="T_7f37f_row4_col4" class="data row4 col4" >44%</td>
#       <td id="T_7f37f_row4_col5" class="data row4 col5" >2%</td>
#       <td id="T_7f37f_row4_col6" class="data row4 col6" >4.94</td>
#       <td id="T_7f37f_row4_col7" class="data row4 col7" >AU</td>
#       <td id="T_7f37f_row4_col8" class="data row4 col8" >2023-09-26 17:57:35</td>
#       <td id="T_7f37f_row4_col9" class="data row4 col9" >Ballina Beach Resort</td>
#     </tr>
#     <tr>

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelLocationDataFrame,
         'Figure 3.1: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
