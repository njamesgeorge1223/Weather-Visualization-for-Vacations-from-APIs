# %% [markdown]
# # VacationPy

# %%
 #*******************************************************************************************
 #
 #  File Name:  VacationPy.ipynb 
 #
 #  File Description:
 #      This interactive Python notebook, VacationPy.ipynb, uses a Python script to 
 #      determine the ideal locations (city and hotel) for a vacation and displays
 #      information on a map.
 #      
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  08/26/2023      Initial Development                     N. James George
 #
 #******************************************************************************************/

import PyFunctions as function
import PyLogFunctions as log_function
import PyLogSubRoutines as log_subroutine
import WeatherPyAPIFunctions as api_function
import WeatherPyConstants as local_constant
import WeatherPyFunctions as local_function
import VacationPySubRoutines as local_subroutine

import hvplot.pandas

import pandas as pd
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
CONSTANT_LOCAL_FILE_NAME \
    = 'VacationPy.py'


log_subroutine \
    .SetLogMode \
        (False)

log_subroutine \
    .SetDebugMode \
        (False)

log_subroutine \
    .SetImageMode \
        (False)


local_subroutine.SetVacationTemperatureRange(70, 95)

local_subroutine.SetVacationHumidityRange(35, 65)

local_subroutine.SetVacationCloudinessRange(0, 10)

local_subroutine.SetVacationWindPSpeedRange(0, 10)


log_subroutine \
    .BeginProgramExecution \
        ('VacationPy')

# %% [markdown]
# # <br> **Section 1: Vacation Data Acquisition**

# %% [markdown]
# ## **1.1: Data Import from CSV File**

# %%
cityWeatherDataFrame \
    = function \
        .ReturnCSVFileAsDataFrame \
            (local_constant \
                 .WEATHER_DATA_FILE_PATH,
             local_constant \
                 .WEATHER_DATA_FILE_INDEX_NAME)


log_function \
    .DebugReturnObjectWriteObject \
        (cityWeatherDataFrame)

# %% [markdown]
# ## **1.2: Display City Weather Data Set**

# %%
captionString \
    = 'Table: 1.2: City Weather Information'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (cityWeatherDataFrame.head(12),
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_d9747 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_d9747_row0_col0, #T_d9747_row0_col1, #T_d9747_row0_col2, #T_d9747_row0_col3, #T_d9747_row0_col4, #T_d9747_row0_col5, #T_d9747_row0_col6, #T_d9747_row0_col7, #T_d9747_row0_col8, #T_d9747_row1_col0, #T_d9747_row1_col1, #T_d9747_row1_col2, #T_d9747_row1_col3, #T_d9747_row1_col4, #T_d9747_row1_col5, #T_d9747_row1_col6, #T_d9747_row1_col7, #T_d9747_row1_col8, #T_d9747_row2_col0, #T_d9747_row2_col1, #T_d9747_row2_col2, #T_d9747_row2_col3, #T_d9747_row2_col5, #T_d9747_row2_col6, #T_d9747_row2_col7, #T_d9747_row2_col8, #T_d9747_row3_col0, #T_d9747_row3_col1, #T_d9747_row3_col2, #T_d9747_row3_col3, #T_d9747_row3_col4, #T_d9747_row3_col5, #T_d9747_row3_col6, #T_d9747_row3_col7, #T_d9747_row3_col8, #T_d9747_row4_col0, #T_d9747_row4_col1, #T_d9747_row4_col2, #T_d9747_row4_col3, #T_d9747_row4_col4, #T_d9747_row4_col5, #T_d9747_row4_col6, #T_d9747_row4_col7, #T_d9747_row4_col8, #T_d9747_row5_col0, #T_d9747_row5_col1, #T_d9747_row5_col2, #T_d9747_row5_col3, #T_d9747_row5_col4, #T_d9747_row5_col7, #T_d9747_row5_col8, #T_d9747_row6_col0, #T_d9747_row6_col1, #T_d9747_row6_col2, #T_d9747_row6_col3, #T_d9747_row6_col4, #T_d9747_row6_col5, #T_d9747_row6_col6, #T_d9747_row6_col7, #T_d9747_row6_col8, #T_d9747_row7_col0, #T_d9747_row7_col1, #T_d9747_row7_col2, #T_d9747_row7_col3, #T_d9747_row7_col4, #T_d9747_row7_col6, #T_d9747_row7_col7, #T_d9747_row7_col8, #T_d9747_row8_col0, #T_d9747_row8_col1, #T_d9747_row8_col2, #T_d9747_row8_col3, #T_d9747_row8_col4, #T_d9747_row8_col5, #T_d9747_row8_col6, #T_d9747_row8_col7, #T_d9747_row8_col8, #T_d9747_row9_col0, #T_d9747_row9_col1, #T_d9747_row9_col2, #T_d9747_row9_col4, #T_d9747_row9_col6, #T_d9747_row9_col7, #T_d9747_row9_col8, #T_d9747_row10_col0, #T_d9747_row10_col1, #T_d9747_row10_col2, #T_d9747_row10_col4, #T_d9747_row10_col5, #T_d9747_row10_col6, #T_d9747_row10_col7, #T_d9747_row10_col8, #T_d9747_row11_col0, #T_d9747_row11_col1, #T_d9747_row11_col2, #T_d9747_row11_col3, #T_d9747_row11_col5, #T_d9747_row11_col7, #T_d9747_row11_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_d9747_row2_col4, #T_d9747_row5_col5, #T_d9747_row5_col6, #T_d9747_row7_col5, #T_d9747_row10_col3 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# #T_d9747_row9_col3, #T_d9747_row9_col5, #T_d9747_row11_col4, #T_d9747_row11_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# </style>
# <table id="T_d9747">
#   <caption>Table: 1.2: City Weather Information</caption>
#   <thead>
#     <tr>
#       <th id="T_d9747_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_d9747_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_d9747_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_d9747_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_d9747_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_d9747_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_d9747_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_d9747_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_d9747_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d9747_row0_col0" class="data row0 col0" >edinburgh of the seven seas</td>
#       <td id="T_d9747_row0_col1" class="data row0 col1" >-37.07</td>
#       <td id="T_d9747_row0_col2" class="data row0 col2" >-12.31</td>
#       <td id="T_d9747_row0_col3" class="data row0 col3" >56.39° F</td>
#       <td id="T_d9747_row0_col4" class="data row0 col4" >79%</td>
#       <td id="T_d9747_row0_col5" class="data row0 col5" >60%</td>
#       <td id="T_d9747_row0_col6" class="data row0 col6" >23.00</td>
#       <td id="T_d9747_row0_col7" class="data row0 col7" >SH</td>
#       <td id="T_d9747_row0_col8" class="data row0 col8" >2023-11-08 11:10:27</td>
#     </tr>
#     <tr>
#       <td id="T_d9747_row1_col0" class="data row1 col0" >ushuaia</td>
#       <td id="T_d9747_row1_col1" class="data row1 col1" >-54.80</td>
#       <td id="T_d9747_row1_col2" class="data row1 col2" >-68.30</td>
#       <td id="T_d9747_row1_col3" class="data row1 col3" >43.43° F</td>
#       <td id="T_d9747_row1_col4" class="data row1 col4" >46%</td>
#       <td id="T_d9747_row1_col5" class="data row1 col5" >40%</td>
#       <td id="T_d9747_row1_col6" class="data row1 col6" >8.05</td>
#       <td id="T_d9747_row1_col7" class="data row1 col7" >AR</td>
#       <td id="T_d9747_row1_col8" class="data row1 col8" >2023-11-08 11:10:29</td>
#     </tr>
#     <tr>
#       <td id="T_d9747_row2_col0" class="data row2 col0" >port-aux-francais</td>
#       <td id="T_d9747_row2_col1" class="data row2 col1" >-49.35</td>
#       <td id="T_d9747_row2_col2" class="data row2 col2" >70.22</td>
#       <td id="T_d9747_row2_col3" class="data row2 col3" >41.52° F</td>
#       <td id="T_d9747_row2_col4" class="data row2 col4" >95%</td>
#       <td id="T_d9747_row2_col5" class="data row2 col5" >90%</td>
#       <td id="T_d9747_row2_col6" class="data row2 col6" >30.24</td>
#       <td id="T_d9747_row2_col7" class="data row2 col7" >TF</td>
#       <td id="T_d9747_row2_col8" class="data row2 col8" >2023-11-08 11:10:32</td>
#     </tr>
#     <tr>
#       <td id="T_d9747_row3_col0" class="data row3 col0" >stanley</td>
#       <td id="T_d9747_row3_col1" class="data row3 col1" >54.87</td>
#       <td id="T_d9747_row3_col2" class="data row3 col2" >-1.70</td>
#       <td id="T_d9747_row3_col3" class="data row3 col3" >41.79° F</td>
#       <td id="T_d9747_row3_col4" class="data row3 col4" >81%</td>
#       <td id="T_d9747_row3_col5" class="data row3 col5" >20%</td>
#       <td id="T_d9747_row3_col6" class="data row3 col6" >10.36</td>
#       <td id="T_d9747_row3_col7" class="data row3 col7" >GB</td>
#       <td id="T_d9747_row3_col8" class="data row3 col8" >2023-11-08 11:10:32</td>
#     </tr>
#     <tr>
#       <td id="T_d9747_row4_col0" class="data row4 col0" >albany</td>
#       <td id="T_d9747_row4_col1" class="data row4 col1" >42.60</td>
#       <td id="T_d9747_row4_col2" class="data row4 col2" >-73.97</td>
#       <td id="T_d9747_row4_col3" class="data row4 col3" >38.37° F</td>
#       <td id="T_d9747_row4_col4" class="data row4 col4" >51%</td>
#       <td id="T_d9747_row4_col5" class="data row4 col5" >28%</td>
#       <td id="T_d9747_row4_col6" class="data row4 col6" >8.61</td>
#       <td id="T_d9747_row4_col7" class="data row4 col7" >US</td>
#       <td id="T_d9747_row4_col8" class="data row4 col8" >2023-11-08 11:00:08</td>
#     </tr>
#     <tr>
#       <td id="T_d9747_row5_col0" class="data row5 col0" >midvagur</td>
#       <td id="T_d9747_row5_col1" class="data row5 col1" >62.05</td>
#       <td id="T_d9747_row5_col2" class="data row5 col2" >-7.19</td>
#       <td id="T_d9747_row5_col3" class="data row5 col3" >43.63° F</td>
#       <td id="T_d9747_row5_col4" class="data row5 col4" >87%</td>
#       <td id="T_d9747_row5_col5" class="data row5 col5" >100%</td>
#       <td id="T_d9747_row5_col6" class="data row5 col6" >31.07</td>
#       <td id="T_d9747_row5_col7" class="data row5 col7" >FO</td>
#       <td id="T_d9747_row5_col8" class="data row5 col8" >2023-11-08 11:10:33</td>
#     </tr>
#     <tr>
#       <td id="T_d9747_row6_col0" class="data row6 col0" >west island</td>
#       <td id="T_d9747_row6_col1" class="data row6 col1" >-12.16</td>
#       <td id="T_d9747_row6_col2" class="data row6 col2" >96.82</td>
#       <td id="T_d9747_row6_col3" class="data row6 col3" >78.78° F</td>
#       <td id="T_d9747_row6_col4" class="data row6 col4" >83%</td>
#       <td id="T_d9747_row6_col5" class="data row6 col5" >75%</td>
#       <td id="T_d9747_row6_col6" class="data row6 col6" >9.22</td>
#       <td id="T_d9747_row6_col7" class="data row6 col7" >CC</td>
#       <td id="T_d9747_row6_col8" class="data row6 col8" >2023-11-08 11:10:33</td>
#     </tr>
#     <tr>
#       <td id="T_

# %% [markdown]
# ## **1.3: Display City Weather Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (cityWeatherDataFrame,
         'Figure 1.3: City Weather Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 2: Desired Weather Locations**

# %% [markdown]
# ## **2.1: Establish Desired Weather Conditions for Vacation Locations**

# %%
vacationDataFrame \
    = cityWeatherDataFrame \
        .loc \
            [(cityWeatherDataFrame['Temperature'] \
                >= local_constant \
                      .weatherConditionsDictionary \
                          ['temperatureIntegerList'][0]) \
                 & (cityWeatherDataFrame['Temperature'] \
                        <= local_constant \
                              .weatherConditionsDictionary \
                                  ['temperatureIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Humidity'] \
                      >= local_constant \
                          .weatherConditionsDictionary \
                              ['humidityIntegerList'][0]) \
                  & (vacationDataFrame['Humidity'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                  ['humidityIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Cloudiness'] \
                      >= local_constant \
                            .weatherConditionsDictionary \
                                ['cloudinessIntegerList'][0]) \
                  & (vacationDataFrame['Cloudiness'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                    ['cloudinessIntegerList'][1]), :]

vacationDataFrame \
    = vacationDataFrame \
            .loc \
                [(vacationDataFrame['Wind Speed'] \
                      >= local_constant \
                            .weatherConditionsDictionary \
                                ['windSpeedIntegerList'][0]) 
                  & (vacationDataFrame['Wind Speed'] \
                         <= local_constant \
                                .weatherConditionsDictionary \
                                    ['windSpeedIntegerList'][1]), :]


log_function \
    .DebugReturnObjectWriteObject \
        (vacationDataFrame)

# %% [markdown]
# ## **2.2: Clean Vacation Data Set**

# %%
vacationDataFrame \
        .dropna \
            (inplace = True)

vacationDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (vacationDataFrame)

# %% [markdown]
# ## **2.3: Display Vacation Data Set**

# %%
captionString \
    = 'Table: 2.3: Vacation Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (vacationDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_41d4e caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_41d4e_row0_col0, #T_41d4e_row0_col1, #T_41d4e_row0_col2, #T_41d4e_row0_col6, #T_41d4e_row0_col7, #T_41d4e_row0_col8, #T_41d4e_row1_col0, #T_41d4e_row1_col1, #T_41d4e_row1_col2, #T_41d4e_row1_col3, #T_41d4e_row1_col7, #T_41d4e_row1_col8, #T_41d4e_row2_col0, #T_41d4e_row2_col1, #T_41d4e_row2_col2, #T_41d4e_row2_col3, #T_41d4e_row2_col4, #T_41d4e_row2_col6, #T_41d4e_row2_col7, #T_41d4e_row2_col8, #T_41d4e_row3_col0, #T_41d4e_row3_col1, #T_41d4e_row3_col2, #T_41d4e_row3_col7, #T_41d4e_row3_col8 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_41d4e_row0_col3, #T_41d4e_row0_col4, #T_41d4e_row1_col5, #T_41d4e_row2_col5, #T_41d4e_row3_col4, #T_41d4e_row3_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_41d4e_row0_col5, #T_41d4e_row1_col4, #T_41d4e_row1_col6, #T_41d4e_row3_col3, #T_41d4e_row3_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_41d4e">
#   <caption>Table: 2.3: Vacation Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_41d4e_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_41d4e_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_41d4e_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_41d4e_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_41d4e_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_41d4e_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_41d4e_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_41d4e_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_41d4e_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_41d4e_row0_col0" class="data row0 col0" >taghazout</td>
#       <td id="T_41d4e_row0_col1" class="data row0 col1" >30.54</td>
#       <td id="T_41d4e_row0_col2" class="data row0 col2" >-9.71</td>
#       <td id="T_41d4e_row0_col3" class="data row0 col3" >70.57° F</td>
#       <td id="T_41d4e_row0_col4" class="data row0 col4" >43%</td>
#       <td id="T_41d4e_row0_col5" class="data row0 col5" >4%</td>
#       <td id="T_41d4e_row0_col6" class="data row0 col6" >3.04</td>
#       <td id="T_41d4e_row0_col7" class="data row0 col7" >MA</td>
#       <td id="T_41d4e_row0_col8" class="data row0 col8" >2023-11-08 11:10:55</td>
#     </tr>
#     <tr>
#       <td id="T_41d4e_row1_col0" class="data row1 col0" >al bawiti</td>
#       <td id="T_41d4e_row1_col1" class="data row1 col1" >28.35</td>
#       <td id="T_41d4e_row1_col2" class="data row1 col2" >28.87</td>
#       <td id="T_41d4e_row1_col3" class="data row1 col3" >74.30° F</td>
#       <td id="T_41d4e_row1_col4" class="data row1 col4" >50%</td>
#       <td id="T_41d4e_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_41d4e_row1_col6" class="data row1 col6" >9.17</td>
#       <td id="T_41d4e_row1_col7" class="data row1 col7" >EG</td>
#       <td id="T_41d4e_row1_col8" class="data row1 col8" >2023-11-08 11:11:17</td>
#     </tr>
#     <tr>
#       <td id="T_41d4e_row2_col0" class="data row2 col0" >fort bragg</td>
#       <td id="T_41d4e_row2_col1" class="data row2 col1" >35.14</td>
#       <td id="T_41d4e_row2_col2" class="data row2 col2" >-79.01</td>
#       <td id="T_41d4e_row2_col3" class="data row2 col3" >78.66° F</td>
#       <td id="T_41d4e_row2_col4" class="data row2 col4" >45%</td>
#       <td id="T_41d4e_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_41d4e_row2_col6" class="data row2 col6" >4.61</td>
#       <td id="T_41d4e_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_41d4e_row2_col8" class="data row2 col8" >2023-11-08 11:08:26</td>
#     </tr>
#     <tr>
#       <td id="T_41d4e_row3_col0" class="data row3 col0" >xique xique</td>
#       <td id="T_41d4e_row3_col1" class="data row3 col1" >-10.82</td>
#       <td id="T_41d4e_row3_col2" class="data row3 col2" >-42.73</td>
#       <td id="T_41d4e_row3_col3" class="data row3 col3" >90.28° F</td>
#       <td id="T_41d4e_row3_col4" class="data row3 col4" >43%</td>
#       <td id="T_41d4e_row3_col5" class="data row3 col5" >4%</td>
#       <td id="T_41d4e_row3_col6" class="data row3 col6" >1.16</td>
#       <td id="T_41d4e_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_41d4e_row3_col8" class="data row3 col8" >2023-11-08 11:12:39</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **2.4: Display Vacation Locations**

# %%
function \
    .DisplayHVPlotFromDataFrame \
        (vacationDataFrame,
         'Figure 2.4: Vacation Locations',
         'City',
         'Humidity')
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity)

# %% [markdown]
# # <br> **Section 3: Hotel Locations**

# %% [markdown]
# ## **3.1: Add Hotel Column to DataFrame**

# %%
hotelDataFrame \
    = vacationDataFrame.copy()

hotelDataFrame \
    ['Hotel Name'] \
        = pd.Series \
            (dtype= 'str')

hotelDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (hotelDataFrame)

# %% [markdown]
# ## **3.2: Find Hotel Locations**

# %%
updatedHotelDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (hotelDataFrame,
             'Hotel Name',
             'accommodation.hotel',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedHotelDataFrame)
# Out:
# Starting hotel search...
#
#
# Located the following hotel...Riad Taghazout in taghazout, MA
#
#
# Located the following hotel...Old Oasis Hotel in al bawiti, EG
#
#
# Located the following hotel...Airborne Inn Lodging in fort bragg, US
#
#
# Located the following hotel...Hotel J. Macedo in xique xique, BR
#
#
# hotel search complete

# %% [markdown]
# ## **3.3: Display Hotel Data Set**

# %%
captionString \
    = 'Table: 3.3: Hotel Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedHotelDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_fa0b7 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_fa0b7_row0_col0, #T_fa0b7_row0_col1, #T_fa0b7_row0_col2, #T_fa0b7_row0_col6, #T_fa0b7_row0_col7, #T_fa0b7_row0_col8, #T_fa0b7_row0_col9, #T_fa0b7_row1_col0, #T_fa0b7_row1_col1, #T_fa0b7_row1_col2, #T_fa0b7_row1_col3, #T_fa0b7_row1_col7, #T_fa0b7_row1_col8, #T_fa0b7_row1_col9, #T_fa0b7_row2_col0, #T_fa0b7_row2_col1, #T_fa0b7_row2_col2, #T_fa0b7_row2_col3, #T_fa0b7_row2_col4, #T_fa0b7_row2_col6, #T_fa0b7_row2_col7, #T_fa0b7_row2_col8, #T_fa0b7_row2_col9, #T_fa0b7_row3_col0, #T_fa0b7_row3_col1, #T_fa0b7_row3_col2, #T_fa0b7_row3_col7, #T_fa0b7_row3_col8, #T_fa0b7_row3_col9 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_fa0b7_row0_col3, #T_fa0b7_row0_col4, #T_fa0b7_row1_col5, #T_fa0b7_row2_col5, #T_fa0b7_row3_col4, #T_fa0b7_row3_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_fa0b7_row0_col5, #T_fa0b7_row1_col4, #T_fa0b7_row1_col6, #T_fa0b7_row3_col3, #T_fa0b7_row3_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_fa0b7">
#   <caption>Table: 3.3: Hotel Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_fa0b7_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_fa0b7_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_fa0b7_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_fa0b7_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_fa0b7_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_fa0b7_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_fa0b7_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_fa0b7_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_fa0b7_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_fa0b7_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fa0b7_row0_col0" class="data row0 col0" >taghazout</td>
#       <td id="T_fa0b7_row0_col1" class="data row0 col1" >30.54</td>
#       <td id="T_fa0b7_row0_col2" class="data row0 col2" >-9.71</td>
#       <td id="T_fa0b7_row0_col3" class="data row0 col3" >70.57° F</td>
#       <td id="T_fa0b7_row0_col4" class="data row0 col4" >43%</td>
#       <td id="T_fa0b7_row0_col5" class="data row0 col5" >4%</td>
#       <td id="T_fa0b7_row0_col6" class="data row0 col6" >3.04</td>
#       <td id="T_fa0b7_row0_col7" class="data row0 col7" >MA</td>
#       <td id="T_fa0b7_row0_col8" class="data row0 col8" >2023-11-08 11:10:55</td>
#       <td id="T_fa0b7_row0_col9" class="data row0 col9" >Riad Taghazout</td>
#     </tr>
#     <tr>
#       <td id="T_fa0b7_row1_col0" class="data row1 col0" >al bawiti</td>
#       <td id="T_fa0b7_row1_col1" class="data row1 col1" >28.35</td>
#       <td id="T_fa0b7_row1_col2" class="data row1 col2" >28.87</td>
#       <td id="T_fa0b7_row1_col3" class="data row1 col3" >74.30° F</td>
#       <td id="T_fa0b7_row1_col4" class="data row1 col4" >50%</td>
#       <td id="T_fa0b7_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_fa0b7_row1_col6" class="data row1 col6" >9.17</td>
#       <td id="T_fa0b7_row1_col7" class="data row1 col7" >EG</td>
#       <td id="T_fa0b7_row1_col8" class="data row1 col8" >2023-11-08 11:11:17</td>
#       <td id="T_fa0b7_row1_col9" class="data row1 col9" >Old Oasis Hotel</td>
#     </tr>
#     <tr>
#       <td id="T_fa0b7_row2_col0" class="data row2 col0" >fort bragg</td>
#       <td id="T_fa0b7_row2_col1" class="data row2 col1" >35.14</td>
#       <td id="T_fa0b7_row2_col2" class="data row2 col2" >-79.01</td>
#       <td id="T_fa0b7_row2_col3" class="data row2 col3" >78.66° F</td>
#       <td id="T_fa0b7_row2_col4" class="data row2 col4" >45%</td>
#       <td id="T_fa0b7_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_fa0b7_row2_col6" class="data row2 col6" >4.61</td>
#       <td id="T_fa0b7_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_fa0b7_row2_col8" class="data row2 col8" >2023-11-08 11:08:26</td>
#       <td id="T_fa0b7_row2_col9" class="data row2 col9" >Airborne Inn Lodging</td>
#     </tr>
#     <tr>
#       <td id="T_fa0b7_row3_col0" class="data row3 col0" >xique xique</td>
#       <td id="T_fa0b7_row3_col1" class="data row3 col1" >-10.82</td>
#       <td id="T_fa0b7_row3_col2" class="data row3 col2" >-42.73</td>
#       <td id="T_fa0b7_row3_col3" class="data row3 col3" >90.28° F</td>
#       <td id="T_fa0b7_row3_col4" class="data row3 col4" >43%</td>
#       <td id="T_fa0b7_row3_col5" class="data row3 col5" >4%</td>
#       <td id="T_fa0b7_row3_col6" class="data row3 col6" >1.16</td>
#       <td id="T_fa0b7_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_fa0b7_row3_col8" class="data row3 col8" >2023-11-08 11:12:39</td>
#       <td id="T_fa0b7_row3_col9" class="data row3 col9" >Hotel J. Macedo</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **3.4: Display Hotel Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Humidity', 
       'Hotel Name', 
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedHotelDataFrame,
         'Figure 3.4: Hotel Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Country)

# %% [markdown]
# # <br> **Section 4: Restaurant Locations**

# %% [markdown]
# ## **4.1: Add Restaurant Column to DataFrame**

# %%
resturantDataFrame \
    = updatedHotelDataFrame.copy()

resturantDataFrame \
    ['Restaurant Name'] \
        = pd.Series \
            (dtype= 'str')

resturantDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (resturantDataFrame)

# %% [markdown]
# ## **4.2: Find Restaurant Locations**

# %%
updatedResturantDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (resturantDataFrame,
             'Restaurant Name',
             'catering.restaurant',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedResturantDataFrame)
# Out:
# Starting restaurant search...
#
#
# Located the following restaurant...La Terrasse d'Argana in taghazout, MA
#
#
# Located the following restaurant...Popular Restaurant in al bawiti, EG
#
#
# Located the following restaurant...El Tucan Mexican Restaurant in fort bragg, US
#
#
# Located the following restaurant...Companhia do Churrasco in xique xique, BR
#
#
# restaurant search complete

# %% [markdown]
# ## **4.3: Display Restaurant Data Set**

# %%
captionString \
    = 'Table: 4.3: Restaurant Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedResturantDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_b1b21 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_b1b21_row0_col0, #T_b1b21_row0_col1, #T_b1b21_row0_col2, #T_b1b21_row0_col6, #T_b1b21_row0_col7, #T_b1b21_row0_col8, #T_b1b21_row0_col9, #T_b1b21_row0_col10, #T_b1b21_row1_col0, #T_b1b21_row1_col1, #T_b1b21_row1_col2, #T_b1b21_row1_col3, #T_b1b21_row1_col7, #T_b1b21_row1_col8, #T_b1b21_row1_col9, #T_b1b21_row1_col10, #T_b1b21_row2_col0, #T_b1b21_row2_col1, #T_b1b21_row2_col2, #T_b1b21_row2_col3, #T_b1b21_row2_col4, #T_b1b21_row2_col6, #T_b1b21_row2_col7, #T_b1b21_row2_col8, #T_b1b21_row2_col9, #T_b1b21_row2_col10, #T_b1b21_row3_col0, #T_b1b21_row3_col1, #T_b1b21_row3_col2, #T_b1b21_row3_col7, #T_b1b21_row3_col8, #T_b1b21_row3_col9, #T_b1b21_row3_col10 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_b1b21_row0_col3, #T_b1b21_row0_col4, #T_b1b21_row1_col5, #T_b1b21_row2_col5, #T_b1b21_row3_col4, #T_b1b21_row3_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_b1b21_row0_col5, #T_b1b21_row1_col4, #T_b1b21_row1_col6, #T_b1b21_row3_col3, #T_b1b21_row3_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_b1b21">
#   <caption>Table: 4.3: Restaurant Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_b1b21_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_b1b21_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_b1b21_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_b1b21_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_b1b21_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_b1b21_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_b1b21_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_b1b21_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_b1b21_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_b1b21_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#       <th id="T_b1b21_level0_col10" class="col_heading level0 col10" >Restaurant Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b1b21_row0_col0" class="data row0 col0" >taghazout</td>
#       <td id="T_b1b21_row0_col1" class="data row0 col1" >30.54</td>
#       <td id="T_b1b21_row0_col2" class="data row0 col2" >-9.71</td>
#       <td id="T_b1b21_row0_col3" class="data row0 col3" >70.57° F</td>
#       <td id="T_b1b21_row0_col4" class="data row0 col4" >43%</td>
#       <td id="T_b1b21_row0_col5" class="data row0 col5" >4%</td>
#       <td id="T_b1b21_row0_col6" class="data row0 col6" >3.04</td>
#       <td id="T_b1b21_row0_col7" class="data row0 col7" >MA</td>
#       <td id="T_b1b21_row0_col8" class="data row0 col8" >2023-11-08 11:10:55</td>
#       <td id="T_b1b21_row0_col9" class="data row0 col9" >Riad Taghazout</td>
#       <td id="T_b1b21_row0_col10" class="data row0 col10" >La Terrasse d'Argana</td>
#     </tr>
#     <tr>
#       <td id="T_b1b21_row1_col0" class="data row1 col0" >al bawiti</td>
#       <td id="T_b1b21_row1_col1" class="data row1 col1" >28.35</td>
#       <td id="T_b1b21_row1_col2" class="data row1 col2" >28.87</td>
#       <td id="T_b1b21_row1_col3" class="data row1 col3" >74.30° F</td>
#       <td id="T_b1b21_row1_col4" class="data row1 col4" >50%</td>
#       <td id="T_b1b21_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_b1b21_row1_col6" class="data row1 col6" >9.17</td>
#       <td id="T_b1b21_row1_col7" class="data row1 col7" >EG</td>
#       <td id="T_b1b21_row1_col8" class="data row1 col8" >2023-11-08 11:11:17</td>
#       <td id="T_b1b21_row1_col9" class="data row1 col9" >Old Oasis Hotel</td>
#       <td id="T_b1b21_row1_col10" class="data row1 col10" >Popular Restaurant</td>
#     </tr>
#     <tr>
#       <td id="T_b1b21_row2_col0" class="data row2 col0" >fort bragg</td>
#       <td id="T_b1b21_row2_col1" class="data row2 col1" >35.14</td>
#       <td id="T_b1b21_row2_col2" class="data row2 col2" >-79.01</td>
#       <td id="T_b1b21_row2_col3" class="data row2 col3" >78.66° F</td>
#       <td id="T_b1b21_row2_col4" class="data row2 col4" >45%</td>
#       <td id="T_b1b21_row2_col5" class="data row2 col5" >0%</td>
#       <td id="T_b1b21_row2_col6" class="data row2 col6" >4.61</td>
#       <td id="T_b1b21_row2_col7" class="data row2 col7" >US</td>
#       <td id="T_b1b21_row2_col8" class="data row2 col8" >2023-11-08 11:08:26</td>
#       <td id="T_b1b21_row2_col9" class="data row2 col9" >Airborne Inn Lodging</td>
#       <td id="T_b1b21_row2_col10" class="data row2 col10" >El Tucan Mexican Restaurant</td>
#     </tr>
#     <tr>
#       <td id="T_b1b21_row3_col0" class="data row3 col0" >xique xique</td>
#       <td id="T_b1b21_row3_col1" class="data row3 col1" >-10.82</td>
#       <td id="T_b1b21_row3_col2" class="data row3 col2" >-42.73</td>
#       <td id="T_b1b21_row3_col3" class="data row3 col3" >90.28° F</td>
#       <td id="T_b1b21_row3_col4" class="data row3 col4" >43%</td>
#       <td id="T_b1b21_row3_col5" class="data row3 col5" >4%</td>
#       <td id="T_b1b21_row3_col6" class="data row3 col6" >1.16</td>
#       <td id="T_b1b21_row3_col7" class="data row3 col7" >BR</td>
#       <td id="T_b1b21_row3_col8" class="data row3 col8" >2023-11-08 11:12:39</td>
#       <td id="T_b1b21_row3_col9" class="data row3 col9" >Hotel J. Macedo</td>
#       <td id="T_b1b21_row3_col10" class="data row3 col10" >Companhia do Churrasco</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **4.4: Display Restaurant Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Hotel Name', 
       'Restaurant Name'
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedResturantDataFrame,
         'Figure 4.4: Restaurant Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name)

# %% [markdown]
# # <br> **Section 5: Tourism Attraction Locations**

# %% [markdown]
# ## **5.1: Add Tourism Attraction Column to DataFrame**

# %%
tourismAttractionDataFrame \
    = updatedResturantDataFrame.copy()

tourismAttractionDataFrame \
    ['Tourism Attraction'] \
        = pd.Series \
            (dtype= 'str')

tourismAttractionDataFrame \
    .reset_index \
        (drop = True, 
         inplace = True)


log_function \
    .DebugReturnObjectWriteObject \
        (tourismAttractionDataFrame)

# %% [markdown]
# ## **5.2: Find Tourism Attraction Locations**

# %%
updatedTourismAttractionDataFrame \
    = api_function \
        .ReturnUpdatedLocationDataFrame \
            (tourismAttractionDataFrame,
             'Tourism Attraction',
             'tourism.attraction',
             10000)


log_function \
    .DebugReturnObjectWriteObject \
        (updatedTourismAttractionDataFrame)
# Out:
# Starting tourism attraction search...
#
#
# Located the following tourism attraction...Taghazout Skatepark in taghazout, MA
#
#
# Located the following tourism attraction...English houses (ruins) in al bawiti, EG
#
#
# tourism attraction search complete

# %% [markdown]
# ## **5.3: Display Tourism Attraction Data Set**

# %%
captionString \
    = 'Table: 5.3: Tourism Attraction Locations'

currentStylerObject \
    = local_function \
        .ReturnCityWeatherStylerObjectStandardFormat \
            (updatedTourismAttractionDataFrame,
             captionString)

log_function \
    .ReturnStylerObjectSavePNGImage \
        (currentStylerObject,
         captionString)
# Out:
# <style type="text/css">
# #T_25e9a caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_25e9a_row0_col0, #T_25e9a_row0_col1, #T_25e9a_row0_col2, #T_25e9a_row0_col7, #T_25e9a_row0_col8, #T_25e9a_row0_col9, #T_25e9a_row0_col10, #T_25e9a_row0_col11, #T_25e9a_row1_col0, #T_25e9a_row1_col1, #T_25e9a_row1_col2, #T_25e9a_row1_col7, #T_25e9a_row1_col8, #T_25e9a_row1_col9, #T_25e9a_row1_col10, #T_25e9a_row1_col11 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# #T_25e9a_row0_col3, #T_25e9a_row0_col4, #T_25e9a_row0_col6, #T_25e9a_row1_col5 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: yellow;
# }
# #T_25e9a_row0_col5, #T_25e9a_row1_col3, #T_25e9a_row1_col4, #T_25e9a_row1_col6 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
#   background-color: lime;
# }
# </style>
# <table id="T_25e9a">
#   <caption>Table: 5.3: Tourism Attraction Locations</caption>
#   <thead>
#     <tr>
#       <th id="T_25e9a_level0_col0" class="col_heading level0 col0" >City</th>
#       <th id="T_25e9a_level0_col1" class="col_heading level0 col1" >Latitude</th>
#       <th id="T_25e9a_level0_col2" class="col_heading level0 col2" >Longitude</th>
#       <th id="T_25e9a_level0_col3" class="col_heading level0 col3" >Temperature</th>
#       <th id="T_25e9a_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_25e9a_level0_col5" class="col_heading level0 col5" >Cloudiness</th>
#       <th id="T_25e9a_level0_col6" class="col_heading level0 col6" >Wind Speed</th>
#       <th id="T_25e9a_level0_col7" class="col_heading level0 col7" >Country</th>
#       <th id="T_25e9a_level0_col8" class="col_heading level0 col8" >Date/Time</th>
#       <th id="T_25e9a_level0_col9" class="col_heading level0 col9" >Hotel Name</th>
#       <th id="T_25e9a_level0_col10" class="col_heading level0 col10" >Restaurant Name</th>
#       <th id="T_25e9a_level0_col11" class="col_heading level0 col11" >Tourism Attraction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_25e9a_row0_col0" class="data row0 col0" >taghazout</td>
#       <td id="T_25e9a_row0_col1" class="data row0 col1" >30.54</td>
#       <td id="T_25e9a_row0_col2" class="data row0 col2" >-9.71</td>
#       <td id="T_25e9a_row0_col3" class="data row0 col3" >70.57° F</td>
#       <td id="T_25e9a_row0_col4" class="data row0 col4" >43%</td>
#       <td id="T_25e9a_row0_col5" class="data row0 col5" >4%</td>
#       <td id="T_25e9a_row0_col6" class="data row0 col6" >3.04</td>
#       <td id="T_25e9a_row0_col7" class="data row0 col7" >MA</td>
#       <td id="T_25e9a_row0_col8" class="data row0 col8" >2023-11-08 11:10:55</td>
#       <td id="T_25e9a_row0_col9" class="data row0 col9" >Riad Taghazout</td>
#       <td id="T_25e9a_row0_col10" class="data row0 col10" >La Terrasse d'Argana</td>
#       <td id="T_25e9a_row0_col11" class="data row0 col11" >Taghazout Skatepark</td>
#     </tr>
#     <tr>
#       <td id="T_25e9a_row1_col0" class="data row1 col0" >al bawiti</td>
#       <td id="T_25e9a_row1_col1" class="data row1 col1" >28.35</td>
#       <td id="T_25e9a_row1_col2" class="data row1 col2" >28.87</td>
#       <td id="T_25e9a_row1_col3" class="data row1 col3" >74.30° F</td>
#       <td id="T_25e9a_row1_col4" class="data row1 col4" >50%</td>
#       <td id="T_25e9a_row1_col5" class="data row1 col5" >0%</td>
#       <td id="T_25e9a_row1_col6" class="data row1 col6" >9.17</td>
#       <td id="T_25e9a_row1_col7" class="data row1 col7" >EG</td>
#       <td id="T_25e9a_row1_col8" class="data row1 col8" >2023-11-08 11:11:17</td>
#       <td id="T_25e9a_row1_col9" class="data row1 col9" >Old Oasis Hotel</td>
#       <td id="T_25e9a_row1_col10" class="data row1 col10" >Popular Restaurant</td>
#       <td id="T_25e9a_row1_col11" class="data row1 col11" >English houses (ruins)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **5.4: Display Tourism Attraction Locations**

# %%
hoverColumnsListOfStrings \
    = ['Latitude', 
       'Longitude', 
       'City', 
       'Hotel Name', 
       'Restaurant Name',
       'Tourism Attraction',
       'Country']

function \
    .DisplayHVPlotFromDataFrame \
        (updatedTourismAttractionDataFrame,
         'Figure 5.4: Tourism Attraction Locations',
         'City',
         'Humidity',
         (-180, 180),
         (-55, 75),
         0.7,
         'OSM',
         hoverColumnsListOfStrings)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (City,Humidity,Hotel Name,Restaurant Name,Tourism Attraction,Country)

# %%
#log_subroutine \
#    .EndProgramExecution()
